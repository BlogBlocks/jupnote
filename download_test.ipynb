# %% [markdown]
# # ------  USING Feedparser  ------

# %% [markdown]
# http://pythonhosted.org/feedparser/

# %% [markdown]
# # Loads the NewsFeeds From 35 Sources
# # into an FTS3 Database

# %%
import sqlite3
import feedparser
import time
import sqlite3
Dbase = 'bigfeedfts.db'
conn = sqlite3.connect(Dbase)
c = conn.cursor()
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS bbctech 
USING FTS3(head, feed);
""")
count=0
while count<35:
    count=count+1
    # This is for posting my actual list has 35 sources
    if count==1:feed='http://feeds.bbci.co.uk/news/technology/rss.xml'
    if count==2:feed='http://www.cbn.com/cbnnews/us/feed/'
    d = feedparser.parse(feed)
    for post in d.entries:
        aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
        bb = `post.title + ": " + post.link + ""`
        conn = sqlite3.connect(Dbase)
        c = conn.cursor()
        c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
        conn.commit()
        conn.close()
        
        
conn = sqlite3.connect(Dbase)
c = conn.cursor()# Never
count=0
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    count=count+1
    print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# Does Online Crowdfunding Actually Reward Innovation?: https://slashdot.org/story/17/10/07/1750207/does-online-crowdfunding-actually-reward-innovation?utm_source=rss1.0mainlinkanon&utm_medium=feed
#
# Number : 2  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# New Video Peeks \Inside the Head\ of Perl Creator Larry Wall: https://developers.slashdot.org/story/17/10/07/0259243/new-video-peeks-inside-the-head-of-perl-creator-larry-wall?utm_source=rss1.0mainlinkanon&utm_medium=feed
#
# Number : 3  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
Dbase = 'bigfeedfts.db'
conn = sqlite3.connect(Dbase)
c = conn.cursor()
#c.execute('''
#CREATE TABLE IF NOT EXISTS bbctech
#(head text, feed text)
#''');
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS bbctech 
USING FTS3(head, feed);
""")
count=0
while count<35:
    count=count+1
    if count==1:feed='http://feeds.bbci.co.uk/news/technology/rss.xml'
    if count==2:feed='http://www.cbn.com/cbnnews/us/feed/'
    if count==3:feed='http://feeds.reuters.com/Reuters/worldNews'
    if count==4:feed='http://feeds.bbci.co.uk/news/technology/rss.xml'
    if count==5:feed='http://news.sky.com/info/rss'
    if count==6:feed='http://www.cbn.com/cbnnews/us/feed/'
    if count==7:feed='http://feeds.reuters.com/Reuters/domesticNews'
    if count==8:feed='http://news.yahoo.com/rss/'
    if count==9:feed='http://www.techradar.com/rss'
    if count==10:feed='https://www.wired.com/feed/rss'
    if count==11:feed='http://www.zdnet.com/zdnet.opml'
    if count==12:feed='http://www.computerweekly.com/rss/All-Computer-Weekly-content.xml'
    if count==13:feed='http://gadgets.ndtv.com/rss/feeds'
    if count==14:feed='http://feeds.arstechnica.com/arstechnica/index'        
    if count==15:feed='https://www.techworld.com/news/rss'
    if count==16:feed='https://www.infoworld.com/index.rss'        
    if count==18:feed='https://www.pcworld.com/index.rss'   
    if count==19:feed='http://tech.economictimes.indiatimes.com/rss/technology'
    if count==20:feed='https://www.technologyreview.com/stories.rss'        
    if count==21:feed='http://tech.economictimes.indiatimes.com/rss/topstories'
    if count==22:feed='http://feeds.feedburner.com/digit/latest-from-digit'
    if count==23:feed='http://feeds.techsoup.org/TechSoup_Articles'
    if count==24:feed='http://rss.sciam.com/ScientificAmerican-News?format=xml'
    if count==25:feed='https://www.sciencedaily.com/rss/all.xml'    
    if count==26:feed='http://feeds.nanowerk.com/nanowerk/agWB'
    if count==27:feed='http://feeds.nanowerk.com/NanowerkNanotechnologySpotlight'
    if count==28:feed='http://feeds.nanowerk.com/feedburner/NanowerkRoboticsNews'
    if count==29:feed='http://feeds.nanowerk.com/NanowerkSpaceExplorationNews'
    if count==30:feed='http://www.npr.org/rss/rss.php?id=1019'
    if count==31:feed='http://feeds.nature.com/news/rss/news_s16?format=xml'
    if count==32:feed='http://feeds.latimes.com/latimes/technology?format=xml'
    if count==33:feed='http://feeds.feedburner.com/BadAstronomyBlog?format=xml'
    if count==34:feed='http://feeds.newscientist.com/physics-math'
    if count==35:feed='http://rss.slashdot.org/Slashdot/slashdotMain'
    d = feedparser.parse(feed)
    for post in d.entries:
        aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
        bb = `post.title + ": " + post.link + ""`
        conn = sqlite3.connect(Dbase)
        c = conn.cursor()
        c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
        conn.commit()
        conn.close()
        
        
conn = sqlite3.connect(Dbase)
c = conn.cursor()# Never
count=0
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    count=count+1
    print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# Does Online Crowdfunding Actually Reward Innovation?: https://slashdot.org/story/17/10/07/1750207/does-online-crowdfunding-actually-reward-innovation?utm_source=rss1.0mainlinkanon&utm_medium=feed
#
# Number : 2  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# New Video Peeks \Inside the Head\ of Perl Creator Larry Wall: https://developers.slashdot.org/story/17/10/07/0259243/new-video-peeks-inside-the-head-of-perl-creator-larry-wall?utm_source=rss1.0mainlinkanon&utm_medium=feed
#
# Number : 3  -----
# Slashdot  https://slashdot.org   https://it.slashdot.org/story/17/10/08/2229222/the-case-against-biometric-ids?utm_source=rss1.0mainlinkanon&utm_medium=feed
# ...

# %% [markdown]
# # READS ENTIRE FTS3 DATABASE - bigfeedfts.db

# %%
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
req = 5000
for row in c.execute('SELECT * FROM bbctech'):    
    count=count+1
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    print"\nNumber :",count," -----\n",(row)    
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Number : 1  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41518351
# Websites hacked to mint crypto-cash: http://www.bbc.co.uk/news/technology-41518351
#
# Number : 2  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41518351
# 100 Women: Five things I learned as a woman in Silicon Valley: http://www.bbc.co.uk/news/world-us-canada-41544037
#
# Number : 3  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41518351
# Scam baiter: Why I risk death threats to expose online cons: http://www.bbc.co.uk/news/technology-41518352
#
# Number : 4  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41518351
# Internet speed guarantees must be realistic, says Ofcom: http://www.bbc.co.uk/news/technology-41524650
#
# Number : 5  -----
# ...

# %%
import sqlite3
import sys
conn = sqlite3.connect('collection.db')
c = conn.cursor()
count=0
# limits query to 1000
req=1000
search = raw_input("Search : ")

for row in c.execute('SELECT rowid,* FROM tweets WHERE text MATCH ?', (search,)):    
    count=count+1
    
    print count,"-",(row)[1]," -- by",(row)[2],"\n"
    if count > req:
        conn.close()
        sys.exit()

# %% [markdown]
# # -------------------------------------------------------

# %% [markdown]
# # SEARCHING the database ( raw_input )

# %%
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
req = 5000
search = raw_input("Search : ")

for row in c.execute('SELECT rowid,* FROM bbctech WHERE feed MATCH ?', (search,)):    
#for row in c.execute('SELECT * FROM bbctech WHERE feed LIKE "%phone%"'):    
    count=count+1
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    print"\nNumber :",count," -----\n",(row)    
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : flight
#
# Number : 1  -----
# (499, uRSS Feeds  : RSS Feed - NDTV Gadgets360.com  http://gadgets.ndtv.com   http://gadgets.ndtv.com/games/news/gran-turismo-sport-demo-download-size-release-date-start-time-ps4-ps4-pro-1760197
# TRAI Floats Consultation Paper for In-Flight Connectivity Services: http://gadgets.ndtv.com/telecom/news/trai-floats-consultation-paper-for-in-flight-connectivity-services-1756855

# %% [markdown]
# # Get a specific ROWID

# %%
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
req = 5000
search = raw_input("Get by ROWID : ")

for row in c.execute('SELECT rowid,* FROM bbctech WHERE rowid=?', (search,)):    
#for row in c.execute('SELECT * FROM bbctech WHERE feed LIKE "%phone%"'):    
    count=count+1
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    print"\nNumber :",count," -----\n",(row)    
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Get by ROWID : 499
#
# Number : 1  -----
# (499, uRSS Feeds  : RSS Feed - NDTV Gadgets360.com  http://gadgets.ndtv.com   http://gadgets.ndtv.com/games/news/gran-turismo-sport-demo-download-size-release-date-start-time-ps4-ps4-pro-1760197
# TRAI Floats Consultation Paper for In-Flight Connectivity Services: http://gadgets.ndtv.com/telecom/news/trai-floats-consultation-paper-for-in-flight-connectivity-services-1756855

# %%
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
req = 5000
for row in c.execute('SELECT * FROM bbctech WHERE feed LIKE "%phone%"'):    
    count=count+1
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    print"\nNumber :",count," -----\n",(row)    
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Number : 1  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/business-41343586
# Google signs $1.1bn HTC smartphone deal: http://www.bbc.co.uk/news/business-41343586
#
# Number : 2  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/business-41343586
# Smartphone sales boom with over-55s: http://www.bbc.co.uk/news/technology-41319684
#
# Number : 3  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/business-41343586
# Apple\s iOS 11 kills old 32-bit iPhone and iPad apps: http://www.bbc.co.uk/news/technology-41319675
#
# Number : 4  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/business-41343586
# Hands on with the new iPhone X: http://www.bbc.co.uk/news/technology-41249273
#
# Number : 5  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/business-41343586
# ...

# %% [markdown]
# # SEARCH USING INPUT --  txt = raw_input("What are you looking for?")

# %%
# WORKS
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
txt = raw_input("What are you looking for?")

for row in c.execute("SELECT * FROM bbctech WHERE feed MATCH ?", (txt,)):
    data = c.fetchall()
    data=data.replace('(u"(u','\n')
    print data,"\n-----\n","\n"
# Out:
# What are you looking for?tech
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-1-ac6788bdb96d> in <module>()
#       6 txt = raw_input("What are you looking for?")
#       7
# ----> 8 for row in c.execute("SELECT * FROM bbctech WHERE feed MATCH ?", (txt,)):
#       9     data = c.fetchall()
#      10     data=data.replace('(u"(u','\n')
#
# OperationalError: no such table: bbctech

# %% [markdown]
# # Limited Amount of Results  --   req=50

# %%
# WORKS
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
# Limited Amount of Results
req=50
num = raw_input("What are you looking for?")

for row in c.execute("SELECT * FROM bbctech WHERE feed MATCH ?", (num,)):
    row=str(row)
    row=row.replace("(u\"(u","");row=row.replace("', u'","  ");
    row=row.replace("u'"," ");row=row.replace(')", u" ', "\n");
    row=row.replace(" http://","\nhttp://");row=row.replace('")','')
    row=row.replace("'","");row=row.replace("#tk.rss_all", "")
    count=count+1
    print "\n",count,"-----\n",(row)
    if count > req:
        conn.close()
        sys.exit()
# Out:
# What line are you looking for?rss
#
# 1 -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html
# IDG Contributor Network: Visual automated CI/CD is essential for great devops: https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html
#
# 2 -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html
# IBM open-sources a microservices-friendly Java app server: https://www.infoworld.com/article/3227167/java/ibm-open-sources-a-microservices-friendly-java-app-server.html
#
# 3 -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html
# ...

# %% [markdown]
# # Verify a database Integrity

# %%
# !sqlite3 bigfeed2.db "PRAGMA integrity_check"
# Out:
# ok

# %%
# WORKS
import sqlite3
import sys
conn = sqlite3.connect('bigfeedfts.db')
c = conn.cursor()# Never 
count=0
req=4
num = raw_input("What line are you looking for?")

for row in c.execute("SELECT * FROM bbctech WHERE feed MATCH ?", (num,)):
    count=count+1
    print(row),"\n-----\n"
    if count > req:
        conn.close()
        sys.exit()
# Out:
# What line are you looking for?Time
# (u"(u'RSS Feeds  : RSS Feed - NDTV Gadgets360.com', u'http://gadgets.ndtv.com/', u'http://gadgets.ndtv.com/transportation/news/blackberry-delphi-partner-on-self-driving-car-operating-system-1753167')", u"u'FIFA 18 Release Date, Price, Editions, Preload Time, PC Specifications, and More: http://gadgets.ndtv.com/games/features/fifa-18-release-date-preload-time-price-editions-download-size-ps4-xbox-one-1752541'")
# -----
#
# (u"(u'RSS Feeds  : RSS Feed - NDTV Gadgets360.com', u'http://gadgets.ndtv.com/', u'http://gadgets.ndtv.com/transportation/news/blackberry-delphi-partner-on-self-driving-car-operating-system-1753167')", u"u'Vodafone Offers Up to Rs. 900 Additional Talk Time to Lava Feature Phone Users: http://gadgets.ndtv.com/telecom/news/vodafone-india-lava-partnership-rs-900-cash-back-feature-phones-1752123'")
# -----
#
# ...

# %% [markdown]
# # NON-FTS Search

# %%
import sqlite3
import feedparser
import time
import sqlite3
Dbase = 'test4.db'
conn = sqlite3.connect(Dbase)
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');
count=0
while count<8:
    count=count+1
    if count==3:feed='http://www.zdnet.com/zdnet.opml'
    d = feedparser.parse(feed)
    for post in d.entries:
        aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
        bb = `post.title + ": " + post.link + ""`
        conn = sqlite3.connect(Dbase)
        c = conn.cursor()
        c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
        conn.commit()
        conn.close()
conn = sqlite3.connect(Dbase)
c = conn.cursor()# Never
count=0
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    count=count+1
    print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html#tk.rss_all
# 74% off Vansky Bias Lighting for HDTV USB LED Multi Color Strip Accent Lighting - Deal Alert: https://www.infoworld.com/article/3088079/computers-accessories/74-off-vansky-bias-lighting-for-hdtv-usb-led-multi-color-strip-accent-lighting-deal-alert.html#tk.rss_all
#
# Number : 2  -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html#tk.rss_all
# IDG Contributor Network: Using big data to improve customer experience and financial results: https://www.infoworld.com/article/3224009/big-data/using-big-data-to-improve-customer-experience-and-financial-results.html#tk.rss_all
#
# Number : 3  -----
# ...

# %% [markdown]
# # MISC STUFF

# %%
import sqlite3
import feedparser
import time
import sqlite3
Dbase = 'test3.db'
conn = sqlite3.connect(Dbase)
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');
count=0
while count<8:
    count=count+1
    if count==1:feed='http://www.techradar.com/rss'
    if count==2:feed='https://www.wired.com/feed/rss'
    if count==3:feed='http://www.zdnet.com/zdnet.opml'
    if count==4:feed='http://www.computerweekly.com/rss/All-Computer-Weekly-content.xml'
    if count==5:feed='http://gadgets.ndtv.com/rss/feeds'
    if count==6:feed='http://feeds.arstechnica.com/arstechnica/index'
    if count==7:feed='https://www.techworld.com/news/rss'
    if count==8:feed='https://www.infoworld.com/index.rss'
    d = feedparser.parse(feed)
    for post in d.entries:
        aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
        bb = `post.title + ": " + post.link + ""`
        conn = sqlite3.connect(Dbase)
        c = conn.cursor()
        c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
        conn.commit()
        conn.close()
conn = sqlite3.connect(Dbase)
c = conn.cursor()# Never
count=0
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
    row=str(row)
    row=row.replace("(u","");row=row.replace('", u"u',"\n")
    row=row.replace("/', u'","   ");row=row.replace('"',"")
    row=row.replace("', u'","  ");row=row.replace("')","  ")
    row=row.replace("'","");row=row.replace("  , uu","\n")
    count=count+1
    print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html#tk.rss_all
# 74% off Vansky Bias Lighting for HDTV USB LED Multi Color Strip Accent Lighting - Deal Alert: https://www.infoworld.com/article/3088079/computers-accessories/74-off-vansky-bias-lighting-for-hdtv-usb-led-multi-color-strip-accent-lighting-deal-alert.html#tk.rss_all
#
# Number : 2  -----
# InfoWorld  https://www.infoworld.com  https://www.infoworld.com/article/3223875/devops/visual-automated-cicd-is-essential-for-great-devops.html#tk.rss_all
# IDG Contributor Network: Using big data to improve customer experience and financial results: https://www.infoworld.com/article/3224009/big-data/using-big-data-to-improve-customer-experience-and-financial-results.html#tk.rss_all
#
# Number : 3  -----
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
Dbase = 'news.db'
conn = sqlite3.connect(Dbase)
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');
A_In='http://feeds.bbci.co.uk/news/technology/rss.xml'
B_In='http://www.cbn.com/cbnnews/us/feed/'
C_In='http://feeds.reuters.com/Reuters/worldNews'
D_In='http://feeds.bbci.co.uk/news/technology/rss.xml'
E_In='http://news.sky.com/info/rss'
F_In='http://www.cbn.com/cbnnews/us/feed/'
G_In='http://feeds.reuters.com/Reuters/domesticNews'
H_In='http://news.yahoo.com/rss/'
count=0
d = feedparser.parse(A_In)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect(Dbase)
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect(Dbase)
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41306321
# Samsung Galaxy Note 8: A giant phone: http://www.bbc.co.uk/news/technology-41010143
#
# Number : 2  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41306321
# Sony phone app takes 3D clone snaps: http://www.bbc.co.uk/news/technology-41111442
#
# Number : 3  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41306321
# LG\s V30 smartphone \leaves gimmicks behind\: http://www.bbc.co.uk/news/technology-41114590
#
# Number : 4  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41306321
# Hands on with the new iPhone X: http://www.bbc.co.uk/news/technology-41249273
#
# Number : 5  -----
# BBC News - Technology  http://www.bbc.co.uk/news   http://www.bbc.co.uk/news/technology-41306321
# ...

# %% [markdown]
# !wget -O BBCTECH.xml http://feeds.bbci.co.uk/news/technology/rss.xml

# %% [markdown]
# # Looking at an actual Feed --   BBCTECH.xml

# %% [raw]
# # %load BBCTECH.xml
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
# <rss xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:atom="http://www.w3.org/2005/Atom" version="2.0" xmlns:media="http://search.yahoo.com/mrss/">
#     <channel>
#         <title><![CDATA[BBC News - Technology]]></title>
#         <description><![CDATA[BBC News - Technology]]></description>
#         <link>http://www.bbc.co.uk/news/</link>
#
#             <url>http://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif</url>
#             <title>BBC News - Technology</title>
#             <link>http://www.bbc.co.uk/news/</link>
#
#         <generator>RSS for Node</generator>
#         <lastBuildDate>Tue, 19 Sep 2017 23:25:00 GMT</lastBuildDate>
#         <copyright><![CDATA[Copyright: (C) British Broadcasting Corporation, see http://news.bbc.co.uk/2/hi/help/rss/4498287.stm for terms and conditions of reuse.]]></copyright>
#         <language><![CDATA[en-gb]]></language>
#         <ttl>15</ttl>
#         <item>
#             <title><![CDATA[Manchester police still relies on Windows XP]]></title>
#             <description><![CDATA[More than 20% of Greater Manchester Police's PCs run on the operating system, posing a hack risk.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41306321</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41306321</guid>
#             <pubDate>Tue, 19 Sep 2017 23:06:34 GMT</pubDate>
#             <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/6F44/production/_97848482_524eaf4a-a303-4fdd-917f-0c06add48710.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Google launches UK 'anti-terror fund']]></title>
#             <description><![CDATA[Google will give UK £1m to counter extremism as part of wider plans to deal with such content on its platforms.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41320171</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41320171</guid>
#             <pubDate>Tue, 19 Sep 2017 23:08:04 GMT</pubDate>
#             <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk/0596/production/_95203410_youtube.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Smartphone sales boom with over-55s]]></title>
#             <description><![CDATA[A study indicates that 71% of 55-to-75 year olds in the UK now own an app-capable handset.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41319684</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41319684</guid>
#             <pubDate>Tue, 19 Sep 2017 23:09:17 GMT</pubDate>
#             <media:thumbnail width="2048" height="1152" url="http://c.files.bbci.co.uk/930E/production/_97864673_mediaitem97864672.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Apple's iOS 11 kills old 32-bit iPhone and iPad apps]]></title>
#             <description><![CDATA[Apple's latest mobile operating system will not launch several ageing educational apps and games.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41319675</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41319675</guid>
#             <pubDate>Tue, 19 Sep 2017 12:28:44 GMT</pubDate>
#             <media:thumbnail width="1280" height="720" url="http://c.files.bbci.co.uk/A9B6/production/_97864434_mediaitem97864433.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Is Amazon recommending bomb ingredients?]]></title>
#             <description><![CDATA[What are Amazon's algorithms recommending when it comes to purchasing the ingredients to make a bomb?]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41320375</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41320375</guid>
#             <pubDate>Tue, 19 Sep 2017 15:27:30 GMT</pubDate>
#             <media:thumbnail width="976" height="549" url="http://c.files.bbci.co.uk
link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/business-41088196</guid>
#             <pubDate>Thu, 31 Aug 2017 23:03:14 GMT</pubDate>
#             <media:thumbnail width="1024" height="576" url="http://c.files.bbci.co.uk/8338/production/_97629533_sky-taxi_010917_cps-rta.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Hands on with the new iPhone X]]></title>
#             <description><![CDATA[Apple has announced a new iPhone that will cost $999. Is it worth the money? The BBC's Dave Lee got hands on with the much anticipated device.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41249273</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41249273</guid>
#             <pubDate>Tue, 12 Sep 2017 20:57:30 GMT</pubDate>
#             <media:thumbnail width="1024" height="576" url="http://c.files.bbci.co.uk/17CD9/production/_97779479_p05fx3nl.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[LG's V30 smartphone 'leaves gimmicks behind']]></title>
#             <description><![CDATA[The device has an OLED display and advanced camera features but no second screen or add-on modules.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41114590</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41114590</guid>
#             <pubDate>Thu, 31 Aug 2017 18:57:32 GMT</pubDate>
#             <media:thumbnail width="1024" height="576" url="http://c.files.bbci.co.uk/16596/production/_97624519_p05dtk6f.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Sony phone app takes 3D clone snaps]]></title>
#             <description><![CDATA[Software creates detailed 3D scans of any object using just a phone's camera and motion sensor.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41111442</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41111442</guid>
#             <pubDate>Thu, 31 Aug 2017 11:08:50 GMT</pubDate>
#             <media:thumbnail width="1024" height="576" url="http://c.files.bbci.co.uk/24FF/production/_97617490_p05dsbpq.jpg"/>
#         </item>
#         <item>
#             <title><![CDATA[Samsung Galaxy Note 8: A giant phone]]></title>
#             <description><![CDATA[Samsung puts the disastrous Note 7 behind it with a follow-up that is both bigger and more costly.]]></description>
#             <link>http://www.bbc.co.uk/news/technology-41010143</link>
#             <guid isPermaLink="true">http://www.bbc.co.uk/news/technology-41010143</guid>
#             <pubDate>Wed, 23 Aug 2017 15:01:42 GMT</pubDate>
#             <media:thumbnail width="1024" height="575" url="http://c.files.bbci.co.uk/16A55/production/_97475729_p05d1d4t.jpg"/>
#         </item>
#     </channel>
# </rss>

# %%
import sqlite3
conn = sqlite3.connect('news.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid'):
        row=str(row)
        row=row.replace("(u"," ")
        row=row.replace('", u"u',"\n")
        print(row),"\n-----\n"
# Out:
#  " 'BBC News - Technology', u'http://www.bbc.co.uk/news/', u'http://www.bbc.co.uk/news/technology-41306321')
# 'Manchester police still relies on Windows XP: http://www.bbc.co.uk/news/technology-41306321'")
# -----
#
#  " 'BBC News - Technology', u'http://www.bbc.co.uk/news/', u'http://www.bbc.co.uk/news/technology-41306321')", u'u"Google launches UK \'anti-terror fund\': http://www.bbc.co.uk/news/technology-41320171"')
# -----
#
#  " 'BBC News - Technology', u'http://www.bbc.co.uk/news/', u'http://www.bbc.co.uk/news/technology-41306321')
# 'Smartphone sales boom with over-55s: http://www.bbc.co.uk/news/technology-41319684'")
# -----
#
#  " 'BBC News - Technology', u'http://www.bbc.co.uk/news/', u'http://www.bbc.co.uk/news/technology-41306321')
# 'Theresa May to warn tech firms over terror content: http://www.bbc.co.uk/news/uk-politics-41327816'")
# -----
#
# ...

# %% [markdown]
# import feedparser
# import time
# d = feedparser.parse('http://feeds.bbci.co.uk/news/technology/rss.xml')
# for post in d.entries:
#     print d['feed']['title'],d['feed']['link'],"\n",d.entries[0]['link']
#     time.sleep(1)
#     print post.title + ": " + post.link + ""

# %% [markdown]
# import feedparser
# import time
# d = feedparser.parse('http://feeds.bbci.co.uk/news/technology/rss.xml')
# print d['feed']['title'],d['feed']['link'],"\n",d.entries[0]['link']
# for post in d.entries:
#     time.sleep(1)
#     print post.title + ": " + post.link + ""

# %% [markdown]
# import feedparser
# d = feedparser.parse('http://feeds.bbci.co.uk/news/technology/rss.xml')

# %% [markdown]
# print d['feed']['title']

# %% [markdown]
# print d['feed']['link']

# %% [markdown]
# print d.feed.subtitle

# %% [markdown]
# print len(d['entries'])

# %% [markdown]
# print d['entries'][0]['title']

# %% [markdown]
# print d.entries[0]['link']

# %% [markdown]
# for post in d.entries:
#     print post.title + ": " + post.link + ""

# %% [markdown]
# # ------------------------------------------------------

# %% [markdown]
# print d.headers

# %% [markdown]
# print d.headers.get('content-type')

# %% [markdown]
# # List of RSS NEWS FEEDS:
# https://www.repeatserver.com/RSSFeedList.aspx

# %%
import sqlite3
import feedparser
import time
import sqlite3
conn = sqlite3.connect('news.db')
#conn = sqlite3.connect('testrss.db')
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');

test01 = 'http://feeds.feedburner.com/TechCrunch/'
test02 = 'http://feeds.feedburner.com/crunchgear'
test03 = 'http://feeds.feedburner.com/TechCrunch/Twitter'
test04 = 'https://www.cnet.com/cnet-podcasts/'
test05 = 'https://www.cnet.com/rss/news/'
    
    
count=0
d = feedparser.parse(test01)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect('newnews.db')
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect('newnews.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        row=row.replace(" \\u2013", "")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/Techcrunch/~3/oGIeeT4wFG0/
# Citizen\\u2019s controversial crime tracker expands to SF, picks up $12 million from Sequoia: http://feedproxy.google.com/~r/Techcrunch/~3/GL41onayR08/
#
# Number : 2  -----
# TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/Techcrunch/~3/oGIeeT4wFG0/
# A bunch of Amazon customers were told about a purchase on their non-existent baby registries: http://feedproxy.google.com/~r/Techcrunch/~3/zq4Cal7y2QA/
#
# Number : 3  -----
# TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/Techcrunch/~3/oGIeeT4wFG0/
# Future astronauts could \\u2018feel\\u2019 alien ground with new space boots: http://feedproxy.google.com/~r/Techcrunch/~3/oKcbS7MJCPc/
#
# Number : 4  -----
# TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/Techcrunch/~3/oGIeeT4wFG0/
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
conn = sqlite3.connect('news.db')
#conn = sqlite3.connect('testrss.db')
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');

test01 = 'http://feeds.feedburner.com/TechCrunch/'
test02 = 'http://feeds.feedburner.com/crunchgear'
test03 = 'http://feeds.feedburner.com/TechCrunch/Twitter'
test04 = 'https://www.cnet.com/cnet-podcasts/'
test05 = 'https://www.cnet.com/rss/news/'
    
    
count=0
d = feedparser.parse(test02)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect('newnews.db')
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect('newnews.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        row=row.replace(" \\u2013", "")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# Gadgets \\u2013 TechCrunch  https://techcrunch.com  https://techcrunch.com/2017/09/19/does-siri-sound-different-today-heres-why/?ncid=rss
# Kuri, the cutest home robot, has learned how to dance: https://techcrunch.com/2017/09/14/kuri-the-cutest-home-robot-has-learned-how-to-dance/?ncid=rss
#
# Number : 2  -----
# Gadgets \\u2013 TechCrunch  https://techcrunch.com  https://techcrunch.com/2017/09/19/does-siri-sound-different-today-heres-why/?ncid=rss
# Tesla files patent for mobile battery swapping rig: https://techcrunch.com/2017/09/15/tesla-files-patent-for-mobile-battery-swapping-rig/?ncid=rss
#
# Number : 3  -----
# Gadgets \\u2013 TechCrunch  https://techcrunch.com  https://techcrunch.com/2017/09/19/does-siri-sound-different-today-heres-why/?ncid=rss
# South Park trolled Amazon Echo owners in the best way possible: https://techcrunch.com/2017/09/15/south-park-trolled-amazon-echo-owners-in-the-best-way-possible/?ncid=rss
#
# Number : 4  -----
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
conn = sqlite3.connect('news.db')
#conn = sqlite3.connect('testrss.db')
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');

test01 = 'http://feeds.feedburner.com/TechCrunch/'
test02 = 'http://feeds.feedburner.com/crunchgear'
test03 = 'http://feeds.feedburner.com/TechCrunch/Twitter'
test04 = 'https://www.cnet.com/cnet-podcasts/'
test05 = 'https://www.cnet.com/rss/news/'
    
    
count=0
d = feedparser.parse(test03)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect('newnews.db')
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect('newnews.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        row=row.replace(" \\u2013", "")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Tech is not winning the battle against white supremacy: http://feedproxy.google.com/~r/techcrunch/twitter/~3/nc7gu9e0KgQ/
#
# Number : 2  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Alt-social network Gab booted from Google Play Store for hate speech: http://feedproxy.google.com/~r/techcrunch/twitter/~3/ugsr_eYo1dc/
#
# Number : 3  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Let\\u2019s review some of tech\\u2019s big second quarter financial stories: http://feedproxy.google.com/~r/techcrunch/twitter/~3/13OSLQZxV98/
#
# Number : 4  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
conn = sqlite3.connect('news.db')
#conn = sqlite3.connect('testrss.db')
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');

test01 = 'http://feeds.feedburner.com/TechCrunch/'
test02 = 'http://feeds.feedburner.com/crunchgear'
test03 = 'http://feeds.feedburner.com/TechCrunch/Twitter'
test04 = 'https://www.cnet.com/cnet-podcasts/'
test05 = 'https://www.cnet.com/rss/news/'
    
    
count=0
d = feedparser.parse(test04)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect('newnews.db')
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect('newnews.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        row=row.replace(" \\u2013", "")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Tech is not winning the battle against white supremacy: http://feedproxy.google.com/~r/techcrunch/twitter/~3/nc7gu9e0KgQ/
#
# Number : 2  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Alt-social network Gab booted from Google Play Store for hate speech: http://feedproxy.google.com/~r/techcrunch/twitter/~3/ugsr_eYo1dc/
#
# Number : 3  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# Let\\u2019s review some of tech\\u2019s big second quarter financial stories: http://feedproxy.google.com/~r/techcrunch/twitter/~3/13OSLQZxV98/
#
# Number : 4  -----
# Twitter \\u2013 TechCrunch  https://techcrunch.com  http://feedproxy.google.com/~r/techcrunch/twitter/~3/v387S7WdRF4/
# ...

# %%
import sqlite3
import feedparser
import time
import sqlite3
conn = sqlite3.connect('news.db')
#conn = sqlite3.connect('testrss.db')
c = conn.cursor()
c.execute('''
CREATE TABLE IF NOT EXISTS bbctech
(head text, feed text)
''');

test01 = 'http://feeds.feedburner.com/TechCrunch/'
test02 = 'http://feeds.feedburner.com/crunchgear'
test03 = 'http://feeds.feedburner.com/TechCrunch/Twitter'
test04 = 'https://www.cnet.com/cnet-podcasts/'
test05 = 'https://www.cnet.com/rss/news/'
    
    
count=0
d = feedparser.parse(test05)
for post in d.entries:
    aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
    bb = `post.title + ": " + post.link + ""`
    conn = sqlite3.connect('newnews.db')
    c = conn.cursor()
    c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
    conn.commit()
    conn.close()
conn = sqlite3.connect('newnews.db')
c = conn.cursor()# Never 
for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
        row=str(row)
        row=row.replace("(u","");row=row.replace('", u"u',"\n")
        row=row.replace("/', u'","   ");row=row.replace('"',"")
        row=row.replace("', u'","  ");row=row.replace("')","  ")
        row=row.replace("'","");row=row.replace("  , uu","\n")
        row=row.replace(" \\u2013", "")
        count=count+1
        print"\nNumber :",count," -----\n",(row)
# Out:
# Number : 1  -----
# CNET News  https://www.cnet.com/#ftag=CAD590a51e  https://www.cnet.com/news/amazon-reportedly-working-on-alexa-powered-smart-glasses/#ftag=CAD590a51e
# NASA astronaut adopts unusual \pets\ in space     - CNET: https://www.cnet.com/news/nasa-astronaut-pets-balloon-animals-international-space-station-iss/#ftag=CAD590a51e
#
# Number : 2  -----
# CNET News  https://www.cnet.com/#ftag=CAD590a51e  https://www.cnet.com/news/amazon-reportedly-working-on-alexa-powered-smart-glasses/#ftag=CAD590a51e
# Buy the iPhone 8 Plus now or wait for the iPhone X? (The 3:59, Ep. 286)     - CNET: https://www.cnet.com/news/buy-the-iphone-8-plus-now-or-wait-for-the-iphone-x-the-359-ep-286/#ftag=CAD590a51e
#
# Number : 3  -----
# CNET News  https://www.cnet.com/#ftag=CAD590a51e  https://www.cnet.com/news/amazon-reportedly-working-on-alexa-powered-smart-glasses/#ftag=CAD590a51e
# ...
