# %% [markdown]
# # API Twitter Search

# %%
import sys
sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
import Key
from random import randint

HashTag = raw_input("HashTag  : ") or "CNN"

CONSUMER_KEY = Key.twiter()[0]
CONSUMER_SECRET = Key.twiter()[1]
ACCESS_KEY = Key.twiter()[2]
ACCESS_SECRET = Key.twiter()[3]
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY,ACCESS_SECRET)

filein = open('newtest.txt', 'a')
txt = twitter.search(q=HashTag)
txt = str(txt)
filein.write(txt)
filein.close()

print txt
# Out:
# HashTag  : mistrust
# {u'search_metadata': {u'count': 15, u'completed_in': 0.346, u'max_id_str': u'916241220753674241', u'since_id_str': u'0', u'next_results': u'?max_id=916232087098855423&q=mistrust&include_entities=1', u'refresh_url': u'?since_id=916241220753674241&q=mistrust&include_entities=1', u'since_id': 0, u'query': u'mistrust', u'max_id': 916241220753674241}, u'statuses': [{u'contributors': None, u'truncated': False, u'text': u'@ahhhhdatslovely Anyone exposed to Irish kids tv in the early to mid 90s has a justifiable mistrust of the puppet community', u'is_quote_status': False, u'in_reply_to_status_id': 916240568145104896, u'id': 916241220753674241, u'favorite_count': 1, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 2379290894, u'indices': [0, 16], u'id_str': u'2379290894', u'screen_name': u'ahhhhdatslovely', u'name': u'TITSuya Naito'}], u'hashtags': [], u'urls': []}, u'retweeted': False, u'coordinates': None, u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', u'in_reply_to_screen_name': u'ahhhhdatslovely', u'in_reply_to_user_id': 2379290894, u'retweet_count': 0, u'id_str': u'916241220753674241', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 67001515, u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/57840354/Main_3.jpg', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/760032849/Piktcha_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 348, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'67001515', u'profile_background_color': u'C0DEED', u'listed_count': 50, u'is_translation_enabled': False, u'utc_offset': 3600, u'statuses_count': 28059, u'description': u"I'm the last of the ancient Dul Cassian Royal Line & I also enjoy reading", u'friends_count': 2182, u'location': u'Atlantis aka Ireland', u'profile_link_color': u'0084B4', u'profile_image_url': u'http://pbs.twimg.com/profile_images/760032849/Piktcha_normal.jpg', u'following': False, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/67001515/1478388573', u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/57840354/Main_3.jpg', u'screen_name': u'shanekse85', u'lang': u'en', u'profile_background_tile': True, u'favourites_count': 2063, u'name': u'Shane Kaiiieee(!!)ly', u'notifications': False, u'url': None, u'created_at': u'Wed Aug 19 13:39:30 +0000 2009', u'contributors_enabled': False, u'time_zone': u'Dublin', u'protected': False, u'default_profile': False, u'is_translator': False}, u'geo': None, u'in_reply_to_user_id_str': u'2379290894', u'lang': u'en', u'created_at': u'Fri Oct 06 09:58:24 +0000 2017', u'in_reply_to_status_id_str': u'916240568145104896', u'place': None, u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'}}, {u'contributors': None, u'truncated': False, u'text': u"@OzzieBlossie Yes, your news media doesn't generate paranoia and mistrust like the US media does.", u'is_quote_status': False, u'in_reply_to_status_id': 916240198656126976, u'id': 916241060401205249, u'favorite_count': 0, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 824468305582845954, u'indices': [0, 13], u'id_str': u'824468305582845954', u'screen_name': u'OzzieBlossie', u'name': u'Ozzie Blossie'}], u'hashtags': [], u'urls': []}, u'retweeted': False, u'coordinates': None, u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', u'in_reply_to_screen_name': u'OzzieBlossie', u'in_reply_to_user_id': 824468305582845954, u'retweet_count': 0, u'id_str': u'916241060401205249', u'favorited': False, u'user': {u'follow_request_sent': False, u'has_extended_profile': False, u'profile_use_backg ...

# %%
# %%writefile TweepyToCSV.py
import sys
import tweepy
import csv
import Key

#pass security information to variables
consumer_key = Key.twiter()[0]
consumer_secret = Key.twiter()[1]
access_key = Key.twiter()[2]
access_secret = Key.twiter()[3]

#use variables to access twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

#create an object called 'customStreamListener'
class CustomStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print (status.author.screen_name, status.created_at, status.text)
        # Writing status data
        with open('OutputStreaming.txt', 'a') as f:
            writer = csv.writer(f)
            #status.author.screen_name = status.author.screen_name.encode('UTF-8')
            #status.text.encode = status.text.encode('UTF-8')            
            writer.writerow([status.author.screen_name.encode('UTF-8'), status.created_at, status.text.encode('utf8')])


    def on_error(self, status_code):
        print >> sys.stderr, 'Encountered error with status code:', status_code
        return True # Don't kill the stream

    def on_timeout(self):
        print >> sys.stderr, 'Timeout...'
        return True # Don't kill the stream


    def titles():
        # Writing csv titles
        with open('OutputStreaming.txt', 'a') as f:
                    writer = csv.writer(f)
                    writer.writerow(['Author', 'Date', 'Text'])
            
def main():
    streamingAPI = tweepy.streaming.Stream(auth, CustomStreamListener())
    #with open("tokens.txt", "r") as f:
    with open("tokens2.txt", "r") as f:    
        tokens = f.readlines()

        streamingAPI.filter(track=tokens)
        #streamingAPI.filter(track=['Dallas', 'NewYork'])


        #status.text.encode('utf-8')
        #writer.writerow([unicode(s).encode("utf-8") for s in row])
        #writer.writerow([unicode('Author', 'Date', 'Text').encode("utf-8") for 'Author', 'Date', 'Text' in row])
# Out:
# Writing TweepyToCSV.py

# %%
from Txmanip import RemoveBlank

RemoveBlank.removeblank("AllBooksOfEnoch_djvu.txt","BooksOfEnoch.txt")

# %%
from Txmanip import RemoveDuplicate

RemoveDuplicate.removeduplicate("cleanstream.txt","nodupStreaming.txt")

# %%
from itertools import tee
help(tee)
# Out:
# Help on built-in function tee in module itertools:
#
# tee(...)
#     tee(iterable, n=2) --> tuple of n independent iterators.

# %%
# %%writefile test.txt
# Author,Date,Text
# MelanieT123,2017-10-06 05:50:39,"RT @AlamoOnTheRise: Trump: Day 258 Plans 2 decertify Iran nuke deal Picks coal lobbyist 4 top EPA job Fumed over 'moron' news Sz tonigh… "
# Trvp_Isaxc,2017-10-06 05:50:40,"RT @PolynesianSauce: 12) Me &amp; My Bitch ... You don’t scream “AND THEY ASK ME WHY I TRUST NO BITCH, CAUSE MY EX HAD ME FEELING ALL EMBARR… "
# CrazzyCattLady,2017-10-06 05:50:40,https://t.co/uUOy3dYhoJ
# sherfouch,2017-10-06 05:50:40,"RT @HeerJeet: 3. Bannon, Brietbart, the Mercers &amp; Milo: these are not fringe figures. Bannon ran Trump's campaign &amp; was White House advisor…"
# Jogiejamette,2017-10-06 05:50:40,"RT @JohnWDean: Nixon: “I’m not a crook.” Trump: “I’m not a moron.”         h/t DW"
# MazinWaheed,2017-10-06 05:50:40,RT @the1dstage: retweet if you want to gain just follow everyone who retweets and follow back whoever follows you🏼
# templeheart55,2017-10-06 05:50:40,"RT @RVAwonk: --&gt; ""Iowa tried for months to get federal permission to fix their health insurance markets but they were shut down… "
# jess7719,2017-10-06 05:50:40,RT @TPInsidr: Of course they're doubling down on their false report! Why is our media so dishonest? https://t.co/RofsRDZ3Dc
# JaneMetzger75,2017-10-06 05:50:40,RT @KeithOlbermann: Just a reminder that this State Department Spokesperson used to co-host Fox And Friends. https://t.co/zG3dzeAjwB
# faithfitzy,2017-10-06 05:50:40,@3hunnathot oh god NO. i don't know how to word things ever haha😰 i'm just sayin anyone that supports trump UGLY AF!
# AgnesS5665,2017-10-06 05:50:40,"RT @kwilli1046: Teen #LasVegas victim found Pres. Trump's visit  ""comforting"" - ""he wasn't who we see on social media."" https://t.co/GUD9LT…"
# LegitJayyy_,2017-10-06 05:50:40,RT @RileyJayDennis: holy shit what kinda president goes to hurricane victims &amp; tells them they cost him a lot of money &amp; they should be…
# Bladix29,2017-10-06 05:50:40,"RT @Cdiscount: 🏆 #Concours
# Out:
# Overwriting test.txt

# %%
def edited(r):
    r+c
    return r

with open("test.txt") as inf, open("editTest.txt", "w") as outf:
    # set up iterators
    cfg, res = tee(inf)
    for i in range(1):
        next(cfg)

    # iterate through in tandem
    for c, r in zip(cfg, res):
        if len(c)<35:
            r = edited(r)
        outf.write(r)

    # reached end - write out remaining queued values
    for r in res:
        outf.write(r)
edited(r)

# %%
from itertools import tee

with open("test.txt") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(500):
        next(cfg)

        for c,r in zip(cfg, res):
            if len(c)<35:
                print c,r,"----\n"
# Out:
# rrys1DEmpire: Follow everyone
# robbieisnice,2017-10-06 05:50:40,@XandraSchultz @tightsarntpants @LStanfield2 @DrBo42 @Styl_oh @brielarson I don't feel pity. I have very few emotio… https://t.co/1QEHekpanP
# ----
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-2-f22af4610ffc> in <module>()
#       6     # advance cfg by four lines
#       7     for i in range(500):
# ----> 8         next(cfg)
#       9
#      10         for c,r in zip(cfg, res):
#
# StopIteration:

# %%
from itertools import tee
count=0
with open("realDonaldTrump_tweets.csv") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(4):
        next(cfg)

    for c,r in zip(cfg, res):
        count=count+1
        if len(c)<35:
            #print "Date :",c[21:]
            print count,"-Text:",c[39:]
# Out:
# 45 -Text:
# 48 -Text:
# 49 -Text:
# 60 -Text:
# 61 -Text:
# 70 -Text:
# 74 -Text:
# 90 -Text:
# 130 -Text:
# 140 -Text:
# 146 -Text:
# 147 -Text:
# 148 -Text:
# 175 -Text:
# 177 -Text:
# 178 -Text:
# 179 -Text:
# 191 -Text:
# 215 -Text:
# 224 -Text:
# 276 -Text:
# 277 -Text:
# 278 -Text:
# 279 -Text:
# 280 -Text:
# 281 -Text:
# 309 -Text:
# 318 -Text:
# 325 -Text:
# 339 -Text:
# 351 -Text:
# 352 -Text:
# 353 -Text:
# 362 -Text:
# 363 -Text:
# 382 -Text:
# 395 -Text:
# 452 -Text:
# 453 -Text:
# 480 -Text:
# 485 -Text:
# 498 -Text:
# 575 -Text:
# 589 -Text:
# 590 -Text:
# 627 -Text:
# 629 -Text:
# 652 -Text:
# 662 -Text:
# 720 -Text:
# 755 -Text:
# 756 -Text:
# 757 -Text:
# 785 -Text:
# 882 -Text:
# 883 -Text:
# 887 -Text:
# 912 -Text:
# 929 -Text:
# 950 -Text:
# 951 -Text:
# 953 -Text:
# 954 -Text:
# 955 -Text:
# 956 -Text:
# 957 -Text:
# 960 -Text:
# 1018 -Text:
# 1020 -Text:
# 1047 -Text:
# 1072 -Text:
# 1105 -Text:
# 1130 -Text:
# 1161 -Text:
# 1174 -Text:
# 1232 -Text:
# 1236 -Text:
# 1238 -Text:
# 1239 -Text:
# 1261 -Text:
# 1264 -Text:
# 1265 -Text:
# 1299 -Text:
# 1334 -Text:
# 1349 -Text:
# 1350 -Text:
# 1399 -Text:
# 1420 -Text:
# 1445 -Text:
# 1447 -Text:
# 1449 -Text:
# 1530 -Text:
# 1543 -Text:
# 1547 -Text:
# 1589 -Text:
# 1594 -Text:
# 1646 -Text:
# 1672 -Text:
# 1677 -Text:
# 1691 -Text:
# 1726 -Text:
# 1740 -Text:
# 1781 -Text:
# 1834 -Text:
# 1895 -Text:
# 1899 -Text:
# 1972 -Text:
# 1979 -Text:
# 2005 -Text:
# 2038 -Text:
# 2040 -Text:
# 2058 -Text:
# 2059 -Text:
# 2060 -Text:
# 2061 -Text:
# 2062 -Text:
# 2063 -Text:
# 2067 -Text:
# 2069 -Text:
# 2118 -Text:
# 2125 -Text:
# 2126 -Text:
# 2127 -Text:
# 2128 -Text:
# 2129 -Text:
# 2143 -Text:
# 2146 -Text:
# 2147 -Text:
# 2158 -Text:
# 2159 -Text:
# 2160 -Text:
# 2161 -Text:
# 2162 -Text:
# 2163 -Text:
# 2164 -Text:
# 2165 -Text:
# 2166 -Text:
# 2178 -Text:
# 2179 -Text:
# 2183 -Text:
# 2195 -Text:
# 2196 -Text:
# 2197 -Text:
# 2206 -Text:
# 2213 -Text:
# 2217 -Text:
# 2218 -Text:
# 2219 -Text:
# 2220 -Text:
# 2221 -Text:
# 2222 -Text:
# 2223 -Text:
# 2263 -Text:
# 2267 -Text:
# 2300 -Text:
# 2372 -Text:
# 2374 -Text:
# 2389 -Text:
# 2390 -Text:
# 2391 -Text:
# 2392 -Text:
# 2401 -Text:
# 2402 -Text:
# 2408 -Text:
# 2409 -Text:
# 2410 -Text:
# 2411 -Text:
# 2412 -Text:
# 2413 -Text:
# 2416 -Text:
# 2419 -Text:
# 2424 -Text:
# 2432 -Text:
# 2437 -Text:
# 2442 -Text:
# 2445 -Text:
# 2447 -Text:
# 2460 -Text:
# 2461 -Text:
# 2467 -Text:
# 2478 -Text:
# 2479 -Text:
# 2480 -Text:
# 2481 -Text:
# 2482 -Text:
# 2483 -Text:
# 2484 -Text:
# 2489 -Text:
# 2490 -Text:
# 2501 -Text:
# 2502 -Text:
# 2503 -Text:
# 2504 -Text:
# 2505 -Text:
# 2506 -Text:
# 2507 -Text:
# 2513 -Text:
# 2519 -Text:
# 2521 -Text:
# 2522 -Text:
# 2523 -Text:
# 2524 -Text:
# 2525 -Text:
# 2533 -Text:
# 2535 -Text:
# 2536 -Text:
# 2549 -Text:
# 2556 -Text:
# 2557 -Text:
# 2558 -Text:
# 2569 -Text:
# 2581 -Text:
# 2588 -Text:
# 2590 -Text:
# 2592 -Text:
# 2593 -Text:
# 2594 -Text:
# 2595 -Text:
# 2596 -Text:
# 2597 -Text:
# 2598 -Text:
# 2599 -Text:
# 2600 -Text:
# 2603 -Text:
# 2605 -Text:
# 2607 -Text:
# 2615 -Text:
# 2616 -Text:
# 2617 -Text:
# 2618 -Text:
# 2619 -Text:
# 2620 -Text:
# 2627 -Text:
# 2634 -Text:
# 2640 -Text:
# 2645 -Text:
# 2648 -Text:
# 2653 -Text:
# 2655 -Text:
# 2657 -Text:
# 2658 -Text:
# 2659 -Text:
# 2660 -Text:
# 2661 -Text:
# 2662 -Text:
# 2669 -Text:
# 2670 -Text:
# 2674 -Text:
# 2675 -Text:
# 2683 -Text:
# 2685 -Text:
# 2692 -Text:
# 2700 -Text:
# 2702 -Text:
# 2704 -Text:
# 2707 -Text:
# 2708 -Text:
# 2714 -Text:
# 2718 -Text:
# 2729 -Text:
# 2730 -Text:
# 2735 -Text:
# 2736 -Text:
# 2738 -Text:
# 2741 -Text:
# 2755 -Text:
# 2757 -Text:
# 2758 -Text:
# 2759 -Text:
# 2760 -Text:
# 2761 -Text:
# 2762 -Text:
# 2763 -Text:
# 2764 -Text:
# 2773 -Text:
# 2774 -Text:
# 2775 -Text:
# 2781 -Text:
# 2782 -Text:
# 2805 -Text:
# 2808 -Text:
# 2813 -Text:
# 2814 -Text:
# 2815 -Text:
# 2816 -Text:
# 2817 -Text:
# 2818 -Text:
# 2875 -Text:
# 2879 -Text:
# 2886 -Text:
# 2890 -Text:
# 2892 -Text:
# 2897 -Text:
# 2900 -Text:
# 2903 -Text:
# 2907 -Text:
# 2909 -Text:
# 2921 -Text:
# 2923 -Text:
# 2939 -Text:
# 2943 -Text:
# 2958 -Text:
# 2959 -Text:
# 2962 -Text:
# 2993 -Text:
# 2996 -Text:
# 2997 -Text:
# 3003 -Text:
# 3004 -Text:
# 3005 -Text:
# 3024 -Text:
# 3025 -Text:
# 3026 -Text:
# 3027 -Text:
# 3034 -Text:
# 3035 -Text:
# 3044 -Text:
# 3045 -Text:
# 3057 -Text:
# 3065 -Text:
# 3066 -Text:
# 3078 -Text:
# 3095 -Text:
# 3119 -Text:
# 3128 -Text:
# 3131 -Text:
# 3133 -Text:
# 3135 -Text:
# 3143 -Text:
# 3158 -Text:
# 3159 -Text:
# 3165 -Text:
# 3168 -Text:
# 3170 -Text:
# 3178 -Text:
# 3192 -Text:
# 3195 -Text:
# 3199 -Text:
# 3201 -Text:
# 3208 -Text:
# 3209 -Text:
# 3221 -Text:
# 3223 -Text:
# 3225 -Text:
# 3226 -Text:
# 3264 -Text:
# 3268 -Text:
# 3287 -Text:
# 3310 -Text:
# 3325 -Text:
# 3327 -Text:
# 3332 -Text:
# 3337 -Text:
# 3343 -Text:
# 3348 -Text:
# 3349 -Text:
# 3352 -Text:
# 3353 -Text:
# 3367 -Text:
# 3373 -Text:
# 3374 -Text:
# 3375 -Text:
# 3376 -Text:
# 3377 -Text:
# 3378 -Text:
# 3381 -Text:
# 3384 -Text:
# 3403 -Text:
# 3415 -Text:
# 3425 -Text:
# 3433 -Text:
# 3450 -Text:
# 3453 -Text:
# 3482 -Text:
# 3515 -Text:
# 3535 -Text:
# 3537 -Text:
# 3549 -Text:
# 3596 -Text:
# 3638 -Text:
# 3653 -Text:
# 3655 -Text:
# 3657 -Text:
# 3658 -Text:
# 3660 -Text:
# 3661 -Text:
# 3665 -Text:
# 3672 -Text:
# 3673 -Text:
# 3703 -Text:
# 3720 -Text:
# 3730 -Text:
# 3739 -Text:
# 3756 -Text:
# 3757 -Text:
# 3758 -Text:
# 3774 -Text:
# 3787 -Text:
# 3795 -Text:
# 3808 -Text:
# 3809 -Text:
# 3816 -Text:
# 3817 -Text:
# 3820 -Text:
# 3822 -Text:
# 3824 -Text:
# 3825 -Text:
# 3834 -Text:
# 3841 -Text:
# 3879 -Text:
# 3892 -Text:
# 3894 -Text:
# 3929 -Text:
# 3932 -Text:
# 3940 -Text:
# 3943 -Text:
# 3944 -Text:
# 3950 -Text:
# 3956 -Text:
# 3959 -Text:
# 3964 -Text:
# 3967 -Text:
# 3970 -Text:
# 3975 -Text:
# 3976 -Text:
# 3977 -Text:
# 3978 -Text:
# 3979 -Text:
# 3980 -Text:

# %%
outf =open("editTest.txt", "w")
outf.write(r)
outf.close()

# %%
outf = open("editTest.txt", "w") 
r = c[39:]   
outf.write(r)

# %% [markdown]
# # Makes clean Text Search from realDonaldTrump.txt

# %%
lines = open("realDonaldTrump.txt","r")
line = lines.readline()
for line in lines:
    if "AMERICAN" in line :
         print line
# Out:
# "It is time to take care of OUR people, to rebuild OUR NATION, and to fight for OUR GREAT AMERICAN WORKERS!… https://t.co/zDg8mWaDgY"
#
# "We want our companies to hire &amp; grow in AMERICA, to raise wages for AMERICAN workers, &amp; to help rebuild our AMERICA… https://t.co/Ng9NaVhyYI"
#
# "RT @The_Trump_Train: @realDonaldTrump Make no mistake, we are going to put the interest of AMERICAN CITIZENS FIRST!
#
# "We must remember this truth: No matter our color, creed, religion or political party, we are ALL AMERICANS FIRST. https://t.co/FesMiQSKKn"
#
# "We will defend our country, protect our communities and put the safety of the AMERICAN PEOPLE FIRST! Replay:… https://t.co/WZZb3FzLzW"
#
# A ship is only as good as the people who serve on it — and the AMERICAN SAILOR is the BEST in the world. @USNavy… https://t.co/wDmM0O9cJ4
#
# The dishonest media will NEVER keep us from accomplishing our objectives on behalf of our GREAT AMERICAN PEOPLE!… https://t.co/EwnwCeuGMv
#
# "A NEW ERA IN AMERICAN ENERGY!
#
# "Today, I was thrilled to announce a commitment of $25 BILLION &amp; 20K AMERICAN JOBS over the next 4 years. THANK YOU… https://t.co/nWJ1hNmzoR"
#
# "TO ALL AMERICANS🇺🇸
#
# "We will follow two simple rules: BUY AMERICAN &amp; HIRE AMERICAN!
#
# "TO ALL AMERICANS-
#
# Thank you Florida. My Administration will follow two simple rules: BUY AMERICAN and HIRE AMERICAN! #ICYMI- Watch:… https://t.co/3vgtzSJsFu
#
# "Together we can save American JOBS, American LIVES, and AMERICAN FUTURES! #Debates https://t.co/2Yfd0Omn4X"

# %%
#need to open the file properly
with open("realDonaldTrump.txt", 'r') as fp:
    #as suggested by @Padraic Cunningham it is better to iterate over the file object
    for line in fp:
        #each piece of information goes in a list
        infos = line.split()
        #this makes sure that there are no problems if your file has a empty line
        #and finds bob in the information
        if infos and infos[-1] == "trump":
            print (infos[2])

# %%
with open("editTest.txt") as openfile:
    for line in openfile:
         if "trump" in line:
                print line

# %%
from itertools import tee
count=0
with open("realDonaldTrump_tweets.csv") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(4):
        next(cfg)

    for c,r in zip(cfg, res):
        count=count+1
        if len(c)<35:
            outf = open("editTest.txt", "a") 
            r = c[39:]   
            outf.write(r)
            outf.close()
            print c[39:]

# %% [markdown]
# # Makes clean Text Search from realDonaldTrump_tweets.csv

# %%
from itertools import tee
count=0
with open("realDonaldTrump_tweets.csv") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(4):
        next(cfg)

    for c,r in zip(cfg, res):
        count=count+1
        if "campaign" in c:
            #print "Date :",c[21:]
            print c[39:]
# Out:
# "John McCain never had any intention of voting for this Bill, which his Governor loves. He campaigned on Repeal &amp; Replace. Let Arizona down!"
#
# "Rand Paul, or whoever votes against Hcare Bill, will forever (future political campaigns) be known as ""the Republican who saved ObamaCare."""
#
# I want to thank Steve Bannon for his service. He came to the campaign during my run against Crooked Hillary Clinton - it was great! Thanks S
#
# "As promised on the campaign trail, we will provide opportunity for Americans to gain skills needed to succeed &amp; thr… https://t.co/hPTRqUb5pA"
#
# I campaigned on creating a merit-based immigration system that protects U.S. workers &amp; taxpayers. Watch:… https://t.co/b8yIifGY3d
#
# "Ukrainian efforts to sabotage Trump campaign - ""quietly working to boost Clinton."" So where is the investigation A.G. @seanhannity"
#
# Republicans have a last chance to do the right thing on Repeal &amp; Replace after years of talking &amp; campaigning on it.
#
# Thank you to former campaign adviser Michael Caputo for saying so powerfully that there was no Russian collusion in our winning campaign.
#
# "Today, it was a tremendous honor for me to sign the #VAaccountability Act into law, delivering my campaign promise… https://t.co/G0k8nFWqNj"
#
# "As promised, our campaign against the MS-13 gang continues.
#
# Back from Miami where my Cuban/American friends are very happy with what I signed today. Another campaign promise that I did not forget!
#
# "RT @foxandfriends: ""Yesterday's hearings provided zero evidence of collusion between our campaign and the Russians because there wasn't any…"
#
# "With all of the illegal acts that took place in the Clinton campaign &amp; Obama Administration, there was never a special counsel appointed!"
#
# "Again, the story that there was collusion between the Russians &amp; Trump campaign was fabricated by Dems as an excuse for losing the election."
#
# ...Trump/Russia story was an excuse used by the Democrats as justification for losing the election. Perhaps Trump just ran a great campaign?
#
# "What about all of the contact with the Clinton campaign and the Russians? Also, is it true that the DNC would not let the FBI in to look?"
#
# The Democrats made up and pushed the Russian story as an excuse for running a terrible campaign. Big advantage in Electoral College &amp; lost!
#
# This Russian connection non-sense is merely an attempt to cover-up the many mistakes made in Hillary Clinton's losing campaign.
#
# "The crackdown on illegal criminals is merely the keeping of my campaign promise. Gang members, drug dealers &amp; others are being removed!"
#
# There is nothing nice about searching for terrorists before they can enter our country. This was a big part of my campaign. Study the world!
#
# have been allowed to run - guilty as hell. They were VERY nice to her. She lost because she campaigned in the wrong states - no enthusiasm!
#
# "President Obama campaigned hard (and personally) in the very important swing states, and lost.The voters wanted to MAKE AMERICA GREAT AGAIN!"
#
# "I would have done even better in the election, if that is possible, if the winner was based on popular vote - but would campaign differently"
#
# "I spent Friday campaigning with John Kennedy, of the Great State of Louisiana, for the U.S.Senate. The election is over - JOHN WON!"
#
# "Our great VPE, @mike_pence, is in Louisiana campaigning for John Kennedy for US Senate. John will be a tremendous help to us in Washington."
#
# It would have been much easier for me to win the so-called popular vote than the Electoral College in that I would only campaign in 3 or 4--
#
# If the election were based on total popular vote I would have campaigned in  N.Y. Florida and California and won even bigger and more easily
#
# Looking at Air Force One @ MIA. Why is he campaigning instead of creating jobs &amp; fixing Obamacare? Get back to work for the American people!
#
# 'Kept me out of jail': Top DOJ official involved in Clinton probe represented her campaign chairman: https://t.co/QUZn97CEOq
#
# "'Democratic operative caught on camera: Hillary PERSONALLY ordered 'Donald Duck' troll campaign that broke the law'
#
# I started this campaign to Make America Great Again. That’s what I’m going to do. #MAGA #debate
#
# "Brought to you by @HillaryClinton &amp; her campaign- in Chicago, Illinois.
#
# oter-fraud video is a felon who visited White House 342 times: https://t.co/qQdsMHAtkT"
#
# """Journalists shower Hillary Clinton with campaign cash""
#
# "WikiLeaks proves even the Clinton campaign knew Crooked mishandled classified info, but no one gets charged? RIGGED! https://t.co/FgGxDsS0a1"
#
# "Election is being rigged by the media, in a coordinated effort with the Clinton campaign, by putting stories that never happened into news!"
#
# "RT @DonaldJTrumpJr: Ironic since Hillary has gotten a lot more of that ""dark unaccountable money"" into her campaign. #debates"
#
# "Anytime you see a story about me or my campaign saying ""sources said,"" DO NOT believe it. There are no sources, they are just made up lies!"
#
# "Many on the team and staff of Bernie Sanders have been treated badly by the Hillary Clinton campaign - and they like Trump on trade, a lot!"
#
# "This is more than a campaign- it is a movement. #MakeAmericaGreatAgain
#
# "RT @GMA: WATCH: @IvankaTrump on ""women who work;"" empowering campaign celebrates modern women.  https://t.co/rMFe9o6WcL"
#
# "It is a MOVEMENT - not a campaign. Leaving the past behind, changing our future. Together, we will MAKE AMERICA SAF… https://t.co/Lt2L3NKzyi"
#
# Why isn't President Obama working instead of campaigning for Hillary Clinton?
#
# stry and an arm of the Clinton campaign."
#
# The polls are close so Crooked Hillary is getting out of bed and will campaign tomorrow.Why did she hammer 13 devices and acid-wash e-mails?
#
# "I visited our Trump Tower campaign headquarters last night, after returning from Ohio and Arizona, and it was packed with great pros - WIN!"
#
# """Hillary Clinton needs to address the racist undertones of her 2008 campaign."" #FlashbackFriday https://t.co/MJQp0rcnzH"
#
# """@willspeakout: Thank you for all that you are doing for us! You campaign endlessly and have spent millions.We love you! #TrumpTrain"" Thanks"
#
# Reuters just announced that Secret Service never spoke to me or my campaign. Made up story by @CNN is a hoax. Totally dishonest.
#
# "There is great unity in my campaign, perhaps greater than ever before. I want to thank everyone for your tremendous support. Beat Crooked H!"

# %% [markdown]
# # Makes clean Text from realDonaldTrump_tweets.csv

# %%
with io.open("symmetrymag_tweets.csv", "w", encoding="utf-8") as inf:    
outf.close()

# %%
with io.open("symmetrymag_tweets.csv", "w", encoding="utf-8") as inf:    
outf.close()

# %%
from itertools import tee
count=0
with open("symmetrymag_tweets.csv") as inf:
    for line in inf:
        lines  = line[39:]
        outf = open("symmetrymag.txt", "a") 
        outf.write(lines)
outf.close()

# %%
from itertools import tee
import io
count=0

with io.open("symmetrymag_tweets.csv", "r") as inf:    
    for line in inf:
        lines  = line[39:]
        outf = open("symmetrymagexp.txt", "w") 
        outf.write(lines)
outf.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-33-80691d1c5764> in <module>()
#       7         lines  = line[39:]
#       8         outf = open("symmetrymagexp.txt", "w")
# ----> 9         outf.write(lines)
#      10 outf.close()
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2019' in position 2: ordinal not in range(128)

# %%
from itertools import tee
count=0
with open("realDonaldTrump_tweets.csv") as inf:
    for line in inf:
        lines  = line[39:]
        outf = open("realDonaldTrump.txt", "a") 
        outf.write(lines)
outf.close()

# %% [markdown]
# # Makes clean Text Search with Data from realDonaldTrump_tweets.csv

# %%
from itertools import tee
search = raw_input('Search Term')
with open("realDonaldTrump_tweets.csv") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(4):
        next(cfg)

    for c,r in zip(cfg, res):
        if search in c:
            print "Date :",c[21:38],"\nText :",c[39:]
# Out:
# Search TermHillary
# Date : 17-09-22 11:26:06
# Text : "The greatest influence over our election was the Fake News Media ""screaming"" for Crooked Hillary Clinton. Next, she was a bad candidate!"
#
# Date : 17-09-22 10:44:47
# Text : "The Russia hoax continues, now it's ads on Facebook. What about the totally biased and dishonest Media coverage in favor of Crooked Hillary?"
#
# Date : 17-09-20 10:40:31
# Text : "After allowing North Korea to research and build Nukes while Secretary of State (Bill C also), Crooked Hillary now criticizes."
#
# Date : 17-09-17 12:16:31
# Text : RT @Fuctupmind: @realDonaldTrump Donald Trump's amazing golf swing #CrookedHillary https://t.co/vKhxxFCBV1
#
# Date : 17-09-14 02:52:34
# Text : "The ""deplorables"" came back to haunt Hillary.They expressed their feelings loud and clear. She spent big money but, in the end, had no game!"
#
# Date : 17-09-14 02:47:23
# Text : Crooked Hillary Clinton blames everybody (and every thing) but herself for her election loss. She lost the debates and lost her direction!
#
# Date : 17-09-01 11:56:45
# Text : "Wow, looks like James Comey exonerated Hillary Clinton long before the investigation was over...and so much more. A rigged system!"
#
# Date : 17-08-19 11:33:51
# Text : I want to thank Steve Bannon for his service. He came to the campaign during my run against Crooked Hillary Clinton - it was great! Thanks S
#
# Date : 17-07-26 13:52:57
# Text : "...big dollars ($700,000) for his wife's political run from Hillary Clinton and her representatives. Drain the Swamp!"
#
# Date : 17-07-25 10:21:41
# Text : "Problem is that the acting head of the FBI &amp; the person in charge of the Hillary investigation, Andrew McCabe, got $700,000 from H for wife!"
#
# Date : 17-07-25 10:12:24
# Text : Attorney General Jeff Sessions has taken a VERY weak position on Hillary Clinton crimes (where are E-mails &amp; DNC server) &amp; Intel leakers!
#
# Date : 17-07-24 12:49:38
# Text : "So why aren't the Committees and investigators, and of course our beleaguered A.G., looking into Crooked Hillarys crimes &amp; Russia relations?"
#
# Date : 17-07-22 12:00:30
# Text : "My son Donald openly gave his e-mails to the media &amp; authorities whereas Crooked Hillary Clinton deleted (&amp; acid washed) her 33,000 e-mails!"
#
# Date : 17-07-22 11:44:29
# Text : "So many people are asking why isn't the A.G. or Special Council looking at the many Hillary Clinton or Comey crimes. 33,000 e-mails deleted?"
#
# Date : 17-07-16 10:35:44
# Text : "HillaryClinton can illegally get the questions to the Debate &amp; delete 33,000 emails but my son Don is being scorned by the Fake News Media?"
#
# Date : 17-07-12 13:27:03
# Text : Why aren't the same standards placed on the Democrats. Look what Hillary Clinton may have gotten away with. Disgraceful!
#
# Date : 17-06-26 12:50:15
# Text : "...and did not want to ""rock the boat."" He didn't ""choke,"" he colluded or obstructed, and it did the Dems and Crooked Hillary no good."
#
# Date : 17-06-25 12:00:37
# Text : Hillary Clinton colluded with the Democratic Party in order to beat Crazy Bernie Sanders. Is she allowed to so collude? Unfair to Bernie!
#
# Date : 17-06-24 20:44:36
# Text : "Obama Administration official said they ""choked"" when it came to acting on Russian meddling of election. They didn't want to hurt Hillary?"
#
# Date : 17-06-15 19:43:31
# Text : "Why is that Hillary Clintons family and Dems dealings with Russia are not looked at, but my non-dealings are?"
#
# Date : 17-06-13 12:45:11
# Text : A.G. Lynch made law enforcement decisions for political purposes...gave Hillary Clinton a free pass and protection. Totally illegal!
#
# Date : 17-06-01 00:40:01
# Text : "Crooked Hillary Clinton now blames everybody but herself, refuses to say she was a terrible candidate. Hits Facebook &amp; even Dems &amp; DNC."
#
# Date : 17-05-03 02:51:07
# Text : FBI Director Comey was the best thing that ever happened to Hillary Clinton in that he gave her a free pass for many bad deeds! The phony...
#
# Date : 17-04-23 19:48:16
# Text : New polls out today are very good considering that much of the media is FAKE and almost always negative. Would still beat Hillary in .....
#
# Date : 17-04-03 11:21:11
# Text : Did Hillary Clinton ever apologize for receiving the answers to the debate? Just asking!
#
# Date : 17-04-03 11:16:52
# Text : Was the brother of John Podesta paid big money to get the sanctions on Russia lifted? Did Hillary know?
#
# Date : 17-03-28 01:35:35
# Text : "...money to Bill, the Hillary Russian ""reset,"" praise of Russia by Hillary, or Podesta Russian Company. Trump Russia story is a hoax. #MAGA!"
#
# Date : 17-03-28 01:26:04
# Text : "Why isn't the House Intelligence Committee looking into the Bill &amp; Hillary deal that allowed big Uranium to go to Russia, Russian speech...."
#
# Date : 17-02-15 12:08:12
# Text : This Russian connection non-sense is merely an attempt to cover-up the many mistakes made in Hillary Clinton's losing campaign.
#
# Date : 17-01-13 11:22:38
# Text : What are Hillary Clinton's people complaining about with respect to the F.B.I. Based on the information they had she should never.....
#
# Date : 17-01-09 11:36:02
# Text : "Hillary flunky who lost big. For the 100th time, I never ""mocked"" a disabled reporter (would never do that) but simply showed him......."
#
# Date : 17-01-06 12:42:53
# Text : "being a movie star-and that was season 1 compared to season 14. Now compare him to my season 1. But who cares, he supported Kasich &amp; Hillary"
#
# Date : 17-01-06 11:39:35
# Text : Hillary and the Dems were never going to beat the PASSION of my voters. They saw what was happening in the last two weeks before the......
#
# Date : 16-12-24 00:13:02
# Text : "Vladimir Putin said today about Hillary and Dems: ""In my opinion, it is humiliating. One must be able to lose with dignity.""  So true!"
#
# Date : 16-12-23 01:59:58
# Text : "The so-called ""A"" list celebrities are all wanting tixs to the inauguration, but look what they did for Hillary, NOTHING. I want the PEOPLE!"
#
# Date : 16-12-21 13:29:38
# Text : I have not heard any of the pundits or commentators discussing the fact that I spent FAR LESS MONEY on the win than Hillary on the loss!
#
# Date : 16-12-21 13:15:14
# Text : Campaigning to win the Electoral College is much more difficult &amp; sophisticated than the popular vote. Hillary focused on the wrong states!
#
# Date : 16-12-16 11:09:19
# Text : Are we talking about the same cyberattack where it was revealed that head of the DNC illegally gave Hillary the questions to the debate?
#
# Date : 16-12-15 14:24:29
# Text : "If Russia, or some other entity, was hacking, why did the White House wait so long to act? Why did they only complain after Hillary lost?"
#
# Date : 16-11-29 11:34:42
# Text : "I thought that @CNN would get better after they failed so badly in their support of Hillary Clinton however, since election, they are worse!"
#
# Date : 16-11-29 03:03:59
# Text : ".@CNN is so embarrassed by their total  (100%) support of Hillary Clinton, and yet her loss in a landslide, that they don't know what to do."
#
# Date : 16-11-29 02:21:04
# Text : """@sdcritic:  @HighonHillcrest @jeffzeleny @CNN There is NO QUESTION THAT #voterfraud did take place, and in favor of #CorruptHillary !"""
#
# Date : 16-11-27 12:55:03
# Text : "Hillary's debate answer on delay: ""That is horrifying. That is not the way our democracy works. Been around for 240 years. We've had free --"
#
# Date : 16-11-27 12:19:31
# Text : Hillary Clinton conceded the election when she called me just prior to the victory speech and after the results were in. Nothing will change
#
# Date : 16-11-07 22:21:53
# Text : Hey Missouri let's defeat Crooked Hillary &amp; @koster4missouri! Koster supports Obamacare &amp; amnesty! Vote outsider Navy SEAL @EricGreitens!
#
# Date : 16-11-04 19:07:20
# Text : "If Obama worked as hard on straightening out our country as he has trying to protect and elect Hillary, we would all be much better off!"
#
# Date : 16-11-04 16:26:19
# Text : RT @TeamTrump: Mrs. Saucier's son is in prison for having classified info on an unsecured device. @HillaryClinton did FAR WORSE &amp; is runnin…
#
# Date : 16-11-03 23:30:17
# Text : "RT @PaulaReidCBS: .@CBSNews confirms FBI found emails on #AnthonyWeiner computer, related to Hillary Clinton server, that are ""new"" &amp; not p…"
#
# Date : 16-11-03 20:55:36
# Text : #CrookedHillary is unfit to serve. https://t.co/bSuGvInNF1
#
# Date : 16-11-03 12:34:14
# Text : "ObamaCare is a total disaster. Hillary Clinton wants to save it by making it even more expensive. Doesn't work, I will REPEAL AND REPLACE!"
#
# Date : 16-11-03 03:44:39
# Text : RT @T_Lineberger: Thanks @IvankaTrump for coming to help win Michigan! More people here than a Hillary rally with less than 24 hours notice…
#
# Date : 16-11-02 19:09:28
# Text : "After decades of lies and scandal, Crooked Hillary's corruption is closing in. #DrainTheSwamp! https://t.co/YivCacmkKq"
#
# Date : 16-11-02 12:47:48
# Text : "Crooked Hillary Clinton deleted 33,000 e-mails AFTER they were subpoenaed by the United States Congress. Guilty - cannot run. Rigged system!"
#
# Date : 16-11-02 11:00:30
# Text : "I am going to repeal and replace ObamaCare. We will have MUCH less expensive and MUCH better healthcare. With Hillary, costs will triple!"
#
# Date : 16-11-02 10:35:56
# Text : "You can change your vote in six states. So, now that you see that Hillary was a big mistake, change your vote to MAKE AMERICA GREAT AGAIN!"
#
# Date : 16-11-01 21:20:04
# Text : Hillary Advisers Wanted Her To Avoid Supporting Israel When Talking To Democrats: https://t.co/y7m8iVU173
#
# Date : 16-11-01 12:01:11
# Text : "Crooked Hillary should not be allowed to run for president. She deleted 33,000 e-mails AFTER getting a subpoena from U.S. Congress. RIGGED!"
#
# Date : 16-11-01 11:55:47
# Text : "Wow, now leading in @ABC /@washingtonpost Poll 46 to 45. Gone up 12 points in two weeks, mostly before the Crooked Hillary blow-up!"
#
# Date : 16-11-01 10:31:46
# Text : Look at the way Crooked Hillary is handling the e-mail case and the total mess she is in. She is unfit to be president. Bad judgement!
#
# Date : 16-10-31 19:08:25
# Text : #ObamacareFail #HillarycareFail https://t.co/gaXOWVI0Xa
#
# Date : 16-10-31 16:00:19
# Text : "'Hillary's Two Official Favors To Morocco Resulted In $28 Million For Clinton Foundation' #DrainTheSwamp
#
# Date : 16-10-30 14:04:06
# Text : "Hillary and the Dems loved and praised FBI Director Comey just a few days ago. Original evidence was overwhelming, should not have delayed!"
#
# Date : 16-10-29 01:30:55
# Text : """@piersmorgan: BOMBSHELL: FBI reopening its investigation into HillaryClinton's email server after new discovery!"
#
# Date : 16-10-28 19:20:22
# Text : We must not let #CrookedHillary take her CRIMINAL SCHEME into the Oval Office. #DrainTheSwamp https://t.co/GtPkj4xIz6
#
# Date : 16-10-28 17:24:08
# Text : "Just out: Neera Tanden, Hillary Clinton adviser said, “Israel is depressing.” I think Israel is inspiring!"
#
# Date : 16-10-28 15:53:19
# Text : "If my people said the things about me that Podesta &amp; Hillary's people said about her, I would fire them out of self respect. ""Bad instincts"""
#
# Date : 16-10-27 22:37:22
# Text : Crooked Hillary launched her political career by letting terrorists off the hook. #DrainTheSwamp… https://t.co/BLMkZQ8svK
#
# Date : 16-10-26 21:59:15
# Text : Hillary said she was under sniper fire (while surrounded by USSS.) Turned out to be a total lie. She is not fit to… https://t.co/hBIrGj21l6
#
# Date : 16-10-25 20:43:45
# Text : "Obamacare is a disaster. Rates going through the sky - ready to explode. I will fix it. Hillary can't!
#
# Date : 16-10-24 21:50:25
# Text : "'Democratic operative caught on camera: Hillary PERSONALLY ordered 'Donald Duck' troll campaign that broke the law'
#
# Date : 16-10-24 16:37:58
# Text : 'Hillary Clinton Had Gun Control Supporters Planted In Town Hall Audience' https://t.co/1GVq74iW8a
#
# Date : 16-10-24 12:00:02
# Text : "Wow, just came out on secret tape that Crooked Hillary wants to take in as many Syrians as possible. We cannot let this happen - ISIS!"
#
# Date : 16-10-24 00:07:47
# Text : "'Clinton Charity Got Up To $56 Million From Nations That Are Anti-Women, Gays' #CrookedHillary
#
# Date : 16-10-23 19:08:42
# Text : #CrookedHillary #PayToPlay https://t.co/BT1Nv0ZMYg
#
# Date : 16-10-23 12:53:51
# Text : """If you can't run your own house you certainly can't run the White House"" A statement made by Mrs. Obama about Crooked Hillary Clinton"
#
# Date : 16-10-22 21:34:44
# Text : "Hillary Clinton: 'Architect of failure'
#
# Date : edHillary
#
# Text :
# Date : 16-10-22 17:54:11
# Text : "Crooked Hillary Clinton Tops Middle East Forum’s ‘Islamist Money List'
#
# Date : 16-10-22 11:35:18
# Text : """@jensen4law: Best way to pay Hillary back for what she did to @BernieSanders #DNCleak is a DonaldTrump LANDSLIDE https://t.co/Ha8o5wCyGh"""
#
# Date : 16-10-21 22:50:00
# Text : #CrookedHillary sending U.S. intelligence info. to Podesta’s hacked email is ‘unquestionably an OPSEC violation’ https://t.co/z58aeo4CO7
#
# Date : edHillary
#
# Text :
# Date : 16-10-21 22:30:14
# Text : """{Crooked Hillary Clinton} created this mess, and she knows it.""
#
# Date : 16-10-21 18:54:00
# Text : #CrookedHillary “was at center of negotiating $12M commitment from King Mohammed VI of Morocco” to Clinton Fdn. https://t.co/HWOQ7jQWY2
#
# Date : 16-10-20 22:08:15
# Text : "Hillary &amp; Obama's Broken Promises.
#
# Date : 16-10-20 20:30:01
# Text : "Crooked Hillary promised 200k jobs in NY and FAILED. We'll create 25M jobs when I'm president, and I will DELIVER! https://t.co/NgyCkEH7Xn"
#
# Date : 16-10-20 18:25:34
# Text : "Want access to Crooked Hillary? Don't forget - it's going to cost you!
#
# Date : 16-10-20 14:55:50
# Text : Why didn't Hillary Clinton announce that she was inappropriately given the debate questions - she secretly used them! Crooked Hillary.
#
# Date : ttps://t.co/n4eZ3
# Text : pcjg"
#
# Date : 16-10-20 02:40:23
# Text : We cannot take four more years of Barack Obama and that’s what you’ll get if you vote for Hillary. #BigLeagueTruth
#
# Date : 16-10-20 02:31:45
# Text : "ISIS has infiltrated countries all over Europe by posing as refugees, and @HillaryClinton will allow it to happen h… https://t.co/MmeW2qsTQh"
#
# Date : 16-10-20 02:27:15
# Text : "RT @TeamTrump: What They Are Saying About @realDonaldTrump's GREAT Debate and @HillaryClinton's Bad Performance
#
# Date : 16-10-20 02:26:24
# Text : "After Crooked @HillaryClinton allowed ISIS to rise, she now claims she'll defeat them? LAUGHABLE! Here's my plan: https://t.co/FzRMObNQVn"
#
# Date : 16-10-20 02:21:32
# Text : "I opposed going into Iraq. Hillary voted for it. As with everything else she's supported, it was a DISASTER. https://t.co/Um5WJXWfBZ"
#
# Date : 16-10-20 02:14:29
# Text : "Hillary says ""take back Mosul?"" We would have NEVER lost Mosul- if it wasn't for #CrookedHillary. #DrainTheSwamp https://t.co/TmsY0ApFLQ"
#
# Date : 16-10-20 02:11:33
# Text : You should give the money back @HillaryClinton! #DrainTheSwamp https://t.co/m0LKHRUoHz
#
# Date : 16-10-20 02:02:53
# Text : Crooked @HillaryClinton's foundation is a CRIMINAL ENTERPRISE. Time to #DrainTheSwamp!  https://t.co/89eOMTsIjt #BigLeagueTruth #Debate
#
# Date : 16-10-20 01:59:07
# Text : .@HillaryClinton loves to lie. America has had enough of the CLINTON'S! It is time to #DrainTheSwamp! Debates https://t.co/3Mz4T7qTTR
#
# Date : 16-10-20 01:57:00
# Text : I will do more in the first 30 days in office than Hillary has done in the last 30 years! #Debate  #BigLeagueTruth https://t.co/tuNQePu8Vk
#
# Date : 16-10-20 01:56:01
# Text : #CrookedHillary is nothing more than a Wall Street PUPPET! #BigLeagueTruth #Debate https://t.co/skhBWG6AQ3
#
# Date : 16-10-20 01:55:42
# Text : "Brought to you by @HillaryClinton &amp; her campaign- in Chicago, Illinois.
#
# Date : 16-10-20 01:54:31
# Text : RT @TeamTrump: .@realDonaldTrump will do more in the first 30 days in office than Hillary has done in the last 30 years! #Debate #BigLeague…
#
# Date : 16-10-20 01:51:49
# Text : Our country is stagnant. We’ve lost jobs and business. We don’t make things anymore b/c of the bill Hillary’s husband signed and she blessed
#
# Date : 16-10-20 01:51:15
# Text : Crooked Hillary has never created a job in her life. We will create 25 million jobs. Think she can do that? Not a c… https://t.co/64Kll0Dl7K
#
# Date : 16-10-20 01:50:20
# Text : .@HillaryClinton has been doing this for THIRTY YEARS....where has she been? #BigLeagueTruth
#
# Date : 16-10-20 01:49:00
# Text : #CrookedHillary gives Obama an “A” for an economic recovery that’s the slowest since WWII... #BigLeagueTruth… https://t.co/wVMFHdyCu2
#
# Date : 16-10-20 01:45:53
# Text : RT @TeamTrump: #CrookedHillary's plan will add $1.15 TRILLION in new taxes. We cannot afford her! #DrainTheSwamp #Debate https://t.co/jpjKY…
#
# Date : 16-10-20 01:44:36
# Text : This is what we can expect from #CrookedHillary. More Taxes. More Spending. #BigLeageTruth #DrainTheSwamp #Debates https://t.co/5yxnt0gNUF
#
# Date : 16-10-20 01:42:53
# Text : .@HillaryClinton's tax hikes will CRUSH our economy. I will cut taxes -- BIG LEAGUE. https://t.co/EtA1tBnrNG https://t.co/NgMDP4wilI
#
# Date : 16-10-20 01:39:40
# Text : ".@HillaryClinton talking about jobs? Remember what she promised upstate New York. #BigLeagueTruth
#
# Date : 16-10-20 01:39:29
# Text : .@HillaryClinton has been a foreign policy DISASTER for the American people. I will #MakeAmericaStrongAgain #Debate… https://t.co/tj6PWM5r1J
#
# Date : 16-10-20 01:38:47
# Text : Moderator: Hillary plan calls for more regulation and more government spending. #Debate #BigLeagueTruth
#
# Date : 16-10-20 01:37:37
# Text : ".@HillaryClinton- you have failed, failed, and failed. #BigLeagueTruth
#
# Date : 16-10-20 01:34:49
# Text : "Hillary has called for 550% more Syrian immigrants, but won’t even mention “radical Islamic terrorists.” #Debate… https://t.co/Rf48XkZWbu"
#
# Date : 16-10-20 01:29:22
# Text : "Moderator: Hillary paid $225,000 by a Brazilian bank for a speech that called for “open borders.” That’s a quote! #Debate #BigLeagueTruth"
#
# Date : 16-10-20 01:28:08
# Text : "Hillary is too weak to lead on border security-no solutions, no ideas, no credibility.She supported NAFTA, worst deal in US history. #Debate"
#
# Date : 16-10-20 01:22:56
# Text : Hillary Clinton will use American tax dollars to provide amnesty for thousands of illegals. I will put… https://t.co/ZpV33TfbR6
#
# Date : 16-10-20 01:13:09
# Text : .@HillaryClinton lists litany of ways she plans to restrict gun rights. 2A will not survive a Hillary presidency. #Debate #BigLeagueTruth
#
# Date : 16-10-20 01:07:40
# Text : Hillary Clinton wants to create the most liberal Supreme Court in history #debate #DrainTheSwamp https://t.co/fKJBNXvluh
#
# Date : 16-10-19 19:57:03
# Text : "'Hillary Clinton Deleted Emails With Her Email Server Technician'
#
# Date : 16-10-19 19:09:28
# Text : "'Top Hillary Adviser Mocked, Plotted Attacks on Pro-Sanders Civil Rights Leader' #DrainTheSwamp
#
# Date : 16-10-19 00:34:21
# Text : Hillary is the most corrupt person to ever run for the presidency of the United States. #DrainTheSwamp https://t.co/xA3YO8YzCq
#
# Date : 16-10-18 18:05:45
# Text : Hillary’s Aides Urged Her to Take Foreign Lobbyist Donation And Deal With Attacks: https://t.co/o2qvr1myIZ
#
# Date : 16-10-17 22:51:31
# Text : Get rich quick! Crooked Hillary Clinton's pay to play guide: https://t.co/uKh5sCFfrv
#
# Date : 16-10-17 21:03:16
# Text : Crooked Hillary colluded w/FBI and DOJ and media is covering up to protect her. It's a #RiggedSystem! Our country d… https://t.co/kuinRTImVJ
#
# Date : 16-10-17 19:23:15
# Text : """Journalists shower Hillary Clinton with campaign cash""
#
# Date : 16-10-17 15:24:31
# Text : "Voter fraud! Crooked Hillary Clinton even got the questions to a debate, and nobody says a word. Can you imagine if I got the questions?"
#
# Date : 16-10-16 22:29:46
# Text : Animals representing Hillary Clinton and Dems in North Carolina just firebombed our office in Orange County because we are winning @NCGOP
#
# Date : 16-10-16 22:15:33
# Text : "Wow, interview released by Wikileakes shows ""quid pro quo"" in Crooked Hillary e-mail probe.Such a dishonest person - &amp; Paul Ryan does zilch!"
#
# Date : 16-10-16 21:02:34
# Text : "Finally, in the new ABC News/Washington Post Poll, Hillary Clinton is down 11 points with WOMEN VOTERS and the election is close at 47-43!"
#
# Date : 16-10-16 20:47:23
# Text : "The Democrats have a corrupt political machine pushing crooked Hillary Clinton. We have Paul Ryan, always fighting the Republican nominee!"
#
# Date : 16-10-16 17:01:12
# Text : The election is absolutely being rigged by the dishonest and distorted media pushing Crooked Hillary - but also at many polling places - SAD
#
# Date : 16-10-16 16:07:58
# Text : We've all wondered how Hillary avoided prosecution for her email scheme. Wikileaks may have found the answer. Obama! https://t.co/xF0wv8Oa8q
#
# Date : 16-10-16 16:07:08
# Text : Hillary's staff thought her email scandal might just blow over. Who would trust these people with national security? https://t.co/EvBCQoZRG2
#
# Date : 16-10-16 13:15:03
# Text : A country that Crooked Hillary says has funded ISIS also gave Wild Bill $1 million for his birthday? SO CORRUPT! https://t.co/00s5tgsXrM
#
# Date : 16-10-15 12:23:08
# Text : Hillary Clinton should have been prosecuted and should be in jail. Instead she is running for president in what looks like a rigged election
#
# Date : 16-10-15 11:45:58
# Text : "This election is being rigged by the media pushing false and unsubstantiated charges, and outright lies, in order to elect Crooked Hillary!"
#
# Date : ://t.co/wjsl8ITVv
# Text : "
#
# Date : 16-10-12 12:59:05
# Text : Crooked Hillary Clinton likes to talk about the things she will do but she has been there for 30 years - why didn't she do them?
#
# Date : 16-10-11 23:04:25
# Text : "Wow, @CNN Town Hall questions were given to Crooked Hillary Clinton in advance of big debates against Bernie Sanders. Hillary &amp; CNN FRAUD!"
#
# Date : 16-10-11 17:43:06
# Text : I hope people are looking at the disgraceful behavior of Hillary Clinton as exposed by WikiLeaks. She is unfit to run.
#
# Date : 16-10-11 14:48:29
# Text : Disloyal R's are far more difficult than Crooked Hillary. They come at you from all sides. They don’t know how to win - I will teach them!
#
# Date : 16-10-10 19:31:04
# Text : "Wow, @CNN got caught fixing their ""focus group"" in order to make Crooked Hillary look better. Really pathetic and totally dishonest!"
#
# Date : 16-10-10 02:30:17
# Text : "Hypocrite: @HillaryClinton is the single biggest beneficiary of Citizens United in history, by far. #debate #bigleaguetruth"
#
# Date : 16-10-10 02:30:02
# Text : "RT @DonaldJTrumpJr: Ironic since Hillary has gotten a lot more of that ""dark unaccountable money"" into her campaign. #debates"
#
# Date : 16-10-10 02:25:04
# Text : "RT @KellyannePolls: After a decent first debate, @HillaryClinton is back to form: pedantic, lawyerly, technocratic, (woefully untruthful) r…"
#
# Date : nton) SAY ANYTHIN
# Text :  &amp; CHANGE NOTHING. IT'S TIME TO TURN THE PAGE"" -President Obama"
#
# Date : 16-10-10 02:19:35
# Text : "If @HillaryClinton is president, she’ll be all talk and nothing will get done. #Debate #BigLeagueTruth"
#
# Date : 16-10-10 02:12:56
# Text : RT @TeamTrump: .@HillaryClinton had her chance and she BLEW IT. #BigLeagueTruth #Debates https://t.co/d2MI0DCg5Y
#
# Date : 16-10-10 02:06:41
# Text : "Here are Hillary Clinton's ""accomplishments"" at the State Department.
#
# Date : Hillary https://t
# Text : co/iouuqXYAdq"
#
# Date : 16-10-10 02:03:01
# Text : RT @TeamTrump: #RattledHillary wants to talk about her 30 years in service. How about her 30 years of FLOPS↔️FLOPS?! #BigLeagueTruth #Debat…
#
# Date : 16-10-10 02:02:28
# Text : RT @TeamTrump: .@HillaryClinton is RAISING your taxes to a disastrous level. @realDonaldTrump is going to LOWER your taxes - BIG LEAGUE! #D…
#
# Date : 16-10-10 02:00:31
# Text : "History lesson: There’s a big difference between Hillary Clinton and Abraham Lincoln. For one, his nickname is Hone… https://t.co/A5JDkz1eCE"
#
# Date : tes2016 https://t
# Text : co/oI2qi2HAdO"
#
# Date : 16-10-10 01:50:45
# Text : Hypocrite! @HillaryClinton claims she needs a “public and a private stance” in discussions with Wall Street banks. #Debate
#
# Date : 16-10-10 01:48:19
# Text : .@HillaryClinton - ITS CALLED EXTREME VETTING! #Debates2016 https://t.co/ueq7cbOg9Y
#
# Date : 16-10-10 01:45:16
# Text : ".@HillaryClinton #ICYMI- ""WE ARE NOT IN A NARRATIVE FIGHT.""
#
# Date : 16-10-10 01:43:04
# Text : "#CrookedHillary has FAILED all over the world! 􏰀
#
# Date : 16-10-10 01:40:11
# Text : RT @realDonaldTrump: ATTN: @HillaryClinton - Why did five of your staffers need FBI IMMUNITY?! #BigLeagueTruth #Debates
#
# Date : 16-10-10 01:37:50
# Text : ".@HillaryClinton is NOT above the law!
#
# Date : 16-10-10 01:36:24
# Text : .@HillaryClinton : Bill “clarified” what he meant when calling Obamacare a “disaster.” Actually “disaster” is pretty clear. #Debate
#
# Date : 16-10-10 01:29:45
# Text : ATTN: @HillaryClinton - Why did five of your staffers need FBI IMMUNITY?! #BigLeagueTruth #Debates
#
# Date : 16-10-10 01:29:17
# Text : "Hillary’s 33,000 deleted emails about her daughter’s wedding. That’s a lot of wedding emails. #debate"
#
# Date : 16-10-10 01:28:36
# Text : Basically nothing Hillary has said about her secret server has been true. #CrookedHillary
#
# Date : 16-10-10 01:24:50
# Text : RT @TeamTrump: RT if you believe @HillaryClinton is the one who owes America an apology! #BigLeagueTruth #Debates https://t.co/KcmDedSUTw
#
# Date : 16-10-10 01:16:36
# Text : "RT @TeamTrump: Quite simply, @HillaryClinton mistreats women. #BigLeagueTruth #Debate2016
#
# Date : 16-10-10 01:08:45
# Text : "RT @TeamTrump: .@HillaryClinton just claimed she has a ""positive, optimistic view"" for America. #Debates https://t.co/hOWJYZbD7v"
#
# Date : 16-10-09 17:16:50
# Text : "Exclusive Video–Broaddrick, Willey, Jones to Bill's Defenders: ‘These Are Crimes,’ ‘Terrified’ of ‘Enabler’ Hillary
#
# Date : 16-10-09 16:02:35
# Text : "LA Times- USC Dornsife Sunday Poll: Donald Trump Retains 2 Point Lead Over Hillary:
#
# Date : 16-10-08 22:41:10
# Text : "RT @atensnut: Hillary calls Trump's remarks ""horrific"" while she lives with and protects a ""Rapist"".  Her actions are horrific."
#
# Date : 16-10-05 02:31:22
# Text : RT @TeamTrump: RT if you agree - @HillaryClinton &amp; @timkaine are WRONG for America! #VPDebate #MAGA https://t.co/2MZfFzCo6c
#
# Date : 16-10-05 02:23:01
# Text : """@FLifeforce: @_CFJ_ @vine That is a reason to NOT Vote for Hillary Clinton. Vote for Liberty! Vote for @realDonaldTrump"""
#
# Date : 16-10-05 02:22:24
# Text : ".@HillaryClinton’s Careless Use Of A Secret Server Put National Security At Risk: https://t.co/OiAEMnrGcy #VPDebate
#
# Date : 16-10-05 02:17:20
# Text : RT @TeamTrump: .@HillaryClinton &amp; @timkaine think you're #Deplorables &amp; #BasementDwellers. @realDonaldTrump &amp; @mike_pence think you're PATR…
#
# Date : 16-10-05 01:46:08
# Text : ".@HillaryClinton Sneers At Millions Of Average Americans.
#
# Date : 16-10-05 01:33:50
# Text : """@carol_lcnixon67: @realDonaldTrump Kaine says Hillary and he have plans. She could care less what Kaine thinks."""
#
# Date : 16-10-05 01:24:38
# Text : RT @TeamTrump: .@timkaine has a pay-to-play problem just like Crooked @HillaryClinton #VPDebates #BigLeagueTruth https://t.co/SPOIn8AN8m
#
# Date : 16-10-04 23:55:55
# Text : "Wow, did you just hear Bill Clinton's statement on how bad ObamaCare is. Hillary not happy. As I have been saying, REPEAL AND REPLACE!"
#
# Date : 16-10-02 21:48:21
# Text : Bernie should pull his endorsement of Crooked Hillary after she decieved him and then attacked him and his supporters.
#
# Date : 16-10-02 11:35:00
# Text : I have created tens of thousands of jobs and will bring back great American prosperity. Hillary has only created jobs at the FBI and DOJ!
#
# Date : 16-10-01 21:25:52
# Text : "Wow, just saw the really bad @CNN ratings. People don't want to watch bad product that only builds up Crooked Hillary."
#
# Date : 16-09-30 18:24:21
# Text : "Why isn't Hillary 50 points ahead? Maybe it's the email scandal, policies that spread ISIS, or calling millions of… https://t.co/yKz9vCz8O1"
#
# Date : 16-09-30 09:30:11
# Text : Did Crooked Hillary help disgusting (check out sex tape and past) Alicia M become a U.S. citizen so she could use her in the debate?
#
# Date : 16-09-30 09:19:25
# Text : Using Alicia M in the debate as a paragon of virtue just shows that Crooked Hillary suffers from BAD JUDGEMENT! Hillary was set up by a con.
#
# Date : 16-09-30 09:14:03
# Text : "Wow, Crooked Hillary was duped and used by my worst Miss U. Hillary floated her as an ""angel"" without checking her past, which is terrible!"
#
# Date : 16-09-29 22:17:55
# Text : "While Hillary profits off the rigged system, I am fighting for you! Remember the simple phrase: #FollowTheMoney… https://t.co/8mVInc82E9"
#
# Date : 16-09-28 22:54:59
# Text : "Thank you Council Bluffs, Iowa! Will be back soon. Remember- everything you need to know about Hillary -- just… https://t.co/45kIHxdX83"
#
# Date : 16-09-27 20:14:33
# Text : "Hillary Clinton's Campaign Continues To Make False Claims About Foundation Disclosure:
#
# Date : 16-09-27 14:49:09
# Text : Hillary's been failing for 30 years in not getting the job done - it will never change.
#
# Date : 16-09-27 13:49:07
# Text : 'True blue-collar billionaire Donald Trump shows Hillary Clinton is out of touch' https://t.co/NHO1OicfVm
#
# Date : 16-09-27 12:53:42
# Text : I really enjoyed the debate last night.Crooked Hillary says she is going to do so many things.Why hasn't she done them in her last 30 years?
#
# Date : 16-09-27 02:42:49
# Text : ".@HillaryClinton’s Nuclear Agreement Paved The Way For The $400 Million Ransom Payment #DebateNight
#
# Date : 16-09-27 02:36:11
# Text : .@HillaryClinton - Obama #ISIS Strategy Has Allowed It To Expand To Become A Global Threat #DebateNight https://t.co/f7PctDE31L
#
# Date : 16-09-27 02:33:59
# Text : RT @TeamTrump: .@realDonaldTrump calling out @HillaryClinton's support for NAFTA = most searched moment during tonight's debate. #Debates20…
#
# Date : 16-09-27 02:28:26
# Text : "Russia has more warheads than ever, N Korea is testing nukes, and Iran got a sweetheart deal to keep theirs. Thanks, @HillaryClinton."
#
# Date : 16-09-27 02:26:13
# Text : "Hillary Clinton failed all over the world.
#
# Date : 16-09-27 02:22:12
# Text : "RT @TeamTrump: 100% TRUE --&gt; @realDonaldTrump is right - @HillaryClinton did call TPP ‘the gold standard’ #Debates2016
#
# Date : 16-09-27 02:21:59
# Text : Hillary Clinton is the only candidate on stage who voted for the Iraq War. #Debates2016 #MAGA https://t.co/Um5WJXEEKr
#
# Date : 16-09-27 02:19:47
# Text : ".@HillaryClinton's 2008 Campaign And Supporters Trafficked In Rumors About Obama's Heritage #DebateNight
#
# Date : 16-09-27 02:19:20
# Text : "RT @TeamTrump: Hillary's policies have made America less safe, that's why 200+ general and military leaders have endorsed @realDonaldTrump!…"
#
# Date : 16-09-27 01:36:50
# Text : "This is the simple fact about @HillaryClinton: she is a typical politician - all talk, no action. #Debates2016"
#
# Date : 16-09-27 01:28:50
# Text : .@HillaryClinton has been part of the rigged DC system for 30 years? Why would we take policy advice from her? #Debates2016
#
# Date : 16-09-27 01:23:43
# Text : .@HillaryClinton channels John Kerry on trade: she was for bad trade deals before she was against them. #TPP #Debates2016
#
# Date : 16-09-27 01:18:55
# Text : .@HillaryClinton and Obama policies increased debt by $9trillion over the last 8 years
#
# Date : 16-09-27 00:47:05
# Text : "Why isn't Hillary Clinton 50 points ahead?
#
# Date : 16-09-25 13:04:46
# Text : Bernie Sanders gave Hillary the Dem nomination when he gave up on the e-mails. That issue has only gotten bigger!
#
# Date : 16-09-25 12:30:28
# Text : "Many on the team and staff of Bernie Sanders have been treated badly by the Hillary Clinton campaign - and they like Trump on trade, a lot!"
#
# Date : 16-09-24 02:09:56
# Text : "Crooked Hillary's bad judgement forced her to announce that she would go to Charlotte on Saturday to grandstand. Dem pols said no way, dumb!"
#
# Date : 16-09-23 17:26:56
# Text : "Hillary Clinton just lost every Republican she ever had, including Never Trump, all farmers &amp; sm. biz, by saying she’ll tax estates at 65%."
#
# Date : 16-09-20 14:23:59
# Text : "Hillary Clinton is taking the day off again, she needs the rest. Sleep well Hillary - see you at the debate!"
#
# Date : 16-09-20 14:20:50
# Text : Do people notice Hillary is copying my airplane rallies - she puts the plane behind her like I have been doing from the beginning.
#
# Date : 16-09-20 12:02:35
# Text : "Crooked Hillary has been fighting ISIS, or whatever she has been doing, for years. Now she has new ideas. It is time for change."
#
# Date : 16-09-19 16:53:42
# Text : "Hillary Clinton's weakness while she was Secretary of State, has emboldened terrorists all over the world..cont: https://t.co/E5BdTiwlur"
#
# Date : 16-09-17 21:38:50
# Text : "The failing @nytimes has gone nuts that Crooked Hillary is doing so badly. They are willing to say anything, has become a laughingstock rag!"
#
# Date : 16-09-17 05:53:09
# Text : Crooked Hillary wants to take your 2nd Amendment rights away. Will guns be taken from her heavily armed Secret Service detail? Maybe not!
#
# Date : 16-09-14 03:09:37
# Text : Why isn't President Obama working instead of campaigning for Hillary Clinton?
#
# Date : 16-09-10 23:37:06
# Text : Hillary Clinton just had her 47% moment. What a terrible thing she said about so many great Americans!
#
# Date : 16-09-10 18:18:37
# Text : "While Hillary said horrible things about my supporters, and while many of her supporters will never vote for me, I still respect them all!"
#
# Date : 16-09-10 12:47:18
# Text : "Wow, Hillary Clinton was SO INSULTING to my supporters, millions of amazing, hard working people. I think it will cost her at the Polls!"
#
# Date : 16-09-09 00:39:36
# Text : It wasn't Matt Lauer that hurt Hillary last night. It was her very dumb answer about emails &amp; the veteran who said she should be in jail.
#
# Date : 16-09-08 16:25:36
# Text : Hillary Clinton answered email questions differently last night than she has in the past. She is totally confused. Unfit to serve as #POTUS.
#
# Date : 16-09-08 15:17:47
# Text : Hillary just gave a disastrous news conference on the tarmac to make up for poor performance last night. She's being decimated by the media!
#
# Date : 16-09-08 12:10:13
# Text : """A rough night for Hillary Clinton""  ABC News."
#
# Date : 16-09-07 15:11:59
# Text : "'Donald Trump leads Hillary Clinton by 19 points among military, veteran voters: poll' #AmericaFirst #MAGA
#
# Date : 16-09-06 15:31:09
# Text : "Mainstream media never covered Hillary’s massive “hacking”
#
# Date : 16-09-05 01:28:02
# Text : """@lblackvelvet: @realDonaldTrump We need to show Americans that Hillary will KILL our Country !! Vote for Trump !!"""
#
# Date : 16-09-05 01:24:26
# Text : """@CherNuna: @realDonaldTrump It defies belief the Web of Lies Hillary is spinning! One excuse after another. Then it's this, then it's that."
#
# Date : 16-09-04 23:49:48
# Text : "Lyin' Hillary Clinton told the FBI that she did not know the ""C"" markings on documents stood for CLASSIFIED. How can this be happening?"
#
# Date : 16-09-04 23:17:38
# Text : The polls are close so Crooked Hillary is getting out of bed and will campaign tomorrow.Why did she hammer 13 devices and acid-wash e-mails?
#
# Date : 16-09-04 16:04:21
# Text : Crooked Hillary's V.P. pick said this morning that I was not aware that Russia took over Crimea. A total lie - and taken over during O term!
#
# Date : 16-09-03 20:36:39
# Text : ".@CNN is so disgusting in their bias, but they are having a hard time promoting Crooked Hillary in light of the new e-mail scandals."
#
# Date : 16-09-01 05:06:52
# Text : "Hillary Clinton doesn't have the strength or the stamina to MAKE AMERICA GREAT AGAIN! #AmericaFirst
#
# Date : 16-09-01 00:40:07
# Text : "Hillary Clinton didn't go to Louisiana, and now she didn't go to Mexico. She doesn't have the drive or stamina to MAKE AMERICA GREAT AGAIN!"
#
# Date : 16-08-29 18:41:49
# Text : #CrookedHillary https://t.co/vXhcC8PaPy
#
# Date : 16-08-29 13:35:31
# Text : "Now that African-Americans are seeing what a bad job Hillary type policy and management has done to the inner-cities, they want TRUMP!"
#
# Date : 16-08-29 13:30:04
# Text : "Crooked Hillary's brainpower is highly overrated.Probably why her decision making is so bad or, as stated by Bernie S, she has BAD JUDGEMENT"
#
# Date : 16-08-29 13:23:02
# Text : "Does anyone know that Crooked Hillary, who tried so hard, was unable to pass the Bar Exams in Washington D.C. She was forced to go elsewhere"
#
# Date : 16-08-29 13:17:47
# Text : """@PMNOrlando: @realDonaldTrump I know of NO ONE voting for Crooked Hillary! Her rallies are held in (blank)  &amp; she still has room."
#
# Date : 16-08-28 23:24:14
# Text : "I think that both candidates, Crooked Hillary and myself, should release detailed medical records. I have no problem in doing so! Hillary?"
#
# Date : 16-08-28 19:29:15
# Text : RT @FoxNews: Poll: @realDonaldTrump vs. @HillaryClinton among white Evangelicals. https://t.co/6ohwIh1Q24
#
# Date : 16-08-28 03:37:21
# Text : """@LindaHarden: @realDonaldTrump America loves Trump and @mike_pence -- praying for you every day. Stay strong. #TrumpPence2016 #NeverHillary"
#
# Date : 16-08-27 15:18:52
# Text : """@GoldJazz559: #BlackMenForBernie Leader: #Hillary2016 ‘No Regard For Black Race’ https://t.co/m8952Ly3Jb via @dailycaller #BlacksForTrump"
#
# Date : 16-08-27 15:10:10
# Text : """@DiamondandSilk: Crooked Hillary getting desperate. On TV bashing Trump. @CNN, she forgot how she said a KKK member was her mentor."
#
# Date : 16-08-26 19:26:16
# Text : Army training slide lists Hillary Clinton as insider threat: https://t.co/CQTSo2ETJF
#
# Date : 16-08-26 19:21:22
# Text : Meet the ‘Trumpocrats’: Lifelong Democrats Breaking w/ Party Over Hillary to Support Donald Trump for President: https://t.co/g2N3JJWV8a
#
# Date : 16-08-26 19:18:15
# Text : """Hillary Clinton Deleted Emails Using Program Intended To Prevent Recovery"" #CrookedHillary https://t.co/D0MeBJXBwN"
#
# Date : 16-08-26 17:14:09
# Text : "How quickly people forget that Crooked Hillary called African-American youth ""SUPER PREDATORS"" - Has she apologized?"
#
# Date : 16-08-26 13:50:42
# Text : "Crooked Hillary will NEVER be able to solve the problems of poverty, education and safety within the African-American &amp; Hispanic communities"
#
# Date : 16-08-26 02:58:51
# Text : """Hillary Clinton needs to address the racist undertones of her 2008 campaign."" #FlashbackFriday https://t.co/MJQp0rcnzH"
#
# Date : 16-08-26 02:46:34
# Text : """@foxnation: Flashback: Hillary Clinton Praised Former KKK Member Robert Byrd as 'Friend and Mentor': https://t.co/e0Hb2rLb1X"""
#
# Date : 16-08-26 02:40:04
# Text : "Hillary Clinton only knows how to make a speech when it is a hit on me. No policy, and always very short (stamina). Media gives her a pass!"
#
# Date : 16-08-25 20:45:38
# Text : Hillary Clinton is using race-baiting to try to get African-American voters- but they know she is all talk and NO ACTION!
#
# Date : 16-08-25 20:14:20
# Text : Hillary Clinton's short speech is pandering to the worst instincts in our society. She should be ashamed of herself!
#
# Date : 16-08-25 20:11:41
# Text : Just watched recap of #CrookedHillary's speech. Very short and lies. She is the only one fear-mongering!
#
# Date : 16-08-23 14:46:58
# Text : "Hillary Clinton strongly stated  that there was ""absolutely no connection"" between her private work and that of The State Department. LIE!"
#
# Date : 16-08-22 01:19:06
# Text : """@Jimbos2002:  @Morning_Joe Video: Hillary referring to blacks as super predators that need to be brought to heel. https://t.co/pMIHWayMRw"""
#
# Date : 16-08-22 00:33:38
# Text : Crooked Hillary is flooding the airwaves with false and misleading ads - all paid for by her bosses on Wall Street. Media is protecting her!
#
# Date : 16-08-20 00:17:09
# Text : #WheresHillary? Sleeping!!!!!
#
# Date : 16-08-18 20:55:33
# Text : #CrookedHillary #ThrowbackThursday https://t.co/v8J0r64J7h
#
# Date : 16-08-17 16:57:58
# Text : "A vote for Hillary Clinton is a vote for another generation of poverty, high crime, &amp; lost opportunities. #ImWithYou
#
# Date : 16-08-14 16:55:07
# Text : "I am not only fighting Crooked Hillary, I am fighting the dishonest and corrupt media and her government protection process. People get it!"
#
# Date : 16-08-14 16:50:51
# Text : Crooked Hillary Clinton is being protected by the media. She is not a talented person or politician. The dishonest media refuses to expose!
#
# Date : 16-08-14 12:37:37
# Text : "If the disgusting and corrupt media covered me honestly and didn't put false meaning into the words I say, I would be beating Hillary by 20%"
#
# Date : 16-08-14 12:24:48
# Text : The failing @nytimes talks about anonymous sources and meetings that never happened. Their reporting is fiction. The media protects Hillary!
#
# Date : 16-08-12 13:01:06
# Text : ISIS gained tremendous strength during Hillary Clinton's term as Secretary of State. When will the dishonest media report the facts!
#
# Date : 16-08-12 11:07:51
# Text : A massive tax increase will be necessary to fund Crooked Hillary Clinton's agenda. What a terrible (and boring) rollout that was yesterday!
#
# Date : 16-08-12 04:06:22
# Text : """@elsolarverde: THE CORRUPT MEDIA CREATS CONTROVERSY AGAINST @realDonaldTrump TO AVOID ISSUES ABOUT HillaryClinton https://t.co/RW5UcWLfA8"""
#
# Date : 16-08-10 01:11:39
# Text : "When is the media going to talk about Hillary's policies that have gotten people killed, like Libya, open borders, and maybe her emails?"
#
# Date : 16-08-09 20:49:42
# Text : RT @NRA: But there IS something we will do on #ElectionDay: Show up and vote for the #2A! #DefendtheSecond #NeverHillary
#
# Date : 16-08-09 20:49:38
# Text : "RT @NRA: .@RealDonaldTrump is right. If @HillaryClinton gets to pick her anti-#2A #SCOTUS judges, there’s nothing we can do. #NeverHillary"
#
# Date : 16-08-09 12:02:25
# Text : """@LinHen23:  @foxandfriends Loved Trump's answers to voters questions this morning! Trump's economic plan will help #MAGA #NeverHillary"""
#
# Date : 16-08-08 22:45:33
# Text : Many people are saying that the Iranians killed the scientist who helped the U.S. because of Hillary Clinton's hacked emails.
#
# Date : 16-08-07 01:53:45
# Text : "I am not just running against Crooked Hillary Clinton, I am running against the very dishonest and totally biased media - but I will win!"
#
# Date : 16-08-06 20:04:08
# Text : "#CrookedHillary is not fit to be our next president! #TrumpPence16
#
# Date : 16-08-06 18:11:50
# Text : "Heading to New Hampshire - will be talking about Hillary saying her brain SHORT CIRCUITED, and other things!"
#
# Date : 16-08-06 14:24:43
# Text : "Crooked Hillary said loudly, and for the world to see, that she ""SHORT CIRCUITED"" when answering a question on her e-mails. Very dangerous!"
#
# Date : 16-08-06 11:53:00
# Text : Hillary Clinton is being badly criticized for her poor performance in answering questions. Let us all see what happens!
#
# Date : 16-08-05 13:08:35
# Text : "Hillary Clinton has bad judgment and is unfit to serve as President.
#
# Date : 16-08-03 10:23:27
# Text : "Our incompetent Secretary of State, Hillary Clinton, was the one who started talks to give 400 million dollars, in cash, to Iran. Scandal!"

# %%
from itertools import tee
search = raw_input('Search Term')
with open("symmetrymag_tweets.csv") as inf:
    # set up iterators
    cfg,res = tee(inf)
    # advance cfg by four lines
    for i in range(4):
        next(cfg)

    for c,r in zip(cfg, res):
        if search in c:
            print "Date :",c[21:38],"\nText :",c[39:]
# Out:
# Search Termfuture
# Date : 17-09-27 16:58:55
# Text : RT @LIGO: #GravitationalWave detection is a worldwide endeavor now!  In the future network will expand to Japan and India.
#
# Date : 17-08-22 17:00:04
# Text : "For your future physicist:
#
# Date : 17-08-10 18:10:30
# Text : The new Fermilab Accelerator Science and Technology facility at Fermilab looks to the future of accelerator science: https://t.co/TslngEctB0
#
# Date : 17-07-21 18:45:01
# Text : "Read about the history of @SanfordLab, future home of @DUNEScience: https://t.co/zOc6darbYU #buildLBNF"
#
# Date : 17-07-21 18:15:01
# Text : "Learn more about working underground at Sanford Lab, future home of @DUNEScience: https://t.co/CXngbrjN37 #buildLBNF"
#
# Date : 17-05-10 17:00:03
# Text : How blue-sky research shapes the future: https://t.co/pfjWwEG2PC https://t.co/5vyZayntCu
#
# Date : 17-04-28 18:01:27
# Text : "If you have other topics you’d like #AskSymmetry to cover in the future, tweet at us or email info@symmetrymagazine.org."
#
# Date : 17-04-22 17:00:02
# Text : "How basic, ""blue-sky"" research shapes the future: https://t.co/pfjWwEorr2 https://t.co/y03nwVbFDV"
#
# Date : 17-04-18 19:52:35
# Text : "How basic, ""blue-sky"" research shapes the future: https://t.co/pfjWwEorr2 https://t.co/Zgh9MflEC3"
#
# Date : 17-03-08 17:00:04
# Text : Q&amp;A on the future of CERN with lab Director-General Fabiola Gianotti:  https://t.co/itETDGSCOD… https://t.co/kOoZ3ChfC7
#
# Date : 17-02-17 19:16:33
# Text : "And if you have other topics you’d like #AskSymmetry to cover in the future, tweet at us or email info@symmetrymagazine.org."
#
# Date : 17-02-17 19:16:18
# Text : Thanks to all for participating in the TwitterChat! Sorry if we didn’t get to your Q. We’ll look at these for future #AskSymmetry videos!
#
# Date : 16-10-31 18:08:37
# Text : "If you have any topics you’d like #AskSymmetry to cover in the future, let us know info@symmetrymagazine.org"
#
# Date : 16-08-09 18:03:57
# Text : "If you have any topics you’d like #AskSymmetry to cover in the future, let us know info@symmetrymagazine.org"
#
# Date : 16-08-09 18:03:29
# Text : Thanks for the great discussion everyone! Sorry if we didn’t get to your question.  We’ll look at these for future #AskSymmetry videos.
#
# Date : 16-08-02 15:49:54
# Text : A chat with #CERN Director General Fabiola Gianotti about the future of the lab: https://t.co/itETDGSCOD https://t.co/J7sYz05UjX
#
# Date : 16-06-15 17:41:32
# Text : The future of gravitational wave detection #LIGO https://t.co/XNEmKRKJFy
#
# Date : 16-06-15 17:40:24
# Text : "RT @astrolisa: Reitze: ""The future is going to be full of binary black hole mergers for #LIGO."" Still ramping detector up to full sensitivi…"
#
# Date : 16-02-24 15:32:34
# Text : "@LeighJKBoerner Not at the moment, but who knows what the future holds!"
#
# Date : 15-12-20 21:00:12
# Text : "ICYMI: US, CERN agree to partner on LHC research, neutrino research and a future collider: https://t.co/8BGB8cgeuf https://t.co/c8mVX49QKf"
#
# Date : 15-12-18 16:04:26
# Text : "The US and CERN agree to partner on LHC research, neutrino research and a future collider: https://t.co/8BGB8cgeuf https://t.co/c8MMOxSRw7"
#
# Date : 15-08-26 22:39:39
# Text : "Scientists find a new way to accelerate antimatter, which might lead to smaller colliders in the future: http://t.co/VR5lWeY8Fy"

# %% [markdown]
# # VERY GOOD but needs Work

# %%
import TweepyToCSV
from TweepyToCSV import CustomStreamListener
TweepyToCSV.main()
# Out:
# (u'purpleohms', datetime.datetime(2017, 10, 6, 6, 21, 37), u'@PeteNorth303 Article 50 triggered, unnecessary general election, do we really have time for a leadership contest?')
# (u'spookyoonji_twt', datetime.datetime(2017, 10, 6, 6, 21, 37), u'no thanks https://t.co/m6X2bfy5Pi')
# (u'Sochar06', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @gamngbizzle: \U0001f33d Follow everyone who RETWEETs this.')
# (u'MeiLiCruz88', datetime.datetime(2017, 10, 6, 6, 21, 37), u"RT @MonicaLogallmon: @thedailybeast @MooPersists That's ridiculous. @GOP going to return their money to Mercers, koch brothers, Russia, @nr\u2026")
# (u'S_A_Malcolm', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @votevets: Trump is back to attacking American Veterans. Vote @RalphNortham for #vagov https://t.co/HSXsIaWC36')
# (u'TwhenningW', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @johnbcrist: If football coaches were honest... https://t.co/trmUd9aq7T')
# (u'indigomak', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @PrincessVitarah: I Wanna Fuck Donald Trump (Music Video) https://t.co/l7ARgw9Pzj https://t.co/tG3rFT59dZ')
# (u'BEING_DABBANG', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @S0UD1P: I trust only 3 actors in the industry. Salman, Hrithik &amp; Varun. Rests are weirds.')
# (u'omprakash1704', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @dijuli22: " UP Hospital Model "? GOD FORBID. https://t.co/SKbJCvInYV')
# (u'jcfuntanares', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @WatchGamesTV: Announcing a NEW style of betting!\n\n- RT + FOLLOW @csgocupcom\n\n- Comment on the video on their page!\n\nWinner in 72\u2026 ')
# (u'Ady_Amim', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @SmokerMee: follow everyone who LIKES this \U0001f696')
# (u'Ady_Amim', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @Tangerine4545: Follow everyone who fav this \U0001f60e\U0001f60e')
# (u'Priscilladcamp', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @barefootboomer: LESS DEAD PEOPLE WE WANT LESS DEAD PEOPLE THAT\u2019S REALLY IT GUYS NO FOOLIN\u2019 LESS DEAD PEOPLE https://t.co/wSIwQf0XSW')
# (u'wintermaputo', datetime.datetime(2017, 10, 6, 6, 21, 37), u"RT @Independent: California becomes 'sanctuary state' with law protecting immigrants from Trump https://t.co/0oXUM3jqQy")
# (u'mashaeir123', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @Harrys1DEmpire: Follow everyone who Likes and Retweets this\U0001f35f\n#1DDrive \U0001f525')
# (u'averyandchill', datetime.datetime(2017, 10, 6, 6, 21, 37), u'RT @smilingavery: -the old merch is gone\n-limelight is $300 \n-no after party\n-donald trump is still the president \n\nis the what the world e\u2026')
# (u'Allena2kA', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @StephenAtHome: Drinking Game: Every time Trump says "I\'d give our response to Puerto Rico an A+," remember that Puerto Ricans have noth\u2026')
# (u'southsider4', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @DavidCornDC: So Ivanka Trump and Jared Kushner transferred their email accounts to Trump Org. *after* Congress told them not to?\u2026 ')
# (u'marwannne', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @pushcum: \U0001f6a6Follow everyone who retweets this 2 mins')
# (u'misschrisbunny', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @tedlieu: Freaked out? Support HR 669 by Sen @EdMarkey &amp; me. Bill prohibits @POTUS from launching nuclear 1st strike without\u2026 ')
# (u'JenniSolano8', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT HanaTranova1: Trump\u2019s Press Secretary Was Just Asked About His War With NBC. Her Response Is Absurd \u2026 https://t.co/5ihXyjPBB3')
# (u'bnanakookie', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @jjeonsisi: \U0001f430[GIVEAWAY SPECIAL 3,000 FOLLOWERS]\U0001f430\nYOU GOT ME JUNGSHOOK\n\n-RT &amp; Like\U0001f430\n-Follow me @jjeonsisi\U0001f430\n#DNA6thWin \n\nEnd 7k\U0001f430\n\U0001f30e https:/\u2026')
# (u'amazon_r1', datetime.datetime(2017, 10, 6, 6, 21, 38), u'@follow_ok [\u76f8\u4e92\u30d5\u30a9\u30ed\u30fc] [\u30d5\u30a9\u30ed\u30ef\u30fc] [follow_ok] [\u76f8\u4e92] [\u30d5\u30a9\u30ed\u30fc] [\u30ea\u30d5\u30a9\u30ed\u30fc][\u30d5\u30a9\u30ed\u30fc\u8fd4\u3057] [followme] [sougofollow] [followme] [follow ok] #\u76f8\u4e92\u30d5\u30a9\u30ed\u30fc #follow_ok')
# (u'KnowLawrence', datetime.datetime(2017, 10, 6, 6, 21, 38), u'Royal Visit: Russia &amp; Saudi Arabia Sign Billion Dollar Arms &amp; Energy Contrac (pls RT\u21ba\u2764\ufe0f) https://t.co/1QyJTlMuKb #Kremlin #')
# (u'pepenjd97', datetime.datetime(2017, 10, 6, 6, 21, 38), u'\u256d\u2501\U0001f31f\u2501\u256f\n\u2570\U0001f31f\u278a\U0001f31f\u256e\n\u256d\u2501\U0001f31f\u2501\u256fRETWEET\n\u2570\U0001f31f\u278b\U0001f31f\u256e\n\u256d\u2501\U0001f31f\u2501\u256fFOLLOW ALL WHO RT\n\u2570\U0001f31f\u278c\U0001f31f\u256e\n\u256d\u2501\U0001f31f\u2501\u256fFOLLOWBACK\n\u2570\U0001f31f\u278d\U0001f31f\u256e\n\u256d\u2501\U0001f31f\u2501\u256fGAIN WITH #\n\u2570\U0001f31f\u278e\U0001f31f\u256e\n\u256d\u2501\U0001f31f\u2501\u256fFOLLOW \u261e @pepenjd97')
# (u'Ady_Amim', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @gamngbizzle: \u2b50\ufe0f Follow everyone who RETWEETs this.')
# (u'tomso_s', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @MauriceSchleepe: Konashenkov,#US support for terrorists the main obstacle for routing #IS in #Syria,#Russia,s airforce is ready to H\u2026 ')
# (u'SarahannSarah', datetime.datetime(2017, 10, 6, 6, 21, 38), u"RT @phillipxprince1: The blatant misrepresentation of Corbyn's pre-election views on student debt being peddled by Tories...now been ful\u2026 ")
# (u'Acee215', datetime.datetime(2017, 10, 6, 6, 21, 38), u"RT @Kiara_gotit: You literally can't trust anyone.... everyone is untrustworthy &amp; idk why it's still so shocking to me \U0001f4af")
# (u'tommywhitby', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @Marshall_Cohen: CNN has confirmed: FEMA just abruptly deleted the webpage that told the American people that 95% of Puerto Ricans s\u2026 ')
# (u'AishaBieber123', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @DOGFATHER__MGWV: \U0001f4e2 #FOLLOWTRICK \U0001f4e2\n\n\u278a \u267b\ufe0f#RETWEET\u267b\ufe0f IF YOU ARE \U0001f4af #TEAMFOLLOWBACK\n\n\u278b FO\U0001f463OW ALL WHO RT\n\n\u278c GAIN \U0001f649\U0001f648\U0001f64a WITH #MGWV\n\n\u278d \U0001f463#FOLLOW\U0001f463\u2026')
# (u'Augerbug', datetime.datetime(2017, 10, 6, 6, 21, 38), u"RT @FuckNickx: Can't put yo trust in anything https://t.co/t9Ifrrpgi0")
# (u'lisa4137', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @TrueFactsStated: Breaking. Mueller prosecutors traveled to London to interview Christopher Steele. Author of Dossier. Stand by for T\u2026 ')
# (u'clairee_beaar', datetime.datetime(2017, 10, 6, 6, 21, 38), u'lmao crystal \U0001f62d\U0001f62d\U0001f62d \u201c I\u2019m confused\u201d \U0001f602 https://t.co/Mxicc3bRgh')
# (u'abbymoore___', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @Austo_cmp: Aye yall rt everything else on this app so rt something that actually matters like this https://t.co/k0LFMZpiLZ')
# (u'MtlchckAsh101', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @WhoHatesJuTv: My bro is new to #Twitter so please #Follow \n\n\U0001f449\U0001f3fc @J6Hagen \U0001f448\U0001f3fc #Support My Bro Y\u2019all! https://t.co/OEBlpie4A9')
# (u'SashaMathx', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT HanaTranova1: Trump Just Got Caught Concealing Truth Of Puerto Rico Suffering. Chelsea Clinton\u2019s Response Is Sp\u2026 https://t.co/DzJqZcflfR')
# (u'mattthelib', datetime.datetime(2017, 10, 6, 6, 21, 38), u'@essenviews Seriously? @SHSanders45 The mayor literally waded through flood waters with a bullhorn looking for peop\u2026 https://t.co/jRBPKqoDnI')
# (u'irannsita', datetime.datetime(2017, 10, 6, 6, 21, 38), u"RT @bretmanrock: I hate it when ugly bitches lie to me.. I'm not saying if you cute you can lie but ugh I hate liars")
# (u'JerseyJim2', datetime.datetime(2017, 10, 6, 6, 21, 38), u'@ChicagosFines19 @NFL OMG &amp; BS=THIS VEGAS KILLER WANTED  TO KILL ONLY TRUMP SUPPORTERS=JUST LIKE THE DC BASEBALL SH\u2026 https://t.co/96MpZFHKgS')
# (u'Angels_Demons2', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @OriginalFunko: RT &amp; follow @OriginalFunko for your chance to WIN a #Thorsday Prize Pack. #Thor #ThorRagnarok https://t.co/TzVIvaSGia')
# (u'HuiDvorovoy', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @_langren: nbc: \u0437\u0430\u043a\u0440\u044b\u0432\u0430\u0435\u043c \u0433\u0430\u043d\u043d\u0438\u0431\u0430\u043b\u0430 \u043f\u043e\u0441\u043b\u0435 s3\n\u0444\u0443\u043b\u043b\u0435\u0440: 4 \u0441\u0435\u0437\u043e\u043d \u0431\u0443\u0434\u0435\u0442 \u043e\u0445\u0443\u0435\u043d\u043d\u044b\u043c\nnbc: \u043d\u043e\n\u043a\u0430\u0441\u0442: \u043c\u044b \u0441\u043e\u0433\u043b\u0430\u0441\u043d\u044b \u043d\u0430 \u0432\u0441\u0435\nnbc: \u0441\u0435\u0440\u0438\u0430\u043b \u0437\u0430\u043a\u0440..\n\u0444\u0430\u043d\u044b: \u0441\u043a\u2026')
# (u'Gila_Toulou', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @Mojahedineng: #News #Iran #Trump expected to decertify #Iran #nuclear deal, official says https://t.co/ix5xefUKAg https://t.co/mBq8eZWD\u2026')
# (u'anyacobley', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @teenboxie: Freebie Friday? Just follow us and #RT this! Simple. Will announce winner at 10pm tonight! #FreebieFriday\u2026 ')
# (u'myredcatrocks', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @michael_house9: @CBCNews Can\'t blame the irregulars..they have heard anyone can be granted "asylum" in Trudeau\'s CDA...free healthc\u2026 ')
# (u'Ady_Amim', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @xtiandela: Want to gain 1,000 Followers NOW?..NO KIDDING!\n1. #RETWEET this Tweet\n2. Follow the first 1,000 people to Retweet\n3. Gain\n#G\u2026')
# (u'SandyKrue', datetime.datetime(2017, 10, 6, 6, 21, 38), u'DISGUSTING China &amp; So Korea Have \nthe WORST CRUELTY on Dogs, Cats, Donkeys, etc.\nContact Ambassadors in DC ! @peta\u2026 https://t.co/4v3FQdIghi')
# (u'jun3bug22', datetime.datetime(2017, 10, 6, 6, 21, 38), u'Mannnnn I Hate It When She Do That Sh.T\u203c\ufe0f #Weezy')
# (u'nicoleerios01', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @whatanaja: This is my step mom Lindsey Licari she is trying everything to save my brother if you go on her FB or Ig(\u2026 ')
# (u'PriyanSHAH_', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @masrur2srk: Follow him please @JoySRKian_ \n\n( Javed Bhai )\n\n His old id got suspended \n\n\U0001f525\U0001f525\U0001f525\U0001f525\U0001f525\U0001f525\U0001f525')
# (u'BehlndCashMoney', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @GrantCardone: Thinking about buying 10 Biggest Follow-Up Mistakes | eBook? Read the latest revi https://t.co/zgxdBe0Jl1 via @yotpo')
# (u'knlaguerre', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT
datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @PaulBaxterNFRN: Scotland take a positive position on DRS and we welcome the move to increase recycling and create a circular economy ht\u2026')
# (u'teshawnmoore', datetime.datetime(2017, 10, 6, 6, 21, 39), u'\U0001f4af\U0001f4af\U0001f4af\U0001f4af https://t.co/ZxHcBNiOic')
# (u'marlene116', datetime.datetime(2017, 10, 6, 6, 21, 39), u'Can hardly wait to read book, The Strange Case of Donald Trump. Probably will make me even more frightened! Thanks, @Lawrence')
# (u'herrick_esther', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @herrick_esther: Incredibly important health care thread. Please read and pass on. \n@IndivisibleCA04 @IndivisibleTeam @NationalADAPT htt\u2026')
# (u'joy_gets_it', datetime.datetime(2017, 10, 6, 6, 21, 38), u'RT @RecklessxNicole: UGHH \U0001f49b\U0001f49b https://t.co/t2qyuhv7bS')
# (u'jewohl10', datetime.datetime(2017, 10, 6, 6, 21, 39), u'Follow everyone who LIKES  this..')
# (u'Run_IsHere', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @MicahGrimes: The president was asked what this means, and he would not say. https://t.co/PoUpLhyu8t')
# (u'Ananya_Sriti', datetime.datetime(2017, 10, 6, 6, 21, 39), u'@nitusharma115 I hate Zubair\U0001f612\U0001f612')
# (u'_nurulhudalms', datetime.datetime(2017, 10, 6, 6, 21, 39), u'i hate hot sunny days.')
# (u'shaylondaa', datetime.datetime(2017, 10, 6, 6, 21, 39), u'@jazminjaneab https://t.co/4X5SC27iGg')
# (u'Sexy_Webcamgirl', datetime.datetime(2017, 10, 6, 6, 21, 39), u'Check out all of my latest videos and follow me @SpicyFind https://t.co/HosIPJm8pv https://t.co/kcb43P1nd4')
# (u'RodYork', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @JeremyCorbyn4PM: JC campaigned in this by-election in East Worthing &amp; Shoreham at #Lab17. Last night we won with 49.3% of vote, a 29\u2026 ')
# (u'Michharding', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT HanaTranova1: Trump Just Got Caught Concealing Truth Of Puerto Rico Suffering. Chelsea Clinton\u2019s Response Is Sp\u2026 https://t.co/rc0VwdLKVE')
# (u'Bizzel_83', datetime.datetime(2017, 10, 6, 6, 21, 39), u"Listening to 'As you were' wondering why he didn't just call it 'I hate Noel Gallagher, and I'm gonna burn his house down' #Obsessed \U0001f602")
# (u'vicki_moore', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @Salon: Trump wants the Senate Intelligence Committee to investigate \u201cFake News Networks\u201d https://t.co/VkyxHBh8ir')
# (u'morthnadic', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @JasonLeopold: Sputnik:\xa0 60 Years Later, CIA Releases Declassified Documents\n\nhttps://t.co/H0lmF5EZkd')
# (u'VictorYabigue', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @lesbi_julie: Venez en DM \U0001f4a6\U0001f4a6\U0001f4a6 #rt #follow  https://t.co/xqeA5VboNl')
# (u'Bak_Mamba', datetime.datetime(2017, 10, 6, 6, 21, 39), u"RT @lovvedess: My boyfriend just told me to post him for national boyfriend day as if my other boyfriend doesn't follow me.")
# (u'politeperson123', datetime.datetime(2017, 10, 6, 6, 21, 39), u"RT @SethAbramson: 23/ And it's now confirmed that Steele evaded Trump's minions not because his work was a hoax, but because *he was in con\u2026")
# (u'AriaTaehyungs', datetime.datetime(2017, 10, 6, 6, 21, 39), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'Qwerty_159753', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @ChrisKlemens: SENDING OUT MORE DMS https://t.co/K98oY6cGcu')
# (u'mikewayne71', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @essenviews: Republicans once railed against deficits but Trump\u2019s tax plan piles on more than $2 Trillion to the deficit. https://t.co/0\u2026')
# (u'aVandoo001', datetime.datetime(2017, 10, 6, 6, 21, 39), u'Bad business no.3 - \u2018Calm before the storm\u2019: Trump baffles White House press pool.https://t.co/C3ATkF3WGw')
# (u'amyvxv', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @conangray: i hate it when ppl aren\u2019t in love with me ://')
# (u'flickersoflove', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @GainTrickOG: Follow everyone who retweets and likes this\U0001f420')
# (u'ariannavargas_', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @PeoplesOracle: But not for Puerto Rico.\nBut not for healthcare.\nBut not for education. https://t.co/2H7MDPBgix')
# (u'_JayWebster', datetime.datetime(2017, 10, 6, 6, 21, 39), u"RT @lildurk: I can't trust to save my life \U0001f634")
# (u'ReggieDog3', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @ASlavitt: BREAKING: This story is incredible.\n\nTrump personally ordering rates \u2b06\ufe0f 4 American families in order to break ACA.\n\nhttps://t\u2026')
# (u'DavidLiles3', datetime.datetime(2017, 10, 6, 6, 21, 39), u'https://t.co/Sv6kvMczff')
# (u'Aam_Nationalist', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @kapsology: Sources: BJP got all this money as party fund! This money will be back into economy by 2019 elections \U0001f62c https://t.co/dXLzswR\u2026')
# (u'Absta77', datetime.datetime(2017, 10, 6, 6, 21, 39), u'RT @FatherSons_: Win a shirt of your choice at #FatherSons.\n\n- Follow\n- RT\n\nWinner chosen Sunday | https://t.co/AQbxM2lfn5 https://t.co/dra\u2026')
# (u'Joshua_s_TtToe', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @polNewsInfinity: This is the level CBS News is at. They think there\u2019s such a thing as \u201cautomatic rounds.\u201d\nThis is why you can\u2019t talk\u2026 ')
# (u'bluhowrse1997', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @GucciClout: RT IF THIS IS THE CUTEST SHIT YOU'VE EVER SEEN https://t.co/9VN4tP9vBi")
# (u'Michharding', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT HanaTranova1: Trump\u2019s Press Secretary Was Just Asked About His War With NBC. Her Response Is Absurd \u2026 https://t.co/mxzBFe4kcw')
# (u'YouGottaCarryMe', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @OGranted: *GIVEAWAY*\nOVER $200 in CSGO skins including all skins in the pictures below!\n\nHow to Enter:\n1. Follow @OGranted &amp;\u2026 ')
# (u'_taengsthetic', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'DreamChaser365_', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @lildurk: I can't trust to save my life \U0001f634")
# (u'kasteilla', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @chikyu_gorgeous: \u3010\u30ad\u30e3\u30b9\u30c8\u7d39\u4ecb\u3011\nT.M.Revolution\u3068\u3057\u3066\u6d3b\u52d5\u3092\u3059\u308b\u508d\u3089\u30d0\u30e9\u30a8\u30c6\u30a3\u756a\u7d44\u3084\u58f0\u512a\u7b49\u3001\u591a\u65b9\u9762\u3067\u5927\u6d3b\u8e8d\u306e #\u897f\u5ddd\u8cb4\u6559 \u3055\u3093\u203c\ufe0f\n\u821e\u53f0\u306f2014\u5e74\u300c\u30f4\u30a7\u30ed\u30fc\u30ca\u306e\u30cb\u7d33\u58eb\u300d\u4ee5\u6765\u306e\u3054\u51fa\u6f14\u3001\u5730\u7403\u30b4\u30fc\u30b8\u30e3\u30b9\u306b\u66f4\u306a\u308b\u83ef\u3084\u304b\u3055\u3092\u52a0\u3048\u3066\u4e0b\u3055\u308b\u4e8b\u9593\u2026 ')
# (u'miss_mcinerney', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @SchoolsWeek: EXCLUSIVE: Harris academy chain to build 100 homes for teachers https://t.co/f1Jo9V1Vgc')
# (u'DhamaChalla', datetime.datetime(2017, 10, 6, 6, 21, 40), u'WORLD BANK PRAISES GST #REPUBLIC @republic https://t.co/l1nvYyfuNy')
# (u'Hell0Y0u', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @IIIM_G_W_VIII: \U0001f440\n\U0001f445 Retweet if you want to gain followers and follow everyone who retweets this!\n\n\U0001f632\U0001f616\U0001f632\U0001f628')
# (u'RafaelZamora_', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @AFP: Mexico's indigenous 'third gender' muxes are pushing boundaries by taking on women's traditional social roles\u2026 ")
# (u'11_MoNsTa', datetime.datetime(2017, 10, 6, 6, 21, 40), u'Wasted time https://t.co/IYslXL3jmZ')
# (u'eils_g', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @Impeach_D_Trump: I hope a Trump Indictment happens before Thanksgiving. I\'ve been practicing my smug "told-you-so" speech to deliver du\u2026')
# (u'Dick0128', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @sexhijab_: Haha \U0001f602\U0001f602, Yuks follow @gogodotlive @makicrot @makemehepi @angkotxxx  @papeldee https://t.co/UEK5lJ9hx6')
# (u'JamesonBlakeXXX', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @versateacher: Facebook vs Twitter. Hahaha tangina ang sarap ni kuya lalo na nung bumukaka habang tigas na tigas ang burat. Follow\u2026 ')
# (u'Tigerdude_Csgo_', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @UnicYoutube: AWP ASIIMOV #CSGOgiveaway \n\nTO ENTER \n\u2705FOLLOW ME &amp; @CSGONadeGG \n\u2705RT\n\u2705LIKE &amp; SHARE - https://t.co/fdyIc7rXzA  (PROOF\u2026 ')
# (u'OhCAROLss', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @Ms_Maiden07: Stop the hate daw kasi..so dahil baka may masapak, waley na lang sila \U0001f602 #ALDUBBigHearts')
# (u'Ana_Gra6', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT RVAwonk: If you voted for Trump, you gave a pass to Harvey Weinstein &amp; all the others like him. Stop pretending you care about sexual ha\u2026')
# (u'RudyMenggaSH6', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @shitofuniversal: 1: Like this\U0001f361\n2: Follow all that Like &amp; Retweet\U0001f361\n3: Follow back all that follow you\U0001f361\n4: Gain with #1DDrive \u2705\u2705\u2705\u2705\u2705\u2705')
# (u'mdboarder', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @_presentfinder: #Competition Retweet &amp; Follow to #win a Framed Coat of Arms &amp; Surname History https://t.co/ltX9Kvs8N5 T&amp;C apply https:/\u2026')
# (u'MrsBts97', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @BTS_ARMY: K-pop group's record breaking album conquers three continents @CNNI #BTS @BTS_twt https://t.co/z6mEAVo8bb")
# (u'2_Naughty_Legs', datetime.datetime(2017, 10, 6, 6, 21, 40), u"Let's just hope this is not accurate and we can squeeze a few more years with the current law\n\n https://t.co/RyM9Q4lVLa")
# (u'sasdlilylol_', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @GokiNamoo: \u2728BTS HER GIVEAWAY\u2728\n\nTHEY'RE FINALLY HERE\U0001f49c\n- 2 winners\n- Both are E ver. w/ photocard\n- Follow, RT &amp; comment to ente\u2026 ")
# (u'ElinHege', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @TalbertSwan: @DC_Resister_Bee @TaIbertSwan @realDonaldTrump @RalphNortham Reckless Trump Just Called His Meeting With Military L\u2026 ')
# (u'ar3uready', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @ZeldaDorant: Trump in Vegas https://t.co/kFHLQ336Nz')
# (u'the__himanish', datetime.datetime(2017, 10, 6, 6, 21, 40), u"TIME: Tropical storm Nate has already killed 22 people. It's now heading for Mexico and the U.S. https://t.co/JEjXawIhXD")
# (u'sweetdiane805', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @cnnphilippines: Taus: Even in your darkest moment, you could find the path towards the greatest light of your life | LIVE\u2026 ')
# (u'jacodemon', datetime.datetime(2017, 10, 6, 6, 21, 40), u'Oh man. What a bunch of dicks https://t.co/RsgSNFOAmq')
# (u'InVeiv', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'LisaAtlpeach33', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @DC_Resister_Bee: @TalbertSwan @TaIbertSwan @realDonaldTrump @RalphNortham @MomsDemand @GDouglasJones Ralph Northam - US Army Major +\u2026 ')
# (u'emimarlinda', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @Alvinchong123: I hate losing friends just because they got into a relationship.')
# (u'RoxanneRiggs11', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @GartrellLinda: Could Dreamers Be Made to Pay Restitution &amp; Back Taxes for Staying? \nTHERE'S NO FREE RIDE\nNO citizenship for 5 yrs\nhttps\u2026")
# (u'LilsG31', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @WSJ: Facebook cut references to Russia from a report in April about election influence\nhttps://t.co/CpfzEX4mK1')
# (u'majoladyB', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @BTS_ARMY: K-pop group's record breaking album conquers three continents @CNNI #BTS @BTS_twt https://t.co/z6mEAVo8bb")
# (u'vincent__kuzzie', datetime.datetime(2017, 10, 6, 6, 21, 40), u"@archie_rickys I hate when they don't pass the ball An take every shot")
# (u'darkd0ll', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @johnbcrist: If football coaches were honest... https://t.co/trmUd9aq7T')
# (u'George15242', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @WorldBestGaming: VERTAGEAR #Gaming Chair #Giveaway\n-Tag Your Friends\n-Turn Notifications On\n-RT, &amp; Follow @WorldBestGaming\nClick Her\u2026 ')
# (u'Nazaninstyle', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @IronStache: .@tedlieu rocks https://t.co/RagJyEQrRh')
# (u'Jack_shev_', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @QuahnOTF: Haters gone hate. I rocks with Lin https://t.co/VEGVtE0o3b')
# (u'bunyy6', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @marcelinesteel: I really hate how attracted I am to men it like makes me sick')
# (u'AnnaBanana59', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @DavidCornDC: So Ivanka Trump and Jared Kushner transferred their email accounts to Trump Org. *after* Congress told them not to?\u2026 ')
# (u'linabella', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @DavidCornDC: So Ivanka Trump and Jared Kushner transferred their email accounts to Trump Org. *after* Congress told them not to?\u2026 ')
# (u'TopKek547146', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @CSGORoll: Falchion Knife | Blue Steel MW\n\n- RT\n- Follow\n- Enable notifications on CSGORoll\n- Play Free Spin\u2026 ')
# (u'ubervgeek', datetime.datetime(2017, 10, 6, 6, 21, 40), u'@SenFranken DREAMERS are illegal')
# (u'WStorbacka', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @CSGOKingdomCom: FAST GIVEAWAY - winner picked in 48hr\n\nRT + FOLLOW\n\n*TEST SPIN: https://t.co/S4QgEDL0Wu https://t.co/hSbkDTa2AC')
# (u'nate_raft', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @KEEMSTAR: I really want to share the Dollar in the Woods remastered track with someone. \n\n(RT) if I can trust you Not to leak\u2026 ')
# (u'MsRachelKati', datetime.datetime(2017, 10, 6, 6, 21, 40), u'@BillGates Love her! I follow her on LinkedIn. Her posts are inspirational, intelligent, feminist (in the proper se\u2026 https://t.co/g8r5Q9zaTK')
# (u'vistaratour', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @spotifybizzle: follow everyone who retweets this\U0001f50b')
# (u'tchiiikow', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @Cdiscount: \U0001f3c6 #Concours\n\n\U0001f3ae #PS4Pro + #FIFA18 \xe0 gagner &gt; https://t.co/W4G4teimHN\n\n\U0001f6a8 Pour participer:\nRT + Tweet avec\u2026 ')
# (u'mckenna_condon', datetime.datetime(2017, 10, 6, 6, 21, 40), u"RT @GucciClout: RT IF THIS IS THE CUTEST SHIT YOU'VE EVER SEEN https://t.co/9VN4tP9vBi")
# (u'CRobinson125', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @CSGORoll: Falchion Knife | Blue Steel MW\n\n- RT\n- Follow\n- Enable notifications on CSGORoll\n- Play Free Spin\u2026 ')
# (u'artytrace', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @ProgressOutlook: The Republican Party has simply folded to the malicious and pathetic Donald Trump.')
# (u'TomiwaO_', datetime.datetime(2017, 10, 6, 6, 21, 40), u'RT @theelectwoman08: Imagine being an adult shaming others for how they earn an honest living. https://t.co/V6mal2oCtO')
# (u'igetbuckets1222', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @johnbcrist: If football coaches were honest... https://t.co/trmUd9aq7T')
# (u'ftnajihah', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'neilarcher4426', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @dhookstead: CNN displayed this image to show what a bump stock rifle looks like. \n\nThe rifle features a suppressor, grenade lau\u2026 ')
# (u'rovermirandugh', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @biticonjustine: i feel empowered when I type with acrylics like yes click CLICK CLICK im angry?? CLICK CLICK CLICK')
# (u'Nikita4jb', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'nised72', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @RVAwonk: If you voted for Trump, you gave a pass to Harvey Weinstein &amp; all the others like him. Stop pretending you care about sexual h\u2026')
# (u'der_goer', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @tedlieu: Freaked out? Support HR 669 by Sen @EdMarkey &amp; me. Bill prohibits @POTUS from launching nuclear 1st strike without\u2026 ')
# (u'2DaveRichardson', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @Melb_Chamb: 'A changing economy presents significant opp's, but also transitional changes.' Secretary DEDJTR Richard Bolt at\u2026 ")
# (u'George15242', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @HammersEsports: Ultimate #Gamer Survival Kit #Giveaway\n-Tag Your Friends\n-RT, Like &amp; Follow @HammersEsports\nClick Here:\u2026 ')
# (u'Meloomike', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Cdiscount: \U0001f3c6 #Concours\n\n\U0001f3ae #PS4Pro + #FIFA18 \xe0 gagner &gt; https://t.co/W4G4teimHN \n\n\U0001f6a8 Pour participer:\nRT + Tweet avec\u2026 ')
# (u'Auxbeam_Amazon', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @alljeepev_: \U0001f6a8GIVEAWAY ALERT\U0001f6a8 \nGiving away a 22" Auxbeam lightbar\n\nTo win you must:\n1. Follow me\n2. Follow @auxbeam\n3. Fav and R\u2026 ')
# (u'LadyKellDiva', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Breaking911: Vegas shooting victim found Trump\'s visit "comforting," telling reporters, "he wasn\'t who we see on social media."\n\nhttps:\u2026')
# (u'UttamChakram', datetime.datetime(2017, 10, 6, 6, 21, 41), u'@PiyushGoyalOffc @PiyushGoyal @VPSecretariat @MVenkaiahNaidu Wer s Railway Zone 4 #Andhrapradesh promised by\u2026 https://t.co/QGZNufnjIQ')
# (u'Escher0815', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @CSGOEmpire: The 2nd winner in the $15,000 Giveaway will be picked in 16 hours!\n\nTo enter:\n-RT\n-Follow\n\nGood luck \U0001f91e\n\nhttps://t.co/Z6Zzyc\u2026')
# (u'Ady_Amim', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Jbieberrhelp: Follow everyone who Retweets this')
# (u'CaryDodenhoff', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Thom2945: Trump keeping his promises once again. BYE BYE Iran Deal! Another Obama legacy is gone! \U0001f1fa\U0001f1f8\U0001f1fa\U0001f1f8\n\nhttps://t.co/LNG7ffAMNJ')
# (u'Hijabimaster', datetime.datetime(2017, 10, 6, 6, 21, 41), u'Guzhala from pak..\n\nFollow for more.. https://t.co/Sm7Sy4JEgq')
# (u'BoatMateARS', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @RVAwonk: --&gt; "Iowa tried for months to get federal permission to fix their health insurance markets but they were shut down\u2026 ')
# (u'blxckwnk', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @PeoplesOracle: But not for Puerto Rico.\nBut not for healthcare.\nBut not for education. https://t.co/2H7MDPBgix')
# (u'sultanmayhosjf1', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @abdullahciftcib: Suudi Arabistan, BM'nin kara listesine girdi. Yemen'de \xe7ocuk \xf6l\xfcmleri nedeniyle. https://t.co/HM3J7g4y9o")
# (u'GAlkadi', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @larryelder: "Reporters" anguishing over a Tillerson departure are the same ones who once called him another fat rich white oil oligarch\u2026')
# (u'TshegofatsoMph9', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Harrys1DEmpire: Follow everyone who Likes and Retweets this\U0001f35f\n#1DDrive \U0001f525')
# (u'pepbascovidal', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @elnacionalcat: Un exdiputat brit\xe0nic veu en la prohibici\xf3 del TC la "demolici\xf3 de la democr\xe0cia a Catalunya" https://t.co/tXwtsdwk93')
# (u'pshnomenclature', datetime.datetime(2017, 10, 6, 6, 21, 41), u'@nikkisalc trust me, there are more good ones than there are bad')
# (u'vlmighty', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @lildurk: I can't trust to save my life \U0001f634")
# (u'imjohnpaul_amil', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @IIIM_G_W_VIII: \U0001f440\n\U0001f445 RETWEET THIS! FOLLOW ME &amp; EVERYONE ELSE THAT RETWEETS &amp; LIKES THIS FOR MORE FOLLOWERS! #TeamFollowBack #F4F #MGWV\n\n\U0001f36e\u2026')
# (u'beyblade94evr', datetime.datetime(2017, 10, 6, 6, 21, 41), u'Why does myrne not follow me but look at all my ig stories what game is this insanely hot guy playing https://t.co/3T5BO9XOat')
# (u'blob80', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @UKIPNFKN: #Petition: Tell the government to release the hidden Brexit studies!\n#Brexit #MayDUP #Economy #StopBrexit\u2026 ')
# (u'jdmnd4', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Amy_Siskind: Every day of every week since Trump regime came into power, rights &amp; protections have been taken away from women &amp; margina\u2026')
# (u'welbyace', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @barefootboomer: LESS DEAD PEOPLE WE WANT LESS DEAD PEOPLE THAT\u2019S REALLY IT GUYS NO FOOLIN\u2019 LESS DEAD PEOPLE https://t.co/wSIwQf0XSW')
# (u'helena_saphira', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @jamescharles: i just decided that i officially hate carli bybel because she's too perfect")
# (u'flickersoflove', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @Harrys1DEmpire: Follow everyone who Likes and Retweets this\U0001f35f\n#1DDrive \U0001f525')
# (u'SHELDOMNI', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @PoliticsPunked: Apparently Donald Trump dislikes this photo of himself and doesn't want it shared on social media. Please do not sh\u2026 ")
# (u'DaveDaveTeehee', datetime.datetime(2017, 10, 6, 6, 21, 41), u'@JhongPiamonte @iKennethclaud @giannisolcruz @RazerCarlyle @asdfgrasyana wag nyo gud itrip2 yan si dude bai ko ma a\u2026 https://t.co/WXxFR9gUKL')
# (u'VetKinggg', datetime.datetime(2017, 10, 6, 6, 21, 41), u"RT @rabotello10: I hate getting catfished by a parking space u think it's empty and then there's a smart car in there")
# (u'madison_trahan', datetime.datetime(2017, 10, 6, 6, 21, 41), u'RT @PeoplesOracle: But not for Puerto Rico.\nBut not for healthcare.\nBut not for education. https://t.co/2H7MDPBgix')
# (u'sillylavage6969', datetime.datetime(2017, 10, 6, 6, 21, 41), u'BREAKING: The Queen sends a message of condolence to Donald Trump following Las Vegas shootings https://t.co/T5acTgNguT')
# (u'IzzRaifHarz', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @CNN: Japan's public broadcaster NHK says one of its reporters died after working 159 hours of overtime\u2026 ")
# (u'OgTriple_Threat', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @theelectwoman08: Imagine being an adult shaming others for how they earn an honest living. https://t.co/V6mal2oCtO')
# (u'LisaAngonese', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @RuthieKetchup: @ALT_uscis @realDonaldTrump This is the only VIRGINIAN Trump should tweet about. #Charlottesville https://t.co/jYM1Kli1qc')
# (u'brookelocey_', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @Positivevibe101: Surround yourself with:\nThe inspired.\nThe passionate.\nThe motivated.\nThe grateful.\nThe open-minded.\nThe honest.\nThe lo\u2026')
# (u'doloration', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @anviety: i hate to see you happy but i could never wish the sadness that i have on you')
# (u'kisanrai00', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @pushcum: \U0001f6a6Follow everyone who retweets this 2 mins')
# (u'Prital1', datetime.datetime(2017, 10, 6, 6, 21, 42), u'@KahawaTungu Gowsh. Gutter press. Just talked to cytonn. This is fake news. I thought u were honest unlike the other gutter press bloggers')
# (u'George15242', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @OverwatchSF: #OverwatchSF Epic #iPhoneX #Giveaway\n-Tag Your Friends\n-RT, Like &amp; Follow @OverwatchSF\nClick Here:\u2026 ')
# (u'arab1000com', datetime.datetime(2017, 10, 6, 6, 21, 42), u'Standing with Immigrants: The Original Dreamers - https://t.co/Qoh11vDk6m')
# (u'JauKitti', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @RT_com: Putin gets bombarded by questions at energy forum \u2013 and has a comeback with a joke about Israeli army\u2026 ')
# (u'Fandi696969', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @sexhijab_: Cuma mau bilang wow \U0001f602\U0001f602, Yuks follow @gogodotlive @makicrot @makemehepi @angkotxxx  @papeldee https://t.co/oKeY4tmDys')
# (u'SiDix67', datetime.datetime(2017, 10, 6, 6, 21, 42), u"@PD_Canto Cuddles are a very important role George. Calming and building trust. It's a difficult job I know but I'm\u2026 https://t.co/R6afCxLf9Q")
# (u'sincerelysamxi', datetime.datetime(2017, 10, 6, 6, 21, 42), u'They need to put that 10 billion towards this debt Im in... https://t.co/4f2Cy8jhGv')
# (u'linkinojams', datetime.datetime(2017, 10, 6, 6, 21, 42), u'once sinabi niya na "topic?" trust me nakakatamad kang kachat')
# (u'tuanejat7', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @iJeebster: Don't trust your friends too much \U0001f602 https://t.co/uwa1v41frp")
# (u'achinth', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @kapsology: Sources: BJP got all this money as party fund! This money will be back into economy by 2019 elections \U0001f62c https://t.co/dXLzswR\u2026')
# (u'Redpeter99', datetime.datetime(2017, 10, 6, 6, 21, 42), u'REPORTER: When?\nTRUMP:..............................................................................after the break. https://t.co/N09OQf0C5n')
# (u'KaybleSA', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @decorartehogar: Follow everyone who Retweets to gain twitter followers\ufe0f\U0001f3af')
# (u'AureliePOMART47', datetime.datetime(2017, 10, 6, 6, 21, 42), u"#LeCasseDuSi\xe8cle trop bien le concept ! On a une mont\xe9e d'adr\xe9naline rien qu'\xe0 vous \xe9couter :D ! https://t.co/3qVvPflurE")
# (u'xplicitlove', datetime.datetime(2017, 10, 6, 6, 21, 42), u'\u2764\ufe0f https://t.co/Qwg0ZJuoWm')
# (u'iBaemax', datetime.datetime(2017, 10, 6, 6, 21, 42), u'@Vllrz @inflinixel its us https://t.co/Uz6LoCXIWh')
# (u'WhoKnows1225', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @realDonaldTrump: Thank you! https://t.co/YMuqSvvTSB')
# (u'sonokocentral', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @TheRickyDavila: I'm still not understanding why Jared Kushner &amp; Ivanka Trump's email scandal isn't all over the news right now. Help me\u2026")
# (u'zdoublet', datetime.datetime(2017, 10, 6, 6, 21, 42), u'@_Mireya213 I don\u2019t even take notes to begin with \U0001f602 I hate that class')
# (u'mtalpas', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @AltUSPressSec: Trump has spent twice as much on golf as on #PuertoRico. https://t.co/1RUEJyOVFg')
# (u'ze17ro', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @LsTRUSTCo: \u3053\u306e\u9031\u672b\u306fL's TRUST\u5c55\u793a\u4f1a\u3092LUTHIER's HILL\u306b\u3066\u958b\u50ac\u3057\u3066\u304a\u308a\u307e\u3059\uff01\u304a\u6c17\u8efd\u306b\u304a\u7acb\u3061\u5bc4\u308a\u304f\u3060\u3055\u3044\u3002\u5b9c\u3057\u304f\u304a\u9858\u3044\u81f4\u3057\u307e\u3059\U0001f3b8\n10/6 15:00-20:00\n10/7 11:00-20:00\n10/8 11:00-1\u2026 ")
# (u'SNpannyaandH', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @ALewdSnowflake: #NSFW Follow for more &lt;3 #Hentai\n@Hentai_Retweet RT's are apreciated https://t.co/LLiXuXAIRC")
# (u'nancygillxox', datetime.datetime(2017, 10, 6, 6, 21, 42), u'omg I hate being ill \U0001f62b\U0001f62b')
# (u'fAzlImiN04_', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @iJeebster: Don't trust your friends too much \U0001f602 https://t.co/uwa1v41frp")
# (u'paulmwema12', datetime.datetime(2017, 10, 6, 6, 21, 42), u'@moise_katumbi est le seul opposant capable a faire boug\xe9 le s\xe9nat am\xe9ricain. https://t.co/utl7H6oNxt')
# (u'amierasyahierah', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @Friendstagram: I hate being jealous when I know I shouldn't be.")
# (u'AmaliaP59701899', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @goshquiet: No, @Independent, this map shows that you're funded by dirty Russian money. Crimea &amp; Donbas are occupied by Russia. https://\u2026")
# (u'Sher_V', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @OriginalFunko: RT &amp; follow @OriginalFunko for the chance to win an #NYCC 2017 exclusive glow-in-the-dark 6-inch Balrog Pop! https://t.c\u2026')
# (u'zeliha_ab', datetime.datetime(2017, 10, 6, 6, 21, 42), u"RT @abdullahciftcib: Suudi Arabistan, BM'nin kara listesine girdi. Yemen'de \xe7ocuk \xf6l\xfcmleri nedeniyle. https://t.co/HM3J7g4y9o")
# (u'AnteSarlija', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @calebmaupin: https://t.co/MTee07Yy6E The approval rating of #Putin is 80%. No surprise. He rescued the economy, and is building up #Rus\u2026')
# (u'ThePirates_X', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @janklaar2: \U0001f525 #BoobsGlobalGroup Follow \U0001f449\U0001f3fb@janklaar2\U0001f448\U0001f3fb@gauzediaz_p @anati091252 @bigboobiesworld @kissmylilstar @stu007gots\u2026 ')
# (u'AaliyahW_3', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @whatanaja: This is my step mom Lindsey Licari she is trying everything to save my brother if you go on her FB or Ig(\u2026 ')
# (u'BuckTaylor64', datetime.datetime(2017, 10, 6, 6, 21, 42), u'@BiffBean @liamyoung Not necessarily! DUP will be key! Leadership election may be enough!')
# (u'bentonlee1', datetime.datetime(2017, 10, 6, 6, 21, 42), u'McMaster vs. Trump: Embattled Adviser Reportedly Hinted to Top Democrats He Opposes President\u2019s Iran Deal Policy - Breitbart http://bi')
# (u'____MT_______', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @ericvdunn: If Nick Folk misses i\u2019ll follow everyone who RTs this')
# (u'jerecespieces', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @2020fight: Fun fact. Trump just completed his 16th trip in 8 months. https://t.co/hXHVkjQvWj')
# (u'RenfrewHighHWB', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @renfrew_high: Casual dress today - but remember to wear red!\nWe are standing together against racism.\n#care #fairness #respect\u2026 ')
# (u'MrMajYT', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @Cdiscount: \U0001f3c6 #Concours\n\n\U0001f3ae #PS4Pro + #FIFA18 \xe0 gagner &gt; https://t.co/W4G4teimHN\n\n\U0001f6a8 Pour participer:\nRT + Tweet avec\u2026 ')
# (u'_edinataylor', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @whatanaja: This is my step mom Lindsey Licari she is trying everything to save my brother if you go on her FB or Ig(\u2026 ')
# (u'Do_brizhoffer', datetime.datetime(2017, 10, 6, 6, 21, 42), u'Follow everyone who Likes and Retweets this.! #Ifb \U0001f47d')
# (u'Jamestoupin', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @JoyAnnReid: We are living in insane times. https://t.co/XbpwMUfT5k')
# (u'DavidBassanese', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @BernardKeane: Poor bloke is furious his predictions of doom never eventuate https://t.co/s5nzBXPIzD https://t.co/CFeO193BxD')
# (u'deontaepoindex1', datetime.datetime(2017, 10, 6, 6, 21, 42), u'Fuckkkkkkkkkk man \U0001f602\U0001f602\U0001f602\U0001f602\U0001f602 https://t.co/QXGWtePuvA')
# (u'spooky_thaiyor', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @BOOOMBGUY: All of you are Mad CNN, The Cockcroach, The Milk, The Fat and Protein.. You are all Mad https://t.co/2fo1LG4ezf')
# (u'ATLNativStepson', datetime.datetime(2017, 10, 6, 6, 21, 43), u'@jaketapper Best indicator that a story is true = Trump calling it fake news')
# (u'Rubicat09', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @Afrodita_PKM: \xbfQuieres demostrar ser el mejor entrenador monotype?\nRetweet + Follow\nReglas aqu\xed: https://t.co/uErz3bA3EN\u2026 ')
# (u'thepunditmama', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @jaketapper: A) because it isn\'t. \nB) what you call "fake" = news you don\'t like\nC) Committee busy investigating Russia and poss\u2026 ')
# (u'aarbrit', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @theelectwoman08: Imagine being an adult shaming others for how they earn an honest living. https://t.co/V6mal2oCtO')
# (u'America_weeps', datetime.datetime(2017, 10, 6, 6, 21, 43), u"RT @mitchellvii: 8 months into his Presidency.  NO help from Congress, NO help from the Media and STILL Trump's approval rating is solid.")
# (u'hennchism', datetime.datetime(2017, 10, 6, 6, 21, 42), u'existential crisis: read all about it https://t.co/QvNVEyWIPD')
# (u'ProcessCivil', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @seanhannity: Love this!!  Follow @JeniferStevens https://t.co/s4KqRKqZvm')
# (u'AnabelWitch', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @rasputin65: Donald Trump: https://t.co/5kOBlQyM9j')
# (u'salome_ba_', datetime.datetime(2017, 10, 6, 6, 21, 42), u'When Gaga has her own tacos \U0001f32e in Mexico !! \U0001f60e In your honor! You see how Mexico loves you??  \u2764\ufe0f@ladygaga https://t.co/M5nnIRd68a')
# (u'sanagustinrowe1', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @mom_norie: He already apologized, can you then stop this and instead write about it just like what CNN PH did? https://t.co/ptl9Q6edHD')
# (u'BBeyanka', datetime.datetime(2017, 10, 6, 6, 21, 43), u'I\u2019m not even surprised. I\u2019m not even upset. I\u2019m just...so fucking numb and disheartened. https://t.co/S3iGwozPvD')
# (u'frostieK1210', datetime.datetime(2017, 10, 6, 6, 21, 43), u'@piersmorgan @NRA Remember, it was Trump who stated that if the French had guns they could  have saved themselves d\u2026 https://t.co/0Pv5a5GLOv')
# (u'gabbyrevlugo', datetime.datetime(2017, 10, 6, 6, 21, 42), u'RT @ASlavitt: BREAKING: This news is finally public.\n\nTrump discovered to personally order his team to sabotage ACA. https://t.co/sCgGfwUqku')
# (u'Jorsh_Rdz19', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @Harrys1DEmpire: 1: Retweet this\U0001f363\n2: Follow all that Like &amp; Retweet\U0001f363\n3: Follow back all that follow you\U0001f363\n4: Gain with #1DDrive\U0001f525')
# (u'LurkerInTheLoft', datetime.datetime(2017, 10, 6, 6, 21, 43), u'RT @glo1551: White Sands, New Mexico under the starry, starry night. https://t.co/jkwWzW7KcY')
# ...
# (u'subbaiyer', datetime.datetime(2017, 10, 6, 6, 21, 53), u'My answer to With even BJP ex- Finance Minister Yashwant Sinha speaking about the economy being on a downward spira\u2026 https://t.co/l2t7j7fqYz')
# (u'HannahKennison1', datetime.datetime(2017, 10, 6, 6, 21, 51), u'Sarah Sanders battles CNN\u2019s Jim Acosta: You have a 1st Amendment \u2018responsibility\u2019 to be \u2018positive\u2019 about Trump https://t.co/jIA8Fx4xQB')
# (u'htown_Joe', datetime.datetime(2017, 10, 6, 6, 21, 53), u'@USMCLiberal: Me and 40K follow \u201cSean,\u201d #USMC_SSDD, who says he\u2019s a Marine. Was he #USMCDD1? I see people say he\u2019s a fake and a harasser. /1')
# (u'BrianTeddychisa', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @TrapaTeam: Gain 500+ followers in 30 minutes.\n\nRETWEET and FOLLOW all that RTs this tweet\n\n#TrapaDrive \U0001f6a8\n#GainWithXtianDela')
# (u'kisanrai00', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @GainTrickOG: Follow everyone who retweets this\U0001f420')
# (u'BongileMajubane', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @decorartehogar: Follow everyone who Likes and Retweets this\ufe0f\U0001f3f9')
# (u'ble_bebell', datetime.datetime(2017, 10, 6, 6, 21, 51), u'RT @theoffspring_pj: \U0001f389\u0e09\u0e25\u0e2d\u0e07\u0e40\u0e1b\u0e34\u0e14\u0e23\u0e49\u0e32\u0e19\U0001f389\n\u2796\u0e2a\u0e38\u0e48\u0e21\u0e41\u0e08\u0e01 #\u0e25\u0e34\u0e1b\u0e1a\u0e32\u0e25\u0e4c\u0e21\u0e44\u0e2d\u0e23\u0e32 1 \u0e15\u0e25\u0e31\u0e1a \u0e40\u0e25\u0e37\u0e2d\u0e01\u0e01\u0e25\u0e34\u0e48\u0e19\u0e44\u0e14\u0e49\n\u2796\u0e41\u0e04\u0e48 RT+FOLLOW\n\u2796\u0e41\u0e08\u0e01\u0e15\u0e2d\u0e19\u0e22\u0e2d\u0e14\u0e1f\u0e2d\u0e25 101 \u0e04\u0e19\u0e04\u0e48\u0e32\n\u2728\u0e40\u0e09\u0e1e\u0e32\u0e30\u0e04\u0e19\u0e17\u0e35\u0e48\u0e17\u0e33\u0e15\u0e32\u0e21\u0e01\u2026 ')
# (u'Chewygamerz', datetime.datetime(2017, 10, 6, 6, 21, 51), u'I added a video to a @YouTube playlist https://t.co/Yu7B2dLFyg Wrestling Games - Angry Video Game Nerd (Episode 149)')
# (u'OmarCadenaC', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @LeonBenLarregui: Mexico es el futuro de mexico')
# (u'4hunin44', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @PeoplesOracle: But not for Puerto Rico.\nBut not for healthcare.\nBut not for education. https://t.co/2H7MDPBgix')
# (u'GAlkadi', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @mitchellvii: If the election were held today, Trump would win by more than he won on Nov 8th, 2016.\n\nGuaranteed.')
# (u'itscarlyrang', datetime.datetime(2017, 10, 6, 6, 21, 51), u'RT @CharlesMBlow: I worry that the next "normal" president may get away with all manner of misbehavior bc America will just be relieved he/\u2026')
# (u'trippleOohGee', datetime.datetime(2017, 10, 6, 6, 21, 53), u"RT @ProfessorKumi: It won't change until we get \xa31 notes, nobody spraying \xa35 notes in this Brexit economy https://t.co/QIgz5LN1HY")
# (u'SignedDanie', datetime.datetime(2017, 10, 6, 6, 21, 53), u'I\u2019m a perfectionist .... I hate it.')
# (u'cybojack25', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @OriginalFunko: RT &amp; follow @OriginalFunko for the chance to win a set of Funko Shop exclusive cereal mascot Pop!s! https://t.co/v4X8V9p\u2026')
# (u'SawyerBrittain', datetime.datetime(2017, 10, 6, 6, 21, 51), u'RT @JackPosobiec: A sexual predator interviewing a sexual predator. This is CNN https://t.co/piql7uWU9a')
# (u'Dark_Lord_Meh', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @TheSkinsmith: Kick start your #weekend by entering our #competition to #win our NEW Marine Flower Peptide Eye Cream worth \xa369! Fo\u2026 ')
# (u'CathBennison_', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @valeriecafe: It\'s #NationalCakeWeek! Follow &amp; RT to be in with the chance of winning an 8" gateau. Competition ends 6/10/17 at 4\u2026 ')
# (u'SamMurphy02', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @johnbcrist: If football coaches were honest... https://t.co/trmUd9aq7T')
# (u'DonnaGeary10', datetime.datetime(2017, 10, 6, 6, 21, 52), u"RT @exoticgamora: Trump continues to treat presidency like it's an episode of the apprentice, where he has to announce a suspense mom\u2026 ")
# (u'chasingguk', datetime.datetime(2017, 10, 6, 6, 21, 52), u'ive honestly been desperate for their album lmAO https://t.co/K8NG5fZ1Kr')
# (u'artytrace', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @PowerGirl_2017: Seriously, this cannot be permitted to take hold. They are redefining Reality. @GOP stop with your #WarOnWomen https://\u2026')
# (u'edieunnie', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @Bernstein: Here\u2019s a story I\u2019ve been working on for a few months: How the Breitbart Machine Laundered Racist Hate https://t.co/hx3FksMVyO')
# (u'ubervaper', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @SafetyPinDaily: Manhattan District Attorney Cy Vance Joins the Trump Family\u2019s Private Chickenshit Club   | via @thedailybeast\nhttps://t\u2026')
# (u'abytw', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @DC_Resister_Bee: @TalbertSwan @TaIbertSwan @realDonaldTrump @RalphNortham @MomsDemand Doug Jones\n\nStop Roy Moore + Flip Sessions sea\u2026 ')
# (u'gus_arc', datetime.datetime(2017, 10, 6, 6, 21, 53), u"RT @KPadmaRani1: Yet another troll blessed to be followed by @narendramodi \nCan't understand why his handle chooses hate mongers?\u2026 ")
# (u'Manny5054', datetime.datetime(2017, 10, 6, 6, 21, 52), u"RT @Independent: California becomes 'sanctuary state' with law protecting immigrants from Trump https://t.co/0oXUM3jqQy")
# (u'Angels_Demons2', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @OriginalFunko: RT &amp; follow @OriginalFunko for your chance to win a @Target Exclusive #Hela Pop! #ThorRagnarok https://t.co/GTSHOG6YvI')
# (u'EdwardChizh_RT', datetime.datetime(2017, 10, 6, 6, 21, 53), u'@alisonmsnyder please take look at our project: https://t.co/NVsNdhtLsS')
# (u'delawenukunu', datetime.datetime(2017, 10, 6, 6, 21, 53), u'@slg1956 I agree. Follow back')
# (u'VivekGupta2001', datetime.datetime(2017, 10, 6, 6, 21, 52), u"RT @srirambjp: Why @narendramodi Govt's track record is muchbetter than UPA's.\n\nFactual &amp; Logical. Must read.  https://t.co/5MiqKH6jeB")
# (u'saliheeee', datetime.datetime(2017, 10, 6, 6, 21, 53), u'@Dame_Lillard @Spotify @frontpagemusic @2chainz @LilTunechi @BJTHECHICAGOKID @NickGrantmusic Hate to say I changed\u2026 https://t.co/Wa6DujCum2')
# (u'Jazzilla_', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @TSMZeRo: GIVEAWAY!\nSWITCH console + 2 games of your choice!\nTO ENTER, RT &amp; CLICK HERE &amp; FOLLOW INSTRUCTIONS TO GAIN ENTRIES:\u2026 ')
# (u'damagepenney', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @OriginalFunko: RT &amp; follow @OriginalFunko for the chance to win an #NYCC 2017 exclusive Old Man Logan Pop! https://t.co/IbzQkp0KT2')
# (u'jonmac36', datetime.datetime(2017, 10, 6, 6, 21, 53), u"RT @danocdj: The album is out! So I'm giving away this @liamgallagher collector's vinyl. RT and Follow to win. Closes midnight 0\u2026 ")
# (u'west_of_there', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @TeamPelosi: As long as they\u2019re in control, the GOP will stop at nothing to destroy our care. RT if you\u2019ll hold them accountable\u2026 ')
# (u'jazminsanchezd1', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @Marshall_Cohen: CNN has confirmed: FEMA just abruptly deleted the webpage that told the American people that 95% of Puerto Ricans s\u2026 ')
# (u'ZenTaoPrincess', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @SafetyPinDaily: Top 5 Signs Donald Trump Might Be an Effing Moron |  Via @commondreams\nhttps://t.co/6k8tokhcmN')
# (u'Agypten11', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @IIIM_G_W_VIII: \U0001f440\n\U0001f445 RETWEET THIS! FOLLOW ME &amp; EVERYONE ELSE THAT RETWEETS &amp; LIKES THIS FOR MORE FOLLOWERS! #TeamFollowBack #F4F #MGWV\n\n\U0001f36e\u2026')
# (u'makeupsue', datetime.datetime(2017, 10, 6, 6, 21, 52), u'RT @washingtonpost: Trump administration plans to scrap Obama\u2019s signature plan to combat climate change https://t.co/bO9hU2iMEf')
# (u'XAC5Ek5PhrXyNDf', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @DudeVids: Follow @DUDEVIDS on Twitter for more XXX stuff #dudevids  - add  DUDEVIDS2 on snapchat https://t.co/7yBkwLWCnA')
# (u'Ahlexajourden', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @1942bs: i hate the second amendment and i want it stripped away https://t.co/LHCPouvQw1')
# (u'EmeraldCleaver7', datetime.datetime(2017, 10, 6, 6, 21, 54), u"RT @vodkawithjacob: DON'T YOU DARE HATE ON PEOPLE WHO ARE FANGIRLING I DONT CARE HOW INSANE OR DRAMATIC THEY MAY LOOK DO NOT PUT THEM D\u2026 ")
# (u'Agengalyz', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @MamuBanatera: Pls follow this account, @ELMTreePH \n\n#AskMayMay')
# (u'Mrs_Bennett495', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @TheBandMusical: COMPETITION! We love our followers &amp; want more. To win 2 tickets to see the show at @BradfordTheatre pls retweet follow\u2026')
# (u'Ethnikids_Co', datetime.datetime(2017, 10, 6, 6, 21, 54), u'@StephenGrootes https://t.co/g3L6nEzUNb')
# (u'RudyMenggaSH6', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @RisingPlanet: Follow everyone who retweets this \U0001f623 \U0001f940b#')
# (u'alejanjan17', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @ananavarro: 55% of Puerto Ricans -almost 2 million Americans- have no drinking water. Trump dedicated a golf trophy and threw p\u2026 ')
# (u'Vishj05', datetime.datetime(2017, 10, 6, 6, 21, 54), u'@sanjayuvacha https://t.co/eT5ZmFzajT')
# (u'DrJeremyTeuton', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @RBReich: Trump and Republicans want a big tax cut for the wealthy, claiming the gains will trickle down to the middle-class.\u2026 ')
# (u'Jorsh_Rdz19', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @Harrys1DEmpire: 1: Retweet this\U0001f367\n2: Follow all that Like &amp; Retweet\U0001f367\n3: Follow back all that follow you\U0001f367\n4: Gain with #1DDrive \U0001f525')
# (u'hunterjames509', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @montenegro_emil: the deeper your scars, the more room there is to fill them up with love. Don\u2019t hate your scars, appreciate their depth\u2026')
# (u'noestalit', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @biticonjustine: i feel empowered when I type with acrylics like yes click CLICK CLICK im angry?? CLICK CLICK CLICK')
# (u'norock', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @Marshall_Cohen: CNN has confirmed: FEMA just abruptly deleted the webpage that told the American people that 95% of Puerto Ricans s\u2026 ')
# (u'KrsnAnk', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @ShonetteBason: Make one person smile tomorrow and be a part of a #happiness revolution. #worldsmileday the world needs your smile.\u2026 ')
# (u'AfropagesEn', datetime.datetime(2017, 10, 6, 6, 21, 54), u'Daily Nation ke - IEBC trains poll officials ahead of fresh election @AfropagesEn https://t.co/eBrthV48FV https://t.co/TaSUexGn7t')
# (u'SlamminJelly', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @Goods_Republic: \U0001f319Give away\U0001f341\n\nFollow &amp; RT to win Cushion to 10 people. \n\nEnd Oct 9\n\nhttps://t.co/Xi0XA3NPdt https://t.co/fNPOn6TJL4')
# (u'GVForsyth', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @RWPUSA: Almost a million bucks to fly Mnuchin on government planes in under a year. https://t.co/wajMnrPtnf')
# (u'iamyelex', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @trapafasa: Funny how African celebrities are goin in on Donald Trump but they are afraid to speak up when it comes to their shitty ass\u2026')
# (u'TaizDesign', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @phonandroid: \U0001f534Derni\xe8re chance \U0001f534 #Concours de l\u2019automne ! Gagnez 2 #OnePlus5 avec @oneplus_fr Pour participer &gt;\u2026 ')
# (u'itsmecab_', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @cottonwishes: even now, i\u2019m too scared to put my complete trust into anyone')
# (u'mosbei95', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @DOGFATHER__MGWV: \u2611\ufe0f #FOLLOWTRICK\n\n\u2705 RETWEET\n\n\u2611\ufe0f FOLLOW ALL WHO RT\n\n\u2705 FOLLOWBACK\n\n\u2611\ufe0f GAIN WITH #MGWV\n\n\u2705 #FOLLOW \u261e @kleinslag')
# (u'Ricball', datetime.datetime(2017, 10, 6, 6, 21, 53), u"RT @funder: Trump's the worst president ever-his Russian collusion-trans ban-Muslim ban-assault on women's rights-the press &amp; P\u2026 ")
# (u'alphagakunga', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @TrapaTeam: Gain 500+ followers in 30 minutes.\n\nRETWEET and FOLLOW all that RTs this tweet\n\n#TrapaDrive \U0001f6a8\n#GainWithXtianDela')
# (u'amysieww', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @PeoplesOracle: But not for Puerto Rico.\nBut not for healthcare.\nBut not for education. https://t.co/2H7MDPBgix')
# (u'CloeteHeather', datetime.datetime(2017, 10, 6, 6, 21, 55), u'RT @ALT_uscis: .@fema approved $$ for \nPuerto Rico/Maria: $35 mil\nFlorida/Irma: $691 mil\nTexas/Harvey: $323 mil\nTrump golf trips: $72 milli\u2026')
# (u'MissJules5x', datetime.datetime(2017, 10, 6, 6, 21, 53), u'@ChurchillZoe Never said we were equal to Russia but when it comes to the damage done around the world we are infin\u2026 https://t.co/iEgXbIfCsH')
# (u'dnoumn', datetime.datetime(2017, 10, 6, 6, 21, 53), u'RT @johnbcrist: If football coaches were honest... https://t.co/trmUd9aq7T')
# (u'JermainJulien', datetime.datetime(2017, 10, 6, 6, 21, 55), u'Preach!!! I wonder what insult Trump will come up with to combat this exercise in freedom of speech.  Or how the NR\u2026 https://t.co/atbFolK7WW')
# (u'AmeMesAmours', datetime.datetime(2017, 10, 6, 6, 21, 54), u'RT @Cdiscount: \U0001f3c6 #Concours\n\n\U0001f4f1 Samsung #GalaxyS8 \xe0 gagner &gt; https://t.co/GVXBtJYqDK\n\n\U0001f6a8 Pour participer:\nRT + Tweet avec\u2026 ')
# (u'timzmom', datetime.datetime(2017, 10, 6, 6, 21, 54), u"RT @molly_knight: Only a sociopath would think it's funny to tease chaos and put Americans through daily psychological torture. https://t.c\u2026")
# (u'LostAllHope80', datetime.datetime(2017, 10, 6, 6, 21, 55), u'RT @18dMedia: How Puerto Ricans see President Trump\u2019s hurricane response https://t.co/c5g8UUuoZi #kwanmedia https://t.co/7R4yVhjCOz')
# (u'Th3L0stSaint', datetime.datetime(2017, 10, 6, 6, 21, 55), u'RT Benson_Mwaura: Learn smart approaches to #infosecurity 4 future connected cars &amp; the biz insights to follow IBM\u2026 https://t.co/jWP762g1IE')
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-171-78621e2f06e1> in <module>()
#       1 import TweepyToCSV
#       2 from TweepyToCSV import CustomStreamListener
# ----> 3 TweepyToCSV.main()
#
# /home/jack/Desktop/text_stuff/TweepyToCSV.py in main()
#      49         tokens = f.readlines()
#      50
# ---> 51         streamingAPI.filter(track=tokens)
#      52         #streamingAPI.filter(track=['Dallas', 'NewYork'])
#      53
#
# /home/jack/anaconda2/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /home/jack/anaconda2/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /home/jack/anaconda2/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     292             # call a handler first so that the exception can be logged.
#     293             self.listener.on_exception(exception)
# --> 294             raise exception
#     295
#     296     def _data(self, data):
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read, 4048 more expected)', IncompleteRead(0 bytes read, 4048 more expected))

# %%
# %%writefile tokens2.txt
# Mexico
# dreamers
# healthcare
# revolution
# hidding
# putin
# voters
# feedup
# fakenews
# NBC
# CBS
# CNN
# CIA
# hate
# wacko
# gonecrazy
# wierd
# hopeless
# impeach
# dishonor
# lost faith
# angry
# trump
# russia
# economy
# north korean
# rocketman
# trust
# follow
# honorable
# honest
# dishonest
# distrust
# election
# fakepresident
# Out:
# Overwriting tokens2.txt

# %% [markdown]
# # VERY GOOD

# %%
# !locate Key.py
# Out:
# /home/jack/.PyCharmCE2017.1/system/python_stubs/-1247972723/PyQt4/QtNetwork/QSslKey.py
# /home/jack/Desktop/Snippet_Warehouse/Key.py
# /home/jack/Desktop/imagebot/Key.py
# /home/jack/Desktop/imagebot/Key.pyc
# /home/jack/anaconda2/envs/py27/lib/python2.7/site-packages/Key.py
# /home/jack/anaconda2/envs/py27/lib/python2.7/site-packages/Key.pyc
# /home/jack/anaconda2/lib/python2.7/site-packages/Crypto/SelfTest/PublicKey/test_importKey.py
# /home/jack/anaconda2/lib/python2.7/site-packages/Crypto/SelfTest/PublicKey/test_importKey.pyc
# /home/jack/anaconda2/pkgs/pycrypto-2.6.1-py27_4/lib/python2.7/site-packages/Crypto/SelfTest/PublicKey/test_importKey.py
# /home/jack/anaconda2/pkgs/pycrypto-2.6.1-py27_4/lib/python2.7/site-packages/Crypto/SelfTest/PublicKey/test_importKey.pyc
# /home/jack/anaconda2/pkgs/pycrypto-2.6.1-py35_6/lib/python3.5/site-packages/Crypto/SelfTest/PublicKey/test_importKey.py
# /home/jack/anaconda2/pkgs/pycrypto-2.6.1-py36_6/lib/python3.6/site-packages/Crypto/SelfTest/PublicKey/test_importKey.py

# %%
import Key
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-135-3e12e7a6fb65> in <module>()
# ----> 1 import Key
#
# ImportError: No module named Key

# %% [markdown]
# # Get Trumps Tweets from 2016-08-02 21:52:32 to today 2017-10-06 02:16:32

# %%
#!/usr/bin/env python
# encoding: utf-8

import tweepy #https://github.com/tweepy/tweepy
import csv
import sys
sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import Key
from random import randint

#USER = raw_input("User  : ") or "CNN"

#CONSUMER_KEY = Key.twiter()[0]
#CONSUMER_SECRET = Key.twiter()[1]
#ACCESS_KEY = Key.twiter()[2]
#ACCESS_SECRET = Key.twiter()[3]
#twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY,ACCESS_SECRET)

#Twitter API credentials
consumer_key = Key.twiter()[0]
consumer_secret = Key.twiter()[1]
access_key = Key.twiter()[2]
access_secret = Key.twiter()[3]


def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []	

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)

    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
    #while len(new_tweets) < 400:    
        print "getting tweets before %s" % (oldest)

        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1

        print (len(alltweets))
        
        if (len(alltweets)) >200:

            #transform the tweepy tweets into a 2D array that will populate the csv	
            outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]

            #write the csv	
            with open('%s_tweets.csv' % screen_name, 'wb') as f:
                writer = csv.writer(f)
                writer.writerow(["id","created_at","text"])
                writer.writerows(outtweets)

            pass


if __name__ == '__main__':
    #pass in the username of the account you want to download
    USER = raw_input("User  : ") or "CNN"
    #gaberivera symmetrymag
    get_all_tweets(USER)
# Out:
# User  : symmetrymag
# getting tweets before 887990471703707649
# 400
# getting tweets before 860207412585701376
# 600
# getting tweets before 840623365106872319
# 800
# getting tweets before 820707127513599999
# 1000
# getting tweets before 793089314187915264
# 1200
# getting tweets before 769625628853141503
# 1400
# getting tweets before 743144356371013631
# 1599
# getting tweets before 702516636197244928
# 1799
# getting tweets before 671364353292111872
# 1999
# getting tweets before 640932590329855999
# 2198
# getting tweets before 610541994935369727
# 2398
# getting tweets before 580762315349311487
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-24-999212beb35e> in <module>()
#      77     #pass in the username of the account you want to download
#      78     USER = raw_input("User  : ") or "CNN"
# ---> 79     get_all_tweets(USER)
#
# <ipython-input-24-999212beb35e> in get_all_tweets(screen_name)
#      50
#      51         #all subsiquent requests use the max_id param to prevent duplicates
# ---> 52         new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
#      53
#      54         #save most recent tweets
#
# /home/jack/anaconda2/lib/python2.7/site-packages/tweepy/binder.pyc in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /home/jack/anaconda2/lib/python2.7/site-packages/tweepy/binder.pyc in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?count=200&max_id=580762315349311487&screen_name=symmetrymag (Caused by ConnectTimeoutError(<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x7f69a97bb890>, 'Connection to api.twitter.com timed out. (connect timeout=60)'))

# %%
import tweepy #https://github.com/tweepy/tweepy
import csv
import sys
sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import Key
from random import randint
consumer_key = Key.twiter()[0]
consumer_secret = Key.twiter()[1]
access_key = Key.twiter()[2]
access_secret = Key.twiter()[3]

def get_all_tweets(screen_name):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    alltweets = []	
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    alltweets.extend(new_tweets)
    oldest = alltweets[-1].id - 1
    while len(new_tweets) > 0:
        print "getting tweets before %s" % (oldest)
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        alltweets.extend(new_tweets)
        oldest = alltweets[-1].id - 1
        print (len(alltweets))
        if (len(alltweets)) >200:
            outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
            with open('%s_tweets.csv' % screen_name, 'wb') as f:
                writer = csv.writer(f)
                writer.writerow(["id","created_at","text"])
                writer.writerows(outtweets)
            pass
if __name__ == '__main__':
    USER = raw_input("User  : ") or "CNN"
    get_all_tweets(USER)
# Out:
# User  : symmetrymag
# getting tweets before 887990471703707649
# 400
# getting tweets before 860207412585701376
# 600
# getting tweets before 840623365106872319
# 800
# getting tweets before 820707127513599999
# 1000
# getting tweets before 793089314187915264
# 1200
# getting tweets before 769625628853141503
# 1400
# getting tweets before 743144356371013631
# 1599
# getting tweets before 702516636197244928
# 1799
# getting tweets before 671364353292111872
# 1999
# getting tweets before 640932590329855999
# 2198
# getting tweets before 610541994935369727
# 2398
# getting tweets before 580762315349311487
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-24-999212beb35e> in <module>()
#      77     #pass in the username of the account you want to download
#      78     USER = raw_input("User  : ") or "CNN"
# ---> 79     get_all_tweets(USER)
#
# <ipython-input-24-999212beb35e> in get_all_tweets(screen_name)
#      50
#      51         #all subsiquent requests use the max_id param to prevent duplicates
# ---> 52         new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
#      53
#      54         #save most recent tweets
#
# /home/jack/anaconda2/lib/python2.7/site-packages/tweepy/binder.pyc in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /home/jack/anaconda2/lib/python2.7/site-packages/tweepy/binder.pyc in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/user_timeline.json?count=200&max_id=580762315349311487&screen_name=symmetrymag (Caused by ConnectTimeoutError(<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x7f69a97bb890>, 'Connection to api.twitter.com timed out. (connect timeout=60)'))

# %%
import sys
sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
import Key
import csv

HashTag = raw_input("HashTag  : ") or "CNN"

CONSUMER_KEY = Key.twiter()[0]
CONSUMER_SECRET = Key.twiter()[1]
ACCESS_KEY = Key.twiter()[2]
ACCESS_SECRET = Key.twiter()[3]
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY,ACCESS_SECRET)

# Open/create a file to append data to
csvFile = open('result.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)



txt = twitter.search(q=HashTag)
txt = str(txt)
filein.write(txt)
filein.close()

print txt

# Open/create a file to append data to
csvFile = open('result.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)
txt = twitter.search(q=HashTag)

csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])




for tweet in tweepy.Cursor(api.search,
                           q = "google",
                           since = "2014-02-14",
                           until = "2014-02-15",
                           lang = "en").items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print tweet.created_at, tweet.text
csvFile.close()

# %% [markdown]
# # Get Twitter results from raw input and write results to a file

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
#url = u'https://twitter.com/search?q='
HashTag = raw_input("HashTag  : ") or "CNN"
#url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
url = u'https://twitter.com/search?q='+ HashTag +'&src=typd'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list
# Out:
# HashTag  : CNN

# %% [markdown]
# # Search for a Random Phrase Using phrases.txt

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)

#url = u'https://twitter.com/search?q='
#HashTag = (random_line('hashtag-nouns.txt'))
HashTag = (random_line('phrases.txt'))
url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list
# Out:
# How many times must u repeat answer to media? #Every time u  them. Sec Tillerson #DoesNot  like that
# Moron=MSMpic.twitter.com/PkwwRJmiCK
#
# @NancyPelosi OMG not the time to bring politics in #every chance you Dems get #leave those who died #RIP #people #Injured #heal #mourn
#
# Has it been weeks now? Whatever, #NewBanner #Again #Because #It #Gets #Retro #Every #Week #4Me #Whelppic.twitter.com/H1r9l72Xtf
#
# You Asked: Should I #Wash My #Hair #Every #Day? https://buff.ly/2xSOIpk
#
# #Every student walking the #FrankProjectRunway will be called by name and creation. @FrankKISD #cardboardchallengepic.twitter.com/L9zwP6oXCS
#
# Human weakness is meant to be met with the strength of God's Word. -
# #Every Battle Won
# #Jesus
# #Word Made Flesh
#
# Not in the USA . You can't just show up anymore .. lol #closed #society #closed #borders #USA #Armedamericans #behind #every #bladeofgrass
#
# KNOW THIS: The end of the world cannot come until #EVERY human being on earth has heard the good news of the gospel of the Kingdom of God
#
# A3: It's when everyone  through the same lens of growing #every student and is not worried if their  is the brightest.@KleinISD #P2Pchat
#
# #Every time I close my eyes #I still member her
#
# Good  #Every body pic.twitter.com/IamCKzkr1Z
#
# Deciphering the levels of proficiency with math exemplars and understanding expectations #every student everyday #Baysideriseuppic.twitter.com/uIyGGmEqf2
#
# #Every Vote Counts
# Do Your Duty as an aware citizen! pic.twitter.com/sxwT82cRTl
#
# #Every student matters, every moment count!!!
# #Call us @ 01765-255450, 252066
# For more details visit @ http://www.gpsgobindgarh.com pic.twitter.com/36b4sANavs
#
# Committee doing lunch!! #every.single.day @IAFBLApic.twitter.com/d56J0fAFAH
#
# #Every #team #need #to #believe - they #can #change The #World (C) #BY https://goo.gl/fqs3CH  #WEB #Mobile #reactjs #AR #VR #IOT #DevOps17pic.twitter.com/VTPYGRsjOJ
#
# #Every man has a child-like mind
#
# When he is stormed by life's problems
#
# The child in him must come out to hope
#
# As heart of a child is pure
#
# @jessaugustyn um.... 2W13th #every #time
#
# Just placed my vote for NASCAR Cup Series Most Popular Driver! @DaleJr #MY #VOTE #TODAY #EVERY #DAY #Appreci88ion @NASCAR #NASCARMPD
#
# #FirePreventionMonth #Every SecondCountsPlan2WaysOut Draw a map of your home w/ family, mark 2 exits & a path to the outside from each exit. pic.twitter.com/GzAuGJdIVS

# %% [markdown]
# # Search Twitter Using Prevous HashTags

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)

#url = u'https://twitter.com/search?q='
#HashTag = (random_line('hashtag-nouns.txt'))
#HashTag = (random_line('nodupsnohash.txt'))
#HashTag = (random_line('clean.txt'))
HashTag = "CNN"
url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list

# %%
# %%writefile /home/jack/anaconda2/lib/python2.7/site-packages/Txmanip/findhashwork.py

def findhash():
    with open('hashtag.txt', 'r') as textin:
        tempstore = set()
        with open('hashonly.txt', 'w') as outfile:
            for line in textin.readlines():
                hashed = [ word for word in line.split() if word.startswith("#") ]
                #hashed = word for word in line.split() if word.startswith("#")
                hashed = str(hashed)
                hashed = hashed.replace("[","");hashed = hashed.replace("]","")
                hashed = hashed.replace(",","\n");hashed = hashed.replace(" '","")
                hashed = hashed.replace("'","");hashed = hashed.replace("#\n ","")
                hashed = hashed.replace("#","\n#")
                outfile.write(hashed)


findhash()

def removeblank():
    with open('hashonly.txt') as infile, open('hashonlyNoBlank.txt', 'w') as outfile:
        for line in infile:
            if not line.strip(): continue  # skip the empty line
            outfile.write(line)  # non-empty
            
removeblank() 

def remove_duplicates(infile):
    tempstore = set()
    with open('hashonlyNoBlankNoDups.txt', 'w+') as out:
        for line in open(infile):
            if line not in tempstore:
                if len(line) < 16 and len(line) >4:
                    out.write(line)
                    tempstore.add(line)

remove_duplicates('hashonlyNoBlank.txt')

def removeHash(infile):
    with open('clean2.txt', 'w+') as out:
        for line in open(infile):
            line = line.replace("#","");line = line.replace('"','')
            out.write(line)

removeHash('hashonlyNoBlankNoDups.txt')
# Out:
# Writing /home/jack/anaconda2/lib/python2.7/site-packages/Txmanip/findhashwork.py

# %% [markdown]
# # ----------------  All Good Above ----------------------------------

# %%
badtext = ''.join(c for c in map(chr, range(173)) if not c.isalnum())
print badtext

word = words.translate(None, badtext)

# %%
from textblob import TextBlob
from nltk.corpus import wordnet

tweetfile = 'realwords.txt'
filein = open(tweetfile, 'w')
filein.close()  
with io.open("clean2.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    if not wordnet.synsets(essays): 
        #Not an English Word
        print essays,"- Is not a word"
    else:
        #English Word    
        filein = open(tweetfile, 'a')
        filein.write(essays)
        filein.close()    

        print essays
# Out:
# Solar
# EnergyStorage
# netmetering
# consumption
# Chinas
# soybeans
# tobacco
# QuitSmoking!
# AskArvi
# HealthTips
# social
# MEASummit2017
# Bitcoin
# energy
# Industry
# Growth
# cities
# develop
# streetcar
# decrease
# traffic
# congestion
# increase
# economic
# activity
# downtown
# Sydney
# BackTheBlue
# Togo
# Trump
# CFCU19
# ElvisHarte
# TeamDOLL
# none
# NONE
# deranged
# filthy
# Sane
# clean
# currently
# Progressive
# None
# Zero
# Nilch
# Nada
# Meme
# threadless
# The
# ArtistShops
# FAIL
# MAKE
# None.Its
# Each
# Day
# Always
# Other
# Appreci88ion
# NASCARMPD
# Winnie
# pooh
# gluten
# Honey
# none.
# know
# Love
# All
# Trust
# Few
# Wrong
# NoNe
# Redskins
# Fuck
# Respect
# Liberal
# Bastards
# America
# DHS
# ICE
# AwanBrothers
# ImranAwan
# FBI
# Wednesday
# MAGA
# POTUS
# pick6
# sofly
# shadeson
# dhs
# ANTIFA
# RIGHT_WING
# OSG
# Obama
# Russia
# DOJ
# CIA
# NSA
# TheResistance
# Equifax
# news
# JONESACT
# PuertoRico
# DHS:
# JonesAct
# ALLCargo
# Ports
# Aid
# Hur...
# Blockchain
# Funding
# infosec
# cybersecurity
# CISO
# privacy
# CIO
# CSO
# CO18
# SEN18R
# MAN
# WHEATGRASS
# COCONUT
# DIE
# PAINFUL
# DEATH!!
# NOTFUNNY!!!
# Man
# Grokitman
# Iot
# smarter
# comic
# book
# superhero!
# reading
# learning
# history
# science
# Grok
# man
# Scania
# DAF
# Nowguesswho
# Sabeans
# believe
# especially
# gotitcoming.
# Recompense
# gym
# hairy
# muscles
# men
# workout
# workingout
# chest
# handsome
# blueeyes
# question
# semantics
# grok
# grokitman
# grokit
# Blessed
# oklahoma
# selfie
# biceps
# lockerroom
# cute
# wrestler
# guy
# Knee
# Persident
# SOB
# MOM
# man-flu
# big-baby
# 6pack
# sixpack
# tummy
# toned
# georgia
# wrestle
# wrestling
# speedos
# beefy
# weightlifter
# Gay
# tbt
# boy
# beard
# veteran
# Fancy
# Spending
# Weekend
# Himself
# exsas?
# oneofthebest
# muscle
# daddy
# contest
# contestants
# pool
# bodybuilder
# bodybuilding
# muscleman
# pumpedup
# delts
# cop
# police
# officer
# policeman
# captain
# strong
# Microbial
# Spoilage
# PCR
# PCR\xc2\xad
# PCR!
# HumpDay
# Medicare
# IMXEMS
# MaxPain
# Genetic
# Molecular
# ONEOF1ignore
# Biotech
# Biotechnology
# DNA
# pcr
# visonmixer
# consumers
# BAX
# Salmonella
# ESICM2017
# lives2017
# Vienna
# mcm
# diagnostics
# PCR!!!
# EndTB
# Swaziland
# research
# biology
# lifescience
# biotech
# laboratory
# curiosity
# ourstuart
# cancer
# cells
# RNAextraction
# cellculture
# rna
# capitalism
# environment.
# consumption
# World
# Energy
# Consumption
# OECD
# Freedom.
# PlanetEarth.
# war.
# consumption.
# 7DeadlySins
# IRS
# Tax
# WriteOffs
# Deductions
# FairTax!
# awareness
# local
# smallholder
# farmers
# agriculture
# land
# green
# materialism.
# Indian
# GDP
# EOTYatSSE
# reduce
# bill
# Multinational
# Corps
# Nutrition
# Food
# Manufactured
# Logistics
# mrx
# Direct
# Insurance
# Carrier
# Revenues
# Global
# Demand
# pricesetting
# tax
# alcohol
# Logos
# tomgalle
# earth
# McDonalds
# Spanish
# kerosene
# consumption:
# maximum
# climatechange
# environment
# ecology
# globalwarming
# population
# lifestyle
# Workstation
# workstation.
# VMware
# vExpert
# Fusion
# setup
# dreamsetup
# workstation
# battlestation
# workspace
# pcgaming
# deskspace
# desksetup
# gaming
# game
# workhard
# buongiorno
# yql
# vmware
# fusion
# newreleases
# pcgamer
# gamer
# gamingpc
# computer
# gamingsetup
# electric
# desks
# health
# performance
# Autodesk
# Maya
# SPEC
# benchmark
# PISDMathChat
# startup
# desk
# WorksForMe
# movies
# design
# uidesign
# dribbble
# behance
# office
# effects
# movie
# Steps
# Run
# KaliLinux
# Howto
# Linux
# Tactig
# photography
# Market
# Profit
# Packaged
# Frozen
# Wholesalers
# FreeAccess:
# Alternative
# food
# Waste
# Collection
# business
# cloud
# technology?
# CyberSecurity
# Analytics
# Security
# Compliance
# adobe
# security
# Unix/
# chrome
# edge
# safari
# ITSecurity
# Crypto
# CSOCartoon
# CISSP
# ITsec
# infosectruth
# NSASymposium
# cryptohistory
# fintech
# Insurtech
# education
# cio
# ciso
# cso
# First
# Female
# Cybersecurity
# Tech
# Regulation
# datasec
# corpgov
# gdpr
# eugdpr
# finserv
# Boston
# InfoSec
# cto
# CyberConnect
# Podcast-
# GDPR
# governance
# regtech
# microfocus
# encryption
# threatintel
# ehr
# ghc17
# excited
# opportunity
# gearing
# thanks
# ABI
# GOOGLE
# folding
# Galaxy
# festiveseason
# weddings
# shows
# socialising
# parties
# mittiofkutch
# treasures
# positive
# negative
# investment
# BikeServicing
# Calella
# Gearing
# Brakes
# Bolts
# HotelMontRosa
# timewalking
# Wow
# HAAS.
# AM100
# Automotive
# News
# Commission
# YOUR
# pets
# dogs
# cats
# birds
# hamsters
# FollowsMe
# Litecoin
# VideoGame
# Manga
# Information
# And
# Sitting
# Choir
# Rihminds
# Addition
# Things
# Thought
# Rihlationship
# KamelaHarris
# Malutto
# Negro
# Malutto
# dont
# choose
# Prospect
# mine.
# Prophetic
# Warrior
# Prayer
# Circle
# Leader
# System
# Most
# Own
# Agenda
# Identified
# Time
# Identify
# Other...
# NPm
# Mirror
# him
# philosophers
# playdate
# play
# lethimout
# iFunny
# meme
# memes
# memethis
# memeit
# - Is not a word

# %%
from textblob import TextBlob
tweetfile = 'realwords.txt'
filein = open(tweetfile, 'w')
filein.close()  
with io.open("clean2.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read()
    if wordnet.synsets(essays):
        print essays
# Out:
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-14-01c20db66b8d> in <module>()
# ----> 1 from textblob import TextBlob
#       2 tweetfile = 'realwords.txt'
#       3 filein = open(tweetfile, 'w')
#       4 filein.close()
#       5 with io.open("clean2.txt", "r", encoding="utf-8") as my_file:
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/__init__.py in <module>()
#       7 PACKAGE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
# ----> 9 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#      10
#      11 __all__ = [
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/blob.py in <module>()
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/__init__.pyc in <module>()
#     126 ###########################################################
#     127
# --> 128 from nltk.chunk import *
#     129 from nltk.classify import *
#     130 from nltk.inference import *
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/__init__.py in <module>()
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (ChunkScore, accuracy, tagstr2tree, conllstr2tree,
#     159                              conlltags2tree, tree2conlltags, tree2conllstr, tree2conlltags,
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/api.py in <module>()
#      11 ##//////////////////////////////////////////////////////
#      12
# ---> 13 from nltk.parse import ParserI
#      14
#      15 from nltk.chunk.util import ChunkScore
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/__init__.py in <module>()
#      77 from nltk.parse.malt import MaltParser
#      78 from nltk.parse.evaluate import DependencyEvaluator
# ---> 79 from nltk.parse.transitionparser import TransitionParser
#      80 from nltk.parse.bllip import BllipParser
#      81 from nltk.parse.corenlp import CoreNLPParser, CoreNLPDependencyParser
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/transitionparser.py in <module>()
#      19     from numpy import array
#      20     from scipy import sparse
# ---> 21     from sklearn.datasets import load_svmlight_file
#      22     from sklearn import svm
#      23 except ImportError:
#
# /home/jack/anaconda2/lib/python2.7/site-packages/sklearn/datasets/__init__.py in <module>()
#      46 from .samples_generator import make_biclusters
#      47 from .samples_generator import make_checkerboard
# ---> 48 from .svmlight_format import load_svmlight_file
#      49 from .svmlight_format import load_svmlight_files
#      50 from .svmlight_format import dump_svmlight_file
#
# /home/jack/anaconda2/lib/python2.7/site-packages/sklearn/datasets/svmlight_format.py in <module>()
#       9 This format is used as the default format for both svmlight and the
#      10 libsvm command line programs.
# ---> 11 """
#      12
#      13 # Authors: Mathieu Blondel <mathieu@mblondel.org>
#
# KeyboardInterrupt:

# %%
textin= open('hashtag.txt', 'r')
lines = textin.readlines()
for line in lines:
    time.sleep(1)
    print line
# Out:
# https://www.theguardian.com/commentisfree/2017/sep/25/laura-kuenssberg-bodyguard-abuse-female-political-journalist-abuse?CMP=Share_AndroidApp_Tweet ignore
#
# I leave all my assignments until the last minute because diamonds are made under pressure
#
# News Anchors Cracking Under Pressure in the #Trump Era - "Stop the Hammering" Has He Lost His Mind?pic.twitter.com/NYREmVNJtI
#
# Pittsburgh Steeler's Alejandro Villanueva Under Pressure:
#
#  “Standing By Myself" Was A “Mistake"
#
#  https://100percentfedup.com/wow-fans-break-nfl-jersey-sales-record-3-time-afghan-war-vet-bravely-stood-alone-national-anthemnow-claims-standing-mistake/ ignore
#
# Clinton: Comey was "under pressure" from Giuliani and other officials to reopen FBI investigation into emails http://hill.cm/KNwa5DJ pic.twitter.com/H1f9QYX7Au
#
# He is slow on the ball, slow off the ball, technically limited, shaky under pressure, too safe on the ball, limited vision. BENCH, PLEASE.
#
# Hillary Clinton: Comey Was ‘Under Pressureignore From Rudy Giuliani To Re-Open Email Probe [VIDEO] https://trib.al/sZ4lS9d pic.twitter.com/xvQ3SLitVV
#
# I'm way better under pressure
#
# Bulka dives to save again. The young Blues are under pressure as half-time nears but have that 3-1 lead. #CFCU19
#
# Playing Only The BEST Oldies 24 Hours A Day 7 Days A Week Got Me Under Pressure - @ZZTopxpic.twitter.com/d1gwzcmr2n
#
# UNDER PRESSURE! PUSHING DOWN ON ME PRESSING DOWN ON YOU NO MAN ASK FOR
#
# #ElvisHarte "fearless, impulsive, self-confident, determined & cool under pressure. A remarkable leader, brave & heroic" - @lucapasqualinopic.twitter.com/ArL6y1boMI
#
# #TeamDOLL .@Lacbleu_ @_KCCO_
#
# Under Pressure/Let It Go Smoosh-Up ~ Queen & Disney's Frozen https://youtu.be/gvX9GxDDPYc  via @YouTube @PuddlesPityP
#
# Azealia Banksignores response to Cardi B on IG made me spit out her water. Lmao. King AB keeps putting these bitches under pressure.
#
# Im deadass tryna find a flaw in this chick #none
#
# What business allows their employees to share their views on their platform #NONE
#
# @cineworld i think you're #deranged wanting me to be #filthy #Sane people want me to be #clean of which there is #currently #none
#
# That's the diseased #Progressive mind.
#
# It makes no sense whatsoever.
#
# #None https://twitter.com/RDevole/status/910914479340376066 ignore
#
# If you call @FedEx about a package they'll track it down & call the driver... @UPS claims they have NO WAY of contacting the driver! #NONE
#
# Remind us @Nigel_Farage how many MPs your party has? #None #Zero #Nilch #Nada #BetterOffVotingTory #Meme
#
# Can I vote for #noneIsaiah 45:6 NIV #know #none
#
# http://ift.tt/2wY7zMl  #threadless @threadless # #None #The Creative Adult #ArtistShops @ArtistShops .pic.twitter.com/0EacRv0vXZ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-5f8862cf09a7> in <module>()
#       2 lines = textin.readlines()
#       3 for line in lines:
# ----> 4     time.sleep(1)
#       5     print line
#
# KeyboardInterrupt:

# %%
import time
textin= open('hashtag.txt', 'r')
lines = textin.read()
time.sleep(1)
print lines,
# Out:
# https://www.theguardian.com/commentisfree/2017/sep/25/laura-kuenssberg-bodyguard-abuse-female-political-journalist-abuse?CMP=Share_AndroidApp_Tweet ignore
# I leave all my assignments until the last minute because diamonds are made under pressure
# News Anchors Cracking Under Pressure in the #Trump Era - "Stop the Hammering" Has He Lost His Mind?pic.twitter.com/NYREmVNJtI
# Pittsburgh Steeler's Alejandro Villanueva Under Pressure:
#  “Standing By Myself" Was A “Mistake"
#  https://100percentfedup.com/wow-fans-break-nfl-jersey-sales-record-3-time-afghan-war-vet-bravely-stood-alone-national-anthemnow-claims-standing-mistake/ ignore
# Clinton: Comey was "under pressure" from Giuliani and other officials to reopen FBI investigation into emails http://hill.cm/KNwa5DJ pic.twitter.com/H1f9QYX7Au
# He is slow on the ball, slow off the ball, technically limited, shaky under pressure, too safe on the ball, limited vision. BENCH, PLEASE.
# Hillary Clinton: Comey Was ‘Under Pressureignore From Rudy Giuliani To Re-Open Email Probe [VIDEO] https://trib.al/sZ4lS9d pic.twitter.com/xvQ3SLitVV
# I'm way better under pressure
# Bulka dives to save again. The young Blues are under pressure as half-time nears but have that 3-1 lead. #CFCU19
# Playing Only The BEST Oldies 24 Hours A Day 7 Days A Week Got Me Under Pressure - @ZZTopxpic.twitter.com/d1gwzcmr2n
# UNDER PRESSURE! PUSHING DOWN ON ME PRESSING DOWN ON YOU NO MAN ASK FOR
# #ElvisHarte "fearless, impulsive, self-confident, determined & cool under pressure. A remarkable leader, brave & heroic" - @lucapasqualinopic.twitter.com/ArL6y1boMI
# #TeamDOLL .@Lacbleu_ @_KCCO_
# Under Pressure/Let It Go Smoosh-Up ~ Queen & Disney's Frozen https://youtu.be/gvX9GxDDPYc  via @YouTube @PuddlesPityP
# Azealia Banksignores response to Cardi B on IG made me spit out her water. Lmao. King AB keeps putting these bitches under pressure.
# Im deadass tryna find a flaw in this chick #none
# What business allows their employees to share their views on their platform #NONE
# @cineworld i think you're #deranged wanting me to be #filthy #Sane people want me to be #clean of which there is #currently #none
# That's the diseased #Progressive mind.
# It makes no sense whatsoever.
# #None https://twitter.com/RDevole/status/910914479340376066 ignore
# If you call @FedEx about a package they'll track it down & call the driver... @UPS claims they have NO WAY of contacting the driver! #NONE
# Remind us @Nigel_Farage how many MPs your party has? #None #Zero #Nilch #Nada #BetterOffVotingTory #Meme
# Can I vote for #noneIsaiah 45:6 NIV #know #none
# http://ift.tt/2wY7zMl  #threadless @threadless # #None #The Creative Adult #ArtistShops @ArtistShops .pic.twitter.com/0EacRv0vXZ
# 57 years of I 'll build road. #NONE I 'll provide electricity, #FAIL I 'll build Schools, #NA TRUE Provide free health care #MAKE I HEAR
# my-head-is-itchy pose  #none https://www.instagram.com/p/BZkfIElBcfs/
# What is the difference between content of white eggs & brown eggs? #None.Its depends on genetics of the hen.No price difference.#nutrition
# Understand that there's no more shame in having a mental illness than there is for having a physical illness.
# #MyTipsForMentalHealth
# LZ Wake the #Fuck Up this is about #Respect of witch you #Liberal #Bastards have #None what have you Done 4 #America !https://twitter.com/Locs_n_Laughs/status/911977844187611136 ignore
# With the travel restrictions about to be implemented how many agree that #DHS or #ICE should take another look at this Jihadist
# #RT 4 #USApic.twitter.com/vommtMBcnt
# We must all defend the 1st Amendment as powerfully as the NRA defends the 2nd. The #DHS snooping on social media accounts is Big Brother
# This is unacceptable! Not ok and not funny #DHS #NoToastorPraisehttps://twitter.com/nottirbeioj_/status/913208382374289408 ignore
# WTF!!!!!!!!!!! This is extremely disturbing. Rao Abbas is using a stolen identity of the guy who is the Technical Director for the Dept of Homeland Security. Read entire thread for more details.
# #AwanBrothers #ImranAwan #FBI #DHS #Wednesday #MAGA #POTUS #WTFhttps://twitter.com/DropThe_Mic/status/913099287306887168 ignore
# and she's gone #pick6 #ai #sofly #shadeson #dhs #flagfootballpic.twitter.com/YIPd1Ng4rB
# FILES SHOW #DHS, #FBI REGARD #ANTIFA AS MORE DANGEROUS THAN #RIGHT_WING GROUPS.https://sputniknews.com/military/201709261057716980-declassified-files-antifa-extremist/ ignore
# Right. It's our bad luck you assaulted, maimed, gaslit, strangled, raped, microwaved & attempted to murder us, organized stalkers. #DHS #OSG
# How did #Obama @DHSgov  detect ? #Russia attemots to hack?.. #DHS was already trying to breach & stumbled on new intruders. @JusticeOIG @IJ
# 2017 Yearbooks are in!! #dhs pic.twitter.com/SUi1tu8GxD
# That's because the #DOJ is just as corrupt as the #CIA #NSA #DHS https://twitter.com/TrishaDishes/status/911773161242468353 ignore
# #DHS planning to collect social media info on ALL immigrants | The Hill #TheResistance
# http://a.msn.com/r/2/AAsucEu pic.twitter.com/dLhe24UnlM
# We can land a miniature spacecraft on a comet that's going at warp speed but we don't know how to avoid an #Equifax  breach. #news #dhs
# 'Potential targeting' statement of #DHS was misreported by US media as 'Russian gov't cyber actors' https://on.rt.com/8nzh
# #JONESACT waived almost immediately for TX LO FL
# Why does @PressSec say waiver not needed #WH incompetent #DHS useless #PuertoRico needs AID
# Original #DHS statement mentioned neither election hacking nor #Russia https://on.rt.com/8nzh
# #HelpFellowPRAmericans #DHS: Waive the #JonesAct for #ALLCargo at #Ports in #PuertoRico to #Aid #Hur... https://www.change.org/p/department-of-homeland-security-waive-the-jones-act-for-all-cargo-at-ports-in-puerto-rico-to-aid-hurricane-maria-relief?recruiter=156698820&utm_source=share_petition&utm_medium=twitter&utm_campaign=psf_combo_share_initial.combo_new_control_progress_bar.redirected&utm_term=148424&utm_content=nafta_twitter_large_image_card%3Acontrol&pt=AjpQZXRpdGlvbjoxMjM2MjMzODoxNTA2NTYyNzkzOjUsDiwaLC06Yjg5YzM0Mzc%3D ignore via @Change
# Russia tried to hack electionsignore: US media misreported #DHS 'potential targeting' warning https://on.rt.com/8nzh pic.twitter.com/kmhMhxUg5a
# The U.S. @DHSgov awarded $750K to blockchain startup DigitalBazaar.
# #setup #dreamsetup #workstation #battlestation #workspace #pcgaming #deskspace #desksetup #gaming #game #gamerpic.twitter.com/inKFGVX2kF
# Buongiorno!! Ready for another #workhard day!! ..#goodmorning #buongiorno #workstationignore https://www.instagram.com/p/BZkyIHWBQup/
# Borrowed workstation & office space. Where my vertical monitors at!? #yql #workstation #deskspace #WorkspaceWednesday #blackandwhitepic.twitter.com/26qAykvDcL
# Now Shipping: VMware Workstation 14 & VMware Fusion 10 #vmware #fusion #workstation #newreleases http://bit.ly/2k3sRqz pic.twitter.com/5gqlN2sQmn
# Here comes the all new #VMware #Workstation 14 & #VMware #Fusion 10 http://bit.ly/2y9envp pic.twitter.com/9F7162fvaB
# .@HP launches HP Z VR backpack for untethered pro #VR - doubles as a desktop #workstation
# http://www.develop3d.com/blog/2017/08/hp-launches-workstation-backpack-for-untethered-pro-vr ignorepic.twitter.com/zmh42LRVY3
# Get your #VMware #Workstation 14 & VMware #Fusion 10 updates, for "High Sierra" and Win 10 "Fall" update support! http://bit.ly/2y9eAPb pic.twitter.com/hVz1ttaFhF
# VMware Workstation 14 Pro Released with New Features @vmw_workstation #workstation https://www.virtualizationhowto.com/2017/09/vmware-workstation-14-pro-released-with-new-features/ ignorepic.twitter.com/QonZ3STY4x
# Reposting @hermanospc:
# #pc #pcgamer #gamer #gamingpc #battlestation #workstation #dreamsetup #computer #desksetup #gamingsetup pic.twitter.com/u4NCjc41BZ
# Talk to us about #electric #desks #workstation #health & have a free #workstation #assessmenthttps://twitter.com/SvenFurniture/status/912954950136860672 ignore
# Evaluate #workstation #performance for #Autodesk #Maya 2017. New free #SPEC #benchmark downloads. http://ow.ly/JFfZ30frS1y pic.twitter.com/fH5WrYGFid
# Check out the #workstation to support Grade 4 place value concepts! (Burnett ES) #PISDMathChat #ElemMathChatpic.twitter.com/gP21tFKLQh
# Srikanth, our community member works from this beautiful breezy terrace at Cooke Town, Bangalore. #workstation #startup #inspirationpic.twitter.com/1NjPBAnRG4
# Screenbox allows for multi-purpose use of a #workstation, integrating monitor, keyboard and mouse into the desktop. #desk #officefurniturepic.twitter.com/wkuz2mM7xC
# Magic station. Creativity zone #workstation #WorksForMe #WorkLifeBalancepic.twitter.com/OXMa5oo9wl
# New design Movies website #movies #design #ui #ux #uidesign #dribbble #behance #workstation #office #effects #design #movie
# #Steps to #Run #KaliLinux 2.0 on #VMware #Workstation Latest Version #Howto #Linux #Tactig http://www.tactig.com/install-kali-linux-2-0-on-vmware-workstation/ ignorepic.twitter.com/ZcljlOrOQy
# I think its important we find a balance between #capitalism and the #environment. It can be done! #consumption pic.twitter.com/pf8wAmM6qd
# #World #Energy #Consumption by country grouping and future prediction
# #OECD #NonOECDpic.twitter.com/FBIGt4sTus
# Most of the #Indian #GDP accounts for #consumption and not fresh #privateinvestment #EOTYatSSE
# There is a cost for #Freedom. There is a cost for #PlanetEarth. There is a cost for #war. There is a cost for #consumption. #7DeadlySins
# #awareness on #local #consumption can benefit #smallholder #farmers on best utilization of their #agriculture #land
# Vehicle stopped on M57. Driver blows mouth alcohol level of 147ug (Limit 35) #Arrested & spending a night with us now. #NoneForTheRoadpic.twitter.com/VWBlARCMEO
# We got him! #arrested https://twitter.com/fortworthpd/status/910578705616867328 ignore Poaching in Burton after #RealTimeANPR hit.
# Driver wanted for distraction Burglary. Bonus no insurance too. #Seized #Arrested pic.twitter.com/I3C221towZ
# P7s had a great time at @radarNI today learning about risks and how to avoid them #internetsafety #roadsafety #firesafety #arrested pic.twitter.com/txxTnnhNq5
# SOLID BLUE States like CA, NY & NJ have the most #IllegalAlien & fraudulent votes pic.twitter.com/R3c6rGmuAS
# If U think the term #IllegalAlien is hate speech then I wish U a speedy recovery of your illness.They R what they R. Get over it snowflakes.
# So now you are calling Steve Jobs' biological father, who abandoned him, an #IllegalAlien? oh, wait!
# If You are From a Foreign Land & are In America Without "Permission", you are an #illegalAlien & U are Breaking The Law. pic.twitter.com/XKYSJjCP7X
# Federal courts admit "#IllegalAlien" is a proper term. Where the Left would have us believe is offensive. Better luck w/their Safe Places pic.twitter.com/3mkap2INzZ
# Undocumented Immigrant Sexually Assaults 12-Year-Old Girl He Met At Church Over A Dozen Times #illegalalien #criminal #deport #buildthewallpic.twitter.com/FVSRjJ3p3H
# Build the WALL... Texas Girls Raped, 1 Killed by #IllegalAlien Satanists #SecureTheBorder #AmericaFirstpic.twitter.com/ozxLOLE8mL
# Oh don't worry he is really a nice guy. This #illegalalien just wants to work. pic.twitter.com/yyqoXqo2Dy
# #IllegalAlien Murders 15-Year-Old Stepdaughter Pregnant With His Child. pic.twitter.com/7CczFtVQe6
# A twice-arrested #illegalalien killed a Kansas sheriff's deputy. He was driving drunk and crashed his pickup truck into a patrol car. pic.twitter.com/P8LUA8RPUB
# Chaz Bono unhappy because ICE arrested his #IllegalAlien employees. Problems paying real wages?
# In 1997 a criminal #illegalalien crashed into me on my motorcycle. When my lawyer went to collect for damages she literally disappeared.
# As of March 2016, not a Legal Citizen. Doesn't even have a Green Card. @Trevornoah shld be deported. #IllegalAlien @ICEgov @realDonaldTrumppic.twitter.com/fEAFRExpD3
# How republicans deny people their right to vote: #illegalalien #magapic.twitter.com/rCTA9F1STc
# DREAMer Gustavo Marquez, 19, was booked on first-degree murder and kidnapping charges in the deaths of two teens. Deport this #illegalalien pic.twitter.com/Om60L6vt9B
# #illegalalien amnesty would be costly to current and future workers by undermining the already vulnerable Social Security system,
# Immigrants can cross into Mexico from the south largely by trekking through jungle brush or crossing rivers on rafts. #illegalalien
# According to the Texas Department of Public Safety, foreign aliens committed 611,234 unique crimes in Texas from 2008 to 2014 #illegalalien pic.twitter.com/cTVfsx3xCp
# I reject these core values. Stop the #illegalalien invasion! pic.twitter.com/ownPw96nPy
# Roughly one in six illegal immigrants is re-arrested on criminal charges within three years of release #illegalalien pic.twitter.com/9dy4mtJfXZ

# %%
textin= open('hashtag.txt', 'r')
lines = textin.read().splitlines()
time.sleep(1)
print lines,
# Out:
Xs', 'Well, you know, all that class they have. #none', '\xe2\x80\x9cso that from the rising of the sun to its setting people may know there is none besides me. I am the LORD...\xe2\x80\x9d', 'LOVE ALL, TRUST A FEW, DO WRONG TO NONE. #Love #All #Trust #Few #Wrong #None #WilliamShakespeare', 'URL:  https://goo.gl/Kdc8sw pic.twitter.com/nDNzHMA9yq', "players & coaches when you're respectful to the flag this respect goes to our Country and your fans! #NoNe for  #Redskins Thank you!", 'When I type @Equifax it keeps autocorrecting to equidad. Which is fitting b/c they have equal technological acumen. #none', "Understand that ...

# %%
def linesonly():
    with open('hashonly.txt') as infile, open('hashonlyNoBlank.txt', 'w') as outfile:
        for line in infile:
            if not line.strip(): continue  # skip the empty line
            outfile.write(line)  # non-empty
linesonly()

# %% [markdown]
# # keeper

# %%
hashed = [ word for word in line.split() if word.startswith("#") ]

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)
#url = u'https://twitter.com/search?q='
HashTag = (random_line('hashtag-nouns.txt'))
print HashTag
# Out:
# Monitoring

# %%
#lines = open('phrases.txt', 'r').readlines()
lines = open('phrases.txt', 'r').read()
lines_set = set(lines)
out  = open('phrases2.txt', 'w')
for line in lines_set:
    out.write(line)

# %%
# %%writefile Bt.py
def badtext(essays):
    badtext = ''.join(c for c in map(chr, range(256)) if not c.isalnum())
    essay = essay.translate(badtext)
    return essay

# %%
from nltk.tag import pos_tag
import io
import Tidyt
with io.open("hashtag.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    tagged_sent = pos_tag(essays.split())
    output = open("hashtag-nouns.txt", "w")
    propernouns = [word for word,pos in tagged_sent if pos == 'NNP']
    in_string = str(propernouns)
    propernouns = Tidyt.tidyt(in_string)
        
    propernouns = propernouns.replace("  "," \n")
    output.write(propernouns)
    output.close()    
    print propernouns
# Out:
# (Solar)
# PV
# Monitoring
# Basically
# USA
# China
# Video
# Global
# Sheetfed
# Scanner
# Market
# Analysis
# Production
# Consumption
# Trends
# Forecastsignore
# Learn
# @Cerosdotcom:
# Global
# PCR
# Workstation
# Market
# Analysis
# Application
# Size
# Production
# Market
# Share
# Consumption
# Trends
# Interesting
# #QuitSmoking!
# #AskArvi
# #HealthTips
# #ICanYouCanpictwittercom/9PM6hsxYYp
# Chief
# Scientist
# David
# Jamieson
# India
# September
# Gebo
# Cermex:
# Facebook
# Facebook
# Instagram
# @socialmedia2day
# Media
# Consumption
# Trends
# Global
# Tranexamic
# Acid
# Market
# Outlook
# Growth
# Production
# Consumption
# Trends
# Anlaysisignore
# Emerging
# New
# Africa
# Andrew
# Waititu
# #MEASummit2017
# @Andrew_YT2
# @BusinessSwedenpictwittercom/SoJ5xbarfm
# @Andrew_YT2
# #MEASummit2017
# #Bitcoin
# #energy
# Up
# Global
# Pumpkin
# Seed
# Oil
# #Industry
# Overview
# Consumption
# Trends
# #Growth
# Opportunitiesignorehttps://googl/fb/ZJ3TKq
# Global
# Acrylic
# Emulsions
# Market
# Analysis
# Production
# Consumption
# Trends
# Research
# Reportignore
# #decrease
# #traffic
# #congestion
# #increase
# #economic
# #activity
# #downtown
# #Sydney
# DHA
# Min
# Prof
# Mkhize
# DG
# Apleni
# Farah
# Black:
# Bodyguard
# Cool
# Usually
# Sometimes
# #DirkGentlyBBCApictwittercom/qWAfk8v9me
# Matos
# Read:
# #BackTheBlue
# #FIFAU17WCpictwittercom/LiwKDNXWNl
# DHS
# Congress
# Jones
# Act
# Puerto
# Rico:
# Been
# "#Kuenssberg
# News
# Cracking
# Era
# Hammering"
# Has
# Mind?pictwittercom/NYREmVNJtI
# Pittsburgh Steelers Alejandro
# Villanueva
# Pressure:
# Myself"
# Was
# A
# Clinton:
# Comey
# Giuliani
# FBI
# BENCH
# PLEASE
# Hillary
# Clinton:
# Comey
# Was
# Under
# Pressureignore
# From
# Rudy
# Giuliani
# Re-Open
# Email
# Probe
# [VIDEO] Im Bulka
# BEST
# Hours
# A
# Day
# Days
# A
# Week
# Got
# Me
# Pressure
# UNDER
# PRESSURE!
# PUSHING
# DOWN
# ON
# ME
# PRESSING
# DOWN
# ON
# YOU
# NO
# MAN
# ASK
# FOR
# #ElvisHarte
# "fearless
# A
# @Lacbleu_
# @_KCCO_
# Pressure/Let
# Go
# Smoosh-Up
# ~
# Queen Disneys Frozen
# @YouTube
# @PuddlesPityP
# Azealia
# Banksignores
# Cardi
# B
# IG
# Lmao
# King
# AB]

# %%
file = open("realDonaldTrump_tweets.csv", 'r')
book = file.read()
def tokenize():
    if book is not None:
        words = book.lower().split()
        return words
    else:
        return None
def count_word(tokens, token):
    count = 0
    for element in tokens:
        # Remove Punctuation
        word = element.replace(",","")
        word = word.replace(".","")
        # Found Word?
        if word == token:
            count += 1
    return count
# Tokenize the Book
words = tokenize()

# Get Word Count
word = 'Hillary'
frequency = count_word(words, word)
print('Word: [' + word + '] Frequency: ' + str(frequency))
# Out:
# Word: [Hillary] Frequency: 0

# %%
import random 

# get the first line if this is the one with the words words
lines = open("realDonaldTrump_tweets.csv").readlines() 
line = lines[0] 

words = line.split() 
myword = random.choice(words)
print myword
# Out:
# id,created_at,text

# %%
import random, heapq

with open('realDonaldTrump_tweets.csv') as fin:
    word, = heapq.nlargest(1, fin, key=lambda L: random.random())
    print word,
# Out:
# 780377077518364673,2016-09-26 12:02:48,"New national Bloomberg poll just released - thank you! Join the MOVEMENT: https://t.co/3KWOl2ibaW.

# %%
import random
def generate_the_word(infile):
    with open(infile) as f:
        contents_of_file = f.read()
    lines = contents_of_file.splitlines()
    line_number = random.randrange(0, len(lines))
    return lines[line_number]
def main():
    print(generate_the_word("realDonaldTrump_tweets.csv"))

main()
# Out:
# 884016887692234753,2017-07-09 11:50:24,"Putin &amp; I discussed forming an impenetrable Cyber Security unit    so that election hacking, &amp; many other negative things, will be guarded.."

# %%
from textblob import TextBlob
import time
import sys
with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
count = 0
Sent = input('Sent') or int(1)
Start = input('Start') or int(1)
End = input('End') or int(5)
Start= int(Start)
End= int(End)
blob = TextBlob(essays)
for word in blob.sentences[Sent].words:
    count = count +1
    if count >= Start and count <= End:
        print count,":",word
    else:
        my_file.close()
        sys.exit
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-67-51f5ac8a607e> in <module>()
# ----> 1 from textblob import TextBlob
#       2 import time
#       3 import sys
#       4 with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
#       5     essays = my_file.read()
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/__init__.py in <module>()
#       7 PACKAGE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
# ----> 9 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#      10
#      11 __all__ = [
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/blob.py in <module>()
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/__init__.py in <module>()
#     126 ###########################################################
#     127
# --> 128 from nltk.chunk import *
#     129 from nltk.classify import *
#     130 from nltk.inference import *
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/__init__.py in <module>()
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (ChunkScore, accuracy, tagstr2tree, conllstr2tree,
#     159                              conlltags2tree, tree2conlltags, tree2conllstr, tree2conlltags,
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/api.py in <module>()
#      11 ##//////////////////////////////////////////////////////
#      12
# ---> 13 from nltk.parse import ParserI
#      14
#      15 from nltk.chunk.util import ChunkScore
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/__init__.py in <module>()
#      79 from nltk.parse.transitionparser import TransitionParser
#      80 from nltk.parse.bllip import BllipParser
# ---> 81 from nltk.parse.corenlp import CoreNLPParser, CoreNLPDependencyParser
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/corenlp.py in <module>()
#      18
#      19 from nltk.parse.api import ParserI
# ---> 20 from nltk.tokenize.api import TokenizerI
#      21 from nltk.parse.dependencygraph import DependencyGraph
#      22 from nltk.tree import Tree
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/__init__.py in <module>()
#      80 from nltk.tokenize.treebank import TreebankWordTokenizer
#      81 from nltk.tokenize.util     import string_span_tokenize, regexp_span_tokenize
# ---> 82 from nltk.tokenize.stanford_segmenter import StanfordSegmenter
#      83
#      84
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/stanford_segmenter.py in <module>()
#      19 from subprocess import PIPE
#      20
# ---> 21 from nltk import compat
#      22 from nltk.internals import find_jar, find_file, find_dir, \
#      23                            config_java, java, _java_options
#
# ImportError: cannot import name compat

# %%
from textblob import TextBlob
with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 

blob = TextBlob(essays)
for np in blob.noun_phrases:
    print np
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-68-d1bb810def7a> in <module>()
# ----> 1 from textblob import TextBlob
#       2 with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
#       3     essays = my_file.read()
#       4
#       5 blob = TextBlob(essays)
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/__init__.py in <module>()
#       7 PACKAGE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
# ----> 9 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#      10
#      11 __all__ = [
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/blob.py in <module>()
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/__init__.py in <module>()
#     126 ###########################################################
#     127
# --> 128 from nltk.chunk import *
#     129 from nltk.classify import *
#     130 from nltk.inference import *
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/__init__.py in <module>()
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (ChunkScore, accuracy, tagstr2tree, conllstr2tree,
#     159                              conlltags2tree, tree2conlltags, tree2conllstr, tree2conlltags,
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/api.py in <module>()
#      11 ##//////////////////////////////////////////////////////
#      12
# ---> 13 from nltk.parse import ParserI
#      14
#      15 from nltk.chunk.util import ChunkScore
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/__init__.py in <module>()
#      79 from nltk.parse.transitionparser import TransitionParser
#      80 from nltk.parse.bllip import BllipParser
# ---> 81 from nltk.parse.corenlp import CoreNLPParser, CoreNLPDependencyParser
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/corenlp.py in <module>()
#      18
#      19 from nltk.parse.api import ParserI
# ---> 20 from nltk.tokenize.api import TokenizerI
#      21 from nltk.parse.dependencygraph import DependencyGraph
#      22 from nltk.tree import Tree
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/__init__.py in <module>()
#      80 from nltk.tokenize.treebank import TreebankWordTokenizer
#      81 from nltk.tokenize.util     import string_span_tokenize, regexp_span_tokenize
# ---> 82 from nltk.tokenize.stanford_segmenter import StanfordSegmenter
#      83
#      84
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/stanford_segmenter.py in <module>()
#      19 from subprocess import PIPE
#      20
# ---> 21 from nltk import compat
#      22 from nltk.internals import find_jar, find_file, find_dir, \
#      23                            config_java, java, _java_options
#
# ImportError: cannot import name compat

# %%
from textblob import TextBlob
with io.open("ToUse.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
blob = TextBlob(essays)
for sentence in blob.sentences:
    print sentence
# Out:
# If will create the same space of about three lines plus one in front of the height, the general rule is satidfied.
# He manages his forces as though they were only a memory.
# Some people are exceeding graciousness and familiar with the table.
# Those people are fewer in number.
# Long, low masses of dust show the soldiers will not be besieged; ground that must be made known beforehand.
# It was thus her wish to sleep.
# She was compelled by fatigue after undertaking, unassisted, entire weight of the task.
# Human life should not underrate the psychic apparatus which alone makes comprehensible the whole night.
# All thinking is only the opposite of conscious.
# Although we cannot identify what it is.
# Freud claims foreconscious is a large sum of energy brought about by consciousness.
# When an idea which does away with the conscious expression of the punishments, others will associate themselves.
# She loved only those who were distinguished in her households.
# If the enemy, from a sudden onslaught, is perceived weak make the defeat rapid.
# Men of the enemy in relation to water:-- After crossing waters, pass on immediately to a distance.
# Now, of the enemy, we may go a thousand leagues without exhaustion.
# The way_ or the proper conduct of war will not reap advantage.
# Do not let proper conduct weaken the effort.
# Their difficulty lies in the night betoken alarm.
# The computer will download an index of the files within one day.
# Non-sanctioned repositories must be made executable.
# It automatically backs itself up and ready to go.
# It takes the sudo apt-get update udates the index of the the week-ends.
# Welcome to The Tales of the first class came I was in Florida.
# The computer will download an index of files, it does not install them.
# If permission error is indicated, the file's permissions must be reviewed and evaluated by you.
# The computer will download an index of files, it does not install them.
# Now for the perception system, and, secondly, from the spot where he was last working.
# It upholds a _logical connection_ as _approximation in time for a moment for ignition.
# If you can not enter into the analysis, the further you are outside the United States.
# I will now point out that my mother was dying; the tomb agrees with this.
# Wherefore the good general's Speech on the psychology of war was inexcusable.
# Vary the stratagem according to my plans, or you will be lost.
# With regard to the occasion and the hearts of men, consider this upon employing troops.
# Therefore they must not be attacked, they must be divided.
# All  of our plans depend on accomplishing a single day's victory.
# They who are sitting may be present, the country as give information.
# For, while quick accomplishment has been a country and then fall upon them.
# If deeply involved in the service of their rights.
# This is called deeply-involved ground.
# But, if he listens and still decides the issue incorrectly, he must be eliminated.
# The diagram given a under no after the surface of every description.
# That part of the light is the highest light, and it is due to rivers which flow into the earth.
# This happens because the heat of the wall, look of the drawings here reproduced in facsimile have never been published before.
# Hence we may look at a spot corresponding to the forehead..
# The cast shadow will resemble a pyramid the same as the chin to the eyes.
# If we hope to get out of the Alps which divide France from Italy.
# THE IMAGES IN THE PUPIL OF THE RAYS WHETHER SHADED OR LUMINOUS HAVE GREATER STRENGTH AND EFFECT AT THEIR SIDES.
# The real size of the object mirrored in it is being exposed to the luminous bodies which are are smooth and white.
# Because they occupy no space, I will sign up for the American image in a couple weeks.
# WHAT PORTION OF A WALL SURFACE WILL BE LEAST LUMINOUS WHICH IS SEEN UNDER THE LEAST AMOUNT OF LIGHT.
# As to the distance we will have a very large shadow Which pervades the air.
# Compound derived shadows will be very plainly visible if the luminous bodyis not in direct view.
# The light which surrounds the derived shadow will show you their shaded side, because on that side of the edges.
# The base of this is the same form and colour; but the intersection as throughout the rest.
# The sea does not regard planes as foreshortened, but as an object which is nearest to black; and white make blue.
# The practice of the middle of the movements made in the same size, the second will seem half the head.
# Shadow partakes of the window from the angle where the author refers to morning light in general.
# Scuba Diving Lessons I was charged up and ready to go.
# The computer will download an index of the newly added repository are available.
# Out of the box, apostrophes have no place in a database and can be dangerous.
# My project of the Saltman is charged up and it is a database on Google Drive.
# As I said I use voice to make an auto-space after a period when using voice.
# Out of the files with one of the files with one of the box, apostrophes have no place in a couple weeks.
# Experimenting with a function to permit the file called configure.
# I signed up for the American image in a database.
# I also wish to say and share.
# If permission error is indicated, the file's permissions must be reviewed and evaluated by you.
# It will show you any upgrades and you must reply with a few Characters - Very UN-SALTMAN like This may be interested.
# This is the location I have things I wish to discourage people to come to the Philippines to party and get drunk.
# It automatically backs itself up and ready to go.
# A friend of mine was a bit of a challenge.
# I was charged up and it's database on Google Drive.
# As I said I use voice to make an auto-space after a period.
# When using voice, I am in the terminal.
# Welcome to The Tales of the commands If it is a tar.
# Find the configure file and enter.
# I program and it also is being recorded.
# When using Online Repository Resources it must begin with a few drinks until it is hard to differentiate the two.
# Some postings will be fun for readers to try out.
# It automatically backs itself up and ready to go.
# Air Horns there were a large set of air horns in the world is this Dude writing an E-book then.
# I am back to doing much of my decision to end my bond with Windows and Linux to me.
# We were cruising down the tube to the the spark plug.
# I saw a county just getting introduced to the death and abandonment of Windows XP.
# It was a home made jet engine using an an igniter I built at home.
# I was in the paper because I also fooled a bit with Mac Computers.
# I was afraid to cut the gas can away and run.
# My friend and I, both on motorcycles, went together to see the van I had to reach over the spark plug.
# I was in the garage on fire, caused by the jet engine igniter created at home.
# Back when a power failure meant a reinstall because of the favorite exhibits was a hard core DOS Dude.
# At the time it was a home made jet engine.
# I saw a county just getting introduced to the death and abandonment of Windows XP.
# Air Horns there were a large set of air horns in the world is this Dude writing an E-book then.
# I am retired and live in the garage on fire.
# I was afraid to cut the gas over the spark plug.
# I had found in the garage examining, modifying, tuning it up.
# It was a Windows project followed up by using a gas can.
# This is a poor country, and most of the small engine at school blew a blue flame and three or four yellow flames.
# I had to reach over the spark plug.
# OPP !
# Almost all the pieces together.
# Now what OMG !
# I was in the paper.
# Then reached over the spark plug.
# This is a poor country, and most of the dance halls and keep your mind sharp.
# Now what OMG !
# I was excited at the thought of the favorite exhibits was a home made jet engine.
# If you are older this may not lead you into a buzzer to pulse the electricity.
# Working from a command line freaks a lot of people out.
# If they could, quite often their hardware could not afford to purchase an upgrade.
# That being said, you must be wondering why in the Philippines when Microsoft decided to learn and promote Linux.
# I had found in the Philippines when Microsoft decided to give serious interest to Ubuntu Linux.
# I took the picture on the igniter, I could hear the spark plug.
# The filters are used for unpickled records received from a pickled event received over the wire.
# Handlers have the following table.
# If these are missing, the message for this handler fails.
# to a logger which is highest in the following attributes and methods.
# The logger name hierarchy is traversed towards the root logger, or delegation to the record will be emitted.
# Tidy up any resources used by the handler will not be threadsafe.
# Filters can be pickled and sent across the wire, but you should not need to pass the extra dictionary with these keys.
# Do formatting for a record - if a message with level INFO on this logger.
# Initializes a thread lock which can be used as the effective level for this handler to lvl.
# The LogRecord has a filter method with the message.
# Filename portion of a message, was a non-root logger.
# Logging messages which are below a certain point in the Python package namespace.
# Applies this handler’s filters to the root is reached, and it has a filter initialized with the same record multiple times.
# If name is lost the filters are consulted in turn by Formatter class.
# Until one of them return a false value, the record is to be added to the same Logger object.
# You shouldn’t need to pass a dictionary which is a non-root logger.
# For example: The keys in the logger is created with level ERROR on this logger.
# I lingered but a glance, for all they went so slowly; it was in his heart, he preferred to speak of it with passion.
# Suddenly and at the paper, and last of the low growl of London from all round, very silent.
# Each closet held an item needed, but not thing of vital to existance.
# I was once again raging and freezing with the passions of Hyde.
# But here I took and furnished that house of voluntary bondage, and to grow more at quiet with himself.
# But for all his energy of life, that Bernie at last his patience was rewarded.
# I mean from henceforth to lead a life of effort, virtue, and control, should usurp the offices of life.
# Six hours after, as I supposed, on every side, I began to cherish a longing for advice.
# Peewee was no more myself when I know how he fears my power to shake me.
# Others will follow, others will outstrip me on the chimney shelf, for even in memory, so dwell on that.
# At sight of him back, conscious at his companion.a few seconds.
# On his way to Malcom's door, where I saw that Sawbones turn sick and white with the door, in consequence.
# And he covered his face was white and his own past, groping in all the time.
# We were by no means in the lives of down-going men.
# Think of me at first sight, without a start of horror.
# Ah, sir, there's blood foully shed in every feature, the marks of prolonged and sordid negligence.
# The doctor had bought the house in Soho, to which I had learned to recognise in him for old sake's sake, as they are.
# Some two months before the murder had been prevented.
# Think of me were in dead earnest; I was able, in clothes of my second character, my faculties seemed sharpened to a watery green.
# The instance is initialized with the message.
# The line number and function name was added.
# These attributes can be used with particular Handlers.
# If none of them returns a false value which means that the message had a low level WARNING.
# If none of them return a reference to the constructor.
# The term ‘delegation to the parent logger is created, the level is treated as the effective level.
# Returns an instance of the ancestor loggers is traversed towards the root logger is EnabledFor lvl.
# If you are unfamiliar with logging, the best way to get to see the links on the right.
# The LogRecord has a number of attributes, most of which are combined using msg % args.
# You don’t actually need to format this yourself.
# That indicates if a formatter is set, use it.
# If none of them return a reference to the appropriate logger which is highest in the Formatter has been flushed.
# If name is specified, it names a logger which is used as the effective level of the time the logging call.
# If one returns a true value if the record may be modified in-place by this LogRecord.
# You don’t actually need to exercise some care.
# In general, you should not clash with the current exception information, or None if no exception has occurred, None.
# This allows use of the record into the msg argument to obtain the event doesn’t use the cached value after a formatter is set, use it.
# Logging messages which are combined using msg % args.
# This is useful because the exception information to be specified.
# The value returned is an integer, typically one of them returns a true value if the record is to be used.
# Time in milliseconds when the LogRecord being processed.
# This version does nothing and is intended to be shown in GMT, set the converter attribute in the final output.
# The message attribute of the record will be ignored.
# The logged message, computed as msg % args to create the message for this handler to form.
# Millisecond portion of pathname.
# Handlers have the following table.
# LogRecord instances are used for the module an if these are missing, the message will not emit the same Logger object.
# The message, computed as msg % args to create the message will not care about errors in the following attributes
# The primary information is passed in the logging messagei Human-readable time when the exception occurred.
# Otherwise, the hierarchy is analogous to the record into the msg argument to obtain the event represented.
# The filters are used to pass the extra dictionary with these keys.
# The LogRecord has a number of attributes, most of which are combined using msg % args.
# If one returns a false value, the record and returns a false value, the handler will not be threadsafe.
# Messages are passed directly to the root is reached.
# I had now seen the full moon.
# But he kept fewer secrets than Mr.
# Guest; and he had grown very silent.
# He did no good; his face as he spoke, harsh and broken.
# I could see by his neighbourhood two natures that contended in the doctor's appearance.
# And all the folks asleep--street after street, and all judges of good wine; and Mr. Utterson a sincere and warm.
# The ivory-faced and silvery-haired old woman remained otherwise empty.
# Mr. Hyde at such an enemy to rest!
# Instantly the spirit of enduring hatred.
# He did not like his friend's quarters; and he sat on the court by three dusty windows barred with iron.
# This little spirit of temper was somewhat theatrical to the post, and which has finally severed me from my bed.
# I rushed to the gallows, but the wood was tough and heavy wood.
# Enough, then, that he wiped away,, had broken in the morning, and the locksmith was near despair.
# The scud had banked over the laboratory, where he would play me, scrawling in my soul that it almost rivalled the brightness of hope.
# A maid servant living alone in a moment, like a rat, and run from me?I knew myself, at the high pressure of spirits.
# involved in their Sunday walks, that they should be continuously struggling.
# Next, in the middle of the night was fully come, he set it down to dinner without relish.
# From these embers the inspector exchanged glances.
# On the 12th, and again the panels crashed and the look of him, even at that time, I set it down to follow.
# I knew myself, at the acuteness of the court.
# The steps drew swiftly nearer, and swelled out suddenly louder as they are.
# And then by a sudden splutter of the drug had to deal with in the dismal quarter of London.
# Presently her eye wandered to the building which was equipped with neither bell nor knocker.
# There are three windows was half-way open; and sitting there by the laboratory or the relief of sorrow and suffering.
# How, then, were they agreed; and that it was with a load of genial respectability, and in my cabinet.
# The hatred of Hyde was patent to the dryness of a white colour blistered and distained.
# Bernie's only answer was to die away, it was without bowels of mercy: a face worth seeing: the face of Edward Hyde.
# The hatred of Hyde for Peewee, was of a great student and critic of handwriting, would consider the step natural and obliging?Supposing that I had been in that moment, braced and delighted me like wine.
# As soon as he now sat on one point, were they agreed; and that was my appetite.
# He was ashamed of his strange associates, of the pulse.
# An ivory-faced and silvery-haired old woman remained otherwise empty, Mr. Hyde that racked me.
# And when at last, in order to pacify their too just resentment, Edward Hyde had to bring my mind submerged in terror.
# Small sounds carried far; domestic sounds out of good wine; and Mr. Utterson a sincere and warm affection.
# On his way out, Mr Rogers all night; and if I had of my ordinary manner to a man I so disliked.
# Here I proceeded to examine the contents of the prison-house of my more wakeful moments, my eyes it bore no postmark.
# To this rule, Dr. Peewee had returned six months before, to serve as a bagpipe.
# So far the letter had run composedly enough, but here with a ferocity of accent that testified to his lips.
# His friends were those of his life was still untasted when he spoke, harsh and broken.

# %%
# !python text2sent.py < realDonaldTrump_tweets.csv
# Out:
# Fire or suspend!"
# Thank you!
# Be safe.
# 785863826361184257,2016-10-11 15:25:11,Wow.
# WIN!"
# LETS #MAGA!!
# Move fast Congress!
# @CNN is unwatchable.
# Thank you John.
# (W.H.)

# %%
# !python text2sent.py < realDonaldTrump_tweets.csv
# Out:
# Want approvals."
# Time to change the playbook!"
# Thank you so much.
# @megynkelly- I am in Nevada.
# You will prevail!
# Republican will win S!"
# says Rush Limbaugh.
# $20 billion investment.
# IT WILL CHANGE!!!!"
# ���Lower taxes!

# %% [markdown]
# # Generate Sentences from Textfiles

# %%
from textblob import TextBlob
import random
import sys
import io
filename ="realDonaldTrump_tweets.csv"
with io.open(filename, "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
# stdin's read() method just reads in all of standard input as a string;
# use the decode method to convert to ascii (textblob prefers ascii)
#text = sys.stdin.read().decode('ascii', errors="replace")
blob = TextBlob(essays)

short_sentences = list()
for sentence in blob.sentences:
    if len(sentence.words) <= 10:
        short_sentences.append(sentence.replace("\n", " "))

for item in random.sample(short_sentences, 10):
	print item
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-72-62e8df282189> in <module>()
# ----> 1 from textblob import TextBlob
#       2 import random
#       3 import sys
#       4 import io
#       5 filename ="realDonaldTrump_tweets.csv"
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/__init__.py in <module>()
#       7 PACKAGE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
# ----> 9 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#      10
#      11 __all__ = [
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/blob.py in <module>()
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/__init__.py in <module>()
#     126 ###########################################################
#     127
# --> 128 from nltk.chunk import *
#     129 from nltk.classify import *
#     130 from nltk.inference import *
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/__init__.py in <module>()
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (ChunkScore, accuracy, tagstr2tree, conllstr2tree,
#     159                              conlltags2tree, tree2conlltags, tree2conllstr, tree2conlltags,
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/api.py in <module>()
#      11 ##//////////////////////////////////////////////////////
#      12
# ---> 13 from nltk.parse import ParserI
#      14
#      15 from nltk.chunk.util import ChunkScore
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/__init__.py in <module>()
#      79 from nltk.parse.transitionparser import TransitionParser
#      80 from nltk.parse.bllip import BllipParser
# ---> 81 from nltk.parse.corenlp import CoreNLPParser, CoreNLPDependencyParser
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/corenlp.py in <module>()
#      18
#      19 from nltk.parse.api import ParserI
# ---> 20 from nltk.tokenize.api import TokenizerI
#      21 from nltk.parse.dependencygraph import DependencyGraph
#      22 from nltk.tree import Tree
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/__init__.py in <module>()
#      80 from nltk.tokenize.treebank import TreebankWordTokenizer
#      81 from nltk.tokenize.util     import string_span_tokenize, regexp_span_tokenize
# ---> 82 from nltk.tokenize.stanford_segmenter import StanfordSegmenter
#      83
#      84
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/stanford_segmenter.py in <module>()
#      19 from subprocess import PIPE
#      20
# ---> 21 from nltk import compat
#      22 from nltk.internals import find_jar, find_file, find_dir, \
#      23                            config_java, java, _java_options
#
# ImportError: cannot import name compat

# %% [markdown]
# !ls /home/jack/Desktop/imagebot/*.txt

# %% [markdown]
# # Generate Sentences from Textfiles 'continued'

# %%
from textblob import TextBlob
import random
import sys
import io
filename ="/home/jack/Desktop/imagebot/hekel.txt"
with io.open(filename, "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
# stdin's read() method just reads in all of standard input as a string;
# use the decode method to convert to ascii (textblob prefers ascii)
#text = sys.stdin.read().decode('ascii', errors="replace")
blob = TextBlob(essays)

short_sentences = list()
for sentence in blob.sentences:
    if len(sentence.words) <= 10:
        short_sentences.append(sentence.replace("\n", " "))

for item in random.sample(short_sentences, 10):
	print item
# Out:
# "And you never asked about the--place with the door?"
# I saw him use it, not a week ago."
# "Open the door."
# What has he done?"
# A well-dressed, elderly servant opened the door.
# "With all my heart," said Hillary.
# "This is beyond me,  66)  Poole," said Mr Rogers.
# Utterson sighed.
# What does the man mean?"
# "It was this way.

# %% [markdown]
# # Turn to Instructions

# %%
from textblob import TextBlob
import sys
sys.path.insert(0, "/home/jack/anaconda2/pkgs/nltk-3.2.2-py27_0/lib/python2.7/site-packages/nltk")
from nltk import compat
# Out:
# -----------------------------------------------------------------
# ImportError                     Traceback (most recent call last)
# <ipython-input-81-7e1b3e86e213> in <module>()
# ----> 1 from textblob import TextBlob
#       2 import sys
#       3 sys.path.insert(0, "/home/jack/anaconda2/pkgs/nltk-3.2.2-py27_0/lib/python2.7/site-packages/nltk")
#       4 from nltk import compat
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/__init__.py in <module>()
#       7 PACKAGE_DIR = os.path.dirname(os.path.abspath(__file__))
#       8
# ----> 9 from .blob import TextBlob, Word, Sentence, Blobber, WordList
#      10
#      11 __all__ = [
#
# /home/jack/anaconda2/lib/python2.7/site-packages/textblob/blob.py in <module>()
#      26 from collections import defaultdict
#      27
# ---> 28 import nltk
#      29
#      30 from textblob.decorators import cached_property, requires_nltk_corpus
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/__init__.py in <module>()
#     126 ###########################################################
#     127
# --> 128 from nltk.chunk import *
#     129 from nltk.classify import *
#     130 from nltk.inference import *
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/__init__.py in <module>()
#     155 from nltk.data import load
#     156
# --> 157 from nltk.chunk.api import ChunkParserI
#     158 from nltk.chunk.util import (ChunkScore, accuracy, tagstr2tree, conllstr2tree,
#     159                              conlltags2tree, tree2conlltags, tree2conllstr, tree2conlltags,
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/chunk/api.py in <module>()
#      11 ##//////////////////////////////////////////////////////
#      12
# ---> 13 from nltk.parse import ParserI
#      14
#      15 from nltk.chunk.util import ChunkScore
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/__init__.py in <module>()
#      79 from nltk.parse.transitionparser import TransitionParser
#      80 from nltk.parse.bllip import BllipParser
# ---> 81 from nltk.parse.corenlp import CoreNLPParser, CoreNLPDependencyParser
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/parse/corenlp.py in <module>()
#      18
#      19 from nltk.parse.api import ParserI
# ---> 20 from nltk.tokenize.api import TokenizerI
#      21 from nltk.parse.dependencygraph import DependencyGraph
#      22 from nltk.tree import Tree
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/__init__.py in <module>()
#      80 from nltk.tokenize.treebank import TreebankWordTokenizer
#      81 from nltk.tokenize.util     import string_span_tokenize, regexp_span_tokenize
# ---> 82 from nltk.tokenize.stanford_segmenter import StanfordSegmenter
#      83
#      84
#
# /home/jack/anaconda2/lib/python2.7/site-packages/nltk/tokenize/stanford_segmenter.py in <module>()
#      19 from subprocess import PIPE
#      20
# ---> 21 from nltk import compat
#      22 from nltk.internals import find_jar, find_file, find_dir, \
#      23                            config_java, java, _java_options
#
# ImportError: cannot import name compat

# %%
from textblob import TextBlob
import sys
sys.path.insert(0, "/home/jack/Desktop/jack_watch/nltk-/nltk")
import compat
import random
filename ="realDonaldTrump_tweets.csv"
with io.open(filename, "r", encoding="utf-8") as my_file:
    essays = my_file.read() 

text = sys.stdin.read().decode('ascii', errors="replace")
blob = TextBlob(essays)
noun_phrases = blob.noun_phrases
verbs = list()
for word, tag in blob.tags:
    if tag == 'VB':
        verbs.append(word.lemmatize())
for i in range(1, 11):
    print "Step " + str(i) + ". " + random.choice(verbs).title() + " " + \
        random.choice(noun_phrases)
# Out:
# Step 1. Be u.s.
# Step 2. Trust joint
# Step 3. Be 834917440450609152,2017-02-24 00:06:44
# Step 4. Lead anytime
# Step 5. Be 827480386120929280,2017-02-03 11:34:32
# Step 6. Hurt //t.co/4p0hzpkvwf 762771974657495041,2016-08-08 22:06:25
# Step 7. Be hillary clinton
# Step 8. Be 769002724218118144,2016-08-26 02:45:11
# Step 9. Rebuild 912771708544802823,2017-09-26 20:11:48
# Step 10. Remember thank you

# %%
compat module is part of asyncio, a

# %% [markdown]
# # Best Twitter to Text yet

# %%
from bs4 import BeautifulSoup
import requests
import csv
import codecs

hashtag = raw_input("hashtag") or "angry crowd"
url = u'https://twitter.com/search?l=en&q='+ hashtag +'&src=typd'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
file = codecs.open( "testfile.txt", "a", "utf-8" )
for list in txt:
    mytext = "<br />\n".join(list.split(".\n\n"))
    file.write(mytext)      
    print mytext
file.close()
# Out:
# hashtagupdate

# %% [markdown]
# # -------------------------------------------------------------

# %%
import re
import textwrap

with open("testfile.txt", "r") as f:
    text = f.read()
    #This was added to get ride od the unicode u from showing up
    words = text.replace(' u ', ' ');words = words.replace('u ', '');words = words.replace(' U ', ' ')
    #This clears out the non-Alpha-numeric characters
    #badtext = ''.join(c for c in map(chr, range(256)) if not c.isalnum())
    badtext = '!,",#,$,%,&,(,),*,+,,-,.,/,:;<=>?@[\]^_`{|}~'
    
    # limit the aount of characters perline displayed
    chars_per_line = 110
    for i in range(0, len(words), chars_per_line):
        word = words.translate(None, badtext)
        print words[i:i+chars_per_line]
# Out:
# PLEASE guy, we are talking about many white rapists who leave sweden & uk for become immigrants in south asia
# for purpose of sex traffickingSupporting #stoppingtrafficfilm  2night.. selling/slaving children, women and me
# n is happening every second.. #sextrafficking  has to end!! pic.twitter.com/DwWPzFWm1sAn undercover operation
# aimed at reducing demand for sex trafficking has led to the arrests of nine men - https://buff.ly/2xKkEN4  pi
# c.twitter.com/T3AdgPix7BOur own @HabibaRezwana is one of the @VitalVoices Fellows participating in a 3 week pr
# evention of #sextrafficking fellowship. #Not4Sale pic.twitter.com/ubH8CRoQDlIf @HillaryClinton & @johnpodesta
# are not involved with child sex trafficking, I encourage them to sue me & prove me wrong! Why did Hillary Clin
# ton go to convicted pedophile Jeff Epstein's child sex trafficking island multiple times?If Hillary & Podesta
# wanted to prove they're not sex trafficking kids, all they need to do is explain thecode words. But they refus
# e to. Y?Kudos to Stone for calling out Podesta's child sex trafficking ring! https://twitter.com/nonstopterri/
# status/912955302147850240 …It's worse than we know. Rampant pedophilia, big pharma, child sex trafficking..
# .some truly disturbing & twisted stuff with these elites!Honored to be one of @VitalVoices 2017 GFE Fellows.Th
# e two week program unites 22 women #sextrafficking leaders from 19 countries. #Not4Sale pic.twitter.com/bzsIxt
# MZ5CLooks the DNC is covering up much more than Obama admin illegal spying & HRC emails. Pedophilia? Sex traff
# icking? Terrorism? Prosecute!Shockingly, the state is more than willing to use sex trafficking/rape hysteria a
# s a means of expanding incarceration and its own powerThat's not even getting into how many prostitutes get fu
# cked over because we have extremely harsh laws allegedly to prevent sex traffickingGuys we need everyone's hel
# p we making a video today talking about the sex trafficking in Reno.. let's assemble a team and get these fuck
# pic.twitter.com/NwjoeVSkPe#chatur
# bate #xxx #bbc
#
# porno teens dvd sample
#
# Watch full
# https://goo.gl/3XcC3P#5Xt4
# pic.twitter.com/ymfEF202KGIs
#  it true that Rupert Murdoch cancelled Fox News in the UK because we already have the BBC?#bbc #weightlossjour
# ney #flowers
#
# xlxx hot jailbait fingering
#
# See here
# https://goo.gl/3XcC3P#cq5E
# pic.twitter.com/bRM2xjMCbS#
# fuck #teen #bbc
#
# trinidad girls sex pic xxx porn girl
#
# See here
# https://goo.gl/3XcC3P#nPku
# pic.twitter.com
# /5oelNiNeyf#bigtits #lipstick #bbc
#
# raw sexy pussis gratis en oxnard
#
# See here
# https://goo.gl/3XcC3P#OeA8
#
# pic.twitter.com/pVbJFacPy8If @FoxNews brings back @billoreilly & sticks him back in 8pm slot before 9PM @seanh
# annity, yocan cancel Christmas. #Unbeatable #RealTalkFOX NEWS ALERT: Taliban targets Secretary Mattis in rocke
# t attack on Kabul, Afghanistan airport | @LucasFoxNewspic.twitter.com/WyZTumdbKA.@michellemalkin on Roy Moore
# Winning the Alabama GOP Senate Runoff: "This was a referendum on Mitch McConnell."pic.twitter.com/KYX4f8ybMeHe
# lp is on the way to Puerto Ricopic.twitter.com/dj3hYFJIFZ"Citizens deserve a tax cut in every state."
#
# WATCH:
# @KellyannePolls's full interview on @foxandfriends.pic.twitter.com/NM5BvLdKDm.@KellyannePolls on tax reform: "
# The code currently favors the wealthy and the privileged and the connected."pic.twitter.com/AAQAT4l2uf.@Kellya
# nnePolls on NFL anthem protests: "The president is supporting the flag and everything that it stands for."pic.
# twitter.com/FCws8gcDHwThe NFL teams stayed away from Tim Tebow because he's kneeling was a distraction#He knel
# t to thank GodEveryone wants to know, what happened, this is our country, no more secrets, lets get it out the
# re.Erich Nikischer: "Kneeling is to me, the players saying 'there's a problem, someone else fix it.'" http://f
# xn.ws/2fMy94Z pic.twitter.com/E3Hch84ecwErich Nikischer: "The national anthem and the flag mean a lot to me."
#  http://fxn.ws/2fMy94Z pic.twitter.com/4RvJ9Ux6alNikischer: "After the anthem ended I... took off my security
#  shirt and walked out of the tunnel and quit my job." http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S. Na
# vy Rescues Families in Dominicapic.twitter.com/JuP5o4GJo3TV Ratings: Fox News' Hannity Tops Maddow in 9 O'Cloc
# k Debut // Winning  http://www.hollywoodreporter.com/live-feed/tv-news-fox-news-hannity-tops-maddow-9-oclock-d
# ebut-1043157 …Border Wall Prototype Construction Begins http://fxn.ws/2fQyvb3 pic.twitter.com/72orCb5ev4Fo
# x News Channel to launch new daytime lineup http://bit.ly/2y8jgFb Shep Smith to Fox News viewers: Trump is wr
# ong, NFL players aren’t attacking the flag http://hill.cm/owdmUsk pic.twitter.com/xf0Ds5eV81WATCH: @billore
# illy's return to Fox News — full segment with @seanhannity http://insider.foxnews.com/2017/09/26/bill-oreill
# y-hannity-nfl-protesters-not-thinking-military-kneeling-flag …pic.twitter.com/iuI7PexxxxIs it true that Rup
# ert Murdoch cancelled Fox News in the UK because we already have the BBC?Said by the person who has a trail of
# https://www.amazon.co.uk/gp/bestsellers/digital-text/2967329031/ref=pd_zg_hrsr_kinc_1_5_last#5 …
# pic.twitt
# er.com/xExHqgBIpF#NewRelease ~today September 26th!
# All about LINDISFARNE....
# http://terrytyler59.blogspot.co.
# uk/2017/09/lindisfarne-my-new-book-out-today.html …
# #TuesdayBookBlog #PostApocalyptic #Dystopian #Survivalp
# ic.twitter.com/oSQJQkHtvMA few days late, but that's okay.  LOTS of goodies last week.  Check em out here. #Th
# riller #PostApocalyptic http://briansbookblog.com/new-notable-audiobooks-september-23rd/ … #scifipic.twitte
# r.com/P2W73PGAX6Dawg I still can't get over it. CARDI FUCKING B kick Taylor Swift scunt off the #1 spot. This
# shit is historyHot days, no AC
# Cold days, no heat
# I never loved fall so much
# #postapocalyptic #twitterfiction*
# 99p/99c*
# Sept 24-30 only
# TIPPING POINT
# https://bookgoodies.com/a/B074LSCX5M
# #PostApocalyptic
# #Dystopian
# 'Dis
# turbingly believable'
# Terrific reviews :)pic.twitter.com/CxtNcup3FGOnly 99p/99c: Sept 24-30!
# TIPPING POINT
# htt
# ps://bookgoodies.com/a/B074LSCX5M
# * Year 2024
# *A deadly virus
# #PostApocalyptic
# Excellent reviews! pic.twitte
# r.com/RUjdaNELaVYear 2024
# A deadly virus
# Civilisation's end does not take long...
# TIPPING POINT and LINDISFARN
# E
# #PostApocalyptic
# http://terrytyler59.blogspot.co.uk/2017/08/lindisfarne-coming-soon-postapocalyptic.html �
# �pic.twitter.com/sQl0S8UgUSA dusty chandelier mocks
# the unfinished dinner party
# bone china with rotting canape
# s
# vinegar wine in chipped crystal
# #postapocalypticTIPPING POINT
# 'Disturbingly believable'
# https://bookgoodie
# s.com/a/B074LSCX5M
# When your internet behaviour can mean life or death...
# #PostApocalyptic pic.twitter.com/m
# Bb9jMrhUGJoin me tonight at 7PM for a Supernatural Evening at the Clapp Memorial Library in Belchertown, MA! F
# ree lecture, Q&A, and book signing.Don't forget we have a selection of supernatural themed games for yoto enjo
# y! #supernatural #spnlondon #lazlonpic.twitter.com/KvXczugd7rCelebrating #NationalFitnessDay by admiring Dean
# Winchester… and then realising it’s about exercise. #Supernatural pic.twitter.com/3i6gzPgP8XThe @HealingSc
# hool daily verse:
# There are certain times when yoneed a supernatural move of God. Try a seed offering, which r
# epresents you. pic.twitter.com/x8xYYMmDRsThe belief in a supernatural source of evil is not necessary; men alo
# ne are quite capable of every wickedness #CONRAD #NIETZSCHEWith God, the supernatural is natural and the impos
# sible is possible.Do Not Put Supernatural Resonance In Your Urethra#PEACE- is an unshakable internal and etern
# al supernatural force rather than an external feeling as a result of life's favorable outcome!!This is the sca
# riest season of #AHS because there's nothing supernatural. Just showing the craziness that hides in real peopl
# e. #AHSCultAs the black witch pulls me toward the nest’s dark maw I sense it's the end, but she has other pl
# ans – https://goo.gl/nQPpQ8  #supernatural pic.twitter.com/eBJFvFF7Tb"Supernatural has everything. Life. De
# ath. Ressurection. Redemption. But above all, F A M I L Y ." pic.twitter.com/OPqVzwH8WB#Supernatural QOTD
#
# @S
# .twitter.com/AL2DzSDSclI have 0 respect for liars.Before yopray, believe. Before yospeak, listen. Before yospe
# nd, earn. Before yoquit, try. Before yodie, live."Too ugly"pic.twitter.com/ImYupbWcVtI think a lot, but I don'
# t say much..@MatPatGT takes on the #streamys Dance nominees... also known as, members of the Illuminati?  pic.
# twitter.com/ZiKkqj3LR7Don’t destroy someone,
#
# just because
#
# someone once destroyed you.Respect me. I respect
#  you. Disrespect me, fuck you.Happiness begins with you. Not with your relationship, your friends, or your job
# . but with you.Never put a limit on what yocan do.The “Illuminati” (“Globalists”) are the sworn enemie
# s of #BiblicalChristianity perpetrators & architects of the New World Order (NWO). #USThe quieter yobecome, th
# e more yocan hear.Better things are coming. Keep your head up.Don't stress over things yocan't change.Sometime
# s, change is what we need.I can't live a day without music.Think for yourself. Trust your own intuition. Other
# s aren't walking the same journey that yoare.Don't change to please people. If they can't accept yofor who yoa
# re, yodon't need them in your life.Pain makes people change.Working on myself, by myself, for myself.Sometimes
#  yohave to put
# the clocks back on time
# I wish yoa great day
# Thank yoLarry
# And another thing…
# RespectMany ha
# ve served, fought, sacrificed & died for your right to stand or take a knee! If yorespect the sacrifice, I sup
# port your kneel! pic.twitter.com/TF6Wscx19bHow many of yoHaters Wanna #Support us.!!
# #HrithikVsTiger It's Time
#  to Respect us..
# @iHrithik #HrithikRoshan @iTIGERSHROFF #TigerShroffpic.twitter.com/fNiMFPEzUjB1A4 is after Ba
# ngtan I LOVE THE RESPECT THANK YOU SHOW CHAMPION!even on bad terms, im still gonna respect and be loyal to you
# .How yoclaim people aren't #Jasam fans when yodon't respect Sam or her portrayer?
# #StopIt
# I don't Fux with Fra
# ud-Stars
# #BuhGudNight
# #GHpic.twitter.com/2mBeek7yGyIf yohustle for your own I respect you.Respect #EXO, I'll r
# espect back..
# Bash #EXO , I'll tear yointo pieces ..I don't care if you're a democrat a republican, or anythin
# g in between. We're all Americans and we all should respect each other.Respect me. I respect you. Disrespect m
# e, fuck you.Respect yourself enough to say
# "I deserve peace", and walk away from people or things that prevent
#  yofrom attaining it.If yobeen hurt to the core and yostill believe in love, i respect you.To all my trans fri
# ends I’m so sorry that you’re continuously faced with ignorance, transphobia and fighting for respecti res
# pect a man who is vocal. tell me why you’re into me. tell me why i pissed yooff & tell me how i can fix it.
# tell me everything. talk.Otiende Amollo, I just added yoto the list of lawyers I respect in this country.  Tha
# nk yofor putting Murkomen in his own corner.I don't care about your
# - age
# - weight
# - sexuality
# - height
# -
# gender
# - skin color.
# As long as yorespect me, I'll respect you."I don't hate you. I just lost all respect tow
# ards yoand have nothing to say to yoanymore."I Stand Proudly for the Nation Anthem - Retweet If YoSupport Amer
# ica & Respect the Flag pic.twitter.com/agr62p3vHXF.R.I.E.N.D.S
#
# Fight for you.
# Respect you.
# Include you.
# E
# ncourage you.
# Need you.
# Deserve you.
# Stand by you.

# %%
from textblob import TextBlob
import sys
import random
import io
filename ="testfile.txt"
with io.open(filename, "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    
text = sys.stdin.read().decode('ascii', errors="replace")
blob = TextBlob(essays)

noun_phrases = blob.noun_phrases

verbs = list()
for word, tag in blob.tags:
    if tag == 'VB':
        verbs.append(word.lemmatize())

for i in range(1, 50):
    print "Step " + str(i) + ". " + random.choice(verbs).title() + " " + \
        random.choice(noun_phrases)
# Out:
# Step 1. Believe nameif
# Step 2. Think characters to better convey our thoughts
# Step 3. Prove own intuition
# Step 4. Have labour
# Step 5. Have keep
# Step 6. Have supernatural
# Step 7. Be # martialarts #
# Step 8. Discus pic.twitter.com/dsqw5sopvflunch time
# Step 9. Foresee oea8
# Step 10. Sleeeeepshould ’ s
# Step 11. Be watch
# Step 12. Do 's return
# Step 13. Stop hillary clinton
# Step 14. Do.The ” ~
# Step 15. Do supernatural pic.twitter.com/v6ul3fs2fz #
# Step 16. It.Let meaningless conversations
# Step 17. Do insurtech
# Step 18. Be still
# Step 19. Voice but like next year
# Step 20. Shut truly vulgar
# Step 21. It.Let kulay
# Step 22. Sign thank
# Step 23. Get jvenergy
# Step 24. ” grotesque_music
# Step 25. Disrespect sorry darling ..cheers darling
# Step 26. Have # nohonor
# Step 27. Play trumpjerry
# Step 28. Have murkomen
# Step 29. Believe job #
# Step 30. Believe ’ m
# Step 31. Find thompson reuters charity
# Step 32. Happen.Pic.Twitter.Com/0Pqbwehrbnas song bothers
# Step 33. Remain pb
# Step 34. Justice.. howard cosell
# Step 35. Take incendiary
# Step 36. Tell reuters
# Step 37. Either.I high school
# Step 38. Keep pic.twitter.com/dsqw5sopvflunch time
# Step 39. Teach unarmed person
# Step 40. Have good prepgraywalkers
# Step 41. Stay @ natagood @ internalmentor @ internalcoach @ dannyscheinmann #
# Step 42. Simplify ammunition depot inferno
# Step 43. Philosopher conservative speech counts
# Step 44. Disband september
# Step 45. Limit youtubepic.twitter.com/ckyvd6q4tiif
# Step 46. Be child sex
# Step 47. Feel id=100015178621547 …pic.twitter.com/y6owisgz8rconspiracy theory
# Step 48. Respect dominicapic.twitter.com/jup5o4gjo3tv ratings
# Step 49. Try f*cked up

# %%
from bs4 import BeautifulSoup
import requests
url = u'https://twitter.com/search?q='
#query = u'%40drawranliou'
#query = u'@JamesOKeefeIII'
#query = u'hurricanne&src=typd'
query = u'very confused'
r = requests.get(url+query)
soup = BeautifulSoup(r.text, 'html.parser')
tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)

for list in txt:
    mytext = "<br />\n".join(list.split("\n\n"))
    
    print mytext
# Out:
# what kinda fuckin mental gymnastics<br />
# like i'm not even upset, just very, VERY confused
# I was very confused for a moment
# That's it, very confused but for your info I have a girlfriend called @brittcooper_x
# Wait a second was this gift not given to everyone I'm very confused am I special?? Is this more than 140 characters?! I actually can't tell like did they get rid of the word count because all I see is a circle and this tweet looks a lot longer than my others ok wow I feel cool af
# If you, like me, were confused about the part on Marvel Legacy showing a very... specific Wakanda, just head back to Secret War’s last issue pic.twitter.com/E34ZaCRjJN
# Don't be confused, I'm actually very sad lol
# "how dare you express yourself freely in the presence of a symbol of free expression." - a lot of very confused people.
# feeling lonely and lost and confused .. very very confused
# Karylle, stahp it. Vice will be very confused. And so do I  pic.twitter.com/oYaXbT4Ljt
# I understand that it's a very confusing time in the country right now. It really is. But I don't think anybody is as confused as COSATU.
# Very Diana and Harley reactions, respectively confused by humans and creepily laughing in murder https://twitter.com/wonderx_jo/status/912656951208824834 …
# BAKIT TAYO NAKA ALL CAPS?? haha pero di nga, I was really lost and confused
# The very first day of #tarak shoot  was still confused with the chracter and my look pic.twitter.com/6rlNMOBkaN
# Sa totoo lang confused ako ng very light sa freckles at warts. Dont hate me please. Hahahahahahahaha
# Disembodied voice tells Tsukasa it's ok to dye the loli with his own colors. Tsukasa is very confused.
# #dothackSignpic.twitter.com/vu77RIONKr
# Very confused on how I came back from a book festival and my own book didn't write itself while I was away, what the hell
# ndi naman ako umasa ng bongga eh very very light lng naman
# May pasok ba talaga bukas?? I'm very confused. Hahaha
# Is saying “son of a bitch” in front of the flag respecting the flag?<br />
# I’M CONFUSED. I’m VERY confused.
# My family is a very confused Catholic. Ang ulam ngayong Biernes ay monggo na may sahog na baboy.

# %%
from textblob import TextBlob
import random
import sys
import io
with io.open("testfile.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
blob = TextBlob(essays)
for sentence in blob.sentences:
    print sentence
    short_sentences = list()
    for sentence in blob.sentences:
        if len(sentence.words) <= 5:
            short_sentences.append(sentence.replace("\n", " "))

    for item in random.sample(short_sentences, 10):
        print item
# Out:
# PLEASE guy, we are talking about many white rapists who leave sweden & uk for become immigrants in south asia for purpose of sex traffickingSupporting #stoppingtrafficfilm  2night.. selling/slaving children, women and men is happening every second.. #sextrafficking  has to end!!
# Our students are so excited!
# Come On Witches!!
# Postapocalyptic Russian.
# I believe in peaceful protest.
# Deserve you.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# It wouldn't be pretty.
# "I don't hate you.
# WHO'D HAVE THUNK IT?!
# .
# pic.twitter.com/DwWPzFWm1sAn undercover operation aimed at reducing demand for sex trafficking has led to the arrests of nine men - https://buff.ly/2xKkEN4  pic.twitter.com/T3AdgPix7BOur own @HabibaRezwana is one of the @VitalVoices Fellows participating in a 3 week prevention of #sextrafficking fellowship.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# You are massive!!
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# Death.
# Postapocalyptic Russian.
# Laughed at surprise emoji.
# BTW...she has!
# Absolutely marvellous.
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Respect you.
# #Not4Sale pic.twitter.com/ubH8CRoQDlIf @HillaryClinton & @johnpodesta are not involved with child sex trafficking, I encourage them to sue me & prove me wrong!
# Clicked.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Territory - over 1000 hectares.
# tell me everything.
# A.D.
# Deserve you.
# .
# Security lacks.
# Absolutely marvellous.
# .
# Why did Hillary Clinton go to convicted pedophile Jeff Epstein's child sex trafficking island multiple times?If Hillary & Podesta wanted to prove they're not sex trafficking kids, all they need to do is explain thecode words.
# It wouldn't be pretty.
# Need you.
# Laughed at surprise emoji.
# I am independent!
# He's a terrible person.
://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# A very huge congratulations!!
# Encourage you.
# pic.twitter.com/JrWYrelea7.
# on the set of 'Broken.'
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# !Sex Trafficking must stop our women are too valuable .
# IDK.
# BTW...she has!
# pic.twitter.com/JrWYrelea7.
# #nohonor.
# Need you.
# Include you.
# I believe in peaceful protest.
# on the set of 'Broken.'
# Ressurection.
# I respect you.
# Sex Traffickers must be put to death Min @LouisFarrakhan #Farrakhan #justiceorelse pic.twitter.com/QK2tsKrZONShe Was Raped 43,200 Times And Now Fights For Sex Trafficking Victims
#
# http://www.fastviralnews.info/fuKQ5 Sex trafficking is at an all time high in Reno right now.
# A very huge congratulations!!
# CHEERS Marvelous Gents!!!
# Come On Witches!!
# Before you speak, listen.
# sho.
# CONSPIRACY!"
# Before you die, live.
# The Ukrainian govt.
# Death.
# "I DIDN'T GET INVITED!
# So everyone please please be aware of your surroundings and be safe!
# Absolutely marvelous.
# Photos by Reuters.
# I love you, Isabelle.
# WHO'D HAVE THUNK IT?!
# A very huge congratulations!!
# Stand by you.
# Pedophilia?
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# The vampires.
# pic.twitter.com/JrWYrelea7.
# Hey, @morningmika, why single out Hillary Clinton re: Puerto Rico?
# Our students are so excited!
# Before you speak, listen.
# BTW...she has!
# @morningmikaWTF!
# The Ukrainian govt.
# Check em out here.
# 200 km away.
# Ressurection.
# But they refuse to.
# OK girl.
# Is she the only person who could do something?
# Include you.
# A.D.
# You get attacked2/2 country.
# The Ukrainian govt.
# Time to go!
# Hillary Clinton is back.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# sho.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Look at her now!
# BTW...she has!
# sho.
# Territory - over 1000 hectares.
# I respect you.
# Same as everyone else.
# The Ukrainian govt.
# Pathetic really.Nadia on Jools Holland.
# Before you speak, listen.
# You get attacked2/2 country.
# OK girl.
# "I DIDN'T GET INVITED!
# #morningjoe#morningjoe HEY MIKA JUST A REMINDER HILLARY CLINTON IS NOT THE PRESIDENT.
# A.D.
# Postapocalyptic Russian.
# Hideous gay ogres.
# Clicked.
# Sex trafficking?
# Our students are so excited!
# Before you quit, try.
# Bernadette Semple is SIMPLE-minded.
# Now and forever.
# Thank You!
# SHE IS A CITIZEN LIKE U- SO U CAN GO TO PUERTO TOO!
# Thank You!
# But they refuse to.
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Which would it be?
# It wouldn't be pretty.
# Territory - over 1000 hectares.
# Check em out here.
# Pls rtStay for breakfast.
# Cause unknown; likely sabotage.
# Need you.
# @morningmikaWTF!
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Got exited.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Pedophilia?
# Before you speak, listen.
# You are massive!!
# "I don't hate you.
# .
# .
# #Castiel from #Supernatural again.
# @morningmika Just criticized @HillaryClinton saying she should do more to help situation in PR?!
# Nor for him.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# Sex trafficking?
# The Ukrainian govt.
# Postapocalyptic Russian.
# Pls rtStay for breakfast.
# The Ukrainian govt.
# tell me everything.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Death.
# Suggested book tour stop there?
# And no serious media coverage!
# @KingJames @StephenCurry30 @Kaepernick7.
# The vampires.
# pic.twitter.com/JrWYrelea7.
# Sex trafficking?
# BTW...she has!
# The Ukrainian govt.
# Photos by Reuters.
# Laughed at surprise emoji.
# You get attacked2/2 country.
# !“The constitutional crisis no one is talking about — except Hillary Clinton” by Adam M. Lowenstein https://medium.com/@adamlowenstein/the-constitutional-crisis-no-one-is-talking-about-except-hillary-clinton-c4b21fa901db …Mika really just said that @HillaryClinton should take her book tour to Puerto Rico.
# He's a terrible person.
# Come On Witches!!
# Terrorism?
# Before you speak, listen.
# IDK.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Before you quit, try.
# Deserve you.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# WHO'D HAVE THUNK IT?!
# That's the dumbest thing I've heard today.
# Pathetic really.Nadia on Jools Holland.
# Come On Witches!!
# A.D.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# Respect you.
# I love you, Isabelle.
# Absolutely marvellous.
# However- if the shoe fits.
# Encourage you.
# on the set of 'Broken.'
# #morningjoePsychiatrist calls Hillary Clinton a sociopath & pathological liar..<br />
# https://youtu.be/se8AvsaZdlY pic.twitter.com/gTC2FdwYQ8The 2X Loser @hillaryclinton is on every talk show PREACHING the STALE "Racism" rhetoric & the @NFL & #hollyweird fell for it!
# Include you.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Cause unknown; likely sabotage.
# Look at her now!
# Same as everyone else.
# Postapocalyptic Russian.
# .
# Before you speak, listen.
# on the set of 'Broken.'
# #nohonor.
# #Stooges Here: your fake picture taken before #NationalAnthem began & screen change 5th debate on #CNN it's on YouTubepic.twitter.com/CKyVd6Q4TiIf @HillaryClinton & @johnpodesta are not involved with child sex trafficking, I encourage them to sue me & prove me wrong!
# Include you.
# Photos by Reuters.
# Pedophilia?
# Check em out here.
# I am independent!
# CHEERS Marvelous Gents!!!
# CONSPIRACY!"
# Which would it be?
# Come On Witches!!
# Terrorism?
# Hillary Clinton is back.
# He's so... pompous.
# sho.
# CONSPIRACY!"
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Deserve you.
# This is HORRIBLE!
# "I don't hate you.
# Got exited.
# Check em out here.
# #Castiel from #Supernatural again.
# http://bit.ly/2wTNJmO If @realDonaldTrump had Sec.
# CONSPIRACY!"
# It wouldn't be pretty.
# Nor for him.
# OK girl.
# This is HORRIBLE!
# Stand by you.
# IDK.
# Cause unknown; likely sabotage.
# Hideous gay ogres.
# A very huge congratulations!!
# @HillaryClinton’s integrity, intellect, and stamina, we’d be better off.
# BTW...she has!
# Hideous gay ogres.
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# Postapocalyptic Russian.
# on the set of 'Broken.'
# Photos by Reuters.
# Pathetic really.Nadia on Jools Holland.
# Deserve you.
# Absolutely marvelous.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Alas, he’s an amoral, ignorant lummox.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# sho.
# "Classrooms are now propaganda vehicles.
# I respect you.
# However- if the shoe fits.
# Hideous gay ogres.
# Include you.
# #nohonor.
# Our students are so excited!
# pic.twitter.com/mmpRSm8UXnHillary Clinton: I'm not sure Trump knows Puerto Ricans are Americans http://huffp.st/JqZdNAj pic.twitter.com/FV9KPK9aYYBut truly of the 4 people on the ballot in Nov half were Russian plants and 2 had the IQ of a baked potato.
# CONSPIRACY!"
# I respect you.
# Hideous gay ogres.
# Before you speak, listen.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# No way, Jose!
# Terrorism?
# I love you, Isabelle.
# Time to go!
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# The other was @HillaryClinton@HillaryClinton should shut the hell up & give back the $2B she stole from the Haitians & help both
# #PuertoRicoRelief & Haiti.pic.twitter.com/2lb5TdkQeM@HillaryClinton So far you've been responsible for more deaths...for example...Benghazi.Or if @HillaryClinton had been allowed to take her rightful place as president and then deleted even so much as one tweet.Hillary Clinton supported PROMESA, which allowed Wall Street to take over Puerto Rico.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Which would it be?
# WHO'D HAVE THUNK IT?!
# Look at her now!
# Absolutely marvelous.
# He's so... pompous.
# The vampires.
# Laughed at surprise emoji.
# Ressurection.
# Our students are so excited!
# Bernie Sanders opposed it http://money.cnn.com/2016/05/20/news/economy/puerto-rico-hillary-clinton/index.html …pic.twitter.com/zpO2mOr7bJIf @HillaryClinton were President we wouldn't be talking about the NFL.
# Suggested book tour stop there?
# I am independent!
# Respect you.
# #InvestigateStart by RESPECTING all citizens.
# Territory - over 1000 hectares.
# The vampires.
# And no serious media coverage!
# CONSPIRACY!"
# WHO'D HAVE THUNK IT?!
# Which would it be?
# people of PR would be receiving supplies & #ACA would be improved.Mr.
# Bernadette Semple is SIMPLE-minded.
# sho.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# A.D.
# Pls rtStay for breakfast.
# And no serious media coverage!
# A very huge congratulations!!
# Redemption.
# BTW...she has!
# Security lacks.
# @POTUS Don't Let The #HATERSOf #USAGet To You@KingJames@StephenCurry30 @WhoopiGoldberg@HillaryClinton
# @BarackObama#LOSERSpic.twitter.com/6FsWdd3IkJAnnette Taddeo, who flipped a district tonight in FL, was, like hillary clinton, a victim of Russia hacking in ’16 http://www.huffingtonpost.com/entry/democrats-2016-campaign-hacking-annette-taddeo_us_59af02f0e4b0b5e53101acf1 …Reuters poll: Majorities say athletes should be req'd to stand for anthem, oppose Kaepernick.
# Postapocalyptic Russian.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Come On Witches!!
# @morningmikaWTF!
# The Ukrainian govt.
# Photos by Reuters.
# Bernadette Semple is SIMPLE-minded.
# "Classrooms are now propaganda vehicles.
# Time to go!
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Reuters leads w/ opposition to Trump overreachToo late.
# Same as everyone else.
# Well done!!
# Sex trafficking?
# Look at her now!
# Terrorism?
# BTW...she has!
# Absolutely marvellous.
# A.D.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# @realDonaldTrump mishandled the disaster in PR from the outset.
# Before you spend, earn.
# And no serious media coverage!
# He's a terrible person.
# No way, Jose!
# Before you quit, try.
# 200 km away.
# Laughed at surprise emoji.
# I am independent!
# Well done!!
# Now and forever.
# He's just crap in an emergency setting.The teacher Mesut Kaçmaz family was kidnapped by passing a sack per Pakistan
# @Reuters @WSJ
# #FreedomToKacmazFamilypic.twitter.com/t9TmRCQez3.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# CONSPIRACY!"
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Security lacks.
# Photos by Reuters.
# I believe in peaceful protest.
# Suggested book tour stop there?
# The vampires.
# The Ukrainian govt.
# @gannemans #5yrsEvin for Thompson Reuters Charity Official #FreeNazanin .
# #Castiel from #Supernatural again.
# Death.
# 200 km away.
# Well done!!
# Nor for him.
# Who benefitted?
# I respect you.
# Cause unknown; likely sabotage.
# Which would it be?
# #nohonor.
# Pls sign & share http://www.FreeNazanin.com pic.twitter.com/AO9VPnJbzjOnly 3 #UK #Universities in the 100 most #innovative, according to #Reuters Come on UK #CII #Insurtech #Tech https://reut.rs/2y88BKH pic.twitter.com/xbyvYxwr4HFresh images from Kalynivka, #Ukraine, where an ammo store has exploded.
# Trust your own intuition.
# The Ukrainian govt.
# "I DIDN'T GET INVITED!
# BTW...she has!
# WHO'D HAVE THUNK IT?!
# Territory - over 1000 hectares.
# Respect you.
# Cause unknown; likely sabotage.
# Hillary Clinton is back.
# I respect you.
# Photos by Reuters.
# Encourage you.
# Postapocalyptic Russian.
# But they refuse to.
# Deserve you.
# Life.
# Love Ya Both!!!
# IDK.
# sho.
# Cause unknown; likely sabotage.
# Terrorism?
# http://ow.ly/um2230fsgmB pic.twitter.com/XMO6YoadA3Khalid bin Salman #Saudi Ambassador to  #US says women won't need permission to get a driving license- Reuters https://www.reuters.com/article/us-saudi-women-driving-envoy/saudi-ambassador-to-u-s-says-his-society-is-ready-to-let-women-drive-idUSKCN1C12ZB …pic.twitter.com/i5cFfUODmhICC judges have ordered former Ivory Coast President Laurent Gbagbo to remain in detention during his trial: Reuters #NBSUpdatespic.twitter.com/7GtITRkbOXA military ammunition depot in central #Ukraine exploded, forcing 24,000 people to evacuate, @Reuters reported http://social.stratfor.com/Fppm30fsdAP pic.twitter.com/jS7vWBQhP6Get well soon you're the best @IamStevenT @AerosmithKidnapping in Pakistan..
# A Turkish teacher and his family kidnapped
# #FreedomToKacmazFamily
# @geopakistantv
# @cnnbrk
# @dailypakistangl
# @ReutersLondon gold dealer Sharps Pixley to accept payment in #bitcoin https://nyti.ms/2jZBdzi  via @nytimes @reutersToday at 2:00 pm SGT: Reuters Asia Commodities & Energy Columnist @ClydeCommods will be #FacebookLive with oil industry experts at #APPECpic.twitter.com/dQAxN6Ej7YDid it for Irma & Harvey.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# IDK.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Got exited.
# Look at her now!
# I love you, Isabelle.
# The Ukrainian govt.
# Before you speak, listen.
# Our students are so excited!
# Before you spend, earn.
# U.S. denies request for Puerto Rico shipping waiver | Article [AMP] | Reuters https://buff.ly/2fyp2bw pic.twitter.com/jCVFppiAnjReuters/Ipsos poll:
#
# 58% say athletes should be required to stand during National Anthem
#
# 33% disagree
#
# 9% don’t know22mil acres of #wildhorse legal herdareas have disappeared.
# @morningmikaWTF!
# .
# The Ukrainian govt.
# I love you, Isabelle.
# Cause unknown; likely sabotage.
# Need you.
# I respect you.
# Security lacks.
# A.D.
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# Who benefitted?
# Photos by Reuters.
# Photos by Reuters.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# However- if the shoe fits.
# Postapocalyptic Russian.
# Include you.
# Suggested book tour stop there?
# pic.twitter.com/JrWYrelea7.
# I believe in peaceful protest.
# I love you, Isabelle.
# @SenateApprops @rollcall @Reuters @APpic.twitter.com/T1RJTEHCSU#Zarif's trip against #HumanRights, democracy & peace in #Iran
# #AFP #AP #Reuters #Bloomberg #NYTimes #NewYork #WPost #BBC #CNNpic.twitter.com/f92xeqdidxBig news, via Reuters: SAUDI KING ISSUES DECREE ALLOWING WOMEN TO DRIVE - AL ARABIYA TV#BREAKING: Kurdish leader Barzani says 'yes' vote won in Kurdistan independence referendum (Reuters) This photo taken near Kalynivka shows explosions at a military munitions depot.
# LOTS of goodies last week.
# Nor for him.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# on the set of 'Broken.'
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Respect you.
# CHEERS Marvelous Gents!!!
# Ressurection.
# Before you die, live.
# You are massive!!
# Sergei Supinsky pic.twitter.com/eX12Z45869#Ukraine's #security service @ServiceSsu  said that the fire at army arms depot in Kalynivka, #Vinnytsia region, was an act of sabotage:Huge explosion at ammunition storage in #Kalynivka, #Vinnytsia region #Ukraine pic.twitter.com/1FoQcWdiiC https://twitter.com/112NewsFeed/status/912867979901186049 …Huge amm.depot explosions in #Kalynivka, central UA, could be heard in Kyiv, ab.
# BTW...she has!
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# He's so... pompous.
# Encourage you.
# CHEERS Marvelous Gents!!!
# .
# Pathetic really.Nadia on Jools Holland.
# A very huge congratulations!!
# .
# Before you die, live.
# 200 km away.
# You are massive!!
# "Classrooms are now propaganda vehicles.
# Before you speak, listen.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Love Ya Both!!!
# And no serious media coverage!
# Absolutely marvelous.
# on the set of 'Broken.'
# Pathetic really.Nadia on Jools Holland.
# Before you spend, earn.
# Security lacks.
# However- if the shoe fits.
# No way, Jose!
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Need you.
# Respect you.
# Terrorism?
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Get in there!!
# #Castiel from #Supernatural again.
# 200 km away.
# https://www.youtube.com/watch?v=VAeRKqurmJQ …Fresh images from Kalynivka, #Ukraine, where an ammo store has exploded.
# It wouldn't be pretty.
# Before you spend, earn.
# .
# "Classrooms are now propaganda vehicles.
# Photos by Reuters.
# LOTS of goodies last week.
# Our students are so excited!
# Redemption.
# Pedophilia?
# He's so... pompous.
# Photos by Reuters.
# Check em out here.
# Our students are so excited!
# BTW...she has!
# 200 km away.
# The Ukrainian govt.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Before you spend, earn.
# @KingJames @StephenCurry30 @Kaepernick7.
# Time to go!
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# http://ow.ly/um2230fsgmB pic.twitter.com/XMO6YoadA3Intensity of blasts at military depots in Kalynivka has decreased.
# Include you.
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# Same as everyone else.
# #nohonor.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# He's a terrible person.
# .
# Absolutely marvelous.
# 200 km away.
# I believe in peaceful protest.
# Hotline +38 043-332-13-35. pic.twitter.com/Sua9sgNUAB#Kalynivka this morning where the ammunition depot inferno is far from over.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Photos by Reuters.
# Our students are so excited!
# Pls rtStay for breakfast.
# Ressurection.
# #InvestigateStart by RESPECTING all citizens.
# However- if the shoe fits.
# I believe in peaceful protest.
# Look at her now!
# Nor for him.
# The Ukrainian govt.
# Clicked.
# Sex trafficking?
# I love you, Isabelle.
# I respect you.
# Which would it be?
# Absolutely marvellous.
# Come On Witches!!
# Redemption.
# Before you speak, listen.
# Got exited.
# blames "external factors" for the blasts.
# A very huge congratulations!!
# Before you quit, try.
# Time to go!
# Before you speak, listen.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# .
# OK girl.
# I believe in peaceful protest.
# Thank You!
# .
# pic.twitter.com/64claaBHnFVIDEO: Massive explosion at Kalynivka arms depot this morning #Ukraine - @krymrealiipic.twitter.com/qYnzRH7ZDoRuble is falling amid reports on sabotage explosion in Kalynivka arms depot.
# Who benefitted?
# 200 km away.
# pic.twitter.com/JrWYrelea7.
# Love Ya Both!!!
# However- if the shoe fits.
# I love you, Isabelle.
# Terrorism?
# Suggested book tour stop there?
# Absolutely marvelous.
# Redemption.
# Ukraine PM says "external factors" USD/RUBVideo of HUGE blast at #Kalynivka arms depot this morning: https://twitter.com/krymrealii/status/912939103263522817 …Fire-control measures are taken at ammo depot in Kalynivka, Vinnytsya oblast.
# Well done!!
# Ressurection.
# Clicked.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# "I don't hate you.
# Our students are so excited!
# Before you quit, try.
# This is HORRIBLE!
# Get in there!!
# Laughed at surprise emoji.
# The fire surface is about 10% of the total facility surface.In Kalynivka, Vinnytsya region,  ammunition depots in flames, 30 thousand residents evacuated.
# I am independent!
# Now and forever.
# Who benefitted?
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Stand by you.
# Clicked.
# Redemption.
# Terrorism?
# Come On Witches!!
# WHO'D HAVE THUNK IT?!
# Air traffic closed within a 50 km radius.Good news: no human casualties reported after explosion in #Kalynivka.
# Pedophilia?
# Clicked.
# Before you die, live.
# I respect you.
# Deserve you.
# But they refuse to.
# "I DIDN'T GET INVITED!
# Nor for him.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# Look at her now!
# Bad news: indirect damage will be much worse than mere munition lossUkrainian railways company changed routes of their trains to avoid Kalynivka explosions  pic.twitter.com/lhhfGYu2on https://liveuamap.com/en/2017/26-september-ukrainian-railways-company-changed-routes-of …#Kalynivka is #Ukraine's biggest ammunition depot.
# I am independent!
# Bernadette Semple is SIMPLE-minded.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Postapocalyptic Russian.
# Pathetic really.Nadia on Jools Holland.
# on the set of 'Broken.'
# @KingJames @StephenCurry30 @Kaepernick7.
# I believe in peaceful protest.
# Before you spend, earn.
# Our students are so excited!
# Territory - over 1000 hectares.
# Who benefitted?
# BTW...she has!
# Terrorism?
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Love Ya Both!!!
# Clicked.
# on the set of 'Broken.'
# I respect you.
# Stand by you.
# Laughed at surprise emoji.
# Ammunition loses for the armed forces will be huge #Vinnytsia: view on ammunition storages burning in #Kalynivka https://www.youtube.com/watch?v=wZGlnqyC2lY&feature=youtu.be …Ukrainian munitions depot #Kalynivka explodes near Vinnytsia, 250km SW of Kyiv.
# Redemption.
# Pedophilia?
# IDK.
# BTW...she has!
# Love Ya Both!!!
# No amount is too small!
# Before you quit, try.
# Need you.
# Life.
# Look at her now!
# Cause unknown; likely sabotage.
# But they refuse to.
# A very huge congratulations!!
# Redemption.
# I respect you.
# Absolutely marvelous.
# Pls rtStay for breakfast.
# Same as everyone else.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Need you.
# However- if the shoe fits.
# Citizens evaluated#Ukraine's largest ammunition depot in #Kalynivka is on fire tonight.
# A.D.
# #Castiel from #Supernatural again.
# Bernadette Semple is SIMPLE-minded.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# .
# Sex trafficking?
# "I DIDN'T GET INVITED!
# Pedophilia?
# But they refuse to.
# Hideous gay ogres.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# "Classrooms are now propaganda vehicles.
# Redemption.
# Include you.
# Encourage you.
# I believe in peaceful protest.
# Need you.
# on the set of 'Broken.'
# Check em out here.
# Ressurection.
# Love Ya Both!!!
# Live stream 6 km from the ammo depot which is on fire since 10 pm https://youtu.be/R59Cys1hyYA Arsenal in Kalynivka is one of the Ukraine's biggest.
# Photos by Reuters.
# Bernadette Semple is SIMPLE-minded.
# It wouldn't be pretty.
# #Castiel from #Supernatural again.
# Hideous gay ogres.
# No way, Jose!
# However- if the shoe fits.
# Before you quit, try.
# Need you.
# Cause unknown; likely sabotage.
# About 200Kt of GRAD/Uragan/Smerch missiles & another artillery pic.twitter.com/04tCAMmnOfMassive explosion at military ammunition depot in Ukraine sparks evacuation and claims of Russian sabotage https://www.thesun.co.uk/news/4557710/ukraine-ammunition-depot-explosion-russian-sabotage-claims/ …A huge fire at an ammunition depot in Ukraine has set off a series of explosions and prompted an evacuation of thousands of people pic.twitter.com/yuCZ8mHaKsMass evacuation due to fire at ammunition depot in Vinnytsya Oblast (UPDATED) | KyivPost https://buff.ly/2xFgaXK pic.twitter.com/sJyyM4FvSzWATCH: Thousands evacuated in Ukraine as ammunition depot explodes http://reut.rs/2fPYYW8  via @ReutersTVpic.twitter.com/xJFAghYolJAmmunition depot explodes in Ukraine amid claims it was a 'gift' from Putin
# http://www.mirror.co.uk/news/world-news/ammunition-depot-explodes-central-ukraine-11243790 …pic.twitter.com/rw1jbbYUCoUkrainian ammunition depot struck by fire  http://latestnewseuropeuu.blogspot.ro/2017/09/ukrainian-ammunition-depot-struck-by.html …pic.twitter.com/PWbJL27kfw#Kalynivka this morning where the ammunition depot inferno is far from over.
# tell me everything.
# Thank You!
# .
# Ressurection.
# I respect you.
# I believe in peaceful protest.
# IDK.
# It wouldn't be pretty.
# Pedophilia?
# However- if the shoe fits.
# The Ukrainian govt.
# Death.
# "I DIDN'T GET INVITED!
# Postapocalyptic Russian.
# @morningmikaWTF!
# Who benefitted?
# Come On Witches!!
# A very huge congratulations!!
# Same as everyone else.
# Redemption.
# The Ukrainian govt.
# blames "external factors" for the blasts.
# Same as everyone else.
# .
# .
# tell me everything.
# He's so... pompous.
# Laughed at surprise emoji.
# CONSPIRACY!"
# Include you.
# WHO'D HAVE THUNK IT?!
# However- if the shoe fits.
# pic.twitter.com/64claaBHnFHuge explosion and fire at military ammunition depot in central Ukraine forces evacuation of 24,000 people http://www.itv.com/news/2017-09-27/explosion-at-ukraine-ammunition-depot/ …pic.twitter.com/G8fJ0pCbT624,000 evacuated after massive explosion at Ukrainian ammunition depot http://read.bi/2fQyrrS pic.twitter.com/W9SPyzGSx1A military ammunition depot in central #Ukraine exploded, forcing 24,000 people to evacuate, @Reuters reported http://social.stratfor.com/Fppm30fsdAP pic.twitter.com/jS7vWBQhP6Dear NFL....You are dead to me, i'll watch college...and if they pull this crap in college, i'll watch hockey....i'm done!!
# Include you.
# Deserve you.
# BTW...she has!
# Clicked.
# Hideous gay ogres.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# I am independent!
# The vampires.
# Terrorism?
# Now and forever.
# !We feel you DaddyFormer President Obama says dropping his daughter Malia off at college was "a little bit like open-heart surgery" http://cnn.it/2wU6CsV pic.twitter.com/0sDImsLnS4A plea for food and water is written on the pavement in a neighborhood in Punto Santiago, Puerto Rico, after Maria http://cnn.it/2y7Lik7 pic.twitter.com/h61Cp5oUACHere are the tweets Trump apparently deleted after the candidate he supported lost in the Alabama special election http://cnn.it/2y90vl0 pic.twitter.com/ivB7LRg8MK#WednesdayWisdom
#
# Daily dose of #Liberalism:
#
# CNN getting sued by 175 black employees while accusing Trump of racism
# #WednesdayWisdomThe IRS is now sharing info about key Trump campaign officials with special counsel Robert Mueller http://cnn.it/2yt5xos pic.twitter.com/DQRffloggjIRONY: CNN Calls Trump Racist While Getting Sued By 175 Black Employees For Discrimination https://bluntforcetruth.com/irony-cnn-calls-trump-racist-while-getting-sued-by-175-black-employees-for-discrimination/ …pic.twitter.com/k35QYcgZIcNew CNN poll: Large majorities oppose Trump's major immigration policies:
#
# http://www.cnn.com/2017/09/27/politics/cnn-poll-immigration-taxes/index.html?adkey=bn …pic.twitter.com/528QaKA929.
# The Ukrainian govt.
# Before you speak, listen.
# Before you die, live.
# tell me everything.
# This is HORRIBLE!
# He's a terrible person.
# However- if the shoe fits.
# Security lacks.
# #Castiel from #Supernatural again.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# @maddow BOMBSHELL:FB notified FBI of Russian espionage TWICE yet Zuckerberg "DIDN'T KNOW"
# #TheResistance #CNN #MSNBCpic.twitter.com/zWsgBFnflYTOP 2 BOYCOTTS
# By Trump Supporters
# *CNN very fake news.
# This is HORRIBLE!
# A.D.
# Time to go!
# Our students are so excited!
# @KingJames @StephenCurry30 @Kaepernick7.
# pic.twitter.com/JrWYrelea7.
# But they refuse to.
# Sex trafficking?
# #Castiel from #Supernatural again.
# Redemption.
# *NFL encourages players to disrespect our flag.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Pathetic really.Nadia on Jools Holland.
# I am independent!
# Before you quit, try.
# Need you.
# CHEERS Marvelous Gents!!!
# .
# Trust your own intuition.
# No amount is too small!
# pic.twitter.com/nTHCL4E6hsHere: your fake picture taken before #NationalAnthem began & screen change 5th debate on #CNN it's on YouTube pic.twitter.com/CKyVd6Q4TiTwitter is changing its character limit for the first time ever, doubling the count to #280characters for some users http://cnn.it/2xAH5Cw pic.twitter.com/ODmPPCsX0vNot all heroes wear capes.
# I love you, Isabelle.
# Need you.
# A.D.
# Laughed at surprise emoji.
# Absolutely marvelous.
# Bernadette Semple is SIMPLE-minded.
# He's a terrible person.
# Which would it be?
# "I don't hate you.
# Got exited.
# This one was a suited-up groom who jumped into a lake to save a drowning child http://cnn.it/2fQkNop pic.twitter.com/NzuN4goPKkCoca-Cola donates an additional $4.3M in the wake of Hurricane Maria and Mexico quakes, tripling its contribution http://cnn.it/2wTkJir pic.twitter.com/j7plgBHneTSouth Korea's President Moon Jae-in is the son of North Korean refugees.
# I love you, Isabelle.
# Cause unknown; likely sabotage.
# A.D.
# He's so... pompous.
# Before you die, live.
# .
# Life.
# "I don't hate you.
# Check em out here.
# WHO'D HAVE THUNK IT?!
# Here, he tells their story http://cnn.it/2hv8Jwt pic.twitter.com/stRZEgILSpHospitals bombed, civilians massacred in N. Syria!
# Postapocalyptic Russian.
# Before you spend, earn.
# Cause unknown; likely sabotage.
# Which would it be?
# Before you die, live.
# The Ukrainian govt.
# .
# .
# He's a terrible person.
# Same as everyone else.
# And no serious media coverage!
# OK girl.
# Ressurection.
# Get in there!!
# Who benefitted?
# Hillary Clinton is back.
# The vampires.
# 200 km away.
# I respect you.
# Time to go!
# Include you.
# Yo @CNN @BBCBreaking @AJEnglish
# Where yall at?!
# Nor for him.
# on the set of 'Broken.'
# OK girl.
# I respect you.
# Postapocalyptic Russian.
# Ressurection.
# A.D.
# Deserve you.
# Pls rtStay for breakfast.
# You get attacked2/2 country.
# pic.twitter.com/mpar4I30QJJust watched a clip from CNN talking about Zuma's corruption, I was waiting to see the Competition Commission's findings!!
# IDK.
# Look at her now!
# Now and forever.
# CHEERS Marvelous Gents!!!
# Hideous gay ogres.
# Well done!!
# Before you die, live.
# A very huge congratulations!!
# You are massive!!
# However- if the shoe fits.
# Oh well Excited and humbled to have been named in BBC’s 100 inspirational and innovative women for 2017 list!!!
# Well done!!
# Pathetic really.Nadia on Jools Holland.
# Check em out here.
# CHEERS Marvelous Gents!!!
# The Ukrainian govt.
# Suggested book tour stop there?
# Got exited.
# Stand by you.
# Before you quit, try.
# "I DIDN'T GET INVITED!
# http://www.bbc.com/news/world-41380265?intlink_from_url=http://www.bbc.com/news/topics/875e94b8-021d-4411-93f4-a8d5e09d6adb/100-women&link_location=live-reporting-story …
# #100Womenpic.twitter.com/rXLK0fv9sG[VIDEO] #GoodbyeChristopherRobin BBC Radio1 Interview feat.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# I believe in peaceful protest.
# Sex trafficking?
# OK girl.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# You are massive!!
# @KingJames @StephenCurry30 @Kaepernick7.
# It wouldn't be pretty.
# Look at her now!
# He's a terrible person.
# Domhnall Gleeson's incredible armpit farts  (26/9/2017)
# https://www.youtube.com/watch?v=BGOAmt0YI7o …pic.twitter.com/kB9qc0G31m#slutty #bbc #ExerciseIsMedicine
#
# korean ass fucking porn yaz
#
# See here
# https://goo.gl/3XcC3P#fW7p
# pic.twitter.com/0LNWBQB2dQCan't wait to see @BBC & the rest of MSM scrutinise every word in Manchester next week & hope they won't be just leading the witness.
# Before you quit, try.
# Before you spend, earn.
# Death.
# Before you die, live.
# Time to go!
# Get in there!!
# Look at her now!
# I am independent!
# And no serious media coverage!
# Love Ya Both!!!
# #bbcdp#BBC Top 100 Women Features @MominaMustehsan
# Read More: https://www.researchsnipers.com/bbc-top-100-women-features-momina-mustehsan …pic.twitter.com/NXUDzfxsEqThe BBC are actually playing the HIghlights from the Labour Party Conference?
# WHO'D HAVE THUNK IT?!
# You get attacked2/2 country.
# Thank You!
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Need you.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# .
# "Classrooms are now propaganda vehicles.
# Well done!!
# I am now seriously worried about waste of my Licence FeeHere is the BBC’s Blue Planet II prequel accompanied by the new track (ocean) bloom: a collaboration between @Radiohead & @HansZimmerpic.twitter.com/VsazdZU61XThis was Ken Loach's brutal reply when a BBC reporter claimed everything is fine as unemployment is down.
# Deserve you.
# "Classrooms are now propaganda vehicles.
# WHO'D HAVE THUNK IT?!
# "I DIDN'T GET INVITED!
# IDK.
# Check em out here.
# Time to go!
# You are massive!!
# Redemption.
# Pls rtStay for breakfast.
# pic.twitter.com/HobfOvz9K7The cheap and lazy political tabloidisation of news at BBC Scotland captured in one story.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Look at her now!
# No way, Jose!
# The Ukrainian govt.
# Encourage you.
# Laughed at surprise emoji.
# Respect you.
# Death.
# Stand by you.
# No amount is too small!
# We are forced to pay for this junk.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Look at her now!
# Before you spend, earn.
# You get attacked2/2 country.
# Postapocalyptic Russian.
# Need you.
# Absolutely marvelous.
# Pathetic really.Nadia on Jools Holland.
# I respect you.
# The Ukrainian govt.
# pic.twitter.com/AyaGaRB6NxBBC went all guns blazing at Labour yesterday.
# Redemption.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# .
# It wouldn't be pretty.
# Bernadette Semple is SIMPLE-minded.
# I am independent!
# Check em out here.
# Love Ya Both!!!
# BTW...she has!
# Include you.
# Mission "destroy Corbyn" has now evolved into mission "stop Labour".
# Suggested book tour stop there?
# Bernadette Semple is SIMPLE-minded.
# Before you quit, try.
# He's a terrible person.
# .
# Pedophilia?
# Hillary Clinton is back.
# @KingJames @StephenCurry30 @Kaepernick7.
# Time to go!
# I am independent!
# Pathetic really.Nadia on Jools Holland.
# Pedophilia?
# BTW...she has!
# Life.
# @KingJames @StephenCurry30 @Kaepernick7.
# Time to go!
# Deserve you.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Get in there!!
# Photos by Reuters.
# LOTS of goodies last week.
# xhttps://m.youtube.com/watch?v=ixlGuj1qiqE …#bbc #escort #weightlossjourney
#
# fuck nice teen piercing sex video
#
# Watch full
# https://goo.gl/3XcC3P#XwS5
# pic.twitter.com/bRM2xjMCbS#apornbiz #results #bbc
#
# porno teens dvd sample
#
# See here
# https://goo.gl/3XcC3P#RKVh
# pic.twitter.com/yWFC4UWyNd#bbc #adult #london
#
# casual oral sex hardcore nude sex teen
#
# Watch full
# https://goo.gl/3XcC3P#kc5X
# pic.twitter.com/NwjoeVSkPe#chaturbate #xxx #bbc
#
# porno teens dvd sample
#
# Watch full
# https://goo.gl/3XcC3P#5Xt4
# pic.twitter.com/ymfEF202KGIs it true that Rupert Murdoch cancelled Fox News in the UK because we already have the BBC?#bbc #weightlossjourney #flowers
#
# xlxx hot jailbait fingering
#
# See here
# https://goo.gl/3XcC3P#cq5E
# pic.twitter.com/bRM2xjMCbS#fuck #teen #bbc
#
# trinidad girls sex pic xxx porn girl
#
# See here
# https://goo.gl/3XcC3P#nPku
# pic.twitter.com/5oelNiNeyf#bigtits #lipstick #bbc
#
# raw sexy pussis gratis en oxnard
#
# See here
# https://goo.gl/3XcC3P#OeA8
# pic.twitter.com/pVbJFacPy8If @FoxNews brings back @billoreilly & sticks him back in 8pm slot before 9PM @seanhannity, you can cancel Christmas.
# Suggested book tour stop there?
# .
# I respect you.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# No way, Jose!
# A.D.
# .
# Respect you.
# OK girl.
# #Unbeatable #RealTalkFOX NEWS ALERT: Taliban targets Secretary Mattis in rocket attack on Kabul, Afghanistan airport | @LucasFoxNewspic.twitter.com/WyZTumdbKA.
# @KingJames @StephenCurry30 @Kaepernick7.
# Thank You!
# Stand by you.
# Before you die, live.
# Ressurection.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# OK girl.
# LOTS of goodies last week.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# Clicked.
# @michellemalkin on Roy Moore Winning the Alabama GOP Senate Runoff: "This was a referendum on Mitch McConnell.
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# @KingJames @StephenCurry30 @Kaepernick7.
# The Ukrainian govt.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# Check em out here.
# No way, Jose!
# Include you.
# Clicked.
# #Castiel from #Supernatural again.
# sho.
# "pic.twitter.com/KYX4f8ybMeHelp is on the way to Puerto Ricopic.twitter.com/dj3hYFJIFZ"Citizens deserve a tax cut in every state."
# Got exited.
# Suggested book tour stop there?
# .
# "I DIDN'T GET INVITED!
# @morningmikaWTF!
# Get in there!!
# You are massive!!
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Pls rtStay for breakfast.
# A.D.
# WATCH: @KellyannePolls's full interview on @foxandfriends.pic.twitter.com/NM5BvLdKDm.
# Sex trafficking?
# Terrorism?
# Before you speak, listen.
# Photos by Reuters.
# I respect you.
# The vampires.
# Suggested book tour stop there?
# Ressurection.
# Encourage you.
# @morningmikaWTF!
# @KellyannePolls on tax reform: "The code currently favors the wealthy and the privileged and the connected."pic.twitter.com/AAQAT4l2uf.
# Which would it be?
# .
# Encourage you.
# Laughed at surprise emoji.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Absolutely marvelous.
# Now and forever.
# Territory - over 1000 hectares.
# #Castiel from #Supernatural again.
# He's a terrible person.
# @KellyannePolls on NFL anthem protests: "The president is supporting the flag and everything that it stands for.
# tell me everything.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# Life.
# You get attacked2/2 country.
# Before you spend, earn.
# Bernadette Semple is SIMPLE-minded.
# Photos by Reuters.
# No amount is too small!
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# CHEERS Marvelous Gents!!!
# Thank You!
# Pedophilia?
# CONSPIRACY!"
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# @KingJames @StephenCurry30 @Kaepernick7.
# Get in there!!
# Trust your own intuition.
# Include you.
# The Ukrainian govt.
# Before you spend, earn.
# Death.
# However- if the shoe fits.
# "I DIDN'T GET INVITED!
# pic.twitter.com/yMHfLZA0iOTyler: Any other meaningless conspiracy theories?
# This is HORRIBLE!
# Laughed at surprise emoji.
# I believe in peaceful protest.
# Hillary Clinton is back.
# #Castiel from #Supernatural again.
# OK girl.
# Photos by Reuters.
# Now and forever.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# Territory - over 1000 hectares.
# Amy, leaning forward, visibly upset: Yeah -- did you know that gogurt is just yogurt?be careful who you trustpic.twitter.com/AL2DzSDSclI have 0 respect for liars.Before you pray, believe.
# Absolutely marvellous.
# Ressurection.
# Absolutely marvelous.
# Pathetic really.Nadia on Jools Holland.
# But they refuse to.
# Stand by you.
# Our students are so excited!
# Same as everyone else.
# The Ukrainian govt.
# pic.twitter.com/JrWYrelea7.
# Before you speak, listen.
# I am independent!
# Thank You!
# I love you, Isabelle.
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# A very huge congratulations!!
# Hideous gay ogres.
# Get in there!!
# I respect you.
# BTW...she has!
# I respect you.
# Before you spend, earn.
# I respect you.
# Security lacks.
# It wouldn't be pretty.
# Absolutely marvelous.
# Pathetic really.Nadia on Jools Holland.
# Clicked.
# on the set of 'Broken.'
# BTW...she has!
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Now and forever.
# Before you quit, try.
# Bernadette Semple is SIMPLE-minded.
# Respect you.
# I believe in peaceful protest.
# The vampires.
# Need you.
# Thank You!
# #Castiel from #Supernatural again.
# Postapocalyptic Russian.
# Laughed at surprise emoji.
# However- if the shoe fits.
# Before you die, live.
# #Castiel from #Supernatural again.
# Same as everyone else.
# Trust your own intuition.
# Postapocalyptic Russian.
# Laughed at surprise emoji.
# Hideous gay ogres.
# Photos by Reuters.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# Check em out here.
# Stand by you.
# "Too ugly"pic.twitter.com/ImYupbWcVtI think a lot, but I don't say much..@MatPatGT takes on the #streamys Dance nominees... also known as, members of the Illuminati?
# Hideous gay ogres.
# No way, Jose!
# Before you spend, earn.
# Photos by Reuters.
# I love you, Isabelle.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# BTW...she has!
# Postapocalyptic Russian.
# He's a terrible person.
# Territory - over 1000 hectares.
# pic.twitter.com/ZiKkqj3LR7Don’t destroy someone,
#
# just because
#
# someone once destroyed you.Respect me.
# Encourage you.
# Territory - over 1000 hectares.
# CONSPIRACY!"
# Absolutely marvellous.
# OK girl.
# Look at her now!
# Nor for him.
# Clicked.
# Pls rtStay for breakfast.
# You are massive!!
# I respect you.
# Absolutely marvellous.
# BTW...she has!
# "I don't hate you.
# #BoycotttheNFL #BoycottNFLSponsorsToo fucking late.
# Death.
# 200 km away.
# It wouldn't be pretty.
# .
# I love you, Isabelle.
# Redemption.
# Disrespect me, fuck you.Happiness begins with you.
# Ressurection.
# Hillary Clinton is back.
# Get in there!!
# 200 km away.
# Photos by Reuters.
# The vampires.
# IDK.
# And no serious media coverage!
# Hideous gay ogres.
# .
# Not with your relationship, your friends, or your job.
# Nor for him.
# IDK.
# Absolutely marvellous.
# A.D.
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# A very huge congratulations!!
# CHEERS Marvelous Gents!!!
# .
# The Ukrainian govt.
# Redemption.
# but with you.Never put a limit on what you can do.The “Illuminati” (“Globalists”) are the sworn enemies of #BiblicalChristianity perpetrators & architects of the New World Order (NWO).
# "I don't hate you.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Now and forever.
# BTW...she has!
# WHO'D HAVE THUNK IT?!
# Before you die, live.
# Before you spend, earn.
# The Ukrainian govt.
# BTW...she has!
# Include you.
# #USThe quieter you become, the more you can hear.Better things are coming.
# Terrorism?
# Before you speak, listen.
# Come On Witches!!
# Sex trafficking?
# IDK.
# #nohonor.
# I believe in peaceful protest.
# CONSPIRACY!"
# BTW...she has!
# Absolutely marvelous.
# Keep your head up.Don't stress over things you can't change.Sometimes, change is what we need.I can't live a day without music.Think for yourself.
# Thank You!
# #nohonor.
# Check em out here.
# Include you.
# WHO'D HAVE THUNK IT?!
# Before you spend, earn.
# Bernadette Semple is SIMPLE-minded.
# Look at her now!
# Before you speak, listen.
# It wouldn't be pretty.
# Trust your own intuition.
# WHO'D HAVE THUNK IT?!
# Deserve you.
# "Classrooms are now propaganda vehicles.
# A very huge congratulations!!
# Pls rtStay for breakfast.
# You get attacked2/2 country.
# Photos by Reuters.
# #nohonor.
# Sex trafficking?
# The Ukrainian govt.
# Others aren't walking the same journey that you are.Don't change to please people.
# .
# Now and forever.
# Pls rtStay for breakfast.
# The Ukrainian govt.
# Our students are so excited!
# IDK.
# And no serious media coverage!
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Clicked.
# If they can't accept you for who you are, you don't need them in your life.Pain makes people change.Working on myself, by myself, for myself.Sometimes you have to put
# the clocks back on time
# I wish you a great day
# Thank you Larry
# And another thing…
# RespectMany have served, fought, sacrificed & died for your right to stand or take a knee!
# Now and forever.
# Laughed at surprise emoji.
# Suggested book tour stop there?
# pic.twitter.com/JrWYrelea7.
# Well done!!
# CHEERS Marvelous Gents!!!
# Clicked.
# Nor for him.
# And no serious media coverage!
# Life.
# If you respect the sacrifice, I support your kneel!
# Time to go!
# Which would it be?
# Hillary Clinton is back.
# Well done!!
# .
# IDK.
# @KingJames @StephenCurry30 @Kaepernick7.
# Clicked.
# Include you.
# No amount is too small!
# pic.twitter.com/TF6Wscx19bHow many of you Haters Wanna #Support us.!!
# Before you die, live.
# .
# WHO'D HAVE THUNK IT?!
# The Ukrainian govt.
# BTW...she has!
# Laughed at surprise emoji.
# I love you, Isabelle.
# Stand by you.
# @morningmikaWTF!
# pic.twitter.com/JrWYrelea7.
# #HrithikVsTiger It's Time to Respect us..
# @iHrithik #HrithikRoshan @iTIGERSHROFF #TigerShroffpic.twitter.com/fNiMFPEzUjB1A4 is after Bangtan I LOVE THE RESPECT THANK YOU SHOW CHAMPION!even on bad terms, im still gonna respect and be loyal to you.How you claim people aren't #Jasam fans when you don't respect Sam or her portrayer?
# Terrorism?
# .
# WHO'D HAVE THUNK IT?!
# Time to go!
# Encourage you.
# "Classrooms are now propaganda vehicles.
# CONSPIRACY!"
# Well done!!
# on the set of 'Broken.'
# Laughed at surprise emoji.
# #StopIt
# I don't Fux with Fraud-Stars
# #BuhGudNight
# #GHpic.twitter.com/2mBeek7yGyIf you hustle for your own I respect you.Respect #EXO, I'll respect back..
# Bash #EXO , I'll tear you into pieces ..I don't care if you're a democrat a republican, or anything in between.
# Which would it be?
# LOTS of goodies last week.
# A.D.
# Pedophilia?
# But they refuse to.
# BTW...she has!
# IDK.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# Redemption.
# I love you, Isabelle.
# We're all Americans and we all should respect each other.Respect me.
# Absolutely marvellous.
# Photos by Reuters.
# Hillary Clinton is back.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# .
# #Castiel from #Supernatural again.
# Postapocalyptic Russian.
# Absolutely marvelous.
# WHO'D HAVE THUNK IT?!
# Territory - over 1000 hectares.
# I respect you.
# Nor for him.
# Come On Witches!!
# Laughed at surprise emoji.
# sho.
# This is HORRIBLE!
# Who benefitted?
# .
# Now and forever.
# Life.
# Absolutely marvelous.
# Disrespect me, fuck you.Respect yourself enough to say
# "I deserve peace", and walk away from people or things that prevent you from attaining it.If you been hurt to the core and you still believe in love, i respect you.To all my trans friends I’m so sorry that you’re continuously faced with ignorance, transphobia and fighting for respecti respect a man who is vocal.
# Before you speak, listen.
# Photos by Reuters.
# Check em out here.
# Hideous gay ogres.
# Got exited.
# Nor for him.
# Who benefitted?
# Our students are so excited!
# Clicked.
# He's so... pompous.
# tell me why you’re into me.
# Thank You!
# on the set of 'Broken.'
# Clicked.
# Same as everyone else.
# CHEERS Marvelous Gents!!!
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# "Classrooms are now propaganda vehicles.
# This is HORRIBLE!
# He's so... pompous.
# Absolutely marvellous.
# tell me why i pissed you off & tell me how i can fix it.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Before you quit, try.
# CONSPIRACY!"
# No way, Jose!
# IDK.
# Nor for him.
# @KingJames @StephenCurry30 @Kaepernick7.
# Absolutely marvellous.
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# 200 km away.
# tell me everything.
# Got exited.
# OK girl.
# Check em out here.
# .
# #InvestigateStart by RESPECTING all citizens.
# A very huge congratulations!!
# Thank You!
# #nohonor.
# No amount is too small!
# #PostApocalyptic pic.twitter.com/DNZAEyipXbTumbling dominoes of destruction!
# talk.Otiende Amollo, I just added you to the list of lawyers I respect in this country.
# It wouldn't be pretty.
# Death.
# No way, Jose!
# pic.twitter.com/VM8DEn0CrDMessage for @Jacob_Rees_Mogg.
# Cause unknown; likely sabotage.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Before you speak, listen.
# #nohonor.
# .
# Photos by Reuters.
# Thank you for putting Murkomen in his own corner.I don't care about your
# - age
# - weight
# - sexuality
# - height
# - gender
# - skin color.
# The Ukrainian govt.
# 200 km away.
# #nohonor.
# Who benefitted?
# Trust your own intuition.
# Stand by you.
# Check em out here.
# #Sizzy #Shadowhunters pic.twitter.com/xC972TNj7YThe Mortal Instruments.
# However- if the shoe fits.
# Postapocalyptic Russian.
# As long as you respect me, I'll respect you.
# Before you spend, earn.
# Trust your own intuition.
# .
# But they refuse to.
# You get attacked2/2 country.
# @morningmikaWTF!
# He's so... pompous.
# Security lacks.
# Cause unknown; likely sabotage.
# A.D.
# "I don't hate you.
# WHO'D HAVE THUNK IT?!
# Come On Witches!!
# Redemption.
# sho.
# tell me everything.
# Photos by Reuters.
# Life.
# Pedophilia?
# Look at her now!
# I am independent!
# I just lost all respect towards you and have nothing to say to you anymore.
# IDK.
# I love you, Isabelle.
# Redemption.
# Time to go!
# Hideous gay ogres.
# BTW...she has!
# Cause unknown; likely sabotage.
# You get attacked2/2 country.
# I respect you.
# on the set of 'Broken.'
# "I Stand Proudly for the Nation Anthem - Retweet If You Support America & Respect the Flag pic.twitter.com/agr62p3vHXF.R.I.E.N.D.S
#
# Fight for you.
# Life.
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# I am independent!
# Stand by you.
# I respect you.
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Pedophilia?
# No amount is too small!
# Postapocalyptic Russian.
# Need you.
# Respect you.
# Need you.
# Well done!!
# Love Ya Both!!!
# But they refuse to.
# The Ukrainian govt.
# http://fxn.ws/2fMy94Z pic.twitter.com/YP27jYUruWU.S.
# Bernadette Semple is SIMPLE-minded.
# Same as everyone else.
# Before you speak, listen.
# pic.twitter.com/ej4fA5SmsI20K people evacuated from #Kalynivka.
# Include you.
# Ressurection.
# However- if the shoe fits.
# Security lacks.
# Absolutely marvellous.
# I am independent!
# Sex trafficking?
# tell me everything.
# Hideous gay ogres.
# The Ukrainian govt.
# I respect you.
# Encourage you.
# Before you speak, listen.
# Life.
# No amount is too small!
# Postapocalyptic Russian.
# And no serious media coverage!
# 200 km away.
# @KingJames @StephenCurry30 @Kaepernick7.
# BTW...she has!
# @morningmikaWTF!
# #KITTpic.twitter.com/TjNxhb6nsIBack at it as A.W.
# Need you.
# Pedophilia?
# Hillary Clinton is back.
# And no serious media coverage!
# Territory - over 1000 hectares.
# This is HORRIBLE!
# A very huge congratulations!!
# Bernadette Semple is SIMPLE-minded.
# The Ukrainian govt.
# 200 km away.
# Encourage you.
# Deserve you.
# A.D.
# He's so... pompous.
# Territory - over 1000 hectares.
# WHO'D HAVE THUNK IT?!
# And no serious media coverage!
# You get attacked2/2 country.
# However- if the shoe fits.
# #LetMeGetACameopic.twitter.com/WRC989IQy8Did you know?
# Now and forever.
# Look at her now!
# Stand by you.
# I love you, Isabelle.
# Need you.
# Respect you.
# He's a terrible person.
# No amount is too small!
# #LittleRockNinepic.twitter.com/Ps0J5ZcQklYou're invited!
# And no serious media coverage!
# #nohonor.
# Who benefitted?
# Photos by Reuters.

# %%
\xa0Sex trafficking is at an all time high in Reno right now. So everyone please please be aware of your surroundings and be safe! Hey, @morningmika, why single out Hillary Clinton re: Puerto Rico? Is she the only person who could do something? BTW...she has! #morningjoe#morningjoe HEY MIKA JUST A REMINDER HILLARY CLINTON IS NOT THE PRESIDENT. SHE IS A CITIZEN LIKE U- SO U CAN GO TO PUERTO TOO! @morningmikaWTF! @morningmika Just criticized @HillaryClinton saying she should do more to help situation in PR?! Suggested book tour stop there?!\xe2\x80\x9cThe constitutional crisis no one is talking about \xe2\x80\x94 except Hillary Clinton\xe2\x80\x9d by Adam M. Lowenstein https://medium.com/@adamlowenstein/the-constitutional-crisis-no-one-is-talking-about-except-hillary-clinton-c4b21fa901db\xc2\xa0\xe2\x80\xa6Mika really just said that @HillaryClinton should take her book tour to Puerto Rico. That's the dumbest thing I've heard today. #morningjoePsychiatrist calls Hillary Clinton a sociopath & pathological liar..<br />", 'https://youtu.be/se8AvsaZdlY\xc2\xa0pic.twitter.com/gTC2FdwYQ8The 2X Loser @hillaryclinton is on every talk show PREACHING the STALE "Racism" rhetoric & the @NFL & #hollyweird fell for it! #Stooges Here: your fake picture taken before #NationalAnthem began & screen change 5th debate on #CNN it\'s on YouTubepic.twitter.com/CKyVd6Q4TiIf @HillaryCli ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-b8d7307ec7b3> in <module>()
#       4 for line in lines:
#       5     line = (lines.split("\n"))
# ----> 6     time.sleep(5)
#       7     print line
#       8
#
# KeyboardInterrupt:

# %%
import time
file = open("testfile.txt")
lines = file.read()
for line in lines:
    
    
    print line.join(lines.split(".\n\n"))
    time.sleep(5)
# Out:
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-249-fd6fede095ea> in <module>()
#       6
#       7     print line.join(lines.split(".\n\n"))
# ----> 8     time.sleep(5)
#
# KeyboardInterrupt:

# %%
import time
file = open("testfile.txt")
lines = file.read()
for line in lines:
    
    time.sleep(1)
    print line.join(lines.split(".\n\n"))
# Out:
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# The Strangest Conspiracy Involving NASA: Project LUCIFER: http://youtu.be/E6Igxa-70sM?a  prin @YouTubeCNM Student tabbed for NASA project
# This is fantastic - congratulations Antonella!<br />
# https://www.abqjournal.com/1067957/student-tabbed-for-nasa-project-excerpt-visit-to-johnson-space-center-included.html …This sounds strange until you look up NASA project A119, which is some crazy story about "bombing the moon" and finding "oceans" there.Consider it a gift, like a PBS tote bag, for the necessary tax increase in order to fund the "Fuck Joe Walsh" NASA project.So Sajor lahat ininterview ko napaligiran ako hahaha Proud of them, sila nasa project ko.Jubilee thought the CHAN tournament was a NASA project hence the lack of commitment? What a shame! Sports lovers should vote Jubilee Out.sinong nasa project kaya ngayon hmmmdid jubilee think the CHAN tournament was a NASA project hence the lack of commitment?How is this man NOT wearing a NASA project manager's badge?Feature on Six Feet Up and our #NASA Project @gabriellehp https://buff.ly/2x78Wfw pic.twitter.com/iRM4AAlcRp@timandsid  that was @NASA project #Nerf @DJGEETVpic.twitter.com/22eXEJzlVfNASA project of no electionsNasa projectAt dahil inspired ako sayo.. Ayieeee nasa project ko siya hihihihi.<br />
# #PushAwardsDARRENaticspic.twitter.com/vKeuSTCpUjI've never had an emotional response to a NASA project before. So, the mourning is new for me. Thank you Cassini.oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss themAnd I did leave a NASA project to go there!  pic.twitter.com/GSmh1RSihj近日発売予定です
# 1/144 NASA Project Mercury spacecraft & Seven astronauts #144スケモ #144scale #DAMEYApic.twitter.com/NhBimIPpcmI love watching NASA project retrospectives (e.g. Cassini) because NASA projects are always just crammed full of hyper-smart women.We see Nasa  project from a distance
# #KaruaBaselessPetition
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-240-57b979524fcc> in <module>()
#       4 for line in lines:
#       5
# ----> 6     time.sleep(1)
#       7     print line.join(lines.split(".\n\n"))
#
# KeyboardInterrupt:

# %%
from bs4 import BeautifulSoup
import requests
import io
import string
def get_text_cleaned(tweet):
    tweet = tweet.replace("u'", "");tweet = tweet.replace(" id ", "\n id")
    return tweet

def get_text_sanitized(tweet):    
    return ' '.join([w.lower().strip().rstrip(string.punctuation)\
        .lstrip(string.punctuation).strip()\
        for w in get_text_cleaned(tweet).split()\
        if w.strip().rstrip(string.punctuation).strip()])

with io.open("testfile002.txt", "w", encoding="utf-8") as my_file:
    

    url = u'https://twitter.com/search?q='
    #query = u'%40drawranliou'
    #query = u'@JamesOKeefeIII'
    #query = u'hurricanne&src=typd'
    query = u'nasa-project'
    r = requests.get(url+query)
    soup = BeautifulSoup(r.text, 'html.parser')
    tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
    txt = (tweets)
    output = open("exp001.txt", "w")
    for list in txt:
        list =get_text_sanitized(list)    
        mytext = "<br />\n".join(list.split("\n\n"))
        txt = [unicode(mytext).encode("utf-8")]
        txt = str(txt)
        my_file.write(mytext) 
        print mytext
output.close()
# Out:
# the strangest conspiracy involving nasa project lucifer http://youtu.be/e6igxa-70sm?a prin youtube
# this sounds strange until you look up nasa project a119 which is some crazy story about bombing the moon and finding oceans there
# consider it a gift like a pbs tote bag for the necessary tax increase in order to fund the fuck joe walsh nasa project
# so sajor lahat ininterview ko napaligiran ako hahaha proud of them sila nasa project ko
# jubilee thought the chan tournament was a nasa project hence the lack of commitment what a shame sports lovers should vote jubilee out
# sinong nasa project kaya ngayon hmmm
# did jubilee think the chan tournament was a nasa project hence the lack of commitment
# how is this man not wearing a nasa project manager's badge
# feature on six feet up and our nasa project gabriellehp https://buff.ly/2x78wfw pic.twitter.com/irm4aalcrp
# timandsid that was nasa project nerf djgeetvpic.twitter.com/22exejzlvf
# nasa project of no elections
# nasa project
# at dahil inspired ako sayo ayieeee nasa project ko siya hihihihi pushawardsdarrenaticspic.twitter.com/vkeustcpuj
# i've never had an emotional response to a nasa project before so the mourning is new for me thank you cassini
# oh shit there's a new uncommon nasa project please can i get someone to start telling me about these things so i don't miss them
# and i did leave a nasa project to go there pic.twitter.com/gsmh1rsihj
# 近日発売予定です 1/144 nasa project mercury spacecraft seven astronauts 144スケモ 144scale dameyapic.twitter.com/nhbimippcm
# i love watching nasa project retrospectives e.g cassini because nasa projects are always just crammed full of hyper-smart women
# we see nasa project from a distance karuabaselesspetition

# %%
string_with_stuff = "weird \xe1ccents"
print string_with_stuff.decode('ascii', errors="ignore")
# Out:
# weird ccents

# %%
from textblob import TextBlob, Word
import sys
import random
filename ="/home/jack/Desktop/imagebot/hekel.txt"
with io.open(filename, "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    
text = sys.stdin.read().decode('ascii', errors="ignore")
blob = TextBlob(essays)

nouns = list()
for word, tag in blob.tags:
	if tag == 'NN':
		nouns.append(word.lemmatize())

print "This text is about..."
for item in random.sample(nouns, 5):
	word = Word(item)
	print word.pluralize()
# Out:
# This text is about...
# forms
# excitements
# headlongs
# readings
# attentions

# %%
from textblob import Word
bank = Word("amazing")
synsets = bank.synsets
print synsets
# Out:
# [Synset('amaze.v.01'), Synset('perplex.v.01'), Synset('amazing.s.01'), Synset('amazing.s.02')]

# %%
from textblob import Word
synsets = Word("amazing").synsets
for synset in synsets:
    print synset.definition()
# Out:
# affect with wonder
# be a mystery or bewildering to
# surprising greatly
# inspiring awe or admiration or wonder

# %%
from textblob import Word
from textblob.wordnet import NOUN
synsets = Word("bank").get_synsets(pos=NOUN)
for synset in synsets:
    print synset.definition()
# Out:
# sloping land (especially the slope beside a body of water)
# a financial institution that accepts deposits and channels the money into lending activities
# a long ridge or pile
# an arrangement of similar objects in a row or in tiers
# a supply or stock held in reserve for future use (especially in emergencies)
# the funds held by a gambling house or the dealer in some gambling games
# a slope in the turn of a road or track; the outside is higher than the inside in order to reduce the effects of centrifugal force
# a container (usually with a slot in the top) for keeping money at home
# a building in which the business of banking transacted
# a flight maneuver; aircraft tips laterally about its longitudinal axis (especially in turning)

# %%
from textblob import Word
from textblob.wordnet import NOUN
synsets = Word("bank").get_synsets(pos=NOUN)
print synsets[1].lemma_names()
# Out:
# [u'depository_financial_institution', u'bank', u'banking_concern', u'banking_company']

# %%
from textblob import Word
from textblob.wordnet import NOUN
synsets = Word("plane").get_synsets(pos=NOUN)
print synsets[1].lemma_names()
# Out:
# [u'plane', u'sheet']

# %%
from textblob import Word
from textblob.wordnet import VERB
synsets = Word("plane").get_synsets(pos=VERB)
print synsets[1].lemma_names()
# Out:
# [u'plane', u'skim']

# %%
from textblob import Word
from textblob.wordnet import NOUN
synsets = Word("plane").get_synsets(pos=NOUN)
for synset in synsets:
    print synset.definition()
# Out:
# an aircraft that has a fixed wing and is powered by propellers or jets
# (mathematics) an unbounded two-dimensional shape
# a level of existence or development
# a power tool for smoothing or shaping wood
# a carpenter's hand tool with an adjustable blade for smoothing or shaping wood

# %%
import sys
import random
import io
count = 0
with io.open("ToUse.txt", "r", encoding="utf-8") as my_file:
    sys.stdin = [my_file.read()] 
for line in sys.stdin:
    print line
# Out:
# 1 XXXXXX If will create the same space of about three lines plus one in front of the height, the general rule is satidfied.
# He manages his forces as though they were only a memory.
# Some people are exceeding graciousness and familiar with the table. Those people are fewer in number.
# Long, low masses of dust show the soldiers will not be besieged; ground that must be made known beforehand.
# It was thus her wish to sleep. She was compelled by fatigue after undertaking, unassisted, entire weight of the task.
# Human life should not underrate the psychic apparatus which alone makes comprehensible the whole night.
# All thinking is only the opposite of conscious. Although we cannot identify what it is.
# Freud claims foreconscious is a large sum of energy brought about by consciousness.
# When an idea which does away with the conscious expression of the punishments, others will associate themselves.
# She loved only those who were distinguished in her households.
# If the enemy, from a sudden onslaught, is perceived weak make the defeat rapid.
# Men of the enemy in relation to water:-- After crossing waters, pass on immediately to a distance.
# Now, of the enemy, we may go a thousand leagues without exhaustion.
# The way_ or the proper conduct of war will not reap advantage. Do not let proper conduct weaken the effort.
# Their difficulty lies in the night betoken alarm.
# The computer will download an index of the files within one day.
# Non-sanctioned repositories must be made executable.
# It automatically backs itself up and ready to go.
# It takes the sudo apt-get update udates the index of the the week-ends.
# Welcome to The Tales of the first class came I was in Florida.
# The computer will download an index of files, it does not install them.
# If permission error is indicated, the file's permissions must be reviewed and evaluated by you.
# The computer will download an index of files, it does not install them.
# Now for the perception system, and, secondly, from the spot where he was last working.
# It upholds a _logical connection_ as _approximation in time for a moment for ignition.
# If you can not enter into the analysis, the further you are outside the United States.
# I will now point out that my mother was dying; the tomb agrees with this.
# Wherefore the good general's Speech on the psychology of war was inexcusable.
# Vary the stratagem according to my plans, or you will be lost.
# With regard to the occasion and the hearts of men, consider this upon employing troops.
# Therefore they must not be attacked, they must be divided.
# All  of our plans depend on accomplishing a single day's victory.
# They who are sitting may be present, the country as give information.
# For, while quick accomplishment has been a country and then fall upon them.
# If deeply involved in the service of their rights. This is called deeply-involved ground.
# But, if he listens and still decides the issue incorrectly, he must be eliminated.
# The diagram given a under no after the surface of every description.
# That part of the light is the highest light, and it is due to rivers which flow into the earth.
# This happens because the heat of the wall, look of the drawings here reproduced in facsimile have never been published before.
# Hence we may look at a spot corresponding to the forehead..
# The cast shadow will resemble a pyramid the same as the chin to the eyes.
# If we hope to get out of the Alps which divide France from Italy.
# THE IMAGES IN THE PUPIL OF THE RAYS WHETHER SHADED OR LUMINOUS HAVE GREATER STRENGTH AND EFFECT AT THEIR SIDES.
# The real size of the object mirrored in it is being exposed to the luminous bodies which are are smooth and white.
# Because they occupy no space, I will sign up for the American image in a couple weeks.
# WHAT PORTION OF A WALL SURFACE WILL BE LEAST LUMINOUS WHICH IS SEEN UNDER THE LEAST AMOUNT OF LIGHT.
# As to the distance we will have a very large shadow Which pervades the air.
# Compound derived shadows will be very plainly visible if the luminous bodyis not in direct view.
# The light which surrounds the derived shadow will show you their shaded side, because on that side of the edges.
# The base of this is the same form and colour; but the intersection as throughout the rest.
# The sea does not regard planes as foreshortened, but as an object which is nearest to black; and white make blue.
# The practice of the middle of the movements made in the same size, the second will seem half the head.
# Shadow partakes of the window from the angle where the author refers to morning light in general.
# Scuba Diving Lessons I was charged up and ready to go.
# The computer will download an index of the newly added repository are available.
# Out of the box, apostrophes have no place in a database and can be dangerous.
# My project of the Saltman is charged up and it is a database on Google Drive.
# As I said I use voice to make an auto-space after a period when using voice.
# Out of the files with one of the files with one of the box, apostrophes have no place in a couple weeks.
# Experimenting with a function to permit the file called configure.
# I signed up for the American image in a database. I also wish to say and share.
# If permission error is indicated, the file's permissions must be reviewed and evaluated by you.
# It will show you any upgrades and you must reply with a few Characters - Very UN-SALTMAN like This may be interested.
# This is the location I have things I wish to discourage people to come to the Philippines to party and get drunk.
# It automatically backs itself up and ready to go. A friend of mine was a bit of a challenge.
# I was charged up and it's database on Google Drive. As I said I use voice to make an auto-space after a period.
# When using voice, I am in the terminal. Welcome to The Tales of the commands If it is a tar.
# Find the configure file and enter. I program and it also is being recorded.
# When using Online Repository Resources it must begin with a few drinks until it is hard to differentiate the two.
# Some postings will be fun for readers to try out. It automatically backs itself up and ready to go.
# Air Horns there were a large set of air horns in the world is this Dude writing an E-book then.
# I am back to doing much of my decision to end my bond with Windows and Linux to me.
# We were cruising down the tube to the the spark plug.
# I saw a county just getting introduced to the death and abandonment of Windows XP.
# It was a home made jet engine using an an igniter I built at home.
# I was in the paper because I also fooled a bit with Mac Computers.
# I was afraid to cut the gas can away and run.
# My friend and I, both on motorcycles, went together to see the van I had to reach over the spark plug.
# I was in the garage on fire, caused by the jet engine igniter created at home.
# Back when a power failure meant a reinstall because of the favorite exhibits was a hard core DOS Dude.
# At the time it was a home made jet engine.
# I saw a county just getting introduced to the death and abandonment of Windows XP.
# Air Horns there were a large set of air horns in the world is this Dude writing an E-book then.
# I am retired and live in the garage on fire. I was afraid to cut the gas over the spark plug.
# I had found in the garage examining, modifying, tuning it up.
# It was a Windows project followed up by using a gas can.
# This is a poor country, and most of the small engine at school blew a blue flame and three or four yellow flames.
# I had to reach over the spark plug. OPP ! Almost all the pieces together.
# Now what OMG ! I was in the paper. Then reached over the spark plug.
# This is a poor country, and most of the dance halls and keep your mind sharp.
# Now what OMG ! I was excited at the thought of the favorite exhibits was a home made jet engine.
# If you are older this may not lead you into a buzzer to pulse the electricity.
# Working from a command line freaks a lot of people out.
# If they could, quite often their hardware could not afford to purchase an upgrade.
# That being said, you must be wondering why in the Philippines when Microsoft decided to learn and promote Linux.
# I had found in the Philippines when Microsoft decided to give serious interest to Ubuntu Linux.
# I took the picture on the igniter, I could hear the spark plug.
# The filters are used for unpickled records received from a pickled event received over the wire.
# Handlers have the following table. If these are missing, the message for this handler fails.
#  to a logger which is highest in the following attributes and methods.
# The logger name hierarchy is traversed towards the root logger, or delegation to the record will be emitted.
# Tidy up any resources used by the handler will not be threadsafe.
# Filters can be pickled and sent across the wire, but you should not need to pass the extra dictionary with these keys.
# Do formatting for a record - if a message with level INFO on this logger.
# Initializes a thread lock which can be used as the effective level for this handler to lvl.
# The LogRecord has a filter method with the message.
# Filename portion of a message, was a non-root logger.
# Logging messages which are below a certain point in the Python package namespace.
# Applies this handler’s filters to the root is reached, and it has a filter initialized with the same record multiple times.
# If name is lost the filters are consulted in turn by Formatter class.
# Until one of them return a false value, the record is to be added to the same Logger object.
# You shouldn’t need to pass a dictionary which is a non-root logger.
# For example: The keys in the logger is created with level ERROR on this logger.
# I lingered but a glance, for all they went so slowly; it was in his heart, he preferred to speak of it with passion.
# Suddenly and at the paper, and last of the low growl of London from all round, very silent.
# Each closet held an item needed, but not thing of vital to existance.
# I was once again raging and freezing with the passions of Hyde.
# But here I took and furnished that house of voluntary bondage, and to grow more at quiet with himself.
# But for all his energy of life, that Bernie at last his patience was rewarded.
# I mean from henceforth to lead a life of effort, virtue, and control, should usurp the offices of life.
# Six hours after, as I supposed, on every side, I began to cherish a longing for advice.
# Peewee was no more myself when I know how he fears my power to shake me.
# Others will follow, others will outstrip me on the chimney shelf, for even in memory, so dwell on that.
# At sight of him back, conscious at his companion.a few seconds.
# On his way to Malcom's door, where I saw that Sawbones turn sick and white with the door, in consequence.
# And he covered his face was white and his own past, groping in all the time.
# We were by no means in the lives of down-going men.
# Think of me at first sight, without a start of horror.
# Ah, sir, there's blood foully shed in every feature, the marks of prolonged and sordid negligence.
# The doctor had bought the house in Soho, to which I had learned to recognise in him for old sake's sake, as they are.
# Some two months before the murder had been prevented.
# Think of me were in dead earnest; I was able, in clothes of my second character, my faculties seemed sharpened to a watery green.
# The instance is initialized with the message. The line number and function name was added.
# These attributes can be used with particular Handlers.
# If none of them returns a false value which means that the message had a low level WARNING.
# If none of them return a reference to the constructor.
# The term ‘delegation to the parent logger is created, the level is treated as the effective level.
# Returns an instance of the ancestor loggers is traversed towards the root logger is EnabledFor lvl.
# If you are unfamiliar with logging, the best way to get to see the links on the right.
# The LogRecord has a number of attributes, most of which are combined using msg % args.
# You don’t actually need to format this yourself. That indicates if a formatter is set, use it.
# If none of them return a reference to the appropriate logger which is highest in the Formatter has been flushed.
# If name is specified, it names a logger which is used as the effective level of the time the logging call.
# If one returns a true value if the record may be modified in-place by this LogRecord.
# You don’t actually need to exercise some care.
# In general, you should not clash with the current exception information, or None if no exception has occurred, None.
# This allows use of the record into the msg argument to obtain the event doesn’t use the cached value after a formatter is set, use it.
# Logging messages which are combined using msg % args.
# This is useful because the exception information to be specified.
# The value returned is an integer, typically one of them returns a true value if the record is to be used.
# Time in milliseconds when the LogRecord being processed.
# This version does nothing and is intended to be shown in GMT, set the converter attribute in the final output.
# The message attribute of the record will be ignored.
# The logged message, computed as msg % args to create the message for this handler to form.
# Millisecond portion of pathname. Handlers have the following table.
# LogRecord instances are used for the module an if these are missing, the message will not emit the same Logger object.
# The message, computed as msg % args to create the message will not care about errors in the following attributes
# The primary information is passed in the logging messagei Human-readable time when the exception occurred.
# Otherwise, the hierarchy is analogous to the record into the msg argument to obtain the event represented.
# The filters are used to pass the extra dictionary with these keys.
# The LogRecord has a number of attributes, most of which are combined using msg % args.
# If one returns a false value, the record and returns a false value, the handler will not be threadsafe.
# Messages are passed directly to the root is reached.
# I had now seen the full moon. But he kept fewer secrets than Mr. Guest; and he had grown very silent.
# He did no good; his face as he spoke, harsh and broken.
# I could see by his neighbourhood two natures that contended in the doctor's appearance.
# And all the folks asleep--street after street, and all judges of good wine; and Mr. Utterson a sincere and warm.
# The ivory-faced and silvery-haired old woman remained otherwise empty.
# Mr. Hyde at such an enemy to rest! Instantly the spirit of enduring hatred.
# He did not like his friend's quarters; and he sat on the court by three dusty windows barred with iron.
# This little spirit of temper was somewhat theatrical to the post, and which has finally severed me from my bed.
# I rushed to the gallows, but the wood was tough and heavy wood.
# Enough, then, that he wiped away,, had broken in the morning, and the locksmith was near despair.
# The scud had banked over the laboratory, where he would play me, scrawling in my soul that it almost rivalled the brightness of hope.
# A maid servant living alone in a moment, like a rat, and run from me?I knew myself, at the high pressure of spirits.
#  involved in their Sunday walks, that they should be continuously struggling.
# Next, in the middle of the night was fully come, he set it down to dinner without relish.
# From these embers the inspector exchanged glances.
# On the 12th, and again the panels crashed and the look of him, even at that time, I set it down to follow.
# I knew myself, at the acuteness of the court.
# The steps drew swiftly nearer, and swelled out suddenly louder as they are.
# And then by a sudden splutter of the drug had to deal with in the dismal quarter of London.
# Presently her eye wandered to the building which was equipped with neither bell nor knocker.
# There are three windows was half-way open; and sitting there by the laboratory or the relief of sorrow and suffering.
# How, then, were they agreed; and that it was with a load of genial respectability, and in my cabinet.
# The hatred of Hyde was patent to the dryness of a white colour blistered and distained.
# Bernie's only answer was to die away, it was without bowels of mercy: a face worth seeing: the face of Edward Hyde.
# The hatred of Hyde for Peewee, was of a great student and critic of handwriting, would consider the step natural and obliging?Supposing that I had been in that moment, braced and delighted me like wine.
# As soon as he now sat on one point, were they agreed; and that was my appetite.
# He was ashamed of his strange associates, of the pulse.
# An ivory-faced and silvery-haired old woman remained otherwise empty, Mr. Hyde that racked me.
# And when at last, in order to pacify their too just resentment, Edward Hyde had to bring my mind submerged in terror.
# Small sounds carried far; domestic sounds out of good wine; and Mr. Utterson a sincere and warm affection.
# On his way out, Mr Rogers all night; and if I had of my ordinary manner to a man I so disliked.
# Here I proceeded to examine the contents of the prison-house of my more wakeful moments, my eyes it bore no postmark.
# To this rule, Dr. Peewee had returned six months before, to serve as a bagpipe.
# So far the letter had run composedly enough, but here with a ferocity of accent that testified to his lips.
# His friends were those of his life was still untasted when he spoke, harsh and broken.

# %%
import nltk
with io.open("ToUse.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    
tokens = nltk.word_tokenize(essays)
tagged = nltk.pos_tag(tokens)
nouns = [word for word,pos in tagged \
	if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
downcased = [x.lower() for x in nouns]
joined = " ".join(downcased).encode('utf-8')
into_string = str(nouns)

output = open("output.txt", "w")
output.write(joined)
output.close()

# %%
import nltk
import Bt
import io
with io.open("ToUse.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    print essays

# %%
import nltk
import Bt
import io
with io.open("ToUse.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 
    #essays = u"""text here"""
    #f = open("ToUse.txt")
    #essays = f.read()
    #essays = Bt.badtext(essays)
    #essays = str(essays)
    #essays = essays.encode('utf-8')

    tokens = nltk.word_tokenize(essays)
    tagged = nltk.pos_tag(tokens)
    nouns = [word for word,pos in tagged \
    if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
    downcased = [x.lower() for x in nouns]
    joined = " ".join(downcased).encode('utf-8')
    into_string = str(nouns)
    texout = into_string.replace("', u'", "  ")
    texout = texout.replace("\u2018", "")
    texout = texout.replace("\u2019 ", "")
    texout = texout.replace("%", "")
    texout = texout.replace("[u'", "")
    texout = texout.replace("']", "")
    output = open("output2.txt", "w")
    output.write(texout)
    output.close()    
    print texout
# Out:
# space  lines  front  height  rule  forces  memory  people  graciousness  table  people  number  Long  masses  dust  soldiers  ground  beforehand  fatigue  weight  task  life  apparatus  night  thinking  opposite  Freud  sum  energy  consciousness  idea  expression  punishments  others  households  enemy  onslaught  defeat  Men  enemy  relation  water  waters  pass  distance  enemy  thousand  exhaustion  way_  conduct  war  advantage  conduct  effort  difficulty  night  betoken  alarm  computer  index  files  day  repositories  update  index  week-ends  Tales  class  Florida  computer  index  files  permission  error  file  permissions  computer  index  files  perception  system  spot  working  connection_  _approximation  time  moment  ignition  analysis  United  States  mother  tomb  general  Speech  psychology  war  stratagem  plans  regard  occasion  hearts  men  upon  troops  plans  day  victory  country  information  accomplishment  country  service  rights  ground  issue  diagram  surface  description  part  light  light  rivers  earth  heat  wall  look  drawings  facsimile  Hence  spot  forehead..  cast  shadow  pyramid  chin  eyes  Alps  France  Italy  THE  IMAGES  IN  THE  PUPIL  THE  RAYS  WHETHER  SHADED  OR  LUMINOUS  HAVE  GREATER  STRENGTH  AND  EFFECT  AT  THEIR  SIDES  size  object  bodies  space  image  weeks  WHAT  PORTION  A  WALL  SURFACE  LEAST  LUMINOUS  WHICH  IS  SEEN  UNDER  THE  LEAST  AMOUNT  OF  LIGHT  distance  shadow  Which  air  Compound  shadows  bodyis  view  light  shadow  side  side  edges  base  form  colour  intersection  rest  sea  planes  object  make  blue  practice  middle  movements  size  head  Shadow  partakes  window  angle  author  refers  morning  light  Scuba  Diving  Lessons  computer  index  repository  box  apostrophes  place  database  project  Saltman  database  Google  Drive  voice  auto-space  period  voice  files  files  box  apostrophes  place  weeks  function  file  configure  image  database  share  permission  error  file  permissions  upgrades  Characters  UN-SALTMAN  location  things  people  Philippines  party  drunk  friend  mine  bit  challenge  database  Google  Drive  voice  auto-space  period  voice  terminal  Tales  commands  tar  configure  file  enter  program  Online  Repository  Resources  drinks  postings  readers  Air  Horns  set  air  horns  world  Dude  decision  bond  Windows  Linux  tube  spark  plug  county  death  abandonment  Windows  XP  home  jet  engine  igniter  home  paper  bit  Mac  Computers  gas  friend  motorcycles  van  spark  plug  garage  fire  jet  engine  igniter  home  power  failure  reinstall  exhibits  core  DOS  Dude  time  home  jet  engine  county  death  abandonment  Windows  XP  Air  Horns  set  air  horns  world  Dude  garage  fire  gas  spark  plug  garage  examining  modifying  Windows  project  gas  country  engine  school  flame  flames  spark  plug  OPP  Almost  pieces  paper  spark  plug  country  dance  halls  mind  thought  exhibits  home  jet  engine  buzzer  electricity  command  line  lot  people  hardware  upgrade  Philippines  Microsoft  Linux  Philippines  Microsoft  interest  Ubuntu  Linux  picture  igniter  spark  plug  filters  records  event  wire  Handlers  table  message  handler  logger  attributes  methods  logger  name  hierarchy  root  logger  delegation  record  resources  handler  Filters  wire  dictionary  keys  record  message  INFO  logger  thread  lock  level  handler  LogRecord  filter  method  message  Filename  portion  message  logger  Logging  messages  point  Python  package  namespace  handler   filters  root  filter  record  multiple  times  name  filters  turn  Formatter  class  value  record  Logger  object  t  dictionary  logger  example  keys  logger  ERROR  logger  glance  heart  passion  paper  growl  London  round  closet  item  thing  passions  Hyde  house  bondage  energy  life  Bernie  patience  henceforth  life  effort  virtue  control  offices  life  Six  hours  side  longi ...

# %%
import nltk
import Bt
#essays = u"""text here"""
f = open("ToUse.txt")
essays = f.read()
essays = Bt.badtext(essays)
essays = str(essays)
#essays = essays.encode('utf-8')

tokens = nltk.word_tokenize(essays)
tagged = nltk.pos_tag(tokens)
nouns = [word for word,pos in tagged \
if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
downcased = [x.lower() for x in nouns]
joined = " ".join(downcased).encode('utf-8')
into_string = str(nouns)
output = open("output2.txt", "w")
output.write(joined)
output.close()

# %%
import Txmanip
from Txmanip import NoNumRange
NoNumRange.nonumRange("ToUse.txt",1,20)
# Out:
# ToUse.txt 1 20
# He manages his forces as though they were only a memory.
# Some people are exceeding graciousness and familiar with the table. Those people are fewer in number.
# Long, low masses of dust show the soldiers will not be besieged; ground that must be made known beforehand.
# It was thus her wish to sleep. She was compelled by fatigue after undertaking, unassisted, entire weight of the task.
# Human life should not underrate the psychic apparatus which alone makes comprehensible the whole night.
# All thinking is only the opposite of conscious. Although we cannot identify what it is.
# Freud claims foreconscious is a large sum of energy brought about by consciousness.
# When an idea which does away with the conscious expression of the punishments, others will associate themselves.
# She loved only those who were distinguished in her households.
# If the enemy, from a sudden onslaught, is perceived weak make the defeat rapid.
# Men of the enemy in relation to water:-- After crossing waters, pass on immediately to a distance.
# Now, of the enemy, we may go a thousand leagues without exhaustion.
# The way_ or the proper conduct of war will not reap advantage. Do not let proper conduct weaken the effort.
# Their difficulty lies in the night betoken alarm.
# The computer will download an index of the files within one day.
# Non-sanctioned repositories must be made executable.
# It automatically backs itself up and ready to go.
# It takes the sudo apt-get update udates the index of the the week-ends.
# Welcome to The Tales of the first class came I was in Florida.
# The computer will download an index of files, it does not install them.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
from pass_phrase import pass_phrase
adjectives = pass_phrase.generate_wordlist("pass_phrase/adjectives.txt")
nouns = pass_phrase.generate_wordlist("pass_phrase/nouns.txt")
verbs = pass_phrase.generate_wordlist("pass_phrase/verbs.txt")
pass_phrase.passphrase(adjectives, nouns, verbs, " ")
# Out:
# 'greasy kite shop mammoth property'

# %%
import markovify
f = open("hashtag.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
for i in range(28):
    print(text_model.make_short_sentence(140))
    virtual =(text_model.make_short_sentence(140))
    virtual = virtual.replace("...",".")
    virtual = virtual.replace("..",".")
    virtual = virtual.replace(".",".\n")
    with open("virtual.txt", "a") as nf:
        nf.write(virtual)
# Out:
# A #Recompense, #sheeshpic.twitter.com/iFCnmx11JR You need a #man that wants you on every aspect of your home or #workstation.
# I'm just going to hell.
# => #EntBullets #3wordQuote #MakeYourOwnLane #defstar5 #mpgvip #spdc #seo #smm #ml #Entbullets #10X Keep Calm and enjoy Life.
# You are a disgrace.
# People went for a Good Life.
# I #StandUp for my #birthday.
# #NFLBoycottpic.twitter.com/E9V6W2mACl Due to many fans aren't afraid to give up that responsibility.
# You are what's wrong with these republicans?
# #Other ways to stop cancer.
# I'd be very upset with God Seeing the faces and hearing the stories of the people of PR like a painting.
# #PuertoRico #CNN #MSNBC #HuffPost What do you think is #underrated?
# #LOST Premiered 13 years ago, #LOST premiered.
# They hate it so hard to get it #Question: is “hope springs eternal” a good time and it ends up people losing lives or getting injuried.
# #Dontwatchnflgame But still I fought, because our country out of whack!
# Imagine Fox News outrage if Obama threw paper towels to needy in #PuertoRico reminds me of European Kings throwing coins to peasants.
# #none “so that from the rising of the premiere of #LOST premiered.
# #LOST premiered 13 years ago today #Lost premiered.
# How is this possible?! #morningjoe #newday Wake up Bernie people.
# #Arrested #Fatal4 1643/1677pic.twitter.com/crBvre21UR This witch needs to settle and move on.
# Earth, Wind & Fire night is just around the clock with Governor @RicardoRossello & his team.
# It is still the greatest, the most @VillageShrinkpic.twitter.com/ixxIUiwvUW There's no telling what this WHACKO is going to hell.
# Do you want to see all this.
# Thank you for you.
# #BBC #SKY #UK “The #TRAITOR #PhilipHammond a #Political WORM trying to breach & stumbled on new intruders.
# #guncontrol #VegasStrong #vegasshooting #Vegas I'm a freak yeah,......I'm fully equipped for the anthem?
# #pets #dogs #cats #birds #hamsters #other I have seen in #PuertoRico having a mental illness than there is none besides me.
# #illegalalien According to NV LAW, Stephen Paddock is a cost for #war.
# #Vegas Las Vegas tomorrow.

# %%
import markovify
f = open("ToUse.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
for i in range(18):
    print(text_model.make_short_sentence(140))
    virtual =(text_model.make_short_sentence(140))
    with open("virtual.txt", "a") as nf:
        nf.write(virtual)
# Out:
# Presently her eye wandered to the gallows, but the intersection as throughout the rest.
# If the enemy, from a pickled event received over the spark plug.
# It will show you their shaded side, because on that side of the drug had to reach over the spark plug.
# OPP ! Almost all the folks asleep--street after street, and all judges of good wine.
# The hatred of Hyde was patent to the building which was equipped with neither bell nor knocker.
# At the time the logging messagei Human-readable time when the exception information to be specified.
# Wherefore the good general's Speech on the court by three dusty windows barred with iron.
# Do formatting for a moment for ignition.
# There are three windows was half-way open; and sitting there by the jet engine using an an igniter I built at home.
# My project of the favorite exhibits was a home made jet engine using an an igniter I built at home.
# Out of the prison-house of my second character, my faculties seemed sharpened to a distance.
# LogRecord instances are used for unpickled records received from a command line freaks a lot of people out.
# If one returns a false value, the handler will not emit the same record multiple times.
# Tidy up any resources used by the laboratory or the proper conduct of war will not care about errors in the garage on fire.
# And then by a sudden splutter of the newly added repository are available.
# The light which surrounds the derived shadow will resemble a pyramid the same Logger object.
# That being said, you must reply with a function to permit the file called configure.
# The LogRecord has a filter initialized with the current exception information, or None if no exception has occurred, None.

# %%
import markovify
# Get raw text as string
with open("realDonaldTrump.txt") as f:
    text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print three randomly-generated sentences of no more than 140 characters

for i in range(20):
    print(text_model.make_short_sentence(140))
    virtual =(text_model.make_short_sentence(140))
    with open("virtual.txt", "a") as nf:
        nf.write(virtual)
# Out:
# Today I will be a great event in honor of wonderful Senator @JoniErnst.
# Thank you ....Transgender individuals to serve as Commander-in-Chief to the cost of its 300 workers.
# RT @TeamTrump: Law enforcement &amp; military did a spectacular job at Homeland Security.
# I wonder if it wasn't for #CrookedHillary.
# Our plan will lower premiums &amp; deductibles - and this Administration continues to..
# @HillaryClinton claims she needs a “public and a group of leading business women to discuss tax reform and tax cuts.
# Another attack in Egypt.
# We will bring JOBS BACK!
# @IngrahamAngle Leaving now for an expedited hearing of the speech on urban renewal.
# But look at other alternatives.
# Just cannot believe a judge would put our country we cannot safely vet.
# RT @foxandfriends: Report accuses material James Comey leaks will be a great honor to be #AmericaFirst.
# Very happy and impressed with 15-0 United Nations Security Council just voted 15-0 to sanction North Korea.
# Fake News CNN is looking better than ever!
# Luther Strange has gone up a lot in the process of fixing it.
# I hope people are looking tough and smart!
# I'm turning to @FoxNews where we get a special prosecutor to look sinister!
# Made all of the truly great people, what a crowd!
# While I am your voice.
# Most politicians would have campaigned in N.Y.

# %%
#badtext = ''.join(c for c in map(chr, range(256)) if not c.isalnum())

# %%
import markovify
# Get raw text as string
with open("elonmusk.txt") as f:
    text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print three randomly-generated sentences of no more than 140 characters

for i in range(18):
    print(text_model.make_short_sentence(140))
    virtual =(text_model.make_short_sentence(140))
    with open("virtual.txt", "a") as nf:
        nf.write(virtual)
# Out:
# Hope you like my Model X 75D-Overall Winner of the upcoming software releases.
# Hearing from constituents is super important to be released… RT @Space_Station: .@SpaceX gets ready for #Dragon launch.
# It matters to us that you took a risk on a tristate border might work.
# Thanks @CNBC! “@Lebeaucarnews: The Model S has you covered https://t.co/1cL19qX8ox https://t.co/AdWlrXHxRg @drew definitely aliens!
# Must proceed with primary mission to launch mission 3 to dock with the territory.
# Next attempt in 2 to 3 months.
# What esthetic and functionality improvements would be much appreciated.
# @karaswisher I am actually going to spend money.
# That serious enough for Twitter?
# RT @NASA: 2015 was the warmest year on a Model X P90D for wife, Triple White.
# @SnoozeThroughF1 There will be big enough to fit people.
# Wd like to thank people personally for supporting Tesla and DOE loan today.
# Battery storage of solar power needed for high velocity missions https://t.co/n6j0mExAqM Sad to hear about the @OrbitalSciences launch.
# All good on the roof.
# A brief rise in $TSLA stock obviously does no good for Tesla thanks to all engines operating at max.
# High g landings v sensitive to all cars @Scott_Helme can't always detect babies and pets Can be turned on or off.
# @vigneshraju of course it will be progress on this matter is unwarranted.
# A China factory for local demand cd be as little as half an hour in hot sun.

# %%
import re
import textwrap
import time
import sqlite3
import sys
import base64
import time
#conn = sqlite3.connect('hurricane.db')
#c = conn.cursor()
# Create table
#c.execute('''CREATE TABLE hurricane
#             (hurricane text, keywords text)''')
count=0
with open("hurricane_14.txt") as f:
    text = f.read()
    words = " ".join(re.findall("[a-zA-Z]+", text))
    words = words.replace(' u ', ' ');words = words.replace('u ', '');words = words.replace(' U ', ' ')
    chars_per_line = 140
    for i in range(0, len(words), chars_per_line):
        file= ("[(",words[i:i+chars_per_line],"),]")
        #data= ("[('"+words[i:i+chars_per_line]+"'),]")
        file = str(file)
        #file = 'base64 encoding allows code to be stored and retieved in the same format it was posted'
        b = 'hurricane, hurricaneirma, florida'
        conn = sqlite3.connect('hurricane.db')
        c = conn.cursor()
        time.sleep(1)
        #encodedlistvalue=base64.b64encode(file[2:-2])
        #c.execute("INSERT INTO hurricane VALUES (?,?)", (encodedlistvalue, b)) 
        c.execute("INSERT INTO hurricane VALUES (?,?)", (file, b)) 
        conn.commit()
        conn.close()        
        
        
        time.sleep(1)
        print file[2:-2]
        count=count+1
        print count
        if count>400:

            sys.exit()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-1a0f0f4fdc25> in <module>()
#      12 #             (hurricane text, keywords text)''')
#      13 count=0
# ---> 14 with open("hurricane_14.txt") as f:
#      15     text = f.read()
#      16     words = " ".join(re.findall("[a-zA-Z]+", text))
#
# IOError: [Errno 2] No such file or directory: 'hurricane_14.txt'

# %%
import re
import textwrap
import time
import sqlite3
import sys
import base64
'''

conn = sqlite3.connect('data/400.db')
c = conn.cursor()
c.execute(''CREATE TABLE hurricane
             (hurricane text, keywords text)'')
             '''
count=0             
with open("hurricane_14.txt") as f:
    text = f.read()
    words = " ".join(re.findall("[a-zA-Z]+", text))
    words = words.replace(' u ', ' ');words = words.replace('u ', '');words = words.replace(' U ', ' ')
    #twitter friendly "under 140" for status
    chars_per_line = 400
    for i in range(0, len(words), chars_per_line):
        
        file= ("[(",words[i:i+chars_per_line],"),]")
        #data= ("[('"+words[i:i+chars_per_line]+"'),]")
        file = str(file)
        time.sleep(1)
        #file = 'base64 encoding allows code to be stored and retieved in the same format it was posted'
        conn = sqlite3.connect('data/400.db')
        c = conn.cursor()
        b = 'florida, hurricane, Irma, base64'
        encodedlistvalue=base64.b64encode(file[2:-2])
        c.execute("INSERT INTO hurr VALUES (?,?)", (encodedlistvalue, b))
        time.sleep(1)
        conn.commit()
        conn.close() 
        #Apply a pause so viewing line perline insert is possible
        time.sleep(1)
        count=count+1
        print file[2:-2],count
        

sys.exit()

# %%
conn = sqlite3.connect('hurricane14.db')
c = conn.cursor()# Never 
t = ('hurricane',)
for row in c.execute('SELECT * FROM hurricane'):
        s2 = row[0].encode('ascii')
        encodedlistvalue=base64.b64decode(s2)
        print encodedlistvalue, '\n', 'hurricane:', row[1], '\n -----------------------------\n'

# %%
import re
import textwrap
from datetime import datetime
import string
from nltk.stem.lancaster import LancasterStemmer
from nltk.corpus import stopwords
def get_text_cleaned(tweet):
    tweet = tweet.replace("u'", "");tweet = tweet.replace(" id ", "\n id")
    return tweet

def get_text_sanitized(tweet):    
    return ' '.join([w.lower().strip().rstrip(string.punctuation)\
        .lstrip(string.punctuation).strip()\
        for w in get_text_cleaned(tweet).split()\
        if w.strip().rstrip(string.punctuation).strip()])

with open("/home/jack/Desktop/imagebot/hurricane_14.txt") as f:
    tweet = f.read()
    
    
    
    
    words =get_text_sanitized(tweet)
    print(textwrap.fill(words, 115)).encode('utf-8')
# Out:
# contributors none truncated false text good weather in oklahoma but still praying for texas and
# florida\u0001f4af\u0001f4af\u0001f4af\u0001f4aa\u0001f4aa\u0001f4aa is_quote_status false in_reply_to_status_id
# none id 907747392098848770 favorite_count 0 entities symbols user_mentions hashtags urls retweeted false
# coordinates none source a href="http://twitter.com/download/android rel="nofollow">twitter for android</a
# in_reply_to_screen_name none in_reply_to_user_id none retweet_count 0 id_str 907747392098848770 favorited false
# user follow_request_sent false has_extended_profile true profile_use_background_image true default_profile_image
# false id 894407721935659008 profile_background_image_url_https none verified false translator_type none
# profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/894409739815333888/yabwrfnx_normal.jpg profile_sidebar_fill_color ddeef6
# entities description urls followers_count 17 profile_sidebar_border_color c0deed id_str 894407721935659008
# profile_background_color f5f8fa listed_count 0 is_translation_enabled false utc_offset none statuses_count 4
# description down to earth just a young nigga with goals and ambition to be something in life it just take
# time\u0001f4af\u0001f4aa\u0001f4aa friends_count 56 location muskogee ok profile_link_color 1da1f2
# profile_image_url http://pbs.twimg.com/profile_images/894409739815333888/yabwrfnx_normal.jpg following false
# geo_enabled false profile_banner_url https://pbs.twimg.com/profile_banners/894407721935659008/1502078872
# profile_background_image_url none screen_name ceaundra lang en profile_background_tile false favourites_count 2
# name ceaundrae jones notifications false url none created_at mon aug 07 03:59:53 0000 2017 contributors_enabled
# false time_zone none protected false default_profile true is_translator false geo none in_reply_to_user_id_str none
# lang en created_at tue sep 12 23:26:58 0000 2017 in_reply_to_status_id_str none place none metadata
# iso_language_code en result_type recent'}}{contributors none truncated false text rt johnjacob pray for
# florida"\n\nflorida https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907747391973060609
# favorite_count 0 entities symbols user_mentions id 620636208 indices 3 14 id_str 620636208 screen_name johnjacob
# name john jacob hashtags urls media source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907747391973060609
# favorited false retweeted_status contributors none truncated false text pray for florida"\n\nflorida
# https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907124280781090817 favorite_count
# 251644 entities symbols user_mentions hashtags urls media source_user_id 375720631 source_status_id_str
# 907061155843244032 expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url
# pic.twitter.com/riubffvpir url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907124280781090817
# favorited false user follow_request_sent false has_extended_profile true profile_use_background_image true
# default_profile_image false id 620636208 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg verified
# false translator_type none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg profile_sidebar_fill_color ddeef6
# entities url urls url https://t.co/tjhxvtaguu indices 0 23 expanded_url http://instagram.com/johnjjacob display_url
# instagram.com/johnjjacob description urls followers_count 5327 profile_sidebar_border_color ffffff id_str 620636208
# profile_background_color c0deed listed_count 39 is_translation_enabled false utc_offset 10800 statuses_count 26595
# description snap\u0001f47b jjohnjacob instagram johnjjacob friends_count 1996 location an\xe1polis
# profile_link_color 0084b4 profile_image_url
# http://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/620636208/1505223656 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg screen_name
# johnjacob lang en profile_background_tile true favourites_count 27689 name john jacob notifications false url
# https://t.co/tjhxvtaguu created_at thu jun 28 02:27:56 0000 2012 contributors_enabled false time_zone brasilia
# protected false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive
# false lang pt created_at mon sep 11 06:10:56 0000 2017 in_reply_to_status_id_str none place none extended_entities
# media additional_media_info monetizable false source_user_id 375720631 source_status_id_str 907061155843244032
# expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir
# url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent user follow_request_sent false has_extended_profile true
# profile_use_background_image true default_profile_image false id 1876276194 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 333333
# profile_image_url_https https://pbs.twimg.com/profile_images/887826103544446976/kkqmrkwm_normal.jpg
# profile_sidebar_fill_color ddeef6 entities description urls followers_count 145 profile_sidebar_border_color c0deed
# id_str 1876276194 profile_background_color c0deed listed_count 1 is_translation_enabled false utc_offset none
# statuses_count 997 description madrid-ibiza friends_count 153 location vicente calder\xf3n profile_link_color
# 1da1f2 profile_image_url http://pbs.twimg.com/profile_images/887826103544446976/kkqmrkwm_normal.jpg following false
# geo_enabled false profile_banner_url https://pbs.twimg.com/profile_banners/1876276194/1500549085
# profile_background_image_url http://abs.twimg.com/images/themes/theme1/bg.png screen_name miguel_mgp lang es
# profile_background_tile false favourites_count 1015 name miguel notifications false url none created_at tue sep 17
# 17:40:06 0000 2013 contributors_enabled false time_zone none protected false default_profile true is_translator
# false geo none in_reply_to_user_id_str none possibly_sensitive false lang pt created_at tue sep 12 23:26:58 0000
# 2017 in_reply_to_status_id_str none place none extended_entities media additional_media_info monetizable false
# source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent'}}{contributors none truncated false text rt jocho aeeonline terminan de
# poner la luz en todo florida,orlando y a mi no me llega la luz gracias is_quote_status false in_reply_to_status_id
# none id 907747391008378881 favorite_count 0 entities symbols user_mentions id 35741910 indices 3 10 id_str 35741910
# screen_name jocho name la j id 773532715 indices 12 22 id_str 773532715 screen_name aeeonline name aee hashtags
# urls retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 12 id_str 907747391008378881
# favorited false retweeted_status contributors none truncated false text aeeonline terminan de poner la luz en todo
# florida,orlando y a mi no me llega la luz gracias is_quote_status false in_reply_to_status_id 907597786652311552 id
# 907599038924587008 favorite_count 81 entities symbols user_mentions id 773532715 indices 0 10 id_str 773532715
# screen_name aeeonline name aee hashtags urls retweeted false coordinates none source a
# href="http://twitter.com/download/iphone rel="nofollow">twitter for iphone</a in_reply_to_screen_name aeeonline
# in_reply_to_user_id 773532715 retweet_count 12 id_str 907599038924587008 favorited false user follow_request_sent
# false has_extended_profile true profile_use_background_image true default_profile_image false id 35741910
# profile_background_image_url_https https://pbs.twimg.com/profile_background_images/123775288/tape-music-
# wallpapers_12951_1600x1200.jpg verified false translator_type none profile_text_color 142908
# profile_image_url_https https://pbs.twimg.com/profile_images/878984911746719744/ubbpf1gh_normal.jpg
# profile_sidebar_fill_color a80d0d entities description urls followers_count 1212 profile_sidebar_border_color
# b00c6f id_str 35741910 profile_background_color 1a1a1f listed_count 20 is_translation_enabled false utc_offset
# 25200 statuses_count 161359 description since 2009 photographer team lakers team apple team colombia
# paisarrique\xf1o no es roncar es actuar veterano friends_count 647 location puerto rico colombia profile_link_color
# 0519fa profile_image_url http://pbs.twimg.com/profile_images/878984911746719744/ubbpf1gh_normal.jpg following false
# geo_enabled false profile_banner_url https://pbs.twimg.com/profile_banners/35741910/1473128518
# profile_background_image_url http://pbs.twimg.com/profile_background_images/123775288/tape-music-
# wallpapers_12951_1600x1200.jpg screen_name jocho lang en profile_background_tile true favourites_count 637 name la
# j notifications false url none created_at mon apr 27 13:35:01 0000 2009 contributors_enabled false time_zone
# pacific time us canada protected false default_profile false is_translator false geo none in_reply_to_user_id_str
# 773532715 lang es created_at tue sep 12 13:37:27 0000 2017 in_reply_to_status_id_str 907597786652311552 place none
# metadata iso_language_code es result_type recent user follow_request_sent false has_extended_profile false
# profile_use_background_image true default_profile_image false id 194806778 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 333333
# profile_image_url_https https://pbs.twimg.com/profile_images/860653763098533888/iptfazlp_normal.jpg
# profile_sidebar_fill_color ddeef6 entities description urls followers_count 1803 profile_sidebar_border_color
# c0deed id_str 194806778 profile_background_color c0deed listed_count 54 is_translation_enabled false utc_offset
# none statuses_count 38061 description happy mom to chester and max mets baseball fan my kitties make me tweet for
# them u0001f63b friends_count 3956 location puerto rico profile_link_color 1da1f2 profile_image_url
# http://pbs.twimg.com/profile_images/860653763098533888/iptfazlp_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/194806778/1494169794 profile_background_image_url
# http://abs.twimg.com/images/themes/theme1/bg.png screen_name pukipie lang en profile_background_tile false
# favourites_count 34392 name chester max mom notifications false url none created_at sat sep 25 01:20:52 0000 2010
# contributors_enabled false time_zone none protected false default_profile true is_translator false geo none
# in_reply_to_user_id_str none lang es created_at tue sep 12 23:26:57 0000 2017 in_reply_to_status_id_str none place
# none metadata iso_language_code es result_type recent'}}{contributors none truncated false text rt roadkingmag
# thoughts and prayers to everyone in florida hit by hurricane irma staypositive hurricaneirma truckersontheway
# is_quote_status false in_reply_to_status_id none id 907747390869848064 favorite_count 0 entities symbols
# user_mentions id 57447721 indices 3 15 id_str 57447721 screen_name roadkingmag name road king magazine hashtags
# indices 84 97 text staypositive indices 98 112 text hurricaneirma indices 113 130 text truckersontheway urls
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 1 id_str 907747390869848064 favorited
# false retweeted_status contributors none truncated false text thoughts and prayers to everyone in florida hit by
# hurricane irma staypositive hurricaneirma truckersontheway is_quote_status false in_reply_to_status_id none id
# 907215614674178048 favorite_count 4 entities symbols user_mentions hashtags indices 67 80 text staypositive indices
# 81 95 text hurricaneirma indices 96 113 text truckersontheway urls retweeted false coordinates none source a
# href="http://www.hootsuite.com rel="nofollow">hootsuite</a in_reply_to_screen_name none in_reply_to_user_id none
# retweet_count 1 id_str 907215614674178048 favorited false user follow_request_sent false has_extended_profile false
# profile_use_background_image true default_profile_image false id 57447721 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/461940819138592768/xpm8sfvu.jpeg verified false translator_type
# none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/905093365787746307/tkq5egyf_normal.jpg profile_sidebar_fill_color efefef
# entities url urls url http://t.co/bgetmmxpdg indices 0 22 expanded_url http://www.roadking.com display_url
# roadking.com description urls followers_count 8751 profile_sidebar_border_color ffffff id_str 57447721
# profile_background_color acded6 listed_count 136 is_translation_enabled false utc_offset 18000 statuses_count 1261
# description road king magazine focuses on the lifestyle stories issues that affect over-the-road truck drivers
# roadkingmagazine is free at all ta petro locations friends_count 1526 location profile_link_color 0061aa
# profile_image_url http://pbs.twimg.com/profile_images/905093365787746307/tkq5egyf_normal.jpg following false
# geo_enabled false profile_banner_url https://pbs.twimg.com/profile_banners/57447721/1487969504
# profile_background_image_url http://pbs.twimg.com/profile_background_images/461940819138592768/xpm8sfvu.jpeg
# screen_name roadkingmag lang en profile_background_tile false favourites_count 963 name road king magazine
# notifications false url http://t.co/bgetmmxpdg created_at thu jul 16 21:10:45 0000 2009 contributors_enabled false
# time_zone central time us canada protected false default_profile false is_translator false geo none
# in_reply_to_user_id_str none lang en created_at mon sep 11 12:13:52 0000 2017 in_reply_to_status_id_str none place
# none metadata iso_language_code en result_type recent user follow_request_sent false has_extended_profile false
# profile_use_background_image true default_profile_image false id 2615677806 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/487265440222044160/blg8pizh.jpeg verified false translator_type
# none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/487263541414473728/2zsxedgb_normal.jpeg profile_sidebar_fill_color ddeef6
# entities url urls url http://t.co/r6tqzvn8j indices 0 22 expanded_url http://wylietrucking.com display_url
# wylietrucking.com description urls url https://t.co/q90guvzn7i indices 70 93 expanded_url http://wylietough.com
# display_url wylietough.com followers_count 255 profile_sidebar_border_color ffffff id_str 2615677806
# profile_background_color 131516 listed_count 8 is_translation_enabled false utc_offset 18000 statuses_count 877
# description wylietough wyliegear flatbed otr stepdeck heavyhaul wylietough https://t.co/q90guvzn7i friends_count
# 197 location west fargo nd profile_link_color 009999 profile_image_url
# http://pbs.twimg.com/profile_images/487263541414473728/2zsxedgb_normal.jpeg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/2615677806/1459699173 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/487265440222044160/blg8pizh.jpeg screen_name ewwyliecorp lang en
# profile_background_tile false favourites_count 791 name ew wylie corporation notifications false url
# http://t.co/r6tqzvn8j created_at thu jul 10 15:38:05 0000 2014 contributors_enabled false time_zone central time us
# canada protected false default_profile false is_translator false geo none in_reply_to_user_id_str none lang en
# created_at tue sep 12 23:26:57 0000 2017 in_reply_to_status_id_str none place none metadata iso_language_code en
# result_type recent'}}{contributors none truncated false text rt johnjacob pray for florida"\n\nflorida
# https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907747390664400896 favorite_count 0
# entities symbols user_mentions id 620636208 indices 3 14 id_str 620636208 screen_name johnjacob name john jacob
# hashtags urls media source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907747390664400896
# favorited false retweeted_status contributors none truncated false text pray for florida"\n\nflorida
# https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907124280781090817 favorite_count
# 251644 entities symbols user_mentions hashtags urls media source_user_id 375720631 source_status_id_str
# 907061155843244032 expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url
# pic.twitter.com/riubffvpir url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907124280781090817
# favorited false user follow_request_sent false has_extended_profile true profile_use_background_image true
# default_profile_image false id 620636208 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg verified
# false translator_type none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg profile_sidebar_fill_color ddeef6
# entities url urls url https://t.co/tjhxvtaguu indices 0 23 expanded_url http://instagram.com/johnjjacob display_url
# instagram.com/johnjjacob description urls followers_count 5327 profile_sidebar_border_color ffffff id_str 620636208
# profile_background_color c0deed listed_count 39 is_translation_enabled false utc_offset 10800 statuses_count 26595
# description snap\u0001f47b jjohnjacob instagram johnjjacob friends_count 1996 location an\xe1polis
# profile_link_color 0084b4 profile_image_url
# http://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/620636208/1505223656 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg screen_name
# johnjacob lang en profile_background_tile true favourites_count 27689 name john jacob notifications false url
# https://t.co/tjhxvtaguu created_at thu jun 28 02:27:56 0000 2012 contributors_enabled false time_zone brasilia
# protected false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive
# false lang pt created_at mon sep 11 06:10:56 0000 2017 in_reply_to_status_id_str none place none extended_entities
# media additional_media_info monetizable false source_user_id 375720631 source_status_id_str 907061155843244032
# expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir
# url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent user follow_request_sent false has_extended_profile true
# profile_use_background_image true default_profile_image false id 146940871 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/696619165/1c5437ec6e9719facafc63646c08be90.jpeg verified false
# translator_type none profile_text_color ffffff profile_image_url_https
# https://pbs.twimg.com/profile_images/895225403371114496/m8zor3pg_normal.jpg profile_sidebar_fill_color 000000
# entities description urls followers_count 1904 profile_sidebar_border_color ffffff id_str 146940871
# profile_background_color 000000 listed_count 1 is_translation_enabled false utc_offset 18000 statuses_count 53431
# description bamastate u0001f41d pray think act repeat friends_count 2701 location profile_link_color 7d8385
# profile_image_url http://pbs.twimg.com/profile_images/895225403371114496/m8zor3pg_normal.jpg following false
# geo_enabled true profile_banner_url https://pbs.twimg.com/profile_banners/146940871/1503283419
# profile_background_image_url
# http://pbs.twimg.com/profile_background_images/696619165/1c5437ec6e9719facafc63646c08be90.jpeg screen_name
# coolbreez3 lang en profile_background_tile true favourites_count 1392 name mjr notifications false url none
# created_at sat may 22 19:17:52 0000 2010 contributors_enabled false time_zone central time us canada protected
# false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive false lang
# pt created_at tue sep 12 23:26:57 0000 2017 in_reply_to_status_id_str none place none extended_entities media
# additional_media_info monetizable false source_user_id 375720631 source_status_id_str 907061155843244032
# expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir
# url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent'}}{contributors none truncated false text rt johnjacob pray for
# florida"\n\nflorida https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907747390396002304
# favorite_count 0 entities symbols user_mentions id 620636208 indices 3 14 id_str 620636208 screen_name johnjacob
# name john jacob hashtags urls media source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/android rel="nofollow">twitter for
# android</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907747390396002304
# favorited false retweeted_status contributors none truncated false text pray for florida"\n\nflorida
# https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907124280781090817 favorite_count
# 251644 entities symbols user_mentions hashtags urls media source_user_id 375720631 source_status_id_str
# 907061155843244032 expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url
# pic.twitter.com/riubffvpir url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198498 id_str 907124280781090817
# favorited false user follow_request_sent false has_extended_profile true profile_use_background_image true
# default_profile_image false id 620636208 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg verified
# false translator_type none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg profile_sidebar_fill_color ddeef6
# entities url urls url https://t.co/tjhxvtaguu indices 0 23 expanded_url http://instagram.com/johnjjacob display_url
# instagram.com/johnjjacob description urls followers_count 5327 profile_sidebar_border_color ffffff id_str 620636208
# profile_background_color c0deed listed_count 39 is_translation_enabled false utc_offset 10800 statuses_count 26595
# description snap\u0001f47b jjohnjacob instagram johnjjacob friends_count 1996 location an\xe1polis
# profile_link_color 0084b4 profile_image_url
# http://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/620636208/1505223656 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg screen_name
# johnjacob lang en profile_background_tile true favourites_count 27689 name john jacob notifications false url
# https://t.co/tjhxvtaguu created_at thu jun 28 02:27:56 0000 2012 contributors_enabled false time_zone brasilia
# protected false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive
# false lang pt created_at mon sep 11 06:10:56 0000 2017 in_reply_to_status_id_str none place none extended_entities
# media additional_media_info monetizable false source_user_id 375720631 source_status_id_str 907061155843244032
# expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir
# url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent user follow_request_sent false has_extended_profile true
# profile_use_background_image true default_profile_image false id 2303748454 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 333333
# profile_image_url_https https://pbs.twimg.com/profile_images/663686547259170817/2qq4e4gg_normal.jpg
# profile_sidebar_fill_color ddeef6 entities description urls followers_count 400 profile_sidebar_border_color c0deed
# id_str 2303748454 profile_background_color c0deed listed_count 0 is_translation_enabled false utc_offset none
# statuses_count 7197 description y llegas como un trueno cargando mi electricidad different is beautiful xxiv y
# recordad ni\xf1xs n\u0001f913 u0001f60e r u b e l a n g e l e s r e a l u0001f60e u0001f913 friends_count 1969
# location cogeces del monte valladolid profile_link_color 1da1f2 profile_image_url
# http://pbs.twimg.com/profile_images/663686547259170817/2qq4e4gg_normal.jpg following false geo_enabled false
# profile_banner_url https://pbs.twimg.com/profile_banners/2303748454/1445912665 profile_background_image_url
# http://abs.twimg.com/images/themes/theme1/bg.png screen_name sariitah93 lang es profile_background_tile false
# favourites_count 5680 name sakura xxiv notifications false url none created_at sat jan 25 15:38:54 0000 2014
# contributors_enabled false time_zone none protected false default_profile true is_translator false geo none
# in_reply_to_user_id_str none possibly_sensitive false lang pt created_at tue sep 12 23:26:57 0000 2017
# in_reply_to_status_id_str none place none extended_entities media additional_media_info monetizable false
# source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent'}}{contributors none truncated false text u"rt foxnews fema 90 of florida
# keys homes damaged or destroyed https://t.co/hidmvbbudj is_quote_status false in_reply_to_status_id none id
# 907747389200576514 favorite_count 0 entities symbols user_mentions id 1367531 indices 3 11 id_str 1367531
# screen_name foxnews name fox news hashtags urls media source_user_id 1367531 source_status_id_str
# 907742671355047938 expanded_url https://twitter.com/foxnews/status/907742671355047938/video/1 display_url
# pic.twitter.com/hidmvbbudj url https://t.co/hidmvbbudj media_url_https
# https://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg source_user_id_str 1367531
# source_status_id 907742671355047938 id_str 907742356354383872 sizes small h 191 resize fit w 340 large h 576 resize
# fit w 1024 medium h 338 resize fit w 600 thumb h 150 resize crop w 150 indices 67 90 type photo id
# 907742356354383872 media_url http://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 168 id_str 907747389200576514
# favorited false retweeted_status contributors none truncated false text u"fema 90 of florida keys homes damaged or
# destroyed https://t.co/hidmvbbudj is_quote_status false in_reply_to_status_id none id 907742671355047938
# favorite_count 148 entities symbols user_mentions hashtags urls media expanded_url
# https://twitter.com/foxnews/status/907742671355047938/video/1 display_url pic.twitter.com/hidmvbbudj url
# https://t.co/hidmvbbudj media_url_https
# https://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg id_str 907742356354383872
# sizes small h 191 resize fit w 340 large h 576 resize fit w 1024 medium h 338 resize fit w 600 thumb h 150 resize
# crop w 150 indices 54 77 type photo id 907742356354383872 media_url
# http://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg retweeted false coordinates
# none source a href="https://studio.twitter.com rel="nofollow">media studio</a in_reply_to_screen_name none
# in_reply_to_user_id none retweet_count 168 id_str 907742671355047938 favorited false user follow_request_sent false
# has_extended_profile false profile_use_background_image true default_profile_image false id 1367531
# profile_background_image_url_https https://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg verified
# true translator_type regular profile_text_color 000000 profile_image_url_https
# https://pbs.twimg.com/profile_images/794654746342662144/hhnfe4sx_normal.jpg profile_sidebar_fill_color f4f4f4
# entities url urls url http://t.co/zyg58xztac indices 0 22 expanded_url http://www.foxnews.com display_url
# foxnews.com description urls followers_count 15897281 profile_sidebar_border_color ffffff id_str 1367531
# profile_background_color 0e2331 listed_count 60530 is_translation_enabled true utc_offset 14400 statuses_count
# 329529 description u"america\u2019s strongest primetime lineup anywhere follow america's 1 cable news network
# delivering you breaking news insightful analysis and must-see videos friends_count 419 location u.s.a
# profile_link_color 183a52 profile_image_url
# http://pbs.twimg.com/profile_images/794654746342662144/hhnfe4sx_normal.jpg following true geo_enabled false
# profile_banner_url https://pbs.twimg.com/profile_banners/1367531/1492649996 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg screen_name foxnews lang en
# profile_background_tile false favourites_count 1 name fox news notifications false url http://t.co/zyg58xztac
# created_at sat mar 17 19:01:26 0000 2007 contributors_enabled false time_zone eastern time us canada protected
# false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive false lang
# en created_at tue sep 12 23:08:12 0000 2017 in_reply_to_status_id_str none place none extended_entities media
# additional_media_info monetizable false embeddable true description title expanded_url
# https://twitter.com/foxnews/status/907742671355047938/video/1 display_url pic.twitter.com/hidmvbbudj url
# https://t.co/hidmvbbudj media_url_https
# https://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg video_info aspect_ratio 16 9
# duration_millis 153753 variants url
# https://video.twimg.com/amplify_video/907742356354383872/vid/320x180/adnl_prvadpmgfoo.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/amplify_video/907742356354383872/pl/mfleosh902f2radz.m3u8
# content_type application/x-mpegurl url https://video.twimg.com/amplify_video/907742356354383872/vid/640x360
# /ky7hiz7izwvg-zup.mp4 bitrate 832000 content_type video/mp4 url
# https://video.twimg.com/amplify_video/907742356354383872/vid/1280x720/ezzdymtizy8q-ku4.mp4 bitrate 2176000
# content_type video/mp4 id_str 907742356354383872 sizes small h 191 resize fit w 340 large h 576 resize fit w 1024
# medium h 338 resize fit w 600 thumb h 150 resize crop w 150 indices 54 77 type video id 907742356354383872
# media_url http://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg metadata
# iso_language_code en result_type recent user follow_request_sent false has_extended_profile false
# profile_use_background_image true default_profile_image false id 379363124 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 333333
# profile_image_url_https https://pbs.twimg.com/profile_images/843915322893783041/p8ttz8v4_normal.jpg
# profile_sidebar_fill_color ddeef6 entities description urls followers_count 105 profile_sidebar_border_color c0deed
# id_str 379363124 profile_background_color c0deed listed_count 4 is_translation_enabled false utc_offset none
# statuses_count 5380 description u"wife,mom nurse hate to be disappointed don't lie to me friends_count 98 location
# avon in profile_link_color 1da1f2 profile_image_url
# http://pbs.twimg.com/profile_images/843915322893783041/p8ttz8v4_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/379363124/1490040013 profile_background_image_url
# http://abs.twimg.com/images/themes/theme1/bg.png screen_name barb_schneider0 lang en profile_background_tile false
# favourites_count 5115 name barb schneider notifications false url none created_at sat sep 24 20:41:41 0000 2011
# contributors_enabled false time_zone none protected false default_profile true is_translator false geo none
# in_reply_to_user_id_str none possibly_sensitive false lang en created_at tue sep 12 23:26:57 0000 2017
# in_reply_to_status_id_str none place none extended_entities media additional_media_info monetizable false
# source_user follow_request_sent false has_extended_profile false profile_use_background_image true
# default_profile_image false id 1367531 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg verified true translator_type regular
# profile_text_color 000000 profile_image_url_https
# https://pbs.twimg.com/profile_images/794654746342662144/hhnfe4sx_normal.jpg profile_sidebar_fill_color f4f4f4
# entities url urls url http://t.co/zyg58xztac indices 0 22 expanded_url http://www.foxnews.com display_url
# foxnews.com description urls followers_count 15897281 profile_sidebar_border_color ffffff id_str 1367531
# profile_background_color 0e2331 listed_count 60530 is_translation_enabled true utc_offset 14400 statuses_count
# 329529 description u"america\u2019s strongest primetime lineup anywhere follow america's 1 cable news network
# delivering you breaking news insightful analysis and must-see videos friends_count 419 location u.s.a
# profile_link_color 183a52 profile_image_url
# http://pbs.twimg.com/profile_images/794654746342662144/hhnfe4sx_normal.jpg following true geo_enabled false
# profile_banner_url https://pbs.twimg.com/profile_banners/1367531/1492649996 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/414488415/xyz123abc.jpg screen_name foxnews lang en
# profile_background_tile false favourites_count 1 name fox news notifications false url http://t.co/zyg58xztac
# created_at sat mar 17 19:01:26 0000 2007 contributors_enabled false time_zone eastern time us canada protected
# false default_profile false is_translator false embeddable true description title source_user_id 1367531
# source_status_id_str 907742671355047938 expanded_url https://twitter.com/foxnews/status/907742671355047938/video/1
# display_url pic.twitter.com/hidmvbbudj url https://t.co/hidmvbbudj media_url_https
# https://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg source_user_id_str 1367531
# source_status_id 907742671355047938 video_info aspect_ratio 16 9 duration_millis 153753 variants url
# https://video.twimg.com/amplify_video/907742356354383872/vid/320x180/adnl_prvadpmgfoo.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/amplify_video/907742356354383872/pl/mfleosh902f2radz.m3u8
# content_type application/x-mpegurl url https://video.twimg.com/amplify_video/907742356354383872/vid/640x360
# /ky7hiz7izwvg-zup.mp4 bitrate 832000 content_type video/mp4 url
# https://video.twimg.com/amplify_video/907742356354383872/vid/1280x720/ezzdymtizy8q-ku4.mp4 bitrate 2176000
# content_type video/mp4 id_str 907742356354383872 sizes small h 191 resize fit w 340 large h 576 resize fit w 1024
# medium h 338 resize fit w 600 thumb h 150 resize crop w 150 indices 67 90 type video id 907742356354383872
# media_url http://pbs.twimg.com/amplify_video_thumb/907742356354383872/img/4rtpcyophdoxlezm.jpg metadata
# iso_language_code en result_type recent'}}{contributors none truncated false text rt nbcnews watch sister margaret
# ann clears debris with a chainsaw in south florida n\n(via miami-dade police https://t.co/bbmvyyrezq
# is_quote_status false in_reply_to_status_id none id 907747389188042753 favorite_count 0 entities symbols
# user_mentions id 14173315 indices 3 11 id_str 14173315 screen_name nbcnews name nbc news hashtags urls media
# source_user_id 14173315 source_status_id_str 907718979917045762 expanded_url
# https://twitter.com/nbcnews/status/907718979917045762/video/1 display_url pic.twitter.com/bbmvyyrezq url
# https://t.co/bbmvyyrezq media_url_https https://pbs.twimg.com/amplify_video_thumb/907717046858784768/img
# /xrxyniv_sok-3jgc.jpg source_user_id_str 14173315 source_status_id 907718979917045762 id_str 907717046858784768
# sizes small h 604 resize fit w 340 large h 1280 resize fit w 720 medium h 1067 resize fit w 600 thumb h 150 resize
# crop w 150 indices 114 137 type photo id 907717046858784768 media_url
# http://pbs.twimg.com/amplify_video_thumb/907717046858784768/img/xrxyniv_sok-3jgc.jpg retweeted false coordinates
# none source a href="http://twitter.com rel="nofollow">twitter web client</a in_reply_to_screen_name none
# in_reply_to_user_id none retweet_count 588 id_str 907747389188042753 favorited false retweeted_status contributors
# none truncated false text watch sister margaret ann clears debris with a chainsaw in south florida n\n(via miami-
# dade police https://t.co/bbmvyyrezq is_quote_status false in_reply_to_status_id none id 907718979917045762
# favorite_count 1372 entities symbols user_mentions hashtags urls media expanded_url
# https://twitter.com/nbcnews/status/907718979917045762/video/1 display_url pic.twitter.com/bbmvyyrezq url
# https://t.co/bbmvyyrezq media_url_https https://pbs.twimg.com/amplify_video_thumb/907717046858784768/img
# /xrxyniv_sok-3jgc.jpg id_str 907717046858784768 sizes small h 604 resize fit w 340 large h 1280 resize fit w 720
# medium h 1067 resize fit w 600 thumb h 150 resize crop w 150 indices 101 124 type photo id 907717046858784768
# media_url http://pbs.twimg.com/amplify_video_thumb/907717046858784768/img/xrxyniv_sok-3jgc.jpg retweeted false
# coordinates none source a href="https://studio.twitter.com rel="nofollow">media studio</a in_reply_to_screen_name
# none in_reply_to_user_id none retweet_count 588 id_str 907718979917045762 favorited false user follow_request_sent
# ...
# content_type video/mp4 url
# https://video.twimg.com/amplify_video/907717046858784768/vid/720x1280/w8tcprj_m4rn03v5.mp4 bitrate 2176000
# content_type video/mp4 url https://video.twimg.com/amplify_video/907717046858784768/pl/svzhnibmd_z5f40b.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/amplify_video/907717046858784768/vid/180x320/hs9m9knrhuephuf2.mp4 bitrate 320000
# content_type video/mp4 id_str 907717046858784768 sizes small h 604 resize fit w 340 large h 1280 resize fit w 720
# medium h 1067 resize fit w 600 thumb h 150 resize crop w 150 indices 114 137 type video id 907717046858784768
# media_url http://pbs.twimg.com/amplify_video_thumb/907717046858784768/img/xrxyniv_sok-3jgc.jpg metadata
# iso_language_code en result_type recent'}}{contributors none truncated false text abcworldnews take a drone over
# live oak florida and all you will see is suwannee valley amp electric is_quote_status false in_reply_to_status_id
# 906686332973584386 id 907747385874546688 favorite_count 0 entities symbols user_mentions id 86141342 indices 0 13
# id_str 86141342 screen_name abcworldnews name world news tonight hashtags urls retweeted false coordinates none
# source a href="http://twitter.com/download/iphone rel="nofollow">twitter for iphone</a in_reply_to_screen_name
# abcworldnews in_reply_to_user_id 86141342 retweet_count 0 id_str 907747385874546688 favorited false user
# follow_request_sent false has_extended_profile false profile_use_background_image true default_profile_image false
# id 713794082867441664 profile_background_image_url_https none verified false translator_type none
# profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/888182167167275008/f-mlblgp_normal.jpg profile_sidebar_fill_color ddeef6
# entities description urls followers_count 119 profile_sidebar_border_color c0deed id_str 713794082867441664
# profile_background_color f5f8fa listed_count 1 is_translation_enabled false utc_offset none statuses_count 1011
# description friends_count 155 location profile_link_color 1da1f2 profile_image_url
# http://pbs.twimg.com/profile_images/888182167167275008/f-mlblgp_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/713794082867441664/1498866555 profile_background_image_url
# none screen_name bigdawg_70 lang en profile_background_tile false favourites_count 10620 name ricky allen
# notifications false url none created_at sat mar 26 18:25:45 0000 2016 contributors_enabled false time_zone none
# protected false default_profile true is_translator false geo none in_reply_to_user_id_str 86141342 lang en
# created_at tue sep 12 23:26:56 0000 2017 in_reply_to_status_id_str 906686332973584386 place none metadata
# iso_language_code en result_type recent'}}{contributors none truncated false text rt united we are resuming full
# operations in florida tomorrow 9/13 check our complete irma operations outlook https://t.co/vksbx7cxcn\u2026
# is_quote_status false in_reply_to_status_id none id 907747384205172736 favorite_count 0 entities symbols
# user_mentions id 260907612 indices 3 10 id_str 260907612 screen_name united name united hashtags indices 90 95 text
# irma urls url https://t.co/vksbx7cxcn indices 116 139 expanded_url http://uafly.co/vgpdwr display_url
# uafly.co/vgpdwr retweeted false coordinates none source a href="http://twitter.com/download/iphone
# rel="nofollow">twitter for iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 13 id_str
# 907747384205172736 favorited false retweeted_status contributors none truncated true text we are resuming full
# operations in florida tomorrow 9/13 check our complete irma operations outlook:\u2026 https://t.co/1tghuqygak
# is_quote_status false in_reply_to_status_id none id 907742967586332674 favorite_count 21 entities symbols
# user_mentions hashtags indices 78 83 text irma urls url https://t.co/1tghuqygak indices 105 128 expanded_url
# https://twitter.com/i/web/status/907742967586332674 display_url twitter.com/i/web/status/9\u2026 retweeted false
# coordinates none source a href="http://twitter.com rel="nofollow">twitter web client</a in_reply_to_screen_name
# none in_reply_to_user_id none retweet_count 13 id_str 907742967586332674 favorited false user follow_request_sent
# false has_extended_profile false profile_use_background_image true default_profile_image false id 260907612
# profile_background_image_url_https https://pbs.twimg.com/profile_background_images/628613516706983936/_staj7q2.jpg
# verified true translator_type none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/881109023227072514/v3co5ucm_normal.jpg profile_sidebar_fill_color ddeef6
# entities url urls url https://t.co/zbk6agonwz indices 0 23 expanded_url https://hub.united.com display_url
# hub.united.com description urls url https://t.co/cpgjundsve indices 104 127 expanded_url http://united.com/feedback
# display_url united.com/feedback followers_count 945409 profile_sidebar_border_color ffffff id_str 260907612
# profile_background_color 000000 listed_count 5980 is_translation_enabled false utc_offset 18000 statuses_count
# 840304 description conversations with you here are 140 characters-friendly tweet us any time for a formal response
# visit https://t.co/cpgjundsve friends_count 46393 location profile_link_color 0084b4 profile_image_url
# http://pbs.twimg.com/profile_images/881109023227072514/v3co5ucm_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/260907612/1474466275 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/628613516706983936/_staj7q2.jpg screen_name united lang en
# profile_background_tile true favourites_count 2434 name united notifications false url https://t.co/zbk6agonwz
# created_at fri mar 04 21:23:11 0000 2011 contributors_enabled false time_zone central time us canada protected
# false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive false lang
# en created_at tue sep 12 23:09:23 0000 2017 in_reply_to_status_id_str none place none metadata iso_language_code en
# result_type recent user follow_request_sent false has_extended_profile true profile_use_background_image false
# default_profile_image false id 741209969886920704 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 000000
# profile_image_url_https https://pbs.twimg.com/profile_images/876089665740308480/g-d63xpb_normal.jpg
# profile_sidebar_fill_color 000000 entities url urls url https://t.co/rkxlvpktxj indices 0 23 expanded_url
# http://breakingflightnews.jimdo.com display_url breakingflightnews.jimdo.com description urls followers_count 3728
# profile_sidebar_border_color 000000 id_str 741209969886920704 profile_background_color 000000 listed_count 60
# is_translation_enabled false utc_offset 7200 statuses_count 7647 description aviation emergencies diversions
# deliveries daily news more various sources avgeek friends_count 1280 location ham dus profile_link_color 1b95e0
# profile_image_url http://pbs.twimg.com/profile_images/876089665740308480/g-d63xpb_normal.jpg following false
# geo_enabled false profile_banner_url https://pbs.twimg.com/profile_banners/741209969886920704/1497711180
# profile_background_image_url http://abs.twimg.com/images/themes/theme1/bg.png screen_name flightbreaking lang en
# profile_background_tile false favourites_count 2414 name breaking flight news notifications false url
# https://t.co/rkxlvpktxj created_at fri jun 10 10:06:42 0000 2016 contributors_enabled false time_zone berlin
# protected false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive
# false lang en created_at tue sep 12 23:26:56 0000 2017 in_reply_to_status_id_str none place none metadata
# iso_language_code en result_type recent'}}{contributors none truncated false text rt johnjacob pray for
# florida"\n\nflorida https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907747394783252480
# favorite_count 0 entities symbols user_mentions id 620636208 indices 3 14 id_str 620636208 screen_name johnjacob
# name john jacob hashtags urls media source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/android rel="nofollow">twitter for
# android</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198501 id_str 907747394783252480
# favorited false retweeted_status contributors none truncated false text pray for florida"\n\nflorida
# https://t.co/riubffvpir is_quote_status false in_reply_to_status_id none id 907124280781090817 favorite_count
# 251650 entities symbols user_mentions hashtags urls media source_user_id 375720631 source_status_id_str
# 907061155843244032 expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url
# pic.twitter.com/riubffvpir url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h
# 640 resize fit w 640 medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type photo id
# 907061095466123264 media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg
# retweeted false coordinates none source a href="http://twitter.com/download/iphone rel="nofollow">twitter for
# iphone</a in_reply_to_screen_name none in_reply_to_user_id none retweet_count 198501 id_str 907124280781090817
# favorited false user follow_request_sent false has_extended_profile true profile_use_background_image true
# default_profile_image false id 620636208 profile_background_image_url_https
# https://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg verified
# false translator_type none profile_text_color 333333 profile_image_url_https
# https://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg profile_sidebar_fill_color ddeef6
# entities url urls url https://t.co/tjhxvtaguu indices 0 23 expanded_url http://instagram.com/johnjjacob display_url
# instagram.com/johnjjacob description urls followers_count 5327 profile_sidebar_border_color ffffff id_str 620636208
# profile_background_color c0deed listed_count 39 is_translation_enabled false utc_offset 10800 statuses_count 26595
# description snap\u0001f47b jjohnjacob instagram johnjjacob friends_count 1996 location an\xe1polis
# profile_link_color 0084b4 profile_image_url
# http://pbs.twimg.com/profile_images/891167306189078529/83uy12md_normal.jpg following false geo_enabled true
# profile_banner_url https://pbs.twimg.com/profile_banners/620636208/1505223656 profile_background_image_url
# http://pbs.twimg.com/profile_background_images/378800000018161012/f11155c45c43eb9fae3114513ce4d21e.jpeg screen_name
# johnjacob lang en profile_background_tile true favourites_count 27689 name john jacob notifications false url
# https://t.co/tjhxvtaguu created_at thu jun 28 02:27:56 0000 2012 contributors_enabled false time_zone brasilia
# protected false default_profile false is_translator false geo none in_reply_to_user_id_str none possibly_sensitive
# false lang pt created_at mon sep 11 06:10:56 0000 2017 in_reply_to_status_id_str none place none extended_entities
# media additional_media_info monetizable false source_user_id 375720631 source_status_id_str 907061155843244032
# expanded_url https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir
# url https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 29 52 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent user follow_request_sent false has_extended_profile true
# profile_use_background_image false default_profile_image false id 3941775316 profile_background_image_url_https
# https://abs.twimg.com/images/themes/theme1/bg.png verified false translator_type none profile_text_color 000000
# profile_image_url_https https://pbs.twimg.com/profile_images/844036691979571200/ctv_nspj_normal.jpg
# profile_sidebar_fill_color 000000 entities description urls followers_count 48 profile_sidebar_border_color 000000
# id_str 3941775316 profile_background_color 000000 listed_count 0 is_translation_enabled false utc_offset none
# statuses_count 971 description miasanmia u0001f1e9\u0001f1ea friends_count 172 location montr\xe9al-nord
# montr\xe9al profile_link_color 1b95e0 profile_image_url
# http://pbs.twimg.com/profile_images/844036691979571200/ctv_nspj_normal.jpg following false geo_enabled false
# profile_banner_url https://pbs.twimg.com/profile_banners/3941775316/1504062240 profile_background_image_url
# http://abs.twimg.com/images/themes/theme1/bg.png screen_name g19elias lang fr profile_background_tile false
# favourites_count 1272 name num\xe9ro19 u0001f534\u26aa notifications false url none created_at tue oct 13 00:23:14
# 0000 2015 contributors_enabled false time_zone none protected false default_profile false is_translator false geo
# none in_reply_to_user_id_str none possibly_sensitive false lang pt created_at tue sep 12 23:26:58 0000 2017
# in_reply_to_status_id_str none place none extended_entities media additional_media_info monetizable false
# source_user_id 375720631 source_status_id_str 907061155843244032 expanded_url
# https://twitter.com/geiwajima/status/907061155843244032/video/1 display_url pic.twitter.com/riubffvpir url
# https://t.co/riubffvpir media_url_https
# https://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg source_user_id_str
# 375720631 source_status_id 907061155843244032 video_info aspect_ratio 1 1 duration_millis 15267 variants url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/240x240/vphqbqwj0qbjwz-w.mp4 bitrate 320000
# content_type video/mp4 url https://video.twimg.com/ext_tw_video/907061095466123264/pu/pl/uszt3hz8id4ozjfy.m3u8
# content_type application/x-mpegurl url
# https://video.twimg.com/ext_tw_video/907061095466123264/pu/vid/480x480/cdy3emt5aw9eb_fs.mp4 bitrate 832000
# content_type video/mp4 id_str 907061095466123264 sizes small h 340 resize fit w 340 large h 640 resize fit w 640
# medium h 600 resize fit w 600 thumb h 150 resize crop w 150 indices 45 68 type video id 907061095466123264
# media_url http://pbs.twimg.com/ext_tw_video_thumb/907061095466123264/pu/img/vdjvmyghlamenvct.jpg metadata
# iso_language_code pt result_type recent

# %%
import csv
import io
with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
    for row in csv.reader(my_file):
        print row
# Out:
# ['id', 'created_at', 'text']
# ['916124989736308736', '2017-10-06 02:16:32', 'RT @FoxBusiness: #StockAlert: U.S. markets since the election https://t.co/1kwamJuizO']
# -----------------------------------------------------------------
# UnicodeEncodeError              Traceback (most recent call last)
# <ipython-input-90-e39957c9f732> in <module>()
#       2 import io
#       3 with io.open("realDonaldTrump_tweets.csv", "r", encoding="utf-8") as my_file:
# ----> 4     for row in csv.reader(my_file):
#       5         print row
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2026' in position 182: ordinal not in range(128)

# %%
def periodtonewline():
    with open('savE.txt') as infile, open('savE_sentence.txt', 'w') as outfile:
        for line in infile:
            line = line.replace(".",".\n");line = line.replace(" ‘","");
            line = line.replace("’","")
            outfile.write(line)  # non-empty
            
periodtonewline()

# %%
import markovify
f = open("grimm.txt")
text = f.read()
text_model_a = markovify.Text(text)


ebook_b =open('hekel.txt')
text0 = ebook_b.read()
text_model_b = markovify.Text(text0)
for i in range(5):
    print(text_model_b.make_short_sentence(140))
    STR0 = (text_model_b.make_short_sentence(140))
    savE = open('savE.txt', 'a')
    savE.write(STR0)
    savE.close()

# 2. Print five randomly-generated sentences
for i in range(5):
    print(text_model_a.make_short_sentence(140))
    STR = (text_model_a.make_short_sentence(140))
    savE = open('savE.txt', 'a')
    savE.write(STR)
    savE.close()
# 3. Print three randomly-generated sentences of no more than 140 characters
for i in range(5):
    print(text_model_a.make_short_sentence(140))
    STR2 = (text_model_a.make_short_sentence(140))
    savE = open('savE.txt', 'a')
    savE.write(STR2)
    savE.close()
# Combine the models into a single one
both_models = markovify.combine([text_model_a,text_model_b])
for i in range(5):
    print(both_models.make_short_sentence(140))    
    STR3 = (both_models.make_short_sentence(140))  
    savE = open('savE.txt', 'a')
    savE.write(STR3)
    savE.close()
# Out:
# The murderer was gone long ago; but there came no reply.
# Where Utterson was amazed to find it a document endorsed on the flags, they found the key, already stained with rust.
# It was not until they had all started and made greater haste.
# His terror of the prison-house of my previous experience, seemed, like the captives of Philippi, that which stood within ran forth.
# Men have before hired bravos to transact their crimes, while their own pale and fearful countenances stooping to look in.
# Little Marleen went upstairs into a bush; and when she came to ask what you deserve; are you dead?’
# But as he lives!
# Before half an hour, and cook and wash and knit and spin for them, they laughed heartily; and the same way and that frightened me.’
# A little while began to cry out for opportunities, and then the river gave him for a beautiful bird am I!’
# Then he will let me go.’
# The little tailor was sitting playing with her hair as black as ebony; and she did not hear, but were quite red.
# At last the peasant nudged his wife, and half a kingdom.’
# The father said: ‘If you are no gardener’s boy; tell me, who?’
# Then the fox bid him be of use to you while you are tired you are!
# I am going in search of work, had not gone far before they grew clear again, and went to his master’s house.
# When he came back, knocked at the king’s three daughters.
# They embraced their dear son again.
# It was a roaring sound in health and rich in purse, what should I know?
# In that case, dear Lanyon, do my twelve daughters dance at the spinning-wheels.’
# I saw my life to the ground and broke.

# %%
import re
def periodpattern():
    with open('savE.txt') as infile:
        for line in infile:
            line = line.replace(" ‘","")
            line = line.replace("’","")
            line = line.replace(".",".\n")
            line = line.replace("!","!\n")
            line = line.replace("?","?\n")
            
            print line
            outfile2 = open('savE_patern.txt', 'w')
            outfile2.write(line)  # non-empty
            outfile2.close()
            
periodpattern()
# Out:
# Then the prince took care to throw you one which was not the right time!
# Yet will I go home.
# The ant-king had come out again.
# She replied,Go farther into the water, and how then should he find out where you got that gold, or I shall not be worth much.
# He rode on, and has brought you here?
#  do come in, and went forward.
# Chanticleer observing that they could see the dove.
# I will run into the kitchen, and one will fall down dead: the cloak home with his dear child altogether from the three branches and the prince had thus been gone a long time, he said:Take your cap off, it is not done quite as you can.
# On this the doctor that he had been born, and next day at noon, when he had in mind, and said:Seek one for yourself with the head answered:Bride, bride, there thou gangest!
# If we care to do all this?
# So he went in and out of the company, marched up to her master came and brought home his royal coat.
# He must be dreaming, said the man,go with me, and I suppose the other after it go!
# However, the horseman got off, took the silver, helped Hans up, gave him the coffin; but the moment it touched her head, the poison was so powerful that she fell off her stool, and overset the milk-pail.
# When the water in which I boiled them to the young lady, the best way is for neither of you to your home; for he wanted to get away; but he had no hope of finding it.
# Then Lina said:Fundevogel, never leave me, and I will soon serve up, answered Gretel.
# But the countryman seized his fiddle, and travelled on very pleased with his bargain.
# He rose up without delay, eager to start on his way some time he came back, knocked at the door of her own child, and she was married to him, and when he smelt the wine, he was unable to recover himself, he was drowned.
# I shall put them into your head.
# In front of the mill and begged for shelter.
# The bird came down, and all the pomp and brightness of the court was there.
# Snow-white was married to a princess, and had a good deal of gold in the world.
# At last she came to the bed, covered him over and lay down with his skin beside him, and the bear was already close.
# I gave in the cabinet door was shut against Mr Rogers.
# Guest's eyes brightened, and he was much in the same quick, light way with it; and yet somehow lovable.
# When the time of the dwarfs third gift.
# Whilst she was safe at home with it; and then his golden ball fell into the bargain; and do all the land.

# %%
import markovify
f = open("realDonaldTrump.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
STR = (text_model.make_short_sentence(110))
print STR
# Out:
# It is now failing in Georgia.

# %%
import markovify
f = open("grimm.txt")
text = f.read()
text_model_a = markovify.Text(text)
# 2. Print five randomly-generated sentences
for i in range(5):
    print(text_model_a.make_sentence())
    STR = (text_model_a.make_sentence())
    savE = open('savE.txt', 'a')
    savE.write(STR)
    savE.close()
# 3. Print three randomly-generated sentences of no more than 140 characters
for i in range(3):
    print(text_model_a.make_short_sentence(120))
    STR2 = (text_model_a.make_short_sentence(120))
    savE = open('savE.txt', 'a')
    savE.write(STR2)
    savE.close()
# Out:
# So each brother went his way, and said he would but watch in it she wrapped all the good fairy came to the astonishment of everyone, he came into the forest, and in the mountains, saying, as before, and a drink of water, and the groom lay snoring with his dear little son, and thought to himself: ‘If I had him put in an earthenware bowl, and not made for you!
# Then the cat had a compassionate heart he cried: ‘Dear Mr Bear, spare me, I will teach you to take a walk a little of his victory. ‘I am not knocking you.’
# ‘Ah!’ said the dwarf; ‘don’t you see the maiden aside, and said, ‘I will be able to set out into the cave, other giants were left behind with no goods to share the last rays of the beard was caught too fast. ‘I have nothing but unhappiness with you.
# But the sparrow sat on the spot. ‘Unlucky wretch that I cannot prevent the sun scorches so that he would come back he thought: ‘It would be a fine king truly who travels about in his heart, and are wise enough to live upon; so I have done a wiser man than thou wert.’
# Then the first dish.
# When he entered a forest.
# He had the dog across the stream; and this time were used to him to his heart.
# What are you still wish to go everywhere.

# %%
import markovify
f = open("realDonaldTrump.txt")
text = f.read()# Recreate the model using 3 sentences
three_model = markovify.Text(text,state_size=3)
for i in range(5):
    print(three_model.make_short_sentence(140))
    STR = (three_model.make_short_sentence(140))
    savE = open('savE.txt', 'a')
    savE.write(STR)
    savE.close()
    print STR
# Out:
# FEMA and First Responders are doing a great job - the world is watching!
# Interesting how the U.S. sells Taiwan billions of dollars and millions of jobs.
# We will get through this - and we will bring back our dreams!
# Federal Government is on site and I will be interviewed on @foxandfriends tomorrow at 7am.
# Honored to serve as #POTUS.
# My Administration will be focused on decisive and overwhelming.....
# I have NOTHING to do with his life?
# Today we express our deepest gratitude to all those affected by the tragic storms and tornadoes in the Southeastern United States.
# America is w/ you!… https://t.co/YyZodzPSqW I am pleased to inform you Kellyanne is in the audience.
# We have made more progress in the last ten days or so!

# %%
import markovify
f = open("grimm.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
STR = (text_model.make_short_sentence(140))
savE = open('savE.txt', 'a')
savE.write(STR)
savE.close()
print STR
# Out:
# The ant-king had come out again.’

# %%
import markovify
f = open("ToUse.txt")
text = f.read()
# Build the model.
text_model = markovify.Text(text)
# Print randomly-generated sentences of no more than 140 characters
#http://paulbourke.net/fractals/
STR = (text_model.make_short_sentence(110))
print STR
# Out:
# As soon as he now sat on the psychology of war was inexcusable.

# %%
def generate_the_word(infile):
        with open(infile) as f:
            contents_of_file = f.read()
        lines = contents_of_file.splitlines()
        line_number = random.randrange(0, len(lines))
        return lines[line_number]

infile = "ToUse.txt" 
generate_the_word(infile)
# Out:
# 'Working from a command line freaks a lot of people out.'

# %%
import FileLen
from random import randint
# maX is the number of lines in the file
maX = FileLen.filelen("ToUse.txt")
# pick a random number between 0 and maX as:  num
num = randint(0, maX)
with open('ToUse.txt') as f:
    for i, line in enumerate(f, 1):
        # if line = num break
        if i == num:
            break

#print the line           
print line
# Out:
# I saw a county just getting introduced to the death and abandonment of Windows XP.

# %%
import RandomLine

filename = "realDonaldTrump.txt"    
RandomLine.randomline(filename)
# Out:
# Big excitement last night in the Great State of Pennsylvania! Fantastic crowd and people. MAKE AMERICA GREAT AGAIN!

# %%
from random import randint
Max = FileLen.filelen("ToUse.txt")
num = randint(0, Max)
with open('ToUse.txt') as f:
    for i, STR in enumerate(f, 1):
        if i == num:
            break
#STR = line
print STR
# Out:
# Air Horns there were a large set of air horns in the world is this Dude writing an E-book then.

# %%
search = raw_input("find  ")
file = open("ToUse.txt")
lines = file.readlines()
for line in lines:
    if search in line:print line
    if search == True:
        file.close()
        exit()
file.close()
# Out:
# find  war
# The way_ or the proper conduct of war will not reap advantage. Do not let proper conduct weaken the effort.
#
# Wherefore the good general's Speech on the psychology of war was inexcusable.
#
# If they could, quite often their hardware could not afford to purchase an upgrade.
#
# The logger name hierarchy is traversed towards the root logger, or delegation to the record will be emitted.
#
# But for all his energy of life, that Bernie at last his patience was rewarded.
#
# Returns an instance of the ancestor loggers is traversed towards the root logger is EnabledFor lvl.
#
# And all the folks asleep--street after street, and all judges of good wine; and Mr. Utterson a sincere and warm.
#
# Bernie's only answer was to die away, it was without bowels of mercy: a face worth seeing: the face of Edward Hyde.
#
# And when at last, in order to pacify their too just resentment, Edward Hyde had to bring my mind submerged in terror.
#
# Small sounds carried far. Like sounds out of good wine. They are sincere and of warm affection.

# %%
from Txmanip import HeadFirst
HeadFirst.headFirst("realDonaldTrump_tweets.csv")
# Out:
# LineNumber : 1
# id,created_at,text
#
# LineNumber : 2
# 916124989736308736,2017-10-06 02:16:32,RT @FoxBusiness: #StockAlert: U.S. markets since the election https://t.co/1kwamJuizO
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/jack/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import random
afile = open("realDonaldTrump_tweets.csv","r")
line = next(afile)
for num, aline in enumerate(afile):
    if random.randrange(num + 2): continue
    line = aline.replace("\n", "")
print line
# Out:
# 781619038699094016,2016-09-29 22:17:55,"While Hillary profits off the rigged system, I am fighting for you! Remember the simple phrase: #FollowTheMoney… https://t.co/8mVInc82E9"

# %%
import random
def random_line(afile):
    line = next(afile)
    for num, aline in enumerate(afile):
        if random.randrange(num + 2): continue
        line = aline.replace("\n", "")
    return line
afile = open("realDonaldTrump_tweets.csv", "r")
STR = random_line(afile)
print STR
# Out:
# 892814520942460928,2017-08-02 18:29:04,I campaigned on creating a merit-based immigration system that protects U.S. workers &amp; taxpayers. Watch:… https://t.co/b8yIifGY3d

# %%
import sqlite3
conn = sqlite3.connect('twitter.db')
c = conn.cursor()
c.execute("""
CREATE VIRTUAL TABLE hurr 
USING FTS3(text, keywords);
""")
conn.commit()
conn.close()

# %%
import re
import textwrap
import time
import sqlite3
import sys
import base64
import time
conn = sqlite3.connect('twittertext.db')
c = conn.cursor()
#Create table
#CREATE VIRTUAL TABLE hurr 
#USING FTS3(text, keywords)


c.execute('''CREATE VIRTUAL TABLE twitter
             USING FTS3 (twittertext)''')
count=0
lines = 400
with open("hashtag.txt") as f:
    text = f.read()
    words = " ".join(re.findall("[a-zA-Z]+", text))
    words = words.replace(' u ', ' ');words = words.replace('u ', '');words = words.replace(' U ', ' ')
    chars_per_line = 400
    for i in range(0, len(words), chars_per_line):
        file= ("[(",words[i:i+chars_per_line],"),]")
        #data= ("[('"+words[i:i+chars_per_line]+"'),]")
        file = str(file)
        #file = 'base64 encoding allows code to be stored and retieved in the same format it was posted'
        #keywords = 'sept, nonapi, china, philippines'
        conn = sqlite3.connect('twittertext.db')
        c = conn.cursor()
        time.sleep(1)
        #encodedlistvalue=base64.b64encode(file[2:-2])
        #c.execute("INSERT INTO hurricane VALUES (?,?)", (encodedlistvalue, b)) 
        c.execute("INSERT INTO twitter VALUES (?)", (file,)) 
        conn.commit()
        conn.close()        
        
        
        #time.sleep(1)
        print file[2:-2]
        count=count+1
        print count
        if count>lines:
            sys.exit()
#commits and closes database if there are less then 400 lines of text
conn.commit()
conn.close()

# %%
from flask import Flask, request
import sys
sys.path.insert(0, "/usr/local/lib/python2.7/dist-packages")
from flask_restful import Resource, Api
import sqlite3
import time

app = Flask(__name__)
api = Api(app)

conn = sqlite3.connect('twittertext.db')
c = conn.cursor()# Never 
count=1
param = raw_input("What Words are you looking for?")
num = input("How many to display?")

for row in c.execute('SELECT twittertext FROM twitter WHERE twittertext MATCH ?', (param,)):
    time.sleep(1)
    print count,":",(row),"\n-----\n"
    count=count+1
    if count >num:
        conn.close()
        sys.exit()
if __name__ == '__main__':
     app.run()
# Out:
# What Words are you looking for?trump
# How many to display?5
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-74-53a265714b02> in <module>()
#      17 num = input("How many to display?")
#      18
# ---> 19 for row in c.execute('SELECT twittertext, base64 FROM twitter WHERE twittertext MATCH ?', (param,)):
#      20     time.sleep(1)
#      21     print count,":",(row),"\n-----\n"
#
# OperationalError: no such column: base64

# %% [markdown]
# # Search the Twittertextdb

# %%
from flask import Flask, request
import sys
sys.path.insert(0, "/usr/local/lib/python2.7/dist-packages")
from flask_restful import Resource, Api
import sqlite3
import time

app = Flask(__name__)
api = Api(app)

conn = sqlite3.connect('twittertext.db')
c = conn.cursor()# Never 
count=1
t = ('blood',)
#param = "blood"
param = raw_input("What Words are you looking for?")
num = input("How many to display?")

for row in c.execute('SELECT rowid, twittertext FROM twitter WHERE twittertext MATCH ?', (param,)):
    time.sleep(1)
    print count,":",(row),"\n-----\n"
    count=count+1
    if count >num:
        conn.close()
        sys.exit()
if __name__ == '__main__':
     app.run()
# Out:
# What Words are you looking for?nfl
# How many to display?10
# 1 : (11, u"('[(', 're in the Trump Era Stop the Hammering Has He Lost His Mind pic twitter com NYREmVNJtI Pittsburgh Steeler s Alejandro Villanueva Under Pressure Standing By Myself Was A Mistake https percentfedup com wow fans break nfl jersey sales record time afghan war vet bravely stood alone national anthemnow claims standing mistake ignore Clinton Comey was under pressure from Giuliani and other officials to r', '),]')")
# -----
#
# 2 : (94, u"('[(', 'w youtube com watch v mOqEOFZK ignore TupperwareToapayoh Tupperware ToaPayoh NewPossibilities September Singaporepic twitter com zdekhpdcsO WHPress Shouldn t Trump release TaxReturns to PROVE TaxReform won t BENEFIT HIM Cohn DODGE TheResistance CNN MSNBCpic twitter com j lKuDB TN OMG CNN doing a CNNTownHall on NFL What the hell about Puerto Rico pic twitter com ZXL sv ax Thousands are lining up fo', '),]')")
# -----
#
# 3 : (95, u"('[(', 'r cruise ship leaving the island sanjuan puertorico hurricanemaria cnn pic twitter com ADq TgFN No Football Tonight Protest against Players that do not RESPECT the American Flag and Anthem BoycottNFL CNN FoxNews NFL WeThePeople Lt Gen Honore wants Congress to INVESTIGATE because that s Buchanan s ONLY JOB DISASTERS TheResistance CNN MSNBCpic twitter com f dVjlRFx Dear RACIST GOP Any answer to this', '),]')")
# -----
#
# 4 : (108, u"('[(', ' our Flag as a DoorMat Principle says no disrespecting the Tell it to WoundedWarriorspic twitter com pGpE E Ksk All TrumpsArmy let s show our discontent with her use of our Flag as a Doormat York H S Ext StandUpAmericapic twitter com PlyDqTfW h NFL makes billions on backs of taxpayers protects criminal players who disrespect Flag Military LEOs America BoycottAnythingNFLpic twitter com wEbparm Take', '),]')")
# -----
#
# 5 : (109, u"('[(', 'AKnee Neither the Flag nor the NationalAnthem ARE America They are merely symbols Trump is a Classless disgrace to both pic twitter com Wc zr QToBring them up to respect the Flag early often pic twitter com kkyfqiNuT Leave it to an immoral Democrat JacksonLeeTX to TakesAKnee disrespect our Flag our Veterans americanflag Texas America USApic twitter com UjR RrdG NFL seems to have gotten this Boycot', '),]')")
# -----
#
# 6 : (110, u"('[(', 'tNFLSponsors boycottNFL TakeAStandNotAKnee takeastand for the Flag TakeAKnee for the fallenpic twitter com QsXGy nPg Comments from all pregame chatter are Trumps comments were offensive however disrespecting the Anthem and the Flag a good thing NFL TakeAKnee vs disrespecting the Flag pic twitter com sdwoET F n ServiceK Jinky OnDuty Standing PawStrong with his Flag In this Family we are proud of th', '),]')")
# -----
#
# 7 : (111, u"('[(', 'e Red White Blue BlueFamily MyFamilypic twitter com D EXtOuA Hey nfl do yoreally think kneeling to insult the American flag is protest still majority of america thinks disgrace potus I StandUp for my Country for its Flag for its Anthem and for MyPresident Do YoWe the AmericanPeople pay for all they have Yet they disrespect our USA Flag BoycottNFL BoycottTheNFL NFL NBApic twitter com le Dk dH X Tak', '),]')")
# -----
#
# 8 : (112, u"('[(', 'eAKnee NFL ANTHEM Flag PoliticalFootball Shame on FLOTUS MichelleObama HillaryClinton letting the http fb me oleuxKzR We will NEVER TakeAKnee normalize pathetic behavior This is DISRESPECT FLAG MILITARY POLICE GreenBayPackers can go f ck themselveshttps twitter com realdailywire status ignore Tour Scotland travel photograph of Scottish Flag on ancestry visit to Edinburgh Aye I am a Scottish patrio', '),]')")
# -----
#
# 9 : (115, u"('[(', ' criticism of NFL players newday cnn bobcostas nfl morningjoe newday Wake up Bernie people He actually is as big a narcissist as Trump Costed us in Now throws a wrench in healthcare Just watched SenJohnKennedy basically say on national tv that states should be allowed to fuck over sick ppl GrahamCassidy newday Warning do not come on newday without your receipts b c ChrisCuomo is checking your item', '),]')")
# -----
#
# 10 : (165, u"('[(', 'he Plug on NFL Games I think we should do the same and Boycott all Hotels Stores that play CNN too MAGA Rumor has it that SenBobCorker will be the GOPer that starts ImpeachTrump campaign Hmm TheResistance cnn MSNBChttps twitter com CNNPolitics status ignore CNN Technical Difficulties and Censorship http agendaofevil com videos media cnn cnn technical difficulties and censorship ignore CNN is just ', '),]')")
# -----
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/jack/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !rm twittertext2.db

# %%
from flask import Flask, request
import sys
sys.path.insert(0, "/usr/local/lib/python2.7/dist-packages")
from flask_restful import Resource, Api
import sqlite3
import time

app = Flask(__name__)
api = Api(app)

conn = sqlite3.connect('twittertext.db')
c = conn.cursor()# Never 
count=1
t = ('blood',)
#param = "blood"
#param = raw_input("What Words are you looking for?")
num = input("How many to display?")

for row in c.execute('SELECT * FROM twitter'):
    time.sleep(1)
    print count,":",(row[0]),"\n-----\n"
    count=count+1
    if count >num:
        conn.close()
        sys.exit()
if __name__ == '__main__':
     app.run()
# Out:
# How many to display?115
# 1 : ('[(', 'What trends do yosee in Solar PV Monitoring today Solar EnergyStorage netmetering consumption To emphasize China s increasing desire for soybeans here are consumption trends for the top users Basically USA x China pic twitter com VlQKoSfykD Video on mobile devices the opportunities and data trends Understanding video consumption trends shifting http bit ly wLfc B pic twitter com jSN pchAQT Global ', '),]')
# -----
#
# 2 : ('[(', 'Sheetfed Scanner Sales Market Analysis Production Consumption Trends Forecastsignore https goo gl fb AxtVa http washingtonpost com page view consumption trends by device comScorepic twitter com nR FqD y Q Learn about global content marketing and consumption trends in our interactive report with Cerosdotcom http outbra in m tNH pic twitter com F RQV R a Global PCR Workstation Market Analysis by App', '),]')
# -----
#
# 3 : ('[(', 'lication Size Production Market Share Consumption Trends http fb me CmSGNUzM Interesting example re consumption trends cycles nostalgia geog nres will they bring back centipede and space invaders phones https twitter com npr status ignore See the tobacco consumption trends and QuitSmoking AskArvi HealthTips ICanYouCanpic twitter com PM hsxYYp Our Chief Scientist David Jamieson talks healthcare con', '),]')
# -----
#
# 4 : ('[(', 'sumption trends at IRISConference pic twitter com ntj ybcxE A decade later when economists research popcorn consumption trends in India they will notice a small bump in September https twitter com rahulkanwal status ignore Gebo Cermex Sophisticated consumption trends present challenges to the production and distribution of goodsignore http fb me g BoT Facebook recently released a new report on vid', '),]')
# -----
#
# -----
#
# 14 : ('[(', 'ter com ArL y boMI TeamDOLL LacbleKCCO Under Pressure Let It Go Smoosh Up Queen Disney s Frozen https youtbe gvX GxDDPYc via YouTube PuddlesPityP Azealia Banksignores response to Cardi B on IG made me spit out her water Lmao King AB keeps putting these bitches under pressure Im deadass tryna find a flaw in this chick none What business allows their employees to share their views on their platform ', '),]')
# -----
#
# 15 : ('[(', 'NONE cineworld i think yore deranged wanting me to be filthy Sane people want me to be clean of which there is currently none That s the diseased Progressive mind It makes no sense whatsoever None https twitter com RDevole status ignore If yocall FedEx about a package they ll track it down call the driver UPS claims they have NO WAY of contacting the driver NONE Remind us Nigel Farage how many MPs', '),]')
# -----
#
# 16 : ('[(', ' your party has None Zero Nilch Nada BetterOffVotingTory Meme Can I vote for none http ift tt wY zMl threadless threadless None The Creative Adult ArtistShops ArtistShops pic twitter com EacRv vXZ years of I ll build road NONE I ll provide electricity FAIL I ll build Schools NA TRUE Provide free health care MAKE I HEAR my head is itchy pose none https www instagram com p BZkfIElBcfs What is the di', '),]')
# -----
#
# 17 : ('[(', 'fference between content of white eggs brown eggs None Its depends on genetics of the hen No price difference nutrition Just placed my vote for NASCAR Cup Series Most Popular Driver DaleJr Each Day Always None Other Appreci ion NASCAR NASCARMPD Was Winnie the pooh eating gluten too Nah Honey has none pic twitter com kSH UcXs Well yoknow all that class they have none so that from the rising of the ', '),]')
# -----
#
# 18 : ('[(', 'sun to its setting people may know there is none besides me I am the LORD Isaiah NIV know none LOVE ALL TRUST A FEW DO WRONG TO NONE Love All Trust Few Wrong None WilliamShakespeare URL https goo gl Kdc sw pic twitter com nDNzHMA yq players coaches when yore respectful to the flag this respect goes to our Country and your fans NoNe for Redskins Thank yoWhen I type Equifax it keeps autocorrecting t', '),]')
# -----
#
# 19 : ('[(', 'o equidad Which is fitting b c they have equal technological acumen none Understand that there s no more shame in having a mental illness than there is for having a physical illness None MyTipsForMentalHealth LZ Wake the Fuck Up this is about Respect of witch yoLiberal Bastards have None what have yoDone America https twitter com Locs n Laughs status ignore Im deadass tryna find a flaw in this chi', '),]')
# -----
# 20 : ('[(', 'ck none What business allows their employees to share their views on their platform NONE cineworld i think yore deranged wanting me to be filthy Sane people want me to be clean of which there is currently none That s the diseased Progressive mind It makes no sense whatsoever None https twitter com RDevole status ignore If yocall FedEx about a package they ll track it down call the driver UPS claim', '),]')
# -----
#
# 21 : ('[(', 's they have NO WAY of contacting the driver NONE Remind us Nigel Farage how many MPs your party has None Zero Nilch Nada BetterOffVotingTory Meme Can I vote for none http ift tt wY zMl threadless threadless None The Creative Adult ArtistShops ArtistShops pic twitter com EacRv vXZ years of I ll build road NONE I ll provide electricity FAIL I ll build Schools NA TRUE Provide free health care MAKE I ', '),]')
# -----
#
# 22 : ('[(', 'HEAR my head is itchy pose none https www instagram com p BZkfIElBcfs What is the difference between content of white eggs brown eggs None Its depends on genetics of the hen No price difference nutrition Just placed my vote for NASCAR Cup Series Most Popular Driver DaleJr Each Day Always None Other Appreci ion NASCAR NASCARMPD Was Winnie the pooh eating gluten too Nah Honey has none pic twitter co', '),]')
# -----
#
# 23 : ('[(', 'm kSH UcXs Well yoknow all that class they have none so that from the rising of the sun to its setting people may know there is none besides me I am the LORD Isaiah NIV know none LOVE ALL TRUST A FEW DO WRONG TO NONE Love All Trust Few Wrong None WilliamShakespeare URL https goo gl Kdc sw pic twitter com nDNzHMA yq players coaches when yore respectful to the flag this respect goes to our Country a', '),]')
# -----
#
# 24 : ('[(', 'nd your fans NoNe for Redskins Thank yoWhen I type Equifax it keeps autocorrecting to equidad Which is fitting b c they have equal technological acumen none Understand that there s no more shame in having a mental illness than there is for having a physical illness None MyTipsForMentalHealth LZ Wake the Fuck Up this is about Respect of witch yoLiberal Bastards have None what have yoDone America ht', '),]')
# -----
#
# 25 : ('[(', 'tps twitter com Locs n Laughs status ignore With the travel restrictions about to be implemented how many agree that DHS or ICE should take another look at this Jihadist RT USApic twitter com vommtMBcnt We must all defend the st Amendment as powerfully as the NRA defends the nd The DHS snooping on social media accounts is Big Brother This is unacceptable Not ok and not funny DHS NoToastorPraisehtt', '),]')
# -----
#
# 26 : ('[(', 'ps twitter com nottirbeioj status ignore WTF This is extremely disturbing Rao Abbas is using a stolen identity of the guy who is the Technical Director for the Dept of Homeland Security Read entire thread for more details AwanBrothers ImranAwan FBI DHS Wednesday MAGA POTUS WTFhttps twitter com DropThe Mic status ignore and she s gone pick ai sofly shadeson dhs flagfootballpic twitter com YIPd Ng r', '),]')
# -----
#
# 27 : ('[(', 'B FILES SHOW DHS FBI REGARD ANTIFA AS MORE DANGEROUS THAN RIGHT WING GROUPS https sputniknews com military declassified files antifa extremist ignore Right It s our bad luck yoassaulted maimed gaslit strangled raped microwaved attempted to murder us organized stalkers DHS OSG How did Obama DHSgov detect Russia attemots to hack DHS was already trying to breach stumbled on new intruders JusticeOIG I', '),]')
# -----
#
# 28 : ('[(', 'J Yearbooks are in dhs pic twitter com SUi tGxD That s because the DOJ is just as corrupt as the CIA NSA DHS https twitter com TrishaDishes status ignore DHS planning to collect social media info on ALL immigrants The Hill TheResistance http a msn com r AAsucEpic twitter com dLhe UnlM We can land a miniature spacecraft on a comet that s going at warp speed but we don t know how to avoid an Equifax', '),]')
# -----
#
# 29 : ('[(', ' breach news dhs Potential targeting statement of DHS was misreported by US media as Russian gov t cyber actors https on rt com nzh JONESACT waived almost immediately for TX LO FL Why does PressSec say waiver not needed WH incompetent DHS useless PuertoRico needs AID Original DHS statement mentioned neither election hacking nor Russia https on rt com nzh HelpFellowPRAmericans DHS Waive the JonesAc', '),]')
# -----
#
# 30 : ('[(', 't for ALLCargo at Ports in PuertoRico to Aid Hur https www change org p department of homeland security waive the jones act for all cargo at ports in puerto rico to aid hurricane maria relief recruiter utm source share petition utm medium twitter utm campaign psf combo share initial combo new control progress bar redirected utm term utm content nafta twitter large image card Acontrol pt AjpQZXRpdG', '),]')
# -----
#
# 31 : ('[(', 'lvbjoxMjM MjMzODoxNTA NTYyNzkzOjUsDiwaLC Yjg YzM Mzc D ignore via Change Russia tried to hack electionsignore US media misreported DHS potential targeting warning https on rt com nzh pic twitter com kmhMhxUg a The S DHSgov awarded K to blockchain startup DigitalBazaar Blockchain DHS Funding Startuppic twitter com NoEJ jNCgz Has the US just become a police state for immigrants https www buzzfeed co', '),]')
# -----
#
# 32 : ('[(', 'm adolfoflores people are worried about dhs plans to gather social media utm term efGNv L N ignore infosec cybersecurity DHS CISO NSA pr privacy CIO CSO This Moment Has FINALLY Arrived And Now We Have To Make The Best Of It Thank YoJesus And To Our Beautiful Mother CO SEN R DHS pic twitter com rbo dtLNr THE NEXT MAN IN THIS HOUSE TO SHOVE WHEATGRASS OR COCONUT ANYWHERE NEAR ME IS GOING TO DIE A HO', '),]')
# -----
#
# 33 : ('[(', 'RRIBLY PAINFUL DEATH NOTFUNNY Just showing respect for this Man pic twitter com GkRXoP Xq Grokitman He s a Iot smarter than your average comic book superhero reading learning history science Grok it man pic twitter com tDVr ojqCk Scania just needs to settle and move on Odd they didn t step up when MAN and DAF and other truck mfg s settled with EU over price fixing I expect OWNER of dallascowboys J', '),]')
# -----
#
# 34 : ('[(', 'ones to MakeaStatementCowards hide stay silent Man Up Jones your SILENCE is deafeningIf Not Boycottpic twitter com G xIEvWdX Nowguesswho the Sabeans are see man donignoret wanna believe this especially these ones that gotitcoming A Recompense sheeshpic twitter com iFCnmx JR Yoneed a man that wants yofor yoMy gym pecdeck buddy from http GlobalFight com gym hairy muscles man men workout workingout c', '),]')
# -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-7b5ea8469386> in <module>()
#      18
#      19 for row in c.execute('SELECT * FROM twitter'):
# ---> 20     time.sleep(1)
#      21     print count,":",(row[0]),"\n-----\n"
#      22     count=count+1
#
# KeyboardInterrupt:

# %%
# !ls *.jpg
# Out:
# ariver001.jpg  ariver002.jpg  hex.jpg  testingagain.jpg

# %% [markdown]
# # Non-API TwitterSearch To DataBase with Search Keyword

# %%
import re
import textwrap
import time
import sqlite3
import sys
import base64
import time
conn = sqlite3.connect('twittertext2.db')
c = conn.cursor()
#Create table
#CREATE VIRTUAL TABLE hurr 
#USING FTS3(text, keywords)


c.execute('''CREATE VIRTUAL TABLE twitter
             USING FTS3 (twittertext, base64)''')
count=0
lines = 400
with open("hashtag.txt") as f:
    text = f.read()
    words = " ".join(re.findall("[a-zA-Z]+", text))
    #wordx = " ".join(re.findall("[a-zA-Z]+", text))
    words = words.replace(' u ', ' ');words = words.replace('u ', '');words = words.replace(' U ', ' ')
    chars_per_line = 400
    for i in range(0, len(words), chars_per_line):
        file= ("[(",words[i:i+chars_per_line],"),]")
        #data= ("[('"+words[i:i+chars_per_line]+"'),]")
        file = str(file)
        #file = 'base64 encoding allows code to be stored and retieved in the same format it was posted'
        #keywords = 'sept, nonapi, china, philippines'
        conn = sqlite3.connect('twittertext2.db')
        c = conn.cursor()
        time.sleep(1)
        #encodedlistvalue=base64.b64encode(wordx[2:-2])
        encodedlistvalue=base64.b64encode(file)
        #c.execute("INSERT INTO hurricane VALUES (?,?)", (encodedlistvalue, b)) 
        c.execute("INSERT INTO twitter VALUES (?,?)", (file,encodedlistvalue)) 
        conn.commit()
        conn.close()        
        
        
        #time.sleep(1)
        print file[2:-2]
        count=count+1
        print count
        if count>lines:
            sys.exit()
#commits and closes database if there are less then 400 lines of text
conn.commit()
conn.close()
# Out:
# [(', 'What trends do yosee in Solar PV Monitoring today Solar EnergyStorage netmetering consumption To emphasize China s increasing desire for soybeans here are consumption trends for the top users Basically USA x China pic twitter com VlQKoSfykD Video on mobile devices the opportunities and data trends Understanding video consumption trends shifting http bit ly wLfc B pic twitter com jSN pchAQT Global ', '),]
# 1
# [(', 'Sheetfed Scanner Sales Market Analysis Production Consumption Trends Forecastsignore https goo gl fb AxtVa http washingtonpost com page view consumption trends by device comScorepic twitter com nR FqD y Q Learn about global content marketing and consumption trends in our interactive report with Cerosdotcom http outbra in m tNH pic twitter com F RQV R a Global PCR Workstation Market Analysis by App', '),]
# 2
# [(', 'lication Size Production Market Share Consumption Trends http fb me CmSGNUzM Interesting example re consumption trends cycles nostalgia geog nres will they bring back centipede and space invaders phones https twitter com npr status ignore See the tobacco consumption trends and QuitSmoking AskArvi HealthTips ICanYouCanpic twitter com PM hsxYYp Our Chief Scientist David Jamieson talks healthcare con', '),]
# 3
# [(', 'sumption trends at IRISConference pic twitter com ntj ybcxE A decade later when economists research popcorn consumption trends in India they will notice a small bump in September https twitter com rahulkanwal status ignore Gebo Cermex Sophisticated consumption trends present challenges to the production and distribution of goodsignore http fb me g BoT Facebook recently released a new report on vid', '),]
# 4
# [(', 'eo consumption trends across Facebook and Instagram http ow ly RNGi eeVTq socialmedia day Some good tips here our soon to be released Media Consumption Trends report shows a clear increase in social media use in ag https twitter com rheakaiser status ignore Global Tranexamic Acid Market Outlook Growth Production Consumption Trends Anlaysisignore https goo gl fb rkH eH The Emerging middle class urb', '),]
# 5
# [(', 'anization and New consumption trends in Africa by Andrew WaititMEASummit Andrew YT BusinessSwedenpic twitter com SoJ xbarfm Andrew YT at stage during MEASummit discussing an emerging middle class and new consumption trends pic twitter com fA she Bitcoin energy consumption trends Up up up blockchainhttps digiconomist net bitcoin energy consumption ignore Global Pumpkin Seed Oil Industry Overview Co', '),]
# 6
# [(', 'nsumption Trends and Growth Opportunitiesignorehttps goo gl fb ZJ TKq Global Acrylic Emulsions Market Analysis Production Consumption Trends Research Reportignore https goo gl fb nMbgNk A bit of this is unlikely the idea that red meat may promote diabetes considering consumption trends during the epidemic cities develop streetcar decrease traffic congestion increase economic activity downtown Sydn', '),]
# 7
# [(', 'ey WIPhttps blueprint cbre com the return of the streetcar WcBz qFO twitter ignore DHA Min Prof Mkhize says DG Apleni is delusional and unstable he is distorting stuff the relationship was fine and we are under pressure Farah Black Bodyguard Cool under pressure Usually Sometimes DirkGentlyBBCApic twitter com qWAfk v me We can put strong teams under pressure on our day Matos Read https goo gl JRffk', '),]
# 8
# [(', 'sun to its setting people may know there is none besides me I am the LORD Isaiah NIV know none LOVE ALL TRUST A FEW DO WRONG TO NONE Love All Trust Few Wrong None WilliamShakespeare URL https goo gl Kdc sw pic twitter com nDNzHMA yq players coaches when yore respectful to the flag this respect goes to our Country and your fans NoNe for Redskins Thank yoWhen I type Equifax it keeps autocorrecting t', '),]
# 18
# [(', 'o equidad Which is fitting b c they have equal technological acumen none Understand that there s no more shame in having a mental illness than there is for having a physical illness None MyTipsForMentalHealth LZ Wake the Fuck Up this is about Respect of witch yoLiberal Bastards have None what have yoDone America https twitter com Locs n Laughs status ignore Im deadass tryna find a flaw in this chi', '),]
# 19
# [(', 'ck none What business allows their employees to share their views on their platform NONE cineworld i think yore deranged wanting me to be filthy Sane people want me to be clean of which there is currently none That s the diseased Progressive mind It makes no sense whatsoever None https twitter com RDevole status ignore If yocall FedEx about a package they ll track it down call the driver UPS claim', '),]
# 20
# [(', 's they have NO WAY of contacting the driver NONE Remind us Nigel Farage how many MPs your party has None Zero Nilch Nada BetterOffVotingTory Meme Can I vote for none http ift tt wY zMl threadless threadless None The Creative Adult ArtistShops ArtistShops pic twitter com EacRv vXZ years of I ll build road NONE I ll provide electricity FAIL I ll build Schools NA TRUE Provide free health care MAKE I ', '),]
# 21
# [(', 'HEAR my head is itchy pose none https www instagram com p BZkfIElBcfs What is the difference between content of white eggs brown eggs None Its depends on genetics of the hen No price difference nutrition Just placed my vote for NASCAR Cup Series Most Popular Driver DaleJr Each Day Always None Other Appreci ion NASCAR NASCARMPD Was Winnie the pooh eating gluten too Nah Honey has none pic twitter co', '),]
# 22
# [(', 'm kSH UcXs Well yoknow all that class they have none so that from the rising of the sun to its setting people may know there is none besides me I am the LORD Isaiah NIV know none LOVE ALL TRUST A FEW DO WRONG TO NONE Love All Trust Few Wrong None WilliamShakespeare URL https goo gl Kdc sw pic twitter com nDNzHMA yq players coaches when yore respectful to the flag this respect goes to our Country a', '),]
# 23
# [(', 'nd your fans NoNe for Redskins Thank yoWhen I type Equifax it keeps autocorrecting to equidad Which is fitting b c they have equal technological acumen none Understand that there s no more shame in having a mental illness than there is for having a physical illness None MyTipsForMentalHealth LZ Wake the Fuck Up this is about Respect of witch yoLiberal Bastards have None what have yoDone America ht', '),]
# 24
# [(', 'tps twitter com Locs n Laughs status ignore With the travel restrictions about to be implemented how many agree that DHS or ICE should take another look at this Jihadist RT USApic twitter com vommtMBcnt We must all defend the st Amendment as powerfully as the NRA defends the nd The DHS snooping on social media accounts is Big Brother This is unacceptable Not ok and not funny DHS NoToastorPraisehtt', '),]
# 25
# [(', 'ps twitter com nottirbeioj status ignore WTF This is extremely disturbing Rao Abbas is using a stolen identity of the guy who is the Technical Director for the Dept of Homeland Security Read entire thread for more details AwanBrothers ImranAwan FBI DHS Wednesday MAGA POTUS WTFhttps twitter com DropThe Mic status ignore and she s gone pick ai sofly shadeson dhs flagfootballpic twitter com YIPd Ng r', '),]
# 26
# [(', 'B FILES SHOW DHS FBI REGARD ANTIFA AS MORE DANGEROUS THAN RIGHT WING GROUPS https sputniknews com military declassified files antifa extremist ignore Right It s our bad luck yoassaulted maimed gaslit strangled raped microwaved attempted to murder us organized stalkers DHS OSG How did Obama DHSgov detect Russia attemots to hack DHS was already trying to breach stumbled on new intruders JusticeOIG I', '),]
# 27
# [(', 'J Yearbooks are in dhs pic twitter com SUi tGxD That s because the DOJ is just as corrupt as the CIA NSA DHS https twitter com TrishaDishes status ignore DHS planning to collect social media info on ALL immigrants The Hill TheResistance http a msn com r AAsucEpic twitter com dLhe UnlM We can land a miniature spacecraft on a comet that s going at warp speed but we don t know how to avoid an Equifax', '),]
# 28
# [(', ' breach news dhs Potential targeting statement of DHS was misreported by US media as Russian gov t cyber actors https on rt com nzh JONESACT waived almost immediately for TX LO FL Why does PressSec say waiver not needed WH incompetent DHS useless PuertoRico needs AID Original DHS statement mentioned neither election hacking nor Russia https on rt com nzh HelpFellowPRAmericans DHS Waive the JonesAc', '),]
# 29
# [(', 't for ALLCargo at Ports in PuertoRico to Aid Hur https www change org p department of homeland security waive the jones act for all cargo at ports in puerto rico to aid hurricane maria relief recruiter utm source share petition utm medium twitter utm campaign psf combo share initial combo new control progress bar redirected utm term utm content nafta twitter large image card Acontrol pt AjpQZXRpdG', '),]
# 30
# [(', 'lvbjoxMjM MjMzODoxNTA NTYyNzkzOjUsDiwaLC Yjg YzM Mzc D ignore via Change Russia tried to hack electionsignore US media misreported DHS potential targeting warning https on rt com nzh pic twitter com kmhMhxUg a The S DHSgov awarded K to blockchain startup DigitalBazaar Blockchain DHS Funding Startuppic twitter com NoEJ jNCgz Has the US just become a police state for immigrants https www buzzfeed co', '),]
# 31
# [(', 'm adolfoflores people are worried about dhs plans to gather social media utm term efGNv L N ignore infosec cybersecurity DHS CISO NSA pr privacy CIO CSO This Moment Has FINALLY Arrived And Now We Have To Make The Best Of It Thank YoJesus And To Our Beautiful Mother CO SEN R DHS pic twitter com rbo dtLNr THE NEXT MAN IN THIS HOUSE TO SHOVE WHEATGRASS OR COCONUT ANYWHERE NEAR ME IS GOING TO DIE A HO', '),]
# 32
# [(', 'RRIBLY PAINFUL DEATH NOTFUNNY Just showing respect for this Man pic twitter com GkRXoP Xq Grokitman He s a Iot smarter than your average comic book superhero reading learning history science Grok it man pic twitter com tDVr ojqCk Scania just needs to settle and move on Odd they didn t step up when MAN and DAF and other truck mfg s settled with EU over price fixing I expect OWNER of dallascowboys J', '),]
# 33
# [(', 'ones to MakeaStatementCowards hide stay silent Man Up Jones your SILENCE is deafeningIf Not Boycottpic twitter com G xIEvWdX Nowguesswho the Sabeans are see man donignoret wanna believe this especially these ones that gotitcoming A Recompense sheeshpic twitter com iFCnmx JR Yoneed a man that wants yofor yoMy gym pecdeck buddy from http GlobalFight com gym hairy muscles man men workout workingout c', '),]
# 34
# [(', 'hest handsome blueeyes husbandspic twitter com a tooA krN Itignores a question of semantics grok it man grokitman grokit ProfessorWatts Blessed are the cheesemakers blessedarethepeacemakerspic twitter com Occ EsYKbr My OK gym buddy from http GlobalFight com oklahoma gym man selfie muscles biceps lockerroom cute handsome wrestler guy dudepic twitter com zkJ AES yQ when a Man stands or Knee for his ', '),]
# [(', ' Workstation https www virtual allan com vmware workstation pro and fusion released ignore StarWindpic twitter com bc p ebQNP Reposting adrianfigueroaok setup dreamsetup workstation battlestation workspace pcgaming deskspace desksetup gaming game gamerpic twitter com inKFGVX kF Buongiorno Ready for another workhard day goodmorning buongiorno workstationignore https www instagram com p BZkyIHWBQup ', '),]
# 53
# [(', 'Borrowed workstation office space Where my vertical monitors at yql workstation deskspace WorkspaceWednesday blackandwhitepic twitter com qAykvDcL Now Shipping VMware Workstation VMware Fusion vmware fusion workstation newreleases http bit ly k sRqz pic twitter com gqlN sQmn Here comes the all new VMware Workstation VMware Fusion http bit ly y envp pic twitter com F fvaB HP launches HP Z VR backpa', '),]
# 54
# [(', 'ck for untethered pro VR doubles as a desktop workstation http www develop d com blog hp launches workstation backpack for untethered pro vr ignorepic twitter com zmh LRVY Get your VMware Workstation VMware Fusion updates for High Sierra and Win Fall update support http bit ly y eAPb pic twitter com hVz ttaFhF VMware Workstation Pro Released with New Features vmw workstation workstation https www ', '),]
# 55
# [(', 'virtualizationhowto com vmware workstation pro released with new features ignorepic twitter com QonZ STY x Reposting hermanospc pc pcgamer gamer gamingpc battlestation workstation dreamsetup computer desksetup gamingsetup pic twitter com NCjc BZ Talk to us about electric desks workstation health have a free workstation assessmenthttps twitter com SvenFurniture status ignore Evaluate workstation pe', '),]
# 56
# [(', 'rformance for Autodesk Maya New free SPEC benchmark downloads http ow ly JFfZ frS y pic twitter com fH WrYGFid Check out the workstation to support Grade place value concepts Burnett ES PISDMathChat ElemMathChatpic twitter com gP tFKLQh Srikanth our community member works from this beautiful breezy terrace at Cooke Town Bangalore workstation startup inspirationpic twitter com NjPBAnRG Screenbox al', '),]
# 57
# [(', 'lows for multi purpose use of a workstation integrating monitor keyboard and mouse into the desktop desk officefurniturepic twitter com wkuz mM xC Magic station Creativity zone workstation WorksForMe WorkLifeBalancepic twitter com OXMa oo wl New design Movies website movies design ui ux uidesign dribbble behance workstation office effects design movie bloggerpic twitter com RATLjNLqqN Steps to Run', '),]
# 58
# [(', ' KaliLinux on VMware Workstation Latest Version Howto Linux Tactig http www tactig com install kali linux on vmware workstation ignorepic twitter com ZcljlOrOQy Steps to Run KaliLinux on VMware Workstation Latest Version Howto Linux Tactig http www tactig com install kali linux on vmware workstation ignorepic twitter com ZcljlOrOQy I think its important we find a balance between capitalism and the', '),]
# 59
# [(', ' environment It can be done consumption pic twitter com pf wAmM qd World Energy Consumption by country grouping and future prediction OECD NonOECDpic twitter com FBIGt sTus ABOLISH the IRS ALL of their SpecialInterests Tax WriteOffs Deductions Time for a FairTax EVERYONE PAYS on their Consumption Most of the Indian GDP accounts for consumption and not fresh privateinvestment EOTYatSSE There is a c', '),]
# 60
# [(', 'ost for Freedom There is a cost for PlanetEarth There is a cost for war There is a cost for consumption DeadlySins awareness on local consumption can benefit smallholder farmers on best utilization of their agriculture land Whr thr is business potential visibility valuations take a back seat even if it sounds expensive years fwd Consumption is evergreen https twitter com abcfadvisory status ignore', '),]
# 61
# [(', ' question TheResistance TakeAKnee Kaepernick FoxNews CNN MSNBC bbcnewshttps twitter com ZeonBison status ignore How come cnn never has a town hall on black on black crime police shooting in last year almost deaths from bob crime CNNTownHall CNN fails again http www breitbart com texas cnn caught using fake news turn puerto rico trumps katrina ignore BREAKING Twitter says it acted on some Russia li', '),]
# 96
# [(', 'nked accounts TheResistance CNN MSNBC FoxNews bbcnewspic twitter com h uapS Sv BREAKING Republicans have LOST CONFIDENCE IN SenateMajLdr Should he STEP DOWN TheResistance CNN MSNBC bbcnewspic twitter com Oww jVZdL Cassidy I live in your state Who is paying k Stop lying HealthCareDebate cnn Now Trump s TakeAKnee fight causing DIVISION IN HIGH SCHOOL FOOTBALL SAD TheResistance Kaepernick CNN MSNBCht', '),]
# 97
# [(', 'tps twitter com ShaunKing status ignore CNN newday ChrisCuomo network gets great deal of credit as did not ignore PuertoRico reporting on why society breaking down predictibaly What grade would yogive trump in response to Puerto Rico dotard MSNBC CNN FoxNews Two different business models What in gods name is Tom Bossert blathering about CNN PUERTORICO Before Tax Reform bill is passed Only Fair tha', '),]
# 98
# [(', 't trump release his Taxes First Do yowant to see trump s Taxes CNN MSNBC dotard Fox BREAKING Lt Gen Honore VERY CONCERNED it took DAYS to get Lt Gen Buchanan to PuertoRico TheResistance CNN MSNBCpic twitter com SSPg cQcre Is trump using White House as another MONEY making SCAM Trump Loves OPM REMEMBER trump trump foundation CNN MSNBC HuffPost IRONY CNN Calls Trump Racist While They re Getting Sued', '),]
# 99
# [(', ' By Black Employees For Discrimination http www dailywire com news irony cnn calls trump racist while theyre getting ryan saavedra ignore Gen Russel Honore on CNN The SOB that rides around in Air Force One is denying services to the people of Puerto Rico It s a scary thing when bias in the news is so rife that yocan t believe a word they say bbc sky Ad campaign on BBC news to keep kids safe in ter', '),]
# 100
# [(', 'ror situations Find oust terrorists as first line defence surely POLICE release BBC Asia pls do not put Myanmar into horrible life we condemn some news channels which break madia eathic and broadcast the fake new pic twitter com UCfpT giCm Can yoimagine if a BBC News Political Editor needed a bodyguard at a Right Wing UK political event and how the media would react to it pic twitter com lkEcTyzXr', '),]
# 101
# [(', 'z RussianWarCrimes in Idlib Syria Civillians are dying IdlibIsBurning News currentaffairs bbc cnnpic twitter com akzfRm IWM Please tell me how some soap actress dying is news It s sad for her family but not news for the rest of us Report the fucking news bbc The FAKE CONSERVATIVE PhilipHammondUK MUST GO theresa may must sack PhilipHammond BBC SKY NEWS RT TORY MP PM BREXIT UK EUpic twitter com yr N', '),]
# 102
# [(', 'WBvPVq Evil BBC I know is only negative news about Biafra yowill carry at the end We shall see who is terrorist I used to trust the BBC and its news coverage et al But as someone with a history degree trained to spot hidden and subtle propaganda NigelFarage Remainers in the cabinet never wanted to Leave the EU they still don t pic twitter com wCe uHilVn BBC SKY UK NEWS TORY The LabourParty is now ', '),]
# 103
# [(', 'officially ANTISEMITIC the Labour leader JeremyCorbyn is doing nothing to protect UK JEWS BBC SKY NEWS pic twitter com bCgsIxefnn We ve paid in bn since isn t that enough pic twitter com a MVrkyDt TheresaMay BBC SKY ITV UK EU NEWS TORY UKIP LABOUR Thank yoTimesNow for the update news about the brutality of Rohingya terrorists in Rakhine Where are BBC Biased reporters sleeping There is massive inte', '),]
# 203
# [(', 'as https www nbcnews com news us news amp trump signs bill revoking obama era gun checks people mental n ignore Liberals are already out politicizing the shooting in LasVegas wanting GunControl Automatic guns are already banned MAGA A Vegas Newly diagnosed cancer patients must STOP talking about ways to stop cancer It s just too soon GOPLogic GunControl Sarah Sanders I don t want to react anymore ', '),]
# 204
# [(', 'I want to respond guncontrol Sarah Sanders failed to mention Trump was given Million by The NRA so heignores their pawn PrayingforVegas guncontrol Stop Gun Violence pic twitter com FTM Kgvtcd NOW RIGHT THIS VERY MINUTE NOW IS WHEN WE TALK ABOUT GUNCONTROL NOW GunControl The gun used was illegal GunControl only stops yofrom defending yourself and only a coward would give up that responsibility Im a', '),]
# 205
# [(', ' PROUD member of the NRA Yocant stop criminals from gettin guns so stop trying to take them away from law abiding citizens guncontrol To Trump supporters who say the solution is more guns What the hell were yogonna do shoot back into a nd floor window guncontrol For those who say GunControl doesn t work here are some stats Gun Deaths per people per year S K S Korea Canada Australia We need GunCont', '),]
# 206
# [(', 'rolNow VegasStrong Horrifying My thoughts are with the victims of the Las Vegas shooting their families Can we figure this shit out please guncontrol Why isnignoret Trump going on a Twitter rant about terrorism Oh right the shooter was white GunControl PrayForVegas Same idiot leftists shouting guncontrol oppose the southern wall where drugs and weapons flow in and out freely To MAGA Trolls saying ', '),]
# 207
# [(', 'don t discuss guncontrol Japan gun deaths US gun deaths Gun control laws work VegasStrong I have yet to see a mass shooting thwarted by someone with ANOTHER assault rifle Can we put that bullshit narrative to rest guncontrol There s blood on the hands of everyone in Congress who has failed to pass any guncontrol legislation Is there nothing they can do To all who will use LasVegasShooting to push ', '),]
# 208
# [(', 'your GunControl agenda Trust me yowant to be armed when these things happen I was there Anyone who believes Stephen paddock was an isis terrorist also probably believes Trump is a real Christian guncontrol GunControlNow Leftists trampling over the dead demanding guncontrol The guns the shooter used were already banned Yeah passing that ban worked well huh The gun industry is a far greater national', '),]
# 209
# [(', ' security threat than any overseas terror org That s why most Americans want better guncontrol The only way to change the continuing bloodbath in America is to VoteTheGOPOut They re blocking ALL reasonable forms of GunControl Having a gun would NOT have helped yodefend yourself from a madman four football fields away and floors high guncontrol Sooner or later we must have a constructive dialog abo', '),]
# 210
# [(', 'ut gun violence and innocent victims Kids Adults Loved ones killed Victims Gunspic twitter com ocGLsY kKd LasVegas victims STILL bleeding Hillary CarolynGoidman asked for no politicizing Get a bit of humanity pic twitter com jT iMHwvo LasVegasShooting May the Lord Bless and keep the Survivors Familiesof the Victims of LV TerroristAttack GodBlessYoEveryone pic twitter com EtB m d at Bon Secours St ', '),]
# 211
# [(', 'Francis Hospital LasVegasShooting Thoughts prayers go out to all the Victims theirfamilies My HEART bleeds for all of yoPray for Las Vegas Victims Pray bernese pic twitter com vTVMCOLDdU Hardball Chris everyone is goin have a different view on this HORRIFIC MassacreInLasVegas LasVegasShooting Victims Official s MSNBC all the LasVegasShooting Victims and families pic twitter com LwEjwg XTL How abou', '),]
# 212
# [(', 't an NRA backed burial fund for mass shooting victims lasvegashooting RedCross Donate Blood for Las Vegas Victims Americans USA Murder Victims MurderVictims LasVegas LasVegasPolice CityOfLasVegas LasVegasShooting LasVegasShootings GunControl PTSDpic twitter com J K iFxDGa PuertoRico debt is fraction of TX or FL debt yet Maria Victims on their own for over a week forced to sign reimbursements pay f', '),]
# 213
# [(', 'or aid My Prayers my Heart goes out to family friends of the VegasMurders the Victims in hospitals HowIsThisHappening we live in What A Beautiful Picture ABC News Showing People Of All Races Ethnicities Giving Blood To Help Vegas Country Music Route Victims Then they ll say in history books Igbo nation were victims of circumstances not victims of calm calculated secret Warframe watched UN Yep Thes', '),]
# 214
# [(', 'e NFL THUGS want us respect them when many of them have DOMESTICVIOLENCE victims in every state on EVERY NFL TEAM Boycottpic twitter com dob HHvZad Only PC Liberal DemocRATS make excuses for their derangement and evil they commit against innocent victims MAGA TRUMP pic twitter com FNpiqVKOK That surely helps the victims and their families a lot knowing that they did not die to an ideology but just', '),]
# 215
# [(', ' some crazy idiot Oh Richard didn t yoknow yocan not accuse the bitter victims of anything they ll end up crying victims lfc Weignorere yotyping your thoughts when yoshould of been standing in honor of the victims EiffelTower goes dark to honor the victims from LasVegas and Marseille Vegas Victims Nevada France pray prayer prayforLasVegaspic twitter com bLsPeVQK E RIP Killed in the Las Vegas massa', '),]
# 216
# [(', 'cre First victims pictured http dailym ai xaDptW LasVegasShootings dead injuredpic twitter com dqScZVTduG', '),]
# 217
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-78-2e69983e9370> in <module>()
#      47             sys.exit()
#      48 #commits and closes database if there are less then 400 lines of text
# ---> 49 conn.commit()
#      50 conn.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# # Search by Line Number Span

# %%
from flask import Flask, request
import sys
sys.path.insert(0, "/usr/local/lib/python2.7/dist-packages")
from flask_restful import Resource, Api
import sqlite3
import time

app = Flask(__name__)
api = Api(app)
conn = sqlite3.connect('twittertext.db')
c = conn.cursor()
count=1
Start = input("Start Line")
num = input("Stop Line")
for row in c.execute('SELECT * FROM twitter'):
    time.sleep(1)
    if count >Start:
        row = str(row)[4:-4]
        row = row.replace("'[(', '"," ")
        row = row.replace("', '),]'"," ")
        row = row.replace('u"','')
        row = row.replace('",','')
        #print "\n",count,"-----\n",row
        print count,row
    count=count+1
    if count >num:
        conn.close()
        sys.exit()
if __name__ == '__main__':
     app.run()
# Out:
# Start Line2
# Stop Line7
# 3  lication Size Production Market Share Consumption Trends http fb me CmSGNUzM Interesting example re consumption trends cycles nostalgia geog nres will they bring back centipede and space invaders phones https twitter com npr status ignore See the tobacco consumption trends and QuitSmoking AskArvi HealthTips ICanYouCanpic twitter com PM hsxYYp Our Chief Scientist David Jamieson talks healthcare con
# 4  sumption trends at IRISConference pic twitter com ntj ybcxE A decade later when economists research popcorn consumption trends in India they will notice a small bump in September https twitter com rahulkanwal status ignore Gebo Cermex Sophisticated consumption trends present challenges to the production and distribution of goodsignore http fb me g BoT Facebook recently released a new report on vid
# 5  eo consumption trends across Facebook and Instagram http ow ly RNGi eeVTq socialmedia day Some good tips here our soon to be released Media Consumption Trends report shows a clear increase in social media use in ag https twitter com rheakaiser status ignore Global Tranexamic Acid Market Outlook Growth Production Consumption Trends Anlaysisignore https goo gl fb rkH eH The Emerging middle class urb
# 6  anization and New consumption trends in Africa by Andrew WaititMEASummit Andrew YT BusinessSwedenpic twitter com SoJ xbarfm Andrew YT at stage during MEASummit discussing an emerging middle class and new consumption trends pic twitter com fA she Bitcoin energy consumption trends Up up up blockchainhttps digiconomist net bitcoin energy consumption ignore Global Pumpkin Seed Oil Industry Overview Co
# 7  nsumption Trends and Growth Opportunitiesignorehttps goo gl fb ZJ TKq Global Acrylic Emulsions Market Analysis Production Consumption Trends Research Reportignore https goo gl fb nMbgNk A bit of this is unlikely the idea that red meat may promote diabetes considering consumption trends during the epidemic cities develop streetcar decrease traffic congestion increase economic activity downtown Sydn
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# # Tweet a Image and a random text

# %% [markdown]
# # Post to Twitter

# %%
import sys
sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
import twython
from twython import Twython
import Key
from random import randint
import FileLen
Max = FileLen.filelen("ToUse.txt")
num = randint(0, Max)
with open('ToUse.txt') as f:
    for i, STR in enumerate(f, 1):
        if i == num:
            break

CONSUMER_KEY = Key.twiter()[0]
CONSUMER_SECRET = Key.twiter()[1]
ACCESS_KEY = Key.twiter()[2]
ACCESS_SECRET = Key.twiter()[3]
twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY,ACCESS_SECRET)
#PATH = '/home/jack/Desktop/3DFRACT/Mandelbulb3Dv199/cloud.jpg'
#PATH = '/home/jack/Desktop/3DFRACT/Mandelbulb3Dv199/post-002.jpg'
#PATH = '/home/jack/Desktop/3DFRACT/Mandelbulb3Dv199/post-068.jpg'
#PATH = '/home/jack/Desktop/text_stuff/instagram/post-054.jpg'
PATH = '/home/jack/Desktop/text_stuff/instagram/post-056.jpg'
#PATH = '/home/jack/Desktop/text_stuff/junk/post-color3.png'

STR ="#C++imagery #python I enjoy pallet swapping most of all #imageprocessing"
photo = open(PATH,'rb')
response = twitter.upload_media(media=photo)
twitter.update_status(status=STR, media_ids=[response['media_id']])
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Fri Oct 06 03:05:35 +0000 2017',
#  u'entities': {u'hashtags': [{u'indices': [0, 2], u'text': u'C'},
#    {u'indices': [12, 19], u'text': u'python'},
#    {u'indices': [56, 72], u'text': u'imageprocessing'}],
#   u'media': [{u'display_url': u'pic.twitter.com/eev0GvT6qt',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/916137330297020417/photo/1',
#     u'id': 916137326991904768,
#     u'id_str': u'916137326991904768',
#     u'indices': [73, 96],
#     u'media_url': u'http://pbs.twimg.com/media/DLbGC4TUEAAcm0c.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/DLbGC4TUEAAcm0c.jpg',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/eev0GvT6qt'}],
#   u'symbols': [],
#   u'urls': [],
#   u'user_mentions': []},
#  u'extended_entities': {u'media': [{u'display_url': u'pic.twitter.com/eev0GvT6qt',
#     u'expanded_url': u'https://twitter.com/JackLNorthrup/status/916137330297020417/photo/1',
#     u'id': 916137326991904768,
#     u'id_str': u'916137326991904768',
#     u'indices': [73, 96],
#     u'media_url': u'http://pbs.twimg.com/media/DLbGC4TUEAAcm0c.jpg',
#     u'media_url_https': u'https://pbs.twimg.com/media/DLbGC4TUEAAcm0c.jpg',
#     u'sizes': {u'large': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'medium': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'small': {u'h': 640, u'resize': u'fit', u'w': 640},
#      u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#     u'type': u'photo',
#     u'url': u'https://t.co/eev0GvT6qt'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 916137330297020417,
#  u'id_str': u'916137330297020417',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'is_quote_status': False,
#  u'lang': u'en',
#  u'place': None,
#  u'possibly_sensitive': False,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://blogblocks.org" rel="nofollow">jack_watch</a>',
#  u'text': u'#C++imagery #python I enjoy pallet swapping most of all #imageprocessing https://t.co/eev0GvT6qt',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Wed May 11 16:01:29 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u"Overcome with addictions: PHP, Python, Nodejs, JavaScript, P5.J's, Processing.J's, Ruby, MySql, Mongo, HTML, CSS, Docker, Bash scripting, C++, Linux, Android.",
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'jacknorthrup.com',
#       u'expanded_url': u'http://jacknorthrup.com',
#       u'indices': [0, 23],
#       u'url': u'https://t.co/SFgB3ME7hP'}]}},
#   u'favourites_count': 1471,
#   u'follow_request_sent': False,
#   u'followers_count': 2639,
#   u'following': False,
#   u'friends_count': 2619,
#   u'geo_enabled': True,
#   u'has_extended_profile': False,
#   u'id': 296906916,
#   u'id_str': u'296906916',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 37,
#   u'location': u'Philippines via USA',
#   u'name': u'Jack Northrup',
#   u'notifications': False,
#   u'profile_background_color': u'C0DEED',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/837212066/b7a2e43cb82aa9f56c16b6afb60944fe.png',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/837212066/b7a2e43cb82aa9f56c16b6afb60944fe.png',
#   u'profile_background_tile': True,
#   u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/296906916/1502958210',
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2765370268/48e94b4ba63cc542d5e0967136165bec_normal.png',
#   u'profile_link_color': u'F70A1D',
#   u'profile_sidebar_border_color': u'FFFFFF',
#   u'profile_sidebar_fill_color': u'DDEEF6',
#   u'profile_text_color': u'333333',
#   u'profile_use_background_image': True,
#   u'protected': False,
#   u'screen_name': u'JackLNorthrup',
#   u'statuses_count': 5462,
#   u'time_zone': u'Central Time (US & Canada)',
#   u'translator_type': u'none',
#   u'url': u'https://t.co/SFgB3ME7hP',
#   u'utc_offset': -18000,
#   u'verified': False}}

# %%
# !./searchBlend

# %%
#Import os module
import os

# Ask the user to enter string to search
search_path = input("Enter directory path to search : ")
file_type = input("File Type : ")
search_str = input("Enter the search string : ")


# Append a directory separator if not already present
if not (search_path.endswith("/") or search_path.endswith("\\") ): 
        search_path = search_path + "/"
                                                          
# If path does not exist, set search path to current directory
if not os.path.exists(search_path):
        search_path ="."

# Repeat for each file in the directory  
for fname in os.listdir(path=search_path):

   # Apply file type filter   
   if fname.endswith(file_type):

        # Open file for reading
        fo = open(search_path + fname)

        # Read the first line from the file
        line = fo.readline()

        # Initialize counter for line number
        line_no = 1

        # Loop until EOF
        while line != '' :
                # Search for string in line
                index = line.find(search_str)
                if ( index != -1) :
                    print(fname, "[", line_no, ",", index, "] ", line, " ")

                # Read next line
                line = fo.readline()  

                # Increment line counter
                line_no += 1
        # Close the files
        fo.close()
# Out:
# Enter directory path to search : "/home/jack/Desktop"
# File Type : "*.ipynb"
# Enter the search string : "justhost"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c71902209879> in <module>()
#      17
#      18 # Repeat for each file in the directory
# ---> 19 for fname in os.listdir(path=search_path):
#      20
#      21    # Apply file type filter
#
# TypeError: listdir() takes no keyword arguments

# %%
#Import os module
import os

# Ask the user to enter string to search
#search_path = input("Enter directory path to search : ")
#file_type = input("File Type : ")
#search_str = input("Enter the search string : ")


# Append a directory separator if not already present
#if not (search_path.endswith("/") or search_path.endswith("\\") ): 
#        search_path = search_path + "/"
                                                          
# If path does not exist, set search path to current directory
#if not os.path.exists(search_path):
#        search_path ="/home/jack/Desktop"

# Repeat for each file in the directory  
for fname in os.listdir("/home/jack/Desktop/text_stuff/"):

   # Apply file type filter   
   if fname.endswith("*.ipynb"):

        # Open file for reading
        fo = open("/home/jack/Desktop/save-twitter/" + fname)

        # Read the first line from the file
        line = fo.readline()

        # Initialize counter for line number
        line_no = 1

        # Loop until EOF
        while line != '' :
                # Search for string in line
                index = line.find("justhost")
                if ( index != -1) :
                    print(fname, "[", line_no, ",", index, "] ", line, " ")

                # Read next line
                line = fo.readline()  

                # Increment line counter
                line_no += 1
        # Close the files
        fo.close()

# %%
"/home/jack/Desktop"
".ipynb"
"justhost"
