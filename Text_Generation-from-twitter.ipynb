# %% [markdown]
# # Get Twitter results from raw input and write results to a file

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
#url = u'https://twitter.com/search?q='
HashTag = raw_input("HashTag  : ") or "CNN"
url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list
# Out:
# HashTag  : Coincidence
#
# Have you seen this #LakeEola sculpture? It's called The Muse, by #MegWhite...
# #WhiteStripes or #coincidence...? #Florida #Orlandopic.twitter.com/BjOyHWJogf
#
# Just curious @ErinAndrews did you get proposed to before or after you won your lawsuit for millions of dollars? #Coincidence #IthinkNot
#
# A fitting combination if I've ever seen one. :) @RealityDemon @burlapwinesack #karma #coincidence #funnypic.twitter.com/7wRqWd1slI
#
# The Mall of America opened in 1992 and that was the same year Chrisopher Columbus sailed the ocean blue! #coincidence #Wonderful
#
# Friday 6th October.
# Birth date of two of my favorite people. #Coincidence
#
# Tmz reporting #KylieJenner is pregnant, just in time for #Kuwtk 10 yr special this weekend. #promotionalgenius or #coincidence ???
#
# I just quoted Ferris Bueller on Instagram and now Mathew Broderick is training right in front of me.  #weird #coincidence #nyc #gymlife
#
# I just realized these last few days have been pretty rough and itignores the same few days I havenignoret had any coffee #coincidence? #ThinkNot
#
# @WillAndGrace so terrible!!! @Mariska and @DebraMessing r best friends #coincidence? Nope. TV has passed them by.
#
# Hugh Hefner died on hump day. #coincidence
#
# Me and @JoelvanDyk made a pact to be off the Lokoignores, but since heignores back on the Lokoignores so am I #coincidence
#
# @realDonaldTrump wants and is trying his best to #DestroyDemocracy #Coincidence? I. Don't. Think. So. :(
#
# This morning @BorsatoSam & I talked about dumb ways people hurt themselves. This afternoon, I hurt my toe running upstairs. #Coincidence?
#
# Lighting my favourite candle and realising itignores as black as my soul #coincidence pic.twitter.com/UE5oXszlsw
#
# Happy Drink Beer and Ask a Stupid Question Day! 4.25 BIG BEERS* Today! #Coincidence ? *Ultra, Coors Light, Miller Lite, Bud, Bud Light pic.twitter.com/kSJHTHoUm8
#
# True story: When TNG came out, I was serving as a CDN Naval Officer. My Captain was English and drank Earl Grey on the bridge. #coincidence?
#
# It canignoret be #coincidence that #GoodNeighborDay is 3 days before #PublicPowerWeek begins. Celebrate with your #publicpower utility workers!pic.twitter.com/sH3H5CUvWN
#
# Got told I'm out of work on the same day Hugh Hefner dies... how would a man go about applying for his job? @Playboy #coincidence #ithinknot
#
# FROM TEN DOWN TO THREE. #Family #Love #Destiny #Chance #ExamineFate #Humour #Coincidence #ASMSG #BYNR #IARTG #YA @AustinMacauleypic.twitter.com/tho8K20Sh5
#
# When My Mum Tells Me That My Nani Did GodhBharai Of Neetu Singh Whn She Was Pregnant With Ranbir On Ranbir's Bday Itself
# #CoIncidence

# %% [markdown]
# # Creating phrases.txt From All the Twitter OutPut

# %%
import io
from textblob import TextBlob
from nltk.corpus import wordnet
tweetfile = 'phrases.txt'
filein = open(tweetfile, 'w')
filein.close()  
with io.open("elonmusk.txt", "r", encoding="utf-8") as my_file:
    essays = my_file.read() 

blob = TextBlob(essays)
for np in blob.noun_phrases:
    filein = open(tweetfile, 'a')
    np = '\n'+ u''.join((np)).encode('utf-8').strip()
    np=np.replace("#","");np=np.replace("//","")
    np=np.replace("... ”","");np=np.replace("... ","")
    np=np.replace(".. ","")
    np = np.lstrip()
    if len(np) < 16 and len(np) >3:
            np = (np+"\n")
            filein.write(np)
            print np
            filein.close()
# Out:
# fredericlambert
#
# mactechgenius
#
# @ blundell_apps
#
# assume
#
# fredericlambert
#
# mactechgenius
#
# @ blundell_apps
#
# answers
#
# does
#
# n't matter
#
# fredericlambert
#
# mactechgenius
#
# @ blundell_apps
#
# fredericlambert
#
# mactechgenius
#
# @ blundell_apps
#
# bear
#
# production ramp
#
# late…
#
# mactechgenius
#
# @ blundell_apps
#
# big month
#
# certain right
#
# outonalumb
#
# @ engadget
#
# yeah
#
# mactechgenius
#
# @ blundell_apps
#
# fair criticism
#
# howe…
#
# @ annerajb
#
# priority @
#
# mactechgenius
#
# @ blundell_apps
#
# @ 14agrim
#
# temeyers semi
#
# semi
#
# oth… https
#
# tesla semi
#
# diverting
#
# model
#
# puer…
#
# mactechgenius
#
# jon4lakers
#
# @ solarcity @
#
# tesla
#
# sounds
#
# tesla
#
# tesla powerwall
#
# install team
#
# small right
#
# sending
#
# experi… https
#
# tesla tesla
#
# powerwall
#
# … https
#
# sounds
#
# tesla
#
# escobar
#
# cobain
#
# rickandmorty
#
# room ...
#
# rickandmorty
#
# 's time
#
# ne… https
#
# loganjastremski
#
# reno
#
# area @
#
# rickandmorty
#
# lo… https
#
# @ stapf
#
# tesla
#
# s… https
#
# fly https
#
# aiming
#
# rocket landings
#
# weekend https
#
# wired
#
# yasserhzain
#
# @ verge
#
# jupiter
#
# low payload
#
# yasserhzain
#
# @ verge
#
# homes
#
# jupiter
#
# powerwall
#
# great price
#
# meltingice
#
# g 's
#
# will
#
# moder… https
#
# spacex
#
# space_station
#
# moon
#
# @ bigajm
#
# part
#
# earth
#
# be… https
#
# spacex
#
# supporting
#
# human presence
#
# mars
#
# earth
#
# mins https
#
# mars
#
# city e
#
# mars
#
# day sky
#
# moon base alpha
#
# will
#
# spacex
#
# falcon
#
# earth
#
# @ kevinroose
#
# office @
#
# fashionista_com
#
# @ mayemusk
#
# congrats
#
# @ mayemusk
#
# @ covergirl
#
# covergirl
#
# covergirlmade
#
# prev
#
# kickstarter
#
# um ...
#
# headed
#
# adelaide
#
# detail @
#
# iac2017
#
# el_deano
#
# daimler
#
# jalopnik
#
# fiction https
#
# adrianzorrillac
#
# simulation
#
# rocket
#
# will
#
# be… https
#
# daimler
#
# major
#
# iac2017
#
# rocket
#
# usatodaymoney
#
# nathanbomey
#
# motortrend
#
# shocking
#
# world 's
#
# greatest drag
#
# ludicrous
#
# wgdr7
#
# its_subhamk
#
# good friends
#
# bobby_gupta def
#
# tesla
#
# nex… https
#
# national govt
#
# jaycruicks_atc
#
# mini version
#
# tesla semi
#
# @ bonnienorman
#
# long road
#
# falcon
#
# upper stage
#
# @ simcrook @
#
# smilesimplify
#
# tesla semi
#
# truck unveil
#
# hawthorne
#
# worth
#
# 's unreal
#
# fastcompany
#
# irma
#
# batteries https
#
# gizmodo
#
# hackers
#
# teslamotors
#
# crew dragon
#
# spacex
#
# ’ s
#
# falcon
#
# → https
#
# teslamotors
#
# supercharger
#
# australia
#
# tesla
#
# world 's
#
# exciting tweets
#
# n't need
#
# normal laws
#
# itchgrid
#
# sethicusgp nk
#
# nuclear missile
#
# china
#
# country leaders
#
# china
#
# russia
#
# countries w
#
# competition
#
# national level
#
# https
#
# putting
#
# spacex
#
# blooper reel
#
# gigarothpack
#
# bad idea
#
# dmc_ryan
#
# linked
#
# pusher pod
#
# it… https
#
# chaseblackmon1
#
# @ boringcompany
#
# tunnels
#
# gas pressure
#
# need walls
#
# @ karpathy
#
# ship autonomy
#
# join
#
# chaseblackmon1
#
# @ boringcompany
#
# @ nickg_uk @
#
# adolfoosthuizen
#
# comma… https
#
# graduatemonkey
#
# worth
#
# reading life
#
# tegmark
#
# ’ s
#
# @ bryanclark
#
# hyperloop
#
# spacex
#
# ju… https
#
# hyperloop
#
# itchgrid brakes
#
# will
#
# spacex
#
# @ newscientist
#
# moon
#
# base alpha
#
# cheesy show
#
# mars
#
# richardfpenn
#
# john_gardi
#
# world… https
#
# richardfpenn
#
# john_gardi
#
# to… https
#
# hyperloop
#
# pod run
#
# warr
#
# excellion
#
# openai
#
# wo n't care
#
# model
#
# boring
#
# company tunnel
#
# los angeles
#
# hawthorne
#
# piprefer
#
# jroque250
#
# freewill404
#
# @ cbotnyse
#
# high accel
#
# 20+ miles
#
# spilt drinks
#
# freewill404
#
# @ cbotnyse
#
# such thing
#
# true vacuum
#
# @ cbotnyse
#
# call
#
# might
#
# hyperloop
#
# congratulations
#
# warr
#
# hyperloop
#
# peak
#
# hyperloop
#
# student teams
#
# amazing talent
#
# officeofomar
#
# hyperloopone
#
# smilesimplify
#
# vita_berlin
#
# @ c12olivas
#
# exactly
#
# token amount
#
# coming
#
# trans-canada
#
# mexico
#
# america
#
# funny
#
# zero incentives
#
# very… https
#
# literally
#
# zero
#
# the… https
#
# own companies
#
# smilesimplify
#
# @ beboutside @
#
# hyperloop
#
# spacex
#
# favorite video
#
# falcon
#
# rocket booster
#
# space… https
#
# @ beboutside @
#
# hyperloop
#
# spacex
#
# spacex
#
# boring
#
# hyperloop
#
# hyperloop
#
# spacex
#
# ’ s
#
# @ paradigm_hype
#
# @ swissloop
#
# warr h…
#
# techmeme tesla
#
# ttunes
#
# @ kateconger
#
# will
#
# gary
#
# rolfewinkler
#
# @ julieverhage
#
# found
#
# rolfewinkler
#
# @ julieverhage
#
# rolfe
#
# neuralink
#
# the… https
#
# rolfewinkler
#
# @ julieverhage
#
# neuralink
#
# mach
#
# bulgariansat
#
# energy
#
# mach
#
# @ rupertdance @
#
# voltzcoreaudio
#
# yeah
#
# @ sroalf
#
# intentionally
#
# harshilshah1910
#
# touchdown
#
# falcon
#
# read
#
# instructions
#
# spacex
#
# formosat-5
#
# low-earth orbit
#
# someone
#
# discovermag
#
# spacex
#
# model x suv
#
# $ 500k
#
# lamborghini
#
# teslarati
#
# tesla
#
# unlocks ‘
#
# level
#
# electric tunnel
#
# boring
#
# spacex
#
# worth
#
# works… https
#
# bluerhythmics
#
# theonion
#
# @ ricky_errera
#
# ball mason jars
#
# judging …
#
# friend 's party
#
# mason jar https
#
# ca n't hide
#
# @ cmleahey
#
# mars
#
# @ elonmusk 's
#
# right hand @
#
# spacex
#
# @ theafterpipe
#
# watching
#
# model
#
# s glass roof
#
# spacex
#
# rocket factory
#
# space https
#
# @ geerinckx1989
#
# yeah
#
# seedecentral
#
# @ technology
#
# @ dfchil
#
# aka server
#
# tesla
#
# world… https
#
# pics
#
# spacex
#
# nasa
#
# undergoing
#
# totally
#
# willfealey
#
# features
#
# dem0ney yeah
#
# need
#
# drain battery
#
# @ _jeffreyr @
#
# thephoenixflare
#
# cupen_ames
#
# @ pjfranks1509
#
# will
#
# ranrinbc
#
# cupen_ames
#
# @ pjfranks1509
#
# problem
#
# possible impact
#
# ground objects
#
# @ andrewket
#
# will
#
# cupen_ames
#
# @ pjfranks1509
#
# yeah
#
# user config
#
# to… https
#
# @ pjfranks1509
#
# good point
#
# @ robcrawford08
#
# kermit
#
# @ 9gagtweets
#
# wigs
#
# deleting
#
# patricknla
#
# @ ericgarcetti
#
# schmidtlaxer
#
# support houses
#
# cool thing
#
# model x
#
# @ neddesmond @
#
# spacex
#
# def high
#
# korea
#
# @ neddesmond @
#
# spacex
#
# in… https
#
# spacex
#
# quick
#
# video recap
#
# falcon
#
# dragon
#
# space_station
#
# nasa
#
# space_station
#
# spacex
#
# dragon
#
# dragon
#
# nasa
#
# space_station
#
# falcon
#
# core launch
#
# next… https
#
# beryllium9
#
# @ jasontoff
#
# sure @
#
# can't… https
#
# microsoft
#
# azure
#
# openai
#
# dota
#
# veryvandy
#
# requires
#
# world 's
#
# @ iainthomson
#
# sure hope
#
# ca n't
#
# vastly
#
# korea
#
# openai
#
# defeat world 's
#
# vastly
#
# openai
#
# dota
#
# world 's
#
# solo players
#
# openai
#
# dota
#
# main stage
#
# smilesimplify
#
# vatsalsngh
#
# coming
#
# @ mayemusk
#
# orc illusionist
#
# dressmaker @
#
# time
#
# time
#
# please
#
# awesome weapons
#
# vatsalsngh
#
# t… https
#
# ninja.… https
#
# join… https
#
# mary beth
#
# bogus anecdotes
#
# ashlee
#
# ashlee vance
#
# 's biography
#
# fact-c… https
#
# lwrgi major
#
# supercharger
#
# tesla
#
# falcon
#
# core launch
#
# next… https
#
# amirnoir
#
# working
#
# awarenessreef
#
# @ lexiheft @
#
# domenick_y
#
# @ bonnienorman
#
# time @
#
# belakorr
#
# true
#
# their… https
#
# arguments
#
# @ idedupe
#
# domenick_y
#
# @ bonnienorman
#
# r… https
#
# tomdines
#
# @ bonnienorman
#
# officially
#
# electric car
#
# guardiansustbiz
#
# looking
#
# nasa
#
# rsorokanich
#
# will
#
# @ jdlien
#
# spacex
#
# hyperloop
#
# hope
#
# sure
#
# @ tsrandall
#
# smilesimplify
#
# culture
#
# @ verge
#
# https
#
# yeah
#
# model
#
# @ robertgaal @
#
# ericdiepeveen
#
# s… https
#
# @ ifahaduddin @
#
# ericdiepeveen
#
# n't fair
#
# hell ...
#
# @ ifahaduddin @
#
# ericdiepeveen
#
# dunno
#
# bad events
#
# @ ifahaduddin @
#
# ericdiepeveen
#
# great highs
#
# terrible lows
#
# @ cunarders
#
# model
#
# lateral fins
#
# dashbo… https
#
# model
#
# interior
#
# nigebe
#
# dmc_ryan
#
# focus
#
# model
#
# production hell
#
# versions =
#
# @ antplaysdrums
#
# oatmeal sure rt
#
# motortrend
#
# teslamotors
#
# model3
#
# teslamotors
#
# teslamotors
#
# watch
#
# tesla model
#
# volvo s60
#
# teslamotors
#
# thank
#
# hard work
#
# model
#
# reality https
#
# project loveday
#
# winners ...
#
# teslamotors
#
# watch
#
# model
#
# @ mkarolian
#
# @ elonmusk
#
# master plan
#
# teslamotors
#
# final step
#
# setting
#
# model
#
# night https
#
# cardoso
#
# cosmic_penguin
#
# @ caradocp
#
# cardoso
#
# cosmic_penguin
#
# @ caradocp
#
# sides
#
# run high thrust
#
# c…
#
# @ caradocp
#
# side
#
# canaveral
#
# center lands
#
# falcon
#
# maiden launch
#
# november
#
# tesla
#
# teslarati
#
# remembering
#
# 's yours
#
# teslamotors
#
# watch
#
# project loveday
#
# twitter
#
# @ guardianeco
#
# britain
#
# ban sale
#
# petrol cars
#
# testing
#
# boring
#
# love
#
# tesla p100d
#
# video https
#
# 's piece
#
# softwa… https
#
# @ dcunni @
#
# svbizjournal
#
# mark
#
# @ maralkalajian
#
# saskatchewan
#
# van gogh
#
# starry
#
# nickhorford
#
# $ us price
#
# import duties
#
# sales tax @
#
# ryanbiddle603
#
# spacex
#
# ca n't
#
# public co.
#
# will
#
# che… https
#
# often
#
# stuff https
#
# @ rj8w
#
# mars
#
# ] delusory idea
#
# voltzcoreaudio
#
# @ andygen21 @
#
# teslarati
#
# factories ...
#
# @ andygen21 @
#
# teslarati
#
# discussing
#
# vargas
#
# hawthorne
#
# boring co…
#
# teslarati
#
# spacex
#
# dragon
#
# ships ”
#
# mars
#
# tesla
#
# logistics costs
#
# sparks-fremont
#
# and… https
#
# @ libbycwatson
#
# verbal
#
# federal level
#
# o… https
#
# providence
#
# @ mariom
#
# hyperloop
#
# right way
#
# chicago
#
# o'hare
#
# makes
#
# big difference
#
# formal approval
#
# @ curiousworlds
#
# will
#
# ny-dc
#
# par… https
#
# city center
#
# city center
#
# boring
#
# ny-dc
#
# mars
#
# theonion
#
# suggests sonic
#
# nasa
#
# spacex
#
# cargo launch
#
# space_station
#
# apply
#
# nasasocial
#
# teslamotors
#
# tesla
#
# james murdoch
#
# board https
#
# dellybeck
#
# @ aylaberan
#
# true
#
# need
#
# full story
#
# tesla
#
# some… https
#
# fredericlambert
#
# electrekco
#
# electrek
#
# sure people
#
# electrekco
#
# email
#
# tesla
#
# tesla
#
# yeah
#
# @ tanyaofmars
#
# marscuriosity
#
# awesome
#
# zsoltbarta42
#
# @ fcingolani
#
# @ monster_bo1
#
# small
#
# source
#
# godaddy
#
# godaddy
#
# @ fcingolani
#
# good point
#
# fixed
#
# @ franticnews
#
# benedictevans
#
# @ stevesi
#
# @ stevesi
#
# excited
#
# @ echo_rm @
#
# kiwi_manu
#
# auersusan
#
# @ valleyhack
#
# true
#
# ariane
#
# primary bay
#
# falcon
#
# falcon
#
# oskaiper
#
# @ valleyhack
#
# commercially
#
# spacex
#
# allowe… https
#
# space https
#
# @ alec_ace11
#
# orgs shd
#
# airplane co
#
# kiwi_manu
#
# sound right
#
# worth
#
# boeing/lockheed
#
# annual subsidy
#
# vicform3 latest
#
# going
#
# small nuances
#
# model
#
# sounds tinny
#
# cool
#
# teslamotors
#
# n alaska
#
# europe
#
# china
#
# japan
#
# alexhpforqvc
#
# stevetdent
#
# bill_gross
#
# old bakery
#
# stevetdent
#
# xavier
#
# professor x
#
# @ jondaily83
#
# @ jeremys
#
# cool
#
# 😎 @
#
# voltzcoreaudio
#
# djsnm
#
# adelaide
#
# djsnm
#
# good guys
#
# peopl… https
#
# leo/orlando
#
# goin… https
#
# thanks paypal
#
# @ yoda
#
# full price
#
# hard
#
# roadster
#
# @ bdsams
#
# ira ehrenpreis
#
# 1st car
#
# full deposit
#
# as… https
#
# production
#
# model
#
# final checkout
#
# pics
#
# australia
#
# worlds
#
# energy effort
#
# htt… @
#
# stop
#
# finger dammit
#
# bbcworld
#
# tesla
#
# huffpostau
#
# @ elonmusk 's @
#
# teslamotors
# australia
#
# world 's
#
# australia
#
# @ newscientist
#
# spacex
#
# intelsat thanks
#
# intelsat
#
# really
#
# spacex
#
# 28… https
#
# spacex
#
# done
#
# spacex
#
# full review
#
# launch
#
# o…
#
# wanted
#
# tesla
#
# new car company
#
# wo n't
#
# looks
#
# model
#
# handover
#
# model
#
# production
#
# sept
#
# model
#
# expecting
#
# @ 30akshay
#
# china
#
# androi…
#
# spacex
#
# good https
#
# sorry
#
# china
#
# launch failure
#
# janeidyeve
#
# @ arstechnica @
#
# teslamotors
#
# thephoenixflare
#
# einstein
#
# thephoenixflare
#
# earth
#
# thephoenixflare
#
# great floor
#
# steel skeleton
#
# across
#
# ground https
#
# perspective
#
# @ satalino15
#
# douglasabailey
#
# wall @
#
# trucker_ty_
#
# savvytroll
#
# georgetakei
#
# man cape
#
# might
#
# @ newscientist
#
# exactly
#
# mxpr
#
# simplydonya
#
# n't care
#
# 's way
#
# moves @
#
# syrenboaz
#
# floors @
#
# sandymazza gary
#
# speed demon
#
# long way
#
# tedtalks thanks
#
# godot
#
# good summary
#
# viss
#
# high angles
#
# mach
#
# r… https
#
# @ migueldelagza
#
# 's rocket
#
# droneship
#
# read
#
# instructions
#
# steep spires
#
# windward side
#
# down
#
# aiming
#
# benjamincoop3
#
# should…
#
# @ mjmdavis
#
# humans @
#
# launch
#
# iridium
#
# droneship
#
# extreme weather
#
# will
#
# closeup
#
# fast reentry
#
# @ dnathe4th @
#
# djsnm
#
# crappyusername
#
# reviewing
#
# true
#
# minor factor
#
# clovenlife
#
# falcon
#
# enable… https
#
# djsnm
#
# but… https
#
# @ zerosixbravo
#
# slightly
#
# touch ups
#
# flying
#
# single
#
# piece cast
#
# reentr… https
#
# sticking
#
# emerald0013
#
# rocket
#
# extra toasty
#
# spacex
#
# webcast
#
# falcon
#
# → https
#
# falcon
#
# reentry force
#
# 's launch
#
# technically
#
# ironyman
#
# looks
#
# spacex
#
# falcon
#
# bulgariasat-1
#
# ’ s
#
# forgot bacon
#
# @ justafandavid
#
# @ elonmusk
#
# social media
#
# social media
#
# keep
#
# dammit
#
# @ partialobs @
#
# dpazdan groan
#
# @ hayskeys7
#
# winter tires
#
# @ hayskeys7
#
# will
#
# @ karpathy
#
# excited
#
# tesla
#
# full regen
#
# nozzle diameter
#
# heat
#
# nuts… https
#
# model
#
# abo… https
#
# spacex
#
# static
#
# fire test
#
# falcon
#
# vandenberg afb
#
# june
#
# @ sulka
#
# press attention
#
# @ sulka
#
# production cost
#
# energy source
#
# model
#
# produc… https
#
# @ sulka
#
# gigafactory
#
# is… https
#
# @ verge
#
# max smart
#
# chaos
#
# coincidence
#
# @ quiggles
#
# robtheic0n
#
# dj_mr_cool
#
# real phone
#
# htc droid
#
# @ verge
#
# shoe phone
#
# real shoe @
#
# iphone case
#
# cat ears
#
# clo… https
#
# @ theseoldcars
#
# backup
#
# valve shows
#
# falcon
#
# vandenberg
#
# weekend https
#
# postponing
#
# pneumatic valve
#
# dual redundant
#
# promising
#
# mayorofla
#
# tunnel network
#
# permit…
#
# 's time
#
# … https
#
# tesla
#
# service rescues
#
# wo n't
#
# colonizing mars
#
# prof hubbard
#
# major
#
# hawthorne
#
# california
#
# flying
#
# falcon
#
# factory https
#
# mars v2
#
# ope… https
#
# radar-only
#
# spacex
#
# boeing/lockheed
#
# spacex
#
# @ jasveer10
#
# india
#
# @ cnntech
#
# tesla model x
#
# safety
#
# @ jovanik21
#
# therealportela
#
# us govt
#
# nhtsagov
#
# model x
#
# openai
#
# human feedback
#
# safety
#
# deepmindai
#
# electrekco
#
# watch
#
# tesla model x
#
# crash tests
#
# category https
#
# @ samsheffer
#
# pro… https
#
# aaronthesilver
#
# @ sama
#
# @ ethank @
#
# electrekco
#
# kernel update
#
# giant
#
# mean… https
#
# @ ethank @
#
# electrekco
#
# teslaroadtrip
#
# new kernel
#
# new web browser
#
# radar-only
#
# electrekco
#
# rajveerjolly
#
# mars…
#
# expensive cars
#
# affordable cars
#
# steveprediletto
#
# tesla
#
# fredericlambert
#
# teslamotors
#
# master plans
#
# tesla
#
# ho… https
#
# teslamotors
#
# martin
#
# lotus elise
#
# dead… https
#
# ritspex
#
# id_aa_carmack
#
# @ mmeijeri
#
# id_aa_carmack
#
# @ mmeijeri
#
# gravity
#
# eclecticlip was
#
# biz plan
#
# tzero
#
# @ __svndee
#
# disruption
#
# deep ai
#
# real risk
#
# teslamotors
#
# 's 'summon
#
# marker2002
#
# @ chrispaine
#
# @ isco__
#
# heard
#
# worth
#
# who killed
#
# @ chrispaine
#
# truth
#
# franco_fwg
#
# zedd
#
# zedd
#
# apexcornerspeed
#
# braverock_
#
# superchargers
#
# wi… https
#
# @ mor10
#
# norway
#
# world leader
#
# great example
#
# @ kieranquinn27
#
# long way
#
# auto industry
#
# o… https
#
# thought
#
# % prob
#
# tesla
#
# electric cars
#
# junkyard @
#
# rafaelm81
#
# ericaboarman
#
# ludicrous
#
# pure joy
#
# mute music
#
# @ cabbey @
#
# jeffmcadams
#
# good point
#
# voice commands
#
# ericidle too
#
# awesome @
#
# belltower
#
# garthredshaw
#
# the1manherd
#
# @ mashabletech
#
# long time
#
# auto play
#
# will
#
# tesla dj
#
# canada
#
# @ sakerjacks
#
# michaelgladis
#
# jeffmcadams tap
#
# voice button
#
# monty python
#
# navigate
#
# voice
#
# commands work
#
# ericaboarman
#
# sedan
#
# @ jschindeler
#
# yeah
#
# @ symonchester
#
# coming
#
# @ castfxman
#
# partly
#
# favorite skit @
#
# angboire might
#
# canada
#
# @ markedtek
#
# @ rrosenbl
#
# yeah
#
# tesla
#
# monty python
#
# does
#
# n't work
#
# @ philwhln
#
# might
#
# tesla
#
# powerwall
#
# tesla
#
# deandcruz
#
# tesla dj
#
# brian
#
# d…
#
# johnnyzenith
#
# falcon
#
# @ redletterdave
#
# voodoo dolls
#
# @ johnbiscevic
#
# yeah
#
# @ danahull
#
# yeah
#
# labjnews
#
# traffic hell
#
# be… https
#
# labjnews
#
# boring
#
# hawthorne
#
# spacex thanks
#
# read
#
# sahershodhan
#
# falcon
#
# spacex
#
# 4k video
#
# falcon
#
# dragon
#
# space_station
#
# @ sama
#
# @ farhad667
#
# red wine
#
# vintage record
#
# ambien
#
# @ avyas0
#
# mistake people
#
# um ...
#
# @ brokesilver
#
# seems
#
# way @
#
# nigelkbaker
#
# tesla
#
# @ newscientist
#
# spacex
#
# private company
#
# teslamotors
#
# f* underwear
#
# @ mcgd @
#
# … https
#
# smilesimplify
#
# robinwigg
#
# great comedy
#
# theonion
#
# hcpg
#
# markbungerlux
#
# high headcount
#
# gigafactory
#
# markbungerlux
#
# logistics
#
# end customer
#
# thestaceyroy
#
# underwear rt
#
# teslamotors
#
# elon
#
# actual sloth
#
# zootopia
#
# desk https
#
# @ commoboy @
#
# spacex
#
# dragon
#
# space station
#
# proud
#
# pandora659 yeah
#
# dead center
#
# target area
#
# @ zlorena70
#
# exactly
#
# reuse rockets
#
# nasa
#
# icymi
#
# earth
#
# space_station
#
# dragon
#
# good point
#
# robertiger
#
# parisagreement
#
# india
#
# electric cars
#
# solar power
#
# paris
#
# china
#
# climate
#
# leaving paris
#
# america
#
# spacex
#
# falcon
#
# dragon
#
# nasakennedy
#
# weather
#
# ’ s
#
# themarssociety
#
# tomorrow
#
# spacex will
#
# futurism
#
# @ danekevincook
#
# yeah
#
# @ insideclimate
#
# breaking
#
# call
#
# disclosure
#
# landmark vote
#
# will
#
# depart councils
#
# paris
#
# potus
#
# liledit
#
# nalepa
#
# taraustralis
#
# piggyback
#
# sydney
#
# andypabari
#
# curtishemming
#
# teslamotors
#
# swift current
#
# openai
#
# comparing model
#
# s vs
#
# model
#
# old-school
#
# fidget spinner
#
# rocks https
#
# fbeuster
#
# dark parts
#
# falcon
#
# exciting https
#
# owners… https
#
# pure joy
#
# going
#
# max speed
#
# busted
#
# will
#
# bond lotus
#
# sub as-is
#
# design ca n't
#
# ha…
#
# true
#
# feel
#
# scott
#
# particularly
#
# spy who loved
#
# irishjugg0
#
# macbentosh
#
# model
#
# bigdak54
#
# paris
#
# cautiously
#
# waldekkubicki
#
# @ shazm01
#
# interesting
#
# have
#
# i… https
#
# @ sethjacob14
#
# early
#
# model
#
# n't do… https
#
# @ shazm01
#
# @ douglasprest
#
# georgetakei
#
# elon musk
#
# new venture
#
# mcornell0
#
# @ marks22
#
# exactly
#
# @ tony_lo
#
# tesla
#
# yea… https
#
# hundreds
#
# w…
#
# @ harropj
#
# june
#
# macbentosh
#
# @ jetkohli
#
# model
#
# approx version
#
# s… https
#
# theavinashsingh
#
# @ rrosenbl
#
# yeah
#
# @ ethank
#
# web browser
#
# @ kedyson1
#
# production cars
#
# july
#
# ritspex
#
# bradmsimon
#
# jonhaber
#
# @ lexiheft @
#
# hugomeister42
#
# excited
#
# tesla autopilot
#
# model x
#
# model
#
# autopilot
#
# r… https
#
# @ songcarver
#
# wear
#
# underpants @
#
# jonhaber will
#
# slate versions
#
# @ waitbutwhy
#
# good resource
#
# worldandscience
#
# ca n't
#
# peo… https
#
# @ waitbutwhy
#
# 's points
#
# co… https
#
# @ waitbutwhy
#
# heisenberg
#
# @ creepypuppet
#
# mera
#
# amber heard
#
# shot
#
# @ jasinboland
#
# electrekco
#
# volvo
#
# tesla
#
# diesel engines
#
# fairaday
#
# ground https
#
# oliver_brian
#
# boring
#
# nowhere
#
# t-boned
#
# model x
#
# mph https
#
# robots
#
# openai
#
# spacex
#
# quick
#
# video recap
#
# falcon
#
# inmarsat-5
#
# openai
#
# roboschool
#
# openai gym
#
# spacex
#
# webcast
#
# falcon
#
# → https
#
# @ wcax
#
# greenmtnpower
#
# tesla
#
# @ alexandrawcax
#
# details https
#
# @ gmem_
#
# 's sort
#
# claw side
#
# speedy gonzales
#
# meth ...
#
# either
#
# godot
#
# our… https
#
# worked
#
# minecraft
#
# sayin @
#
# ujustgotcarled
#
# imma
#
# gon na dig
#
# hammer @
#
# andrewhws
#
# moose jaw
#
# @ gleesin
#
# going
#
# barn raising
#
# cousin 's farm
#
# canada
#
# hat https
#
# @ jewhittingham
#
# yeah
#
# africa
#
# becauseimash
#
# warning
#
# motion sickness
#
# gary
#
# pet snail
#
# godot
#
# boring
#
# starter tunnel
#
# going
#
# cutterhead
#
# ten… https
#
# boring
#
# full length
#
# to… https
#
# entry
#
# boring machine
#
# godot
#
# complete https
#
# @ samgalaviz_
#
# tesla
#
# tesla
#
# tragik187
#
# frost
#
# armstrong_anth
#
# godot
#
# naming
#
# decided
#
# @ sahilmalik
#
# tesla
#
# or… https
#
# lee_ars
#
# utility costs
#
# property taxes
#
# slo-mo
#
# hail cannonball
#
# tesla
#
# @ cubamark
#
# will
#
# teslamotors
#
# solar roof
#
# @ business
#
# tesla
#
# electrekco
#
# tesla
#
# regular roof
#
# solar
#
# deployment
#
# @ chriscardinal
#
# black
#
# tuscan
#
# u.k.
#
# tesla
#
# hours ...
#
# heat death
#
# journey https
#
# georgechiesa
#
# @ jovanik21
#
# thanks
#
# headed
#
# guardians
#
# loved
#
# @ keithdcohen
#
# @ zanesloanbc
#
# simple
#
# kinda
#
# snoop dug
#
# andrewhws
#
# well
#
# @ reviewero
#
# boring
#
# boring
#
# been
#
# thinking
#
# machine …
#
# mrjc2012
#
# p100d
#
# ludicrous
#
# thank
#
# close-up
#
# boostback burn
#
# then… https
#
# landing
#
# spacex
#
# screen shot
#
# falcon
#
# earth
#
# landing
#
# zone 1. https
#
# launch
#
# spy satellite
#
# tough
#
# high altitude
#
# t… https
#
# spacex
#
# falcon
#
# lz-1
#
# worrying
#
# elon musk
#
# cars https
#
# spacex
#
# falcon
#
# nrol-76
#
# launch
#
# climatemarch
#
# washington dc
#
# huge
#
# @ williamlegate
#
# @ batfflck
#
# extremely
#
# boring
#
# xhnews
#
# wang yang
#
# beijing
#
# surface detail
#
# teslamotors
#
# charging
#
# ’ re
#
# supercharger
#
# pjwu8
#
# great food
#
# great ambience
#
# great friends
#
# judeburger
#
# will
#
# moo moo
#
# moo moo
#
# gold coast
#
# creepypuppet
#
# cowanfilms
#
# @ waitbutwhy
#
# full story
#
# neuralink
#
# teslamotors
#
# tesla
#
# ~500-ft fall
#
# model s.
#
# electrekco rt
#
# aaaauto
#
# winner
#
# car guide
#
# car reviews
#
# fredericlambert
#
# taylorsmarks
#
# flipperb
#
# @ pkingdesign
#
# yeah
#
# kwh pa… https
#
# flipperb
#
# @ pkingdesign
#
# @ pkingdesign
#
# tesla
#
# @ gucci_mau
#
# july
#
# truck unveil
#
# months @
#
# samgonzales
#
# roadster
#
# tesla semi
#
# truck unveil
#
# september
#
# team
#
# amazing job
#
# seriously
#
# @ danahull @
#
# reuters yeah
#
# reuters
#
# scty
#
# will
#
# this… https
#
# reuters
#
# investor group
#
# ford
#
# amazing ...
#
# autolist
#
# tesla
#
# car values
#
# fairing
#
# ~ $ 5m
#
# min max
#
# checking
#
# feature
#
# touch access
#
# tesla easter
#
# eggs https
#
# openai
#
# neural network
#
# humanity https
#
# forin2020
#
# exactly
#
# tesla
#
# 's irr… https
#
# walt
#
# stormy
#
# shortville
#
# daveleebbc
#
# @ verge coal
#
# nat gas
#
# lexxxzis
#
# wo n't matter @
#
# supercoolcube
#
# silly rockets
#
# damn
#
# crazy tech
#
# ca n't
#
# english
#
# openai
#
# world 's
#
# physical robot
#
# profbriancox
#
# @ elonmusk
#
# spacex
#
# much
#
# @ adamsbj
#
# def p100d
#
# ludicrous+
#
# badastronomer
#
# dragon
#
# @ jasonlamb
#
# looks
#
# expendable mode
#
# @ cheron
#
# lot @
#
# secret payload
#
# dragon
#
# giant wheel
#
# inspired
#
# b… https
#
# @ redletterdave
#
# good point
#
# falcon
#
# test flight
#
# late summer
#
# upper stage
#
# falcon
#
# demo flight
#
# odds
#
# @ oxfordteddy
#
# browser
#
# kernel
#
# browser update
#
# spacex
#
# ’ s
#
# falcon
#
# → https
#
# badastronomer
#
# incredibly
#
# spacex
#
# spacex
#
# falcon
#
# love
#
# — world ’ s
#
# spacex
#
# ~60 minutes
#
# launch window
#
# ses-10
#
# watch
#
# → https
#
# spacex
#
# falcon
#
# ses-10
#
# kennedy
#
# launch
#
# made
#
# tesla
#
# v8.1
#
# center screen
#
# center screen
#
# changes opacity
#
# @ danahull
#
# china
#
# europe
#
# model
#
# @ business
#
# glad
#
# tencent
#
# tesla
#
# wo n't care @
#
# nakatomitim
#
# @ nickg_uk
#
# spacex
#
# deep space
#
# edits https
#
# neuralink
#
# @ waitbutwhy
#
# difficult
#
# openai
#
# 's limitations
#
# norway
#
# isabelle_kent
#
# d1sneynut
#
# @ nickbaum
#
# @ nddugan
#
# mr_ewe_guy oh
#
# faith @ kryniog
#
# model
#
# pokervixen
#
# @ elonmusk
#
# model s.
#
# rh_way
#
# @ elonmusk
#
# tessi
#
# member
#
# april
#
# @ dr_angus
#
# yeah
# @ morrisonbrett
#
# @ elonmusk
#
# model
#
# p85d
#
# grey
#
# triple
#
# model
#
# seater option
#
# cargo space
#
# @ arctechinc
#
# @ elonmusk
#
# tesla
#
# model
#
# model x
#
# thank
#
# … @
#
# camkode
#
# model
#
# drivin… https
#
# herifin_teki
#
# @ elonmusk
#
# lil monster
#
# tesla model x
#
# thank
#
# elon
#
# bluebowles
#
# will
#
# @ juanmlemao
#
# djburges
#
# sorry
#
# fredericlambert
#
# timshelton
#
# jimpengelly
#
# magic wand ...
#
# ricardotwumasi
#
# @ elonmusk
#
# tesla model
#
# shkottt
#
# @ elonmusk
#
# tesla roadster
#
# car i 've
#
# timshelton
#
# fredericlambert
#
# jimpengelly
#
# dual motor
#
# @ meangene2030
#
# damn
#
# coming
#
# model
#
# fredericlambert
#
# @ danieltadros
#
# mrthorman
#
# model s
#
# voltzcoreaudio
#
# lots
#
# new tech
#
# @ arctechinc
#
# dash info
#
# @ asimo3089
#
# model
#
# @ bobbykansara
#
# mrthorman
#
# @ elonmusk
#
# model x
#
# period
#
# @ trabru
#
# machine arrives
#
# @ oakhaller
#
# fredericlambert
#
# jimpengelly
#
# production ramp
#
# @ jdaz
#
# dumb idiot
#
# tues/wed
#
# skate_a_book
#
# model
#
# tesla
#
# roadster
#
# jimpengelly
#
# alsaibie
#
# hardware
#
# production s
#
# @ theken_miller
#
# sorta
#
# model
#
# audi a4
#
# model
#
# faste… https
#
# greg525
#
# oh model y
#
# kinda
#
# @ luciojr
#
# tesla
#
# definitely
#
# model
#
# model e
#
# ford
#
# totally
#
# timbeiko
#
# model
#
# model
#
# model
#
# model
#
# tesla
#
# looking
#
# @ aaronpaul_8
#
# trying
#
# hope
#
# 'm building
#
# home planet
#
# least… https
#
# @ phirate
#
# either
#
# great filter
#
# nites
#
# n't work @
#
# nites
#
# looks
#
# tues/wed
#
# house ...
#
# @ karaswisher
#
# future bill
#
# mars
#
# @ karaswisher
#
# bill changes
#
# nasa
#
# existing
#
# @ ryanrossuk
#
# @ elonmusk
#
# hope
#
# model x
#
# customer story
#
# never
#
# spacex
#
# recovery teams
#
# dragon
#
# spacex
#
# falcon
#
# spacex
#
# echostar xxiii
#
# spacex
#
# final burn
#
# spacex
#
# liftoff
#
# capnjesus
#
# lurpatron
#
# mkbhd
#
# @ jakerawr
#
# great car
#
# model
#
# @ kyleugh
#
# good point @
#
# priyancaford
#
# sense https
#
# andreelijah ok
#
# bizbuilderusa
#
# legit_bacon
#
# looking
#
# 's cliche
#
# lotr
#
# favorite book
#
# want
#
# t… https
#
# vgroysman sure
#
# w…
#
# key govt
#
# utility leaders
#
# s… https
#
# australians
#
# battery plan
#
# @ ah_pton16
#
# wikipedia
#
# jmmzherrera
#
# electric motors
#
# induction motor
#
# igbt
#
# inve… https
#
# high voltage
#
# long distances
#
# ironically
#
# right approach
#
# solar
#
# renewables
#
# + storage
#
# disr… https
#
# jayweatherill
#
# australia
#
# govt
#
# @ shails
#
# 100mwh+ systems
#
# tesla
#
# tesla
#
# zedd will
#
# teslamotors
#
# project loveday
#
# thank
#
# lovely letter
#
# great idea
#
# spacex
#
# nasa
#
# @ jamesatbuzz
#
# moon ...
#
# ok spacex
#
# mactechgenius
#
# course @
#
# duediamond
#
# roller
#
# tristate border
#
# gigafactory
#
# large workforce
#
# @ donbarbieri @
#
# greencarreports
#
# good chance
#
# toysrus exactly
#
# @ meganmurp @
#
# chrisfaile
#
# n't pose
#
# tunnel
#
# machine pic wd
#
# @ adrianvolts
#
# minor
#
# review https
#
# video https
#
# baby
#
# spacex
#
# falcon
#
# lz-1
#
# @ mattnewby
#
# nasa
#
# right
#
# solar arrays
#
# spacex
#
# dragon
#
# watch
#
# xuan_thai
#
# @ spacecom
#
# dragon
#
# @ zperrin99
#
# uses
#
# high pressure
#
# fuel side
#
# rp-1
#
# % chance
#
# zybbby
#
# helium leak
#
# n't symptomatic
#
# movement trace
#
# standing
#
# spacex
#
# falcon
#
# dragon
#
# space_station
#
# rocket
#
# launch
#
# counting
#
# spacex
#
# apollo
#
# nasa
#
# hear
#
# 's 10:01am
#
# spacex
#
# cargo launch
#
# space_station
#
# provided dragon
#
# demo missions
#
# spacex
#
# us astronauts
#
# looks
#
# added
#
# abort trigger
#
# t-60
#
# pressure decay
#
# investigating
#
# upper stage
#
# solid rock
#
# @ sc00bs
#
# daylight
#
# rocket launch
#
# will
#
# spacex
#
# apollo
#
# phoebecoleman
#
# good ones
#
# will
#
# kids ca n't
#
# vrgtech
#
# floydilicious
#
# india
#
# isro
#
# ludwigmorelos
#
# ca n't hide
#
# irony
#
# man ...
#
# samcornwell
#
# tesla
#
# repair costs
#
# congrats
#
# tesla
#
# own car
#
# @ lollieshopmom
#
# cape causeway @
#
# seacitylight
#
# nas2four sounds
#
# tesla powerwall
#
# powerpack
#
# falcon
#
# canaveral
#
# complex 39-a
#
# launch… https
#
# megangeuss
#
# @ arstechnica
#
# exactly
#
# rusulalrubail
#
# markruffalo
#
# @ guardian
#
# please
#
# tesla
#
# spacex
#
# teslamotors
#
# supercharger
#
# tesla
#
# ar… @
#
# sundalj
#
# trend
#
# porsche
#
# voltzcoreaudio
#
# tarpaulin ...
#
# spacex
#
# targeting feb.
#
# dragon
#
# space_station
#
# 1st launch
#
# lc-39a
#
# nasa
#
# jim baker
#
# batlag
#
# hoping
#
# @ mdcdave yes
#
# opposite
#
# combustion cars
#
# @ jovanik21 @
#
# veidit
#
# wheelbase
#
# ca n't
#
# @ jovanik21
#
# tesla
#
# n't use
#
# veidit
#
# semi
#
# pickup truck
#
# @ jovanik21
#
# floor mats
#
# @ quick_pi yes
#
# p100dl
#
# trend
#
# sec https
#
# @ verge
#
# millions
#
# tesla
#
# battery cells
#
# homes https
#
# signing
#
# twitter
#
# stevecase
#
# mactechgenius
#
# ready @
#
# linux
#
# browser update
#
# hw2 autopilot
#
# fredericlambert
#
# model
#
# @ clay_ellis
#
# africa
#
# asia
#
# favorite things
#
# @ christesla @
#
# fredericlambert
#
# @ trylks
#
# terrible things
#
# complex ideas
#
# cycletrades
#
# blind
#
# wise1919
#
# new update
#
# @ recipher
#
# @ iamdeveloper
#
# really
#
# sorry
#
# fredericlambert
#
# @ thelogicbox @
#
# earth
#
# @ seanbroswag @
#
# energy density
#
# travelingmom23
#
# canada
#
# regina
#
# minnesota
#
# fredericlambert
#
# @ brendangage
#
# great country
#
# looking
#
# @ rtoro20
#
# really
#
# own idiocy @
#
# daringkid true
#
# @ marcelsalathe
#
# 200+ countries
#
# activists
#
# bencam137
#
# love norway
#
# bullflags yeah
#
# twitter
#
# hellscape
#
# w4as
#
# good grief
#
# trump
#
# bittermercy
#
# callumk24
#
# erichaegler
#
# @ ilexomat
#
# default option
#
# @ vladsavov
#
# fifthrocket
#
# kenemonics
#
# politics
#
# somebody
#
# @ paulvankeep
#
# exactly
#
# thelaadams
#
# laws need
#
# judges
#
# @ humplik
#
# callumk24 ok
#
# @ ilexomat
#
# biesseman true
#
# america
#
# legal system
#
# teslamotors
#
# honored
#
# germany
#
# thank
#
# walking
#
# chrisjcav
#
# favorite mug
#
# oldmanriver1800
#
# @ alext4627
#
# love half-life
#
# @ ana_lontana
#
# nuances
#
# rainbows
#
# d.c.
#
# really
#
# feels
#
# daniellebloeme
#
# doing
#
# travel ban
#
# petergleick
#
# @ business
#
# will
#
# officeofomar
#
# video
#
# 's entrant
#
# hyperloop
#
# almo… https
#
# minecraft
#
# @ mcun1
#
# green cards
#
# dual citizens
#
# ok. work
#
# spousal visas
#
# judicial action
#
# white house
#
# wired
#
# world 's
#
# poker players
#
# human intuition
#
# sarahfkessler
#
# @ qz
#
# headline
#
# wo n't
#
# pres
#
# be… https
#
# reesandersen
#
# flixrisk
#
# good future
#
# top ai
#
# teslamotors
#
# utility grid
#
# tesla
#
# powerpack
#
# 's substation
#
# 's relian…
#
# @ inhaleray
#
# great jobs
#
# us strength
#
# yeah
#
# jacobofamber
#
# source material
#
# reading
#
# source material
#
# hyperloop
#
# congrats
#
# warr hyperloop
#
# entire length
#
# world 's
#
# hyperloop
#
# hyperloop
#
# watch
#
# warr hyperloop
#
# test flights
#
# hyperloop
#
# watchlive
#
# warr hyperloop
#
# team attempts
#
# policy forum
#
# exactly
#
# please
#
# will
#
# parparv
#
# n't deserve
#
# muslim
#
# country ’ s
#
# miguelgamino
#
# popsci
#
# @ techinsider
#
# futuristic pods
#
# elon musk
#
# hyperloop
#
# weekend https
#
# hyperloop
#
# pod race
#
# spacex hq
#
# yeah
#
# positi… https
#
# hyperloop
#
# teams
#
# testing
#
# spacex hq
#
# jan.
#
# → https
#
# gizmodo
#
# elon musk
#
# rex tillerson
#
# donald trump
#
# can… https
#
# @ _wsimson
#
# spacex
#
# crenshaw
#
# freeway
#
# @ clay_ellis
#
# belovedrevol
#
# exciting
#
# tunnel front
#
# rex tillerson
#
# carbon tax
#
# gizmodo
#
# michaelemann
#
# michaelemann
#
# nivo0o0 was
#
# sigh
#
# michael_mclean
#
# difficult award
#
# tillerson
#
# “ action
#
# theeconomist
#
# address threats
#
# global response
#
# ’ s
#
# se… https
#
# @ redletterdave
#
# soldier
#
# @ danahull
#
# economist
#
# 's opinion
#
# @ danahull
#
# theeconomist
#
# economist
#
# rex tillerson
#
# poten… https
#
# software update
#
# @ neiltyson
#
# lindbergh
#
# paris
#
# moon
#
# @ tsrandall
#
# @ stephenstohn
#
# regs disallow
#
# auto
#
# heavy traffic
#
# limit
#
# @ dnansink40
#
# autonomy
#
# weeks @
#
# thesammyyyd
#
# hendrikstruik
#
# 100d price
#
# vehicle prices
#
# block
#
# final upgrade
#
# falcon
#
# significantly
#
# … https
#
# @ dtweiseth
#
# @ dtweiseth
#
# tesla
#
# wrong car
#
# maj… https
#
# ritachung16
#
# vinnylingham
#
# entire car
#
# 300+ parts
#
# easy way
#
# giant x
#
# model x
#
# tesla
#
# china
#
# falcon
#
# falcon
#
# @ jakebathman
#
# wo n't
#
# working
#
# image crop
#
# … https
#
# autopilot
#
# please
#
# validating
#
# driver fix
#
# ukpjd
#
# spacex
#
# cross section
#
# electric motor
#
# @ tsrandall
#
# tesla
#
# ’ s
#
# autopilot
#
# nhtsa
#
# % drop
#
# crashes https
#
# tochote
#
# % reduction
#
# @ cameronrad
#
# autopilot
#
# modularlifesys
#
# nhtsagov
#
# @ gavinnwaters
#
# looking
#
# data show
#
# tesla
#
# crash rate
#
# autosteer
#
# final
#
# autopilot
#
# nhtsagov
#
# positive https
#
# bbc_topgear
#
# tesla
#
# race car
#
# ’ ll
#
# seconds https
#
# spacex
#
# updated
#
# falcon
#
# launch https
#
# fellipec
#
# olivierw4
#
# rewatched
#
# ghost
#
# shell
#
# colossus
#
# forbin project
#
# hw2 autopilot
#
# jimdekort
#
# spacex rotates
#
# retro burn @
#
# jimdekort
#
# spacex
#
# liftoff
#
# spacex
#
# read
#
# instructions
#
# started
#
# iridium
#
# rocket
#
# spacex
#
# less
#
# falcon
#
# launch window
#
# spacex
#
# tracking
#
# weather
#
# favorable https
#
# teslamotors
#
# have
#
# steam engines
#
# jrmygrnbrgr
#
# trying
#
# @ trevoclark
#
# good point
#
# tesla
#
# stripped
#
# claremacraeuk
#
# promising
#
# early results
#
# looks
#
# trend
#
# achievable ...
#
# @ mjreddymd
#
# point release
#
# hw1…
#
# @ redletterdave
#
# @ mbhnyc
#
# year @
#
# 's approach
#
# teslamotors
#
# teslamotors
#
# supercharger
#
# top priority
#
# ov… https
#
# will
#
# rais… https
#
# hw2 autopilot
#
# active mode
#
# new rev
#
# autopilot hw2
#
# shadow mode
#
# ludicrous+
#
# @ fatihorhan @
#
# spacex
#
# wired hold-down
#
# spacex falcon
#
# vandenberg
#
# air force
#
# hw2 autopilot
#
# will
#
# field issues
#
# @ vicentes @
#
# linux
#
# kernel upgrade
#
# dragtimes
#
# autopilot
#
# t… https
#
# resolving
#
# autopilot hw2
#
# churchill
#
# iridiumcomm
#
# milestone alert
#
# iridiumnext
#
# falcon
#
# nextevolutio…
#
# @ andrewket
#
# undergoing
#
# might
#
# electrekco
#
# tesla autopilot
#
# ’ s
#
# deus
#
# ex machina
#
# center screen
#
# ends @ quipme
#
# occasional
#
# @ djsearle @
#
# fredericlambert
#
# grid wo n't
#
# moderate use
#
# superchargers
#
# fredericlambert
#
# kw ...
#
# children 's toy
#
# full right
#
# fredericlambert
#
# full rollout
#
# supercharger v3
#
# powerpack v2
#
# … https
#
# @ ddaogaru
#
# p100dl
#
# @ wpconner
#
# sweenschris
#
# swift current
#
# @ darkdude203
#
# scroll wheel
#
# center console
#
# will
#
# cell connection
#
# model x
#
# type holidays
#
# modelxmas
#
# mars
#
# cjdsb looking
#
# @ pcwizardllc
#
# @ jelleprins
#
# @ pcwizardllc
#
# will
#
# lead vehicle
#
# thebeazles
#
# twilight
#
# @ vicentes
#
# model x
#
# @ vicentes
#
# samlawrence
#
# looks
#
# autopilot
#
# tesla
#
# tesla autopilot
#
# road time
#
# wide range
#
# @ slackmds
#
# teslamotors
#
# teslamotorsclub
#
# teslarati tesla
#
# software team
#
# chromejs10
#
# teslamotors
#
# ba… https
#
# boring
#
# boring
#
# @ loic
#
# @ loic
#
# supercharger
#
# will
#
# forming
#
# n't fake
#
# openai
#
# video tutorial
#
# universe
#
# @ sirajology
#
# openai
#
# universe
#
# model
#
# s smashes
#
# teslamotors
#
# faster
# rating
#
# mailonline
#
# @ edwardsanchez
#
# @ thedrive
#
# lobbyists
#
# tesla
#
# mederinho10
#
# @ business
#
# @ stryker_88
#
# will
#
# cjdsb
#
# teslamotors
#
# backlog
#
# fav version
#
# pic tho
#
# fake pieces
#
# electrekco
#
# right-wing
#
# trump
#
# elon musk
#
# tesla
#
# spacex
#
# teslamotors
#
# samoa
#
# @ newscientist
#
# google
#
# ’ s
#
# deepmind ai
#
# pro https
#
# teslamotors
#
# longer
#
# paint
#
# black
#
# teslamotors
#
# paint
#
# black
#
# easter
#
# teslamotors
#
# yes @
#
# parparv
#
# tesla
#
# benny
#
# consequences
#
# upside
#
# social services
#
# techcrunch
#
# p85d
#
# teslamotors
#
# @ turo
#
# @ vicentes @
#
# teslamotors
#
# fortunemagazine
#
# teslamotors
#
# battery
#
# solar farm
#
# kauai
#
# fortunemagazine
#
# spacex
#
# successfully
#
# mars
#
# full cryo
#
# vote
#
# tesla/solarcity
#
# thanks
#
# theeconomist
#
# new data show
#
# contra_9077
#
# @ tsrandall
#
# tesla
#
# easter
#
# world 's
#
# arminkeyani
#
# p100d
#
# model x
#
# looks
#
# model
#
# p100d easter
#
# software update
#
# wo n't
#
# id_aa_carmack
#
# red detection
#
# natgeo
#
# watch
#
# mars
#
# realronhoward
#
# mars
#
# natgeo hope
#
# love
#
# nasa
#
# mars
#
# ’ s worth
#
# earth
#
# learn
#
# neighbor planet
#
# teslamotors
#
# survey
#
# tesla
#
# germany
#
# autopilot
#
# @ ggreenwald
#
# teslamotors
#
# model x
#
# steering
#
# teslamotors
#
# world 's
#
# inlucidreverie
#
# meaningful role
#
# playing amish
#
# tesla
#
# @ muodebe
#
# rudolph
#
# mrspanier
#
# light tartan
#
# plaid
#
# roadster
#
# shireeshagrawal
#
# humanity @
#
# dmc_ryan
#
# @ davidtayar5
#
# tesla
#
# solarcity
#
# altho
#
# debts
#
# seltzerplease
#
# playoverwatch
#
# great time
#
# pmnickbeach
#
# @ bakkedahl
#
# dragtimes
#
# @ joshuadistler
#
# tesla
#
# solarcity
#
# mikemfknsplain
#
# day @
#
# locobooff
#
# @ _andyoneal @
#
# john_gardi
#
# forgot
#
# mactechgenius
#
# john_gardi
#
# wheel @
#
# mrroryreid
#
# mactechgenius
#
# ambien
#
# n't wise
#
# mactechgenius
#
# fold flat
#
# small family
#
# john_gardi
#
# option @
#
# john_gardi
#
# mrroryreid
#
# mykalsocal
#
# bbc_topgear
#
# @ balaji_kann
#
# primarily
#
# b pillar
#
# glass overlay
#
# body structure
#
# glass roof
#
# model s.
#
# @ originaltman
#
# will
#
# cnbc
#
# ron baron
#
# hour https
#
# model x
#
# bbc_topgear
#
# world 's
#
# tesla-solarcity
#
# merger https
#
# china
#
# @ brainwipe
#
# monte carlo
#
# weaknesses @
#
# clintonkeith
#
# good chance
#
# internet
#
# teslamotors
#
# additional
#
# tesla
#
# solarcity
#
# bobafaux
#
# solar
#
# glass tiles
#
# rear defroster
#
# hipstreeet
#
# teslamotors
#
# solar
#
# roof glass tile
#
# tesla
#
# solar roof
#
# heavy hail
#
# standard roof
#
# @ jodyfisher
#
# exactly
#
# cnbc
#
# tesla
#
# 's solar roof
#
# teslamotors
#
# tuscan
#
# teslamotors
#
# close
#
# teslamotors
#
# powerwall
#
# storage https
#
# teslamotors
#
# tesla
#
# solarcity
#
# pushing
#
# unveil
#
# solar
#
# powerwall
#
# launch event
#
# johngarryvo
#
# solar
#
# roof unveil
#
# need daylight
#
# obvious reasons
#
# california
#
# @ solarcity
#
# thanks
#
# ’ s
#
# great couple
#
# months –
#
# techcrunch
#
# musk
#
# tesla network
#
# tesla
#
# uber
#
# people vs․
#
# https
#
# dear
#
# cult members
#
# electrekco
#
# bob lutz
#
# tesla
#
# $ 11b
#
# reign https
#
# @ bstep
#
# different way
#
# @ soswow yeah
#
# great questions
#
# meant
#
# california
#
# teslamotors
#
# tesla
#
# turning point
#
# fortunemagazine
#
# @ verge
#
# tesla model
#
# teslamotors
#
# new hardware
#
# work https
#
# praneshsuvarna
#
# youtube
#
# char_bit
#
# summon
#
# bret_with1t
#
# teslamotors
#
# body color
#
# tesla
#
# human input
#
# urban streets
#
# @ vicentes
#
# new car
#
# @ elonmusk
#
# fully
#
# alternatejones
#
# tesla
#
# year https
#
# futureboy
#
# will
#
# post video
#
# tesla
#
# extra couple
#
# teslamotors
#
# teslas
#
# self-driving
#
# model
#
# @ elonmusk
#
# model
#
# according
#
# hyperloop
#
# tesla
#
# california
#
# calculated
#
# florida
#
# solar vote
#
# miami herald
#
# @ zebedee666
#
# dare
#
# tesla
#
# rain https
#
# @ electrekco @
#
# fortunemagazine
#
# teslamotors
#
# tesla
#
# panasonic
#
# buffalo
#
# york
#
# tesla
#
# needs
#
# @ markpinc @
#
# teslamotors
#
# reuters umm
#
# autobahn
#
# @ jeffmason1
#
# potus
#
# @ vicentes
#
# teslamotors
#
# model x
#
# rating
#
# carmagazine
#
# theeconomist
#
# early
#
# driverless cars
#
# @ 1843mag https
#
# t… @
#
# cocoanetics
#
# @ heiseonline
#
# objective
#
# data shows
#
# autopilot
#
# @ saufkopf87 @
#
# empirical
#
# sounds
#
# germany
#
# real
#
# climate science
#
# tesla
#
# dollar vs coal
#
# coal-mining ceo
#
# debates https
#
# walpoleboy6_rbx
#
# impact velocity
#
# big difference
#
# walpoleboy6_rbx
#
# @ elonmusk
#
# tesla model
#
# tiny dents
#
# @ roger_kappler
#
# tesla/solarcity
#
# corp debt
#
# tesla
#
# tesla/solarcity
#
# funcrandm
#
# speed
#
# miles https
#
# danmerriweather
#
# teslamotors
#
# vermont
#
# 's mountains
#
# insidewestworld
#
# talulahriley
#
# angela
#
# @ jimmisimpson
#
# william
#
# westworld
#
# pm et
#
# mars
#
# rare set
#
# target list
#
# color gold
#
# yostrobert
#
# various times
#
# twitter list
#
# @ mrdeanmiller
#
# linux os
#
# december
#
# sabotage
#
# great theories
#
# @ dougfeig
#
# @ elonmusk 's
#
# teslamotors
#
# tesla
#
# powerpacks
#
# africa
#
# singita_
#
# safari lodge
#
# sa…
#
# cardoso true
#
# @ motherboard
#
# news orgs
#
# insta
#
# space_station
#
# cameras
#
# space station
#
# dramatic views
#
# teslamotors
#
# keeping
#
# simple👌rt @
#
# jon4lakers
#
# car online
#
# future @
#
# teslamotors
#
# exactly
#
# america
#
# venturebeat
#
# tesla
#
# @ thekenyeung
#
# rorschach
#
# 's character
#
# worth
#
# future episodes
#
# westworld
#
# talulah
#
# great job
#
# westworldhbo
#
# live
#
# kerbal
#
# @ futuregames
#
# kerbalspacep
#
# badastronomer
#
# elon musk
#
# mars
#
# ’ s
#
# will
#
# reddit ama
#
# mars
#
# @ waitbutwhy
#
# full story
#
# spacex
#
# day https
#
# stevebatzer
#
# seems
#
# small number
#
# lett… https
#
# gooddaym am
#
# zero discounts
#
# gooddaym
#
# tesla
#
# equal pricing
#
# floor model
#
# bartusio
#
# cable elevator
#
# wind
#
# mars
#
# n't need
#
# @ inversedotcom
#
# @ elonmusk
#
# 'hitchhiker 's
#
# guide
#
# galaxy
#
# spacex
#
# ship name
#
# @ geekwire
#
# spacex
#
# ’ s
#
# elon musk
#
# 40-year plan
#
# mars
#
# @ verge
#
# elon musk
#
# transit system
#
# solar
#
# system https
#
# million humans
#
# live
#
# mars
#
# 2060s https
#
# natgeo
#
# spacex
#
# goal
#
# good article
#
# gizmodo
#
# waiting
#
# m stack height
#
# ~30 mins
#
# simulation
#
# spacex
#
# presenting
#
# learn
#
# meant
#
# flow separation
#
# earth
#
# id_aa_carmack
#
# spacex
#
# tomorrow
#
# elon musk
#
# iac2016
#
# davidkyoon
#
# mars
#
# will
#
# tues.
#
# merlin
#
# area ratio
#
# mach
#
# diamonds https
#
# spacex
#
# raptor
#
# forbes
#
# tesla/solarcity
#
# merger https
#
# hyperloop
#
# hyperloop
#
# aiming
#
# bay area
#
# tesla/solarcity
#
# solar roof
#
# powerwall
#
# tesla
#
# @ westcoastbill
#
# cantwait https
#
# @ ccyuan2013 @
#
# teslamotors
#
# @ tsrandall yes
#
# teslamotors
#
# tesla
#
# t…
#
# hot sun
#
# royarne83
#
# % state
#
# @ ninjas
#
# @ notch
#
# tesla
#
# @ massossltd
#
# cars @
#
# scott_helme
#
# ca n't
#
# detect babies
#
# v8.1
#
# always-on min
#
# max temps
#
# tesla
#
# full charge
#
# major overhaul
#
# v8.0
#
# release
#
# car configs
#
# favorite names
#
# @ thescalex @
#
# spacex
#
# iac2016
#
# youtube
#
# preview
#
# spacex
#
# iac2016
#
# jonaspolsky
#
# @ schellgames
#
# right name
#
# larrymasters778
#
# powered
#
# themikebartley
#
# version
#
# turns
#
# mars
#
# new name…
#
# p100d
#
# wo n't
#
# minute issues
#
# tesla p100d
#
# drag
#
# p100d glad
#
# battery size
#
# @ ycombinator
#
# @ sama
#
# @ elonmusk
#
# future https
#
# @ sama
#
# new @
#
# openai
#
# teslamotors
#
# los angeles
#
# world 's
#
# @ verge
#
# tesla
#
# 80mwh battery
#
# power https
#
# turns
#
# exxonmobil
#
# tesla model
#
# 50k miles
#
# audi a8
#
# comprehensive
#
# autolist
#
# tesla
#
# gasoline sedans
#
# scientists
#
# strain
#
# borowitzreport
#
# climate
#
# comic book form
#
# techcrunch
#
# tesla autopilot
#
# uses radar
#
# model
#
# s crash https
#
# teslamotors
#
# radar https
#
# will
#
# autopilot
#
# sorry
#
# unusually
#
# space news
#
# spacex
#
# @ spacex.com
#
# material
#
# @ abadcliche
#
# ca n't
#
# vehicle sensors
#
# will
#
# autopilot
#
# update blog
#
# @ ashwin7002 @
#
# nasa
#
# @ faa @
#
# afpaa
#
# lewischandlerdn
#
# particularly
#
# support
#
# nasa
#
# afpaa
#
# please
#
# @ spacex.com
#
# engines
#
# falcon
#
# turning
#
# complex failure
#
# @ waitbutwhy
#
# fast fire
#
# dragon
#
# loss
#
# falcon
#
# originated
#
# cause
#
# lockyep
#
# happy
#
# minor rev
#
# wide release
#
# writing
#
# will
#
# tesla
#
# major
#
# autopilot
#
# v8.0
#
# openai
#
# thanks
#
# spacex
#
# teslamotors
#
# tesla
#
# miles
#
# state road trip
#
# uber rides
#
# rentals
#
# stevesasman
#
# electrekco
#
# tesla model
#
# new ‘
#
# amazon vehicles
#
# ’ https
#
# kotaku
#
# favorite games
#
# kid @
#
# have
#
# deus ex
#
# @ business
#
# tesla
#
# lamborghini
#
# teslamotors
#
# model
#
# teslamotors
#
# ludicrous mode
#
# model
#
# model x
#
# journalist q
#
# embargo ends
#
# tesla
#
# california
#
# owner
#
# model x
#
# yukon
#
# badastronomer
#
# july
#
# ever
#
# @ sapinker
#
# steven pinker
#
# @ voxdotcom
#
# openai
#
# thrilled
#
# team members
#
# teslamotors
#
# mystery
#
# tesla
#
# correlation
#
# @ mayemusk
#
# @ elonmusk
#
# toscamusk
#
# 's twins
#
# happysunday
#
# bake cookies
#
# definitely
#
# spacex
#
# jcsat-16
#
# orbit https
#
# spacex
#
# weather
#
# falcon
#
# jcsat-16
#
# launch
#
# congrats
#
# talulahriley
#
# acts
#
# love
#
# characters –
#
# real people –
#
# fictional …
#
# hodderbooks
#
# delectable
#
# actsoflove
#
# 's @
#
# talulahriley
#
# spacex
#
# high-speed
#
# past launches
#
# reentries https
#
# openai
#
# openai
#
# starkickmg
#
# nomanssky
#
# will
#
# nomanssky
#
# https
#
# @ nvidia
#
# jensen
#
# dgx-1 ai
#
# openai
#
# @ verge
#
# yeah
#
# movie
#
# really
#
# joker+harley
#
# sure
#
# @ kytv
#
# tesla
#
# @ elonmusk
#
# branson
#
# man thanks
#
# t…
#
# jamesrossi100
#
# roadandtrack
#
# model
#
# model x
#
# dmc_ryan
#
# @ voguemaster @
#
# jalopnik
#
# good point @
#
# dmc_ryan
#
# @ voguemaster @
#
# jalopnik
#
# model y
#
# dragon
#
# space_station
#
# cupola https
#
# idea https
#
# teslamotors
#
# glad people
#
# great time
#
# @ voguemaster @
#
# jalopnik
#
# gigafactory
#
# hamster https
#
# jalopnik
#
# tesla minibus
#
# model x
#
# nasa
#
# spacex
#
# u.s.
#
# space_station
#
# launchamerica
#
# will
#
# gigafactory
#
# launch party
#
# @ engadget
#
# watch spacex
#
# test fire
#
# falcon
#
# reuters
#
# tesla
#
# top investor
#
# fidelity
#
# good summary
#
# gigafactory q
#
# yamada-san
#
# @ thedrive
#
# s https
#
# gigafactory
#
# clean energy
#
# @ westcoastbill
#
# happy birthday
#
# wired
#
# gigafactory
#
# teslamotors
#
# cnbc
#
# rare look
#
# tesla
#
# 's 'gigafactory
#
# @ solarimpulse
#
# breaking
#
# driverless cars
#
# letter
#
# scientific org
#
# congress
#
# world https
#
# id_aa_carmack
#
# @ vicentes
#
# alive https
#
# looking
#
# gigafactory
#
# scale blows
#
# autopilot
#
# serious injury
#
# owner anecdote
#
# vehicle logs
#
# @ danahull
#
# jerome
#
# tesla semi
#
# great job
#
# daimler
#
# @ danahull
#
# mramseywsj
#
# great game
#
# whole fallout
#
# @ katiefehren
#
# tesla
#
# master plan
#
# part deux
#
# @ elonmusk
#
# california
#
# time post
#
# tesla
#
# annadotblue
#
# large amounts
#
# small amounts
#
# lana finishing
#
# gatsby
#
# seems
#
# appropriate ...
#
# will
#
# tesla
#
# autopilot
#
# model
#
# @ drehmer
#
# canaveral
#
# california
#
# really
#
# upper stage
#
# falcon
#
# mars
#
# falcon
#
# landing
#
# paulprijs
#
# @ alexfrance
#
# babel
#
# working
#
# lz-1
#
# ready
#
# falcon
#
# lz-1
# canaveral
#
# spacex
#
# dragon
#
# space_station
#
# falcon
#
# way home https
#
# exactly
#
# tesla
#
# makes
#
# awesome
#
# meeting
#
# w design team
#
# tesla
#
# v smart
#
# behalf abt
#
# autopilot
#
# recent
#
# boschglobal
#
# moderate range
#
# = water density
#
# does
#
# n't need
#
# great rebuttal
#
# tesla
#
# autopilot
#
# zero input
#
# tyler_k_berg
#
# good point
#
# have
#
# 's @
#
# spacex
#
# will
#
# tesla
#
# bosch
#
# mobileye
#
# autopilot
#
# please
#
# tesla
#
# promising
#
# boschglobal
#
# radar sensor
#
# looks
#
# software update
#
# mikey67tang
#
# @ reddersla
#
# sensible
#
# autopilot
#
# guardian https
#
# spacex
#
# dragon
#
# space_station
#
# liftoff
#
# therealbuzz
#
# neil
#
# mike
#
# big rocket
#
# nasa
#
# live now
#
# find
#
# space_station
#
# spacex
#
# t.co… @
#
# forin2020
#
# kellybluejazz
#
# toy phone
#
# real @
#
# forin2020
#
# kellybluejazz
#
# large amounts
#
# kellybluejazz
#
# guid00
#
# good size
#
# ruthedick
#
# @ pfierens
#
# logs
#
# nhtsa
#
# ntsb
#
# identical
#
# good thing
#
# big advances w
#
# various points
#
# simplydonya
#
# danistopme
#
# dmc_ryan
#
# process crash
#
# working
#
# tesla
#
# w temporal
#
# dmc_ryan
#
# loud chime
#
# visual warning
#
# @ scojjac
#
# onboard
#
# vehicle logs
#
# autopilot
#
# pennsylvania
#
# autopilot
#
# thehackersnews
#
# @ defcon
#
# https
#
# n't mind
#
# customer safety
#
# right thing
#
# roadandtrack
#
# realdavebarton
#
# juddapatow
#
# siliconhbo
#
# fredericlambert
#
# mikejudge
#
# ca n't
#
# costume @
#
# realdavebarton
#
# @ kumailn @
#
# juddapatow
#
# siliconhbo
#
# fredericlambert
#
# tesla
#
# ca n't
#
# pied piper
#
# eddy_jahn
#
# great video
#
# progress
#
# spacex
#
# kinda
#
# creating
#
# tesla
#
# reason https
#
# swiftonsecurity
#
# software mods
#
# blog
#
# autopilot
#
# peterdiamandis
#
# swiftonsecurity
#
# ~11 deaths
#
# autopilot
#
# @ c4757p @
#
# wo n't
#
# fantaaiex
#
# tesla
#
# test fleet
#
# swiftonsecurity
#
# 1b miles
#
# @ nicatrontg @
#
# @ _craigr @
#
# fortunemagazine
#
# fortunemagazine
#
# n't criticism
#
# swiftonsecurity
#
# fortunemagazine
#
# reuters
#
# copied
#
# wrong link
#
# @ vicentes
#
# will
#
# autopilot
#
# @ stegen @
#
# fortunemagazine
#
# @ chirag
#
# beta software
#
# standard sense
#
# tesla
#
# autopilot
#
# system w
#
# 1b miles
#
# real world
#
# nikola tesla
#
# 's birthday
#
# working
#
# part
#
# hoping
#
# brooklynbrett
#
# leood3
#
# conleich
#
# allytaft
#
# love
#
# gandel
#
# wo n't
#
# funny comments
#
# koch
#
# model
#
# nhtsa
#
# https
#
# dougeatwell
#
# elon musk
#
# killer
#
# down
#
# climate
#
# youtube
#
# tripl…
#
# cnbc
#
# @ mrmeireles
#
# good point
#
# @ alansmurray
#
# jalopnik
#
# 's sense
#
# vanityfair
#
# tesla
#
# accident https
#
# eddy_jahn
#
# eddy_jahn
#
# google
#
# eddy_jahn
#
# @ jacobrossi
#
# tesla
#
# incl vehicles
#
# odd *not*
#
# tesla
#
# fortune
#
# autopilot
#
# sponsored
#
# gizmodo
#
# hyperloop
#
# helsinki
#
# stockholm
#
# 300-mile trip
#
# flamingos ...
#
# flamingo eggs
#
# exactly
#
# twitter
#
# @ samabuelsamid
#
# wrong
#
# autopilot
#
# @ alansmurray
#
# auto deaths
#
# 1m+/year deaths
#
# auto companies
#
# @ alansmurray
#
# n't material
#
# tsla
#
# @ nickbilton
#
# car accidents
#
# tesla
#
# radar
#
# overhead road
#
# favorite animal
#
# well
#
# thoughtful
#
# tesla/solarcity
#
# thanks
#
# @ vicentes cute
#
# china
#
# deluded
#
# journalistic
#
# week ...
#
# wired
#
# tesla
#
# energy company
#
# recode article
#
# williamshatner
#
# great @
#
# katelynbrock
#
# drive units
#
# curious abt
#
# tswlm
#
# sports sub car
#
# side project
#
# limited
#
# model
#
# s floats
#
# short periods
#
# thrust
#
# wheel rotation
#
# tesla
#
# looks
#
# engine shutdown
#
# deck https
#
# turns
#
# @ fucktyler
#
# gain access
#
# hardest impact
#
# droneship
#
# upgrades
#
# enable rocket
#
# astroorionmk
#
# badastronomer
#
# rapid ...
#
# looks
#
# ascent
#
# booster rocket
#
# spacex
#
# targeting
#
# eutelsat_sa
#
# 45-min window
#
# highly
#
# sean carroll
#
# @ seanmcarroll
#
# arguably
#
# @ seanmcarroll
#
# primitive
#
# highly
#
# europa
#
# hence
#
# @ rsmoz
#
# alien ...
#
# latest
#
# either
#
# aliens https
#
# benjaminrphoto
#
# safety issue
#
# nhtsa
#
# false location
#
# nhtsa
#
# safety concern
#
# model
#
# s suspension
#
# matter @
#
# deftechpat
#
# nice
#
# model
#
# topgear_bbca
#
# teslamotors
#
# salt https
#
# teslamotors
#
# price $ 58.5k
#
# federally
#
# $ 56k
#
# california
#
# adamhuet
#
# panasonic
#
# tesla
#
# panasonic
#
# model
#
# news articles
#
# fourth
#
# rocket arrives
#
# aiming
#
# sept/oct
#
# kotaku_uk
#
# elite
#
# super weapons
#
# skynet
#
# playoverwatch
#
# blizzard_ent pc
#
# highly
#
# playoverwatch
#
# good people
#
# blizzard_ent
#
# ultrafast team
#
# spacex
#
# june
#
# canaveral
#
# trippy
#
# recode
#
# douglas adams
#
# hhgttg
#
# exactly
#
# good article
#
# @ themotleyfool
#
# tesla
#
# swiftonsecurity
#
# creating
#
# neural lace
#
# machines @
#
# jedbrown5
#
# goetzman
#
# tom_stears
#
# tom_stears
#
# crazy things
#
# small number
#
# norway
#
# new sales
#
# fuel cars
#
# awesome country
#
# guys rock
#
# spacex
#
# plane https
#
# youtube
#
# recode
#
# @ karaswisher
#
# youtube
#
# supercharger
#
# latimes
#
# good balance
#
# good summary
#
# tesla
#
# annual meeting
#
# sorry
#
# will
#
# https
#
# fast
#
# 's rocket
#
# spacex
#
# ocisly
#
# @ dfjsteve
#
# crush core
#
# falcon
#
# soft landings
#
# crush
#
# easy
#
# falcon
#
# rocket
#
# design max
#
# prob
#
# satellite
#
# km apogee
#
# launch https
#
# spacex
#
# tiny glitch
#
# flight risk
#
# spacex
#
# weather
#
# droneship
#
# openai
#
# welcome
#
# really
#
# model x
#
# motortrend
#
# fuel sports car
#
# @ nicoleva
#
# schaffffff
#
# great image
#
# mars
#
# @ juanmtrejo
#
# guys
#
# teslamotors
#
# @ elonmusk
#
# spacex
#
# photographer
#
# falcon
#
# stage burn
#
# @ jlgolson
#
# @ jlgolson
#
# tesla
#
# $ 55/hr
#
# @ jlgolson
#
# merc
#
# tesla
#
# low cost labor
#
# $ 55/hr
#
# merc
#
# merc
#
# news story
#
# tesla
#
# $ 5/hr labor
#
# tesla
#
# $ 55/hr
#
# thurs
#
# fri.
#
# full height
#
# falcon
#
# ~165 ft
#
# falcon
#
# side boosters
#
# falcon
#
# center core
#
# usatoday
#
# global
#
# record temps
#
# getty
#
# mercury
#
# news article
#
# sounds
#
# wrong thing
#
# will
#
# @ bittdk
#
# @ joshuapinter
#
# totally
#
# recent rocket
#
# max damage
#
# will
#
# life leader
#
# ground tests
#
# snuggle thread
#
# comments
#
# excited
#
# tesla
#
# 's entry
#
# @ jdickerson
#
# seating
#
# tesla
#
# base
#
# teslamotors
#
# modelx
#
# teslamotors
#
# model
#
# kids ”
#
# michelle
#
# teslamotors
#
# cool
#
# view
#
# modelx
#
# stationcdrkelly
#
# thanks
#
# spacex
#
# earth
#
# clubteslaes
#
# teslamotors
#
# también te amo
#
# nashenas88
#
# teslamotors
#
# @ elonmusk
#
# fantastic
#
# fredericlambert
#
# ambien
#
# definitely ok
#
# full credit
#
# teslamotors
#
# earth
#
# tesla
#
# owners https
#
# earthday
#
# gizmodo
#
# climate
#
# teslamotors
#
# tim_stevens
#
# cnet
#
# teslamotors
#
# model x
#
# road @
#
# tim_stevens
#
# cnet
#
# good spirit
#
# lifeofrockstar
#
# @ lukealization
#
# merlin
#
# ~40 %
#
# merlin
#
# @ ryybuzz
#
# tesla
#
# help https
#
# launch
#
# jcsat-14
#
# earth
#
# @ hansmikael @
#
# yeah
#
# woohoo
#
# rocket
#
# spacex
#
# falcon
#
# jcsat-14
#
# ’ s 1:21am
#
# tesla
#
# production ramp
#
# model
#
# @ chamath
#
# hey jerkwater
#
# tsla…
#
# ” https
#
# teslamotors
#
# cool things
#
# model x
#
# @ edmunds https
#
# filtering
#
# measurable diff
#
# larry page
#
# bioweapon
#
# mode
#
# real https
#
# mactechgenius
#
# sacev have
#
# slowed
#
# mars
#
# sacev
#
# good stuff
#
# @ scottymeuk @
#
# dericlew
#
# spaceflightins
#
# cyberdinex
#
# falcon
#
# 5.1m lbf
#
# beast ...
#
# 1.71m lbf
#
# 1.9m lbf
#
# @ elonmusk
#
# f9 leo
#
# main page
#
# @ lukealization
#
# @ lukealization
#
# thrust increase
#
# @ elonmusk
#
# subtract
#
# @ mattyteare
#
# basically
#
# recent launches
#
# sigma reserve
#
# falcon
#
# @ westcoastbill
#
# hm https
#
# n't need
#
# mini_elon
#
# @ jbdeck
#
# tweetermeyer
#
# rokbottomgamers
#
# heat shields
#
# world 's
#
# @ gdoehne
#
# jcsat
#
# fast mission
#
# mrboylan
#
# system scan
#
# @ vigneshraju
#
# temporary
#
# row seat recall
#
# june
#
# ~5 %
#
# @ erothenberg
#
# simple
#
# teslas
#
# demand
#
# @ erothenberg
#
# spacex
#
# recently
#
# dragon
#
# ’ s
#
# superdraco
#
# mcgregor
#
# mars
#
# @ open_ai
#
# openai gym
#
# public beta
#
# @ romn8tr
#
# pica-3
#
# heat shield
#
# cardoso
#
# venus
#
# tough
#
# earth-moon
#
# internal
#
# volume ~size
#
# dragon
#
# solar system
#
# dragon mars
#
# test flight
#
# spacex
#
# dragon
#
# mars
#
# dragons
#
# mars
#
# electrekco
#
# automakers
#
# electric https
#
# @ physorg_com
#
# solar-powered
#
# plane
#
# kristiannairn
#
# motortrend
#
# have
#
# new
#
# exclusive look
#
# tesla
#
# model3
#
# @ hamids
#
# lots
#
# tesla model x
#
# amazing car
#
# review
#
# @ hamids
#
# teslamotors
#
# t.co/rf… @
#
# wager
#
# tesla
#
# looks
#
# model x
#
# resale value
#
# teslamotors
#
# model
#
# autoexpress
#
# @ dannysparker
#
# aiming
#
# realdarthbl
#
# sea https
#
# will
#
# hitler
#
# microsoft
#
# owner
#
# autopilot
#
# godot
#
# have
#
# absurdist humor
#
# waiting
#
# godot
#
# id_aa_carmack
#
# falcon
#
# kinematic
#
# spacex
#
# falcon
#
# port https
#
# activate
#
# autopilot 4x
#
# spacex
#
# 's awesome
#
# well
#
# spacex
#
# thehackersnews
#
# spacex thanks
#
# @ rjcc yes
#
# spacex
#
# 4k footage
#
# spacex
#
# onboard
#
# @ levie
#
# tickets
#
# orbital hotels
#
# mars
#
# tesla
#
# spacex
#
# solarcity
#
# thank
#
# potus thanks
#
# amazing team
#
# spacex
#
# jon_favreau
#
# spacex thanks
#
# nasa
#
# @ sgvcrime @
#
# spacex
#
# looking
#
# spacex
#
# 1st stage
#
# love
#
# spacex
#
# propellant
#
# load underway
#
# falcon
#
# launch
#
# minutes https
#
# screen
#
# stern cam
#
# love
#
# @ arstechnica
#
# reasons
#
# orbit
#
# nasa
#
# launch
#
# spacex
#
# dragon
#
# cargo ship
#
# space_station
#
# weather
#
# solarcity
#
# tesla
#
# fleet https
#
# nickel
#
# @ nonesuchzach
#
# battery
#
# earth
#
# main ingredient
#
# coat cutlery
#
# 325k cars
#
# ~ $ 14b
#
# alaska
#
# teslamotors
#
# ludicrous
#
# model
#
# p90d
#
# boeing
#
# qantas
#
# recode dex
#
# conversation w
#
# @ maximumblue
#
# sound right
#
# will
#
# mthorpxxi
#
# aperture
#
# space_station
#
# spacex
#
# dragon
#
# nasa
#
# april
#
# et/7:30p utc
#
# porsche
#
# turbo
#
# model x
#
# model x
#
# review @
#
# brianmrtz
#
# christiano92
#
# inspron
#
# jerry22499879
# wo n't
#
# opening width
#
# jerry22499879
#
# yes @ qa2198 @
#
# teslamotors
#
# yes @
#
# goesazedo
#
# signing
#
# twitter ama
#
# thanks
#
# cow bells
#
# @ lordsshrivas
#
# coming
#
# tesla
#
# software update
#
# gonzalobolio
#
# amarnathrevanna
#
# air suspension
#
# height @
#
# gatorwass
#
# will
#
# eduardoforneck
#
# peteehmkay
#
# @ gerardomarina
#
# @ tapwin
#
# europe
#
# regional demand
#
# fremont
#
# max capacity
#
# @ mpatfield
#
# problem @
#
# whole country
#
# andersrytter
#
# alexbelohlavek
#
# @ torvos torque
#
# rear motors
#
# ~.01 secs
#
# traction
#
# digital
#
# vs analog
#
# model
#
# dual motor
#
# great traction
#
# tesla
#
# golfshard
#
# yes @
#
# zooropa88
#
# service centers
#
# italy
#
# michaelsd01
#
# techgrltweeter
#
# alandbru
#
# teslamotors
#
# year @
#
# cmaxvs
#
# @ ikrivetko
#
# system @
#
# b_rans
#
# will
#
# child seats
#
# slim seats
#
# @ gerardomarina
#
# underway @
#
# hbl_cosmin wait
#
# michaelsd01
#
# reason
#
# initial cars
#
# early issues
#
# @ scottkelley99
#
# edge
#
# .1mm matters
#
# @ _amwolo_
#
# will
#
# road trips
#
# bvalvsracing
#
# model
#
# model
#
# tho total
#
# big difference
#
# ryancasburn
#
# loyalty
#
# begets loyalty
#
# snoozethroughf1
#
# rgspan
#
# matte
#
# waltnew
#
# @ mindthreat @
#
# ryanhummer
#
# model
#
# sat model
#
# @ grebakshay
#
# exact date
#
# tesla
#
# india
#
# model3owners
#
# @ vicentes
#
# ...
#
# review
#
# model
#
# bbc_topgear
#
# announcing
#
# tesla
#
# technology http
#
# snowed
#
# rushmore
#
# goparks
#
# http
#
# rocket
#
# mt rushmore
#
# sudden
#
# teslamotors
#
# consumer groups
#
# tesla
#
# flatefred
#
# badastronomer
#
# astronomers
#
# universe
#
# nuclear war
#
# missile arc
#
# christie
#
# 's action
#
# direct sales
#
# jersey
#
# working
#
# model
#
# bloomberg
#
# graphite story
#
# ridiculous ...
#
# @ jnags92
#
# tesla
#
# teamaizek
#
# japan
#
# clean way
#
# x4nwo well
#
# tesla
#
# teslamotors
#
# tesla
#
# vehicle
#
# hq tues
#
# state st.
#
# floor ea…
#
# jersey
#
# auto dealers
#
# tesla
#
# sales http
#
# interesting
#
# “ @ om
#
# physicist
#
# new type
#
# sxsw
#
# teslams60
#
# arrived
#
# hawthorne
#
# teslamotors
#
# models60
#
# yeah
#
# homeless kids
#
# rescue
#
# lockheed
#
# boeing
#
# model
#
# falcon
#
# mounting
#
# ~60 ft span
#
# falcon
#
# flight http
#
# @ wendelljopson
#
# hb2524
#
# sb6272
#
# capital
#
# hightechjoe
#
# tank
#
# amazing http
#
# welcome
#
# jade rabbit
#
# yutu
#
# auto
#
# ohio
#
# tesla v6
#
# software upload
#
# need
#
# lord business
#
# lego movie
#
# brilliant
#
# loved
#
# awesome ...
#
# theme song
#
# value
#
# tesla
#
# new |
#
# tesla la
#
# ny supercharger
#
# northern route
#
# heavy snow
#
# tesla
#
# us states
#
# map credit
#
# edmunds
#
# @ plugshare
#
# congratulations
#
# john
#
# jill
#
# free @
#
# tesla
#
# speed record
#
# departing fri
#
# will
#
# la-ny
#
# made
#
# lampoon
#
# vacation
#
# york
#
# coast +
#
# texas
#
# approx
#
# us population
#
# tesla
#
# + taxes
#
# world http
#
# teslamotors
#
# model
#
# theonion
#
# mattress
#
# king |
#
# horoscopes
#
# rough
#
# falcon
#
# thaicom
#
# flight http
#
# spacex
#
# photo
#
# liftoff
#
# spacex
#
# ’ s
#
# falcon
#
# thaicom
#
# spacex
#
# falcon
#
# thaicom
#
# thanks bill
#
# sure
#
# great start
#
# preparing
#
# thaicom
#
# florida
#
# time http
#
# @ olajahr @
#
# teslamotors
#
# teslamotors
#
# teslamotors
#
# nhtsa
#
# 5-star safety
#
# model
#
# america
#
# @ simonhackett
#
# huge amount
#
# solar power
#
# vertical http
#
# teslamotors
#
# learn
#
# model
#
# norway
#
# solarcity
#
# power
#
# foundation http
#
# @ bonnienorman
#
# santa
#
# texas
#
# tesla
#
# sock
#
# rest
#
# nelson mandela
#
# battery cells
#
# wh/kg
#
# model s.
#
# short term
#
# solar
#
# earth
#
# upper stage
#
# miles http
#
# spacex
#
# photo
#
# falcon
#
# ses-8
#
# spacex
#
# 's launch
#
# canaveral
#
# restart
#
# 80k km
#
# 50k miles
#
# reached
#
# upper stage
#
# live
#
# ses_satellites
#
# spacex
#
# @ toruonu
#
# ufrugger10
#
# will
#
# jon_favreau
#
# amazon
#
# tierrauniversu
#
# tierrauniversu
#
# 12v battery
#
# sound right
#
# investigating
#
# tesla model
#
# s fires
#
# concludes
#
# recall http
#
# will
#
# launch
#
# gas generator
#
# engines
#
# replaced
#
# gas generator
#
# abort
#
# ground side
#
# tea-teb
#
# upper
#
# rocket
#
# aiming
#
# eve launch
#
# depends
#
# manual abort
#
# bringing
#
# launch aborts
#
# helium spin
#
# % chance
#
# countdown
#
# launch
#
# thrust ramp
#
# seems
#
# cycling
#
# live
#
# liftoff http
#
# @ lomac92 @
#
# wired
#
# max chance
#
# model
#
# owner
#
# miles solo
#
# canada
#
# mexico
#
# wired
#
# honda
#
# yr house
#
# adammke model
#
# front trunk
#
# might
#
# honda
#
# fire risk
#
# spacex
#
# falcon
#
# launch window
#
# watch live
#
# happy
#
# spacegiving
#
# @ mgalimany
#
# teslamotors
#
# @ elonmusk
#
# ford
#
# escapes
#
# falcon
#
# want
#
# thurs
#
# spacex
#
# falcon
#
# ses-8
#
# ses_satellites
#
# spacex geo
#
# disney
#
# world w kids
#
# good flight
#
# mountain
#
# launch
#
# cape causeways
#
# local time
#
# darksapiens
#
# done
#
# will
#
# requires
#
# coast +
#
# km altitude
#
# ~1/4 way
#
# headed
#
# canaveral
#
# spacex
#
# tesla model
#
# tesla
#
# model
#
# s warranty
#
# fire damage
#
# driver accident
#
# model
#
# safety record
#
# tesla
#
# fire w
#
# media headlines
#
# gas car fires
#
# tesla
#
# superdraco
#
# rocket engine
#
# full thrust w
#
# inconel
#
# used
#
# dragon
#
# george clooney
#
# model
#
# s owner blogs
#
# accident http
#
# thanks woz
#
# @ stevewoz
#
# new car
#
# teslamotors
#
# tesla
#
# west coast
#
# supercharger
#
# travel
#
# vancouver
#
# tijuana
#
# giant
#
# dog topiary
#
# bilbao
#
# rocket
#
# model
#
# s fire http
#
# debbieviviers
#
# spacex
#
# upper stage
#
# liquid oxygen
#
# white sphere
#
# grasshopper
#
# rocket
#
# booster relit
#
# aero torque
#
# launch
#
# looks
#
# launch attempt
#
# upper
#
# water ice
#
# mars
#
# id_aa_carmack
#
# @ elonmusk @
#
# badastronomer
#
# ipcc
#
# sensible
#
# badastronomer
#
# falcon
#
# launch window
#
# good weather
#
# vandenberg
#
# air force
#
# base
#
# good progress
#
# sky http
#
# hyperloop
#
# ansys
#
# completed
#
# systems green
#
# launch
#
# days http
#
# falcon
#
# sunset http
#
# mile range
#
# electric car
#
# right
#
# hope
#
# approach
#
# deg flush
#
# engineers
#
# team
#
# intense
#
# effort underway
#
# tesla
#
# model
#
# will
#
# static fire
#
# icbms
#
# probable launch
#
# sept
#
# full thrust
#
# sec static fire
#
# launch date tbd
#
# upcoming falcon
#
# new technology
#
# falcon
#
# rockets rolls
#
# vandenberg
#
# air force
#
# base
#
# wired
#
# japan
#
# california
#
# high speed rail
#
# mph w avg speed
#
# japan
#
# wired
#
# japan
#
# ’ s
#
# l-zero
#
# maglev train
#
# pretty awesome
#
# video
#
# model
#
# autocar
#
# designing
#
# vandenberg
#
# rocket launch
#
# tense days
#
# jon_favreau yup
#
# good idea
#
# will
#
# post video
#
# rocket part
#
# hand gestures
#
# @ brynmooser
#
# reality
#
# model
#
# us govt http
#
# rocket flight
#
# latest
#
# rapid descent
#
# will
#
# hyperloop alpha
#
# pulled
#
# hyperloop
#
# will
#
# publish link
#
# hangout
#
# california
#
# time http
#
# 1-planet graves
#
# economic http
#
# europe
#
# cinderella
#
# norway
#
# teslamotors
#
# model
#
# london
#
# designmuseum
#
# “ @ temochdez
#
# mexico
#
# fear
#
# uberobvi
#
# @ physorg_com
#
# valley networks
#
# mars
#
# brownuniversity
#
# tesla
#
# tesla
#
# john_gardi
#
# 2m @ schadlu
#
# will
#
# hyperloop
#
# open source
#
# tobiasvdb
#
# air brakes
#
# landing
#
# vehicle mass
#
# will
#
# hyperloop
#
# alpha design
#
# critical
#
# @ elonmusk http
#
# falcon
#
# tough issues
#
# leilanimunter
#
# dear
#
# http
#
# teslamotors
#
# @ elonmusk @
#
# teslamotorsclub
#
# briandunning
#
# spacex
#
# new spacesuit
#
# hoping
#
# bittorrent
#
# everyone
#
# sip. ”
#
# ’ d
#
# beer. ”
#
# barman
#
# ’ d
#
# ” “
#
# ’ d
#
# beer. ”
#
# @ physorg_com
#
# glass
#
# latest
#
# rocket vid
#
# 325m altitude
#
# land w
#
# loop http
#
# woohoo
#
# tesla
#
# 100k threshold
#
# thanks
#
# have
#
# henry fielding
#
# hercules
#
# day “ @
#
# uberfacts
#
# buttload
#
# thanks
#
# @ lougil_ace
#
# will
#
# ext warranty
#
# john_gardi
#
# @ elonmusk
#
# please
#
# direct sales
#
# states http
#
# @ arthurblake
#
# turning
#
# right film
#
# rear glass
#
# hvac
#
# @ arthurblake
#
# tesla
#
# auto glass
#
# @ arthurblake
#
# turn
#
# cool air
#
# rear vents
#
# rear glass
#
# @ justinchace
#
# lisaroutel
#
# auto dealers
#
# tesla
#
# teslamotors
#
# tesla
#
# vid http
#
# tomorrow
#
# gas pump
#
# tesla
#
# partial
#
# model
#
# s http
#
# battery
#
# tesla model
#
# s cars
#
# @ zatulsky
#
# shai
#
# tesla
#
# video
#
# tesla
#
# live
#
# thurs
#
# california
#
# design studio
#
# hawthorne
#
# seeing
#
# battery
#
# solar power
#
# night operation
#
# buffer grid
#
# beta
#
# long way
#
# long duration
#
# new generation
#
# falcon
#
# rocket ~1.5
#
# vac thrust http
#
# true
#
# gwynne
#
# ur qtr
#
# mars
#
# market cares
#
# sqminc
#
# near term plans
#
# spacex
#
# mars
#
# transporter
#
# forgot
#
# tesla
#
# love
#
# dragon
#
# space station
#
# dark side
#
# earth
#
# tons means avg
#
# story building
#
# @ williamricci6
#
# will
#
# falcon
#
# 1m lbs thrust
#
# skyscraper http
#
# huge
#
# will
#
# year http
#
# bloomberg
#
# andreasjames
#
# nose http
#
# robertgaristo v
#
# feedback loops
#
# robertgaristo
#
# @ elonmusk
#
# kindergartners
#
# tesla model
#
# houston
#
# chronicle http
#
# thank
#
# smoking
#
# worth
#
# merchants
#
# doubt
#
# deaths r
#
# yeah
#
# centrist issue
#
# right
#
# dyson
#
# human actions
#
# *any* subject
#
# @ kn0xvi11ain
#
# scientific
#
# columbus
#
# round http
#
# sorry
#
# world wd
#
# exactly
# climate
#
# lung cancer
#
# good article
#
# climate
#
# global warming
#
# forresttanaka
#
# uberfacts
#
# iron
#
# man edition
#
# potato head
#
# tony starch
#
# harder
#
# @ 1sthubblefan
#
# garydownie
#
# @ elonmusk
#
# wrong
#
# climatechange
#
# sealevelrise
#
# minor operation
#
# sign
#
# good design
#
# pickup truck
#
# w ultra
#
# sports car
#
# mega torque
#
# technically
#
# zip2
#
# paypal
#
# w zero govt
#
# spacex
#
# tesla
#
# solarcity
#
# basic foods
#
# critical meds
#
# @ ponder68
#
# carbon
#
# spacex
#
# rocket flight
#
# gas savings
#
# tesla
#
# $ 600/month
#
# tax credits
#
# market
#
# trees
#
# net consumers
#
# exactly
#
# seems
#
# big difference
#
# ie consumption
#
# maxmberger
#
# private money
#
# tesla
#
# ipo+
#
# govt money
#
# carbon tax
#
# @ grayj_
#
# tax code
#
# weight
#
# taxes
#
# n't ban
#
# increase cost
#
# extreme cases
#
# exactly
#
# bad thing
#
# simple taxes
#
# incent good
#
# great article
#
# tesla-dealer
#
# leilani munter
#
# carbonfreegirl
#
# varung_ belief
#
# carbon tax
#
# @ karlbrauer
#
# making
#
# zillion tweets
#
# makes
#
# tweet history
#
# sapientcapital
#
# electric cars
#
# easy money
#
# earth
#
# wrong http
#
# chrysler
#
# $ 1.3b
#
# 1st http
#
# chrysler
#
# fiat
#
# italian company
#
# *us* company
#
# interview
#
# bloombergnews
#
# tesla
#
# details http
#
# tesla
#
# us car company
#
# govt http
#
# @ yes_andre
#
# big fan
#
# stanford
#
# spacex
#
# watch
#
# spacex
#
# world ’ s
#
# nasaglenn
#
# mcbartvolgers
#
# spacex
#
# @ xyrth
#
# cool
#
# talulahriley
#
# destiny xx
#
# petting
#
# pet chicken
#
# danabrunetti
#
# model
#
# druidic dwarves
#
# supercharger
#
# broad range
#
# worth
#
# model
#
# @ malkosh
#
# harder
#
# @ slate
#
# @ thehighsign
#
# sendup
#
# dan brown
#
# dan brown
#
# dan brown
#
# vast majority
#
# solarcity
#
# lyndon
#
# peter rive
#
# awesome team
#
# small part
#
# seanchin
#
# raimisj
#
# air upgrade
#
# improving
#
# short term
#
# free right
#
# text people
#
# @ enggirl
#
# macallan
#
# good job
#
# requires
#
# extreme burn
#
# raimisj tesla
#
# software knits
#
# google voice
#
# slacker
#
# gracenote
#
# cory johnson
#
# sure behaves
#
# cheese
#
# spam
#
# fish license
#
# monty python
#
# hold
#
# voice button
#
# amish
#
# model
#
# internet
#
# @ realbhuwan
#
# part
#
# tesla model
#
# gas tank
#
# crcars
#
# tesla model
#
# top test score
#
# road test
#
# tesla
#
# roadsters
#
# @ mjasandoval
#
# tesla
#
# dark night
#
# @ westcoastbill
#
# thanks bill
#
# larry
#
# sergey
#
# google
#
# cars comments
#
# bloomberg
#
# tesla
#
# model
#
# model x
#
# mass market
#
# gen vehicle
#
# @ rebel_sal
#
# creating
#
# tesla
#
# top priority
#
# direct request
#
# tesla
#
# chris porritt
#
# aston martin
#
# tesla
#
# @ bdcs
#
# moon
#
# back yard
#
# mars
#
# @ nirdthebird
#
# definitely
#
# douglasbullard
#
# @ teslamotors
#
# nikola tesla
#
# @ fink_justin
#
# supercharger
#
# teslatrip
#
# teslamotors
#
# carolina
#
# tesla
#
# teslanc
#
# @ thebradholt
#
# world 's
#
# resale value
#
# took
#
# long time
#
# supercharger
#
# aiming
#
# @ stoneymonster
#
# indirect floor
#
# resale value
#
# tesla
#
# model
#
# s resale value
#
# side
#
# boosters fall
#
# center core
#
# florida
#
# landing
#
# @ pataneous
#
# ca n't
#
# @ 2552nsf
#
# yeah
#
# super tricky
#
# will
#
# ocean platform
#
# @ rebel_sal
#
# alan_nestos
#
# @ darma_setia
#
# frozen wastes
#
# hell
#
# clarkson
#
# jsonberland
#
# impact energy
#
# extremely
#
# bigballi
#
# needs
#
# ~60 ft span
#
# model s.
#
# f-niner
#
# piston w
#
# tesla
#
# nasa
#
# 's role
#
# cool
#
# @ rebel_sal
#
# good piece
#
# realtomlangel
#
# long time
#
# paying
#
# good ways
#
# @ wfww
#
# right song
#
# slacker
#
# supposed
#
# interesting
#
# @ sciam
#
# arduous quest
#
# find flowing
#
# mars may be
#
# auto
#
# sterling mccall
#
# tesla
#
# direct sales
#
# texas
#
# congrats
#
# virgingalactic
#
# richardbranson
#
# falcon
#
# ignition system
#
# fire http
#
# teslamotors
#
# creating
#
# world ’ s
#
# @ tcmeggs
#
# @ tcmeggs
#
# infinite size
#
# n't traffic
#
# nycomwireless
#
# tapp697 thanks
#
# tesla
#
# market
#
# announcement
#
# new @
#
# teslamotors
#
# tesla
#
# @ wheelseditor
#
# cool
#
# seems
#
# stormy weather
#
# shortville
#
# days @
#
# rocketrichardp
#
# @ ct_la
#
# exactly
#
# dmv comm
#
# hearing
#
# trekker56
#
# virginia
#
# good news
#
# virginia dmv
#
# tesla
#
# dealer license
#
# hearing
#
# in_sight_full
#
# @ juliewestfall
#
# great neighbors
#
# themilns try
#
# wringing
#
# zero g
#
# way trippy http
#
# good idea
#
# grasshopper
#
# rocket flies
#
# hexacopter http
#
# @ dbhyslop
#
# will
#
# grasshopper
#
# new hexacopter
#
# actual picture
#
# cool
#
# jupiter
#
# @ shervin
#
# congratulations
#
# orbitalsciences
#
# “ @
#
# cnetnews
#
# orbital
#
# antares
#
# afhdisasterteam
#
# will
#
# heart
#
# texas
#
# spacex tx
#
# whitehouse
#
# direct sales
#
# please
#
# texas
#
# tesla
#
# myabj
#
# opinion poll
#
# interesting
#
# putin
#
# russian
#
# @ physorg_com
#
# @ batasrki
#
# supercharger
#
# definitely
#
# hearing
#
# dealer lobby
#
# york
#
# judge states
#
# dealers
#
# franchised
#
# dealer act
#
# exactly
#
# york
#
# tesla
#
# legal attack
#
# auto dealers
#
# direct sales
#
# @ latimes
#
# tesla motors
#
# @ twittelator
#
# austin
#
# will
#
# press conf
#
# launch site
#
# texas bbq
#
# tesla
#
# tesla
#
# capitol room
#
# e2.014
#
# gun control ...
#
# 've shot
#
# taniapalme
#
# right thing
#
# cool points
#
# reagan
#
# obama
#
# clinton
#
# good people
#
# sides ...
#
# @ ticeestes
#
# cool points
#
# early years
#
# britain
#
# english nana
#
# @ ryanjoyce88
#
# n't suck
#
# @ quietlybear
#
# intro courses
#
# tesla
#
# assembly line
#
# sarah palin
#
# tesla
#
# model
#
# s warranty
#
# teslamotors
#
# techcrunch
#
# hoping
#
# century city
#
# tesla
#
# teslamotors
#
# introducing
#
# world 's
#
# world 's
#
# bjartereve
#
# europe
#
# downtownprojlv
#
# startup buys
#
# teslas
#
# aims
#
# techcocktail
#
# bjartereve july
#
# tesla
#
# please
#
# @ 8am
#
# teslatx
#
# teslamotors
#
# texas
#
# auto dealers
#
# tesla
#
# senate hearing
#
# tesla
#
# spacex
#
# hhgttg
#
# tesla
#
# part trilogy
#
# douglas adams
#
# @ edmunds
#
# exclusive
#
# teslamotors
#
# nascar
#
# elonmusk
#
# electric sedan
#
# good ol
#
# @ stopman
#
# thanks michael
#
# @ jeremys
#
# thanks jeremy
#
# awesome
#
# yelp
#
# tesla
#
# california
#
# april fool
#
# tues
#
# tesla
#
# hard work
#
# team http
#
# candy
#
# happy easter
#
# thanks bob
#
# “ @
#
# bobmetcalfe
#
# tesla takes
#
# repeal
#
# sorry
#
# tesla
#
# texas
#
# state senate
#
# house member
#
# free
#
# auto
#
# texas
#
# tesla
#
# right http
#
# rocket
#
# deployment test
#
# vacuum chamber
#
# scale http
#
# “ @
#
# ernex
#
# @ davidharvey
#
# @ elonmusk
#
# a123
#
# b456
#
# teslamotors
#
# chick magnet
#
# dragon
#
# powering
#
# cargo
#
# telemetry
#
# main parachutes
#
# recovery ship
#
# sonic booms
#
# dragon
#
# dragon
#
# deorbit burn
#
# backup power
#
# slight
#
# tues
#
# really
#
# exciting @
#
# teslamotors
#
# v major way
#
# 's batsh*t
#
# korea
#
# crazy http
#
# michaellindahl
#
# think audi a4
#
# model
#
# deanjfalkenberg
#
# yep @
#
# nezheim
#
# @ jbmeicher
#
# @ jbmeicher
#
# model
#
# highest
#
# norway
#
# canada
#
# $ 25k
#
# v sweet
#
# @ benmacy $ 30k
#
# ie + inflation
#
# cool tech
#
# ca n't talk
#
# @ joshj777
#
# electric car
#
# @ malkosh
#
# test drive car
#
# review
#
# tesla model
#
# roadandtrack
#
# good article w
#
# minor errors
#
# shoemaker-levy
#
# jupiter
#
# earth
#
# size hole
#
# earth
#
# rock 'was
#
# tedchris
#
# anthropic yeah
#
# plum
#
# brook space
#
# power facility
#
# nasa glenn
#
# research center
#
# glenn
#
# testing
#
# city bus
#
# world 's
#
# sharing
#
# rainnwilson
#
# jbsiegelmd cool
#
# craig venter
#
# flu vaccines
#
# tesla model
#
# sxsw
#
# @ shervin
#
# @ travisk http
#
# johnny cash
#
# hover slam
#
# will
#
# johnny cash
#
# test
#
# sxsw rt
#
# nice
#
# tesla
#
# govt loans
#
# model
#
# tesla austin
#
# domain
#
# @ sdvillella
#
# nice pic
#
# rebeccajarvis
#
# random trivia
#
# minnesota
#
# minnesota
#
# auto dealers
#
# tesla
#
# bill
#
# thanks mn
#
# asherlaw spacex
#
# launch ops
#
# canaveral
#
# need
#
# flight rate
#
# weather risk
#
# arrived austin
#
# orbital launch
#
# brownsville
#
# sxsw
#
# @ navidob
#
# ibsen
#
# stalin
#
# norwegian
#
# solzhenitsyn
#
# oslo
#
# norwegian
#
# teslamotors
#
# highest model
#
# s orders
#
# nasakennedy
#
# spacex dragon
#
# harmony module
#
# spacex
#
# dragon
#
# nasa
#
# updated
#
# spacex
#
# dragon
#
# nasa
#
# tv coverage
#
# grapple
#
# dragon
#
# nasa
#
# will
#
# space station
#
# pacific time
#
# usairforce
#
# dragon
#
# free drift
#
# nasa
#
# world 's
#
# looking
#
# orbit
#
# dragon
#
# thruster
#
# preparing
#
# systems green
#
# pods
#
# dragon
#
# free drift
#
# active control
#
# attempting
#
# thruster pods
#
# solar
#
# thruster
#
# tank pressure
#
# preparing
#
# australia
#
# ground station
#
# holding
#
# thruster pods
#
# dragon
#
# thruster pods
#
# falcon
#
# dragon
#
# target orbit
#
# @ willsamari
#
# @ elonmusk
#
# launch mission
#
# computer
#
# spacex
#
# n't replicate
#
# launch
#
# launch
#
# canaveral
#
# edmunds_test
#
# head home
#
# wo n't plug
#
# return trip
#
# side trips ...
#
# exactly
#
# mkt behavior
#
# @ _chrissimmons
#
# carbon tax
#
# us carbon tax
#
# china
#
# well
#
# @ johnvoelcker
#
# happy owner
#
# tesla model
#
# sport sedan
#
# delivery
#
# rocket
#
# static fire @
#
# spacex
#
# canaveral
#
# engines
#
# faeloba
#
# ericidle cool
#
# 1st flight
#
# dragon
#
# large wheel
#
# nasa
#
# want
#
# spacex
#
# march
#
# t.co ...
#
# @ lenfeldman
#
# nytjamescobb
#
# @ elonmusk
#
# @ jbrodernyt
#
# consummate pro
#
# fa ...
#
# thanks
#
# cnbc
#
# “ @
#
# lebeaucarnews
#
# model
#
# @ elonmusk
#
# electric. ”
#
# appreciate
#
# thoughtful @
#
# sulliview
#
# faith
#
# @ nytimes
#
# yaeltabouhalkah
#
# interesting
#
# @ nytimes
#
# tesla
#
# sulliview
#
# thorny problem
#
# / ...
#
# teslaroadtrip
#
# teslaroadtrip
#
# lawrencechanin
#
# teslaroadtrip
#
# @ avantgame @
#
# tedchris
#
# revolutions
#
# teslaroadtrip
#
# @ elonmusk
#
# elon
#
# coasters
#
# weekend ...
#
# teslaroadtrip
#
# @ kjkuske
#
# @ elonmusk
#
# have
#
# love
#
# genius
#
# “ @ cdabel114
#
# cnn well
#
# car ”
#
# benioff
#
# abigailbassett
#
# teslamotors
#
# peterdrives
#
# t.co ...
#
# peterdrives
#
# boston
#
# game
#
# abigailbassett
#
# teslamotors
#
# peterdrives
#
# been
#
# miles ht ...
#
# east coast
#
# supercharger
#
# test drive
#
# s w @
#
# peterdrives
#
# model
#
# pure ice
#
# snow http
#
# thomsen_lars
#
# @ elonmusk
#
# model
#
# boston
#
# a_c_r
#
# @ elonmusk
#
# nytimes
#
# knappontech
#
# @ elonmusk
#
# wondered
#
# nytimes
#
# 400+ mile 1day
#
# full speed
#
# w heat/ac w ...
#
# free east coast
#
# superchargers
#
# will
#
# initial charge
#
# long detours
#
# nytimes
#
# @ batasrki
#
# yeah
#
# top gear
#
# tesla roadster
#
# logs
#
# miles range
#
# @ tomleykis
#
# thanks tom
#
# support
#
# tesla
#
# tesla
#
# top gear bs
#
# tesla
#
# broder
#
# nytimes
#
# range test
#
# nytimes
#
# tesla
#
# vehicle
#
# true story
#
# long detour
#
# busted
#
# “ @
#
# theonion
#
# barack obama
#
# going
#
# grasshopper
#
# rocket test
#
# yeah baby
#
# might
#
# crater ...
#
# spacex
#
# reddit
#
# tesla model
#
# superchargers
#
# “ @
#
# autobloggreen
#
# 'dead end
#
# reuters
#
# great spirit
#
# superdome
#
# awesome
#
# sb47
#
# boeing
#
# desire
#
# boeing
#
# corresponding w
#
# chief engineer
#
# junod
#
# esquire
#
# tesla
#
# spacex
#
# rocket http
#
# mars colony
#
# mars
#
# nice
#
# model
#
# s coast
#
# coast road trip
#
# superchargers
#
# mars
#
# death
#
# world 's
#
# place http
#
# death
#
# tesla
#
# hot weather
#
# model
#
# gas tow truck
#
# @ gigaom
#
# tesla
#
# ’ s solar
#
# super chargers
#
# coast http
#
# t.co/o9gahtbg @

# %% [markdown]
# # Search for a Random Phrase Using phrases.txt

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)

#url = u'https://twitter.com/search?q='
#HashTag = (random_line('hashtag-nouns.txt'))
HashTag = (random_line('phrases.txt'))
url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list
# Out:
# It's been 13 years since Lost premiered, so here's a thread down memory lane highlighting what made this show so special. #Lost #13years
#
# On September 22, 2004 Oceanic flight 815......
#
# #LOST Premiered 13 years ago today! pic.twitter.com/Xkm9zu3LaM
#
# Episode 2? Didn't it premiere tonight? #lost
#
# 13 years ago today, #LOST premiered. Do yourself a favor and go back to the island with @LookingBackLost
#
# I just realized the significance of having finished #Lost yesterday. It premiered 13 years ago yesterday.
#
# 13 years since #LOST premiered. Changed the landscape of TV dramas. Virtually saved ABC.
#
# Also, happy 13 year anniversary to the premiere of one of the greatest shows ever aired #LOST
#
# #lost premiered 13 years today and tonight I met David Lynch. Coincidence?! Probably.
#
# Happy 13th anniversary of the premiere of #LOST boys @shreds_42 @T_Cagz @RealMikePrijic @Kam_merinhttps://www.youtube.com/watch?v=mX7md0HoR8E ignore
#
# This is the day #LOST premiered. Still the best fandom Iignoreve ever been a part of. Fitting for a show about love.
#
# 13 years ago today @ABC #Lost premiered on cable television and changed the world forever. Thanks again @DamonLindeIof @bad_robot
#
# The CGL charity auction for @TheLOSTCon is Locke'd & loaded - we had to go pack! Happy #LOST Premiere Anniversary, you all everybody!
# -Jo pic.twitter.com/H7YrYGIK5v
#
# 13 years ago today the first ever episode of #LOST premiered. I remember watching it, even though I was only nine at the time.
#
# #LOST premiered 13 years ago today. pic.twitter.com/JvDX5718xK
#
# Just re-watched the pilot episode of #Lost. It is still the greatest, the most breathtaking series premiere in history. #FlashbackFridaypic.twitter.com/ypA1HhVt9D
#
# in honor of the 13th anniversary of the premiere of #lost here is my way-too-revealing essay about its creation - http://okbjgm.weebly.com/uploads/3/1/5/0/31506003/lost_will_final.pdf ignore
#
# @SpencerKarter Do u know today marks the 13th anniversary of the premiere of #LOST on @ABCNetwork?pic.twitter.com/yRkl6Cse9d
#
# My beloved shows premiered today - 23, 13, and 6 years ago respectively.
# @FriendsTV #Friends
# #Lost
# #PersonOfInterestpic.twitter.com/AIyDxNGldy
#
# Today was the day. 13 years ago, #LOST premiered. #LiveTogetherDieAlone
# 4 8 15 16 23 42
# #WeHaveToGoBack
# Ugh, thinking of show has me like..pic.twitter.com/9SlwkfE4Qp
#
# Saw it was 13 years ago today #Lost premiered. Great series. #Wehavetogobackpic.twitter.com/QmCzLHNaOd

# %% [markdown]
# # Search Twitter Using Prevous HashTags

# %%
from bs4 import BeautifulSoup
import requests
import sqlite3
import base64
import time
import random
def random_line(fname):
    lines = open(fname).read().splitlines()
    return random.choice(lines)

#url = u'https://twitter.com/search?q='
#HashTag = (random_line('hashtag-nouns.txt'))
HashTag = (random_line('nodupsnohash.txt'))
url = u'https://twitter.com/hashtag/'+ HashTag +'?lang=en'
tweetfile = 'hashtag.txt'
#url = u'https://twitter.com/scavino45/lists/florida-hurricane-irma'
#url = u'https://twitter.com/Selebog55680943'
#url = u'https://twitter.com/WinMansfield'
#query = u'%40drawranliou'
#query = u'%23hurricanne&src=typd'
#query = u'python, florida'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

tweets = [p.text for p in soup.findAll('p', class_='tweet-text')]
txt = (tweets)
for list in txt:
    filein = open(tweetfile, 'a')
    list = list.replace(u'\xa0', u' ')
    list = list.replace(u'\u2026','ignore')
    list = list.replace(u'\xa0','ignore')
    list = list.replace(u'\u2013', u' ')
    list = list.replace(u'\xf1', u' ')
    list = list.replace(u'\u2019','ignore')
    list = '\n'+ u''.join((list)).encode('utf-8').strip()
   
    filein.write(list)
    filein.close()
    time.sleep(1)
    print list

# %% [markdown]
# # Create a file of hashtags only from Twitter Ouput hashtag.txt

# %%
def findhash():
    with open('hashtag.txt', 'r') as textin:
        tempstore = set()
        with open('hashonly.txt', 'w') as outfile:
            for line in textin.readlines():
                hashed = [ word for word in line.split() if word.startswith("#") ]
                #hashed = word for word in line.split() if word.startswith("#")
                hashed = str(hashed)
                hashed = hashed.replace("[","");hashed = hashed.replace("]","")
                hashed = hashed.replace(",","\n");hashed = hashed.replace(" '","")
                hashed = hashed.replace("'","");hashed = hashed.replace("#\n ","")
                hashed = hashed.replace("#","\n#")
                outfile.write(hashed)


findhash()

# %% [markdown]
# # Remove Blank Lines

# %%
def removeblank():
    with open('hashonly.txt') as infile, open('hashonlyNoBlank.txt', 'w') as outfile:
        for line in infile:
            if not line.strip(): continue  # skip the empty line
            outfile.write(line)  # non-empty
            
removeblank()

# %% [markdown]
# # Remove Duplicates

# %%
def remove_duplicates(infile):
    tempstore = set()
    with open('hashonlyNoBlankNoDups.txt', 'w+') as out:
        for line in open(infile):
            if line not in tempstore:
                if len(line) < 16 and len(line) >4:
                    out.write(line)
                    tempstore.add(line)

remove_duplicates('hashonlyNoBlank.txt')

# %% [markdown]
# # Remove HashTags

# %%
def removeHash(infile):
    with open('clean.txt', 'w+') as out:
        for line in open(infile):
            line = line.replace("#","")
            out.write(line)

removeHash('hashonlyNoBlankNoDups.txt')

# %% [markdown]
# # All In One File Twittertext to plain HashTags

# %%
def findhash():
    with open('hashtag.txt', 'r') as textin:
        tempstore = set()
        with open('hashonly.txt', 'w') as outfile:
            for line in textin.readlines():
                hashed = [ word for word in line.split() if word.startswith("#") ]
                #hashed = word for word in line.split() if word.startswith("#")
                hashed = str(hashed)
                hashed = hashed.replace("[","");hashed = hashed.replace("]","")
                hashed = hashed.replace(",","\n");hashed = hashed.replace(" '","")
                hashed = hashed.replace("'","");hashed = hashed.replace("#\n ","")
                hashed = hashed.replace("#","\n#")
                outfile.write(hashed)


findhash()

def removeblank():
    with open('hashonly.txt') as infile, open('hashonlyNoBlank.txt', 'w') as outfile:
        for line in infile:
            if not line.strip(): continue  # skip the empty line
            outfile.write(line)  # non-empty
            
removeblank() 

def remove_duplicates(infile):
    tempstore = set()
    with open('hashonlyNoBlankNoDups.txt', 'w+') as out:
        for line in open(infile):
            if line not in tempstore:
                if len(line) < 16 and len(line) >4:
                    out.write(line)
                    tempstore.add(line)

remove_duplicates('hashonlyNoBlank.txt')

def removeHash(infile):
    with open('clean2.txt', 'w+') as out:
        for line in open(infile):
            line = line.replace("#","");line = line.replace('"','')
            out.write(line)

removeHash('hashonlyNoBlankNoDups.txt')

# %% [markdown]
# # ----------------  All Good Above ----------------------------------

# %%
import glob
for file in glob.glob('/home/jack/Desktop/Snippet_Warehouse/*.ipynb'):
    print 'DEBUG: file=>{0}<'.format(file)
    with open(file) as f:
        contents = f.read()
    if 'nluug' in contents:
        print file
# Out:
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Bible-in-PHP-with-MySQL.ipynb<
# /home/jack/Desktop/Snippet_Warehouse/Bible-in-PHP-with-MySQL.ipynb
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Working_with_Tweets_and_Text_Results.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/NewNotebook.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Using_quandl.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/NewNotebook1.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/FTP_and_Editor.ipynb<
# /home/jack/Desktop/Snippet_Warehouse/FTP_and_Editor.ipynb
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Snippet_Warehouse-MySQL-SQLite-code-storage-search.ipynb<
# DEBUG: file=>/home/jack/Desktop/Snippet_Warehouse/Analysis-of-Crimes_-_2001_to_present.csv 1.5gig in size.ipynb<
