# %% [markdown]
# # Search and View bash history

# %%
import sqlite3
import sys
conn = sqlite3.connect('historyFTS4.db')
conn.text_factory = str
c = conn.cursor()
count=0;req=200
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, text FROM history WHERE text MATCH ?', (search,)):    
    count=count+1
    print (row)[0],"-",(row)[1],"\n"
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : http-server
# 333 - wget http://www.no-ip.com/client/linux/noip-duc-linux.tar.gz
#
# 335 - wget http://www.no-ip.com/client/linux/noip-duc-linux.tar.gz
#
# 898 - ffmpeg -i "rtmp://127.0.0.1/video_audio live=1" -f mpeg1video -b:v 500k -r 21 -q:v 10 -s 640x480 http://127.0.0.1:8000/temp123/640/480/
#
# 899 - sudo ffmpeg -i "rtmp://127.0.0.1/video_audio live=1" -f mpeg1video -b:v 500k -r 21 -q:v 10 -s 640x480 http://127.0.0.1:8000/temp123/640/480/
#
# 900 - sudo ffmpeg -i "rtmp://127.0.0.1/video_audio live=1" -f mpeg1video -b:v 500k -r 21 -q:v 10 -s 640x480 http://127.0.0.1:8080/temp123/640/480/
#
# 901 - ffmpeg -f vfwcap -i 0 -f image2 -vcodec mjpeg -b:v 500k -r 21 -q:v 10 -s 640x480 http://127.0.0.1:8082/temp123/640/480/image-%3d.jpg
#
# 922 - ffmpeg -f vfwcap -i 0 -f image2 -vcodec mjpeg -b:v 500k -r 21 -q:v 10 -s 640x480 http://127.0.0.1:8082/temp123/640/480/image-%3d.jpg
#
# ...

# %%
# !ls ~/Desktop/basemap/src
# Out:
# c_numpy.pxd  _geoslib.c  _geoslib.pyx

# %%
import sys
sys.path.insert(0,"/usr/local/lib/python2.7/dist-packages")
import mpl_toolkits
sys.path.insert(0,"/usr/local/lib/python2.7/dist-packages/mpl_toolkits")
import basemap
from basemap import data


#/home/jack/Desktop/basemap/examples/
help(mpl_toolkits)

#from mpl_toolkits.basemap import Basemap
#from mpl_toolkits.basemap import Basemap
# Out:
# Help on package mpl_toolkits:
#
# NAME
#     mpl_toolkits
#
# FILE
#     (built-in)
#
# PACKAGE CONTENTS
#     axes_grid (package)
#     axes_grid1 (package)
#     axisartist (package)
#     exceltools
#     gtktools
#     mplot3d (package)
#     tests (package)

# %%
import Find
import sys
sys.path.insert(0,'/home/jack/git/documentation')
import Documentation
from Documentation import Resource
help(Resource)
# Out:
# Help on module Documentation.Resource in Documentation:
#
# NAME
#     Documentation.Resource
#
# FILE
#     /home/jack/git/documentation/Documentation/Resource.py
#
# DATA
#     resource = ['/home/jack/git/documentation/AnacondaPython.html', '/home...

# %%
    Double-click on the “just63.justhost.com Secure WebDisk.desktop” icon.
    Enter your Web Disk username, jaclnorthrut@jacknorthrup.com, and password when the system prompts you.

Manual Connection Instructions

    Open Nautilus.
    If the address bar is not visible, from the menu bar, select Go, and then Location (Ctrl + L).
    Paste the following URL into the address bar:
        
        davs://just63.justhost.com:2078
        
        
    You should now have access to your files through Web Disk.
    From the menu bar, select “Bookmarks”, and “Add Bookmark” to add a bookmark for quick access in the future.

# %%
https://www.blog.pythonlibrary.org/2012/07/18/python-a-simple-step-by-step-sqlite-tutorial/
    @importpython
    https://awesome-python.com/

# %%
# %%writefile /home/jack/anaconda2/lib/python2.7/site-packages/QuickStore.py
import sqlite3

def store():
    print "Leave Database-Name empty to use `/home/jack/Default.db`."
    print "You many enter three sets of data (DataOne & DataTwo), and Keywords  "  
    Dbname = raw_input("Database-Name: >>") or "/home/jack/Default.db"
    conn = sqlite3.connect(Dbname)
    conn.commit()
    conn.close()
    print Dbname
    storeOne = raw_input("Enter DataOne: >>")
    storeTwo = raw_input("Enter DataTwo: >>")
    keywords = raw_input("Enter Keywords: >>")

    info = (storeOne,storeTwo,keywords)
    insert_info(info,Dbname)
    return Dbname

def insert_info(info,Dbname):
        conn = sqlite3.connect(Dbname)
        c = conn.cursor()
        c.execute("""CREATE TABLE IF NOT EXISTS storage (
                   id integer PRIMARY KEY,
                   storeOne text NOT NULL,
                   storeTwo text NOT NULL,
                   keywords text NOT NULL);
                   """)
        sql = "insert into storage (storeOne,storeTwo,keywords) values (?, ?, ?)"
        c.execute(sql, info)
        conn.commit()
        conn.close()

        
def readDB():
    print "Leave Database-Name empty to use `/home/jack/Default.db`."
    Dbname = raw_input("Database-Name: >>") or "/home/jack/Default.db"
    conn = sqlite3.connect('/home/jack/Default.db')
    c = conn.cursor()
    for row in c.execute('SELECT * FROM storage ORDER BY id'):
        print row[0],"  ",row[1],"  ",row[2],"  ",row[3],"\n-----\n",
    conn.close()
# Out:
# Overwriting /home/jack/anaconda2/lib/python2.7/site-packages/QuickStore.py

# %%
# !rm /home/jack/anaconda2/lib/python2.7/site-packages/QuickStore.py

# %%
import QuickStore
QuickStore.readDB()
# Out:
# 1    dfdfdf    dfdfdf    dfdfdf
# -----

# %%
import QuickStore
QuickStore.readDB('do\ i\ need\,\ to\ use\,\ Quotes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-00a471d167b6> in <module>()
#       1 import QuickStore
# ----> 2 QuickStore.readDB('do\ i\ need\,\ to\ use\,\ Quotes')
#
# TypeError: readDB() takes no arguments (1 given)

# %%
import QuickStore
QuickStore.store()
# Out:
# Leave Database-Name empty to use `/home/jack/Default.db`.
# You many enter three sets of data (DataOne & DataTwo), and Keywords
# Database-Name: >>do i need, to use, Quotes
# do i need, to use, Quotes
# Enter DataOne: >>I do not think I do
# Enter DataTwo: >>But I will find out soon
# Enter Keywords: >>uh od I defined my database
# 'do i need, to use, Quotes'

# %%
import Find
import sys
sys.path.insert(0,'/home/jack/git/documentation')
import Documentation
from Documentation import Resource
#filename = "/home/jack/git/documentation/Documentation/All.txt"
#re = Documentation.Resources.resource[0]
#findS = raw_input("What word")
#Find.find3(filename, findS)
C= Resource.resource[2:3]
cS = str(C)
cS = cS[2:-2]
cS=str(cS)



#filename = Documentation.Resource.resource[1:2]
filename = cS
findS = "ports"
print cS
Find.find3(filename, findS)
# Out:
# /home/jack/git/documentation/Documentation/CAFFE_STUFF.html
#
# 0 : # This reports 33.04% prediction error on test data.
#
# 1 : predictions_raw = net.predict(input_data)
#
# 2 :

# %% [markdown]
# <a href='#ftp'>FTP</a>&nbsp;&nbsp;|&nbsp;&nbsp;<a href='#LineReader'>LineReader</a>

# %%
<a href='#ftp'>FTP</a> 
<a href='#LineReader'>LineReader</a>

# %%
import ftplib
help(ftplib)
# Out:
# Help on module ftplib:
#
# NAME
#     ftplib - An FTP client class and some helper functions.
#
# FILE
#     /home/jack/anaconda2/lib/python2.7/ftplib.py
#
# MODULE DOCS
#     https://docs.python.org/library/ftplib
#
# DESCRIPTION
#     Based on RFC 959: File Transfer Protocol (FTP), by J. Postel and J. Reynolds
#
#     Example:
#
#     >>> from ftplib import FTP
#     >>> ftp = FTP('ftp.python.org') # connect to host, default port
#     >>> ftp.login() # default, i.e.: user anonymous, passwd anonymous@
#     '230 Guest login ok, access restrictions apply.'
#     >>> ftp.retrlines('LIST') # list directory contents
#     total 9
#     drwxr-xr-x   8 root     wheel        1024 Jan  3  1994 .
#     drwxr-xr-x   8 root     wheel        1024 Jan  3  1994 ..
#     drwxr-xr-x   2 root     wheel        1024 Jan  3  1994 bin
#     drwxr-xr-x   2 root     wheel        1024 Jan  3  1994 etc
#     d-wxrwxr-x   2 ftp      wheel        1024 Sep  5 13:43 incoming
# ...

# %%
ftp.login("jack@epistlerblogs.com", "]-In4aoc8+10fF")

# %%
import ftplib
ftp = ftplib.FTP("ftp.epistlerblogs.com")
ftp.login("jack@epistlerblogs.com", "]-In4aoc8+10fF")
data = []
ftp.dir(data.append)
ftp.quit()
for line in data:
    print "-", line
# Out:
# - drwxr-x---   11 epistler   12               4096 Oct  7 09:25 .
# - drwxr-x---   11 epistler   12               4096 Oct  7 09:25 ..
# - -rw-r--r--    1 epistler   epistler          185 Nov 23  2015 .htaccess
# - -rw-r--r--    1 epistler   epistler           66 Jun 13  2014 .htaccess.bak.1402706025
# - -rw-r--r--    1 epistler   epistler           66 Nov 23  2015 .htaccess.bak.1448317018
# - -rw-r--r--    1 epistler   epistler           66 Jun 13  2014 .htaccess.php-upgrade-backup
# - -rw-r--r--    1 epistler   epistler         1971 Sep 17 02:43 005.php
# - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:55 006.php
# - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:57 007.php
# - -rw-r--r--    1 epistler   epistler         1115 Sep 17 03:05 1.php
# - -rw-r--r--    1 epistler   epistler         1638 Sep 17 21:51 1a.php
# - -rw-r--r--    1 epistler   epistler         1730 Sep 18 19:01 1b.php
# ...

# %% [markdown]
# # Get a Hosting Directory Listing with FTP

# %%
import ftplib
ftp = ftplib.FTP("ftp.website.com")
ftp.login("user", "password")
data = []
ftp.dir(data.append)
ftp.quit()
for line in data:
    print "-", line
# Out:
# - drwxr-x---   11 epistler   12               4096 Oct  7 09:25 .
# - drwxr-x---   11 epistler   12               4096 Oct  7 09:25 ..
# - -rw-r--r--    1 epistler   epistler          185 Nov 23  2015 .htaccess
# - -rw-r--r--    1 epistler   epistler           66 Jun 13  2014 .htaccess.bak.1402706025
# - -rw-r--r--    1 epistler   epistler           66 Nov 23  2015 .htaccess.bak.1448317018
# - -rw-r--r--    1 epistler   epistler           66 Jun 13  2014 .htaccess.php-upgrade-backup
# - -rw-r--r--    1 epistler   epistler         1971 Sep 17 02:43 005.php
# - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:55 006.php
# - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:57 007.php
# - -rw-r--r--    1 epistler   epistler         1115 Sep 17 03:05 1.php
# - -rw-r--r--    1 epistler   epistler         1638 Sep 17 21:51 1a.php
# - -rw-r--r--    1 epistler   epistler         1730 Sep 18 19:01 1b.php
# ...

# %%
import ftplib
ftp = ftplib.FTP("ftp.epistlerblogs.com")
#ftp.login("login", "password")
ftp.login("jack@epistlerblogs.com", "]-In4aoc8+10fF")
data = []
ftp.cwd('/jacknorthrup.com/')         # change directory to /pub/
ftp.dir(data.append)
ftp.quit()
l=0
for line in data:
    l=l+1
    print l,"-", line
# Out:
# 1 - drwxr-xr-x    2 epistler   epistler         4096 Oct  8 00:12 .
# 2 - drwxr-x---   11 epistler   12               4096 Oct  7 23:26 ..
# 3 - -rw-r--r--    1 epistler   epistler         1971 Sep 17 02:43 005.php
# 4 - -rw-r--r--    1 epistler   epistler      1569519 Oct  7 23:26 005.php.zip
# 5 - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:55 006.php
# 6 - -rw-r--r--    1 epistler   epistler         1980 Sep 17 02:57 007.php
# 7 - -rw-r--r--    1 epistler   epistler         1115 Sep 17 03:05 1.php
# 8 - -rw-r--r--    1 epistler   epistler         1638 Sep 17 21:51 1a.php
# 9 - -rw-r--r--    1 epistler   epistler         1730 Sep 18 19:01 1b.php
# 10 - -rw-r--r--    1 epistler   epistler         1115 Sep 17 03:37 2.php
# 11 - -rw-r--r--    1 epistler   epistler        40975 Sep 17 16:53 21.jpg
# 12 - -rw-r--r--    1 epistler   epistler         2316 Sep 17 03:47 2a.php
# 13 - -rw-r--r--    1 epistler   epistler          911 Sep 17 07:58 3.php
# ...

# %% [markdown]
# # Upload Working Fine
#
# <a href='#LineReader'>LineReader</a>

# %% [markdown]
# # Upload Working Fine
#
# <a id='ftp'></a><a href='#LineReader'>LineReader</a>&nbsp;&nbsp;|&nbsp;<a href='#indexTemp'>indexTemp.php</a>

# %%
# !ls *.ipynb
# Out:
# Bible_Search_in_SQL.ipynb
# Creating-C++-Image-blender.ipynb
# Creating-C++-Image-viewer.ipynb
# Creation-of-collection.db.ipynb
# DEEP-DREAM-ONLY.ipynb
# FTP_and_Editor.ipynb
# FTS3_Database.ipynb
# Image_Pack.ipynb
# INDEX.ipynb
# misc_twitter_stuff.ipynb
# NewNotebook1.ipynb
# NewNotebook.ipynb
# Palett_Swap.ipynb
# Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb
# Snippet_Warehouse-MySQL-SQLite-code-storage-search.ipynb
# Text_Generation-BEST.ipynb
# Text_Generation-from-twitter.ipynb
# Text_Generation.ipynb
# Words-and-Sentences.ipynb
# Working_with_Tweets_and_Text_Results.ipynb

# %%
# !wget -O download_test.ipynb http://jacknorthrup.com/Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb
# Out:
# --2017-10-09 08:55:53--  http://jacknorthrup.com/Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb
# Resolving jacknorthrup.com (jacknorthrup.com)... 173.254.28.63
# Connecting to jacknorthrup.com (jacknorthrup.com)|173.254.28.63|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1710969 (1.6M) [text/plain]
# Saving to: ‘download_test.ipynb’
#
# download_test.ipynb 100%[===================>]   1.63M   242KB/s    in 7.2s
#
# 2017-10-09 08:56:01 (231 KB/s) - ‘download_test.ipynb’ saved [1710969/1710969]

# %% [markdown]
# # Simple FTP using Python

# %%
#%%writefile FTPit.py
import ftplib
import os
def upload(ftp, file):
    ext = os.path.splitext(file)[1]
    ftp.cwd('/jacknorthrup.com/')    
    if ext in (".txt", ".htm", ".html",".ipynb",".pdf"):
        ftp.storlines("STOR " + file, open(file))
    else:
        ftp.storbinary("STOR " + file, open(file, "rb"), 1024)
# Out:
# Writing FTPit.py

# %%
def twiter():
    CONSUMER_KEY = 'YazCRIfWX4VICiRCOiph08jDL'
    CONSUMER_SECRET = 'QOkLHou6NMwkghSHjMFXMdffQKJlDzttKtP6uBCcZ4VlQtvJyc'
    ACCESS_KEY = '296906916-AWggjhqpEWIS7EzXXhc2pOPBeCVJczpOm11cQGIf'
    ACCESS_SECRET = 'zFrCiyaPt8gCBVVs1bLCmdCSyQQ3DKxT5wHJq2tOu2AMj'
    twir = (CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
    return ftp.login

# %%
# %%writefile Authorize.py
def keys():
    ftp = "ftp.MYsite.com"
    username = "Josephine"
    password = "WhaWah2525"
    login = (ftp,username,password)
    return login
# Out:
# Overwriting Authorize.py

# %%
ftp = ftplib.FTP("ftp.XXXXXXXXXXXXXX.com")
ftp.login("USERNAME", "PASSWORD")
upload(ftp, "Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb")

# %%
# !rm Authorize.pyc

# %% [markdown]
# # Create a PDF of my Snippet Images

# %%
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch, cm
c = canvas.Canvas('snippet4.pdf')

c.drawImage('/home/jack/Desktop/text_stuff/snippets/database024.png',\
            11*cm, 18*cm+30, 9*cm, 9*cm)
c.drawImage('/home/jack/Desktop/text_stuff/snippets/database025.png',\
            1*cm, 18*cm+30, 9*cm, 9*cm)
c.drawImage('/home/jack/Desktop/text_stuff/snippets/database026.png',\
            11*cm, 9*cm+20, 9*cm, 9*cm)
c.drawImage('/home/jack/Desktop/text_stuff/snippets/database027.png',\
            1*cm, 9*cm+20, 9*cm, 9*cm)
c.drawImage('/home/jack/Desktop/text_stuff/snippets/database028.png',\
            11*cm, 10, 9*cm, 9*cm)
c.drawImage('/home/jack/Desktop/text_stuff/snippets/database029.png',\
            1*cm, 10, 9*cm, 9*cm)
c.showPage()
c.save()

# %%
# Working Fine
import ftplib
import os
 
def upload(ftp, file):
    ext = os.path.splitext(file)[1]
    ftp.cwd('/jacknorthrup.com/')    
    if ext in (".txt", ".htm", ".html"):
        ftp.storlines("STOR " + file, open(file))
    else:
        ftp.storbinary("STOR " + file, open(file, "rb"), 1024)

ftp = ftplib.FTP("ftp.epistlerblogs.com")
ftp.login("jack@epistlerblogs.com", "]-In4aoc8+10fF")

 
upload(ftp, "PDFshort.html")

# %% [markdown]
# # FTP a File to a Hosting Server

# %%
# Working Fine
import ftplib
import os
 
def upload(ftp, file):
    ext = os.path.splitext(file)[1]
    ftp.cwd('/jacknorthrup.com/')    
    if ext in (".txt", ".htm", ".html"):
        ftp.storlines("STOR " + file, open(file))
    else:
        ftp.storbinary("STOR " + file, open(file, "rb"), 1024)

ftp = ftplib.FTP("ftp.website.com")
ftp.login("user", "password")

 
upload(ftp, "snippet1.pdf")

# %%
import Authorize
print Authorize.keys()[0],Authorize.keys()[1],Authorize.keys()[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-3f009897e592> in <module>()
#       1 import Authorize
# ----> 2 print Authorize.keys()[0],Authorize.keys()[1],Authorize.keys()[2]
#
# AttributeError: 'module' object has no attribute 'keys'

# %%
import Authorize
ftp = Authorize.keys()[0]
username = Authorize.keys()[1]
password = Authorize.keys()[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5f9b60c40078> in <module>()
#       1 import Authorize
# ----> 2 ftp = Authorize.keys()[0]
#       3 username = Authorize.keys()[1]
#       4 password = Authorize.keys()[2]
#
# AttributeError: 'module' object has no attribute 'keys'

# %%
#removed keys for privacy reasons
CONSUMER_KEY = Key.twiter()[0]
CONSUMER_SECRET = Key.twiter()[1]
ACCESS_KEY = Key.twiter()[2]
ACCESS_SECRET = Key.twiter()[3]

# %%
import Authorize
help(Authorize)
# Out:
# Help on module Authorize:
#
# NAME
#     Authorize
#
# FILE
#     /home/jack/Desktop/text_stuff/Authorize.py
#
# DATA
#     ftp = 'ftp.XXXXXXXXXXXXXX.com'
#     password = 'PASSWORD'
#     username = 'USERNAME'

# %%
# Working Fine
import ftplib
import os
 
def upload(ftp, file):
    ext = os.path.splitext(file)[1]
    ftp.cwd('/jacknorthrup.com/')    
    if ext in (".txt", ".htm", ".html"):
        ftp.storlines("STOR " + file, open(file))
    else:
        ftp.storbinary("STOR " + file, open(file, "rb"), 1024)

ftp = ftplib.FTP("ftp.epistlerblogs.com")
ftp.login("jack@epistlerblogs.com", "]-In4aoc8+10fF")

 
upload(ftp, "snippet.pdf")

# %% [markdown]
# # Upload a File via FTP

# %%
import ftplib
import os
 
def upload(ftp, file):
    ext = os.path.splitext(file)[1]
    ftp.cwd('/jacknorthrup.com/')    
    if ext in (".txt", ".htm", ".html", ".ipynb"):
        ftp.storlines("STOR " + file, open(file))
    else:
        ftp.storbinary("STOR " + file, open(file, "rb"), 1024)
 
ftp = ftplib.FTP("ftp.")
ftp.login("login", "password")
 
upload(ftp, "index1.php")

# %% [markdown]
# # Download a File via FTP

# %%
import ftplib
import sys
 
def getFile(ftp, filename):
    try:
        ftp.retrbinary("RETR " + filename ,open(filename, 'wb').write)
    except:
        print "Error"
 
ftp = ftplib.FTP("ftp.")
ftp.login("login", "password")
data = []
#ftp.cwd('/bible/')         # change directory to /pub/

getFile(ftp,'index.php')
 
ftp.quit()
# Out:
# '221-Goodbye. You uploaded 0 and downloaded 3 kbytes.\n221 Logout.'

# %%
# !ls
# Out:
# 1a.php			       config2.php	  red.jpg
# 21.jpg			       index.php	  seal.png
# back.jpg		       local-connect.php  story.css
# back.png		       NewNotebook.ipynb  story-header.php
# bible2.txt		       paper.jpg	  the-great-text-entry.php
# Bible-in-PHP-with-MySQL.ipynb  README.nluug	  WhereToFindWhat.txt

# %% [markdown]
# # ------------------------------------------
# ## the-great-text-entry.php
# ## Requires: bible2.txt config2.php

# %%
# %load the-great-text-entry.php
<?php
$file = fopen("bible2.txt","r");
while(! feof($file))
  {
$scriptures= fgets($file);
echo "<font color='green'>add a row.";
include_once("config2.php");
$result = mysqli_query($mysqli, "INSERT INTO verse(scriptures) VALUES('$scriptures')");
}
fclose($file);
?>

# %% [markdown]
# # -----------------------------------------------------------------
# ## index.php
# ## Requires: story-header-index.php  local-connect.php story.css

# %%
# %load index.php
<!DOCTYPE html>
<head>
<title>King James Searchable Bible</title>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
<meta name="keywords" content="King James, Searchable Bible, Online Bible,Bible Online" />
<meta name="description" content="King James Searchable Bible Online" />
<meta content="Jack Northrup " name="author" />
<link rel="stylesheet" href="story.css" />
<script type="text/javascript" src="https://apis.google.com/js/platform.js"></script>
</head>
<body>
<div id="wrapper">
<?php include('story-header-index.php'); ?>

</div>
<p style = "width:80%;color:#f5c350;margin-right:auto;margin-left:auto;text-align:center;">Enter a word, words or a phrase in the search input and press: FULL TEXT SEARCH</p>
<form method="get" action="<?=$_SERVER['PHP_SELF'];?>">
    <input type="text" name="query" />
    <button>FULL TEXT SEARCH</button>
</form>
<?php include('local-connect.php'); ?>
<div id="read-search">
<?php
    $query = $_GET['query'];
    //$id = $_GET['id'];
    //echo $query;
    $min_length = 1;
    //$query = truth ;
if(strlen($query) >= $min_length){ 
    //$query = htmlspecialchars($query);
    //$query = mysql_real_escape_string($query);

      //$results = mysql_query('SELECT * FROM verse WHERE MATCH(scriptures) AGAINST("'.$qry.'")');
  
   //$results = mysql_query("SELECT * FROM verse WHERE MATCH (scriptures) AGAINST ('.$query.' IN BOOLEAN MODE)");
     
//$results = mysql_query("select id,scriptures from verse where MATCH(scriptures) AGAINST('".$query."') ORDER BY `id`"); 
//$results = mysql_query("select id,scriptures from verse where MATCH(scriptures) AGAINST('".$query."')"); 
$results = mysql_query("select id,scriptures from verse where MATCH(scriptures)
                        AGAINST('".$query."' IN NATURAL LANGUAGE MODE) ORDER BY `id` DESC"); 
//$results = mysql_query("select id,scriptures from verse where MATCH(scriptures)
//                         AGAINST('".$query."') ORDER BY `id` DESC"); 
$results =  mysql_query("SELECT * FROM verse WHERE scriptures regexp '".$query."'");                          
    

    
    
if(mysql_num_rows($results) > 0){ 
    while($row = mysql_fetch_array($results)){
        echo "<br /><br />".$row['id']."<br />
        ".$row['scriptures']; }			 
  }
        else{ 
            echo "No results";
        }}
    else{ 
        echo "Minimum length is ".$min_length;
    }
?>
</div>
</body>
</html>

# %% [markdown]
# <a href='#ftp'>FTP</a> <a id='#index'a>

# %% [markdown]
# <a href='#ftp'>FTP</a>&nbsp;&nbsp;&nbsp;&nbsp;|| <a id="indexTemp">linked</a>

# %%
# %%writefile index1.php
# <!DOCTYPE html>
# <head>
# <title>King James Searchable Bible</title>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="keywords" content="King James, Searchable Bible, Online Bible,Bible Online" />
# <meta name="description" content="King James Searchable Bible Online" />
# <meta content="Jack Northrup " name="author" />
# <link rel="stylesheet" href="story.css" />
# <script type="text/javascript" src="https://apis.google.com/js/platform.js"></script>
# </head>
# <body>
# <div id="wrapper">
# <?php include('story-header-index.php'); ?>
#
# </div>
# <p style = "width:80%;color:#f5c350;margin-right:auto;margin-left:auto;text-align:center;">Enter a word, words or a phrase in the search input and press: FULL TEXT SEARCH</p>
# <form method="get" action="<?=$_SERVER['PHP_SELF'];?>">
#     <input type="text" name="query" />
#     <button>FULL TEXT SEARCH</button>
# </form>
# <?php include('local-connect.php'); ?>
# <div id="read-search">
# <?php
#     $query = $_GET['query'];
#     //$id = $_GET['id'];
#     //echo $query;
#     $min_length = 1;
#     //$query = truth ;
# if(strlen($query) >= $min_length){
#     //$query = htmlspecialchars($query);
#     //$query = mysql_real_escape_string($query);
#
#       //$results = mysql_query('SELECT * FROM verse WHERE MATCH(scriptures) AGAINST("'.$qry.'")');
#
#    //$results = mysql_query("SELECT * FROM verse WHERE MATCH (scriptures) AGAINST ('.$query.' IN BOOLEAN MODE)");
#
# //$results = mysql_query("select id,scriptures from verse where MATCH(scriptures) AGAINST('".$query."') ORDER BY `id`");
# //$results = mysql_query("select id,scriptures from verse where MATCH(scriptures) AGAINST('".$query."')");
# $results = mysql_query("select id,scriptures from verse where MATCH(scriptures)
#                         AGAINST('".$query."' IN NATURAL LANGUAGE MODE) ORDER BY `id` DESC");
# //$results = mysql_query("select id,scriptures from verse where MATCH(scriptures)
# //                         AGAINST('".$query."') ORDER BY `id` DESC");
# $results =  mysql_query("SELECT * FROM verse WHERE scriptures regexp '".$query."' LIMIT 1000");
#
#
#
#
# if(mysql_num_rows($results) > 0){
#     while($row = mysql_fetch_array($results)){
#         echo "<br /><br />Line Number :".$row['id']."<br />
#         ".$row['scriptures']; }
#   }
#         else{
#             echo "No results";
#         }}
#     else{
#         echo "Minimum length is ".$min_length;
#     }
# ?>
# </div>
# </body>
# </html>
# Out:
# Overwriting index1.php

# %% [markdown]
# <a href='#ftp'>FTP</a>&nbsp;&nbsp;&nbsp;&nbsp;|| <a id="indexTemp">linked</a>

# %%
# %%writefile indexTemp.php
# <!DOCTYPE html>
# <head>
# <title>King James Searchable Bible</title>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="keywords" content="King James, Searchable Bible, Online Bible,Bible Online" />
# <meta name="description" content="King James Searchable Bible Online" />
# <meta content="Jack Northrup " name="author" />
# <link rel="stylesheet" href="story.css" />
# <script type="text/javascript" src="https://apis.google.com/js/platform.js"></script>
# </head>
# <body>
# <div id="wrapper">
# <?php include('story-header-index.php'); ?>
#
# </div>
# <p style = "width:80%;color:#f5c350;margin-right:auto;margin-left:auto;text-align:center;">Enter a word, words or a phrase in the search input and press: FULL TEXT SEARCH</p>
# <form method="get" action="<?=$_SERVER['PHP_SELF'];?>">
#     <input type="text" name="query" />
#     <button>FULL TEXT SEARCH</button>
# </form>
# <?php include('local-connect.php'); ?>
# <div id="read-search">
# <?php
#     $query = $_GET['query'];
#     //$id = $_GET['id'];
#     //echo $query;
#     $min_length = 1;
#     //$query = truth ;
# if(strlen($query) >= $min_length){
#     $query = htmlspecialchars($query);
#     $query = mysql_real_escape_string($query);
#
# $results = mysql_query('SELECT * FROM verse WHERE MATCH(scriptures) AGAINST("'.$query.'")');
#
# //$results = mysql_query("SELECT * FROM verse WHERE MATCH (scriptures) AGAINST ('.$query.' IN BOOLEAN MODE)");
# //$results = mysql_query("SELECT * FROM verse WHERE MATCH (scriptures) AGAINST ('.$query.' IN NATURAL LANGUAGE MODE WITH QUERY EXPANSION)");
# //$result = mysql_query("SELECT * FROM verse WHERE scriptures LIKE (\'"%.$query%."\') LIMIT 50");
# //$results = mysql_query("select id,scriptures from verse where MATCH(scriptures) AGAINST('".$query."') ORDER BY `id`");
#
# //$results = mysql_query("SELECT id,scriptures FROM verse WHERE MATCH(scriptures) AGAINST ({`.$query.`})");
#
#
#
# if(mysql_num_rows($results) > 0){
#     while($row = mysql_fetch_array($results)){
#         echo "<br /><br />".$row['id']."<br />
#         ".$row['scriptures']; }
#   }
#         else{
#             echo "No results";
#         }}
#     else{
#         echo "Minimum length is ".$min_length;
#     }
# ?>
# </div>
# </body>
# </html>
# Out:
# Overwriting indexTemp.php

# %% [markdown]
# <a href='#ftp'>FTP</a>&nbsp;&nbsp;&nbsp;&nbsp;

# %%
# %%writefile story-header-index.php
# <div id="header">
#
# <div id="sidebar">
# <center><h3>King James <br />Version</h3>
# <img src="seal.png" alt="PH_world logo" style="width:75px;height:75px;">
# </center>
# </div>
# <div id="content"><center>
# <h1>Bible Search</h1>
# <p><a style = "color:blue;font-size:1.5em;"href="1b.php">SEARCH BY LINE NUMBER</a><br /><br />by Jack Northrup</p></center>
# </div>
# </div>
# Out:
# Overwriting story-header-index.php

# %% [markdown]
# # -----------------------------------------------------------------
# ## 1a.php
# ## Requires: story-header.php  local-connect.php story.css
# <a href='#ftp'>FTP</a>

# %%
<a href='#LineReader'>ftp'</a>

# %% [markdown]
# <a id='LineReader'>LineReader</a>

# %%
# %%writefile 1b.php
# <!DOCTYPE html>
# <head>
# <title>King James Searchable Bible</title>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta name="keywords" content="Notes Mini-Blog, SQL comments, online comments, sql based comments, comments code" />
# <meta name="description" content="Documentation for Notes Mini-Blog ver 2.04 is an MySQLbased online documentation. It is a works in progress. It will soon be a fully searchable BlogBlocks Documentation Source." />
# <meta content="Jack Northrup " name="author" />
# <link rel="stylesheet" href="story.css" />
# <script type="text/javascript" src="https://apis.google.com/js/platform.js"></script>
# </head>
# <body>
# <div id="wrapper">
# <?php include('story-header.php'); ?>
# </div>
# <p style = "width:80%;color:#f5c350;margin-right:auto;margin-left:auto;text-align:center;">
# Enter a line number to read. Some ideas are, times, dates, appointments, birthdays etc.<br>
# Your line and, to provide context, the next five lines will be listed.</p>
#
# <form method="get" action="<?=$_SERVER['PHP_SELF'];?>">
#     <input type="text" name="id" />
#     <button>Search by Line</button>
# </form>
# <?php include('local-connect.php'); ?>
# <?php
#     $id = $_GET['id'];
#
#
#     $min_length = 1;
#
# if(strlen($id) >= $min_length){
#     $query = htmlspecialchars($query);
#     $query = mysql_real_escape_string($query);
#     $results = mysql_query("SELECT * FROM `verse` WHERE id >= $id LIMIT 5");
#
# if(mysql_num_rows($results) > 0){
#             while($row = mysql_fetch_array($results)){
# echo "<br /> Line Number : ".$row['id']."<br>
# ".$row['scriptures']; }
#   }
#         else{
#             echo "No results";
#         }}
#     else{
#         echo "Enter any number from 1 to 31102";
#     }
# ?>
# </div>
# </body>
# </html>
# Out:
# Overwriting 1b.php

# %% [markdown]
# <a href='#ftp'>FTP</a>

# %% [markdown]
# # ------------------------------------------------
# ## story-header.php
# ## Requires: seal.png

# %%
# %load story-header.php
<div id="header">

<div id="sidebar"> 
<center><h3>King James <br />Version</h3>
<img src="seal.png" alt="PH_world logo" style="width:75px;height:75px;">
</center>
</div>
<div id="content"><center>
<h1>Bible Search</h1>
<p><a style = "color:blue;font-size:1.5em;"href="index.php">FULL TEXT SEARCH</a><br /><br />by Jack Northrup</p></center>
</div>
</div>

# %% [markdown]
# # ---------------------------------------------------
# ## story.css
# ## Requires:  back.jpg  21.jpg paper.jpg red.jpg

# %%
# %load story.css
/*
 Theme Name:     BlogBlock BookMaker ver 2.04
 Theme URI:         http://www.blogblocks.net
 Description:        BlogBlock Blog theme BookMaker
 Author:               Jack Northrup
 Author URI:         http://jacknorthrup.com
 Template:           Create a Book
 Version:              3.0.5
*/
html{
margin:0;
padding:0;
/* background-image: 517904494.jpg; */
background-image: url("back.jpg");
}
body{
margin:0;
padding:20;
background-color: brown;
color:#fcecc8;
padding:15px;
font-size:2em;
background-image: url("back.jpg");
}
h1, h2, h3, h4, h5, h6,
article, applet,  audio,  body, caption, center,
del, dd, div, dl, dt, em, embed, footer, form, header, html,
i, iframe, input, img, label, li, legend, menu, nav, ol,
object, output, p, section, select, span, table, tbody, textarea, tfoot, thead, tr, th, td, ul, video {
margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit;
}
article,footer, header, menu, nav, section { display: block;
}
a {margin: 0; padding: 0; border: 0; font-size: 100%; font: inherit;
color: inherit; outline: none; text-decoration: none; text-align:right;
}
blockquote, q {quotes: none;}
body {line-height: 1;
font-size:20px;}
caption, th {text-align:center;}
img {border: 0;}
legend {color: #000;}
ol, ul {list-style: none;}
table {border-collapse: collapse; border-spacing: 0;
}



#wrapper{

margin-top:8px;
margin-left:auto;
margin-right:auto;
width:95%;
height:auto;
min-height:250px;
padding-top:5px;
padding-right:1%;
padding-left:1%;
padding-bottom:15px;
border:1px solid gray;
background:  #cccc99;
background-image: url("21.jpg");
border-radius:8px;
-moz-box-shadow:    inset 0 0 10px #000000;
-webkit-box-shadow: inset 0 0 10px #000000;
box-shadow:         inset 0 0 10px #000000;
}
#editor-wrapper{
margin:5px auto;
width:98%;
max-width:1000px;
height:auto;
min-height:900px;
padding-top:5px;
padding-right:.5%;
padding-left:.5%;
padding-bottom:15px;
border:1px solid gray;
border-radius:8px;
}
.shadowi {
   -moz-box-shadow:    inset 0 0 10px #000000;
   -webkit-box-shadow: inset 0 0 10px #000000;
   box-shadow:         inset 0 0 10px #000000;
}

textarea {
	-webkit-box-sizing: border-box;
	-moz-box-sizing: border-box;
	box-sizing: border-box;
    width: 100%;
    height:auto:
    height:500px;
}

input[name=origchapter] {
    width: 100%;
    font-size: 1.5em;
    height: 40px;
    display: block;
    margin-bottom: 10px;
    background-color: #F8F6B4;
}

input[name=origkeywords] {
    width: 100%;
    font-size: 1.5em;
    height: 40px;
    display: block;
    margin-bottom: 10px;
    background-color: #F8F6B4;
}

input[name=origcategory] {
    width: 100%;
    font-size: 1.5em;
    height: 25px;
    display: block;
    margin-bottom: 10px;
    background-color: #F8F6B4;
}


input[name=query] { 
        width: 65%; 
        font-size: 1.5em; 
        height: 35px; 
        margin-bottom: 10px; 
        background-color: #F8F6B4; 
        border-radius: 8px;
} 
                
button {
     background-color: gray;
    border: none;
    color: white;
    padding: 5px 15px;
    text-align: center;
    text-decoration: none;
    display: inline-block;
    font-size: 14px;
    margin: 4px 2px;
    cursor: pointer;
    box-shadow: 0 8px 16px 0 rgba(0,0,0,0.2), 0 6px 20px 0 rgba(0,0,0,0.19);
}

button:hover {
     background-color: gray;
    border: none;
    color: white;
    padding: 5px 15px;
    text-align: center;
    text-decoration: none;
    display: inline-block;
    font-size: 14px;
    margin: 4px 2px;
    cursor: pointer;
    box-shadow: 0 12px 16px 0 rgba(0,0,0,0.44), 0 17px 50px 0 rgba(0,0,0,0.29);
}      
.video-container iframe,  
.video-container object,  
.video-container embed {
	position: absolute;
	top: 0;
	left: 5%;
	width: 90%;
	height: 90%;
}
.entry-content img, 
.entry-content iframe, 
.entry-content object, 
.entry-content embed {
    max-width: 100%;
}

#header{
margin: auto;
width: 90%;
padding:20px;
background-color:#f5c350;
border: 2px solid #000000;
height:auto;
}
#header h1{
font-size: 2em;
text-align: center;
padding-right:20px;
color: #FFC300;    
} 
#header p{
font-size: 1em;
text-align: center;
padding:2%;
color: #660000;    
} 

#header a{
font-size: 1em;
text-align: center;
padding:5px;    
}   

.right{
text-align:right;
} 
.left{
text-align:left;
}         
.boxit h1{
font-size: 1.8em;
text-align: center;
padding-right:5px;
color: #660000;   
}         
.boxit h2{
font-size: 1.6em;
text-align: center;
padding-right:5px;
color: #660000;   
} 
.boxit h3{
font-size: 1.3em;
text-align: center;
padding-right:5px;
color: #BB2727;   
} 

#wrapper .boxit {
width: 75%;
margin-top:30px;
}
    
.boxit p{
text-indent: 40px;
font-size: 1.2em;
width: 75%;
text-align: justify;
padding-right:5px;
color: #660000;   
}      
#read-search .boxit h1{
font-size: 1.8em;
text-align: center;
padding-right:5px;
color: #660000;   
}         
#read-search .boxit h2{
font-size: 1.6em;
text-align: center;
padding-right:5px;
color: #660000;   
} 

#read-search .boxit p{
font-size: 1.2em;
width: 95%;
text-align: justify;
padding-right:5px;
color: #660000;   
}                  

label{
padding:5px;
border: 1px solid black;
color:red;
}

.notice{
font-style: italic;
color:navy;
font-size:1em;
}

.notice2{
font-style: italic;
color:navy;
font-size:1.2em;
text-decoration: underline;
}
#content {
background:#eee;
background-image: url("paper.jpg");
width: 300px;
border:1px solid white;
margin:20px;
width:50%;
padding-right:2.5%;  
padding-left:2.5%;   
height:auto;
float: left;
-webkit-box-shadow: -8px 11px 5px 0px rgba(0,0,0,0.39);
-moz-box-shadow: -8px 11px 5px 0px rgba(0,0,0,0.39);
box-shadow: -8px 11px 5px 0px rgba(0,0,0,0.39);
}     

#sidebar {
background:#c00;
background-image: url("red.jpg");
color:yellow;
width: 200px;
height:auto;
float:left;
padding-top:20px;
padding-bottom:20px;
padding-right:10px;
padding-left:10px;
-webkit-box-shadow: -3px 4px 5px 0px rgba(0,0,0,0.49);
-moz-box-shadow: -3px 4px 5px 0px rgba(0,0,0,0.49);
box-shadow: -3px 4px 5px 0px rgba(0,0,0,0.49);
}

form{ 
margin: 20px auto; 
padding: 1.5%; 
width:50%; 
background-color: #cfcfcf; 
border: 1px dotted black; 
border-radius: 8px; 
-webkit-box-shadow: -5px 3px 19px 0px rgba(50, 50, 50, 0.76); 
-moz-box-shadow: -5px 3px 19px 0px rgba(50, 50, 50, 0.76); 
box-shadow: -5px 3px 19px 0px rgba(50, 50, 50, 0.76); }

h1 {
text-shadow: 2px 2px 4px #000000;
}





/* */

# %% [markdown]
# # -----------------------------------------------------------------
# # -----------------------------------------------------------------
# # -----------------------------------------------------------------

# %% [markdown]
# # ftp.nluug.nl

# %%
import ftplib
ftp = ftplib.FTP("ftp.nluug.nl")
ftp.login("anonymous", "ftplib-example-1")
data = []
ftp.dir(data.append)
ftp.quit()
for line in data:
    print "-", line
# Out:
# - lrwxrwxrwx    1 0        0               1 Nov 13  2012 ftp -> .
# - lrwxrwxrwx    1 0        0               3 Nov 13  2012 mirror -> pub
# - lrwxrwxrwx    1 0        0              26 Nov 13  2012 pub -> vol/1/.CLUSTER/var_ftp/pub
# - lrwxrwxrwx    1 0        0              28 Nov 13  2012 site -> vol/1/.CLUSTER/var_ftp/site/
# - drwxr-xr-x    9 0        0            4096 Jan 23  2014 vol

# %%
import ftplib
import sys
 
def getFile(ftp, filename):
    try:
        ftp.retrbinary("RETR " + filename ,open(filename, 'wb').write)
    except:
        print "Error"
 
 
ftp = ftplib.FTP("ftp.nluug.nl")
ftp.login("anonymous", "ftplib-example-1")
 
ftp.cwd('/pub/')         # change directory to /pub/
getFile(ftp,'WhereToFindWhat.txt')
 
ftp.quit()
# Out:
# '221 Goodbye.'

# %%
# !ls
# Out:
# 21.jpg			       index-backupof online .php  story.css
# app-header.php		       index.php		   story-header1.php
# back.jpg		       instructions.php		   story-header.php
# back.png		       NewNotebook.ipynb	   test002.php
# Bible-in-PHP-with-MySQL.ipynb  paper.jpg		   untitled.php
# good-local-backindex.php       README.nluug		   WhereToFindWhat.txt
# header2.php		       red.jpg			   working_search.php
# header.php		       seal.png

# %%
epistler ftp
jack@epistlerblogs.com
ThinkPadT$#43

# %%
$quoted_query = $pdo->quote($query);
$sql = "SELECT * FROM bible 
        WHERE book = ? AND chapter = ? AND verse = ?
          AND MATCH(text) AGAINST ({$quoted_query})"
$stmt = $pdo->prepare($sql);
$stmt->execute(array($book, $chapter, $verse));

# %%
# %load local-connect.php
<?php

$hostname = "localhost";
$username = "";
$password = "";

$dbhandle = mysql_connect($hostname, $username, $password)
or die("Unable to connect to MySQL");

//select a database to work with

$selected = mysql_select_db("",$dbhandle)
or die("Could not select ");

# %%
# %%writefile PDO.log.class.php
# <?php
# class Log
# {
# 	private $path = '/logs/';
# 	public function __construct()
# 	{
# 		$this->path = dirname(__FILE__) . $this->path;
# 	}
#
# 	public function write($message, $fileSalt)
# 	{
# 		$date = new DateTime();
# 		$log  = $this->path . $date->format('Y-m-d') . "-" . md5($date->format('Y-m-d') . $fileSalt) . ".txt";
# 		if (is_dir($this->path)) {
# 			if (!file_exists($log)) {
# 				$fh = fopen($log, 'a+') or die("Fatal Error !");
# 				$logcontent = "Time : " . $date->format('H:i:s') . "\r\n" . $message . "\r\n";
# 				fwrite($fh, $logcontent);
# 				fclose($fh);
# 			} else {
# 				$this->edit($log, $date, $message);
# 			}
# 		} else {
# 			if (mkdir($this->path, 0777) === true) {
# 				$this->write($message, $fileSalt);
# 			}
# 		}
# 	}
# 	private function edit($log, $date, $message)
# 	{
# 		$logcontent = "Time : " . $date->format('H:i:s') . "\r\n" . $message . "\r\n\r\n";
# 		$logcontent = $logcontent . file_get_contents($log);
# 		file_put_contents($log, $logcontent);
# 	}
# }
# Out:
# Writing PDO.log.class.php

# %%
$dsn = 'mysql:dbname=epistler_bible;host=localhost';
$username = 'epistler_dudes';
$password = '@rockon2dawn#';
try {
    $db = new PDO($dsn, $username, $password); // also allows an extra parameter of configuration
} catch(PDOException $e) {
    die('Could not connect to the database:<br/>' . $e);
}
$statement = <<<SQL
    SELECT *
    FROM `verse`
    WHERE `scriptures` = "trust"
SQL;

$verse = $db->query($statement);

foreach($verse->FetchAll() as $verse) {
    echo $verse['scripture'] . '<br />';
}

# %%
# %%writefile index001.php
# <form method="get" action="001_pdo.php">
# <!-- This will use the GET method in order to interact with the php file. -->
#
# <input type="text" name="q" placeholder="Search...">
#
# <input type="submit" name="btn_submit" value="Search">
# <!-- You can either use an input or a button. Make sure that the "type" attribute is set. -->
#
# </form>
# Out:
# Overwriting index001.php

# %%
https://theokonst.tk/php/php-search-using-pdo/

# %%
# %%writefile search_pdo.php
# <?php
#
# $trim_q = trim($_GET['q']);
# if (empty($trim_q)) {
# header("refresh: 3;url=/search_pdo.php");
# die("<h4>The search field is empty!</h4>");
# }
#
# try {
#
# //include_once "conf.php"; // Include a file containing credentials or specify below
#
# $host = 'localhost';
#
# $dbname = 'search_db';
#
# $username = 'root';
#
# $password = 'password';
#
# $dbc = new PDO("mysql:host=$host;dbname=$dbname", $username, $password); // Make the connection
# // $dbc->exec("set names utf8mb4");  // Optional
# } catch (PDOException $e) {
# echo $e->getMessage(); // Catch errors
# }
#
# $keyword = strip_tags($_GET['q']);
#
# $crows = $dbc->prepare("SELECT count(*) FROM names WHERE name LIKE :q");
# $crows->bindValue(':q', "%".$keyword."%", PDO::PARAM_STR);
# $crows->execute();
# $crows->setFetchMode(PDO::FETCH_NUM);
# $crows = $crows->fetch();
#
# &nbsp;
#
# $stmt = $dbc->prepare("SELECT * FROM names WHERE name LIKE
# Out:
# Writing search_pdo.php

# %%
# %%writefile 001_pdo.php
# <?php
#
# $trim_q = trim($_GET['q']);
# if (empty($trim_q)) {
# header("refresh: 3;url=/001_pdo.php");
# die("<h4>The search field is empty!</h4>");
# }
#
# try {
#
# //include_once "conf.php"; // Include a file containing credentials or specify below
#
#
# $host = 'localhost';
# $dbname = 'bible';
# $username = 'root';
# $password = '';
# $dbc = new PDO("mysql:host=$host;dbname=$dbname", $username, $password); // Make the connection
# // $dbc->exec("set names utf8mb4");  // Optional
# } catch (PDOException $e) {
# echo $e->getMessage(); // Catch errors
# }
#
# $keyword = strip_tags($_GET['q']);
#
# //$crows = $dbc->prepare("SELECT count(*) FROM verse WHERE scriptures LIKE :q");
# $crows = $dbc->prepare("SELECT count(*) FROM verse WHERE id LIKE :q");
# $crows->bindValue(':q', "%".$keyword."%", PDO::PARAM_STR);
# $crows->execute();
# $crows->setFetchMode(PDO::FETCH_NUM);
# $crows = $crows->fetch();
#
# &nbsp;
#
# //$stmt = $dbc->prepare("SELECT * FROM verse WHERE scriptures LIKE :q");
# $stmt = $dbc->prepare("SELECT * FROM verse WHERE id LIKE :q");
# $stmt->bindValue(':q', "%".$keyword."%", PDO::PARAM_STR);
# $stmt->execute();
#
# ?>
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>PDO</title>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>
# <meta name="description" content="PHP PDO SEARCH"/>
# <meta charset="utf-8">
# <!--Import Google Icon Font-->
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# <!--Import materialize.css-->
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.6/css/materialize.min.css" media="screen,projection"/>
# <script src="https://static3.tsearch.eu/api/files/js/jquery.js"></script>
# <!-- Compiled and minified JavaScript -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.6/js/materialize.min.js"></script>
# <!--Let browser know website is optimized for mobile-->
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# </head>
# <body>
#
# <div class="card-panel">
# <!-- Card Content -->
# <div class="card-content">
# <h4 class="flow-text">Total rows: <?=$rows["count(*)"]?></h4>
# </div>
# </div>
#
# <?php
# if (isset($_GET['q'])) {
# if ($stmt->rowCount() > 0) {
# $stmt->setFetchMode(PDO::FETCH_ASSOC);
# $iterator = new IteratorIterator($stmt);
# if ($crows[0] == 1) {
# ?>
# <h2><?=$crows[0]?> search result</h2>
# <?php
# } else {
# ?>
# <h2><?=$crows[0]?> search results</h2>
# <?php
# }
# ?>
# <div class="row">
# <?php
# foreach ($iterator as $data) {
# ?>
# <div class="card white">
# <div class="card-content">
# <span class="card-title"><?=$data[scriptures]?></span>
# </div>
# </div>
#
# <?php
# }
# ?>
# <?php
# } else {
# ?>
# <h4>No results found for "<?=$keyword?>"</h4>
#
# <?php
#
# }
#
# }
#
# ?>
#
# </body>
#
# </html>
# Out:
# Overwriting 001_pdo.php

# %%
import QUICKdb
insert="""
import sqlite3
import os.path
from os import listdir, getcwd
from IPython.core.display import Image 

def get_picture_list(rel_path):
    abs_path = os.path.join(os.getcwd(),rel_path)
    print 'abs_path =', abs_path
    dir_files = os.listdir(abs_path)
    #print dir_files
    return dir_files

picture_list = get_picture_list('snippets')
print picture_list
import sqlite3
import os.path
from os import listdir, getcwd
from IPython.core.display import Image 

def create_or_open_db(db_file):
    db_is_new = not os.path.exists(db_file)
    conn = sqlite3.connect(db_file)
    if db_is_new:
        print 'Creating schema'
        sql = '''create table if not exists PICTURES(
        ID INTEGER PRIMARY KEY AUTOINCREMENT,
        PICTURE BLOB,
        TYPE TEXT,
        FILE_NAME TEXT);'''
        conn.execute(sql) # shortcut for conn.cursor().execute(sql)
    else:
        print 'Schema exists\n'
    return conn

def insert_picture(picture_file):
    with open(picture_file, 'rb') as input_file:
        conn = sqlite3.connect(dbname)
        c = conn.cursor()
        ablob = input_file.read()
        base=os.path.basename(picture_file)
        afile, ext = os.path.splitext(base)
        sql = '''INSERT INTO PICTURES
        (PICTURE, TYPE, FILE_NAME)
        VALUES(?, ?, ?);'''
        c.execute(sql,[sqlite3.Binary(ablob), ext, afile]) 
        conn.commit()

def loadimages(dbname, path):
    conn = sqlite3.connect(dbname)
    c = conn.cursor()
    #conn.execute("DELETE FROM PICTURES")
    for fn in picture_list:
        picture_file = path+"/"+fn
        insert_picture(picture_file)

    for r in c.execute("SELECT rowid, FILE_NAME FROM PICTURES"):
        print r[0],r[1]
   
    conn.commit()


def get_image(picture_id):
    conn = sqlite3.connect(dbname)
    c = conn.cursor()
    c.execute("SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = ?;",(picture_id,))
    #sql = "SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = 19"
    param = {'id': picture_id}
    #c.execute(sql, param)
    ablob, ext, afile = c.fetchone()
    filename = afile + ext
    with open(filename, 'wb') as output_file:
        output_file.write(ablob)
    return filename


dbname = "ImageC.db"
db_file = create_or_open_db(dbname)
path = "snippets/"
loadimages(dbname, path)
filename = get_image(16)
print filename
Image(filename=filename)
"""
QUICKdb.dbstore(insert)

# %%
import sqlite3
import os.path
from os import listdir, getcwd
from IPython.core.display import Image 

def get_picture_list(rel_path):
    abs_path = os.path.join(os.getcwd(),rel_path)
    print 'abs_path =', abs_path
    dir_files = os.listdir(abs_path)
    #print dir_files
    return dir_files

picture_list = get_picture_list('snippets')
print picture_list
import sqlite3
import os.path
from os import listdir, getcwd
from IPython.core.display import Image 

def create_or_open_db(db_file):
    db_is_new = not os.path.exists(db_file)
    conn = sqlite3.connect(db_file)
    if db_is_new:
        print 'Creating schema'
        sql = '''create table if not exists PICTURES(
        ID INTEGER PRIMARY KEY AUTOINCREMENT,
        PICTURE BLOB,
        TYPE TEXT,
        FILE_NAME TEXT);'''
        conn.execute(sql) # shortcut for conn.cursor().execute(sql)
    else:
        print 'Schema exists\n'
    return conn

def insert_picture(picture_file):
    with open(picture_file, 'rb') as input_file:
        conn = sqlite3.connect(dbname)
        c = conn.cursor()
        ablob = input_file.read()
        base=os.path.basename(picture_file)
        afile, ext = os.path.splitext(base)
        sql = '''INSERT INTO PICTURES
        (PICTURE, TYPE, FILE_NAME)
        VALUES(?, ?, ?);'''
        c.execute(sql,[sqlite3.Binary(ablob), ext, afile]) 
        conn.commit()

def loadimages(dbname, path):
    conn = sqlite3.connect(dbname)
    c = conn.cursor()
    #conn.execute("DELETE FROM PICTURES")
    for fn in picture_list:
        picture_file = path+"/"+fn
        insert_picture(picture_file)

    for r in c.execute("SELECT rowid, FILE_NAME FROM PICTURES"):
        print r[0],r[1]
   
    conn.commit()


def get_image(picture_id):
    conn = sqlite3.connect(dbname)
    c = conn.cursor()
    c.execute("SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = ?;",(picture_id,))
    #sql = "SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = 19"
    param = {'id': picture_id}
    #c.execute(sql, param)
    ablob, ext, afile = c.fetchone()
    filename = afile + ext
    with open(filename, 'wb') as output_file:
        output_file.write(ablob)
    return filename


dbname = "ImageC.db"
db_file = create_or_open_db(dbname)
path = "snippets/"
loadimages(dbname, path)
filename = get_image(16)
print filename
Image(filename=filename)
# Out:
# abs_path = /home/jack/Desktop/text_stuff/snippets
# ['database016.png', 'database025.png', 'database006.png', 'database012.png', 'database028.png', 'database018.png', 'database030.png', 'database008.png', 'database010.png', 'database021.png', 'database003.png', 'database002.png', 'database029.png', 'database019.png', 'database011.png', 'database024.png', 'database009.png', 'database013.png', 'database023.png', 'snippet_base.png', 'database027.png', 'database022.png', 'database026.png', 'database014.png', 'database017.png', 'database001.png', 'database007.png', 'database005.png', 'database015.png', 'database031.png', 'database020.png', 'database004.png']
# Creating schema
# 1 database016
# 2 database025
# 3 database006
# 4 database012
# 5 database028
# 6 database018
# 7 database030
# 8 database008
# 9 database010
# 10 database021
# 11 database003
# 12 database002
# 13 database029
# 14 database019
# 15 database011
# 16 database024
# 17 database009
# 18 database013
# 19 database023
# ...
