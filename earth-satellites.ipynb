# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (8.0, 7.0)
pylab.rcParams['font.size'] = 14
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#elements = """ISS (ZARYA)             
#1 25544U 98067A   13330.58127943  .00000814  00000-0  21834-4 0  1064
#2 25544  51.6484  23.7537 0001246  74.1647  18.7420 15.50540527859894
#"""

# %%
#from skyfield.api import earth
#topos = earth.topos('75 W', '35 N')
#sat = earth.satellite(elements.splitlines())

# %%
from itertools import izip, islice
with open('visual.txt', 'r') as f:
    for next_n_lines in izip(*[f] * 3):
        sleep(1)
        print next_n_lines
# Out:
# ('ATLAS CENTAUR 2 R/B\r\n', '1   694U 63047A   17289.27221401 +.00000825 +00000-0 +96824-4 0  9993\r\n', '2   694 030.3566 218.6620 0587343 002.0514 358.2331 14.02172662700105\r\n')
# ('THOR AGENA D R/B\r\n', '1   733U 64002A   17289.57624160 +.00000064 +00000-0 +41421-4 0  9999\r\n', '2   733 099.1233 121.2560 0033722 184.8081 175.2782 14.32291068799267\r\n')
# ('SL-3 R/B\r\n', '1 00877U 64053B   17289.48483068 -.00000046  00000-0  15405-4 0  9998\r\n', '2 00877  65.0774 297.9596 0051772  54.4881 306.1031 14.59308084819219\r\n')
# ('SL-8 R/B\r\n', '1  2802U 67045B   17289.55433413 +.00000014 +00000-0 +12354-4 0  9993\r\n', '2  2802 074.0102 300.7555 0067457 325.0761 034.5978 14.43665078646495\r\n')
# ('SL-8 R/B\r\n', '1 03230U 68040B   17289.74954389  .00000331  00000-0  37948-4 0  9994\r\n', '2 03230  74.0376 359.8963 0031920 279.2356  80.5216 14.90226456653622\r\n')
# ('OAO 2\r\n', '1  3597U 68110A   17289.57515037 +.00000036 +00000-0 +15202-4 0  9993\r\n', '2  3597 034.9940 072.8760 0005088 137.8408 222.2674 14.45785496575035\r\n')
# ('ISIS 1\r\n', '1  3669U 69009A   17289.53831027 +.00000068 +00000-0 +34675-4 0  9997\r\n', '2  3669 088.4267 134.9112 1712256 151.6633 218.9420 11.29442039002329\r\n')
# ('SERT 2\r\n', '1  4327U 70009A   17289.34999977 -.00000034 +00000-0 +10907-4 0  9995\r\n', '2  4327 099.3073 016.7782 0005773 093.5068 316.1266 13.58468510363539\r\n')
# ('SL-3 R/B\r\n', '1  4814U 70113B   17289.58303268 +.00002558 +00000-0 +77912-4 0  9991\r\n', '2  4814 081.1426 245.2889 0026745 024.8947 335.3574 15.33230722553648\r\n')
# ('SL-3 R/B\r\n', '1 05118U 71028B   17289.76901336  .00000995  00000-0  52325-4 0  9999\r\n', '2 05118  81.2594  14.9589 0047272 221.2230 138.5425 15.13753450522603\r\n')
# ('ASTEX 1\r\n', '1 05560U 71089A   17289.44229537  .00000136  00000-0  36950-4 0  9991\r\n', '2 05560  92.7153 242.6467 0015226 337.6125  22.4413 14.47921044418677\r\n')
# ('SL-8 R/B\r\n', '1  5730U 71119B   17289.48492749 +.00001284 +00000-0 +85774-4 0  9998\r\n', '2  5730 073.8916 283.2274 0697690 140.6095 224.7991 14.02049430222705\r\n')
# ('COSMOS 482 DESCENT CRAFT\r\n', '1 06073U 72023E   17289.79883817  .00023287  49274-5  11357-3 0  9991\r\n', '2 06073  52.0640  66.4197 1519762 221.5468 125.9636 12.69758541376463\r\n')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-5f94f308f2a2> in <module>()
#       2 with open('visual.txt', 'r') as f:
#       3     for next_n_lines in izip(*[f] * 3):
# ----> 4         sleep(1)
#       5         print next_n_lines
#
# KeyboardInterrupt:

# %%
! List Satellites

# %%
from time import sleep
rw = raw_input("Name : ")
print rw
with open('visual.txt', 'r') as f:
    while True:
            name = f.readline()
            one = f.readline()
            two = f.readline()
            sleep(1)
            if name == rw:
                print "HERE :",name, one, two
                print name, one, two    
            if not one: break  # EOF
# Out:
# Name : OAO 2
# OAO 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-184-b83b29440038> in <module>()
#       7             one = f.readline()
#       8             two = f.readline()
# ----> 9             sleep(1)
#      10             if name == rw:
#      11                 print "HERE :",name, one, two
#
# KeyboardInterrupt:

# %%
# %%writefile SatInfo.py
from itertools import izip, islice
from time import sleep
def satinfo():
    search_string = raw_input("Load : ")
    with open('visual.txt', 'r') as infile, open('visual.tmp', 'w') as outfile:
        for line in infile:
            if search_string in line:
                outfile.writelines([line, next(infile), next(infile)])

    from time import sleep
    with open('visual.tmp', 'r') as f:
        while True:
                name = f.readline()
                one = f.readline()
                two = f.readline()
                sleep(1)
                return name, one, two    
                         
def prntlist():            
    from time import sleep
    with open('visual.txt', 'r') as f:
        while True:
            next_n_lines = list(islice(f, 3))
            if not next_n_lines:
                break
            sleep(.5)
            print next_n_lines[0],
        
def reuse():
    from time import sleep
    with open('visual.tmp', 'r') as f:
        while True:
                name = f.readline()
                one = f.readline()
                two = f.readline()
                sleep(1)
                #print name, one, two    
                f.close()
                return name, one, two
# Out:
# Overwriting SatInfo.py

# %%
# !rm SatInfo.pyc

# %%
import SatInfo
print SatInfo.satinfo()
# Out:
# Load :
# ('ATLAS CENTAUR 2 R/B\r\n', '1   694U 63047A   17289.27221401 +.00000825 +00000-0 +96824-4 0  9993\r\n', '2   694 030.3566 218.6620 0587343 002.0514 358.2331 14.02172662700105\r\n')

# %%
import SatInfo
SatInfo.prntlist()

# %%
import SatInfo
a,b,c = SatInfo.reuse()
print a,b,c
# Out:
# SERT 2
# 1  4327U 70009A   17289.34999977 -.00000034 +00000-0 +10907-4 0  9995
# 2  4327 099.3073 016.7782 0005773 093.5068 316.1266 13.58468510363539

# %%
from time import sleep
with open('ALL_TLE.TXT', 'r') as f:
    while True:
        next_n_lines = list(islice(f, 3))
        if not next_n_lines:
            break

        sleep(1)
        print next_n_lines[0],
# Out:
# VANGUARD 1
# VANGUARD 2
# VANGUARD R/B
# VANGUARD R/B
# VANGUARD 3
# EXPLORER 7
# TIROS 1
# TRANSIT 2A
# SOLRAD 1 (GREB)
# THOR ABLESTAR R/B
# DELTA 1 R/B
# ECHO 1 DEB (METAL OBJ)
# ECHO 1 DEB (METAL OBJ)
# COURIER 1B
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-189-edd77afde11a> in <module>()
#       6             break
#       7
# ----> 8         sleep(1)
#       9         print next_n_lines[0],
#
# KeyboardInterrupt:

# %%
from time import sleep
with open('visual.tmp', 'r') as f:
    while True:
            name = f.readline()
            one = f.readline()
            two = f.readline()
            sleep(1)
            print name, one, two    
            if not one: break  # EOF
# Out:
# THOR AGENA D R/B
# 1   733U 64002A   17289.57624160 +.00000064 +00000-0 +41421-4 0  9999
# 2   733 099.1233 121.2560 0033722 184.8081 175.2782 14.32291068799267

# %%
from time import sleep
with open('ALL_TLE.TXT', 'r') as f:
    lines = f.readlines()
    for line in lines:
        sleep(1)
        print line
# Out:
# VANGUARD 1
#
# 1     5U 58002B   17288.51066995 +.00000265 +00000-0 +31484-3 0  9993
#
# 2     5 034.2621 354.4712 1846789 281.0386 058.8921 10.84748461099264
#
# VANGUARD 2
#
# 1    11U 59001A   17289.90851244 +.00000408 +00000-0 +21220-3 0  9999
#
# 2    11 032.8654 113.7079 1467916 150.8108 218.3207 11.85473935159281
#
# VANGUARD R/B
#
# 1 00012U 59001B   17289.88953885  .00000054  00000-0  28612-4 0  9991
#
# 2 00012  32.8993 160.3562 1666098 352.6419   5.2288 11.44137848410896
#
# VANGUARD R/B
#
# 1    16U 58002A   17289.82861031 +.00000020 +00000-0 +55315-4 0  9993
#
# 2    16 034.2596 088.6742 2023092 088.4513 294.5258 10.48624953356517
#
# VANGUARD 3
#
# 1    20U 59007A   17289.68766689 +.00000296 +00000-0 +12303-3 0  9995
#
# 2    20 033.3430 054.1590 1665668 136.6335 237.8083 11.55448817117812
#
# EXPLORER 7
#
# 1 00022U 59009A   17290.18535108  .00000417  00000-0  55013-4 0  9997
#
# 2 00022  50.2851 350.6571 0141612 138.6565 222.5204 14.94320954 79591
#
# TIROS 1
#
# 1    29U 60002B   17289.86433656 -.00000049 +00000-0 +23789-4 0  9994
#
# 2    29 048.3794 227.4900 0024035 022.0075 338.1863 14.74200167074748
#
# TRANSIT 2A
#
# 1    45U 60007A   17289.85653926 -.00000031 +00000-0 +19260-4 0  9990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-188-f9bb1bfd3296> in <module>()
#       3     lines = f.readlines()
#       4     for line in lines:
# ----> 5         sleep(1)
#       6         print line
#
# KeyboardInterrupt:

# %%
from time import sleep
with open('visual.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        sleep(1)
        print line

# %%
# !ls *.txt
# Out:
# AllBooksOfEnoch_djvu.txt	 temp.txt
# ALLtextClean.txt		 testfile002.txt
# ALLtextnbCleaner.txt		 testfile.txt
# ALLtextnbClean.txt		 test.txt
# ALLtextnb.txt			 textwik.txt
# ALLtext.txt			 tokens2.txt
# ALLWIKI.txt			 tokens.txt
# astralGOOD.txt			 ToUse.txt
# astral.txt			 trumpstuff.txt
# astral.txtGOOD.txt		 usersNoBlank.txt
# Automate-the-Boring-Stuff.txt	 usersNoDups.txt
# bashhis.txt			 users.txt
# BookOfEnochGood2.txt		 Use.txt
# BookOfEnochGOOD.txt		 usewik.txt
# BookOfEnochpdf.txt		 virtual2.txt
# BooksOfEnoch.txt		 virtual.txt
# clean2.txt			 visual.txt
# cleanout.txt			 WebScrapingwithPython.txt
# cleanstream.txt			 Wiki_Abiogenesis.txt
# clean.txt			 Wiki_Analemma.txt
# cleanwords.txt			 Wiki_AncientEgypt.txt
# e_101.txt			 Wiki_ancientmanuscripts.txt
# editTest.txt			 Wiki_assemblylanguage.txt
# Effective_Python.txt		 Wiki_Asteroidbelt.txt
# elonmusk.txt			 Wiki_astrologicalConstellation.txt
# ephrem_manual_text.txt		 Wiki_Astrology.txt
# exp001.txt			 Wiki_Biblicalmanuscript.txt
# file.txt			 Wiki_BookofEnoch.txt
# grimm.txt			 Wiki_C++compiler.txt
# hardread.txt			 Wiki_computerdata.txt
# hashonly2.txt			 Wiki_computerprogramming.txt
# hashonlyNoBlank2.txt		 Wiki_Cradleofcivilization.txt
# hashonlyNoBlankNoDupsNoHash.txt  Wiki_Darwinism.txt
# hashonlyNoBlankNoDups.txt	 Wiki_DonaldTrump.txt
# hashonlyNoBlank.txt		 Wiki_Enoch(ancestorofNoah).txt
# hashonlyS.txt			 Wiki_enochNephilim.txt
# hashonly.txt			 Wiki_Enoch.txt
# hashtag-nouns.txt		 Wiki_Extraterrestriallife.txt
# hashtag.txt			 Wiki_FederalReserveSystem.txt
# hekel.txt			 Wiki_firstBookofEnoch.txt
# hek.txt				 Wiki_GeographyofEthiopia.txt
# history.txt			 Wiki_HistoryofEarth.txt
# importpython.txt		 Wiki_Human–computerinteraction.txt
# IPythonInteractiveComputing.txt  Wiki_Humancomputerinteraction.txt
# junque.txt			 Wiki_Illuminati:NewWorldOrder.txt
# links.txt			 Wiki_InternationalMonetaryFund.txt
# MarkovifyWikipedia.txt		 Wiki_javaprogramminglanguage.txt
# my_utf8_file.txt		 Wiki_javaprogramming.txt
# newtest.txt			 Wiki_Javavirtualmachine.txt
# nodupsnohash2.txt		 Wiki_KnightsTemplar.txt
# nodupsnohash.txt		 Wiki_linuxoperatingsystem.txt
# nodupStreaming.txt		 wikilist2.txt
# NShashonlyS.txt			 wikilist.txt
# output2.txt			 Wiki_MachineLearning.txt
# OutputStreaming.txt		 Wiki_memoryconformity.txt
# output.txt			 Wiki_memoryresearch.txt
# pdf.txt				 Wiki_MySQL.txt
# phrases2.txt			 Wiki_NaturalLanguageToolkit.txt
# phrases3.txt			 Wiki_NewWorldOrderconspiracytheory.txt
# phrases.txt			 Wiki_opensource.txt
# pythonbot__.txt			 Wiki_Orbitalelements.txt
# Python_Cookbook_3rd_Edition.txt  Wiki_OriginofwateronEarth.txt
# PythonRR.txt			 Wiki_programmingcode.txt
# realDonaldTrump.txt		 Wiki_programmingdebug.txt
# realwords.txt			 Wiki_Prokaryote.txt
# sample.txt			 Wiki_Python(programminglanguage).txt
# savE_patern.txt			 Wiki_Pythonprogramminglanguage.txt
# savE_sentence.txt		 Wiki_quantummechanics.txt
# savE.txt			 Wiki_SecondBookofEnoch.txt
# SavE.txt			 Wiki_SolarSystem.txt
# snippetsTX.txt			 Wiki_Sourcecode.txt
# stations.txt			 Wiki_SQLite.txt
# super.txt			 Wiki_Sunpath.txt
# symmetrymagexp.txt		 Wiki_Ubuntu(operatingsystem).txt
# symmetrymag.txt			 Wiki_Ubuntu(philosophy).txt
# TEDTalks.txt			 Wiki_UnitedStates.txt
# temp2.txt			 Wiki_war.txt
# tempfile2.txt			 Wiki_WebScraping.txt
# tempfile.txt			 Wiki_worldeconomy.txt

# %%
# based on 'grouper()' example from the python 2 itertools documentation
from itertools import izip
def partition(lines, n):
    iters = [iter(lines)] * n
    return izip(*iters)

# %%
import skyfield
help(skyfield)
# Out:
# Help on package skyfield:
#
# NAME
#     skyfield - Elegant astronomy for Python
#
# FILE
#     /home/jack/Desktop/text_stuff/skyfield/__init__.pyc
#
# DESCRIPTION
#     Most users will use Skyfield by importing ``skyfield.api`` and using the
#     functions and classes there.  See the ``documentation`` directory inside
#     the source code, as well as the http://rhodesmill.org/skyfield/ site!
#
# PACKAGE CONTENTS
#
#
# SUBMODULES
#     constants
#     errors
#
# DATA
#     VERSION = (1, 0)
#     __version__ = '1.0'
#
# VERSION
#     1.0

# %%
import skyfield.api
help(skyfield.api)
# Out:
# Help on module skyfield.api in skyfield:
#
# NAME
#     skyfield.api - Top-level objects and functions offered by the Skyfield library.
#
# FILE
#     /usr/local/lib/python2.7/dist-packages/skyfield/api.py
#
# DESCRIPTION
#     Importing this library is not always the fastest way to use a Skyfield
#     feature, since importing this module involves importing almost the
#     entirety of Skyfield and its dependencies, but is the most convenient
#     way for most users to use Skyfield's main features.
#
# CLASSES
#     __builtin__.object
#         skyfield.iokit.Loader
#         skyfield.starlib.Star
#         skyfield.timelib.Time
#         skyfield.timelib.Timescale
#         skyfield.units.Angle
#     datetime.date(__builtin__.object)
#         datetime.datetime
#     skyfield.vectorlib.VectorFunction(__builtin__.object)
#         skyfield.sgp4lib.EarthSatellite
#         skyfield.toposlib.Topos
#
#     class Angle(__builtin__.object)
#      |  Methods defined here:
#      |
#      |  __getattr__(self, name)
#      |
#      |  __init__(self, angle=None, radians=None, degrees=None, hours=None, preference=None, signed=False)
#      |
#      |  __repr__(self)
#      |
#      |  __str__(self)
#      |
#      |  dms(self, warn=True)
#      |      Convert to a tuple (degrees, minutes, seconds).
#      |
#      |      All three quantities will have the same sign as the angle itself.
#      |
#      |  dstr(self, places=1, warn=True)
#      |      Convert to a string like ``181deg 52' 30.0"``.
#      |
#      |  hms(self, warn=True)
#      |      Convert to a tuple (hours, minutes, seconds).
#      |
#      |      All three quantities will have the same sign as the angle itself.
#      |
#      |  hstr(self, places=2, warn=True)
#      |      Convert to a string like ``12h 07m 30.00s``.
#      |
#      |  signed_dms(self, warn=True)
#      |      Convert to a tuple (degrees, hours, minutes, seconds).
#      |
#      |      The ``sign`` will be either +1 or -1, and the other quantities
#      |      will all be positive.
#      |
#      |  signed_hms(self, warn=True)
#      |      Convert to a tuple (sign, hours, minutes, seconds).
#      |
#      |      The ``sign`` will be either +1 or -1, and the other quantities
#      |      will all be positive.
#      |
#      |  to(self, unit)
#      |      Convert this angle to the given AstroPy unit.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class EarthSatellite(skyfield.vectorlib.VectorFunction)
#      |  An Earth satellite loaded from a TLE file and propagated with SGP4.
#      |
#      |  An earth satellite object is a Skyfield vector function, so you will
#      |  call its :meth:`~skyfield.vectorlib.VectorSum.at()` method to have
#      |  it generate its position in the sky, or use addition and subtraction
#      |  to combine it with other vectors.
#      |
#      |  Method resolution order:
#      |      EarthSatellite
#      |      skyfield.vectorlib.VectorFunction
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, line1, line2, name=None)
#      |
#      |  __repr__(self)
#      |
#      |  __str__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  center = 399
#      |
#      |  center_name = '399 EARTH'
#      |
#      |  timescale = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  __add__(self, other)
#      |
#      |  __sub__(self, other)
#      |
#      |  at(self, jd=None, utc=None, tai=None, tt=None, tdb=None)
#      |      At time ``t``, compute the target's position relative to the center.
#      |
#      |      If ``t`` is an array of times, then the returned position object
#      |      will specify as many positions as there were times.  The kind of
#      |      position returned depends on the value of the ``center``
#      |      attribute:
#      |
#      |      * Solar System Barycenter: :class:`~skyfield.positionlib.Barycentric`
#      |      * Center of the Earth: :class:`~skyfield.positionlib.Geocentric`
#      |      * Difference: :class:`~skyfield.positionlib.Geometric`
#      |      * Anything else: :class:`~skyfield.positionlib.ICRF`
#      |
#      |  geometry_of(self, other)
#      |
#      |  satellite(self, text)
#      |
#      |  topos(self, latitude=None, longitude=None, latitude_degrees=None, longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  ephemeris = None
#
#     class Loader(__builtin__.object)
#      |  A tool for downloading and opening astronomical data files.
#      |
#      |  A default `Loader` that saves data files to the current working
#      |  directory can be imported directly from the Skyfield API::
#      |
#      |      from skyfield.api import load
#      |
#      |  But users can also create a `Loader` of their own, if there is
#      |  another directory they want data files saved to, or if they want to
#      |  specify different options.  The directory is created automatically
#      |  if it does not yet exist::
#      |
#      |      from skyfield.api import Loader
#      |      load = Loader('~/skyfield-data')
#      |
#      |  The options are:
#      |
#      |  ``verbose``
#      |    If set to ``False``, then the loader will not print a progress bar
#      |    to the screen each time it downloads a file.  (If the standard
#      |    output is not a TTY, then no progress bar is printed in any case.)
#      |
#      |  ``expire``
#      |    If set to ``False``, then Skyfield will always use an existing
#      |    file on disk, instead of expiring files that are out of date and
#      |    replacing them with newly downloaded copies.
#      |
#      |  Once a `Loader` is created, it can be called like a function to
#      |  open, or else to download and open, a file whose name it recognizes::
#      |
#      |      planets = load('de405.bsp')
#      |
#      |  Each loader also supports an attribute and a few methods.
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, filename)
#      |      Open the given file, downloading it first if necessary.
#      |
#      |  __init__(self, directory, verbose=True, expire=True)
#      |
#      |  open(self, url, mode='rb', reload=False)
#      |      Open a file, downloading it first if it does not yet exist.
#      |
#      |      Unlike when you call a loader directly like ``my_loader()``,
#      |      this ``my_loader.open()`` method does not attempt to parse or
#      |      interpret the resulting file.  Instead, it simply returns an
#      |      open file object without trying to interpret the contents.
#      |
#      |  path_to(self, filename)
#      |      Return the path to ``filename`` in this loader's directory.
#      |
#      |  timescale(self, delta_t=None)
#      |      Open or download three time scale files, returning a `Timescale`.
#      |
#      |      This method is how most Skyfield users build a `Timescale`
#      |      object, which is necessary for building specific `Time` objects
#      |      that name specific moments.
#      |
#      |      This will open or download the three files that Skyfield needs
#      |      to measure time.  UT1 is tabulated by the United States Naval
#      |      Observatory files ``deltat.data`` and ``deltat.preds``, while
#      |      UTC is defined by ``Leap_Second.dat`` from the International
#      |      Earth Rotation Service.
#      |
#      |  tle(self, url, reload=False)
#      |      Load and parse a satellite TLE file.
#      |
#      |      Given a URL or a local path, this loads a file of three-line
#      |      records in the common Celestrak file format, where each first
#      |      line gives the name of a satellite and the following two lines
#      |      are the TLE orbital elements.
#      |
#      |      Returns a Python dictionary whose keys are satellite names and
#      |      values are :class:`~skyfield.sgp4lib.EarthSatellite` objects.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  log
#
#     class Star(__builtin__.object)
#      |  The position in the sky of a star or other fixed object.
#      |
#      |  Each `Star` object specifies the position of a distant object.  You
#      |  should provide as a right ascension and declination relative to the
#      |  ICRS (the recent improvement upon J2000).  You can specify the
#      |  coordinates using either floating point hours and degrees, or tuples
#      |  that specify hour and degree fractions as minutes and seconds, or
#      |  even full Skyfield :class:`~skyfield.units.Angle` objects (which can
#      |  themselves be initialized using hours, degrees, or radians):
#      |
#      |  >>> barnard = Star(ra_hours=17.963471675, dec_degrees=4.69339088889)
#      |  >>> barnard = Star(ra_hours=(17, 57, 48.49), dec_degrees=(4, 41, 36.20))
#      |  >>> barnard = Star(ra=Angle(hours=17.963471675),
#      |  ...                dec=Angle(degrees=4.69339088889))
#      |
#      |  For objects whose proper motion across the sky has been detected,
#      |  you can supply velocities in milliarcseconds (mas) per year, and
#      |  even a parallax and radial velocity if those are known:
#      |
#      |  >>> barnard = Star(ra_hours=(17, 57, 48.49803),
#      |  ...                dec_degrees=(4, 41, 36.2072),
#      |  ...                ra_mas_per_year=-798.71,
#      |  ...                dec_mas_per_year=+10337.77,
#      |  ...                parallax_mas=545.4,
#      |  ...                radial_km_per_s=-110.6)
#      |
#      |  See `stars` for a guide to using a `Star` once you have created it.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, ra=None, dec=None, ra_hours=None, dec_degrees=None, ra_mas_per_year=0.0, dec_mas_per_year=0.0, parallax_mas=0.0, radial_km_per_s=0.0, names=())
#      |
#      |  __repr__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  au_km = 149597870.7
#
#     class Time(__builtin__.object)
#      |  A single moment in history, or an array of several moments.
#      |
#      |  You will typically not instantiate this class yourself, but will
#      |  rely on a Skyfield ``Timescale`` object to build dates for you:
#      |
#      |  >>> ts = load.timescale()
#      |  >>> print(ts.utc(1980, 1, 1))
#      |  <Time tt=2444239.500592>
#      |
#      |  Times are represented internally by floating point Julian dates, but
#      |  can be converted to other formats by using the many methods that
#      |  time objects make available.
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other_time)
#      |
#      |  __getattr__(self, name)
#      |
#      |  __getitem__(self, index)
#      |
#      |  __init__(self, ts, tt)
#      |
#      |  __len__(self)
#      |
#      |  __repr__(self)
#      |
#      |  __sub__(self, other_time)
#      |
#      |  astimezone(self, tz)
#      |      Convert to a Python ``datetime`` in a ``pytz`` provided timezone.
#      |
#      |      Convert this time to a ``datetime`` in the timezone ``tz``,
#      |      which should be one of the timezones provided by the third-party
#      |      ``pytz`` package.  If this time is an array, then an array of
#      |      datetimes is returned instead of a single value.
#      |
#      |  astimezone_and_leap_second(self, tz)
#      |      Convert to a Python ``datetime`` and leap second in a timezone.
#      |
#      |      Convert this time to a Python ``datetime`` and a leap second::
#      |
#      |          dt, leap_second = t.astimezone_and_leap_second(tz)
#      |
#      |      The argument ``tz`` should be a timezone from the third-party
#      |      ``pytz`` package, which must be installed separately.  The date
#      |      and time returned will be for that time zone.
#      |
#      |      The leap second value is provided because a Python ``datetime``
#      |      can only number seconds ``0`` through ``59``, but leap seconds
#      |      have a designation of at least ``60``.  The leap second return
#      |      value will normally be ``0``, but will instead be ``1`` if the
#      |      date and time are a UTC leap second.  Add the leap second value
#      |      to the ``second`` field of the ``datetime`` to learn the real
#      |      name of the second.
#      |
#      |      If this time is an array, then an array of ``datetime`` objects
#      |      and an array of leap second integers is returned, instead of a
#      |      single value each.
#      |
#      |  tai_calendar(self)
#      |      Return TAI as a tuple (year, month, day, hour, minute, second).
#      |
#      |  toordinal(self)
#      |      Return the proleptic Gregorian ordinal of the UTC date.
#      |
#      |      This method makes Skyfield `Time` objects compatible with Python
#      |      `datetime`_ objects, which also provide a ``toordinal()``
#      |      method.  Thanks to this method, a `Time` can often be used
#      |      directly as a coordinate for a plot.
#      |
#      |  tt_calendar(self)
#      |      Return TT as a tuple (year, month, day, hour, minute, second).
#      |
#      |  utc_datetime(self)
#      |      Convert to a Python ``datetime`` in UTC.
#      |
#      |      If the third-party `pytz`_ package is available, then its
#      |      ``utc`` timezone will be used as the timezone of the returned
#      |      `datetime`_.  Otherwise, an equivalent Skyfield ``utc`` timezone
#      |      object is used.  If this time is an array, then a sequence of
#      |      datetimes is returned instead of a single value.
#      |
#      |  utc_datetime_and_leap_second(self)
#      |      Convert to a Python ``datetime`` in UTC, plus a leap second value.
#      |
#      |      Convert this time to a `datetime`_ object and a leap second::
#      |
#      |          dt, leap_second = t.utc_datetime_and_leap_second()
#      |
#      |      If the third-party `pytz`_ package is available, then its
#      |      ``utc`` timezone will be used as the timezone of the return
#      |      value.  Otherwise, Skyfield uses its own ``utc`` timezone.
#      |
#      |      The leap second value is provided because a Python ``datetime``
#      |      can only number seconds ``0`` through ``59``, but leap seconds
#      |      have a designation of at least ``60``.  The leap second return
#      |      value will normally be ``0``, but will instead be ``1`` if the
#      |      date and time are a UTC leap second.  Add the leap second value
#      |      to the ``second`` field of the ``datetime`` to learn the real
#      |      name of the second.
#      |
#      |      If this time is an array, then an array of ``datetime`` objects
#      |      and an array of leap second integers is returned, instead of a
#      |      single value each.
#      |
#      |  utc_iso(self, places=0)
#      |      Convert to an ISO 8601 string like ``2014-01-18T01:35:38Z`` in UTC.
#      |
#      |      If this time is an array of dates, then a sequence of strings is
#      |      returned instead of a single string.
#      |
#      |  utc_jpl(self)
#      |      Convert to an ``A.D. 2014-Jan-18 01:35:37.5000 UT`` string.
#      |
#      |      Returns a string for this date and time in UTC, in the format
#      |      used by the JPL HORIZONS system.  If this time is an array of
#      |      dates, then a sequence of strings is returned instead of a
#      |      single string.
#      |
#      |  utc_strftime(self, format)
#      |      Format the UTC time using a Python date formatting string.
#      |
#      |      This internally calls the Python ``strftime()`` routine from the
#      |      Standard Library ``time()`` module, for which you can find a
#      |      quick reference at ``http://strftime.org/``.  If this object is
#      |      an array of times, then a sequence of strings is returned
#      |      instead of a single string.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  eps_correction = 0.0
#      |
#      |  psi_correction = 0.0
#
#     class Timescale(__builtin__.object)
#      |  The data necessary to express dates in different timescales.
#      |
#      |  Whenever you want to express a date in Skyfield, you need a
#      |  `Timescale` that can translate between several different systems for
#      |  expressing time.  You will usually create a single `Timescale` at
#      |  the beginning of your program, and use it every time you want to
#      |  generate a specific `Time`:
#      |
#      |  >>> from skyfield.api import load
#      |  >>> ts = load.timescale()
#      |  >>> t = ts.utc(1980, 3, 1, 9, 30)
#      |  >>> t
#      |  <Time tt=2444299.896426>
#      |
#      |  Loading a timescale downloads tables from the United States Naval
#      |  Observatory and the International Earth Rotation Service.  These
#      |  files go out of date, and Skyfield will fetch updated copies once
#      |  your copy of the files are too old.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, delta_t_recent, leap_dates, leap_offsets)
#      |
#      |  from_astropy(self, t)
#      |      Return a Skyfield time corresponding to the AstroPy time `t`.
#      |
#      |  now(self)
#      |      Return the current date and time as a `Time` object.
#      |
#      |      For the return value to be correct, your operating system time
#      |      and timezone settings must be set so that the Python Standard
#      |      Library constructor ``datetime.datetime.utcnow()`` returns a
#      |      correct UTC date and time.
#      |
#      |  tai(self, year=None, month=1, day=1, hour=0, minute=0, second=0.0, jd=None)
#      |      Return the Time corresponding to a specific moment in TAI.
#      |
#      |      You can specify International Atomic Time (TAI) by providing
#      |      either a proleptic Gregorian calendar date or a raw Julian Date
#      |      float.  The following two method calls are equivalent::
#      |
#      |          timescale.tai(2014, 1, 18, 1, 35, 37.5)
#      |          timescale.tai(jd=2456675.56640625)
#      |
#      |  tdb(self, year=None, month=1, day=1, hour=0, minute=0, second=0.0, jd=None)
#      |      Return the Time corresponding to a specific moment in TDB.
#      |
#      |      You can supply the Barycentric Dynamical Time (TDB) by providing
#      |      either a proleptic Gregorian calendar date or a raw Julian Date
#      |      float.  The following two method calls are equivalent::
#      |
#      |          timescale.tdb(2014, 1, 18, 1, 35, 37.5)
#      |          timescale.tdb(jd=2456675.56640625)
#      |
#      |  tt(self, year=None, month=1, day=1, hour=0, minute=0, second=0.0, jd=None)
#      |      Return the Time corresponding to a specific moment in TT.
#      |
#      |      You can supply the Terrestrial Time (TT) by providing either a
#      |      proleptic Gregorian calendar date or a raw Julian Date float.
#      |      The following two method calls are equivalent::
#      |
#      |          timescale.tt(2014, 1, 18, 1, 35, 37.5)
#      |          timescale.tt(jd=2456675.56640625)
#      |
#      |  utc(self, year, month=1, day=1, hour=0, minute=0, second=0.0)
#      |      Return the Time corresponding to a specific moment in UTC.
#      |
#      |      You can either specify the date as separate components, or
#      |      provide a time zone aware Python datetime.  The following two
#      |      calls are equivalent (the ``utc`` time zone object can be
#      |      imported from the ``skyfield.api`` module, or from ``pytz`` if
#      |      you have it)::
#      |
#      |          ts.utc(2014, 1, 18, 1, 35, 37.5)
#      |          ts.utc(datetime(2014, 1, 18, 1, 35, 37, 500000, tzinfo=utc))
#      |
#      |      Note that only by passing the components separately can you
#      |      specify a leap second, because a Python datetime will not allow
#      |      the value 60 in its seconds field.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class Topos(skyfield.vectorlib.VectorFunction)
#      |  A vector function that knows the position of a place on Earth.
#      |
#      |  You can specify latitude and longitude by either either building
#      |  Skyfield :class:`~skyfield.units.Angle` objects yourself and
#      |  supplying them to the constructor as its first two arguments, or by
#      |  providing floating point numbers to the alternate keyword arguments
#      |  ``latitude_degrees`` and ``longitude_degrees``.
#      |
#      |  The ``center`` of a topos object is always ``399``, the center of
#      |  gravity of the Earth, so every call to the ``at(t)`` method of a
#      |  topos object returns a :class:`~skyfield.positionlib.Geocentric`
#      |  position.
#      |
#      |  Method resolution order:
#      |      Topos
#      |      skyfield.vectorlib.VectorFunction
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, latitude=None, longitude=None, latitude_degrees=None, longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0)
#      |
#      |  __repr__(self)
#      |
#      |  __str__(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  center = 399
#      |
#      |  center_name = '399 EARTH'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  __add__(self, other)
#      |
#      |  __sub__(self, other)
#      |
#      |  at(self, jd=None, utc=None, tai=None, tt=None, tdb=None)
#      |      At time ``t``, compute the target's position relative to the center.
#      |
#      |      If ``t`` is an array of times, then the returned position object
#      |      will specify as many positions as there were times.  The kind of
#      |      position returned depends on the value of the ``center``
#      |      attribute:
#      |
#      |      * Solar System Barycenter: :class:`~skyfield.positionlib.Barycentric`
#      |      * Center of the Earth: :class:`~skyfield.positionlib.Geocentric`
#      |      * Difference: :class:`~skyfield.positionlib.Geometric`
#      |      * Anything else: :class:`~skyfield.positionlib.ICRF`
#      |
#      |  geometry_of(self, other)
#      |
#      |  satellite(self, text)
#      |
#      |  topos(self, latitude=None, longitude=None, latitude_degrees=None, longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from skyfield.vectorlib.VectorFunction:
#      |
#      |  ephemeris = None
#
#     class datetime(date)
#      |  datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#      |
#      |  The year, month and day arguments are required. tzinfo may be None, or an
#      |  instance of a tzinfo subclass. The remaining arguments may be ints or longs.
#      |
#      |  Method resolution order:
#      |      datetime
#      |      date
#      |      __builtin__.object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(...)
#      |      x.__add__(y) <==> x+y
#      |
#      |  __eq__(...)
#      |      x.__eq__(y) <==> x==y
#      |
#      |  __ge__(...)
#      |      x.__ge__(y) <==> x>=y
#      |
#      |  __getattribute__(...)
#      |      x.__getattribute__('name') <==> x.name
#      |
#      |  __gt__(...)
#      |      x.__gt__(y) <==> x>y
#      |
#      |  __hash__(...)
#      |      x.__hash__() <==> hash(x)
#      |
#      |  __le__(...)
#      |      x.__le__(y) <==> x<=y
#      |
#      |  __lt__(...)
#      |      x.__lt__(y) <==> x<y
#      |
#      |  __ne__(...)
#      |      x.__ne__(y) <==> x!=y
#      |
#      |  __radd__(...)
#      |      x.__radd__(y) <==> y+x
#      |
#      |  __reduce__(...)
#      |      __reduce__() -> (cls, state)
#      |
#      |  __repr__(...)
#      |      x.__repr__() <==> repr(x)
#      |
#      |  __rsub__(...)
#      |      x.__rsub__(y) <==> y-x
#      |
#      |  __str__(...)
#      |      x.__str__() <==> str(x)
#      |
#      |  __sub__(...)
#      |      x.__sub__(y) <==> x-y
#      |
#      |  astimezone(...)
#      |      tz -> convert to local time in new timezone tz
#      |
#      |  combine(...)
#      |      date, time -> datetime with same date and time fields
#      |
#      |  ctime(...)
#      |      Return ctime() style string.
#      |
#      |  date(...)
#      |      Return date object with same year, month and day.
#      |
#      |  dst(...)
#      |      Return self.tzinfo.dst(self).
#      |
#      |  fromtimestamp(...)
#      |      timestamp[, tz] -> tz's local time from POSIX timestamp.
#      |
#      |  isoformat(...)
#      |      [sep] -> string in ISO 8601 format, YYYY-MM-DDTHH:MM:SS[.mmmmmm][+HH:MM].
#      |
#      |      sep is used to separate the year from the time, and defaults to 'T'.
#      |
#      |  now(...)
#      |      [tz] -> new datetime with tz's local day and time.
#      |
#      |  replace(...)
#      |      Return datetime with new specified fields.
#      |
#      |  strptime(...)
#      |      string, format -> new datetime parsed from a string (like time.strptime()).
#      |
#      |  time(...)
#      |      Return time object with same time but with tzinfo=None.
#      |
#      |  timetuple(...)
#      |      Return time tuple, compatible with time.localtime().
#      |
#      |  timetz(...)
#      |      Return time object with same time and tzinfo.
#      |
#      |  tzname(...)
#      |      Return self.tzinfo.tzname(self).
#      |
#      |  utcfromtimestamp(...)
#      |      timestamp -> UTC datetime from a POSIX timestamp (like time.time()).
#      |
#      |  utcnow(...)
#      |      Return a new datetime representing UTC day and time.
#      |
#      |  utcoffset(...)
#      |      Return self.tzinfo.utcoffset(self).
#      |
#      |  utctimetuple(...)
#      |      Return UTC time tuple, compatible with time.localtime().
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  hour
#      |
#      |  microsecond
#      |
#      |  minute
#      |
#      |  second
#      |
#      |  tzinfo
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of type object>
#      |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#      |
#      |  max = datetime.datetime(9999, 12, 31, 23, 59, 59, 999999)
#      |
#      |  min = datetime.datetime(1, 1, 1, 0, 0)
#      |
#      |  resolution = datetime.timedelta(0, 0, 1)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from date:
#      |
#      |  __format__(...)
#      |      Formats self with strftime.
#      |
#      |  fromordinal(...)
#      |      int -> date corresponding to a proleptic Gregorian ordinal.
#      |
#      |  isocalendar(...)
#      |      Return a 3-tuple containing ISO year, week number, and weekday.
#      |
#      |  isoweekday(...)
#      |      Return the day of the week represented by the date.
#      |      Monday == 1 ... Sunday == 7
#      |
#      |  strftime(...)
#      |      format -> strftime() style string.
#      |
#      |  today(...)
#      |      Current date or datetime:  same as self.__class__.fromtimestamp(time.time()).
#      |
#      |  toordinal(...)
#      |      Return proleptic Gregorian ordinal.  January 1 of year 1 is day 1.
#      |
#      |  weekday(...)
#      |      Return the day of the week represented by the date.
#      |      Monday == 0 ... Sunday == 6
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from date:
#      |
#      |  day
#      |
#      |  month
#      |
#      |  year
#
# FUNCTIONS
#     NamedStar(name)
#         Return a Star instance given the name of a named star
#
# DATA
#     T0 = 2451545.0
#     __all__ = ['Angle', 'Loader', 'NamedStar', 'Star', 'EarthSatellite', '...
#     load = <skyfield.iokit.Loader object>
#     pi = 3.141592653589793
#     tau = 6.283185307179586
#     utc = <UTC>

# %%
from skyfield.api import JulianDate, earth, utc, EarthSatellite
help(EarthSatellite)
# Out:
# Help on class EarthSatellite in module skyfield.sgp4lib:
#
# class EarthSatellite(skyfield.vectorlib.VectorFunction)
#  |  An Earth satellite loaded from a TLE file and propagated with SGP4.
#  |
#  |  An earth satellite object is a Skyfield vector function, so you will
#  |  call its :meth:`~skyfield.vectorlib.VectorSum.at()` method to have
#  |  it generate its position in the sky, or use addition and subtraction
#  |  to combine it with other vectors.
#  |
#  |  Method resolution order:
#  |      EarthSatellite
#  |      skyfield.vectorlib.VectorFunction
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, line1, line2, name=None)
#  |
#  |  __repr__(self)
#  |
#  |  __str__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  center = 399
#  |
#  |  center_name = '399 EARTH'
#  |
#  |  timescale = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  __add__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  at(self, jd=None, utc=None, tai=None, tt=None, tdb=None)
#  |      At time ``t``, compute the target's position relative to the center.
#  |
#  |      If ``t`` is an array of times, then the returned position object
#  |      will specify as many positions as there were times.  The kind of
#  |      position returned depends on the value of the ``center``
#  |      attribute:
#  |
#  |      * Solar System Barycenter: :class:`~skyfield.positionlib.Barycentric`
#  |      * Center of the Earth: :class:`~skyfield.positionlib.Geocentric`
#  |      * Difference: :class:`~skyfield.positionlib.Geometric`
#  |      * Anything else: :class:`~skyfield.positionlib.ICRF`
#  |
#  |  geometry_of(self, other)
#  |
#  |  satellite(self, text)
#  |
#  |  topos(self, latitude=None, longitude=None, latitude_degrees=None, longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  ephemeris = None

# %%
import numpy as np
import matplotlib.pyplot as plt

from skyfield.api import load

planets = load('de421.bsp')

earth   = planets['earth']
mars    = planets['mars']

year_zero = 2010
days = np.linspace(1, 3650, 10000)
years = year_zero + days / 365.2564
ts = load.timescale()
t = ts.utc(year_zero, 1, days)

# thanks to @barrycarter's comment, do it the right way!
eclat, eclon, ecd = earth.at(t).observe(mars).ecliptic_latlon()

eclondgs      = (180./np.pi) * eclon.radians
eclondel      = eclondgs[1:] - eclondgs[:-1]

eclondel[eclondel < -300] += 360. # this is a fudge for now
eclondel[eclondel > +300] -= 360. # this is a fudge for now

prograde   = eclondel > 0.

eclon_prograde   = eclondgs.copy()[:-1]
eclon_retrograde = eclondgs.copy()[:-1]

eclon_prograde[-prograde]  = np.nan
eclon_retrograde[prograde] = np.nan

plt.figure()
plt.plot(years[:-1], eclon_prograde,   '-g', linewidth=1)
plt.plot(years[:-1], eclon_retrograde, '-r', linewidth=3)
plt.ylim(0, 360)
plt.title('Mars Ecliptic longitude (degrees) AD 2010.0 to 2020.0',
          fontsize=16)
plt.show()
# Out:
# [#################################] 100% de421.bsp
# [#################################] 100% deltat.data
# [#################################] 100% deltat.preds
# [#################################] 100% Leap_Second.dat
# /home/jack/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:31: DeprecationWarning: numpy boolean negative, the `-` operator, is deprecated, use the `~` operator or the logical_not function instead.

# %%
from skyfield.api import JulianDate, earth, utc, EarthSatellite

tle = """
GOCE                    
1 34602U 09013A   13314.96046236  .14220718  20669-5  50412-4 0   930
2 34602 096.5717 344.5256 0009826 296.2811 064.0942 16.58673376272979
"""
print x,y =tle[0:]

# %%
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()

sat = EarthSatellite(b, c, a)
print(sat.epoch.utc_jpl())
# Out:
# A.D. 2017-Oct-16 08:23:59.9801 UT

# %%
from skyfield.api import JulianDate, earth, utc
from skyfield.api import EarthSatellite

a = '1 34602U 09013A   13314.96046236  .14220718  20669-5  50412-4 0   930'
b = '2 34602 096.5717 344.5256 0009826 296.2811 064.0942 16.58673376272979'
c = 'GOCE' 

sat = EarthSatellite(a,b,c)
print(sat.epoch.utc_jpl())
# Out:
# A.D. 2013-Nov-10 23:03:03.9479 UT

# %%
from skyfield.api import JulianDate, earth, utc
from skyfield.api import EarthSatellite
from skyfield.api import load
help(sat)
# Out:
# Help on EarthSatellite in module skyfield.sgp4lib object:
#
# class EarthSatellite(skyfield.vectorlib.VectorFunction)
#  |  An Earth satellite loaded from a TLE file and propagated with SGP4.
#  |
#  |  An earth satellite object is a Skyfield vector function, so you will
#  |  call its :meth:`~skyfield.vectorlib.VectorSum.at()` method to have
#  |  it generate its position in the sky, or use addition and subtraction
#  |  to combine it with other vectors.
#  |
#  |  Method resolution order:
#  |      EarthSatellite
#  |      skyfield.vectorlib.VectorFunction
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, line1, line2, name=None)
#  |
#  |  __repr__(self)
#  |
#  |  __str__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  center = 399
#  |
#  |  center_name = '399 EARTH'
#  |
#  |  timescale = <skyfield.timelib.Timescale object>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  __add__(self, other)
#  |
#  |  __sub__(self, other)
#  |
#  |  at(self, jd=None, utc=None, tai=None, tt=None, tdb=None)
#  |      At time ``t``, compute the target's position relative to the center.
#  |
#  |      If ``t`` is an array of times, then the returned position object
#  |      will specify as many positions as there were times.  The kind of
#  |      position returned depends on the value of the ``center``
#  |      attribute:
#  |
#  |      * Solar System Barycenter: :class:`~skyfield.positionlib.Barycentric`
#  |      * Center of the Earth: :class:`~skyfield.positionlib.Geocentric`
#  |      * Difference: :class:`~skyfield.positionlib.Geometric`
#  |      * Anything else: :class:`~skyfield.positionlib.ICRF`
#  |
#  |  geometry_of(self, other)
#  |
#  |  satellite(self, text)
#  |
#  |  topos(self, latitude=None, longitude=None, latitude_degrees=None, longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from skyfield.vectorlib.VectorFunction:
#  |
#  |  ephemeris = None

# %%
from skyfield.api import load
ts = load.timescale()
reentry = ts.utc(1980, 4, 20)       # the new way
t = ts.tt(jd=2444349.500592)  # jd is also supported for tai, tt, tdb



x= 2,6,4,5,7,8,9,5,45
y= 12,26,4,15,7,18,9,15,45

plot(x, y)

#reentry = JulianDate(utc=(2013, 11, 11, 0, 16))

for j, label in [(sat.epoch, 'Epoch of TLE data'),
                 (reentry, 'Actual moment of re-entry')]:
    px = j.toordinal()
    py = sat.gcrs(j).distance().km - earth.radius.km
    plot(px, py, 'ro')
    text(px, py + 10, label)

xaxis = axes().xaxis
xaxis.grid(True)
xaxis.set_major_locator(HourLocator([0]))
xaxis.set_minor_locator(HourLocator([0, 12]))
xaxis.set_major_formatter(DateFormatter('\n%a %d'))
xaxis.set_minor_formatter(DateFormatter('%Hh'))

yaxis = axes().yaxis
yaxis.grid(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-222-f7ff8c061d53> in <module>()
#      16                  (reentry, 'Actual moment of re-entry')]:
#      17     px = j.toordinal()
# ---> 18     py = sat.gcrs(j).distance().km - earth.radius.km
#      19     plot(px, py, 'ro')
#      20     text(px, py + 10, label)
#
# AttributeError: 'EarthSatellite' object has no attribute 'gcrs'

# %%
ISS_TLE = """1 25544U 98067A   16341.96974289  .00003303  00000-0  57769-4 0  9996
2 25544  51.6456 276.4739 0005937 300.1004 104.8148 15.53811586 31866"""

import numpy as np
import matplotlib.pyplot as plt
from skyfield.api import load, Topos
degs     = 180./np.pi

r_earth  = 6371.  # for approx. ground track, just use spherical Earth

data     = load('de421.bsp')
Earth    = data['earth']
ZeroZero = Earth+Topos(0.0, 0.0)
ISS      = Earth.satellite(ISS_TLE)

ts       = load.timescale()
minutes  = np.arange(0, 12*60, 1)
time     = ts.utc(2016, 12, 7, 12, minutes)

Epos     = Earth.at(time).position.km
ZZpos    = ZeroZero.at(time).position.km - Epos   ## Position of (0.0N, 0.0E) to get rotation
ISSpos   = ISS._position_and_velocity_TEME_km(time)[0] ## semi-private method, unellegant use

theta_ZZ = np.arctan2(ZZpos[1], ZZpos[0])   # calculate Earth's rotaion

sth, cth         = np.sin(-theta_ZZ), np.cos(-theta_ZZ) # unwind
xISS, yISS, zISS = ISSpos
xISSnew, yISSnew = xISS*cth - yISS*sth, xISS*sth + yISS*cth # rotate ISS data to match Earth
ISSnew           = np.vstack((xISSnew, yISSnew, zISS))

x, y, z = ISSnew
r       = np.sqrt((ISSpos**2).sum(axis=0))
rxy     = np.sqrt(x**2 + y**2)
ISSlat, ISSlon   = np.arctan2(z, rxy), np.arctan2(y, x)

plt.figure()
plt.plot(degs*ISSlon, degs*ISSlat, 'ok')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-19-91ddae67b6d7> in <module>()
#      12 Earth    = data['earth']
#      13 ZeroZero = Earth+Topos(0.0, 0.0)
# ---> 14 ISS      = Earth.satellite(ISS_TLE)
#      15
#      16 ts       = load.timescale()
#
# /usr/local/lib/python2.7/dist-packages/skyfield/vectorlib.pyc in satellite(self, text)
#     143     from skyfield.api import EarthSatellite
#     144     line1, line2 = tle_text.splitlines()[-2:]
# --> 145     sat = earth + EarthSatellite(line1, line2)""")
#     146
#     147
#
# DeprecationError: the satellite() method has, alas, been deprecated
#
# This old method has been replaced by an improved interface.  If you just
# need your software working again, install Skyfield 0.9.1 for a quick fix:
#
#     pip install skyfield==0.9.1
#
# Or, to update your old code, replace each operation that looks like:
#
#     sat = earth.satellite(tle_text)
#
# with the vector math (and the little bit of text manipulation) that was
# previously hiding inside the old method:
#
#     from skyfield.api import EarthSatellite
#     line1, line2 = tle_text.splitlines()[-2:]
#     sat = earth + EarthSatellite(line1, line2)

# %%
http://rhodesmill.org/skyfield/toc.html

# %%
from skyfield.api import load

planets = load('de421.bsp')
earth, mars = planets['earth'], planets['mars']

ts = load.timescale()
t = ts.now()
astrometric = earth.at(t).observe(mars)
ra, dec, distance = astrometric.radec()

print(ra)
print(dec)
print(distance)
# Out:
# 11h 47m 56.63s
# +02deg 34' 12.0"
# 2.4844 au

# %%
from skyfield.api import Topos

boston = earth + Topos('42.3583 N', '71.0636 W')
astrometric = boston.at(t).observe(mars)
alt, az, d = astrometric.apparent().altaz()

print(alt)
print(az)
# Out:
# -43deg 15' 44.6"
# 20deg 13' 53.3"

# %%
from astropy import units as u
xyz = astrometric.position.to(u.au)
altitude = alt.to(u.deg)

print(xyz)
print('{0:0.03f}'.format(altitude))
# Out:
# [-2.47849514  0.13049321  0.11137141] AU
# -43.262 deg

# %%
from skyfield.api import load
ts = load.timescale()
planets = load('de405.bsp')
# Out:
# [#################################] 100% de405.bsp

# %%
from skyfield import api
ts = api.load_timescale()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-b9b6a1d48693> in <module>()
#       1 from skyfield import api
# ----> 2 ts = api.load_timescale()
#
# AttributeError: 'module' object has no attribute 'load_timescale'

# %%
from skyfield.api import Topos, load

ts = load.timescale()
t = ts.now()

planets = load('de421.bsp')
earth = planets['earth']
mars = planets['mars']

# From the center of the Solar System (Barycentric)

barycentric = mars.at(t)

# From the center of the Earth (Geocentric)

astrometric = earth.at(t).observe(mars)
apparent = earth.at(t).observe(mars).apparent()

# From a place on Earth (Topocentric)

boston = earth + Topos('42.3583 N', '71.0603 W')
astrometric = boston.at(t).observe(mars)
apparent = boston.at(t).observe(mars).apparent()
print apparent
# Out:
# <Apparent position at date t>

# %%
# BCRS positions of Earth and Venus

from skyfield.api import load

planets = load('de421.bsp')
earth = planets['earth']
mars = planets['mars']

t = ts.utc(1980, 1, 1)
print(earth.at(t).position.au)
print(mars.at(t).position.au)
# Out:
# [-0.16287311  0.88787399  0.38473904]
# [-1.09202418  1.10723168  0.53739021]

# %%
# Observing Mars from the Earth's position

astrometric = earth.at(ts.utc(1980, 1, 1)).observe(mars)
print(astrometric.position.au)
# Out:
# [-0.92909581  0.21939949  0.15266885]

# %%
# Astrometric RA and declination

ra, dec, distance = astrometric.radec()
print(ra.hstr())
print(dec.dstr())
print(distance)
# Out:
# 11h 06m 51.22s
# +09deg 05' 09.2"
# 0.96678 au

# %%
import Here
print Here.here()[0],"N"
print Here.here()[1],"W"
# Out:
# 14.797424 N
# 121.057481 W

# %%
from skyfield.api import Star, Topos, load
from datetime import datetime
import Here
laT = (Here.here()[0]+" N")
loN = (Here.here()[1]+" W")

t = ts.utc(1980, 1, 1)
#Manila = earth + Topos(laT, loN)
boston = earth + Topos('42.3583 N', '71.0603 W')
barnard = Star(ra_hours=(17, 57, 48.49803),
               dec_degrees=(4, 41, 36.2072))

# From the center of the Earth (Geocentric)

astrometric = earth.at(t).observe(barnard)
apparent = earth.at(t).observe(barnard).apparent()

# From a place on Earth (Topocentric)

astrometric = boston.at(t).observe(barnard)
apparent = boston.at(t).observe(barnard).apparent()

# %% [markdown]
# # Experiment Stuff

# %%
from skyfield.api import Topos, load
import Here
laT = (Here.here()[0]+" N")
loN = (Here.here()[1]+" W")

ts = load.timescale()
t = ts.now()

planets = load('de421.bsp')
earth = planets['earth']
mars = planets['mars']

# From the center of the Solar System (Barycentric)

barycentric = mars.at(t)

# From the center of the Earth (Geocentric)

astrometric = earth.at(t).observe(mars)
apparent = earth.at(t).observe(mars).apparent()

# From a place on Earth (Topocentric)

#boston = earth + Topos('42.3583 N', '71.0603 W')
manila = earth + Topos(laT, loN)
astrometric = manila.at(t).observe(mars)
apparent = manila.at(t).observe(mars).apparent()

# %%
# Apparent GCRS ("J2000.0") coordinates

apparent = astrometric.apparent()
ra, dec, distance = apparent.radec()

print(ra.hstr())
print(dec.dstr())
print(distance)
# Out:
# 11h 47m 58.84s
# +02deg 33' 55.5"
# 2.48431 au

# %% [markdown]
# # BOSTON RESULTS
# 17h 57m 47.12s<br />
# +04deg 41' 34.5"<br />
# 2.06265e+14 au<br />

# %%
from skyfield.api import Star, Topos, load
from datetime import datetime
import Here
laT = (Here.here()[0]+" N")
loN = (Here.here()[1]+" W")
print laT,loN
# Out:
# 14.797424 N 121.057481 W

# %%
alt, az, distance = apparent.altaz()

# %%
from skyfield.api import Topos, load
import Here
laT = (Here.here()[0]+" N")
loN = (Here.here()[1]+" W")



# Altitude and azimuth in the sky of a
# specific geographic location
manila = earth + Topos(laT, loN)
#boston = earth + Topos('42.3583 N', '71.0603 W')
astro = manila.at(ts.utc(2017, 10, 17)).observe(mars)
app = astro.apparent()

alt, az, distance = app.altaz()
print(alt.dstr())
print(az.dstr())
print(distance)
# Out:
# 03deg 02' 26.4"
# 271deg 47' 57.6"
# 2.48515 au

# %%
http://panahon.observatory.ph/

# %%
alt, az, distance = app.altaz(temperature_C=32.0,
                              pressure_mbar=1005.6)
print(alt.dstr())
# Out:
# 03deg 14' 59.7"

# %%
alt, az, distance = app.altaz('standard')
print(alt.dstr())
# Out:
# 03deg 15' 59.0"

# %%
from skyfield.api import Topos, load

stations_url = 'http://celestrak.com/NORAD/elements/stations.txt'
satellites = load.tle(stations_url)
satellite = satellites['ISS (ZARYA)']
print(satellite)
# Out:
# [#################################] 100% stations.txt
# EarthSatellite u'ISS (ZARYA)' number=25544 epoch=2017-10-17T02:29:36Z

# %%
print(satellite.epoch)
print(satellite.epoch.utc_jpl())
# Out:
# <Time tt=2458043.604688>
# A.D. 2017-Oct-17 02:29:35.8212 UT

# %%
ts = load.timescale()
t = ts.utc(2017, 10, 17, 12, 18, 7)

days = t - satellite.epoch
print('{:.3f} days away from epoch'.format(days))

if abs(days) > 14:
    satellites = load.tle(stations_url, reload=True)
    satellite = satellites['ISS (ZARYA)']
# Out:
# 0.409 days away from epoch

# %%
geocentric = satellite.at(t)
print(geocentric.position.km)
# Out:
# [ 2850.36190986  3156.08115431 -5292.46535832]

# %%
bluffton = Topos('40.8939 N', '83.8917 W')
difference = satellite - bluffton
print(difference)
# Out:
# Sum of 2 vectors:
#  - Topos 40deg 53' 38.0" N -83deg 53' 30.1" E
#  + EarthSatellite u'ISS (ZARYA)' number=25544 epoch=2017-10-17T02:29:36Z

# %%
topocentric = difference.at(t)
print(topocentric.position.km)
# Out:
# [ 5722.4408557   -719.72197479 -9451.03129625]

# %%
alt, az, distance = topocentric.altaz()

if alt.degrees > 0:
    print('The ISS is above the horizon')

print(alt)
print(az)
print(distance.km)
# Out:
# -56deg 14' 11.6"
# 222deg 45' 16.5"
# 11071.8707376

# %%
ra, dec, distance = topocentric.radec()  # ICRF ("J2000")
print(ra)
print(dec)
# Out:
# 23h 31m 19.55s
# -58deg 36' 22.4"

# %%
ra, dec, distance = topocentric.radec(epoch='date')
print(ra)
print(dec)
# Out:
# 23h 32m 17.50s
# -58deg 30' 32.5"

# %%
# OVERLY EXPENSIVE APPROACH - Compute both the satellite
# and observer positions relative to the Solar System
# barycenter ("ssb"), then call observe() to compensate
# for light-travel time.

de421 = load('de421.bsp')
earth = de421['earth']
ssb_bluffton = earth + bluffton
ssb_satellite = earth + satellite
topocentric2 = ssb_bluffton.at(t).observe(ssb_satellite).apparent()

# After all that work, how big is the difference, really?
difference_km = (topocentric2 - topocentric).distance().km
print('Difference between the two positions:')
print('{0:.3f} km'.format(difference_km))

difference_angle = topocentric2.separation_from(topocentric)
print('Angle between the two positions in the sky:')
print('{}'.format(difference_angle))
# Out:
# Difference between the two positions:
# 0.792 km
# Angle between the two positions in the sky:
# 00deg 00' 04.8"

# %%
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()

sat = EarthSatellite(b,c,a)

print sat
# Out:
# EarthSatellite 'SERT 2' number=4327 epoch=2017-10-16T08:24:00Z

# %%
#%%writefile TLE.py
#!/usr/bin/python
# -*- coding: ascii -*-
import numpy as np
import pylab as plt
import ephem
import datetime
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()
# Setup lat long of telescope
oxford = ephem.Observer()
oxford.lat = np.deg2rad(51.75)
oxford.long = np.deg2rad(-1.259)
oxford.date = datetime.datetime.now()
#Satillite info from SatInfo Module
biif1 = ephem.readtle(a,b,c)
# Make datetimes
midnight = datetime.datetime.replace(datetime.datetime.now(), hour=0)
dt  = [midnight + datetime.timedelta(minutes=20*x) for x in range(0, 24*3)]
# Compute satellite locations at each datetime
sat_alt, sat_az = [], []
for date in dt:
    oxford.date = date
    biif1.compute(oxford)
    sat_alt.append(np.rad2deg(biif1.alt))
    sat_az.append(np.rad2deg(biif1.az))
# Satellite Tracks
plt.subplot(211)
plt.plot(dt, sat_alt)
plt.ylabel("Altitude (deg)")
plt.xticks(rotation=25)
plt.subplot(212)
plt.plot(dt, sat_az)
plt.ylabel("Azimuth (deg)")
plt.xticks(rotation=25)
plt.show()
# Satellite Polar Coordinates
plt.polar(np.deg2rad(sat_az), 90-np.array(sat_alt))
plt.ylim(0,90)
plt.show()
def loadTLE(filename):
    """ Loads a TLE file and creates a list of satellites."""
    f = open(filename)
    satlist = []
    l1 = f.readline()
    while l1:
        l2 = f.readline()
        l3 = f.readline()
        sat = ephem.readtle(l1,l2,l3)
        satlist.append(sat)
        print sat.name
        l1 = f.readline()

    f.close()
    print "%i satellites loaded into list"%len(satlist)
    return satlist
loadTLE('ALL_TLE.TXT')
# Out:
# VANGUARD 1
# VANGUARD 2
# VANGUARD R/B
# VANGUARD R/B
# VANGUARD 3
# EXPLORER 7
# TIROS 1
# TRANSIT 2A
# SOLRAD 1 (GREB)
# THOR ABLESTAR R/B
# DELTA 1 R/B
# ECHO 1 DEB (METAL OBJ)
# ECHO 1 DEB (METAL OBJ)
# COURIER 1B
# THOR ABLESTAR R/B
# SCOUT X-1 R/B
# SCOUT X-1 DEB
# EXPLORER 11
# THOR ABLE DEB (YO)
# TRANSIT 4A
# SOLRAD 3/INJUN 1
# THOR ABLESTAR R/B
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# TIROS 3
# MIDAS 3
# DELTA 1 DEB (YO)
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# MIDAS 3 DEB
# MIDAS 4
# MIDAS 4 DEB
# MIDAS 4 DEB
# MIDAS 3 DEB
# TRANSIT 4B
# THOR ABLESTAR R/B
# TRAAC
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# TIROS 4
# DELTA 1 DEB (YO)
# DELTA 1 DEB (YO)
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# MIDAS 5 (STRONGBACK)
# MIDAS 5 DEB
# MIDAS 5 DEB
# THOR ABLESTAR DEB
# TIROS 5
# DELTA 1 DEB (YO)
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# TELSTAR 1
# DELTA 1 R/B
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# FTV 3502
# TIROS 6
# DELTA 1 DEB (YO)
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# ALOUETTE 1 (S-27)
# THOR AGENA B R/B
# ANNA 1B
# THOR ABLESTAR R/B
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# RELAY 1 (A-15)
# EXPLORER 16
# THOR AGENA B DEB
# THOR AGENA B DEB
# DELTA 1 R/B
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# TELSTAR 2 (A-41)
# MIDAS 6 (FTV 1169)
# DELTA 1 R/B
# DASH 1
# WESTFORD NEEDLES
# ERS 6
# HITCH HIKER 1
# MIDAS 7/ERS 10
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# ATLAS AGENA B DEB
# ATLAS AGENA B DEB
# SYNCOM 2 (A 26)
# ERS 9
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR R/B
# TRANSIT 5B-1
# RADIATION SAT (5E 1)
# THOR ABLESTAR DEB
# ATLAS CENTAUR 2 R/B
# ATLAS CENTAUR 2 DEB
# ATLAS CENTAUR 2 DEB
# ATLAS CENTAUR 2 DEB
# WESTFORD NEEDLES
# THOR ABLESTAR R/B
# TRANSIT 5B-2
# TRANSIT 5E 3
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# TIROS 8
# DELTA 1 DEB
# SCOUT X-4 R/B
# SCOUT X-4 DEB
# SCOUT X-4 DEB
# THOR AGENA D R/B
# GGSE 1 (GGRS)
# SECOR 1B
# SOLRAD 7A
# GREB
# SCOUT X-4 DEB
# THOR AGENA D R/B
# OPS 3367 A
# OPS 3367 B
# RELAY 2
# DELTA 1 R/B
# ATLAS CENTAUR 2 DEB
# THOR AGENA B R/B
# THOR AGENA B DEB
# THOR AGENA B DEB
# THOR ABLESTAR DEB
# ELEKTRON 1
# ELEKTRON 1 DEB
# THOR ABLESTAR DEB
# OPS 4412 (TRANSIT 9)
# SCOUT X-4 DEB
# SCOUT X-4 R/B
# OPS 4467 A
# OPS 4467 B
# THOR AGENA D R/B
# ELEKTRON 3
# ELEKTRON 3 DEB
# SYNCOM 3
# DELTA 1 R/B
# EXPLORER 20
# SCOUT X-4 R/B
# COSMOS 44
# SL-3 R/B
# OGO 1
# THOR ABLESTAR R/B
# OPS 5798 (TRANSIT 5B-4)
# EXPLORER 22
# CALSPHERE 1
# OPS 5798 DEB
# CALSPHERE 2
# OPS 5798 DEB
# SCOUT X-4 R/B
# EXPLORER 25 (INJUN-4)
# SCOUT X-4 R/B
# THOR ABLESTAR R/B
# THOR ABLESTAR DEB
# OPS 6582 (TRANSIT 5E-5)
# EXPLORER 26 (EPE-D)
# OPS 6582 (TRANSIT 5B-5)
# THOR ABLESTAR DEB
# SCOUT X-4 DEB
# SCOUT X-4 DEB
# TIROS 9
# DELTA 1 R/B
# TITAN 3A DEB (TRUSS)
# TITAN 3A TRANSTAGE R/B
# LES 1
# THOR ABLESTAR DEB
# SECOR 3
# GGSE 2
# THOR AGENA D R/B
# OPS 4988 (GREB 6)
# PORCUPINE 1
# SOLRAD 7B
# GGSE 3
# OSCAR 3
# DELTA 1 DEB
# DELTA 1 DEB
# OPS 4682 (SNAPSHOT)
# SECOR 4 (EGRS 4)
# OPS 4682 DEB
# INTELSAT 1-F1
# DELTA 1 R/B(2)
# EXPLORER 27
# SL-8 DEB
# SCOUT X-4 R/B
# TITAN 3A TRANSTAGE R/B
# LES 2
# LCS 1
# OPS 4682 DEB
# SL-8 DEB
# OPS 4682 DEB
# OPS 8480 (TRANSIT 5B-6)
# THOR ABLESTAR DEB
# THOR ABLESTAR R/B
# TIROS 10
# DELTA 1 R/B
# THOR ABLESTAR DEB
# OPS 6564 (VELA 6)
# SL-8 DEB
# SL-8 DEB
# SL-8 DEB
# SL-8 DEB
# SCOUT B R/B
# THOR ABLESTAR DEB
# SECOR 5 (EGRS 5)
# THOR ABLESTAR R/B
# DODECAPOLE 2
# THOR ABLESTAR DEB
# TEMPSAT 1
# OPS 8464 (TRANSIT 5B-7)
# NAVSPASUR ROD 1
# CALSPHERE 4(A)
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# DELTA 1 DEB
# SL-8 DEB
# COSMOS 80
# COSMOS 81
# COSMOS 82
# COSMOS 83
# COSMOS 84
# SL-8 R/B
# VANGUARD DEB
# PORCUPINE 2
# OPS 8068
# THOR ALTAIR R/B
# COSMOS 86
# COSMOS 87
# COSMOS 88
# COSMOS 89
# COSMOS 90
# SL-8 R/B
# SL-8 DEB
# SL-8 DEB
# THOR ABLESTAR DEB
# OV1-2
# ATLAS D R/B
# SL-8 DEB
# SL-8 DEB
# SL-8 DEB
# OV2-1
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# EXPLORER 29 (GEOS 1)
# DELTA 1 R/B
# EXPLORER 30
# SCOUT X-4 R/B
# A-1 (ASTERIX)
# ALOUETTE 2
# DIAMANT R/B
# EXPLORER 31 (ISIS-X)
# THOR AGENA B R/B
# FR 1
# SCOUT X-4 R/B
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE R/B
# OPS 1509 (TRANSIT 10)
# SCOUT A R/B
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# THOR ALTAIR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR AGENA B DEB
# THOR AGENA B DEB
# OPS 1593 (TRANSIT 11)
# SCOUT A R/B
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# ESSA 1 (OT-3)
# DELTA 1 R/B
# MIDAS 4 DEB
# SCOUT X-4 DEB
# DIAPASON (D1-A)
# DIAMANT R/B
# TITAN 3C TRANSTAGE DEB
# SCOUT X-4 DEB
# ESSA 2 (OT-2)
# THOR AGENA B DEB
# DELTA 1 R/B
# TRANSIT 5B-1 DEB
# TRANSIT 5B-1 DEB
# DELTA 1 DEB
# OPS 1117 (TRANSIT 12)
# SCOUT A R/B
# OV1-4
# OV1-5
# OV1-5 R/B
# OV1-4 R/B
# OPS 0340
# SCOUT A DEB
# SCOUT A DEB
# OAO 1
# ATLAS AGENA D R/B
# OPS 1527 (OV3-1)
# THOR AGENA B DEB
# DELTA 1 DEB
# NIMBUS 2
# THOR AGENA B R/B
# OPS 0082 (TRANSIT 13)
# THOR ALTAIR DEB
# SCOUT A R/B
# OPS 1427 (OV3-4)
# SCOUT B R/B
# OPS 9381 (GGTS)
# OPS 9311 (IDSCS 1)
# OPS 9312 (IDSCS 2)
# OPS 9313 (IDSCS 3)
# OPS 9314 (IDSCS 4)
# OPS 9315 (IDSCS 5)
# OPS 9316 (IDSCS 6)
# OPS 9317 (IDSCS 7)
# TITAN 3C TRANSTAGE R/B
# DELTA 1 DEB
# DELTA 1 DEB
# SCOUT A DEB
# THOR AGENA D R/B
# PAGEOS 1 DEB
# ATLAS D DEB
# ATLAS D R/B
# ATLAS D DEB
# SL-8 DEB
# ATLAS D DEB
# SCOUT A DEB
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# MIDAS 4 DEB
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# SCOUT A DEB
# OV3-3
# OPS 2366 (TRANSIT 14)
# OPS 0856
# SECOR 7 (EGRS 7)
# ERS 15
# SCOUT A R/B
# OPS 6026 (DMSP 4A F1)
# THOR BURNER 2 R/B
# WESTFORD NEEDLES
# THOR ABLESTAR DEB
# ESSA 3 (TOS-A)
# DELTA 1 R/B
# OPS 1920
# SCOUT B DEB
# PAGEOS 1 DEB
# INTELSAT 2-F1
# SCOUT B DEB
# DELTA 1 DEB
# SECOR 8 (EGRS 8)
# LES 2 AKM
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# SCOUT A DEB
# ATS 1
# OV1-9
# THOR ABLESTAR DEB
# OV1-10 R/B
# OV1-9 R/B
# INTELSAT 2-F2
# DELTA 1 R/B(2)
# SCOUT A DEB
# OPS 9321 (IDSCS 8)
# SL-8 DEB
# OPS 9322 (IDSCS 9)
# OPS 9323 (IDSCS 10)
# OPS 9324 (IDSCS 11)
# OPS 9325 (IDSCS 12)
# OPS 9326 (IDSCS 13)
# OPS 9327 (IDSCS 14)
# OPS 9328 (IDSCS 15)
# ESSA 4 (TOS-B)
# DELTA 1 R/B
# OPS 6073 (DMSP 4A F2)
# DIAMANT R/B
# DIADEME 1
# DIADEME 2
# DIAMANT R/B
# DIAMANT DEB
# DIAMANT DEB
# DELTA 1 DEB
# THOR ABLESTAR DEB
# SCOUT A DEB
# DELTA 1 DEB
# DELTA 1 DEB
# INTELSAT 2-F3
# THOR BURNER 2 R/B
# OPS 0100 (TRANSIT 15)
# SCOUT A R/B
# ESSA 5
# DELTA 1 R/B
# TITAN 3C TRANSTAGE R/B
# DELTA 1 DEB
# SCOUT A DEB
# SCOUT A DEB
# TITAN 3C TRANSTAGE DEB
# WESTFORD NEEDLES
# TITAN 3C TRANSTAGE DEB
# SCOUT B DEB
# COSMOS 158
# SL-8 R/B
# OPS 7218 (TRANSIT 16)
# SCOUT A R/B
# THOR AGENA D R/B
# OPS 5712 (P/L 160)
# GGSE 4
# GGSE 5
# TIMATION 1
# SECOR 9 (EGRS 9)
# OPS 9331 (IDSCS 16)
# OPS 9332 (IDSCS 17)
# OPS 9333 (IDSCS 18)
# OPS 9334 (IDSCS 19)
# LES 5
# DODGE 1
# TITAN 3C TRANSTAGE R/B
# SURCAL 159
# OPS 5712 (P/L 152)
# OPS 5712 (P/L 153)
# AURORA 1
# THOR BURNER 2 R/B
# ATLAS CENTAUR 2 DEB
# DELTA 1 DEB
# SCOUT A DEB
# SURCAL 150B
# OPS 7202 (DMSP 4A F3)
# SL-8 DEB
# THOR BURNER 2 R/B
# WESTFORD NEEDLES
# OPS 4947 (TRANSIT 17)
# SCOUT A R/B
# INTELSAT 2-F4
# DELTA 1 R/B(2) *
# DELTA 1 DEB
# DELTA 1 DEB
# OPS 1264 (DMSP 4A F4)
# THOR BURNER 2 R/B
# SCOUT X-4 DEB
# SCOUT A DEB
# SCOUT A DEB
# WESTFORD NEEDLES
# ATS 3
# ESSA 6 (TOS-D)
# DELTA 1 R/B
# SL-8 DEB
# SL-8 DEB *
# COSMOS 192
# SL-8 R/B
# DELTA 1 DEB
# COSMOS 198
# EXPLORER 36 (GEOS 2)
# DELTA 1 R/B
# ATLAS AGENA B DEB
# SCOUT A DEB
# DELTA 1 DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 203
# SL-8 R/B
# ATLAS AGENA B DEB
# OPS 7034 (TRANSIT 18)
# SCOUT A R/B
# COSMOS 209
# THOR ABLESTAR DEB
# TRANSIT 5B-1 DEB
# OV1-13
# OV1-14
# OV1-14 R/B
# OV1-13 R/B
# SCOUT A DEB
# SCOUT A DEB
# COSMOS 220
# SL-8 R/B
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# WESTFORD NEEDLES
# OPS 7869 (DMSP 4B F1)
# WESTFORD NEEDLES *
# THOR BURNER 2 R/B
# OPS 9341 (IDSCS 20)
# OPS 9342 (IDSCS 21)
# OPS 9343 (IDSCS 22)
# OPS 9344 (IDSCS 23)
# OPS 9345 (IDSCS 24)
# OPS 9346 (IDSCS 25)
# OPS 9347 (IDSCS 26)
# OPS 9348 (IDSCS 27)
# TITAN 3C TRANSTAGE R/B
# EXPLORER 38 (RAE-A)
# DELTA 1 R/B
# EXPLORER 40 (INJUN-5)
# SCOUT B R/B
# ESSA 7 (TOS-E)
# DELTA 1 R/B
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# SCOUT B DEB
# DELTA 1 DEB
# DELTA 1 DEB
# OV2-5
# LES 6
# TITAN 3C TRANSTAGE R/B
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# COSMOS 249
# COSMOS 249 DEB
# COSMOS 249 DEB
# OPS 4078 (DMSP 4B F2)
# THOR BURNER 2 R/B
# COSMOS 252
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 256
# SL-8 R/B
# COSMOS 249 DEB
# COSMOS 249 DEB
# SCOUT A DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# OAO 2
# ATLAS CENTAUR R/B
# OPS 7684
# COSMOS 249 DEB
# COSMOS 249 DEB
# OV1-5 DEB
# ESSA 8 (TOS-F)
# DELTA 1 R/B
# OPS 7684 DEB
# OPS 7684 DEB
# INTELSAT 3-F2
# ISIS 1
# DELTA 1 R/B
# OPS 2644
# INTELSAT 3-F3
# COSMOS 249 DEB *
# COSMOS 252 DEB *
# COSMOS 252 DEB *
# OPS 0757 (TACSAT)
# TITAN 3C TRANSTAGE R/B
# COSMOS 249 DEB
# COSMOS 252 DEB *
# THOR ABLESTAR DEB
# ATLAS CENTAUR 2 DEB
# SL-8 DEB *
# THOR ABLESTAR DEB
# SL-8 DEB *
# THOR ABLESTAR DEB
# SL-8 DEB
# SCOUT X-4 DEB
# THOR ABLESTAR DEB
# COSMOS 249 DEB *
# COSMOS 249 DEB
# COSMOS 249 DEB
# COSMOS 249 DEB *
# ESSA 9 (TOS-G)
# DELTA 1 R/B
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 249 DEB *
# COSMOS 249 DEB
# COSMOS 249 DEB
# THOR ABLESTAR DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 252 DEB
# COSMOS 272
# SL-8 R/B
# OV1-19
# OV1-19 R/B
# OPS 2644 DEB
# OPS 2644 DEB
# THOR ABLESTAR DEB
# COSMOS 252 DEB
# EXPLORER 38 DEB
# COSMOS 249 DEB
# NIMBUS 3
# SECOR 13 (EGRS 13)
# THORAD AGENA D R/B
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB
# COSMOS 252 DEB *
# COSMOS 249 DEB *
# COSMOS 249 DEB
# COSMOS 249 DEB
# COSMOS 249 DEB
# SCOUT X-1 DEB
# SL-8 DEB *
# THOR ABLESTAR DEB
# COSMOS 252 DEB *
# INTELSAT 3-F4
# TITAN 3C TRANSTAGE R/B
# SL-8 DEB *
# DELTA 1 DEB
# DELTA 1 DEB
# TITAN 3C TRANSTAGE DEB
# THOR ABLESTAR DEB
# COSMOS 249 DEB *
# THOR ABLESTAR DEB
# SCOUT X-1 DEB
# THOR ABLESTAR DEB
# OPS 1127 (DMSP 4B F3)
# THOR BURNER 2 R/B
# ATS 5
# ATLAS CENTAUR R/B
# COSMOS 292
# SL-8 R/B
# SL-8 DEB
# SOICAL (CONE)
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 304
# SL-8 R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# SOICAL (CYLINDER)
# TEMPSAT 2
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# AZUR (GRS A)
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# OPS 7613 (P/L 4)
# OPS 7613 (P/L 5)
# THORAD AGENA D DEB
# SKYNET 1
# DELTA 1 R/B
# COSMOS 312
# SL-8 R/B
# OPS 7613 (P/L 1)
# TIMATION 2
# OPS 7613 (P/L 3)
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# OPS 7613 (P/L 6)
# INTELSAT 3-F6
# DELTA 1 R/B
# THORAD AGENA D DEB
# ITOS 1 (TIROS M)
# OSCAR 5
# DELTA 1 R/B
# THORAD AGENA D DEB
# SERT 2
# OPS 0054 (DMSP 5A F1)
# THOR BURNER 2 R/B
# NATO 2A
# DELTA 1 R/B
# NIMBUS 4
# TOPO 1
# THORAD AGENA D R/B
# COSMOS 332
# SL-8 R/B
# INTELSAT 3-F7
# DELTA 1 R/B
# DFH-1
# COSMOS 336
# COSMOS 337
# COSMOS 338
# COSMOS 339
# COSMOS 340
# COSMOS 341
# COSMOS 342
# COSMOS 343
# SL-8 R/B
# SL-3 R/B
# METEOR 1-5
# SL-3 R/B
# COSMOS 252 DEB *
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# INTELSAT 3-F8
# DELTA 1 R/B
# DELTA 1 DEB
# NNSS 19 (TRANSIT 19)
# OPS 0203 (DMSP 5A F2)
# THOR BURNER 2 R/B
# SCOUT A R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# SCOUT A DEB
# COSMOS 367
# COSMOS 371
# SL-8 R/B
# COSMOS 372
# SL-8 R/B
# COSMOS 374
# SL-11 R/B
# COSMOS 375
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB
# COSMOS 374 DEB
# COSMOS 374 DEB
# COSMOS 375 DEB
# COSMOS 375 DEB
# OPS 5960
# TITAN 3C TRANSTAGE R/B
# COSMOS 375 DEB
# COSMOS 375 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 375 DEB
# COSMOS 374 DEB
# COSMOS 374 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB
# COSMOS 374 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB
# COSMOS 375 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 375 DEB
# COSMOS 375 DEB
# COSMOS 375 DEB
# COSMOS 375 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 381
# SL-8 R/B
# COSMOS 382
# SL-12 R/B(AUX MOTOR)
# SL-12 R/B(AUX MOTOR)
# NOAA 1
# DELTA 1 R/B(CEP 1)
# COSMOS 385
# SL-8 R/B
# SL-3 R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB
# THORAD AGENA D DEB
# OPS 0100 DEB *
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# INTELSAT 4-F2
# ATLAS CENTAUR R/B
# THORAD AGENA D DEB
# NATO 2B
# DELTA 1 R/B
# TITAN 3C TRANSTAGE DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 394
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 375 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# TANSEI 1 (MS-T1)
# OPS 5268 (DMSP 5A F3)
# THOR BURNER 2 R/B
# COSMOS 397
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 374 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB *
# SCOUT A DEB
# COSMOS 397 DEB
# COSMOS 400
# SL-8 R/B
# SL-8 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 374 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# ISIS 2
# COSMOS 402
# THOR DELTA 1 R/B
# COSMOS 405
# SL-3 R/B
# M-4S R/B
# THORAD AGENA D DEB
# COSMOS 397 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# THORAD AGENA D DEB
# COSMOS 407
# SL-8 R/B
# COSMOS 409
# SL-8 R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 397 DEB
# COSMOS 374 DEB
# COSMOS 374 DEB *
# COSMOS 397 DEB
# COSMOS 397 DEB
# THORAD AGENA D DEB
# COSMOS 411
# COSMOS 412
# COSMOS 413
# COSMOS 414
# COSMOS 415
# COSMOS 416
# COSMOS 417
# COSMOS 418
# SL-8 R/B
# THORAD AGENA D DEB
# COSMOS 397 DEB
# SL-8 DEB
# COSMOS 422
# SL-8 R/B
# COSMOS 374 DEB
# THOR ABLESTAR DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# SL-8 DEB
# SL-8 DEB
# COSMOS 252 DEB *
# COSMOS 374 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# SL-8 DEB
# THORAD AGENA D DEB
# THOR DELTA 1 DEB
# OV1-5 DEB
# OV1-20/OV1-21 DEB
# THORAD AGENA D DEB *
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# OV1-20/OV1-21 AKM
# OV1-21 R/B
# RIGIDSPHERE 2 (LCS 4)
# COSMOS 397 DEB *
# COSMOS 397 DEB *
# THORAD AGENA D DEB
# COSMOS 434 DEB
# THORAD AGENA D DEB
# EOLE 1 (CAS-A)
# SCOUT B-1 R/B
# DELTA 1 DEB
# THORAD AGENA D DEB
# SCOUT A DEB
# TITAN 3C TRANSTAGE DEB
# SHINSEI (MS-F2)
# M-4S R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# TITAN 3C TRANSTAGE DEB
# THORAD AGENA D DEB
# COSMOS 397 DEB *
# COSMOS 397 DEB *
# COSMOS 397 DEB *
# COSMOS 444
# COSMOS 445
# COSMOS 446
# COSMOS 447
# COSMOS 448
# COSMOS 449
# COSMOS 450
# COSMOS 451
# SL-8 R/B
# THOR BURNER 2 R/B
# OPS 4311 (DMSP 5B F1)
# ASTEX 1
# PROSPERO (BLACK ARROW)
# BLACK ARROW R/B
# OPS 9431 (DSCS 2-1)
# OPS 9432 (DSCS 2-2)
# TITAN 3C TRANSTAGE R/B
# COSMOS 252 DEB *
# COSMOS 397 DEB *
# OV1-5 DEB
# COSMOS 457
# SL-8 R/B
# TITAN 3C TRANSTAGE DEB
# THORAD AGENA D DEB
# COSMOS 465
# SL-8 R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# WESTFORD NEEDLES
# COSMOS 468
# SL-8 R/B
# INTELSAT 4-F3
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# COSMOS 397 DEB *
# COSMOS 469
# AUREOLE 1
# SL-8 R/B
# METEOR 1-10
# SL-3 R/B
# THORAD AGENA D DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# COSMOS 397 DEB *
# INTELSAT 4-F4
# SL-8 DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THORAD AGENA D DEB
# THOR ABLESTAR DEB
# ATLAS CENTAUR R/B
# THORAD AGENA D DEB *
# THOR ABLESTAR DEB
# THORAD AGENA D DEB
# COSMOS 475
# SL-8 R/B
# SL-8 DEB
# COSMOS 252 DEB *
# THOR ABLESTAR DEB
# OPS 5058 (DMSP 5B F2)
# THOR BURNER 2 R/B
# COSMOS 480
# SL-8 R/B
# METEOR 1-11
# SL-3 R/B
# TIROS 2 DEB *
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB *
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 R/B(2)
# TITAN 3C TRANSTAGE DEB
# DELTA 1 DEB *
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# THORAD AGENA D DEB
# COSMOS 489
# SL-8 R/B
# INTELSAT 4-F5
# ATLAS CENTAUR R/B
# COSMOS 494
# SL-8 R/B
# SL-8 DEB
# SL-8 DEB
# COSMOS 482 DESCENT CRAFT
# METEOR 1-12
# SL-3 R/B
# COSMOS 504
# COSMOS 505
# COSMOS 506
# COSMOS 507
# COSMOS 508
# COSMOS 509
# COSMOS 510
# COSMOS 511
# SL-8 R/B
# LANDSAT 1 (ERTS 1)
# DELTA 1 R/B
# THORAD AGENA D DEB
# COSMOS 514
# SL-8 R/B
# OAO 3 (COPERNICUS)
# COSMOS 516
# ATLAS CENTAUR R/B
# THORAD AGENA D DEB
# THORAD AGENA D DEB *
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# TRIAD 1
# COSMOS 249 DEB *
# SCOUT B-1 R/B
# COSMOS 520
# COSMOS 521
# SL-8 R/B
# SL-8 DEB
# DELTA 1 DEB *
# DELTA 1 DEB
# THORAD AGENA D DEB
# OPS 8180 (STP RADSAT)
# ATLAS F BURNER 2 R/B
# NOAA 2 (ITOS-D)
# OSCAR 6
# DELTA 1 R/B
# SL-8 DEB *
# METEOR 1-13
# SL-3 R/B
# COSMOS 528
# COSMOS 529
# COSMOS 530
# COSMOS 531
# COSMOS 532
# COSMOS 533
# COSMOS 534
# COSMOS 535
# SL-8 R/B
# OPS 7323 (DMSP 5B F3)
# THOR BURNER 2 R/B
# SL-8 DEB
# ANIK A1 (TELESAT 1)
# SCOUT B-1 DEB
# SL-8 DEB
# SL-6 R/B(2)
# NIMBUS 5
# DELTA 1 R/B
# COSMOS 539
# SL-8 R/B
# COSMOS 540
# SL-8 R/B
# COSMOS 546
# METEOR 1-14
# SL-3 R/B
# SL-8 DEB
# ANIK A2 (TELESAT 2)
# METEOR 1-15
# SL-3 R/B
# COSMOS 564
# COSMOS 565
# COSMOS 566
# COSMOS 567
# COSMOS 568
# COSMOS 569
# COSMOS 570
# COSMOS 571
# SL-8 R/B
# COSMOS 574
# SL-8 R/B
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# COSMOS 249 DEB
# COSMOS 249 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# ATLAS CENTAUR R/B
# OPS 8364 (DMSP 4)
# THOR BURNER 2 R/B
# INTELSAT 4-F7
# ATLAS CENTAUR R/B
# OPS 8314 (2)
# TITAN 3D DEB
# TITAN 3D DEB
# COSMOS 585
# SL-8 R/B
# COSMOS 586
# SL-8 R/B
# THOR ABLESTAR DEB
# COSMOS 397 DEB
# COSMOS 397 DEB
# COSMOS 588
# COSMOS 589
# COSMOS 590
# COSMOS 591
# COSMOS 592
# COSMOS 593
# COSMOS 594
# COSMOS 595
# SL-8 R/B
# NNSS 20 (TRANSIT 20)
# SCOUT A-1 R/B
# COSMOS 606
# NOAA 3
# DELTA 1 R/B
# OPS 6630 (2)
# COSMOS 614
# SL-8 R/B
# OPS 9433 (DSCS 2-3)
# OPS 9434 (DSCS 2-4)
# TITAN 3C TRANSTAGE R/B
# COSMOS 617
# COSMOS 618
# COSMOS 619
# COSMOS 620
# COSMOS 621
# COSMOS 622
# COSMOS 623
# COSMOS 624
# SL-8 R/B
# AUREOLE 2
# SL-8 R/B
# COSMOS 626
# COSMOS 627
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 628
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# METEOR 1-16
# SL-3 R/B
# MIRANDA (X-4)
# OPS 8579 (DMSP 5B F5)
# THOR BURNER 2A R/B
# SCOUT D-1 R/B
# COSMOS 637
# WESTAR 1
# COSMOS 641
# COSMOS 642
# COSMOS 643
# COSMOS 644
# COSMOS 645
# COSMOS 646
# COSMOS 647
# COSMOS 648
# SL-8 R/B
# METEOR 1-17
# SL-3 R/B
# MOLNIYA 2-9
# COSMOS 650
# SL-8 R/B
# COSMOS 651
# COSMOS 654
# SMS 1
# ATS 6
# TITAN 3C TRANSTAGE R/B
# COSMOS 660
# COSMOS 663
# SL-8 R/B
# METEOR 1-18
# SL-3 R/B
# OPS 7518 (NTS 1)
# SL-6 R/B(2)
# MOLNIYA 2-10
# MOLNIYA 1-S
# SL-12 R/B(AUX MOTOR)
# OPS 6983 (DMSP 5C F1)
# THOR BURNER 2A R/B
# COSMOS 675
# SL-8 R/B
# COSMOS 676
# SL-8 R/B
# COSMOS 677
# COSMOS 678
# COSMOS 679
# COSMOS 680
# COSMOS 681
# COSMOS 682
# COSMOS 683
# COSMOS 684
# SL-8 R/B
# WESTAR 2
# COSMOS 689
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# METEOR 1-19
# SL-3 R/B
# NOAA 4
# OSCAR 7
# INTASAT
# THORAD DELTA 1 R/B
# INTELSAT 4-F8
# ATLAS CENTAUR R/B
# SKYNET 2B
# OPS 6630 DEB
# SL-8 DEB
# METEOR 1-20
# SL-3 R/B
# SYMPHONIE 1
# COSMOS 700
# SL-8 R/B
# LANDSAT 2
# DELTA 1 R/B
# COSMOS 706
# SL-6 R/B(2)
# STARLETTE
# DIAMANT B-P4 R/B
# SMS 2
# DIAMANT B-P4 DEB
# DIAMANT B-P4 DEB
# DIAMANT B-P4 DEB
# COSMOS 708
# SL-8 R/B
# COSMOS 711
# COSMOS 712
# COSMOS 713
# COSMOS 714
# COSMOS 715
# COSMOS 716
# COSMOS 717
# COSMOS 718
# SL-8 R/B
# METEOR 1-21
# SL-3 R/B
# COSMOS 723
# COSMOS 724
# GEOS 3
# DELTA 1 R/B
# COSMOS 726
# SL-8 R/B
# COSMOS 729
# SL-8 R/B
# MOLNIYA 1-29
# ANIK A3 (TELESAT-3)
# SL-6 R/B(2)
# INTELSAT 4-F1
# COSMOS 732
# COSMOS 733
# COSMOS 734
# COSMOS 735
# COSMOS 736
# COSMOS 737
# COSMOS 738
# COSMOS 739
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# ATLAS CENTAUR R/B
# DELTA 1 DEB
# NIMBUS 6
# DELTA 1 DEB
# OPS 6381 (SSU 1)
# SSU 1 DEB
# SSU 1 DEB
# DELTA 1 DEB
# DELTA 1 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# MOLNIYA 2-13
# SL-6 R/B(2)
# METEOR 2-1
# SL-3 R/B
# SL-3 DEB
# COSMOS 755
# SL-8 R/B
# DELTA 1 DEB
# SL-3 DEB
# SYMPHONIE 2
# DELTA 1 R/B(2)
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# MOLNIYA 2-14
# KIKU 1 (ETS 1)
# COSMOS 761
# COSMOS 762
# COSMOS 763
# COSMOS 764
# COSMOS 765
# COSMOS 766
# COSMOS 767
# COSMOS 768
# METEOR 1-22
# SL-3 R/B
# SL-8 R/B
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 770
# SL-8 R/B
# INTELSAT 4A-F1
# ATLAS CENTAUR R/B
# COSMOS 773
# SL-8 R/B
# N-1 R/B
# COSMOS 775
# GOES 1 (SMS-C)
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# SL-6 R/B(2)
# COSMOS 778
# SL-8 R/B
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# COSMOS 783
# SL-8 R/B
# SL-6 R/B(2)
# COSMOS 785
# SATCOM 1
# DELTA 1 DEB *
# RADUGA 1
# METEOR 1-23
# SL-3 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# SL-12 R/B(AUX MOTOR)
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# CTS
# COSMOS 789
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# SL-8 R/B
# NTS 1 AKM
# MOLNIYA 1-32
# COSMOS 791
# COSMOS 792
# COSMOS 793
# COSMOS 794
# COSMOS 795
# COSMOS 796
# COSMOS 797
# COSMOS 798
# SL-8 R/B
# INTELSAT 4A-F2
# ATLAS CENTAUR R/B
# COSMOS 800
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB *
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 803
# MARISAT 1
# UME 1 (ISS 1)
# N-1 R/B
# COSMOS 807
# LES 8
# LES 9
# TITAN 3C TRANSTAGE R/B
# SL-8 DEB
# SL-8 DEB
# SL-8 DEB
# SATCOM 2
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# DELTA 1 DEB *
# METEOR 1-24
# SL-3 R/B
# NATO 3A
# LAGEOS 1
# LAGEOS 1 AKM
# METEOR 1-10 DEB
# METEOR 1-10 DEB
# NOAA 1 DEB *
# SL-8 DEB
# TITAN 3C TRANSTAGE DEB
# COMSTAR 1
# ATLAS CENTAUR R/B
# METEOR 1-25
# SL-3 R/B
# P 76-5
# SCOUT B-1 R/B
# SCOUT B-1 DEB
# SCOUT B-1 DEB
# COSMOS 823
# SL-8 R/B
# MARISAT 3
# COSMOS 825
# COSMOS 826
# COSMOS 827
# COSMOS 828
# COSMOS 829
# COSMOS 830
# COSMOS 831
# COSMOS 832
# SL-8 R/B
# THORAD AGENA D DEB
# COSMOS 836
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# PALAPA 1
# COSMOS 839
# SL-8 R/B
# SL-8 DEB
# COSMOS 841
# SL-8 R/B
# COSMOS 842
# DELTA 1 DEB
# DELTA 1 DEB
# SL-8 R/B
# COMSTAR 2
# NOAA 5
# COSMOS 846
# SL-8 R/B
# DELTA 1 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# OPS 6630 DEB
# ATLAS CENTAUR R/B
# THORAD DELTA 1 R/B(2)
# RADUGA 2
# COSMOS 858
# SL-8 R/B
# PAGEOS 1 DEB
# MARISAT 2
# METEOR 1-26
# SL-3 R/B
# COSMOS 860
# COSMOS 861
# COSMOS 862
# EKRAN 1
# COSMOS 864
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# SL-8 DEB *
# DELTA 1 DEB
# SL-8 DEB
# COSMOS 871
# COSMOS 872
# COSMOS 873
# COSMOS 874
# COSMOS 875
# COSMOS 876
# COSMOS 877
# COSMOS 878
# SL-8 R/B
# COSMOS 883
# SL-8 R/B
# DELTA 1 DEB
# COSMOS 886
# COSMOS 887
# SL-8 R/B
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# METEOR 2-2
# SL-3 R/B
# SL-3 DEB
# SL-3 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# DELTA 1 DEB
# DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB *
# SL-8 DEB
# DELTA 1 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# DELTA 1 DEB
# THORAD DELTA 1 DEB
# COSMOS 890
# SL-8 R/B
# NATO 3B
# DELTA 1 R/B(1)
# THORAD DELTA 1 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB *
# COSMOS 886 DEB *
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# MOLNIYA 2-17
# DELTA 1 DEB
# TANSEI 3 (MS-T3)
# TANSEI 3 DEB
# COSMOS 894
# SL-8 R/B
# SL-6 R/B(2)
# KIKU 2 (ETS 2)
# PALAPA 2
# DELTA 1 R/B(2)
# MOLNIYA 1-36
# COSMOS 862 DEB
# METEOR 1-27
# SL-3 R/B
# SL-3 DEB
# SL-6 R/B(2)
# SL-6 R/B(2)
# ESA/GOES
# MOLNIYA 3-7
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB *
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 252 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# TANSEI 3 DEB
# TANSEI 3 DEB
# TANSEI 3 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# SMS 1 AKM
# OPS 9437 (DSCS 2-7)
# OPS 9438 (DSCS 2-8)
# TITAN 3C TRANSTAGE R/B
# COSMOS 909
# SL-8 R/B
# SL-8 DEB
# COSMOS 911
# SL-8 R/B
# INTELSAT 4A-F4
# ATLAS CENTAUR R/B
# COSMOS 917
# GOES 2
# DELTA 1 R/B(1)
# SL-6 R/B(2)
# NTS 2
# COSMOS 921
# SL-14 R/B
# SL-3 R/B
# COSMOS 923
# SL-8 R/B
# THORAD AGENA D DEB
# COSMOS 926
# SL-8 R/B
# COSMOS 928
# SL-8 R/B
# HIMAWARI 1 (GMS 1)
# DELTA 1 R/B(1)
# COSMOS 931
# SL-6 R/B(2)
# RADUGA 3
# SL-6 R/B(2)
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 939
# COSMOS 940
# COSMOS 941
# COSMOS 942
# COSMOS 943
# COSMOS 944
# COSMOS 945
# COSMOS 946
# SL-8 R/B
# SIRIO
# DELTA 1 R/B(1)
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 951
# SL-8 R/B
# COSMOS 952
# EKRAN 2
# PROGNOZ 6
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# DELTA 1 DEB *
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# MOLNIYA 3-8
# TRANSAT
# COSMOS 962
# SL-8 R/B
# SCOUT D-1 R/B
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# SL-6 R/B(2)
# METEOSAT 1
# DELTA 1 R/B(1)
# COSMOS 963
# SL-8 R/B
# COSMOS 967
# SL-8 R/B
# METEOR 2-3
# SL-3 R/B
# SAKURA 1A (CS-1A)
# DELTA 1 R/B(1)
# SL-8 DEB
# DELTA 1 DEB *
# COSMOS 968
# SL-8 R/B
# SL-8 DEB
# SL-8 DEB
# SL-8 DEB
# COSMOS 970
# COSMOS 970 DEB
# COSMOS 971
# SL-8 R/B
# COSMOS 972
# SL-14 R/B
# INTELSAT 4A-F3
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB *
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 976
# COSMOS 977
# COSMOS 978
# COSMOS 979
# COSMOS 980
# COSMOS 981
# COSMOS 982
# COSMOS 983
# SL-8 R/B
# COSMOS 985
# SL-8 R/B
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# IUE
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# KYOKKO 1 (EXOS A)
# UME 2 (ISS-B)
# N-1 R/B
# COSMOS 990
# SL-8 R/B
# OPS 5111 (NAVSTAR 1)
# COSMOS 991
# SL-8 R/B
# LANDSAT 3
# OSCAR 8
# DELTA 1 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# ATLAS CENTAUR R/B
# DELTA 1 R/B(2)
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 994
# SL-8 R/B
# COSMOS 996
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 1000
# SL-8 R/B
# INTELSAT 4A-F6
# ATLAS CENTAUR R/B
# YURI (BSE)
# DELTA 1 R/B(1)
# TRAAC DEB
# OPS 6182 (DMSP 5D-1 F3)
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# OTS 2
# DELTA 1 R/B(1)
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# OPS 5112 (NAVSTAR 2)
# ATLAS F R/B
# COSMOS 1011
# SL-8 R/B
# MOLNIYA 1-40
# COSMOS 1013
# COSMOS 1014
# COSMOS 1015
# COSMOS 1016
# COSMOS 1017
# COSMOS 1018
# COSMOS 1019
# COSMOS 1020
# SL-8 R/B
# SL-6 R/B(2)
# GOES 3
# DELTA 1 R/B(1)
# COSMOS 1023
# SL-8 R/B
# SEASAT 1
# COSMOS 1024
# SL-14 R/B
# COMSTAR 3
# ATLAS CENTAUR R/B
# GEOS 2
# RADUGA 4
# THORAD DELTA 1 DEB
# COSMOS 1027
# SL-8 R/B
# SL-6 R/B(2)
# JIKIKEN (EXOS-B)
# M-3H R/B
# COSMOS 1034
# COSMOS 1035
# COSMOS 1036
# COSMOS 1037
# COSMOS 1038
# COSMOS 1039
# COSMOS 1040
# COSMOS 1041
# SL-8 R/B
# OPS 5113 (NAVSTAR 3)
# MOLNIYA 3-10
# TIROS N
# TIROS N DEB
# TIROS N DEB
# SL-6 R/B(2)
# SL-6 R/B(2)
# NIMBUS 7
# DELTA 1 R/B(+CAMEO)
# COSMOS 1045
# RADIO 1
# RADIO 2
# SL-14 R/B
# COSMOS 1048
# SL-8 R/B
# SL-8 DEB
# SL-8 DEB
# NATO 3C
# COSMOS 1051
# COSMOS 1052
# COSMOS 1053
# COSMOS 1054
# COSMOS 1055
# COSMOS 1056
# COSMOS 1057
# COSMOS 1058
# SL-8 R/B
# OPS 5114 (NAVSTAR 4)
# ATLAS F R/B
# OPS 9441 (DSCS 2-11)
# OPS 9442 (DSCS 2-12)
# TITAN 3C TRANSTAGE R/B
# ANIK B1 (TELESAT-4)
# GORIZONT 1
# COSMOS 1066
# SL-3 R/B
# COSMOS 1067
# SL-8 R/B
# COSMOS 1072
# SL-8 R/B
# METEOR 1-29
# SCATHA
# AYAME 1 (ECS 1)
# SL-14 R/B
# EKRAN 3
# METEOR 2-4
# SL-3 R/B
# SL-3 DEB
# COSMOS 1081
# COSMOS 1082
# COSMOS 1083
# COSMOS 1084
# COSMOS 1085
# COSMOS 1086
# COSMOS 1087
# COSMOS 1088
# SL-8 R/B
# COSMOS 1089
# SL-8 R/B
# COSMOS 1091
# SL-8 R/B
# COSMOS 1092
# SL-8 R/B
# RADUGA 5
# OPS 6392 (FLTSATCOM 2)
# COSMOS 1104
# SL-8 R/B
# NOAA 6
# COSMOS 1109
# COSMOS 1110
# SL-8 R/B
# GORIZONT 2
# MOLNIYA 1-44
# WESTAR 3
# COSMOS 1124
# COSMOS 1125
# SL-8 R/B
# COSMOS 1130
# COSMOS 1131
# COSMOS 1132
# COSMOS 1133
# COSMOS 1134
# COSMOS 1135
# COSMOS 1136
# COSMOS 1137
# SL-8 R/B
# SL-6 R/B(2)
# EKRAN 4
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# COSMOS 1140
# SL-8 R/B
# EKRAN 2 DEB
# COSMOS 1141
# SL-8 R/B
# SL-8 DEB
# METEOR 2-5
# SL-3 R/B
# OPS 9443 (DSCS 2-13)
# OPS 9444 (DSCS 2-14)
# TITAN 3C TRANSTAGE R/B
# OPS 4682 DEB
# SATCOM 3
# DELTA 1 R/B(1)
# GORIZONT 3
# COSMOS 1150
# SL-8 R/B
# OPS 6393 (FLTSATCOM 3)
# SL-14 R/B
# SL-12 R/B(2)
# COSMOS 1153
# SL-8 R/B
# SL-12 R/B(2)
# OPS 5117 (NAVSTAR 5)
# COSMOS 1156
# COSMOS 1157
# COSMOS 1158
# COSMOS 1159
# COSMOS 1160
# COSMOS 1161
# COSMOS 1162
# COSMOS 1163
# SL-8 R/B
# ATLAS 35F R/B
# RADUGA 6
# AYAME 2 (ECS-2)
# SL-12 R/B(2)
# COSMOS 1168
# SL-8 R/B
# COSMOS 1171
# SL-8 R/B
# SL-8 DEB
# COSMOS 1174
# COSMOS 1174 DEB
# OPS 5118 (NAVSTAR 6)
# COSMOS 1176
# DELTA 1 R/B(2) *
# COSMOS 1181
# SL-8 R/B
# SL-3 R/B
# GORIZONT 4
# SL-6 R/B(2)
# SL-12 R/B(2)
# COSMOS 1190
# SL-8 R/B
# COSMOS 1191
# COSMOS 1192
# COSMOS 1193
# COSMOS 1194
# COSMOS 1195
# COSMOS 1196
# COSMOS 1197
# COSMOS 1198
# COSMOS 1199
# SL-8 R/B
# SL-6 R/B(2)
# MOLNIYA 3-13
# SL-6 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# METEOR 2-6
# SL-3 R/B
# GOES 4
# GOES 4 AKM
# COSMOS 1176 FUEL CORE
# DELTA 1 R/B(2)
# TRANSIT 11 DEB
# DELTA 1 DEB
# RADUGA 7
# COSMOS 1217
# SBS 1
# COSMOS 1223
# SL-6 R/B(2)
# COSMOS 1225
# SL-8 R/B
# INTELSAT 502
# COSMOS 1226
# SL-8 R/B
# OPS 4988 DEB
# OPS 4682 DEB
# COSMOS 1228
# COSMOS 1229
# COSMOS 1230
# COSMOS 1231
# COSMOS 1232
# COSMOS 1233
# COSMOS 1234
# COSMOS 1235
# SL-8 R/B
# EKRAN 6
# COSMOS 1238
# SL-8 R/B
# COSMOS 1241
# SL-8 R/B
# SL-8 DEB
# SL-3 R/B
# MOLNIYA 1-49
# SL-6 R/B(2)
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# KIKU 3 (ETS 4)
# COSMOS 1244
# SL-8 R/B
# COSMOS 1247
# ESIAFI 1 (COMSTAR 4)
# SL-6 R/B(2)
# COSMOS 1249
# COSMOS 1250
# COSMOS 1251
# COSMOS 1252
# COSMOS 1253
# COSMOS 1254
# COSMOS 1255
# COSMOS 1256
# COSMOS 1257
# SL-8 R/B
# KYOKKO 1 DEB
# KYOKKO 1 DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 1174 DEB
# RADUGA 8
# COSMOS 1174 DEB
# ATLAS CENTAUR R/B
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 1261
# SL-6 R/B(2)
# COSMOS 1263
# SL-8 DEB
# KYOKKO 1 DEB
# COSMOS 1266
# DELTA 1 DEB
# COSMOS 1266 FUEL CORE
# COSMOS 1269
# SL-8 R/B
# ATLAS CENTAUR R/B
# SL-12 R/B(2)
# METEOR 2-7
# SL-3 R/B
# NOVA 1
# SL-3 R/B
# SL-12 R/B(2)
# GOES 5
# INTELSAT 501
# ATLAS CENTAUR R/B
# COSMOS 1275
# SL-8 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 839 DEB
# METEOSAT 2
# APPLE
# CAT 3
# COSMOS 1249 FUEL CORE
# NOAA 7
# NOAA 7 DEB
# NOAA 7 DEB
# EKRAN 7
# DELTA 1 DEB
# DELTA 1 DEB
# METEOR PRIRODA
# SL-3 R/B
# RADUGA 9
# DYNAMICS EXPLORER 1
# COSMOS 1285
# FLTSATCOM 5
# COSMOS 1287
# COSMOS 1288
# COSMOS 1289
# COSMOS 1290
# COSMOS 1291
# COSMOS 1292
# COSMOS 1293
# COSMOS 1294
# SL-8 R/B
# INTERCOSMOS 22
# SL-3 R/B
# DELTA 1 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# HIMAWARI 2 (GMS 2)
# DELTA 1 R/B(2)
# SL-6 R/B(2)
# COSMOS 1295
# SL-8 R/B
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1299
# COSMOS 1300
# SL-14 R/B
# N-2 R/B(2)
# COSMOS 1302
# SL-8 R/B
# SL-8 DEB
# COSMOS 1304
# SL-8 R/B
# COSMOS 1299 FUEL CORE
# COSMOS 931 DEB
# COSMOS 1124 DEB
# COSMOS 1191 DEB
# COSMOS 1305
# DELTA 1 DEB
# SL-6 R/B(2)
# COSMOS 1191 DEB
# COSMOS 1308
# SL-8 R/B
# AUREOLE 3
# SL-14 R/B
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 DEB
# SBS 2
# SCOUT D-1 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 1312
# SL-14 R/B
# THOR DELTA 1 R/B
# COSMOS 1261 DEB
# COSMOS 1261 DEB
# COSMOS 1261 DEB
# RADUGA 10
# SL-3 R/B
# COSMOS 931 DEB
# COSMOS 1030 DEB
# COSMOS 1317
# SL-6 R/B(2)
# COSMOS 970 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# SATCOM 3R
# COSMOS 1320
# COSMOS 1321
# COSMOS 1322
# COSMOS 1323
# COSMOS 1324
# COSMOS 1325
# COSMOS 1326
# COSMOS 1327
# SL-8 R/B
# COSMOS 1247 DEB
# COSMOS 1328
# SL-14 R/B
# COSMOS 1247 DEB
# COSMOS 1285 DEB
# INTELSAT 503
# EKRAN 2 DEB
# RADIO 3
# RADIO 8
# RADIO 5
# RADIO 4
# RADIO 7
# RADIO 6
# SL-8 R/B
# ATLAS CENTAUR R/B
# MARECS A
# CAT 4
# MOLNIYA 1-52
# SL-6 R/B(2)
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1331
# SL-8 R/B
# SL-8 DEB *
# SL-8 DEB
# COSMOS 1333
# SL-8 R/B
# SATCOM 4
# COSMOS 1275 DEB
# EKRAN 8
# COSMOS 1339
# SL-8 R/B
# COSMOS 1340
# SL-3 R/B
# WESTAR 4
# MOLNIYA 1-53
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# SL-6 R/B(2)
# COSMOS 1341
# INTELSAT 504
# SL-6 R/B(2)
# GORIZONT 5
# COSMOS 1344
# SL-8 R/B
# METEOR 2-8
# SL-14 R/B
# COSMOS 1346
# SL-3 R/B
# COSMOS 1348
# COSMOS 1349
# SL-8 R/B
# INSAT 1A
# OPS 4682 DEB
# N-1 DEB
# COSMOS 1354
# SL-8 R/B
# COSMOS 1356
# SL-3 R/B
# COSMOS 1357
# COSMOS 1358
# COSMOS 1359
# COSMOS 1360
# COSMOS 1361
# COSMOS 1362
# COSMOS 1363
# COSMOS 1364
# SL-8 R/B
# SL-6 R/B(2)
# COSMOS 1365
# COSMOS 1366
# COSMOS 1367
# COSMOS 1371
# SL-8 R/B
# COSMOS 1372
# COSMOS 1375
# SL-8 R/B
# SL-8 DEB
# WESTAR 5
# COSMOS 1378
# SL-14 R/B
# COSMOS 1382
# SL-6 R/B(2)
# COSMOS 1383
# SL-8 R/B
# COSMOS 1386
# SL-8 R/B
# THOR ABLESTAR DEB
# LANDSAT 4
# COSMOS 1388
# COSMOS 1389
# COSMOS 1390
# COSMOS 1391
# COSMOS 1392
# COSMOS 1393
# COSMOS 1394
# COSMOS 1395
# SL-8 R/B
# SL-3 R/B
# COSMOS 1372 FUEL CORE
# ANIK D1 (TELESAT 6)
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# SL-8 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 926 DEB
# KIKU 4 (ETS 3)
# N-1 R/B
# SL-8 DEB *
# SL-8 DEB *
# SL-8 DEB *
# SL-8 DEB *
# COSMOS 839 DEB
# THOR ABLESTAR DEB *
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 886 DEB
# N-1 DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# THOR ABLESTAR DEB
# COSMOS 839 DEB
# COSMOS 839 DEB
# SL-8 DEB
# THORAD AGENA D DEB
# DELTA 1 DEB
# DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 1408
# SL-14 R/B
# EKRAN 9
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 1410
# SL-14 R/B
# COSMOS 1365 FUEL CORE
# INTELSAT 505
# COSMOS 1412
# COSMOS 1413 (GLONASS)
# COSMOS 1414 (GLONASS)
# COSMOS 1415 (GLONASS)
# SL-12 R/B(AUX MOTOR)
# SL-12 R/B(AUX MOTOR)
# SL-12 R/B(2)
# COSMOS 1417
# SL-8 R/B
# COSMOS 1275 DEB
# GORIZONT 6
# SL-12 R/B(2)
# SATCOM C5
# DSCS 2-15
# TITAN 34D IUS R/B(2)
# COSMOS 1420
# SL-8 R/B
# SBS 3
# ANIK C3 (TELESAT-5)
# COSMOS 1412 FUEL CORE
# SBS 3 R/B(PAM-D)
# ANIK C3 R/B(PAM-D)
# RADUGA 11
# METEOR 2-9
# SL-3 R/B
# SL-3 DEB
# OPS 9845 (DMSP 5D-2 F6)
# LES 8 9/SOL 11A B DEB *
# COSMOS 1428
# SL-8 R/B
# COSMOS 1429
# COSMOS 1430
# COSMOS 1431
# COSMOS 1432
# COSMOS 1433
# COSMOS 1434
# COSMOS 1435
# COSMOS 1436
# SL-8 R/B
# COSMOS 1437
# SL-3 R/B
# COSMOS 397 DEB *
# IRAS
# DELTA 1 R/B
# SAKURA 2A (CS-2A)
# IRAS DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# SL-3 R/B
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# MOLNIYA 3-20
# EKRAN 10
# SL-6 R/B(2)
# MOLNIYA 1-56
# SL-6 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# ASTRON
# SL-6 DEB
# TITAN 3C TRANSTAGE DEB
# METEOSAT 1 AKM
# SL-6 DEB
# SL-6 DEB
# SL-6 DEB
# OV2-3
# COSMOS 1447
# SL-8 R/B
# NOAA 8
# THOR ABLESTAR DEB
# COSMOS 886 DEB *
# COSMOS 839 DEB
# COSMOS 839 DEB
# COSMOS 970 DEB
# COSMOS 1448
# SL-8 R/B
# SL-12 R/B(2)
# TITAN 3C TRANSTAGE DEB
# TITAN 3C TRANSTAGE DEB
# COSMOS 1285 DEB
# TDRS 1
# IUS R/B(2)
# IUS R/B(1)
# RADUGA 12
# SL-12 R/B(2)
# SATCOM 1R
# COSMOS 1452
# SL-8 R/B
# COSMOS 1191 DEB
# SL-12 R/B(2)
# COSMOS 1455
# SL-14 R/B
# OPS 4682 DEB
# OPS 4682 DEB
# OPS 4682 DEB
# GOES 6
# DELTA 1 R/B(1)
# COSMOS 1459
# SL-8 R/B
# COSMOS 1461
# GOES 6 AKM
# INTELSAT 506
# COSMOS 1464
# SL-8 R/B
# SL-12 R/B(2)
# DELTA 1 R/B
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# COSMOS 374 DEB
# EUTELSAT 1-F1 (ECS 1)
# OSCAR 10
# SL-6 DEB
# NAHUEL I2 (ANIK C2)
# PALAPA B1
# ANIK C2 R/B(PAM-D)
# PALAPA B1 R/B(PAM-D)
# COSMOS 1470
# SL-14 R/B
# HILAT
# SCOUT G-1 R/B
# GALAXY 1
# GORIZONT 7
# COSMOS 1473
# COSMOS 1474
# COSMOS 1475
# COSMOS 1476
# COSMOS 1477
# COSMOS 1478
# COSMOS 1479
# COSMOS 1480
# SL-8 R/B
# COSMOS 1481
# OPS 9794 (NAVSTAR 8)
# ATLAS 75E R/B
# SL-6 R/B(2)
# COSMOS 1481 DEB
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-12 R/B(2)
# SL-3 R/B
# SL-3 DEB
# SCOUT G-1 DEB
# SCOUT G-1 DEB
# COSMOS 1275 DEB
# SL-3 DEB
# ARABSAT 1DR (TELSTAR 3A)
# COSMOS 1486
# SL-8 R/B
# SAKURA 2B (CS-2B)
# COSMOS 1490 (GLONASS)
# COSMOS 1491 (GLONASS)
# COSMOS 1492 (GLONASS)
# SL-12 R/B(2)
# SL-12 R/B(AUX MOTOR)
# SL-12 R/B(AUX MOTOR)
# RADUGA 13
# INSAT 1B
# SATCOM 2R
# SL-12 R/B(2)
# SL-8 DEB *
# SL-8 DEB *
# SL-8 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# GALAXY 2
# COSMOS 1500
# SL-14 R/B
# EKRAN 11
# SL-12 R/B(2)
# SL-8 DEB *
# COSMOS 1503
# SL-8 R/B
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 249 DEB
# COSMOS 249 DEB
# COSMOS 249 DEB *
# COSMOS 252 DEB
# INTELSAT 507
# COSMOS 249 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 970 DEB
# COSMOS 397 DEB *
# COSMOS 1506
# SL-8 R/B
# METEOR 2-10
# SL-3 R/B
# SL-3 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# THORAD AGENA D DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD DELTA 1 DEB
# THORAD AGENA D DEB
# DELTA 1 DEB
# COSMOS 1508
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 886 DEB
# COSMOS 1275 DEB
# OPS 1294 (DMSP 5D-2 F7)
# DELTA 1 DEB
# DELTA 1 DEB
# COSMOS 970 DEB
# TANSEI 3 DEB
# OPS 4682 DEB
# COSMOS 1510
# SL-14 R/B
# INSAT 1B R/B(PAM-D)
# GORIZONT 8
# COSMOS 1513
# SL-8 R/B
# SL-12 R/B(2)
# COSMOS 1515
# SL-14 R/B
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# COSMOS 1275 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# DELTA 1 DEB
# SL-8 DEB
# N-1 DEB
# COSMOS 1519 (GLONASS)
# COSMOS 1520 (GLONASS)
# COSMOS 1521 (GLONASS)
# SL-12 R/B(2)
# SL-12 R/B(AUX MOTOR)
# SL-12 R/B(AUX MOTOR)
# COSMOS 1522
# COSMOS 1523
# ...
#  <ephem.EarthSatellite 'OPS 1127 (DMSP 4B F3)' at 0x7fe62f9a5300>,
#  <ephem.EarthSatellite 'THOR BURNER 2 R/B' at 0x7fe62f9a5468>,
#  <ephem.EarthSatellite 'ATS 5' at 0x7fe62f9a55d0>,
#  <ephem.EarthSatellite 'ATLAS CENTAUR R/B' at 0x7fe62f9a5738>,
#  <ephem.EarthSatellite 'COSMOS 292' at 0x7fe62f9a58a0>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9a5a08>,
#  <ephem.EarthSatellite 'SL-8 DEB' at 0x7fe62f9a5b70>,
#  <ephem.EarthSatellite 'SOICAL (CONE)' at 0x7fe62f9a5cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a5e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9030>,
#  <ephem.EarthSatellite 'COSMOS 304' at 0x7fe62f9a9198>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9a9300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a95d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a98a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9a9e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ac030>,
#  <ephem.EarthSatellite 'THORAD AGENA D R/B' at 0x7fe62f9ac198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ac300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ac468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ac5d0>,
#  <ephem.EarthSatellite 'SOICAL (CYLINDER)' at 0x7fe62f9ac738>,
#  <ephem.EarthSatellite 'TEMPSAT 2' at 0x7fe62f9ac8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9aca08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9acb70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9accd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ace40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae5d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ae8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9aea08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9aeb70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9aecd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9aee40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b15d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1738>,
#  <ephem.EarthSatellite 'AZUR (GRS A)' at 0x7fe62f9b18a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b1b70>,
#  <ephem.EarthSatellite 'OPS 7613 (P/L 4)' at 0x7fe62f9b1cd8>,
#  <ephem.EarthSatellite 'OPS 7613 (P/L 5)' at 0x7fe62f9b1e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b4030>,
#  <ephem.EarthSatellite 'SKYNET 1' at 0x7fe62f9b4198>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9b4300>,
#  <ephem.EarthSatellite 'COSMOS 312' at 0x7fe62f9b4468>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9b45d0>,
#  <ephem.EarthSatellite 'OPS 7613 (P/L 1)' at 0x7fe62f9b4738>,
#  <ephem.EarthSatellite 'TIMATION 2' at 0x7fe62f9b48a0>,
#  <ephem.EarthSatellite 'OPS 7613 (P/L 3)' at 0x7fe62f9b4a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b4b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b4cd8>,
#  <ephem.EarthSatellite 'OPS 7613 (P/L 6)' at 0x7fe62f9b4e40>,
#  <ephem.EarthSatellite 'INTELSAT 3-F6' at 0x7fe62f9b6030>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9b6198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b6300>,
#  <ephem.EarthSatellite 'ITOS 1 (TIROS M)' at 0x7fe62f9b6468>,
#  <ephem.EarthSatellite 'OSCAR 5' at 0x7fe62f9b65d0>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9b6738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b68a0>,
#  <ephem.EarthSatellite 'SERT 2' at 0x7fe62f9b6a08>,
#  <ephem.EarthSatellite 'OPS 0054 (DMSP 5A F1)' at 0x7fe62f9b6b70>,
#  <ephem.EarthSatellite 'THOR BURNER 2 R/B' at 0x7fe62f9b6cd8>,
#  <ephem.EarthSatellite 'NATO 2A' at 0x7fe62f9b6e40>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9f8030>,
#  <ephem.EarthSatellite 'NIMBUS 4' at 0x7fe62f9f8198>,
#  <ephem.EarthSatellite 'TOPO 1' at 0x7fe62f9f8300>,
#  <ephem.EarthSatellite 'THORAD AGENA D R/B' at 0x7fe62f9f8468>,
#  <ephem.EarthSatellite 'COSMOS 332' at 0x7fe62f9f85d0>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9f8738>,
#  <ephem.EarthSatellite 'INTELSAT 3-F7' at 0x7fe62f9f88a0>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9f8a08>,
#  <ephem.EarthSatellite 'DFH-1' at 0x7fe62f9f8b70>,
#  <ephem.EarthSatellite 'COSMOS 336' at 0x7fe62f9f8cd8>,
#  <ephem.EarthSatellite 'COSMOS 337' at 0x7fe62f9f8e40>,
#  <ephem.EarthSatellite 'COSMOS 338' at 0x7fe62f9f6030>,
#  <ephem.EarthSatellite 'COSMOS 339' at 0x7fe62f9f6198>,
#  <ephem.EarthSatellite 'COSMOS 340' at 0x7fe62f9f6300>,
#  <ephem.EarthSatellite 'COSMOS 341' at 0x7fe62f9f6468>,
#  <ephem.EarthSatellite 'COSMOS 342' at 0x7fe62f9f65d0>,
#  <ephem.EarthSatellite 'COSMOS 343' at 0x7fe62f9f6738>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9f68a0>,
#  <ephem.EarthSatellite 'SL-3 R/B' at 0x7fe62f9f6a08>,
#  <ephem.EarthSatellite 'METEOR 1-5' at 0x7fe62f9f6b70>,
#  <ephem.EarthSatellite 'SL-3 R/B' at 0x7fe62f9f6cd8>,
#  <ephem.EarthSatellite 'COSMOS 252 DEB *' at 0x7fe62f9f6e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b9030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b9198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b9300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b9468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b95d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b9738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9b98a0>,
#  <ephem.EarthSatellite 'INTELSAT 3-F8' at 0x7fe62f9b9a08>,
#  <ephem.EarthSatellite 'DELTA 1 R/B' at 0x7fe62f9b9b70>,
#  <ephem.EarthSatellite 'DELTA 1 DEB' at 0x7fe62f9b9cd8>,
#  <ephem.EarthSatellite 'NNSS 19 (TRANSIT 19)' at 0x7fe62f9b9e40>,
#  <ephem.EarthSatellite 'OPS 0203 (DMSP 5A F2)' at 0x7fe62f9ba030>,
#  <ephem.EarthSatellite 'THOR BURNER 2 R/B' at 0x7fe62f9ba198>,
#  <ephem.EarthSatellite 'SCOUT A R/B' at 0x7fe62f9ba300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ba468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9ba5d0>,
#  <ephem.EarthSatellite 'SCOUT A DEB' at 0x7fe62f9ba738>,
#  <ephem.EarthSatellite 'COSMOS 367' at 0x7fe62f9ba8a0>,
#  <ephem.EarthSatellite 'COSMOS 371' at 0x7fe62f9baa08>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9bab70>,
#  <ephem.EarthSatellite 'COSMOS 372' at 0x7fe62f9bacd8>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9bae40>,
#  <ephem.EarthSatellite 'COSMOS 374' at 0x7fe62f9bb030>,
#  <ephem.EarthSatellite 'SL-11 R/B' at 0x7fe62f9bb198>,
#  <ephem.EarthSatellite 'COSMOS 375' at 0x7fe62f9bb300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bb468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bb5d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bb738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bb8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bba08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bbb70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bbcd8>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9bbe40>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9bc030>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9bc198>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9bc300>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9bc468>,
#  <ephem.EarthSatellite 'OPS 5960' at 0x7fe62f9bc5d0>,
#  <ephem.EarthSatellite 'TITAN 3C TRANSTAGE R/B' at 0x7fe62f9bc738>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9bc8a0>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9bca08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bcb70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bccd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bce40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be5d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9be8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bea08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9beb70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9becd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9bee40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c05d0>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9c0738>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9c08a0>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9c0a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c0e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c25d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c28a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c2cd8>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9c2e40>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9c5030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c55d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5738>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f9c58a0>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9c5a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9c5e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948300>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f948468>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9485d0>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f948738>,
#  <ephem.EarthSatellite 'COSMOS 375 DEB' at 0x7fe62f9488a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f948e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a5d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94a8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94aa08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94ab70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94acd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94ae40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d5d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94d8a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94da08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94db70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94dcd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f94de40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9505d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9508a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f950b70>,
#  <ephem.EarthSatellite 'COSMOS 381' at 0x7fe62f950cd8>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f950e40>,
#  <ephem.EarthSatellite 'COSMOS 382' at 0x7fe62f952030>,
#  <ephem.EarthSatellite 'SL-12 R/B(AUX MOTOR)' at 0x7fe62f952198>,
#  <ephem.EarthSatellite 'SL-12 R/B(AUX MOTOR)' at 0x7fe62f952300>,
#  <ephem.EarthSatellite 'NOAA 1' at 0x7fe62f952468>,
#  <ephem.EarthSatellite 'DELTA 1 R/B(CEP 1)' at 0x7fe62f9525d0>,
#  <ephem.EarthSatellite 'COSMOS 385' at 0x7fe62f952738>,
#  <ephem.EarthSatellite 'SL-8 R/B' at 0x7fe62f9528a0>,
#  <ephem.EarthSatellite 'SL-3 R/B' at 0x7fe62f952a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f952b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f952cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f952e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955198>,
#  <ephem.EarthSatellite 'COSMOS 374 DEB' at 0x7fe62f955300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955468>,
#  <ephem.EarthSatellite 'OPS 0100 DEB *' at 0x7fe62f9555d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9558a0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955a08>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955b70>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955cd8>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f955e40>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f958030>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f958198>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f958300>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f958468>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9585d0>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f958738>,
#  <ephem.EarthSatellite 'THORAD AGENA D DEB' at 0x7fe62f9588a0>,
#  <ephem.EarthSatellite 'INTELSAT 4-F2' at 0x7fe62f958a08>,
#  ...]

# %%
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()

print a, b, c
# Out:
# SERT 2
# 1  4327U 70009A   17289.34999977 -.00000034 +00000-0 +10907-4 0  9995
# 2  4327 099.3073 016.7782 0005773 093.5068 316.1266 13.58468510363539

# %%
# %%writefile SatInfo.py
from itertools import izip, islice
from time import sleep
def satinfo():
    search_string = raw_input("Load : ")
    with open('visual.txt', 'r') as infile, open('visual.tmp', 'w') as outfile:
        for line in infile:
            if search_string in line:
                outfile.writelines([line, next(infile), next(infile)])

    from time import sleep
    with open('visual.tmp', 'r') as f:
        while True:
                name = f.readline()
                one = f.readline()
                two = f.readline()
                sleep(1)
                return name, one, two    
                         
def prntlist():            
    from time import sleep
    with open('visual.txt', 'r') as f:
        while True:
            next_n_lines = list(islice(f, 3))
            if not next_n_lines:
                break
            sleep(.5)
            print next_n_lines[0],
        
def reuse():
    from time import sleep
    with open('visual.tmp', 'r') as f:
        while True:
                name = f.readline()
                one = f.readline()
                two = f.readline()
                sleep(1)
                #print name, one, two    
                f.close()
                return name, one, two
# Out:
# Overwriting SatInfo.py

# %% [markdown]
# # Generating visual.tmp - The Satilite File

# %%
import SatInfo
a,b,c = SatInfo.reuse()

# %% [markdown]
# # List the Satilites in visual.txt

# %%
import SatInfo
SatInfo.prntlist()

# %% [markdown]
# # Using the Generated Satilite info file

# %%
import SatInfo
a,b,c = SatInfo.reuse()

# %%
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()

sat = EarthSatellite(b, c, a)
print(sat.epoch.utc_jpl())
# Out:
# A.D. 2017-Oct-16 08:23:59.9801 UT

# %% [markdown]
# # Using Module SatInfo

# %%
from skyfield.api import EarthSatellite
import SatInfo
a,b,c = SatInfo.reuse()
#print a,b,c
#text = """
#GOCE
#1 34602U 09013A   13314.96046236  .14220718  20669-5  50412-4 0   930
#2 34602 096.5717 344.5256 0009826 296.2811 064.0942 16.58673376272979
#"""
#lines = text.strip().splitlines()
sat = EarthSatellite(b, c, a)
#sat = EarthSatellite(lines[1], lines[2], lines[0])
print(sat.epoch.utc_jpl())
# Out:
# A.D. 2017-Oct-16 08:23:59.9801 UT

# %%
from skyfield.api import EarthSatellite
text = """
GOCE
1 34602U 09013A   13314.96046236  .14220718  20669-5  50412-4 0   930
2 34602 096.5717 344.5256 0009826 296.2811 064.0942 16.58673376272979
"""
lines = text.strip().splitlines()

sat = EarthSatellite(lines[1], lines[2], lines[0])
print(sat.epoch.utc_jpl())
# Out:
# A.D. 2013-Nov-10 23:03:03.9479 UT

# %%
geocentric = sat.at(ts.utc(2013, 11, 9))
print('Before:')
print(geocentric.position.km)
print(geocentric.message)

geocentric = sat.at(ts.utc(2013, 11, 13))
print('\nAfter:')
print(geocentric.position.km)
print(geocentric.message)
# Out:
# Before:
# [ nan  nan  nan]
# mean eccentricity -0.001416 not within range 0.0 <= e < 1.0
#
# After:
# [ nan  nan  nan]
# mrt 0.997178 is less than 1.0 indicating the satellite has decayed

# %%
from pprint import pprint

geocentric = sat.at(ts.utc(2013, 11, [9, 10, 11, 12, 13]))
pprint(geocentric.message)
# Out:
# ['mean eccentricity -0.001416 not within range 0.0 <= e < 1.0',
#  None,
#  None,
#  None,
#  'mrt 0.997178 is less than 1.0 indicating the satellite has decayed']

# %%
"""
XKCD plot generator
-------------------
Author: Jake Vanderplas

This is a script that will take any matplotlib line diagram, and convert it
to an XKCD-style plot.  It will work for plots with line & text elements,
including axes labels and titles (but not axes tick labels).

The idea for this comes from work by Damon McDougall
  http://www.mail-archive.com/matplotlib-users@lists.sourceforge.net/msg25499.html
"""
import numpy as np
import pylab as pl
from scipy import interpolate, signal
import matplotlib.font_manager as fm


# We need a special font for the code below.  It can be downloaded this way:
import os
import urllib2
if not os.path.exists('Humor-Sans.ttf'):
    fhandle = urllib2.urlopen('http://antiyawn.com/uploads/Humor-Sans-1.0.ttf')
    open('Humor-Sans.ttf', 'wb').write(fhandle.read())

    
def xkcd_line(x, y, xlim=None, ylim=None,
              mag=1.0, f1=30, f2=0.05, f3=15):
    """
    Mimic a hand-drawn line from (x, y) data

    Parameters
    ----------
    x, y : array_like
        arrays to be modified
    xlim, ylim : data range
        the assumed plot range for the modification.  If not specified,
        they will be guessed from the  data
    mag : float
        magnitude of distortions
    f1, f2, f3 : int, float, int
        filtering parameters.  f1 gives the size of the window, f2 gives
        the high-frequency cutoff, f3 gives the size of the filter
    
    Returns
    -------
    x, y : ndarrays
        The modified lines
    """
    x = np.asarray(x)
    y = np.asarray(y)
    
    # get limits for rescaling
    if xlim is None:
        xlim = (x.min(), x.max())
    if ylim is None:
        ylim = (y.min(), y.max())

    if xlim[1] == xlim[0]:
        xlim = ylim
        
    if ylim[1] == ylim[0]:
        ylim = xlim

    # scale the data
    x_scaled = (x - xlim[0]) * 1. / (xlim[1] - xlim[0])
    y_scaled = (y - ylim[0]) * 1. / (ylim[1] - ylim[0])

    # compute the total distance along the path
    dx = x_scaled[1:] - x_scaled[:-1]
    dy = y_scaled[1:] - y_scaled[:-1]
    dist_tot = np.sum(np.sqrt(dx * dx + dy * dy))

    # number of interpolated points is proportional to the distance
    Nu = int(200 * dist_tot)
    u = np.arange(-1, Nu + 1) * 1. / (Nu - 1)

    # interpolate curve at sampled points
    k = min(3, len(x) - 1)
    res = interpolate.splprep([x_scaled, y_scaled], s=0, k=k)
    x_int, y_int = interpolate.splev(u, res[0]) 

    # we'll perturb perpendicular to the drawn line
    dx = x_int[2:] - x_int[:-2]
    dy = y_int[2:] - y_int[:-2]
    dist = np.sqrt(dx * dx + dy * dy)

    # create a filtered perturbation
    coeffs = mag * np.random.normal(0, 0.01, len(x_int) - 2)
    b = signal.firwin(f1, f2 * dist_tot, window=('kaiser', f3))
    response = signal.lfilter(b, 1, coeffs)

    x_int[1:-1] += response * dy / dist
    y_int[1:-1] += response * dx / dist

    # un-scale data
    x_int = x_int[1:-1] * (xlim[1] - xlim[0]) + xlim[0]
    y_int = y_int[1:-1] * (ylim[1] - ylim[0]) + ylim[0]
    
    return x_int, y_int


def XKCDify(ax, mag=1.0,
            f1=50, f2=0.01, f3=15,
            bgcolor='w',
            xaxis_loc=None,
            yaxis_loc=None,
            xaxis_arrow='+',
            yaxis_arrow='+',
            ax_extend=0.1,
            expand_axes=False):
    """Make axis look hand-drawn

    This adjusts all lines, text, legends, and axes in the figure to look
    like xkcd plots.  Other plot elements are not modified.
    
    Parameters
    ----------
    ax : Axes instance
        the axes to be modified.
    mag : float
        the magnitude of the distortion
    f1, f2, f3 : int, float, int
        filtering parameters.  f1 gives the size of the window, f2 gives
        the high-frequency cutoff, f3 gives the size of the filter
    xaxis_loc, yaxis_log : float
        The locations to draw the x and y axes.  If not specified, they
        will be drawn from the bottom left of the plot
    xaxis_arrow, yaxis_arrow : str
        where to draw arrows on the x/y axes.  Options are '+', '-', '+-', or ''
    ax_extend : float
        How far (fractionally) to extend the drawn axes beyond the original
        axes limits
    expand_axes : bool
        if True, then expand axes to fill the figure (useful if there is only
        a single axes in the figure)
    """
    # Get axes aspect
    ext = ax.get_window_extent().extents
    aspect = (ext[3] - ext[1]) / (ext[2] - ext[0])

    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    xspan = xlim[1] - xlim[0]
    yspan = ylim[1] - xlim[0]

    xax_lim = (xlim[0] - ax_extend * xspan,
               xlim[1] + ax_extend * xspan)
    yax_lim = (ylim[0] - ax_extend * yspan,
               ylim[1] + ax_extend * yspan)

    if xaxis_loc is None:
        xaxis_loc = ylim[0]

    if yaxis_loc is None:
        yaxis_loc = xlim[0]

    # Draw axes
    xaxis = pl.Line2D([xax_lim[0], xax_lim[1]], [xaxis_loc, xaxis_loc],
                      linestyle='-', color='k')
    yaxis = pl.Line2D([yaxis_loc, yaxis_loc], [yax_lim[0], yax_lim[1]],
                      linestyle='-', color='k')

    # Label axes3, 0.5, 'hello', fontsize=14)
    ax.text(xax_lim[1], xaxis_loc - 0.02 * yspan, ax.get_xlabel(),
            fontsize=14, ha='right', va='top', rotation=12)
    ax.text(yaxis_loc - 0.02 * xspan, yax_lim[1], ax.get_ylabel(),
            fontsize=14, ha='right', va='top', rotation=78)
    ax.set_xlabel('')
    ax.set_ylabel('')

    # Add title
    ax.text(0.5 * (xax_lim[1] + xax_lim[0]), yax_lim[1],
            ax.get_title(),
            ha='center', va='bottom', fontsize=16)
    ax.set_title('')

    Nlines = len(ax.lines)
    lines = [xaxis, yaxis] + [ax.lines.pop(0) for i in range(Nlines)]

    for line in lines:
        x, y = line.get_data()

        x_int, y_int = xkcd_line(x, y, xlim, ylim,
                                 mag, f1, f2, f3)

        # create foreground and background line
        lw = line.get_linewidth()
        line.set_linewidth(2 * lw)
        line.set_data(x_int, y_int)

        # don't add background line for axes
        if (line is not xaxis) and (line is not yaxis):
            line_bg = pl.Line2D(x_int, y_int, color=bgcolor,
                                linewidth=8 * lw)

            ax.add_line(line_bg)
        ax.add_line(line)

    # Draw arrow-heads at the end of axes lines
    arr1 = 0.03 * np.array([-1, 0, -1])
    arr2 = 0.02 * np.array([-1, 0, 1])

    arr1[::2] += np.random.normal(0, 0.005, 2)
    arr2[::2] += np.random.normal(0, 0.005, 2)

    x, y = xaxis.get_data()
    if '+' in str(xaxis_arrow):
        ax.plot(x[-1] + arr1 * xspan * aspect,
                y[-1] + arr2 * yspan,
                color='k', lw=2)
    if '-' in str(xaxis_arrow):
        ax.plot(x[0] - arr1 * xspan * aspect,
                y[0] - arr2 * yspan,
                color='k', lw=2)

    x, y = yaxis.get_data()
    if '+' in str(yaxis_arrow):
        ax.plot(x[-1] + arr2 * xspan * aspect,
                y[-1] + arr1 * yspan,
                color='k', lw=2)
    if '-' in str(yaxis_arrow):
        ax.plot(x[0] - arr2 * xspan * aspect,
                y[0] - arr1 * yspan,
                color='k', lw=2)

    # Change all the fonts to humor-sans.
    prop = fm.FontProperties(fname='Humor-Sans.ttf', size=16)
    for text in ax.texts:
        text.set_fontproperties(prop)
    
    # modify legend
    leg = ax.get_legend()
    if leg is not None:
        leg.set_frame_on(False)
        
        for child in leg.get_children():
            if isinstance(child, pl.Line2D):
                x, y = child.get_data()
                child.set_data(xkcd_line(x, y, mag=10, f1=100, f2=0.001))
                child.set_linewidth(2 * child.get_linewidth())
            if isinstance(child, pl.Text):
                child.set_fontproperties(prop)
    
    # Set the axis limits
    ax.set_xlim(xax_lim[0] - 0.1 * xspan,
                xax_lim[1] + 0.1 * xspan)
    ax.set_ylim(yax_lim[0] - 0.1 * yspan,
                yax_lim[1] + 0.1 * yspan)

    # adjust the axes
    ax.set_xticks([])
    ax.set_yticks([])      

    if expand_axes:
        ax.figure.set_facecolor(bgcolor)
        ax.set_axis_off()
        ax.set_position([0, 0, 1, 1])
    
    return ax

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jack/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['text', 'datetime', 'load']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
np.random.seed(0)

ax = pylab.axes()

x = np.linspace(0, 10, 100)
ax.plot(x, np.sin(x) * np.exp(-0.1 * (x - 5) ** 2), 'b', lw=1, label='damped sine')
ax.plot(x, -np.cos(x) * np.exp(-0.1 * (x - 5) ** 2), 'r', lw=1, label='damped cosine')

ax.set_title('check it out!')
ax.set_xlabel('x label')
ax.set_ylabel('y label')

ax.legend(loc='lower right')

ax.set_xlim(0, 10)
ax.set_ylim(-1.0, 1.0)

#XKCDify the axes -- this operates in-place
XKCDify(ax, xaxis_loc=0.0, yaxis_loc=1.0,
        xaxis_arrow='+-', yaxis_arrow='+-',
        expand_axes=True)

# %%
# Some helper functions
def norm(x, x0, sigma):
    return np.exp(-0.5 * (x - x0) ** 2 / sigma ** 2)

def sigmoid(x, x0, alpha):
    return 1. / (1. + np.exp(- (x - x0) / alpha))
    
# define the curves
x = np.linspace(0, 1, 100)
y1 = np.sqrt(norm(x, 0.7, 0.05)) + 0.2 * (1.5 - sigmoid(x, 0.8, 0.05))

y2 = 0.2 * norm(x, 0.5, 0.2) + np.sqrt(norm(x, 0.6, 0.05)) + 0.1 * (1 - sigmoid(x, 0.75, 0.05))

y3 = 0.05 + 1.4 * norm(x, 0.85, 0.08)
y3[x > 0.85] = 0.05 + 1.4 * norm(x[x > 0.85], 0.85, 0.3)

# draw the curves
ax = pl.axes()
ax.plot(x, y1, c='gray')
ax.plot(x, y2, c='blue')
ax.plot(x, y3, c='red')

ax.text(0.3, -0.1, "Yard")
ax.text(0.5, -0.1, "Steps")
ax.text(0.7, -0.1, "Door")
ax.text(0.9, -0.1, "Inside")

ax.text(0.05, 1.1, "fear that\nthere's\nsomething\nbehind me")
ax.plot([0.15, 0.2], [1.0, 0.2], '-k', lw=0.5)

ax.text(0.25, 0.8, "forward\nspeed")
ax.plot([0.32, 0.35], [0.75, 0.35], '-k', lw=0.5)

ax.text(0.9, 0.4, "embarrassment")
ax.plot([1.0, 0.8], [0.55, 1.05], '-k', lw=0.5)

ax.set_title("Walking back to my\nfront door at night:")

ax.set_xlim(0, 1)
ax.set_ylim(0, 1.5)

# modify all the axes elements in-place
XKCDify(ax, expand_axes=True)

# %%
def alt_lonlat(lon, lat, t):

    topo = earth.topos(lat, lon)

    alt, az, dist = topo.at(trise).observe(sun).apparent().altaz() ## apparent() args for atmospheric refraction

    return alt.degrees


from skyfield.api import load
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as spo

data  = load('de421.bsp')
ts    = load.timescale()

# your example:  '2014-08-27', sunset = '10:00 PM', sunrise = '7:30 AM'

trise  = ts.utc(2014, 8, 27,  7, 30, 0)
tset   = ts.utc(2014, 8, 27, 22,  0, 0)

earth = data['earth']
sun   = data['sun']

zerozero = earth.topos(0.0, 0.0)   # gotta start looking somewhere!

alt, az, dist = zerozero.at(trise).observe(sun).apparent().altaz() ## apparent() args for atmospheric refraction

print "at trise, JD = ", trise.tt
print "at (0N, 0E) Sun's altitude: ", alt.degrees, "azimuth: ", az.degrees
print "at (0N, 0E) Sun's distance (km): ", dist.km

# Find points on equator where sun is on horizon (rise or set) at t=trise

limits   = ((0, 180.), (180, 360.))
lonzeros = []

for a, b in limits:

    answer, info = spo.brentq(alt_lonlat, a, b,
                              args=(0.0, trise),
                              full_output = True )

    if info.converged:
        lonzeros.append(answer)
        print "limits ", a, b, " converged! Found longitude (deg): ", answer
    else:
        print "limits ", a, b, "whaaaa?"
        lonzeros.append(None)

# make some curves

lats = np.linspace(-60, 60, 13)

longis = []
for lon0 in lonzeros:
    lons = []
    for lat in lats:

        answer, info = spo.brentq(alt_lonlat, lon0-90, lon0+90,
                                  args=(lat, trise),
                                  full_output = True )
        if info.converged:
            lons.append(answer)
        else:
            lons.append(None)

        lons = [(lon+180)%360.-180 for lon in lons]  # wraparound at +/- 180

    longis.append(lons)

plt.figure()

for lons in longis:
    plt.plot(lons, lats)

for lons in longis:
    plt.plot(lons, lats, 'ok')

plt.xlim(-180, 180)
plt.ylim(-90, 90)

plt.title("at trise, JD = " + str(trise.tt))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# <ipython-input-98-bf5aa8f68fb0> in <module>()
#      24 sun   = data['sun']
#      25
# ---> 26 zerozero = earth.topos(0.0, 0.0)   # gotta start looking somewhere!
#      27
#      28 alt, az, dist = zerozero.at(trise).observe(sun).apparent().altaz() ## apparent() args for atmospheric refraction
#
# /usr/local/lib/python2.7/dist-packages/skyfield/vectorlib.pyc in topos(self, latitude, longitude, latitude_degrees, longitude_degrees, elevation_m, x, y)
#     123
#     124     from skyfield.api import Topos
# --> 125     boston = earth + Topos(...)""")
#     126
#     127     def satellite(self, text):
#
# DeprecationError: the topos() method has, alas, been deprecated
#
# This old method has been replaced by an improved interface.  If you just
# need your software working again, install Skyfield 0.9.1 for a quick fix:
#
#     pip install skyfield==0.9.1
#
# Or, to update your old code, replace each operation that looks like:
#
#     boston = earth.topos(...)
#
# with the vector math that was previously hiding inside the old method:
#
#     from skyfield.api import Topos
#     boston = earth + Topos(...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from   skyfield.api import load, JulianDate
import time

ephem = 'de421.bsp'
ephem = 'de405.bsp'

de = load(ephem)  

earth            = de['earth']
moon             = de['moon']
earth_barycenter = de['earth barycenter']
mercury          = de['mercury']
jupiter          = de['jupiter barycenter']
pluto            = de['pluto barycenter']

things = [ earth,   moon,   earth_barycenter,   mercury,   jupiter,   pluto ]
names  = ['earth', 'moon', 'earth barycenter', 'mercury', 'jupiter', 'pluto']

ntimes = [i*10**n for n in range(5) for i in [1, 2, 5]]

years  = [np.zeros(1)] + [np.linspace(0, 100, n) for n in ntimes[1:]] # 100 years

microsecs = []
for y in years:

    from skyfield.api import load
    ts = load.timescale()
    t = ts.utc(1980, 4, 20)       # the new way

    jd = ts.tt(jd=2444349.500592)  # jd is also supported for tai, tt, tdb
    
    # Depreciated
    #jd = JulianDate(utc=(1900 + y, 1, 1))
    mics = []
    for thing in things:

        tstart = time.clock()
        answer = thing.at(jd).position.km
        mics.append(1E+06 * (time.clock() - tstart))

    microsecs.append(mics)

microsecs = np.array(microsecs).T

many = [len(y) for y in years]


fig = plt.figure(figsize=(10, 8))
ax  = plt.subplot(111, xlabel='length of JD object',
                       ylabel='microseconds',
                       title='time for thing.at(jd).position.km with ' + ephem )

for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(item.get_fontsize() + 4) # http://stackoverflow.com/a/14971193/3904031

for name, mics in zip(names, microsecs):
    ax.plot(many, mics, lw=2, label=name)
plt.legend(loc='upper left', shadow=False, fontsize='x-large')
plt.xscale('log')
plt.yscale('log')
plt.savefig("skyfield speed test " + ephem.split('.')[0])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from jplephem.spk import SPK
import time

ephem = 'de421.bsp'
ephem = 'de405.bsp'

kernel = SPK.open(ephem)

jd_1900_01_01 = 2415020.5004882407

ntimes = [i*10**n for n in range(5) for i in [1, 2, 5]]

years  = [np.zeros(1)] + [np.linspace(0, 100, n) for n in ntimes[1:]] # 100 years

barytup  = (0, 3)
earthtup = (3, 399)
# moontup  = (3, 301)

microsecs = []
for y in years:
    mics = []
    #for thing in things:

    jd = jd_1900_01_01 + y * 365.25 # roughly, it doesn't matter here

    tstart = time.clock()
    answer = kernel[earthtup].compute(jd) + kernel[barytup].compute(jd)
    mics.append(1E+06 * (time.clock() - tstart))

    microsecs.append(mics)

microsecs = np.array(microsecs)

many = [len(y) for y in years]

fig = plt.figure()
ax  = plt.subplot(111, xlabel='length of JD object',
                       ylabel='microseconds',
                       title='time for jplephem [0,3] and [3,399] with ' + ephem )

#   from here: http://stackoverflow.com/a/14971193/3904031
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(item.get_fontsize() + 4)

#for name, mics in zip(names, microsecs):
ax.plot(many, microsecs, lw=2, label='earth')
plt.legend(loc='upper left', shadow=False, fontsize='x-large')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1E+02, 1E+06)

plt.savefig("jplephem speed test " + ephem.split('.')[0])

plt.show()

# %%
"""Vector functions and their composition."""

from numpy import max, min
from .constants import C_AUDAY
from .errors import DeprecationError, raise_error_for_deprecated_time_arguments
from .functions import length_of
from .positionlib import build_position
from .timelib import Time

class VectorFunction(object):
    """Given a time, computes a corresponding position."""

    ephemeris = None

    def __add__(self, other):
        if self.target != other.center:
            if other.target == self.center:
                self, other = other, self
            else:
                raise ValueError(
                    "you can only add two vectors"
                    " if the target where one of the vectors ends"
                    " is the center where the other vector starts"
                )

        selfp = getattr(self, 'positives', None) or (self,)
        selfn = getattr(self, 'negatives', ())

        otherp = getattr(other, 'positives', None) or (other,)
        othern = getattr(other, 'negatives', ())

        return VectorSum(self.center, other.target,
                         self.center_name, other.target_name,
                         selfp + otherp, selfn + othern)

    def __sub__(self, other):
        if self.center != other.center:
            raise ValueError(
                "you can only subtract two vectors"
                " if they both start at the same center"
            )

        selfp = getattr(self, 'positives', None) or (self,)
        selfn = getattr(self, 'negatives', ())

        otherp = getattr(other, 'positives', None) or (other,)
        othern = getattr(other, 'negatives', ())

        return VectorSum(other.target, self.target,
                         self.target_name, other.target_name,
                         selfp + othern, selfn + otherp)

    @raise_error_for_deprecated_time_arguments
    def at(self, t):
        """At time ``t``, compute the target's position relative to the center.

        If ``t`` is an array of times, then the returned position object
        will specify as many positions as there were times.  The kind of
        position returned depends on the value of the ``center``
        attribute:

        * Solar System Barycenter: :class:`~skyfield.positionlib.Barycentric`
        * Center of the Earth: :class:`~skyfield.positionlib.Geocentric`
        * Difference: :class:`~skyfield.positionlib.Geometric`
        * Anything else: :class:`~skyfield.positionlib.ICRF`

        """
        if not isinstance(t, Time):
            raise ValueError('please provide the at() method with a Time'
                             ' instance as its argument, instead of the'
                             ' value {0!r}'.format(t))
        observer_data = ObserverData()
        observer_data.ephemeris = self.ephemeris
        p, v, observer_data.gcrs_position, message = self._at(t)
        center = self.center
        if center == 0:
            observer_data.bcrs_position = p
            observer_data.bcrs_velocity = v
        self._snag_observer_data(observer_data, t)
        position = build_position(p, v, t, center, self.target, observer_data)
        position.message = message
        return position

    def _snag_observer_data(self, data, t):
        pass

    def _observe_from_bcrs(self, observer):
        assert self.center == 0
        return _correct_for_light_travel_time(observer, self)

    def geometry_of(self, other):
        raise DeprecationError(
"""the geometry_of() method has, alas, been deprecated

This old method has been replaced by an improved interface.  If you just
need your software working again, install Skyfield 0.9.1 for a quick fix:

    pip install skyfield==0.9.1

Or, to update your old code, replace each operation that looks like:

    position = boston.geometry_of(satellite).at(t)

with the vector math that was previously hiding inside the old method:

    position = (satellite - boston).at(t)""")

    def topos(self, latitude=None, longitude=None, latitude_degrees=None,
              longitude_degrees=None, elevation_m=0.0, x=0.0, y=0.0):
        raise DeprecationError(
"""the topos() method has, alas, been deprecated

This old method has been replaced by an improved interface.  If you just
need your software working again, install Skyfield 0.9.1 for a quick fix:

    pip install skyfield==0.9.1

Or, to update your old code, replace each operation that looks like:

    boston = earth.topos(...)

with the vector math that was previously hiding inside the old method:

    from skyfield.api import Topos
    boston = earth + Topos(...)""")

    def satellite(self, text):
        raise DeprecationError(
"""the satellite() method has, alas, been deprecated

This old method has been replaced by an improved interface.  If you just
need your software working again, install Skyfield 0.9.1 for a quick fix:

    pip install skyfield==0.9.1

Or, to update your old code, replace each operation that looks like:

    sat = earth.satellite(tle_text)

with the vector math (and the little bit of text manipulation) that was
previously hiding inside the old method:

    from skyfield.api import EarthSatellite
    line1, line2 = tle_text.splitlines()[-2:]
    sat = earth + EarthSatellite(line1, line2)""")


class VectorSum(VectorFunction):
    def __init__(self, center, target, center_name, target_name,
                 positives, negatives):
        self.center = center
        self.target = target
        self.center_name = center_name
        self.target_name = target_name
        self.positives = positives
        self.negatives = negatives

        # For now, just grab the first ephemeris we can find.
        ephemerides = (segment.ephemeris for segments in (positives, negatives)
                       for segment in segments if segment.ephemeris)
        self.ephemeris = next(ephemerides, None)

    def __str__(self):
        positives = self.positives
        negatives = self.negatives
        lines = [' - ' + str(segment) for segment in reversed(negatives)]
        lines.extend(' + ' + str(segment) for segment in positives)
        return 'Sum of {0} vectors:\n{1}'.format(
            len(positives) + len(negatives),
            '\n'.join(lines),
        )

    def __repr__(self):
        return '<{0} of {1} vectors {2} -> {3}>'.format(
            type(self).__name__,
            len(self.positives) + len(self.negatives),
            self.center_name,
            self.target_name,
        )

    def _at(self, t):
        p, v = 0.0, 0.0
        for segment in self.positives:
            p2, v2, gcrs_position, message = segment._at(t)
            p += p2
            v += v2
        for segment in self.negatives:
            p2, v2, gcrs_position, ignored_message = segment._at(t)
            p -= p2
            v -= v2
        return p, v, gcrs_position, message

    def _snag_observer_data(self, observer_data, t):
        if self.negatives:
            final_segment = self.negatives[-1]
        elif self.positives:
            final_segment = self.positives[-1]
        final_segment._snag_observer_data(observer_data, t)


def _correct_for_light_travel_time(observer, target):
    """Return a light-time corrected astrometric position and velocity.

    Given an `observer` that is a `Barycentric` position somewhere in
    the solar system, compute where in the sky they will see the body
    `target`, by computing the light-time between them and figuring out
    where `target` was back when the light was leaving it that is now
    reaching the eyes or instruments of the `observer`.

    """
    t = observer.t
    ts = t.ts
    cposition = observer.position.au
    cvelocity = observer.velocity.au_per_d
    tposition, tvelocity, gcrs_position, message = target._at(t)
    distance = length_of(tposition - cposition)
    light_time0 = 0.0
    t_tdb = t.tdb
    for i in range(10):
        light_time = distance / C_AUDAY
        delta = light_time - light_time0
        if -1e-12 < min(delta) and max(delta) < 1e-12:
            break
        t2 = ts.tdb(jd=t_tdb - light_time)
        tposition, tvelocity, gcrs_position, message = target._at(t2)
        distance = length_of(tposition - cposition)
        light_time0 = light_time
    else:
        raise ValueError('light-travel time failed to converge')
    return tposition - cposition, tvelocity - cvelocity, light_time


class ObserverData(object):
    """Essential facts about an observer, that may be needed later."""
    # TODO: expand the documentation for this class

    __slots__ = ('altaz_rotation', 'elevation_m', 'ephemeris',
                 'gcrs_position', 'bcrs_position', 'bcrs_velocity')

    def __init__(self):
        self.altaz_rotation = None
        self.elevation_m = None
        self.ephemeris = None
        self.gcrs_position = None
        self.bcrs_position = None
        self.bcrs_velocity = None
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-225-c19e7f97cef5> in <module>()
#       2
#       3 from numpy import max, min
# ----> 4 from .constants import C_AUDAY
#       5 from .errors import DeprecationError, raise_error_for_deprecated_time_arguments
#       6 from .functions import length_of
#
# ValueError: Attempted relative import in non-package

# %%
import sqlite3
import base64
conn = sqlite3.connect('snippet.db') 
c = conn.cursor()
conn.text_factory = str
file = """
# %load SearchFilename.py
'''
Search a filename for a phrase and how many following lines to display
USAGE:
import SearchFilename
filename = "hek.txt"
length = 4
SearchFilename.searchfilename(filename, length)
'''
def searchfilename(filename, length):
    f = open(filename, "r")
    searchlines = f.readlines()
    f.close()
    search = str(raw_input("Search Phrase : "))
    for i, line in enumerate(searchlines):
        if search in line: 
            for l in searchlines[i:i+length]: print l,
            print
            
#USAGE:
import SearchFilename
filename = "ALL_WIKI_GOOD.txt"
# length = how many lines after
length = 7
SearchFilename.searchfilename(filename, length) 
"""
keywords = "store, retrieve images, from SQLite Database"
encodedlistvalue=base64.b64encode(file)
c.execute("INSERT INTO snippet VALUES (?,?,?)", (encodedlistvalue, file, keywords))
conn.commit()
conn.close()
